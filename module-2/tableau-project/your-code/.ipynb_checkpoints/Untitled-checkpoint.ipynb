# %%
import pandas as pd
from pymongo import MongoClient
import googlemaps

# %%
client = MongoClient()
db = client.Companies
comp = db.Companies
#AIzaSyADyT-RAq5sre6oRVbR_2jJZEqp7DbYSko

# %%
gmaps = googlemaps.Client(key='AIzaSyADyT-RAq5sre6oRVbR_2jJZEqp7DbYSko')
place = 'https://maps.googleapis.com/maps/api/place/textsearch/json?query=123+main+street&key=AIzaSyADyT-RAq5sre6oRVbR_2jJZEqp7DbYSko'

# %%
place
# Out:
# 'https://maps.googleapis.com/maps/api/place/textsearch/json?query=123+main+street&key=AIzaSyADyT-RAq5sre6oRVbR_2jJZEqp7DbYSko'

# %%
list(comp.find().limit(10))
# Out:
# [{'_id': ObjectId('52cdef7c4bab8bd675297d8a'),
#   'name': 'Wetpaint',
#   'permalink': 'abc2',
#   'crunchbase_url': 'http://www.crunchbase.com/company/wetpaint',
#   'homepage_url': 'http://wetpaint-inc.com',
#   'blog_url': 'http://digitalquarters.net/',
#   'blog_feed_url': 'http://digitalquarters.net/feed/',
#   'twitter_username': 'BachelrWetpaint',
#   'category_code': 'web',
#   'number_of_employees': 47,
#   'founded_year': 2005,
#   'founded_month': 10,
#   'founded_day': 17,
#   'deadpooled_year': 1,
#   'tag_list': 'wiki, seattle, elowitz, media-industry, media-platform, social-distribution-system',
#   'alias_list': '',
#   'email_address': 'info@wetpaint.com',
#   'phone_number': '206.859.6300',
#   'description': 'Technology Platform Company',
#   'created_at': datetime.datetime(2007, 5, 25, 6, 51, 27),
#   'updated_at': 'Sun Dec 08 07:15:44 UTC 2013',
# ...

# %% [markdown]
# """
# definicion de el cliente: un cliente esta pidiendo un lugar para trabajar dentro de usa en el cual tenga cerca
# restaurantes, cafeterias y zonas de negocios, ya que quiere que sus empleados se encuentren comodos dentro del
# lugar en el que trabajan y que su zona de movimiento no sea mayor a 500 mts, el negocio se quiere establecer dentro
# de los EUA y si año de fundacion debe ser mayor a 2008, la adquisition debe ser none ya que si una empresa esta
# iniciando no debe haber sido, por lo general adquirida por nadie
#
# # promedio de caminata de una persona al dia es de 5km/hr
# """

# %%
# una persona promedio camina 5km/hr 
# la persona promedio esta dispuesta a caminar solamente 1/4 de hora como maximo para ir a comer
cam = 1/5
cam
# Out:
# 0.2

# %%
# query para sacar los parametros que se necesitan para 
df = list(comp.find({'deadpooled_year':None,
               'founded_year':{'$gt':2008},
               'category_code':'web',
               'acquisition':None,
               'number_of_employees':{'$gt':20}},
              {'_id':0,'name':1,'number_of_employees':1,'founded_year':1,'total_money_raised':1,'offices.latitude':1,'offices.longitude':1,'offices.country_code':1}))

# %%
# empresas que si tienen latitud y longitud
new_df = pd.DataFrame(df)
new_df.drop(1)
# Out:
#             name  number_of_employees  founded_year total_money_raised  \
# 0          Fixya                   30          2013                $8M
# 2  BrandYourself                   22          2009              $1.5M
# 3          Yipit                   23          2010             $7.55M
#
#                                              offices
# 0  [{'country_code': 'USA', 'latitude': 37.566879...
# 2  [{'country_code': 'USA', 'latitude': 42.275263...
# 3  [{'country_code': 'USA', 'latitude': 40.744618...

# %%
lst = []
for i in df:
    lst.append(i['offices'])
lst.pop(1)
new_lst = []
for i in range(len(lst)):
    new_lst.append(lst[i][0])
lat = []
long = []
for i in new_lst:
    lat.append(i['latitude'])
    long.append(i['longitude'])
    
df = list(zip(lat,long))
df = pd.DataFrame(df)
lst_df = [new_df,df]
pd.concat(lst_df)
# Out:
#            0           1  founded_year           name  number_of_employees  \
# 0        NaN         NaN        2013.0          Fixya                 30.0
# 1        NaN         NaN        2013.0          Wamba                120.0
# 2        NaN         NaN        2009.0  BrandYourself                 22.0
# 3        NaN         NaN        2010.0          Yipit                 23.0
# 0  37.566879 -122.323895           NaN            NaN                  NaN
# 1  42.275263  -71.247620           NaN            NaN                  NaN
# 2  40.744618  -73.987764           NaN            NaN                  NaN
#
#                                              offices total_money_raised
# 0  [{'country_code': 'USA', 'latitude': 37.566879...                $8M
# 1                                                 []                €3M
# 2  [{'country_code': 'USA', 'latitude': 42.275263...              $1.5M
# 3  [{'country_code': 'USA', 'latitude': 40.744618...             $7.55M
# ...

# %%
import pandas as pd
from pymongo import MongoClient
import folium
from pandas.io.json import json_normalize
from folium.plugins import HeatMap
from folium.plugins import HeatMap

# %%
client = MongoClient()
db = client.Companies
comp = db.Companies

# %%
df = pd.DataFrame(comp.find({'category_code':'web','offices.0.country_code':'USA'},
                                {'_id':0, 'name':1, 'offices':1, 'category_code':1, 'founded_year':1}))
df.offices[0]
# Out:
# [{'description': '',
#   'address1': '710 - 2nd Avenue',
#   'address2': 'Suite 1100',
#   'zip_code': '98104',
#   'city': 'Seattle',
#   'state_code': 'WA',
#   'country_code': 'USA',
#   'latitude': 47.603122,
#   'longitude': -122.333253},
#  {'description': '',
#   'address1': '270 Lafayette Street',
#   'address2': 'Suite 505',
#   'zip_code': '10012',
#   'city': 'New York',
#   'state_code': 'NY',
#   'country_code': 'USA',
#   'latitude': 40.7237306,
#   'longitude': -73.9964312}]

# %%
df['offices'] = df['offices'].apply(lambda x: x[0])
df.head()
# Out:
#                     name category_code  founded_year  \
# 0               Wetpaint           web        2005.0
# 1                Postini           web        1999.0
# 2                   Geni           web        2006.0
# 3  Fox Interactive Media           web        1979.0
# 4            StumbleUpon           web        2002.0
#
#                                              offices
# 0  {'description': '', 'address1': '710 - 2nd Ave...
# 1  {'description': None, 'address1': '959 Skyway ...
# 2  {'description': 'Headquarters', 'address1': '9...
# 3  {'description': '', 'address1': '407 N Maple D...
# 4  {'description': '', 'address1': '', 'address2'...

# %%
df = pd.concat([json_normalize(df['offices']), df[['name' ,'category_code']]], axis=1)
df = df.dropna().reset_index()
df = df[['name','city','state_code','latitude','longitude','category_code','country_code']]
df
# Out:
#                       name            city state_code   latitude   longitude  \
# 0                 Wetpaint         Seattle         WA  47.603122 -122.333253
# 1                     Geni  West Hollywood         CA  34.090368 -118.393064
# 2    Fox Interactive Media   Beverly Hills         CA  34.076179 -118.394170
# 3              StumbleUpon   San Francisco         CA  37.775196 -122.419204
# 4                     eBay        San Jose         CA  37.295005 -121.930035
# ..                     ...             ...        ...        ...         ...
# 962          Wolfram Alpha       Champaign         IL  40.097071  -88.245638
# 963              CalFinder         Oakland         CA  37.797862 -122.277506
# 964              VestMatch         Oakland         CA  37.810448 -122.239864
# 965              VitalLock       Cambridge         MA  42.362856  -71.083762
# 966               Ubequity        Bethesda         MD  39.091071  -77.187623
#
#     category_code country_code
# 0             web          USA
# 1             web          USA
# 2             web          USA
# 3             web          USA
# 4             web          USA
# ..            ...          ...
# 962           web          USA
# 963           web          USA
# 964           web          USA
# 965           web          USA
# 966           web          USA
#
# [967 rows x 7 columns]

# %%
df
# Out:
#                       name            city state_code   latitude   longitude  \
# 0                 Wetpaint         Seattle         WA  47.603122 -122.333253
# 1                     Geni  West Hollywood         CA  34.090368 -118.393064
# 2    Fox Interactive Media   Beverly Hills         CA  34.076179 -118.394170
# 3              StumbleUpon   San Francisco         CA  37.775196 -122.419204
# 4                     eBay        San Jose         CA  37.295005 -121.930035
# ..                     ...             ...        ...        ...         ...
# 962          Wolfram Alpha       Champaign         IL  40.097071  -88.245638
# 963              CalFinder         Oakland         CA  37.797862 -122.277506
# 964              VestMatch         Oakland         CA  37.810448 -122.239864
# 965              VitalLock       Cambridge         MA  42.362856  -71.083762
# 966               Ubequity        Bethesda         MD  39.091071  -77.187623
#
#     category_code country_code
# 0             web          USA
# 1             web          USA
# 2             web          USA
# 3             web          USA
# 4             web          USA
# ..            ...          ...
# 962           web          USA
# 963           web          USA
# 964           web          USA
# 965           web          USA
# 966           web          USA
#
# [967 rows x 7 columns]

# %%
data = list(zip(df['latitude'], df['longitude']))
data = [i for i in data]
df
# Out:
#                       name            city state_code   latitude   longitude  \
# 0                 Wetpaint         Seattle         WA  47.603122 -122.333253
# 1                     Geni  West Hollywood         CA  34.090368 -118.393064
# 2    Fox Interactive Media   Beverly Hills         CA  34.076179 -118.394170
# 3              StumbleUpon   San Francisco         CA  37.775196 -122.419204
# 4                     eBay        San Jose         CA  37.295005 -121.930035
# ..                     ...             ...        ...        ...         ...
# 962          Wolfram Alpha       Champaign         IL  40.097071  -88.245638
# 963              CalFinder         Oakland         CA  37.797862 -122.277506
# 964              VestMatch         Oakland         CA  37.810448 -122.239864
# 965              VitalLock       Cambridge         MA  42.362856  -71.083762
# 966               Ubequity        Bethesda         MD  39.091071  -77.187623
#
#     category_code country_code
# 0             web          USA
# 1             web          USA
# 2             web          USA
# 3             web          USA
# 4             web          USA
# ..            ...          ...
# 962           web          USA
# 963           web          USA
# 964           web          USA
# 965           web          USA
# 966           web          USA
#
# [967 rows x 7 columns]

# %% [markdown]
# """
# Cliente que quiere concentrarse en donde se encuentran la mayoria de las empresas web dentro de los EUA, por lo que lo primero que hicimos es sacar el mapa de calor para encontrar los estados con mayor cantidad de empresas con categoria "web"
#
# """

# %%
mapa=folium.Map(location=[37.295005, -121.930035 ])
mapa.add_child(HeatMap(data))
for i in range(len(data)):
    mapa.add_child(folium.Marker([data[i][0], data[i][1]], popup=df['name'][i]))
    
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# valores que mas se repiten en el dataframe por estado, por lo que vemos que aunque en el mapa parece que existen
# mas empresas en la costa este, la mayor parte de las empresas de desarrollo web se encuentran en california(CA)
new_df = pd.DataFrame(df['state_code'].value_counts())       
new_df
# Out:
#     state_code
# CA         433
# NY         119
# WA          49
# MA          41
# TX          34
# FL          33
# IL          31
# GA          22
# VA          19
# PA          17
# CO          16
# NJ          14
# NC          13
# MD          12
# OR          12
# AZ          10
# UT           9
# TN           8
# DC           8
# MO           7
# MI           7
# IN           6
# NV           6
# CT           5
# OH           5
# VT           4
# NE           4
# IA           3
# MN           3
# KY           3
# KS           3
# OK           3
# AL           3
# ME           2
# RI           1
# DE           1
# NM           1

# %% [markdown]
# # suponemos que el cliente elige ny ya que es un punto medio entre tener muchas empresas que lleguen a competir y poder tener una red de contactos del mismo ambito de negocios

# %%
city_df = df.loc[df['state_code'] == 'NY'].reset_index()
city_df
# Out:
#      index           name       city state_code   latitude   longitude  \
# 0        5         Viacom   New York         NY  40.757725  -73.986011
# 1       35         Forbes   New York         NY  40.736416  -73.993302
# 2       39            AOL   New York         NY  40.731132  -73.991931
# 3       59        Nielsen   New York         NY  40.731118  -73.991933
# 4       74          Tutor   New York         NY  40.707921  -74.004792
# ..     ...            ...        ...        ...        ...         ...
# 114    918  CollectiveSys   Flushing         NY  40.760922  -73.830489
# 115    927       MyWealth   New York         NY  40.703826  -74.008328
# 116    937       Tinychat  Glen Cove         NY  42.375641  -72.519691
# 117    944       CogniFit   New York         NY  47.602337 -122.285011
# 118    959        Wee Web   New York         NY  40.756054  -73.986951
#
#     category_code country_code
# 0             web          USA
# 1             web          USA
# 2             web          USA
# 3             web          USA
# 4             web          USA
# ..            ...          ...
# 114           web          USA
# 115           web          USA
# 116           web          USA
# 117           web          USA
# 118           web          USA
#
# [119 rows x 8 columns]

# %%
lat_long = list(zip(city_df['latitude'], city_df['longitude']))

# %%
mapa2=folium.Map(location=[37.295005, -121.930035 ])
mapa2.add_child(HeatMap(lat_long))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for i in range(len(city_df['latitude'])):
     mapa2.add_child(folium.Marker([city_df['latitude'][i],city_df['longitude'][i]], popup=city_df['name'][i]))
     mapa2.add_child(folium.Circle([city_df['latitude'][i],city_df['longitude'][i]],radius=150))
mapa2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

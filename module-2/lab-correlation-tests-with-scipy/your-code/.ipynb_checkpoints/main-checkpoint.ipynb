# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# %matplotlib inline
# import numpy and pandas
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import re

# %% [markdown]
# # Challenge 1 - Analysis of Variance
#
# In this part of the lesson, we will perform an analysis of variance to determine whether the factors in our model create a significant difference in the group means. We will be examining a dataset of FIFA players. We'll start by loading the data using the code in the cell below.

# %%
# Run this code:

fifa = pd.read_csv('fifa.csv')

# %% [markdown]
# Let's examine the dataset by looking at the `head`.

# %%
# Your code here:

fifa.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0           L. Messi   31   Argentina       94         94
# 1  Cristiano Ronaldo   33    Portugal       94         94
# 2          Neymar Jr   26      Brazil       92         93
# 3             De Gea   27       Spain       91         93
# 4       K. De Bruyne   27     Belgium       91         92
#
#                   Club    Value Preferred Foot Position  Weak Foot  \
# 0         FC Barcelona  €110.5M           Left       RF        4.0
# 1             Juventus     €77M          Right       ST        4.0
# 2  Paris Saint-Germain  €118.5M          Right       LW        5.0
# 3    Manchester United     €72M          Right       GK        3.0
# 4      Manchester City    €102M          Right      RCM        5.0
#
#    Acceleration  SprintSpeed  Stamina  Strength  LongShots  Aggression  \
# 0          91.0         86.0     72.0      59.0       94.0        48.0
# ...

# %% [markdown]
# Player's values are expressed in millions of euros. We would like this column to be numeric. Therefore, let's create a numeric value column. Do this by stripping all non-numeric characters from each cell. Assign this new data to `ValueNumeric`. There is no need to multiply the value to be expressed in millions.

# %%
# Your code here:
fifa['ValueNumeric'] = fifa.Value.apply(lambda x: float(re.sub('[^0-9\.]','', x)))

#fifa.head()

# %%
fifa_new=fifa[['ValueNumeric','Preferred Foot','Position','Nationality']]

fifa_new = fifa_new.rename(columns={'Preferred Foot':'Pref_foot'})
fifa_new = fifa_new.dropna()
fifa_new.head()
# Out:
#    ValueNumeric Pref_foot Position Nationality
# 0         110.5      Left       RF   Argentina
# 1          77.0     Right       ST    Portugal
# 2         118.5     Right       LW      Brazil
# 3          72.0     Right       GK       Spain
# 4         102.0     Right      RCM     Belgium

# %% [markdown]
# #### We'd like to determine whether a player's preffered foot and position have an impact on their value.
#
# Using the `statsmodels` library, we are able to produce an ANOVA table without munging our data. Create an ANOVA table with value as a function of position and preferred foot. Recall that pivoting is performed by the `C` function.
#
# Hint: For columns that have a space in their name, it is best to refer to the column using the dataframe (For example: for column `A`, we will use `df['A']`).

# %%
# Your code here:
import statsmodels.api as sm
from statsmodels.formula.api import ols


model = ols('ValueNumeric ~ C(Position)*C(Pref_foot)', data=fifa_new).fit()

anova_table=sm.stats.anova_lm(model, typ=1)

anova_table

#model.summary()

#print(model.f_pvalue)
# Out:
#                                df        sum_sq        mean_sq         F  \
# C(Position)                  26.0  9.006867e+06  346417.962922  4.143877
# C(Pref_foot)                  1.0  7.292211e+04   72922.110443  0.872300
# C(Position):C(Pref_foot)     26.0  3.050243e+06  117317.045252  1.403355
# Residual                  18093.0  1.512530e+09   83597.550120       NaN
#
#                                 PR(>F)
# C(Position)               7.064170e-12
# C(Pref_foot)              3.503319e-01
# C(Position):C(Pref_foot)  8.327900e-02
# Residual                           NaN

# %% [markdown]
# What is your conclusion from this ANOVA?

# %%
# Your conclusions here:

# Null Hypothesis: The means are the same

# The P value for C(Position):C(Pref_foot) is 0.08 > .05. There si little to no correlation.
# The P value for Pref_foot is .35, p > .05 there is some correlation between pref foot and value.

# The P value for Position is 7.06 e-12 , p < .05 there is no correlation between pref foot and value.

# %% [markdown]
# After looking at a model of both preffered foot and position, we decide to create an ANOVA table for nationality. Create an ANOVA table for numeric value as a function of nationality.

# %%
# Your code here:
model = ols('ValueNumeric ~ C(Nationality)', data=fifa_new).fit()

anova_table=sm.stats.anova_lm(model, typ=1)

anova_table
# Out:
#                      df        sum_sq        mean_sq         F        PR(>F)
# C(Nationality)    163.0  4.214794e+07  258576.326284  3.136552  7.514368e-37
# Residual        17983.0  1.482513e+09   82439.668880       NaN           NaN

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           ValueNumeric   R-squared:                       0.028
# Model:                            OLS   Adj. R-squared:                  0.019
# Method:                 Least Squares   F-statistic:                     3.137
# Date:                Tue, 11 Feb 2020   Prob (F-statistic):           7.51e-37
# Time:                        16:12:03   Log-Likelihood:            -1.2838e+05
# No. Observations:               18147   AIC:                         2.571e+05
# Df Residuals:                   17983   BIC:                         2.584e+05
# Df Model:                         163
# Covariance Type:            nonrobust
# ...
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# What is your conclusion from this ANOVA?

# %%
# p value for Nationality = 7.5 e-37 < .05 --- There is no correlation between

# %% [markdown]
# # Challenge 2 - Linear Regression
#
# Our goal with using linear regression is to create a mathematical model that will enable us to predict the outcome of one variable using one or more additional independent variables.
#
# We'll start by ensuring there are no missing values. Examine all variables for all missing values. If there are missing values in a row, remove the entire row.

# %%
# Your code here:

fifa = fifa.dropna()
fifa.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0           L. Messi   31   Argentina       94         94
# 1  Cristiano Ronaldo   33    Portugal       94         94
# 2          Neymar Jr   26      Brazil       92         93
# 3             De Gea   27       Spain       91         93
# 4       K. De Bruyne   27     Belgium       91         92
#
#                   Club    Value Preferred Foot Position  Weak Foot  ...  \
# 0         FC Barcelona  €110.5M           Left       RF        4.0  ...
# 1             Juventus     €77M          Right       ST        4.0  ...
# 2  Paris Saint-Germain  €118.5M          Right       LW        5.0  ...
# 3    Manchester United     €72M          Right       GK        3.0  ...
# 4      Manchester City    €102M          Right      RCM        5.0  ...
#
#    SprintSpeed  Stamina  Strength  LongShots  Aggression  Interceptions  \
# 0         86.0     72.0      59.0       94.0        48.0           22.0
# ...

# %% [markdown]
# Using the FIFA dataset, in the cell below, create a linear model predicting value using stamina and sprint speed. create the model using `statsmodels`. Print the model summary.
#
# Hint: remember to add an intercept to the model using the `add_constant` function.

# %%
# Your code here:
x=sm.add_constant(fifa[['Stamina'
                        ,'SprintSpeed'
                       ]])

y=fifa.ValueNumeric

modelo=sm.OLS(y, x).fit()

modelo.summary()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           ValueNumeric   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     4.454
# Date:                Tue, 11 Feb 2020   Prob (F-statistic):             0.0116
# Time:                        16:28:20   Log-Likelihood:            -1.2702e+05
# No. Observations:               17918   AIC:                         2.540e+05
# Df Residuals:                   17915   BIC:                         2.541e+05
# Df Model:                           2
# ...

# %% [markdown]
# Report your findings from the model summary. In particular, report about the model as a whole using the F-test and how much variation is predicted by the model using the r squared.

# %%
# The R2 is very small, not a good prediction model
# F value is large so there is a considerable variation

# %%
# Your code here:
model = ols('ValueNumeric ~ Stamina*SprintSpeed', data=fifa).fit()

anova_table=sm.stats.anova_lm(model, typ=1)

anova_table
# Out:
#                           df        sum_sq       mean_sq           F  \
# Stamina                  1.0  5.085148e+05  5.085148e+05    6.102225
# SprintSpeed              1.0  2.411205e+05  2.411205e+05    2.893469
# Stamina:SprintSpeed      1.0  1.480610e+07  1.480610e+07  177.674507
# Residual             17914.0  1.492822e+09  8.333270e+04         NaN
#
#                            PR(>F)
# Stamina              1.351042e-02
# SprintSpeed          8.895662e-02
# Stamina:SprintSpeed  2.428838e-40
# Residual                      NaN

# %% [markdown]
# Next, create a second regression model predicting value using potential. Create the model using `statsmodels` and print the model summary. Remember to add a constant term.

# %%
# Your code here:
x=sm.add_constant(fifa[['Potential']])

y=fifa.ValueNumeric

modelo=sm.OLS(y, x).fit()

modelo.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           ValueNumeric   R-squared:                       0.056
# Model:                            OLS   Adj. R-squared:                  0.056
# Method:                 Least Squares   F-statistic:                     1054.
# Date:                Tue, 11 Feb 2020   Prob (F-statistic):          9.15e-225
# Time:                        17:00:37   Log-Likelihood:            -1.2651e+05
# No. Observations:               17918   AIC:                         2.530e+05
# Df Residuals:                   17916   BIC:                         2.530e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1062.4312     24.547     43.281      0.000    1014.316    1110.546
# ...

# %% [markdown]
# Report your findings from the model summary. In particular, report about the model as a whole using the F-test and how much variation is predicted by the model using the r squared.

# %%
# Your conclusions here:

# There is a huge F stat value (very small p value as well). This means There is a lot of variance between the samples.
# The R2 is very small. Not a good model.
# The Coeff for potential is negative, which goes against common sence.
# By removing constant we get a better lineal model.
# Observing the Scatter plots, we can see that it is not a linear model that we needed.

# %% [markdown]
# Plot a scatter plot of value vs. potential. Do you see a linear relationship?

# %%
# Your code here:

i = fifa[['Potential']]
j = fifa[['ValueNumeric']]

r_x = fifa[['Potential']]
r_y = fifa[['Potential']]*(-11.1326)+1062.4312

r_x2 = fifa[['Potential']]
r_y2 = 3.6525*fifa[['Potential']]

fig, ax = plt.subplots(figsize=(16,10))
plt.scatter(i,j)
plt.scatter(r_x,r_y)
plt.scatter(r_x2,r_y2)

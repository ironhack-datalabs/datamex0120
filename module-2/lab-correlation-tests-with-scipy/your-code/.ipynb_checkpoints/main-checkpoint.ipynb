# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# import numpy and pandas
import numpy as np
import pandas as pd
from scipy import stats
from statsmodels.formula.api import ols
import statsmodels.api as sm
from scipy.stats import linregress
import matplotlib.pyplot as plt

# %% [markdown]
# # Challenge 1 - Analysis of Variance
#
# In this part of the lesson, we will perform an analysis of variance to determine whether the factors in our model create a significant difference in the group means. We will be examining a dataset of FIFA players. We'll start by loading the data using the code in the cell below.

# %%
# Run this code:

fifa = pd.read_csv('fifa.csv')

# %% [markdown]
# Let's examine the dataset by looking at the `head`.

# %%
# Your code here:

fifa.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0           L. Messi   31   Argentina       94         94
# 1  Cristiano Ronaldo   33    Portugal       94         94
# 2          Neymar Jr   26      Brazil       92         93
# 3             De Gea   27       Spain       91         93
# 4       K. De Bruyne   27     Belgium       91         92
#
#                   Club    Value Preferred Foot Position  Weak Foot  \
# 0         FC Barcelona  €110.5M           Left       RF        4.0
# 1             Juventus     €77M          Right       ST        4.0
# 2  Paris Saint-Germain  €118.5M          Right       LW        5.0
# 3    Manchester United     €72M          Right       GK        3.0
# 4      Manchester City    €102M          Right      RCM        5.0
#
#    Acceleration  SprintSpeed  Stamina  Strength  LongShots  Aggression  \
# 0          91.0         86.0     72.0      59.0       94.0        48.0
# ...

# %% [markdown]
# Player's values are expressed in millions of euros. We would like this column to be numeric. Therefore, let's create a numeric value column. Do this by stripping all non-numeric characters from each cell. Assign this new data to `ValueNumeric`. There is no need to multiply the value to be expressed in millions.

# %%
# Your code here:

fifa['Value'] = fifa['Value'].replace('[A-Z]+|€', ' ',regex=True) 
fifa['Value'] = fifa['Value'].astype('float64')
fifa = fifa.rename(columns={'Preferred Foot': 'Pref_Foot'})
fifa
# Out:
#                      Name  Age Nationality  Overall  Potential  \
# 0                L. Messi   31   Argentina       94         94
# 1       Cristiano Ronaldo   33    Portugal       94         94
# 2               Neymar Jr   26      Brazil       92         93
# 3                  De Gea   27       Spain       91         93
# 4            K. De Bruyne   27     Belgium       91         92
# ...                   ...  ...         ...      ...        ...
# 18202        J. Lundstram   19     England       47         65
# 18203  N. Christoffersson   19      Sweden       47         63
# 18204           B. Worman   16     England       47         67
# 18205      D. Walker-Rice   17     England       47         66
# 18206           G. Nugent   16     England       46         66
#
#                       Club  Value Pref_Foot Position  Weak Foot  Acceleration  \
# 0             FC Barcelona  110.5      Left       RF        4.0          91.0
# ...

# %% [markdown]
# #### We'd like to determine whether a player's preffered foot and position have an impact on their value.
#
# Using the `statsmodels` library, we are able to produce an ANOVA table without munging our data. Create an ANOVA table with value as a function of position and preferred foot. Recall that pivoting is performed by the `C` function.
#
# Hint: For columns that have a space in their name, it is best to refer to the column using the dataframe (For example: for column `A`, we will use `df['A']`).

# %%
# Your code here:
new_fifa = fifa[['Value','Position','Pref_Foot']].dropna()
new_fifa
# Out:
#        Value Position Pref_Foot
# 0      110.5       RF      Left
# 1       77.0       ST     Right
# 2      118.5       LW     Right
# 3       72.0       GK     Right
# 4      102.0      RCM     Right
# ...      ...      ...       ...
# 18202   60.0       CM     Right
# 18203   60.0       ST     Right
# 18204   60.0       ST     Right
# 18205   60.0       RW     Right
# 18206   60.0       CM     Right
#
# [18147 rows x 3 columns]

# %%
#i: new_fifa.Value[new_fifa.Position==i] for i in pref_position

# %%
modelo = ols('Value ~C(Position)*(Pref_Foot)', data=new_fifa).fit()
anova_table=sm.stats.anova_lm(modelo, typ=2)
anova_table
# Out:
#                              sum_sq       df         F        PR(>F)
# C(Position)            8.767522e+06     26.0  4.033759  2.141952e-11
# Pref_Foot              7.292211e+04      1.0  0.872300  3.503319e-01
# C(Position):Pref_Foot  3.050243e+06     26.0  1.403355  8.327900e-02
# Residual               1.512530e+09  18093.0       NaN           NaN

# %% [markdown]
# What is your conclusion from this ANOVA?

# %% [markdown]
# # Your conclusions here:
# # para este modelo, no hay significancia real entre los campos, ya que el pvalue es casi 0 por lo que se rechaza la hipotesis nula

# %% [markdown]
# After looking at a model of both preffered foot and position, we decide to create an ANOVA table for nationality. Create an ANOVA table for numeric value as a function of nationality.

# %%
# Your code here:
anova_1 = fifa[['Nationality', 'Value']]
model = ols('Value ~C(Nationality)',data = anova_1).fit()
anova_table1 = sm.stats.anova_lm(model,typ=1)
anova_table1
# Out:
#                      df        sum_sq        mean_sq         F        PR(>F)
# C(Nationality)    163.0  4.292914e+07  263368.987135  3.202987  1.976253e-38
# Residual        18043.0  1.483605e+09   82226.058289       NaN           NaN

# %% [markdown]
# What is your conclusion from this ANOVA?

# %%
# que el pvalue nos muestra que la columna de Nationality no es significativa, volvemos a rechazar la hipotes nula

# %% [markdown]
# # Challenge 2 - Linear Regression
#
# Our goal with using linear regression is to create a mathematical model that will enable us to predict the outcome of one variable using one or more additional independent variables.
#
# We'll start by ensuring there are no missing values. Examine all variables for all missing values. If there are missing values in a row, remove the entire row.

# %%
# Your code here:
new_fifa = fifa.copy()
new_fifa = new_fifa.dropna().reset_index()
new_fifa
# Out:
#        index                Name  Age Nationality  Overall  Potential  \
# 0          0            L. Messi   31   Argentina       94         94
# 1          1   Cristiano Ronaldo   33    Portugal       94         94
# 2          2           Neymar Jr   26      Brazil       92         93
# 3          3              De Gea   27       Spain       91         93
# 4          4        K. De Bruyne   27     Belgium       91         92
# ...      ...                 ...  ...         ...      ...        ...
# 17913  18202        J. Lundstram   19     England       47         65
# 17914  18203  N. Christoffersson   19      Sweden       47         63
# 17915  18204           B. Worman   16     England       47         67
# 17916  18205      D. Walker-Rice   17     England       47         66
# 17917  18206           G. Nugent   16     England       46         66
#
#                       Club  Value Pref_Foot Position  ...  Acceleration  \
# ...

# %%
new_fifa.columns
# Out:
# Index(['index', 'Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club',
#        'Value', 'Pref_Foot', 'Position', 'Weak Foot', 'Acceleration',
#        'SprintSpeed', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties'],
#       dtype='object')

# %% [markdown]
# Using the FIFA dataset, in the cell below, create a linear model predicting value using stamina and sprint speed. create the model using `statsmodels`. Print the model summary.
#
# Hint: remember to add an intercept to the model using the `add_constant` function.

# %%
# Your code here:
x = sm.add_constant(new_fifa[['Stamina','SprintSpeed']])
y = new_fifa.Value
modelo1 = sm.OLS(y,x).fit()
modelo1.summary()
# Out:
# /home/jibo16/snap/jupyter/common/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2542: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Value   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     4.454
# Date:                Thu, 06 Feb 2020   Prob (F-statistic):             0.0116
# Time:                        17:43:52   Log-Likelihood:            -1.2702e+05
# No. Observations:               17918   AIC:                         2.540e+05
# Df Residuals:                   17915   BIC:                         2.541e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ...

# %% [markdown]
# Report your findings from the model summary. In particular, report about the model as a whole using the F-test and how much variation is predicted by the model using the r squared.

# %%
# Your conclusions here:
# el pvalue nos hace rechazar la hipotesis nula otra vez, podemos observar que la stamina y el sprint speed si son factores determinantes para el value
print(modelo1.fvalue, modelo1.f_pvalue, modelo1.rsquared)
# Out:
# 4.453922741122145 0.011645728719240656 0.0004969812140876995

# %% [markdown]
# Next, create a second regression model predicting value using potential. Create the model using `statsmodels` and print the model summary. Remember to add a constant term.

# %%
# Your code here:

x = sm.add_constant(new_fifa['Potential'])
y = new_fifa.Value
modelo = sm.OLS(y,x).fit()
modelo.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Value   R-squared:                       0.056
# Model:                            OLS   Adj. R-squared:                  0.056
# Method:                 Least Squares   F-statistic:                     1054.
# Date:                Thu, 06 Feb 2020   Prob (F-statistic):          9.15e-225
# Time:                        17:43:53   Log-Likelihood:            -1.2651e+05
# No. Observations:               17918   AIC:                         2.530e+05
# Df Residuals:                   17916   BIC:                         2.530e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1062.4312     24.547     43.281      0.000    1014.316    1110.546
# ...

# %% [markdown]
# Report your findings from the model summary. In particular, report about the model as a whole using the F-test and how much variation is predicted by the model using the r squared.

# %%
# Your conclusions here:
# En este caso el rsquared nos muestra que el modelo no puede predecir tan bien ya que nos sale un valor muy pequeño que se acerca mucho a 0
# ademas de que el pvalue nos ayuda a rechazar la hipotesis original ya que su valor es muy cercano a 0
print(modelo.fvalue, modelo.f_pvalue, modelo.rsquared)
# Out:
# 1054.229300276653 9.154945285005881e-225 0.05557282854041612

# %% [markdown]
# Plot a scatter plot of value vs. potential. Do you see a linear relationship?

# %%
# Your code here:
plt.scatter(fifa.Value,fifa.Potential);

# %%
# si, existe una relacion lineal entre el valor y el potencial de el dataset

# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd
'''
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
'''
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
#titanic = pd.read_csv('./titanic.csv',low_memory=False)
#titanic.head()





from google.colab import drive 
drive.mount('/content/gdrive')
titanic=pd.read_csv('gdrive/My Drive/titanic.csv')
titanic.head()
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1       0.0       3  ...   7.2500    U0         S
# 1            2       1.0       1  ...  71.2833   C85         C
# 2            3       1.0       3  ...   7.9250    U0         S
# 3            4       1.0       1  ...  53.1000  C123         S
# 4            5       0.0       3  ...   8.0500    U0         S
#
# [5 rows x 12 columns]

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable
titanic.select_dtypes(include=['float64', 'int'])
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
#your code here- categorical variable
titanic.select_dtypes(include='object')
# Out:
#                                                    Name  Gender  ... Cabin Embarked
# 0                               Braund, Mr. Owen Harris    male  ...    U0        S
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  ...   C85        C
# 2                                Heikkinen, Miss. Laina  female  ...    U0        S
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  ...  C123        S
# 4                              Allen, Mr. William Henry    male  ...    U0        S
# ...                                                 ...     ...  ...   ...      ...
# 1304                                 Spector, Mr. Woolf    male  ...    U0        S
# 1305                       Oliva y Ocana, Dona. Fermina  female  ...  C105        C
# 1306                       Saether, Mr. Simon Sivertsen    male  ...    U0        S
# 1307                                Ware, Mr. Frederick    male  ...    U0        S
# ...

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
# your code here
plt.figure(figsize=(12,6));
sns.set(style='darkgrid')

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
# your code here
plt.boxplot(titanic['Age']);

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
# your code here
plt.subplot(1,3,1)
plt.hist(titanic['Age'], bins=10);
plt.subplot(1,3,2)
plt.hist(titanic['Age'], bins=20);
plt.subplot(1,3,3)
plt.hist(titanic['Age'], bins=50);

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
#your comment here
sns.boxplot(titanic.Age);

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
# your code here
xval = titanic.Gender.value_counts().index
yval = titanic.Gender.value_counts().values

plt.bar(xval, yval);

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
# your code here- 1st way
sns.barplot(xval, yval);

# %%
# your code here- 2nd way

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
# your code here
xval = titanic.Pclass.value_counts().index
yval = titanic.Pclass.value_counts().values

sns.barplot(xval, yval);

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
# your code here
xval = titanic.Age.describe().index
yval = titanic.Age.describe().values

sns.barplot(xval[1:], yval[1:]);

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
# your comment here
plt.hist(titanic.Age);

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
#your code here
corr = titanic[['Fare', 'Age']].corr()
sns.heatmap(corr);

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
#your comment here
plt.scatter(titanic.Age, titanic.Fare);

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way
corr = titanic[['Fare', 'Age']].corr()
sns.heatmap(corr);

# %%
# your code-2nd way
plt.scatter(titanic.Age, titanic.Fare);

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
#your code here
corr = titanic.corr()
sns.heatmap(corr);

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your comment here
plt.figure()

xval = titanic.Age.describe().index
yval = titanic.Age.describe().values
plt.plot(xval[1:], yval[1:], 'bo');

xval = titanic.Fare.describe().index
yval = titanic.Fare.describe().values
plt.plot(xval[1:], yval[1:], 'ro');

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#your code here
maleAge = titanic[titanic.Gender=='male'].Age
femaleAge = titanic[titanic.Gender=='female'].Age
plt.hist(maleAge)
plt.hist(femaleAge);

# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable
titanic.select_dtypes(include=['int64','float64']).head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1       0.0       3  22.0      1      0   7.2500
# 1            2       1.0       1  38.0      1      0  71.2833
# 2            3       1.0       3  26.0      0      0   7.9250
# 3            4       1.0       1  35.0      1      0  53.1000
# 4            5       0.0       3  35.0      0      0   8.0500

# %%
#your code here- categorical variable
titanic.select_dtypes(include='object').head()
# Out:
#                                                 Name  Gender  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171    U0        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282    U0        S
# 3            113803  C123        S
# 4            373450    U0        S

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
# your code here
a = plt.figure(figsize=(12, 6))
a =sns.set_style("whitegrid")

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
# your code here
sns.boxplot(titanic.Age)

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
# your code here
plt.figure(figsize=(12, 6))

plt.subplot(1,3,1)
plt.hist(titanic.Age, bins=10)
plt.subplot(1,3,2)
plt.hist(titanic.Age, bins=20)
plt.subplot(1,3,3)
plt.hist(titanic.Age, bins=50)
# Out:
# (array([ 22.,  19.,  10.,  11.,  10.,  13.,   8.,   8.,  23.,  26.,  20.,
#          75.,  29.,  93., 109.,  43.,  72.,  68., 111.,  53.,  71.,  47.,
#          35.,  24.,  43.,  26.,  29.,  15.,  35.,  31.,  15.,  26.,   7.,
#          14.,  13.,   5.,   9.,   8.,  11.,   9.,   3.,   2.,   0.,   2.,
#           3.,   0.,   1.,   1.,   0.,   1.]),
#  array([ 0.17  ,  1.7666,  3.3632,  4.9598,  6.5564,  8.153 ,  9.7496,
#         11.3462, 12.9428, 14.5394, 16.136 , 17.7326, 19.3292, 20.9258,
#         22.5224, 24.119 , 25.7156, 27.3122, 28.9088, 30.5054, 32.102 ,
#         33.6986, 35.2952, 36.8918, 38.4884, 40.085 , 41.6816, 43.2782,
#         44.8748, 46.4714, 48.068 , 49.6646, 51.2612, 52.8578, 54.4544,
#         56.051 , 57.6476, 59.2442, 60.8408, 62.4374, 64.034 , 65.6306,
#         67.2272, 68.8238, 70.4204, 72.017 , 73.6136, 75.2102, 76.8068,
#         78.4034, 80.    ]),
#  <a list of 50 Patch objects>)

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
#your comment here
# Yes, the bigger the bin the bigger the qty of items in it and the value of y.
# But there is a similarity in between the shapes of the charts.

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
# your code here
plt.figure(figsize=(16, 6))
sns.distplot(titanic['Age'],bins=30,color='blue')

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
# your code here- 1st way
plt.figure(figsize=(16, 6))
sns.countplot(x=titanic['Gender'],color='blue', alpha=.6)

# %%
# your code here- 2nd way
plt.figure(figsize=(16, 6))
titanic['Gender'].value_counts().plot(kind='bar')

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
# your code here
plt.figure(figsize=(16, 6))

titanic['Pclass'].value_counts().plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('# of Peolple')
# Out:
# Text(0, 0.5, '# of Peolple')

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
# your code here
plt.figure(figsize=(16, 6))
titanic.boxplot(column='Age')

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
# your comment here
# Most passangers are from ages 20-40, but there are other passangers from ages 0 to 60. 
# very very fwe older that 60.

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
#your code here
sns.set_style("ticks")
plt.figure(figsize=(16, 6))
sns.violinplot("Age", data=titanic, palette="Paired")

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
# lots of 2-30, but also from 4-50.

# %%
#your comment here

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way
sns.regplot(x=titanic.Age, y=titanic.Fare);

# %%
# your code-2nd way
plt.scatter(x=titanic.Age, y=titanic.Fare)

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
#your code here
sns.heatmap(titanic.corr())

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
#your comment here
#Age vs Pclass & Fare vs Pclas & Survived

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your code here
plt.figure(figsize=(16, 6))
sns.boxplot(x='Pclass',y='Age',data=titanic,palette='Paired')

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#your code here
ag = sns.FacetGrid(data=titanic,col='Gender')
ag.map(plt.hist,'Age')

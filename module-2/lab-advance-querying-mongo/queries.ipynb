# %% [markdown]
# ![Ironhack Logo](https://i.imgur.com/1QgrNNw.png)

# %%
import pymongo
from pymongo import MongoClient
client=MongoClient("mongodb://localhost:27017/")

# %% [markdown]
# # Answers
# ### 1. All the companies that it's name match 'Babelgum'. Retrieve only their `name` field.

# %%
db = client.companies
collection = db['companies']

# %%
res = collection.find({'name':'Babelgum'})

for resu in res:
    print(resu.keys())
# Out:
# dict_keys(['_id', 'name', 'permalink', 'crunchbase_url', 'homepage_url', 'blog_url', 'blog_feed_url', 'twitter_username', 'category_code', 'number_of_employees', 'founded_year', 'founded_month', 'founded_day', 'deadpooled_year', 'deadpooled_month', 'deadpooled_day', 'deadpooled_url', 'tag_list', 'alias_list', 'email_address', 'phone_number', 'description', 'created_at', 'updated_at', 'overview', 'image', 'products', 'relationships', 'competitions', 'providerships', 'total_money_raised', 'funding_rounds', 'investments', 'acquisition', 'acquisitions', 'offices', 'milestones', 'ipo', 'video_embeds', 'screenshots', 'external_links', 'partners'])

# %% [markdown]
# ### 2. All the companies that have more than 5000 employees. Limit the search to 20 companies and sort them by **number of employees**.

# %%
results = collection.find( {'number_of_employees': { '$gt': 5000 } } ).sort({'number_of_employees': -1}).limit(20)
for i in results:
        print(i['name'])
# Out:
# Facebook
# eBay
# Cisco
# Yahoo!
# Google
# Intel
# Nintendo
# Adobe Systems
# Sony
# PayPal
# The Walt Disney Company
# AOL
# Webkinz
# Sun Microsystems
# Nokia
# Rakuten
# Microsoft
# Apple
# NetApp
# Motorola Solutions

# %% [markdown]
# ### 3. All the companies founded between 2000 and 2005, both years included. Retrieve only the `name` and `founded_year` fileds.

# %%
comp = collection.find( { 'founded_year': { '$gt': 2000, '$lt': 2005 } } )
for i in comp:
    print(i['name'], i['founded_year'])
# Out:
# Digg 2004
# Facebook 2004
# StumbleUpon 2002
# Gizmoz 2003
# Plaxo 2002
# Technorati 2002
# AddThis 2004
# Veoh 2004
# Meetup 2002
# SmugMug 2002
# Skype 2003
# Pando Networks 2004
# Ikan 2003
# delicious 2003
# Topix 2002
# Jobster 2004
# AllPeers 2004
# iContact 2003
# blinkx 2004
# Yelp 2004
# Coghead 2003
# Farecast 2003
# KickApps 2004
# Flickr 2004
# FeedBurner 2004
# Dogster 2004
# Sway 2004
# CornerWorld 2002
# adBrite 2003
# Loomia 2004
# LinkedIn 2003
# iLike 2002
# Redfin 2004
# Wink 2004
# TechnologyGuide 2001
# Techmeme 2004
# Eventful 2004
# Oodle 2004
# Simply Hired 2004
# ooma 2004
# stylediary 2004
# Vast 2001
# MyPublicInfo 2004
# Spreadshirt 2002
# Socialtext 2002
# IceRocket 2004
# Ohloh 2004
# hi5 2003
# Tagged 2004
# Indeed 2004
# Cerado 2002
# introNetworks 2003
# eBuddy 2003
# PeerMe 2004
# Crackle 2004
# Clipmarks 2003
# Brightcove 2004
# Hightail 2004
# TalkPlus 2004
# Vudu 2004
# Kaneva 2004
# IMVU 2004
# Userplane 2001
# Dubit 2003
# Millsberry 2004
# ...

# %% [markdown]
# ### 4. All the companies that had a Valuation Amount of more than 100.000.000 and have been founded before 2010. Retrieve only the `name` and `ipo` fields.

# %%
comp = collection.find( {
    '$and' : [
        { '$or' : [ { 'total_money_raised' : {'$gt':100000}}] },
        { '$or' : [ { 'founded_year' : {'$lt':2010} } ] }
    ]
} )
for i in comp:
    print(i['name'], i['ipo'])

# %% [markdown]
# ### 5. All the companies that have less than 1000 employees and have been founded before 2005. Order them by the number of employees and limit the search to 10 companies.

# %%
comp = collection.find( {
    '$and' : [
        { '$or' : [ { 'number_of_employees' : {'$gt':1000}}] },
        { '$or' : [ { 'founded_year' : {'$lt':2005} } ] }
    ]
} ).limit(10)
for i in comp:
    print(i['name'])
# Out:
# Facebook
# eBay
# Cisco
# Yahoo!
# Google
# Intel
# LinkedIn
# Nintendo
# NetSuite
# Adobe Systems

# %% [markdown]
# ### 6. All the companies that don't include the `partners` field.

# %%
fal = collection.find({'partners' : {'$exists' : False}})
for i in fal:
    print(i['name'])

# %% [markdown]
# ### 7. All the companies that have a null type of value on the `category_code` field.

# %%
r = collection.find({'category': None})
for i in r:
    print(i['name'])
# Out:
# Wetpaint
# AdventNet
# Zoho
# Digg
# Facebook
# Omnidrive
# Postini
# Geni
# Flektor
# Fox Interactive Media
# Twitter
# StumbleUpon
# Gizmoz
# Scribd
# Slacker
# Lala
# Helio
# eBay
# MeetMoi
# Joost
# CBS
# Viacom
# Babelgum
# Plaxo
# Cisco
# Yahoo!
# Powerset
# Technorati
# SpinVox
# AddThis
# OpenX
# Mahalo
# Sparter
# Kyte
# Veoh
# Gannett
# Thoof
# Jingle Networks
# Info
# JotSpot
# Meetup
# Mercora
# NetRatings
# LifeLock
# Wesabe
# Jangl SMS
# SmugMug
# Prosper
# Google
# Jajah
# Skype
# YouTube
# Stickam
# blogTV
# Livestream
# Ustream
# AdaptiveBlue
# Pando Networks
# Intel
# GrandCentral
# Ikan
# delicious
# Topix
# Jobster
# Pownce
# Revision3
# AllPeers
# CriticalMetrics
# ZenZui
# Spock
# Wize
# SodaHead
# CastTV
# iSkoot
# EQO
# AllofMP3
# There
# SellABand
# Funny Or Die
# Steorn
# iContact
# MeeVee
# blinkx
# Mashery
# ClipBlast!
# Zlio
# Yelp
# Jaiku
# Tun3r
# Spotplex
# Yapta
# TripUp
# Wakoopa
# Fleck
# Coghead
# Zamzar
# Zooomr
# SideStep
# coRank
# Farecast
# ...

# %% [markdown]
# ### 8. All the companies that have at least 100 employees but less than 1000. Retrieve only the `name` and `number of employees` fields.

# %%
comp = collection.find( { 'number_of_employees': { '$gte': 100, '$lt': 1000 } } )
for i in comp:
    print(i['name'], i['number_of_employees'])
# Out:
# AdventNet 600
# AddThis 120
# OpenX 305
# LifeLock 644
# Jajah 110
# Livestream 120
# Ustream 250
# iContact 300
# Yelp 800
# Dailymotion 120
# RockYou 106
# Meebo 200
# Eventbrite 200
# Box 950
# Conduit 215
# Redfin 100
# oDesk 120
# Simply Hired 100
# PhotoBox 600
# Spreadshirt 230
# Bazaarvoice 600
# spigit 120
# PowerReviews 120
# hi5 100
# Tagged 162
# PayScale 130
# Truphone 450
# Brightcove 220
# Hightail 200
# Nimbuzz 140
# IMVU 150
# INgage Networks 100
# Dropbox 350
# MobiTV 300
# Jimdo 170
# KIT digital 200
# BlueLithium 135
# MySpace 800
# ZoomInfo 800
# Zango 225
# Trulia 500
# TubeMogul 230
# TechTarget 600
# Sportsline 264
# OpenTable 550
# Espotting 250
# Adknowledge 300
# airG 180
# ChannelAdvisor 300
# Ooyala 300
# hulu 153
# ZocDoc 450
# PubMatic 380
# Clickable 160
# mig33 100
# Mozilla 800
# Kaltura 160
# Zillow 600
# Moz 130
# Zimbra 200
# Wamba 120
# Fon 100
# Blurb 150
# The Climate Corporation 150
# Automattic 200
# uTest 120
# Payoneer 200
# Shopatron 166
# ...

# %% [markdown]
# ### 9. Order all the companies by their IPO price descendently.

# %%
order = collection.find().sort('ipo',-1)

# %% [markdown]
# ### 10. Retrieve the 10 companies with more employees, order by the `number of employees`

# %%
results = collection.find({}).sort('number_of_employees').limit(10)
for i in results:
        print(i['name'])
# Out:
# Omnidrive
# Postini
# Flektor
# StumbleUpon
# Gizmoz
# Slacker
# Lala
# Helio
# CBS
# Viacom

# %% [markdown]
# ### 11. All the companies founded on the second semester of the year. Limit your search to 1000 companies.

# %%
comp = collection.find( {
    '$and' : [
        { '$or' : [ { 'founded_month' : {'$gte':4}}] },
        { '$or' : [ { 'founded_month' : {'$lte':6} } ] },
        
    ]
} ).limit(1000)
for i in comp:
    print(i['name'])
# Out:
# Postini
# Geni
# Fox Interactive Media
# Technorati
# OpenX
# Sparter
# blogTV
# Livestream
# GrandCentral
# Topix
# Pownce
# Revision3
# Spock
# iSkoot
# AllofMP3
# Mashery
# Coghead
# TripHub
# TVtrip
# PBworks
# WatZatSong
# LinkedIn
# Carbonite
# Seesmic
# Hotelicopter
# MyPublicInfo
# Checkster
# Bazaarvoice
# spigit
# LiveWorld
# Respectance
# Kiptronic
# Vuze
# DOmedia
# PodTech
# PayScale
# Nimbuzz
# MeeMix
# Alstrasoft
# AOL
# Webkinz
# Zwinky
# ActiveWorlds
# Sulake
# Pickle
# HireAHelper
# Dropbox
# TimeBridge
# TokBox
# DanceJam
# Inneractive
# EventVue
# Socialthing
# Filtrbox
# Cloudant
# Doostang
# TechCrunch
# Vlingo
# Alibaba
# Trulia
# Yeigo
# Shopzilla
# Seedcamp
# Webshots
# LimeLife
# Yap
# BlogSigs
# BBE
# Fotolog
# Contrastream
# Collagr
# Ooyala
# Daylife
# CrowdSpirit
# FAROO
# AgentMatch
# ElephantDrive
# LineUpNewYork
# Mixx
# HylioSoft
# in2apps
# IMSafer
# Avvo
# ChessPark
# Extravigator
# BroadClip
# Fixya
# Myxer
# Empressr
# Type-Any-Circle-Of-Six
# ...

# %% [markdown]
# ### 12. All the companies that have been 'deadpooled' after the third year.

# %%
comp = collection.find( { 'deadpoooled_year': { '$gt': 3 } } )
for i in comp:
    print(i['name'])

# %% [markdown]
# ### 13. All the companies founded before 2000 that have and acquisition amount of more than 10.000.000

# %%
comp = collection.find( {
    '$and' : [
        { '$or' : [ { 'founded_year' : {'$lt':2000}}] },
        { '$or' : [ { 'acquisition.price_amount' : {'$gt':10000000} } ] },
        
    ]
} )
for i in comp:
    print(i['name'])
# Out:
# Postini
# SideStep
# Recipezaar
# PayPal
# Snapfish
# Neopets
# Sun Microsystems
# Zappos
# Alibaba
# Sabre
# Lastminute
# Sportsline
# Digitas
# Webshots
# MIVA
# iVillage
# PriceGrabber
# LinkShare
# Kaboose
# Fastclick
# Eloqua
# Omniture
# Interwoven
# HowStuffWorks
# RealAge
# Match
# Xdrive
# Alexa
# Offermatica
# ioko
# MyNewPlace
# DoubleClick
# Danger
# Direct Hit
# BEA Systems
# Napster
# SafeNet
# LowerMyBills
# Various
# aQuantive
# PeopleSupport
# Wedding Channel
# iCrossing
# Responsys
# Homestead Technologies
# Phoenix Technologies
# Macromedia
# GlobalEnglish
# PGP Corporation
# Iomega
# BizRate
# MessageLabs
# Gracenote
# Razorfish
# Sonic Solutions
# Siebel Systems
# Aprimo
# Opsware
# Netscape
# Vignette
# Blue Coat Systems
# Ars Technica
# LSI
# VMware
# OpenAir
# mindSHIFT Technologies
# InsureMe
# SwapDrive
# Marvel Entertainment
# CyberCoders
# Channel Intelligence
# Q-go
# Xerox
# Speedera Networks
# eBaum's World
# Audible
# Extend Media
# ...

# %% [markdown]
# ### 14. All the companies that have been acquired after 2015, order by the acquisition amount, and retrieve only their `name` and `acquisiton` field.

# %%
results = collection.find( {'acquisition.acquired_year': { '$gt': 2015 } } )
for i in results:
        print(i['name'], i ['acquisition'])

# %% [markdown]
# ### 15. Order the companies by their `founded year`, retrieving only their `name` and `founded year`.

# %%
results = collection.find({}).sort('founded_year')
for i in results:
        print(i['name'], i['founded_year']).limit(100)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-106-756b0239426e> in <module>
#       1 results = collection.find({}).sort('founded_year')
# ----> 2 for i in results:
#       3         print(i['name'], i['founded_year']).limit(100)
#
# ~\Anaconda3\lib\site-packages\pymongo\cursor.py in next(self)
#    1154         if self.__empty:
#    1155             raise StopIteration
# -> 1156         if len(self.__data) or self._refresh():
#    1157             if self.__manipulate:
#    1158                 _db = self.__collection.database
#
# ~\Anaconda3\lib\site-packages\pymongo\cursor.py in _refresh(self)
#    1071                                   self.__session,
#    1072                                   self.__collection.database.client)
# -> 1073             self.__send_message(q)
#    1074         elif self.__id:  # Get More
#    1075             if self.__limit:
# ...

# %% [markdown]
# ### 16. All the companies that have been founded on the first seven days of the month, including the seventh. Sort them by their `aquisition price` descendently. Limit the search to 10 documents.

# %%
comp = collection.find( {
    '$and' : [
        { '$or' : [ { 'founded_day' : {'$gte':1}}] },
        { '$or' : [ { 'founded_day' : {'$lte':7} } ] },
        
    ]
} ).sort('acquisition.price_amount').limit(10)
for i in comp:
    print(i['name'])
# Out:
# Facebook
# Omnidrive
# Geni
# Fox Interactive Media
# Gizmoz
# eBay
# Joost
# Babelgum
# Yahoo!
# Technorati

# %% [markdown]
# ### 17. All the companies on the 'web' `category` that have more than 4000 employees. Sort them by the amount of employees in ascendant order.

# %%
comp = collection.find( {
    '$and' : [
        { '$or' : [ { 'category_code' : 'web'}] },
        { '$or' : [ { 'number_of_employees' : {'$gt':4000} } ] },
        
    ]
} )
for i in comp:
    print(i['name'])
# Out:
# eBay
# Yahoo!
# AOL
# Webkinz
# Rakuten
# Expedia
# Experian
# Los Angeles Times Media Group
# Groupon

# %% [markdown]
# ### 18. All the companies which their acquisition amount is more than 10.000.000, and currency are 'EUR'.

# %%
comp = collection.find( {
    '$and' : [
        { '$or' : [ { 'acquisition.price_currency_code' : 'EUR'}] },
        { '$or' : [ { 'acquisition.price_amount' : {'$gt':10000000} } ] },
        
    ]
} )
for i in comp:
    print(i['name'])
# Out:
# ZYB
# Apertio
# Greenfield Online
# Webedia
# Wayfinder
# Tuenti Technologies
# BioMed Central

# %% [markdown]
# ### 19. All the companies that have been acquired on the first trimester of the year. Limit the search to 10 companies, and retrieve only their `name` and `acquisition` fields.

# %%
comp = collection.find( {
    '$and' : [
        { '$or' : [ { 'founded_month' : {'$gte':1}}] },
        { '$or' : [ { 'founded_month' : {'$lte':3} } ] },
        
    ]
} )
for i in comp:
    print(i['name'], i['acquisition'])
# Out:
# Facebook None
# Twitter None
# StumbleUpon {'price_amount': 29000000, 'price_currency_code': 'USD', 'term_code': None, 'source_url': 'http://techcrunch.com/2009/04/13/ebay-unacquires-stumbleupon/', 'source_description': "StumbleUpon Beats Skype In Escaping EBay's Clutches", 'acquired_year': 2009, 'acquired_month': 4, 'acquired_day': None, 'acquiring_company': {'name': 'StumbleUpon', 'permalink': 'stumbleupon'}}
# Gizmoz {'price_amount': None, 'price_currency_code': 'USD', 'term_code': None, 'source_url': 'http://www.gizmoz.com', 'source_description': 'TechCrunch', 'acquired_year': 2009, 'acquired_month': 12, 'acquired_day': 15, 'acquiring_company': {'name': 'Daz 3d', 'permalink': 'daz-3d'}}
# ...

# %% [markdown]
# ### 20. All the companies that have been founded between 2000 and 2010, but have not been acquired before 2011.

# %%
comp = collection.find( {
    '$and' : [
        { '$or' : [ { 'founded_year' : {'$gt':2000}}] },
        { '$or' : [ { 'founded_year' : {'$lt':2010} } ] },
        {'$or' : [{'deadpooled_year': {'not': 2010}}]}
    ]
} )
for i in comp:
    print(i['name'])

# %%
f = collection.find({'acquisition.price_currency_code':'USD'})
for i in f:
    print(i.keys())
# Out:
# dict_keys(['_id', 'name', 'permalink', 'crunchbase_url', 'homepage_url', 'blog_url', 'blog_feed_url', 'twitter_username', 'category_code', 'number_of_employees', 'founded_year', 'founded_month', 'founded_day', 'deadpooled_year', 'tag_list', 'alias_list', 'email_address', 'phone_number', 'description', 'created_at', 'updated_at', 'overview', 'image', 'products', 'relationships', 'competitions', 'providerships', 'total_money_raised', 'funding_rounds', 'investments', 'acquisition', 'acquisitions', 'offices', 'milestones', 'video_embeds', 'screenshots', 'external_links', 'partners'])
# ...

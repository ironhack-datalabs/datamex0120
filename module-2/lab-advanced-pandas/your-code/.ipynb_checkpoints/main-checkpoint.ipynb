# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# import numpy and pandas
import numpy as np
import pandas as pd

# %% [markdown]
# # Challenge 1 - Index Functions
#
# In this challenge, we will practice the advanced functions introduced in the lesson. However, before we start, we will load and evaluate our dataset.

# %%
# Run this code:

admissions = pd.read_csv('../Admission_Predict.csv')
#to remove trailing spaces at the end of the column names
admissions.columns = admissions.columns.str.rstrip()

# %% [markdown]
# Let's evaluate the dataset by looking at the `head` function.

# %%
# Your code here:
admissions.head()
admissions['Serial No.'].unique().size
# Out:
# 385

# %% [markdown]
# Before beginning to work with this dataset and evaluating graduate admissions data, we will verify that there is no missing data in the dataset. Do this in the cell below.

# %%
# Your code here:
admissions.isnull().values.any()
# Out:
# False

# %% [markdown]
# Interestingly, there is a column that uniquely identifies the applicants. This column is the serial number column. Instead of having our own index, we should make this column our index. Do this in the cell below. Keep the column in the dataframe in addition to making it an index.

# %%
# Your code here:
admissions.set_index('Serial No.', inplace=True)
admissions.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 316          104                  3  3.0  3.5  8.00
# 3                 322          110                  3  3.5  2.5  8.67
# 4                 314          103                  2  2.0  3.0  8.21
# 5                 330          115                  5  4.5  3.0  9.34
#
#             Research  Chance of Admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.72
# 3                  1             0.80
# 4                  0             0.65
# 5                  1             0.90

# %% [markdown]
# Turns out that `GRE Score` and `CGPA` also uniquely identify the data. Show this in the cell below.

# %%
# Your code here:
admissions.set_index(['GRE Score', 'CGPA']).index.size == admissions.shape[0]
# Out:
# True

# %% [markdown]
# Replace the index with an index comprised of two columns - `GRE Score` and `CGPA`. Remove the columns from the dataset as well. Make sure to use `inplace=True`.

# %% [markdown]
# Now change the index back to a sequence starting at zero using the `reset_index` function. Make sure to use `inplace=True`.

# %%
# Your code here:
admissions.set_index(['GRE Score', 'CGPA'], inplace=True)
admissions.reset_index(inplace=True)
admissions.head()
# Out:
#    GRE Score  CGPA  TOEFL Score  University Rating  SOP  LOR  Research  \
# 0        337  9.65          118                  4  4.5  4.5         1
# 1        316  8.00          104                  3  3.0  3.5         1
# 2        322  8.67          110                  3  3.5  2.5         1
# 3        314  8.21          103                  2  2.0  3.0         0
# 4        330  9.34          115                  5  4.5  3.0         1
#
#    Chance of Admit
# 0             0.92
# 1             0.72
# 2             0.80
# 3             0.65
# 4             0.90

# %% [markdown]
# # Challenge 2 - Advanced Functions
#
# In this part of the lab, we would like to test complex conditions on the entire dataset at once. Let's start by finding the number of rows where the CGPA is higher than 9 and the student has conducted research.

# %%
# Your code here:
admissions[admissions['CGPA']>9][admissions['Research']>0].count()
# Out:
# /home/linuxbrew/.linuxbrew/Cellar/ipython/7.8.0/libexec/vendor/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# GRE Score            101
# CGPA                 101
# TOEFL Score          101
# University Rating    101
# SOP                  101
# LOR                  101
# Research             101
# Chance of Admit      101
# dtype: int64

# %% [markdown]
# Now return all the rows where the CGPA is greater than 9 and the SOP score is less than 3.5. Find the mean chance of admit for these applicants.

# %%
# Your code here:
admissions[admissions.CGPA>9][admissions.SOP<3.5]['Chance of Admit'].mean()
# Out:
# /home/linuxbrew/.linuxbrew/Cellar/ipython/7.8.0/libexec/vendor/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# 0.8019999999999999

# %% [markdown]
# We would like to create a deciding factor column for each student. We standardize several columns and then pick the most important factor from a lookup table. If the standardized value is above 0.8, the student will be accepted.
#
# We will start by creating a standardized column for `CGPA`, `GRE Score` and `LOR`. We will name these columns `CGPA_std`, `GRE_std`, and `LOR_std` respecively.
#
# Recall that standardizing a column is done by subtracting the mean of the column from all observations in the column and then dividing each observation in the column by the column's standard deviation.
#
# In the cell below, write a standardization function (a function that takes a column as input and returns a standardized column as output). Make sure to use the `numpy` versions of mean and standard deviation.

# %%
def standardize(col):
    # This function takes a column from a dataframe and returns a standardized column by subtracting the column's mean
    # and dividing by the column's standard deviation.
    
    # Your code here:
    return (col - col.mean())/col.std()

# %% [markdown]
# Now create the standardized columns `CGPA_std`, `GRE_std`, and `LOR_std` and add them to the `admissions` dataframe.

# %%
# Your code here:
admissions = admissions.assign(CGPA_std=standardize(admissions.CGPA), GRE_std=standardize(admissions['GRE Score']), LOR_std=standardize(admissions.LOR))
admissions.head()
# Out:
#    GRE Score  CGPA  TOEFL Score  University Rating  SOP  LOR  Research  \
# 0        337  9.65          118                  4  4.5  4.5         1
# 1        316  8.00          104                  3  3.0  3.5         1
# 2        322  8.67          110                  3  3.5  2.5         1
# 3        314  8.21          103                  2  2.0  3.0         0
# 4        330  9.34          115                  5  4.5  3.0         1
#
#    Chance of Admit  CGPA_std   GRE_std   LOR_std
# 0             0.92  1.747900  1.753381  1.191647
# 1             0.72 -0.991211 -0.063367  0.076740
# 2             0.80  0.121034  0.455704 -1.038166
# 3             0.65 -0.642597 -0.236391 -0.480713
# 4             0.90  1.233279  1.147798 -0.480713

# %% [markdown]
# We will generate the decision choice at random using the code below. Please run the cell.

# %%
# Run this code:

from random import choices
std_columns = ['CGPA_std', 'GRE_std', 'LOR_std']

decision_choice = choices(std_columns, k=admissions.shape[0])

# %% [markdown]
# Now create the deciding column using the `lookup` function. The lookup column is `decision_choice` found above. Call the column resulting from the lookup function `deciding_column` and add it to the `admissions` dataframe.

# %%
# Your code here:
decision_choice
admissions['deciding_column'] = admissions.lookup(admissions.index, decision_choice)

# %% [markdown]
# Create a column called `decision` in the `admissions` dataframe. Assign 1 to this column if the value of `deciding_column` is greater than 0.8 and 0 otherwise.

# %%
# Your code here:
admissions['decision'] = np.where(admissions.deciding_column>0.8, 1, 0)
admissions.head()
# Out:
#    GRE Score  CGPA  TOEFL Score  University Rating  SOP  LOR  Research  \
# 0        337  9.65          118                  4  4.5  4.5         1
# 1        316  8.00          104                  3  3.0  3.5         1
# 2        322  8.67          110                  3  3.5  2.5         1
# 3        314  8.21          103                  2  2.0  3.0         0
# 4        330  9.34          115                  5  4.5  3.0         1
#
#    Chance of Admit  CGPA_std   GRE_std   LOR_std  deciding_column  decision
# 0             0.92  1.747900  1.753381  1.191647         1.191647         1
# 1             0.72 -0.991211 -0.063367  0.076740         0.076740         0
# 2             0.80  0.121034  0.455704 -1.038166         0.455704         0
# 3             0.65 -0.642597 -0.236391 -0.480713        -0.642597         0
# 4             0.90  1.233279  1.147798 -0.480713         1.147798         1

# %% [markdown]
# How many applicants will be accepted to the program using the decision column? Compute the result below.

# %%
# Your code here:
admissions[admissions.decision>0].shape[0]
# Out:
# 88

# %% [markdown]
# # Challenge 3 - Method Chaining
#
# To increase our coding efficiency, let's make a number of changes to our dataframe in one line of code.
#
# In the cell below, remove all non character symbols from the column names, replace all spaces in column names to underscores, and change all upper case characters to lower case. Assign these new column values to `admissions.columns`.

# %%
# Your code here:
admissions.columns = [name.replace(' ','_').lower() for name in admissions.columns]
admissions.columns
# Out:
# Index(['gre_score', 'cgpa', 'toefl_score', 'university_rating', 'sop', 'lor',
#        'research', 'chance_of_admit', 'cgpa_std', 'gre_std', 'lor_std',
#        'deciding_column', 'decision'],
#       dtype='object')

# %% [markdown]
# In the cell below, give all student with a university rating of 4 or higher a 10 point boost on their GRE score and split the column into 4 bins using the `cut` function. Assign this new score to the variable `adjusted_gre`.

# %%
# Your code here:
admissions = admissions.assign(adjusted_gre = pd.cut(admissions[admissions.university_rating>4].gre_score+10, bins=4))
#admissions['adjusted_gre'] = pd.cut(admissions[admissions.university_rating>4].gre_score+10, bins=4)
admissions[admissions.university_rating>4]
# Out:
#      gre_score  cgpa  toefl_score  university_rating  sop  lor  research  \
# 4          330  9.34          115                  5  4.5  3.0         1
# 19         328  9.50          116                  5  5.0  5.0         1
# 20         334  9.70          119                  5  5.0  4.5         1
# 21         336  9.80          119                  5  4.0  3.5         1
# 22         322  8.80          109                  5  4.5  3.5         0
# 29         340  9.60          114                  5  4.0  4.0         1
# 30         331  9.80          112                  5  4.0  5.0         1
# 31         320  9.20          110                  5  5.0  5.0         1
# 40         326  9.40          113                  5  4.5  4.0         1
# 41         322  9.10          110                  5  5.0  4.0         1
# 42         329  9.30          114                  5  4.0  5.0         1
# 43         339  9.70          119                  5  4.5  4.0         0
# 66         332  9.64          118                  5  5.0  5.0         1
# 67         336  9.76          112                  5  5.0  5.0         1
# 68         321  9.45          111                  5  5.0  5.0         1
# 78         320  9.22          110                  5  5.0  4.5         1
# 79         322  9.36          115                  5  4.0  4.5         1
# 80         340  9.45          115                  5  4.5  4.5         1
# 103        331  9.38          116                  5  5.0  5.0         1
# 104        304  8.64          103                  5  5.0  4.0         0
# 105        305  8.48          108                  5  3.0  3.0         0
# 114        327  8.84          104                  5  3.0  3.5         1
# 115        335  9.56          117                  5  5.0  5.0         1
# 116        334  9.48          119                  5  4.5  4.5         1
# 124        333  9.35          118                  5  5.0  5.0         1
# 125        339  9.76          114                  5  4.0  4.5         1
# 126        303  8.65          105                  5  5.0  4.5         0
# 127        323  8.78          112                  5  4.0  4.5         0
# 128        333  9.28          113                  5  4.0  4.0         1
# 135        331  9.44          115                  5  4.0  3.5         1
# 144        332  9.28          116                  5  5.0  5.0         1
# 145        321  9.06          112                  5  5.0  5.0         1
# 158        322  8.97          110                  5  4.5  4.0         0
# 164        334  9.07          117                  5  4.0  4.5         1
# 179        335  9.44          118                  5  4.5  3.5         1
# 180        331  9.36          115                  5  4.5  3.5         1
# 181        324  9.16          111                  5  4.5  4.0         1
# 182        323  8.98          110                  5  4.0  5.0         1
# 183        322  8.94          114                  5  4.5  4.0         1
# 184        336  9.53          118                  5  4.5  5.0         1
# 192        340  9.91          120                  5  4.5  4.5         1
# 193        334  9.87          120                  5  4.0  5.0         1
# 203        333  9.78          119                  5  5.0  4.5         1
# 205        330  9.36          116                  5  5.0  4.5         1
# 222        330  9.31          113                  5  5.0  4.0         1
# 223        326  9.23          111                  5  4.5  4.0         1
# 225        329  9.19          114                  5  4.5  5.0         1
# 247        327  9.13          108                  5  5.0  3.5         1
# 263        329  9.45          113                  5  5.0  4.5         1
# 272        331  9.26          116                  5  4.0  4.0         1
# 184             0.94  1.548692  1.666869  1.749100         1.548692         1
# 192             0.97  2.179517  2.012916  1.191647         1.191647         1
# 193             0.97  2.113114  1.493846  1.749100         1.749100         1
# 203             0.96  1.963708  1.407334  1.191647         1.963708         1
# 205             0.93  1.266480  1.147798  1.191647         1.266480         1
# 222             0.91  1.183477  1.147798  0.634193         1.183477         1
# 223             0.88  1.050671  0.801751  0.634193         1.050671         1
# 225             0.86  0.984269  1.061286  1.749100         0.984269         1
# 247             0.87  0.884665  0.888263  0.076740         0.888263         1
# 263             0.89  1.415886  1.061286  1.191647         1.191647         1
# 272             0.93  1.100474  1.234310  0.634193         0.634193         0
# 273             0.92  0.984269  1.666869  0.634193         0.984269         1
# 274             0.89  0.801661  0.628727  1.191647         0.801661         1
# 322             0.94  1.449088  1.320822  1.749100         1.320822         1
# 323             0.81  0.237239  0.542216  0.634193         0.634193         0
# 324             0.81  0.104433  0.628727  0.634193         0.104433         0
# 347             0.91  1.050671  1.839893  1.749100         1.050671         1
# 370             0.96  2.030111  1.580357  1.749100         1.580357         1
#
#           adjusted_gre
# 4      (331.5, 340.75]
# 19     (331.5, 340.75]
# 20     (340.75, 350.0]
# 21     (340.75, 350.0]
# 22     (331.5, 340.75]
# 29     (340.75, 350.0]
# 30     (340.75, 350.0]
# 31     (322.25, 331.5]
# 40     (331.5, 340.75]
# 41     (331.5, 340.75]
# 42     (331.5, 340.75]
# 43     (340.75, 350.0]
# 66     (340.75, 350.0]
# 67     (340.75, 350.0]
# 68     (322.25, 331.5]
# 78     (322.25, 331.5]
# 79     (331.5, 340.75]
# 80     (340.75, 350.0]
# 103    (340.75, 350.0]
# 104  (312.963, 322.25]
# 105  (312.963, 322.25]
# 114    (331.5, 340.75]
# 115    (340.75, 350.0]
# 116    (340.75, 350.0]
# 124    (340.75, 350.0]
# 125    (340.75, 350.0]
# 126  (312.963, 322.25]
# 127    (331.5, 340.75]
# 128    (340.75, 350.0]
# 135    (340.75, 350.0]
# 144    (340.75, 350.0]
# 145    (322.25, 331.5]
# 158    (331.5, 340.75]
# 164    (340.75, 350.0]
# 179    (340.75, 350.0]
# 180    (340.75, 350.0]
# 181    (331.5, 340.75]
# 182    (331.5, 340.75]
# 183    (331.5, 340.75]
# 184    (340.75, 350.0]
# 192    (340.75, 350.0]
# 193    (340.75, 350.0]
# 203    (340.75, 350.0]
# 205    (331.5, 340.75]
# 222    (331.5, 340.75]
# 223    (331.5, 340.75]
# 225    (331.5, 340.75]
# 247    (331.5, 340.75]
# 263    (331.5, 340.75]
# 272    (340.75, 350.0]
# 273    (340.75, 350.0]
# 274    (331.5, 340.75]
# 322    (340.75, 350.0]
# 323    (331.5, 340.75]
# 324    (331.5, 340.75]
# 347    (340.75, 350.0]
# 370    (340.75, 350.0]

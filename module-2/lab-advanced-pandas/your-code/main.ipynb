# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# import numpy and pandas
import numpy as np
import pandas as pd
import re

# %% [markdown]
# # Challenge 1 - Index Functions
#
# In this challenge, we will practice the advanced functions introduced in the lesson. However, before we start, we will load and evaluate our dataset.

# %%
# Run this code:

admissions = pd.read_csv('../Admission_Predict.csv')
#to remove trailing spaces at the end of the column names
admissions.columns = admissions.columns.str.rstrip()

# %% [markdown]
# Let's evaluate the dataset by looking at the `head` function.

# %%
# Your code here:
admissions.head(10)
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        316          104                  3  3.0  3.5  8.00
# 2           3        322          110                  3  3.5  2.5  8.67
# 3           4        314          103                  2  2.0  3.0  8.21
# 4           5        330          115                  5  4.5  3.0  9.34
# 5           6        321          109                  3  3.0  4.0  8.20
# 6           7        308          101                  2  3.0  4.0  7.90
# 7           8        302          102                  1  2.0  1.5  8.00
# 8           9        323          108                  3  3.5  3.0  8.60
# 9          10        327          111                  4  4.0  4.5  9.00
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.72
# 2         1             0.80
# 3         0             0.65
# 4         1             0.90
# 5         1             0.75
# 6         0             0.68
# 7         0             0.50
# 8         0             0.45
# 9         1             0.84

# %% [markdown]
# Before beginning to work with this dataset and evaluating graduate admissions data, we will verify that there is no missing data in the dataset. Do this in the cell below.

# %%
# Your code here:
admissions.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %% [markdown]
# Interestingly, there is a column that uniquely identifies the applicants. This column is the serial number column. Instead of having our own index, we should make this column our index. Do this in the cell below. Keep the column in the dataframe in addition to making it an index.

# %%
# Your code here:
admissions.set_index('Serial No.')
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 316          104                  3  3.0  3.5  8.00
# 3                 322          110                  3  3.5  2.5  8.67
# 4                 314          103                  2  2.0  3.0  8.21
# 5                 330          115                  5  4.5  3.0  9.34
# ...               ...          ...                ...  ...  ...   ...
# 381               324          110                  3  3.5  3.5  9.04
# 382               325          107                  3  3.0  3.5  9.11
# 383               330          116                  4  5.0  4.5  9.45
# 384               312          103                  3  3.5  4.0  8.78
# 385               333          117                  4  5.0  4.0  9.66
#
#             Research  Chance of Admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.72
# 3                  1             0.80
# 4                  0             0.65
# 5                  1             0.90
# ...              ...              ...
# 381                1             0.82
# 382                1             0.84
# 383                1             0.91
# 384                0             0.67
# 385                1             0.95
#
# [385 rows x 8 columns]

# %% [markdown]
# Turns out that `GRE Score` and `CGPA` also uniquely identify the data. Show this in the cell below.

# %%
# Your code here:
new = admissions.copy()
new.set_index(['GRE Score','CGPA'], inplace=True)
new
# Out:
#                 Serial No.  TOEFL Score  University Rating  SOP  LOR  \
# GRE Score CGPA
# 337       9.65           1          118                  4  4.5  4.5
# 316       8.00           2          104                  3  3.0  3.5
# 322       8.67           3          110                  3  3.5  2.5
# 314       8.21           4          103                  2  2.0  3.0
# 330       9.34           5          115                  5  4.5  3.0
# ...                    ...          ...                ...  ...  ...
# 324       9.04         381          110                  3  3.5  3.5
# 325       9.11         382          107                  3  3.0  3.5
# 330       9.45         383          116                  4  5.0  4.5
# 312       8.78         384          103                  3  3.5  4.0
# 333       9.66         385          117                  4  5.0  4.0
#
#                 Research  Chance of Admit
# GRE Score CGPA
# 337       9.65         1             0.92
# 316       8.00         1             0.72
# 322       8.67         1             0.80
# 314       8.21         0             0.65
# 330       9.34         1             0.90
# ...                  ...              ...
# 324       9.04         1             0.82
# 325       9.11         1             0.84
# 330       9.45         1             0.91
# 312       8.78         0             0.67
# 333       9.66         1             0.95
#
# [385 rows x 7 columns]

# %% [markdown]
# Replace the index with an index comprised of two columns - `GRE Score` and `CGPA`. Remove the columns from the dataset as well. Make sure to use `inplace=True`.

# %% [markdown]
# Now change the index back to a sequence starting at zero using the `reset_index` function. Make sure to use `inplace=True`.

# %%
# Your code here:

res_new = new.reset_index()
res_new
# Out:
#      GRE Score  CGPA  Serial No.  TOEFL Score  University Rating  SOP  LOR  \
# 0          337  9.65           1          118                  4  4.5  4.5
# 1          316  8.00           2          104                  3  3.0  3.5
# 2          322  8.67           3          110                  3  3.5  2.5
# 3          314  8.21           4          103                  2  2.0  3.0
# 4          330  9.34           5          115                  5  4.5  3.0
# ..         ...   ...         ...          ...                ...  ...  ...
# 380        324  9.04         381          110                  3  3.5  3.5
# 381        325  9.11         382          107                  3  3.0  3.5
# 382        330  9.45         383          116                  4  5.0  4.5
# 383        312  8.78         384          103                  3  3.5  4.0
# 384        333  9.66         385          117                  4  5.0  4.0
#
#      Research  Chance of Admit
# 0           1             0.92
# 1           1             0.72
# 2           1             0.80
# 3           0             0.65
# 4           1             0.90
# ..        ...              ...
# 380         1             0.82
# 381         1             0.84
# 382         1             0.91
# 383         0             0.67
# 384         1             0.95
#
# [385 rows x 9 columns]

# %% [markdown]
# # Challenge 2 - Advanced Functions
#
# In this part of the lab, we would like to test complex conditions on the entire dataset at once. Let's start by finding the number of rows where the CGPA is higher than 9 and the student has conducted research.

# %%
# Your code here:
av_func = res_new.loc[res_new['CGPA']>9].reset_index()
av_func
# Out:
#      index  GRE Score  CGPA  Serial No.  TOEFL Score  University Rating  SOP  \
# 0        0        337  9.65           1          118                  4  4.5
# 1        4        330  9.34           5          115                  5  4.5
# 2       10        328  9.10          11          112                  4  4.0
# 3       19        328  9.50          20          116                  5  5.0
# 4       20        334  9.70          21          119                  5  5.0
# ..     ...        ...   ...         ...          ...                ...  ...
# 105    379        329  9.23         380          111                  4  4.5
# 106    380        324  9.04         381          110                  3  3.5
# 107    381        325  9.11         382          107                  3  3.0
# 108    382        330  9.45         383          116                  4  5.0
# 109    384        333  9.66         385          117                  4  5.0
#
#      LOR  Research  Chance of Admit
# 0    4.5         1             0.92
# 1    3.0         1             0.90
# 2    4.5         1             0.78
# 3    5.0         1             0.94
# 4    4.5         1             0.95
# ..   ...       ...              ...
# 105  4.0         1             0.89
# 106  3.5         1             0.82
# 107  3.5         1             0.84
# 108  4.5         1             0.91
# 109  4.0         1             0.95
#
# [110 rows x 10 columns]

# %% [markdown]
# Now return all the rows where the CGPA is greater than 9 and the SOP score is less than 3.5. Find the mean chance of admit for these applicants.

# %%
# Your code here:
cgpa_sop = res_new.loc[(res_new['CGPA']>9) & (res_new['SOP'] < 3.5)].reset_index()
#cgpa_sop = cgpa_sop['Chance of Admit'].mean()
cgpa_sop
# Out:
#    index  GRE Score  CGPA  Serial No.  TOEFL Score  University Rating  SOP  \
# 0     28        338  9.40          29          118                  4  3.0
# 1     62        327  9.02          63          114                  3  3.0
# 2    140        326  9.11         141          114                  3  3.0
# 3    217        324  9.01         218          111                  4  3.0
# 4    381        325  9.11         382          107                  3  3.0
#
#    LOR  Research  Chance of Admit
# 0  4.5         1             0.91
# 1  3.0         0             0.61
# 2  3.0         1             0.83
# 3  3.0         1             0.82
# 4  3.5         1             0.84

# %%
cgpa_sop = cgpa_sop['Chance of Admit'].mean()
cgpa_sop
# Out:
# 0.8019999999999999

# %% [markdown]
# We would like to create a deciding factor column for each student. We standardize several columns and then pick the most important factor from a lookup table. If the standardized value is above 0.8, the student will be accepted.
#
# We will start by creating a standardized column for `CGPA`, `GRE Score` and `LOR`. We will name these columns `CGPA_std`, `GRE_std`, and `LOR_std` respecively.
#
# Recall that standardizing a column is done by subtracting the mean of the column from all observations in the column and then dividing each observation in the column by the column's standard deviation.
#
# In the cell below, write a standardization function (a function that takes a column as input and returns a standardized column as output). Make sure to use the `numpy` versions of mean and standard deviation.

# %%
def standardize(col):
    # This function takes a column from a dataframe and returns a standardized column by subtracting the column's mean
    # and dividing by the column's standard deviation.
    # Your code here:
    return ( (col-col.mean())/col.std() )

# %% [markdown]
# Now create the standardized columns `CGPA_std`, `GRE_std`, and `LOR_std` and add them to the `admissions` dataframe.

# %%
# Your code here:
admissions['CGPA_std'] = standardize(admissions['CGPA'])
admissions['GRE_std'] = standardize(admissions['GRE Score'])
admissions['LOR_std']=standardize(admissions['LOR'])
admissions
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        316          104                  3  3.0  3.5  8.00
# 2             3        322          110                  3  3.5  2.5  8.67
# 3             4        314          103                  2  2.0  3.0  8.21
# 4             5        330          115                  5  4.5  3.0  9.34
# ..          ...        ...          ...                ...  ...  ...   ...
# 380         381        324          110                  3  3.5  3.5  9.04
# 381         382        325          107                  3  3.0  3.5  9.11
# 382         383        330          116                  4  5.0  4.5  9.45
# 383         384        312          103                  3  3.5  4.0  8.78
# 384         385        333          117                  4  5.0  4.0  9.66
#
#      Research  Chance of Admit  CGPA_std   GRE_std   LOR_std
# 0           1             0.92  1.747900  1.753381  1.191647
# 1           1             0.72 -0.991211 -0.063367  0.076740
# 2           1             0.80  0.121034  0.455704 -1.038166
# 3           0             0.65 -0.642597 -0.236391 -0.480713
# 4           1             0.90  1.233279  1.147798 -0.480713
# ..        ...              ...       ...       ...       ...
# 380         1             0.82  0.735259  0.628727  0.076740
# 381         1             0.84  0.851463  0.715239  0.076740
# 382         1             0.91  1.415886  1.147798  1.191647
# 383         0             0.67  0.303641 -0.409414  0.634193
# 384         1             0.95  1.764500  1.407334  0.634193
#
# [385 rows x 12 columns]

# %% [markdown]
# We will generate the decision choice at random using the code below. Please run the cell.

# %%
# Run this code:

from random import choices
std_columns = ['CGPA_std', 'GRE_std', 'LOR_std']

decision_choice = choices(std_columns, k=admissions.shape[0])

# %% [markdown]
# Now create the deciding column using the `lookup` function. The lookup column is `decision_choice` found above. Call the column resulting from the lookup function `deciding_column` and add it to the `admissions` dataframe.

# %%
# Your code here:
admissions['deciding_column'] = admissions.lookup(admissions.index,decision_choice)
admissions
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        316          104                  3  3.0  3.5  8.00
# 2             3        322          110                  3  3.5  2.5  8.67
# 3             4        314          103                  2  2.0  3.0  8.21
# 4             5        330          115                  5  4.5  3.0  9.34
# ..          ...        ...          ...                ...  ...  ...   ...
# 380         381        324          110                  3  3.5  3.5  9.04
# 381         382        325          107                  3  3.0  3.5  9.11
# 382         383        330          116                  4  5.0  4.5  9.45
# 383         384        312          103                  3  3.5  4.0  8.78
# 384         385        333          117                  4  5.0  4.0  9.66
#
#      Research  Chance of Admit  CGPA_std   GRE_std   LOR_std  deciding_column
# 0           1             0.92  1.747900  1.753381  1.191647         1.191647
# 1           1             0.72 -0.991211 -0.063367  0.076740         0.076740
# 2           1             0.80  0.121034  0.455704 -1.038166         0.121034
# 3           0             0.65 -0.642597 -0.236391 -0.480713        -0.642597
# 4           1             0.90  1.233279  1.147798 -0.480713         1.233279
# ..        ...              ...       ...       ...       ...              ...
# 380         1             0.82  0.735259  0.628727  0.076740         0.076740
# 381         1             0.84  0.851463  0.715239  0.076740         0.076740
# 382         1             0.91  1.415886  1.147798  1.191647         1.415886
# 383         0             0.67  0.303641 -0.409414  0.634193        -0.409414
# 384         1             0.95  1.764500  1.407334  0.634193         1.764500
#
# [385 rows x 13 columns]

# %% [markdown]
# Create a column called `decision` in the `admissions` dataframe. Assign 1 to this column if the value of `deciding_column` is greater than 0.8 and 0 otherwise.

# %%
# Your code here:
admissions['decision'] = np.where(admissions['deciding_column']>0.8,1,0)
admissions
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        316          104                  3  3.0  3.5  8.00
# 2             3        322          110                  3  3.5  2.5  8.67
# 3             4        314          103                  2  2.0  3.0  8.21
# 4             5        330          115                  5  4.5  3.0  9.34
# ..          ...        ...          ...                ...  ...  ...   ...
# 380         381        324          110                  3  3.5  3.5  9.04
# 381         382        325          107                  3  3.0  3.5  9.11
# 382         383        330          116                  4  5.0  4.5  9.45
# 383         384        312          103                  3  3.5  4.0  8.78
# 384         385        333          117                  4  5.0  4.0  9.66
#
#      Research  Chance of Admit  CGPA_std   GRE_std   LOR_std  deciding_column  \
# 0           1             0.92  1.747900  1.753381  1.191647         1.191647
# 1           1             0.72 -0.991211 -0.063367  0.076740         0.076740
# 2           1             0.80  0.121034  0.455704 -1.038166         0.121034
# 3           0             0.65 -0.642597 -0.236391 -0.480713        -0.642597
# 4           1             0.90  1.233279  1.147798 -0.480713         1.233279
# ..        ...              ...       ...       ...       ...              ...
# 380         1             0.82  0.735259  0.628727  0.076740         0.076740
# 381         1             0.84  0.851463  0.715239  0.076740         0.076740
# 382         1             0.91  1.415886  1.147798  1.191647         1.415886
# 383         0             0.67  0.303641 -0.409414  0.634193        -0.409414
# 384         1             0.95  1.764500  1.407334  0.634193         1.764500
#
#      decision
# 0           1
# 1           0
# 2           0
# 3           0
# 4           1
# ..        ...
# 380         0
# 381         0
# 382         1
# 383         0
# 384         1
#
# [385 rows x 14 columns]

# %% [markdown]
# How many applicants will be accepted to the program using the decision column? Compute the result below.

# %%
# Your code here:
conteo = admissions.loc[admissions['decision'] == 1]['decision'].count()
print('el numero de ingresos es :', conteo)
# Out:
# el numero de ingresos es : 84

# %% [markdown]
# # Challenge 3 - Method Chaining
#
# To increase our coding efficiency, let's make a number of changes to our dataframe in one line of code.
#
# In the cell below, remove all non character symbols from the column names, replace all spaces in column names to underscores, and change all upper case characters to lower case. Assign these new column values to `admissions.columns`.

# %%
# Your code here:
cols = admissions.columns
new_cols = [i.lower().replace(' ', '_') for i in admissions]
new_cols
# Out:
# ['serial_no.',
#  'gre_score',
#  'toefl_score',
#  'university_rating',
#  'sop',
#  'lor',
#  'cgpa',
#  'research',
#  'chance_of_admit',
#  'cgpa_std',
#  'gre_std',
#  'lor_std',
#  'deciding_column',
#  'decision']

# %% [markdown]
# In the cell below, give all student with a university rating of 4 or higher a 10 point boost on their GRE score and split the column into 4 bins using the `cut` function. Assign this new score to the variable `adjusted_gre`.

# %%
# Your code here:
admissions['adjusted_gre'] = np.where(admissions['GRE Score']> 4 , admissions['GRE Score']+10,admissions['GRE Score'])
admissions
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        316          104                  3  3.0  3.5  8.00
# 2             3        322          110                  3  3.5  2.5  8.67
# 3             4        314          103                  2  2.0  3.0  8.21
# 4             5        330          115                  5  4.5  3.0  9.34
# ..          ...        ...          ...                ...  ...  ...   ...
# 380         381        324          110                  3  3.5  3.5  9.04
# 381         382        325          107                  3  3.0  3.5  9.11
# 382         383        330          116                  4  5.0  4.5  9.45
# 383         384        312          103                  3  3.5  4.0  8.78
# 384         385        333          117                  4  5.0  4.0  9.66
#
#      Research  Chance of Admit  CGPA_std   GRE_std   LOR_std  deciding_column  \
# 0           1             0.92  1.747900  1.753381  1.191647         1.191647
# 1           1             0.72 -0.991211 -0.063367  0.076740         0.076740
# 2           1             0.80  0.121034  0.455704 -1.038166         0.121034
# 3           0             0.65 -0.642597 -0.236391 -0.480713        -0.642597
# 4           1             0.90  1.233279  1.147798 -0.480713         1.233279
# ..        ...              ...       ...       ...       ...              ...
# 380         1             0.82  0.735259  0.628727  0.076740         0.076740
# 381         1             0.84  0.851463  0.715239  0.076740         0.076740
# 382         1             0.91  1.415886  1.147798  1.191647         1.415886
# 383         0             0.67  0.303641 -0.409414  0.634193        -0.409414
# 384         1             0.95  1.764500  1.407334  0.634193         1.764500
#
#      decision  adjusted_gre
# 0           1           347
# 1           0           326
# 2           0           332
# 3           0           324
# 4           1           340
# ..        ...           ...
# 380         0           334
# 381         0           335
# 382         1           340
# 383         0           322
# 384         1           343
#
# [385 rows x 15 columns]

# %%
admissions['bins'] = pd.cut(admissions['adjusted_gre'], bins=4)
admissions
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        316          104                  3  3.0  3.5  8.00
# 2             3        322          110                  3  3.5  2.5  8.67
# 3             4        314          103                  2  2.0  3.0  8.21
# 4             5        330          115                  5  4.5  3.0  9.34
# ..          ...        ...          ...                ...  ...  ...   ...
# 380         381        324          110                  3  3.5  3.5  9.04
# 381         382        325          107                  3  3.0  3.5  9.11
# 382         383        330          116                  4  5.0  4.5  9.45
# 383         384        312          103                  3  3.5  4.0  8.78
# 384         385        333          117                  4  5.0  4.0  9.66
#
#      Research  Chance of Admit  CGPA_std   GRE_std   LOR_std  deciding_column  \
# 0           1             0.92  1.747900  1.753381  1.191647         1.191647
# 1           1             0.72 -0.991211 -0.063367  0.076740         0.076740
# 2           1             0.80  0.121034  0.455704 -1.038166         0.121034
# 3           0             0.65 -0.642597 -0.236391 -0.480713        -0.642597
# 4           1             0.90  1.233279  1.147798 -0.480713         1.233279
# ..        ...              ...       ...       ...       ...              ...
# 380         1             0.82  0.735259  0.628727  0.076740         0.076740
# 381         1             0.84  0.851463  0.715239  0.076740         0.076740
# 382         1             0.91  1.415886  1.147798  1.191647         1.415886
# 383         0             0.67  0.303641 -0.409414  0.634193        -0.409414
# 384         1             0.95  1.764500  1.407334  0.634193         1.764500
#
#      decision  adjusted_gre            bins
# 0           1           347  (337.5, 350.0]
# 1           0           326  (325.0, 337.5]
# 2           0           332  (325.0, 337.5]
# 3           0           324  (312.5, 325.0]
# 4           1           340  (337.5, 350.0]
# ..        ...           ...             ...
# 380         0           334  (325.0, 337.5]
# 381         0           335  (325.0, 337.5]
# 382         1           340  (337.5, 350.0]
# 383         0           322  (312.5, 325.0]
# 384         1           343  (337.5, 350.0]
#
# [385 rows x 16 columns]

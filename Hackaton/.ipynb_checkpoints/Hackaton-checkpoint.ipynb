# %% [markdown]
# # Hackaton

# %% [markdown]
# Creación de Estructura de Base de Datos

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as bs
from pymongo import MongoClient
from tqdm import tqdm_notebook as tqdm

# %%
#Login
f= open("k.txt","r")
pw=f.read()
f.close()
connect_local='mongodb://localhost:27017'
connect='mongodb+srv://albertoid:{}@ironhack-hackaton-6ah57.azure.mongodb.net/test?retryWrites=true&w=majority'.format(pw)
client=MongoClient(connect_local)

# %%
client.list_database_names()
# Out:
# ['Hackaton', 'admin', 'companies', 'config', 'local']

# %%
cHack_Places=client.Hackaton.Places

# %%
#Estructura Básica del Data Frame
df_Places=pd.DataFrame(columns=['name','gps','address','price','kind','cap',
                                'schedule','menu','service','bike','phone',
                                'email','social','reviews'])

# %%
df_Users=pd.DataFrame(columns=['user_id','email','google_id','password'])

# %%
df_Users
# Out:
# Empty DataFrame
# Columns: [user_id, email, google_id, password]
# Index: []

# %%
df_Places
# Out:
# Empty DataFrame
# Columns: [name, gps, address, price, kind, cap, schedule, menu, service, bike, phone, email, social, reviews]
# Index: []

# %%
#Carga de datos iniciales del INEGI
inegi=pd.read_csv('./inegi_cdmx.csv',encoding='ISO-8859-1')

#Busqueda de actividades economicas
actividades=inegi.nombre_act.unique()
af=[]
for i in actividades:
    #i=i.upper()
    #print(i)
    if i.find('Restaurante')>=0:
        af.append(i)
    elif i.find('COMIDA')>=0:
        af.append(i)

#Limpieza de columnas no relevantes
dcol=['id','codigo_act','raz_social','tipo_vial','manzana','fecha_alta','ageb','entidad','cve_mun','cve_loc','tipo_v_e_1','nom_v_e_1','tipo_v_e_2','tipo_v_e_3','nom_v_e_3','nom_v_e_2','cve_ent','localidad','tipoUniEco','edificio','edificio_e','numero_int','letra_int','tipoCenCom','nom_CenCom','num_local']
inegi = inegi.drop(columns=dcol)

#Filtro Restaurantes
inegi = inegi[(inegi.nombre_act==af[0]) | (inegi.nombre_act==af[1]) | (inegi.nombre_act==af[2]) | (inegi.nombre_act==af[3]) | (inegi.nombre_act==af[4]) | (inegi.nombre_act==af[5]) | (inegi.nombre_act==af[6])]

#Filtro Municipio = Cuahutemoc
inegi=inegi[inegi.municipio=='Cuauhtémoc']

inegi=inegi.reset_index()
inegi=inegi.drop(columns='index')
inegi=inegi.drop(columns='nombre_act')
inegi=inegi.fillna('')

# %%
inegi.numero_ext=inegi.numero_ext.apply(lambda x: str(x))
inegi.cod_postal=inegi.cod_postal.apply(lambda x: str(x))

# %%
inegi['Address'] = inegi.nom_vial + ' ' + inegi.numero_ext + ' ' + \
                   inegi.letra_ext + ', ' + inegi.tipo_asent + ' ' + inegi.nomb_asent + ', C.P.' + \
                   inegi.cod_postal + ', Alcaldía '+ inegi.municipio

# %%
pd.Series([inegi.latitud,inegi.longitud])
# Out:
# 0    0       19.434085
# 1       19.429225
# 2       19...
# 1    0      -99.168079
# 1      -99.161818
# 2      -99...
# dtype: object

# %%
inegi.dtypes
# Out:
# nom_estab      object
# per_ocu        object
# nom_vial       object
# numero_ext     object
# letra_ext      object
# tipo_asent     object
# nomb_asent     object
# cod_postal     object
# municipio      object
# telefono       object
# correoelec     object
# www            object
# latitud       float64
# longitud      float64
# Address        object
# gps           float64
# dtype: object

# %%
inegi['gps'] = pd.Series([inegi.latitud,inegi.longitud])
inegi.gps[1][2]
# Out:
# -99.17270412

# %%
inegi.head()
# Out:
#               nom_estab           per_ocu             nom_vial numero_ext  \
# 0        100% CARNÍVORO    0 a 5 personas             RIO SENA
# 1      1500 REFORMA 222  31 a 50 personas  PASEO DE LA REFORMA      222.0
# 2    50 FRIENDS CONDESA  11 a 30 personas            CADEREYTA       19.0
# 3    50 FRIENDS REFORMA    0 a 5 personas  PASEO DE LA REFORMA      342.0
# 4  A BURGER RESTAURANTE    0 a 5 personas             COAHUILA      180.0
#
#   letra_ext tipo_asent  nomb_asent cod_postal   municipio     telefono  \
# 0        SN    COLONIA  CUAHUTEMOC     6500.0  Cuauhtémoc  5.51916e+09
# 1              COLONIA      JUAREZ     6600.0  Cuauhtémoc
# 2              COLONIA     CONDESA     6140.0  Cuauhtémoc
# 3              COLONIA  CUAUHTÉMOC     6600.0  Cuauhtémoc
# 4              MANZANA   TECNOCASA     6760.0  Cuauhtémoc
#
#                              correoelec                        www    latitud  \
# 0                                                                   19.434085
# 1  pfc_reforma222@pfchangsmexico.com.mx  WWW.PFCHANGSMEXICO.COM.MX  19.429225
# 2             RENE.RIVERA@CINBERSOL.COM     WWW.GRUPOCINBERSOL.COM  19.412547
# 3             RENE.RIVERA@CINBERSOL.COM                             19.426064
# 4                                                                   19.410796
#
#     longitud                                            Address  \
# 0 -99.168079  RIO SENA  SN, COLONIA CUAHUTEMOC, C.P.6500.0, ...
# 1 -99.161818  PASEO DE LA REFORMA 222.0 , COLONIA JUAREZ, C....
# 2 -99.172704  CADEREYTA 19.0 , COLONIA CONDESA, C.P.6140.0, ...
# 3 -99.167580  PASEO DE LA REFORMA 342.0 , COLONIA CUAUHTÉMOC...
# 4 -99.164705  COAHUILA 180.0 , MANZANA TECNOCASA, C.P.6760.0...
#
#                                                  gps
# 0  0       19.434085
# 1       19.429225
# 2       19...
# 1  0      -99.168079
# 1      -99.161818
# 2      -99...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
inegi.drop(columns='gps')
# Out:
#                  nom_estab           per_ocu                nom_vial  \
# 0           100% CARNÍVORO    0 a 5 personas                RIO SENA
# 1         1500 REFORMA 222  31 a 50 personas     PASEO DE LA REFORMA
# 2       50 FRIENDS CONDESA  11 a 30 personas               CADEREYTA
# 3       50 FRIENDS REFORMA    0 a 5 personas     PASEO DE LA REFORMA
# 4     A BURGER RESTAURANTE    0 a 5 personas                COAHUILA
# ...                    ...               ...                     ...
# 5986               YUE HAI   6 a 10 personas                HAMBURGO
# 5987       YUG VEGETARIANO  11 a 30 personas                VARSOVIA
# 5988            ZAID-LOUGE    0 a 5 personas                HAMBURGO
# 5989              ZANDIATH    0 a 5 personas  REPUBLICA DE ARGENTINA
# 5990    ZONA ROSA WINGSTOP    0 a 5 personas               LIVERPOOL
#
#      numero_ext letra_ext tipo_asent  nomb_asent cod_postal   municipio  \
# 0                      SN    COLONIA  CUAHUTEMOC     6500.0  Cuauhtémoc
# 1         222.0              COLONIA      JUAREZ     6600.0  Cuauhtémoc
# 2          19.0              COLONIA     CONDESA     6140.0  Cuauhtémoc
# 3         342.0              COLONIA  CUAUHTÉMOC     6600.0  Cuauhtémoc
# 4         180.0              MANZANA   TECNOCASA     6760.0  Cuauhtémoc
# ...         ...       ...        ...         ...        ...         ...
# 5986       96.0         B    COLONIA      JUAREZ     6600.0  Cuauhtémoc
# 5987        3.0         B    COLONIA      JUAREZ     6600.0  Cuauhtémoc
# 5988       15.0         2    COLONIA      JUAREZ     6600.0  Cuauhtémoc
# 5989       51.0              COLONIA      CENTR0     6010.0  Cuauhtémoc
# 5990       49.0              COLONIA      JUAREZ     6600.0  Cuauhtémoc
#
#          telefono                            correoelec  \
# 0     5.51916e+09
# 1                  pfc_reforma222@pfchangsmexico.com.mx
# 2                             RENE.RIVERA@CINBERSOL.COM
# 3                             RENE.RIVERA@CINBERSOL.COM
# 4
# ...           ...                                   ...
# 5986  5.55533e+09
# 5987                                    VEGYU@GMAIL.COM
# 5988                             ZAIDELSOTERO@YAHOO.COM
# 5989
# 5990                   FERNANDA.GUEREÑA@WINGSTOP.COM.MX
#
#                             www    latitud   longitud  \
# 0                                19.434085 -99.168079
# 1     WWW.PFCHANGSMEXICO.COM.MX  19.429225 -99.161818
# 2        WWW.GRUPOCINBERSOL.COM  19.412547 -99.172704
# 3                                19.426064 -99.167580
# 4                                19.410796 -99.164705
# ...                         ...        ...        ...
# 5986                             19.426627 -99.163657
# 5987      WWW.LOVEGETARIANO.COM  19.425667 -99.168721
# 5988                             19.429048 -99.158835
# 5989                             19.438826 -99.131268
# 5990                             19.423832 -99.165177
#
#                                                 Address
# 0     RIO SENA  SN, COLONIA CUAHUTEMOC, C.P.6500.0, ...
# 1     PASEO DE LA REFORMA 222.0 , COLONIA JUAREZ, C....
# 2     CADEREYTA 19.0 , COLONIA CONDESA, C.P.6140.0, ...
# 3     PASEO DE LA REFORMA 342.0 , COLONIA CUAUHTÉMOC...
# 4     COAHUILA 180.0 , MANZANA TECNOCASA, C.P.6760.0...
# ...                                                 ...
# 5986  HAMBURGO 96.0 B, COLONIA JUAREZ, C.P.6600.0, A...
# 5987  VARSOVIA 3.0 B, COLONIA JUAREZ, C.P.6600.0, Al...
# 5988  HAMBURGO 15.0 2, COLONIA JUAREZ, C.P.6600.0, A...
# 5989  REPUBLICA DE ARGENTINA 51.0 , COLONIA CENTR0, ...
# 5990  LIVERPOOL 49.0 , COLONIA JUAREZ, C.P.6600.0, A...
#
# [5991 rows x 15 columns]

# %% [markdown]
# ####

# %%
inegi['gps'] = list(zip(inegi['latitud'],inegi['longitud']))
inegi.head()
# Out:
#               nom_estab           per_ocu             nom_vial numero_ext  \
# 0        100% CARNÍVORO    0 a 5 personas             RIO SENA
# 1      1500 REFORMA 222  31 a 50 personas  PASEO DE LA REFORMA      222.0
# 2    50 FRIENDS CONDESA  11 a 30 personas            CADEREYTA       19.0
# 3    50 FRIENDS REFORMA    0 a 5 personas  PASEO DE LA REFORMA      342.0
# 4  A BURGER RESTAURANTE    0 a 5 personas             COAHUILA      180.0
#
#   letra_ext tipo_asent  nomb_asent cod_postal   municipio     telefono  \
# 0        SN    COLONIA  CUAHUTEMOC     6500.0  Cuauhtémoc  5.51916e+09
# 1              COLONIA      JUAREZ     6600.0  Cuauhtémoc
# 2              COLONIA     CONDESA     6140.0  Cuauhtémoc
# 3              COLONIA  CUAUHTÉMOC     6600.0  Cuauhtémoc
# 4              MANZANA   TECNOCASA     6760.0  Cuauhtémoc
#
#                              correoelec                        www    latitud  \
# 0                                                                   19.434085
# 1  pfc_reforma222@pfchangsmexico.com.mx  WWW.PFCHANGSMEXICO.COM.MX  19.429225
# 2             RENE.RIVERA@CINBERSOL.COM     WWW.GRUPOCINBERSOL.COM  19.412547
# 3             RENE.RIVERA@CINBERSOL.COM                             19.426064
# 4                                                                   19.410796
#
#     longitud                                            Address  \
# 0 -99.168079  RIO SENA  SN, COLONIA CUAHUTEMOC, C.P.6500.0, ...
# 1 -99.161818  PASEO DE LA REFORMA 222.0 , COLONIA JUAREZ, C....
# 2 -99.172704  CADEREYTA 19.0 , COLONIA CONDESA, C.P.6140.0, ...
# 3 -99.167580  PASEO DE LA REFORMA 342.0 , COLONIA CUAUHTÉMOC...
# 4 -99.164705  COAHUILA 180.0 , MANZANA TECNOCASA, C.P.6760.0...
#
#                            gps
# 0  (19.43408487, -99.16807939)
# 1  (19.42922524, -99.16181843)
# 2  (19.41254691, -99.17270412)
# 3   (19.42606429, -99.1675795)
# 4  (19.41079613, -99.16470454)

# %% [markdown]
# Scrapings

# %%
inegi['address']= inegi.nom_vial + str

# %% [markdown]
# Pruebas de conexión

# %%
import pandas as pd
import re

# %% [markdown]
# # Lectura del archivo csv

# %%
# lee el archivo con un encoding diferente a utf-8 ya que no reconoce ciertos caracteres dentro de el csv
shark = pd.read_csv('attacks.csv',encoding = "ISO-8859-1")
shark_info = pd.DataFrame(shark)

# %%
shark_info
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722         NaN          NaN     NaN         NaN        NaN
# 25723         NaN          NaN     NaN         NaN        NaN
# 25724          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 25720              NaN                             NaN          NaN
# 25721              NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
# 25723              NaN                             NaN          NaN
# 25724              NaN                             NaN          NaN
#
#                   Name Sex   ...         Species   \
# 0          Julie Wolfe    F  ...      White shark
# 1      Adyson McNeely     F  ...              NaN
# 2          John Denges    M  ...              NaN
# 3                 male    M  ...        2 m shark
# 4       Gustavo Ramos     M  ...  Tiger shark, 3m
# ...                ...  ...  ...              ...
# 25720              NaN  NaN  ...              NaN
# 25721              NaN  NaN  ...              NaN
# 25722              NaN  NaN  ...              NaN
# 25723              NaN  NaN  ...              NaN
# 25724              NaN  NaN  ...              NaN
#
#                Investigator or Source                       pdf  \
# 0                    R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1      K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2      K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3                      B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4                           A .Kipper      2018.06.04-Ramos.pdf
# ...                               ...                       ...
# 25720                             NaN                       NaN
# 25721                             NaN                       NaN
# 25722                             NaN                       NaN
# 25723                             NaN                       NaN
# 25724                             NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 25720                                                NaN
# 25721                                                NaN
# 25722                                                NaN
# 25723                                                NaN
# 25724                                                NaN
#
#                                                     href Case Number.1  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                  ...           ...
# 25720                                                NaN           NaN
# 25721                                                NaN           NaN
# 25722                                                NaN           NaN
# 25723                                                NaN           NaN
# 25724                                                NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0        2018.06.25         6303.0         NaN         NaN
# 1        2018.06.18         6302.0         NaN         NaN
# 2        2018.06.09         6301.0         NaN         NaN
# 3        2018.06.08         6300.0         NaN         NaN
# 4        2018.06.04         6299.0         NaN         NaN
# ...             ...            ...         ...         ...
# 25720           NaN            NaN         NaN         NaN
# 25721           NaN            NaN         NaN         NaN
# 25722           NaN            NaN         NaN         NaN
# 25723           NaN            NaN         NaN         NaN
# 25724           NaN            NaN         NaN         NaN
#
# [25725 rows x 24 columns]

# %%
shark_info.shape
# Out:
# (25725, 24)

# %%
shark_info.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %% [markdown]
# # Drop Duplicates

# %%
# elimina todas las filas que contienen valores iguales, que para este caso es nan en todas sus columnas
duplicados = shark_info.drop_duplicates().reset_index()
duplicados.sample(10)
# Out:
#       index   Case Number         Date    Year        Type           Country  \
# 1518   1518    2005.12.20  20-Dec-2005  2005.0     Boating    ATLANTIC OCEAN
# 2887   2887    1984.09.11  11-Sep-1984  1984.0    Provoked            MEXICO
# 3931   3931  1961.01.06.c  06-Jan-1961  1961.0  Unprovoked      SOUTH AFRICA
# 4616   4616  1946.00.00.a         1946  1946.0  Unprovoked      PERSIAN GULF
# 1941   1941    2001.06.10  10-Jun-2001  2001.0    Provoked               USA
# 2363   2363    1995.08.07  07-Aug-1995  1995.0  Unprovoked               USA
# 578     578    2014.03.12  12-Mar-2014  2014.0  Unprovoked         AUSTRALIA
# 4206   4206  1957.04.07.b  07-Apr-1957  1957.0  Unprovoked  PAPUA NEW GUINEA
# 378     378  2015.08.18.b  18-Aug-2015  2015.0     Boating               USA
# 186     186  2017.01.13.a  13-Jan-2017  2017.0  Unprovoked               USA
#
#                                    Area                              Location  \
# 1518  600 nm west of the Canary Islands                                   NaN
# 2887                    Baja California                      Guadalupe Island
# 3931                      KwaZulu-Natal                          Winkelspruit
# 4616                 "Head of the Gulf"                                   NaN
# 1941                         California                       Catalina Island
# 2363                            Florida  Ponce de Leon Inlet, Volusia County
# 578                     New South Wales                      Lighthouse Beach
# 4206      Bougainville (North Solomons)                                 Kieta
# 378                          California                  Santa Barbara County
# 186                             Florida                          Jensen Beach
#
#                                             Activity  \
# 1518  Competing in the Woodvale Atlantic Rowing Race
# 2887                                    Spearfishing
# 3931                                        Standing
# 4616                   Bitten after dhow shipwrecked
# 1941                                    Spearfishing
# 2363                                   Body boarding
# 578                                         Swimming
# 4206                               Diving from canoe
# 378                                    Kayak Fishing
# 186                                              NaN
#
#                                                    Name  ...  \
# 1518  7 m boat, occupants: Tara Remington & Iain Rudkin  ...
# 2887                                       Harry Ingram  ...
# 3931                                       Michael Land  ...
# 4616                                         Arab woman  ...
# 1941                                        Bill McNair  ...
# 2363                                       Matt Sturgis  ...
# 578                                         Mike Porter  ...
# 4206                                     Omni (rescuer)  ...
# 378                                         Connor Lyon  ...
# 186                                         a lifeguard  ...
#
#                                     Species   \
# 1518                               3 m shark
# 2887               4.5 m to 5.5m white shark
# 3931      White shark, based on bite pattern
# 4616                                     NaN
# 1941  White shark, 2.4 m to 3 m [8' to 10']
# 2363         1.2 m to 1.5 m [4' to 5'] shark
# 578                          Wobbegong shark
# 4206                                     NaN
# 378                         White shark, 13'
# 186                                      NaN
#
#                                  Investigator or Source  \
# 1518            R.D. Weeks, GSAF; NZ Herald, 12/21/2005
# 2887                                         R. Collier
# 3931  GSAF;  D. Davies & J. D'Aubrey; D. Davies, pp....
# 4616                   E. Davies; V.M. Coppleson, p.133
# 1941                                   R. Collier, GSAF
# 2363  S. Petersohn, GSAF; Orlando Sentinel, 8/9/1995...
# 578            N. Keene, The Daily Telegraph, 3/13/2014
# 4206                V.M. Coppleson (1958), pp.248 & 266
# 378                                    R. Collier, GSAF
# 186                                     WPTV. 1/13/2017
#
#                                 pdf  \
# 1518         2005.12.20-rowboat.pdf
# 2887          1984.09.11-Ingram.pdf
# 3931          1961.01.06.c-Land.pdf
# 4616     1946.00.00.a-Arabwoman.pdf
# 1941          2001.06.10-McNair.pdf
# 2363     1995.08.07-MattSturgis.pdf
# 578   2014.03.12-LightouseBeach.pdf
# 4206          1957.04.07.b-Omni.pdf
# 378           2015.08.18.b-Lyon.pdf
# 186    2017.01.13.a-JensenBeach.pdf
#
#                                            href formula  \
# 1518  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2887  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3931  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4616  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1941  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2363  http://sharkattackfile.net/spreadsheets/pdf_di...
# 578   http://sharkattackfile.net/spreadsheets/pdf_di...
# 4206  http://sharkattackfile.net/spreadsheets/pdf_di...
# 378   http://sharkattackfile.net/spreadsheets/pdf_di...
# 186   http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 1518  http://sharkattackfile.net/spreadsheets/pdf_di...    2005.12.20
# 2887  http://sharkattackfile.net/spreadsheets/pdf_di...    1984.09.11
# 3931  http://sharkattackfile.net/spreadsheets/pdf_di...  1961.01.06.c
# 4616  http://sharkattackfile.net/spreadsheets/pdf_di...  1946.00.00.a
# 1941  http://sharkattackfile.net/spreadsheets/pdf_di...    2001.06.10
# 2363  http://sharkattackfile.net/spreadsheets/pdf_di...    1995.08.07
# 578   http://sharkattackfile.net/spreadsheets/pdf_di...    2014.03.12
# 4206  http://sharkattackfile.net/spreadsheets/pdf_di...  1957.04.07.b
# 378   http://sharkattackfile.net/spreadsheets/pdf_di...  2015.08.18.b
# 186   http://sharkattackfile.net/spreadsheets/pdf_di...  2017.01.13.a
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23
# 1518    2005.12.20         4786.0         NaN         NaN
# 2887    1984.09.11         3418.0         NaN         NaN
# 3931  1961.01.06.c         2374.0         NaN         NaN
# 4616  1946.00.00.a         1689.0         NaN         NaN
# 1941    2001.06.10         4363.0         NaN         NaN
# 2363    1995.08.07         3942.0         NaN         NaN
# 578     2014.03.12         5726.0         NaN         NaN
# 4206  1957.04.07.b         2099.0         NaN         NaN
# 378   2015.08.18.b         5926.0         NaN         NaN
# 186   2017.01.13.a         6118.0         NaN         NaN
#
# [10 rows x 25 columns]

# %% [markdown]
# # comparacion original vs drop duplicates

# %%
print('tamaño de las filas en el archivo originial',shark_info.shape)
print('tamaño de las filas en el archivo que elimina valores duplicados',duplicados.shape)
# Out:
# tamaño de las filas en el archivo originial (25725, 24)
# tamaño de las filas en el archivo que elimina valores duplicados (6314, 25)

# %%
# reorganizacion de las columnas de la mas importante a menos importante 
cols = ['Case Number', 'Date', 'Year','Type','Country', 'Area','Location',
       'Activity', 'Name', 'Sex ', 'Age', 'Fatal (Y/N)','Species ', 'Time','Investigator or Source',
       'original order','Case Number.1', 'Case Number.2','pdf', 'href formula', 'href','Unnamed: 22','Unnamed: 23']
shark_clean = pd.DataFrame(duplicados, columns=cols)
shark_clean = shark_clean
shark_clean
# Out:
#      Case Number         Date    Year        Type    Country             Area  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
# ...          ...          ...     ...         ...        ...              ...
# 6309           0          NaN     NaN         NaN        NaN              NaN
# 6310           0          NaN     NaN         NaN        NaN              NaN
# 6311           0          NaN     NaN         NaN        NaN              NaN
# 6312         NaN          NaN     NaN         NaN        NaN              NaN
# 6313          xx          NaN     NaN         NaN        NaN              NaN
#
#                             Location     Activity             Name Sex   ...  \
# 0        Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1     St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                       Habush, Oahu      Surfing      John Denges    M  ...
# 3                 Arrawarra Headland      Surfing             male    M  ...
# 4                           La Ticla  Free diving   Gustavo Ramos     M  ...
# ...                              ...          ...              ...  ...  ...
# 6309                             NaN          NaN              NaN  NaN  ...
# 6310                             NaN          NaN              NaN  NaN  ...
# 6311                             NaN          NaN              NaN  NaN  ...
# 6312                             NaN          NaN              NaN  NaN  ...
# 6313                             NaN          NaN              NaN  NaN  ...
#
#                Time          Investigator or Source original order  \
# 0             18h00                R. Collier, GSAF         6303.0
# 1     14h00  -15h00  K.McMurray, TrackingSharks.com         6302.0
# 2             07h45  K.McMurray, TrackingSharks.com         6301.0
# 3               NaN                  B. Myatt, GSAF         6300.0
# 4               NaN                       A .Kipper         6299.0
# ...             ...                             ...            ...
# 6309            NaN                             NaN         6309.0
# 6310            NaN                             NaN         6310.0
# 6311            NaN                             NaN            NaN
# 6312            NaN                             NaN            NaN
# 6313            NaN                             NaN            NaN
#
#      Case Number.1 Case Number.2                       pdf  \
# 0       2018.06.25    2018.06.25      2018.06.25-Wolfe.pdf
# 1       2018.06.18    2018.06.18    2018.06.18-McNeely.pdf
# 2       2018.06.09    2018.06.09     2018.06.09-Denges.pdf
# 3       2018.06.08    2018.06.08  2018.06.08-Arrawarra.pdf
# 4       2018.06.04    2018.06.04      2018.06.04-Ramos.pdf
# ...            ...           ...                       ...
# 6309           NaN           NaN                       NaN
# 6310           NaN           NaN                       NaN
# 6311           NaN           NaN                       NaN
# 6312           NaN           NaN                       NaN
# 6313           NaN           NaN                       NaN
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6309                                                NaN
# 6310                                                NaN
# 6311                                                NaN
# 6312                                                NaN
# 6313                                                NaN
#
#                                                    href Unnamed: 22  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                 ...         ...
# 6309                                                NaN         NaN
# 6310                                                NaN         NaN
# 6311                                                NaN         NaN
# 6312                                                NaN         NaN
# 6313                                                NaN         NaN
#
#      Unnamed: 23
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 6309         NaN
# 6310         NaN
# 6311         NaN
# 6312         NaN
# 6313         NaN
#
# [6314 rows x 23 columns]

# %% [markdown]
# # primera columna 'Case Number'

# %%
# limpiando primera columna de tabla
shark_clean['Case Number'] = shark_clean['Case Number'].str.replace('\.[a-z]+|\.[A-Z]+','', regex=True).fillna('2010.01.01')
shark_clean.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Fatal (Y/N)                object
# Species                    object
# Time                       object
# Investigator or Source     object
# original order            float64
# Case Number.1              object
# Case Number.2              object
# pdf                        object
# href formula               object
# href                       object
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %%
shark_clean['Case Number'] = shark_clean['Case Number'].str.replace('xx','2010.01.01')
shark_clean
# Out:
#      Case Number         Date    Year        Type    Country             Area  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
# ...          ...          ...     ...         ...        ...              ...
# 6309           0          NaN     NaN         NaN        NaN              NaN
# 6310           0          NaN     NaN         NaN        NaN              NaN
# 6311           0          NaN     NaN         NaN        NaN              NaN
# 6312  2010.01.01          NaN     NaN         NaN        NaN              NaN
# 6313  2010.01.01          NaN     NaN         NaN        NaN              NaN
#
#                             Location     Activity             Name Sex   ...  \
# 0        Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1     St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                       Habush, Oahu      Surfing      John Denges    M  ...
# 3                 Arrawarra Headland      Surfing             male    M  ...
# 4                           La Ticla  Free diving   Gustavo Ramos     M  ...
# ...                              ...          ...              ...  ...  ...
# 6309                             NaN          NaN              NaN  NaN  ...
# 6310                             NaN          NaN              NaN  NaN  ...
# 6311                             NaN          NaN              NaN  NaN  ...
# 6312                             NaN          NaN              NaN  NaN  ...
# 6313                             NaN          NaN              NaN  NaN  ...
#
#                Time          Investigator or Source original order  \
# 0             18h00                R. Collier, GSAF         6303.0
# 1     14h00  -15h00  K.McMurray, TrackingSharks.com         6302.0
# 2             07h45  K.McMurray, TrackingSharks.com         6301.0
# 3               NaN                  B. Myatt, GSAF         6300.0
# 4               NaN                       A .Kipper         6299.0
# ...             ...                             ...            ...
# 6309            NaN                             NaN         6309.0
# 6310            NaN                             NaN         6310.0
# 6311            NaN                             NaN            NaN
# 6312            NaN                             NaN            NaN
# 6313            NaN                             NaN            NaN
#
#      Case Number.1 Case Number.2                       pdf  \
# 0       2018.06.25    2018.06.25      2018.06.25-Wolfe.pdf
# 1       2018.06.18    2018.06.18    2018.06.18-McNeely.pdf
# 2       2018.06.09    2018.06.09     2018.06.09-Denges.pdf
# 3       2018.06.08    2018.06.08  2018.06.08-Arrawarra.pdf
# 4       2018.06.04    2018.06.04      2018.06.04-Ramos.pdf
# ...            ...           ...                       ...
# 6309           NaN           NaN                       NaN
# 6310           NaN           NaN                       NaN
# 6311           NaN           NaN                       NaN
# 6312           NaN           NaN                       NaN
# 6313           NaN           NaN                       NaN
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6309                                                NaN
# 6310                                                NaN
# 6311                                                NaN
# 6312                                                NaN
# 6313                                                NaN
#
#                                                    href Unnamed: 22  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                 ...         ...
# 6309                                                NaN         NaN
# 6310                                                NaN         NaN
# 6311                                                NaN         NaN
# 6312                                                NaN         NaN
# 6313                                                NaN         NaN
#
#      Unnamed: 23
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 6309         NaN
# 6310         NaN
# 6311         NaN
# 6312         NaN
# 6313         NaN
#
# [6314 rows x 23 columns]

# %% [markdown]
# # limpieza de las fechas date

# %%
shark_clean['Date'] = shark_clean['Date'].str.replace('Reported| Early| Late|\.[a-z]|\.[A-Z]|Between May &' ,'').fillna('01-01-2000')
shark_clean.sample(20)
# Out:
#       Case Number          Date    Year          Type           Country  \
# 1825   2002.09.27   27-Sep-2002  2002.0      Provoked               USA
# 423    2015.05.24   24-May-2015  2015.0    Unprovoked               USA
# 4240   1956.08.15   15-Aug-1956  1956.0    Unprovoked               USA
# 1911   2001.09.01   01-Sep-2001  2001.0    Unprovoked               USA
# 5768   1885.08.17   17-Aug-1885  1885.0    Unprovoked    ATLANTIC OCEAN
# 1418   2006.11.25   25-Nov-2006  2006.0  Sea Disaster       PHILIPPINES
# 1922   2001.08.18   18-Aug-2001  2001.0    Unprovoked               USA
# 4467   1950.07.27   27-Jul-1950  1950.0       Boating         AUSTRALIA
# 751    2012.08.28   28-Aug-2012  2012.0    Unprovoked         AUSTRALIA
# 2187   1998.05.29   29-May-1998  1998.0    Unprovoked      SOUTH AFRICA
# 4682   1943.03.14   14-Mar-1943  1943.0  Sea Disaster      SIERRA LEONE
# 3499   1967.11.30   30-Nov-1967  1967.0      Provoked         AUSTRALIA
# 2955   1983.01.15   15-Jan-1983  1983.0       Invalid      SOUTH AFRICA
# 2458   1994.01.12   12-Jan-1994  1994.0          Boat         AUSTRALIA
# 3795   1962.09.02  02-Sep-1962   1962.0    Unprovoked             ITALY
# 3393   1970.06.13   13-Jun-1970  1970.0    Unprovoked           GRENADA
# 4110   1959.02.06   16-Feb-1959  1959.0      Provoked  PAPUA NEW GUINEA
# 4251   1956.07.12   12-Jul-1956  1956.0    Unprovoked               USA
# 4103  1959.04.09.   09-Apr-1959  1959.0    Unprovoked      SOUTH AFRICA
# 2344   1995.09.16   16-Sep-1995  1995.0    Unprovoked           REUNION
#
#                        Area                                        Location  \
# 1825                Florida                        Key Largo, Monroe County
# 423                 Florida                    Cocoa Beach, Brevard  County
# 4240             California             Pismo Beach, San Luis Obispo County
# 1911               Virginia          Sandbridge Beach, Princess Anne County
# 5768                    NaN                                             NaN
# 1418      Surigao del Norte             Off Bilisan Point, Hinatuarn Island
# 1922                Florida                New Smyrna Beach, Volusia County
# 4467        South Australia                                     Streaky Bay
# 751       Western Australia                   Red Bluff near Quobba Station
# 2187  Eastern Cape Province                Sardinia Bay near Port Elizabeth
# 4682                    NaN                                             NaN
# 3499        New South Wales                                      Wollongong
# 2955          KwaZulu-Natal                                     Amanzimtoti
# 2458      Western Australia                                          Albany
# 3795         Tyrrhenian Sea                        Circeo, Secca del Quadro
# 3393      St. Andrew Parish                                       Grenville
# 4110     Kikori River mouth  Ururumba, mouth of Kikori River 7.45S, 144.40E
# 4251         South Carolina                Isle of Palms, Charleston County
# 4103  Eastern Cape Province                                 Port Elizabeth
# 2344            Saint-Denis                                             NaN
#
#                                                Activity  \
# 1825                                            Fishing
# 423                                            Swimming
# 4240                                 Swimming near pier
# 1911                                          Swimming
# 5768   Fell or jumped overboard from the liner Rhynland
# 1418                                       Sea Disaster
# 1922                                            Surfing
# 4467                                            Fishing
# 751                                             Surfing
# 2187                                      Body boarding
# 4682  The 21,516-ton troopship Empress of Canada tor...
# 3499                                         Freediving
# 2955                                                NaN
# 2458                                            Fishing
# 3795                       Spearfishing with Scuba gear
# 3393                                             Wading
# 4110                                            Fishing
# 4251                                           Swimming
# 4103                                            Fishing
# 2344                                      Body-boarding
#
#                                                    Name Sex   ...  \
# 1825                                          Jose Diaz    M  ...
# 423                                        Alysa Whetro    F  ...
# 4240                                     Douglas Clarke    M  ...
# 1911                                      David Peltier    M  ...
# 5768                                        J.R. Loesch    M  ...
# 1418                         Sinking of the m.v.Leonida  NaN  ...
# 1922                                         Jeff White    M  ...
# 4467                                 40' fishing cutter  NaN  ...
# 751                                           Jon Hines    M  ...
# 2187                                        Marc Jucker    M  ...
# 4682                                                NaN  NaN  ...
# 3499                                         Jeff Short    M  ...
# 2955                                         black male    M  ...
# 2458  5 m aluminum boat, occupants: Ben Turnbull, Li...  NaN  ...
# 3795                                     Maurizio Sarra    M  ...
# 3393                                    Lincoln Alpheus    M  ...
# 4110                                               male    M  ...
# 4251                                         Eric Rawls    M  ...
# 4103                                               male    M  ...
# 2344                                    Jerome Pruneaux    M  ...
#
#                         Time  \
# 1825               Afternoon
# 423                      NaN
# 4240                   16h30
# 1911                   18h00
# 5768                     NaN
# 1418                   14h20
# 1922                   12h30
# 4467                     NaN
# 751                    15h30
# 2187  2 hours after Opperman
# 4682                     NaN
# 3499                     NaN
# 2955                     NaN
# 2458                   07h30
# 3795                   10h20
# 3393                   14h00
# 4110                     NaN
# 4251                  15h00j
# 4103                     NaN
# 2344                     NaN
#
#                                  Investigator or Source original order  \
# 1825                           J. Eager, scubaradio.com         4479.0
# 423                                    WFTV,  5/27/2015         5881.0
# 4240  D. Miller & R. Collier, V.M. Coppleson (1958),...         2065.0
# 1911                        M. Levine, GSAF                     4393.0
# 5768                          New York Times, 8/27/1885          537.0
# 1418                 Manila Bulletin Online, 11/27/2006         4886.0
# 1922  S. Petersohn, GSAF; Orlando Sentinel, 8/20/200...         4382.0
# 4467                             The Mercury, 7/27/1950         1838.0
# 751                                      T. Peake, GSAF         5553.0
# 2187                                   A. Gifford, GSAF         4117.0
# 4682                                     Greatships.net         1623.0
# 3499               H.D. Baldridge (1994) SAF Case #1516         2806.0
# 2955                           G. Cliff & B. Davis, NSB         3350.0
# 2458                        Advertiser, 1/12/1994, p.18         3847.0
# 3795  A. De Maddalena & C. Moore, GSAF; Carletti (19...         2510.0
# 3393                                      E. Pace, FSAF         2912.0
# 4110  T. Ingledew, Medical Assistant; A. M Rapson, p...         2195.0
# 4251  News & Courier, 7/14/1956; V.M. Coppleson (195...         2054.0
# 4103                                                NaN         2202.0
# 2344                             LeQuotidien, 12/4/1999         3961.0
#
#       Case Number.1  Case Number.2                               pdf  \
# 1825   2002.09.27.b   2002.09.27.b             2002.09.27.b-Diaz.pdf
# 423      2015.05.24     2015.05.24            2015.05.24-Wheatro.pdf
# 4240   1956.08.15.a   1956.08.15.a    1956.08.15.a-DouglasClarke.pdf
# 1911     2001.09.01     2001.09.01            2001.09.01-Peltier.pdf
# 5768     1885.08.17     1885.08.17             1885.08.17-Loesch.pdf
# 1418     2006.11.25     2006.11.25            2006.11.25-Leonida.pdf
# 1922   2001.08.18.c   2001.08.18.c            2001.08.18.c-White.pdf
# 4467   1950.07.27.R   1950.07.27.R     1950.07.27.R-Horsell-boat.pdf
# 751      2012.08.28     2012.08.28              2012.08.28-Hines.pdf
# 2187   1998.05.29.b   1998.05.29.b           1998.05.29.b-Jucker.pdf
# 4682     1943.03.14     1943.03.14  1943.03.14-Empress-of-Canada.pdf
# 3499   1967.11.30.b   1967.11.30.b    1967.11.30.b- NV-JeffShort.pdf
# 2955     1983.01.15     1983.01.15        1983.01.15-Amanzimtoti.pdf
# 2458   1994.01.12.R   1994.01.12.R         1994.01.12.R-Turnbull.pdf
# 3795     1962.09.02     1962.09.02              1962.09.02-Sarra.pdf
# 3393   1970.06.13.b   1970.06.13.b      1970.06.13.b-LincolnJohn.pdf
# 4110     1959.02.06     1959.02.06           1959.02.06-Ururumba.pdf
# 4251     1956.07.12     1956.07.12              1956.07.12-Rawls.pdf
# 4103  1959.04.09..a  1959.04.09..a        1959.04.09.a-Fisherman.pdf
# 2344     1995.09.16     1995.09.16           1995.09.16-Pruneaux.pdf
#
#                                            href formula  \
# 1825  http://sharkattackfile.net/spreadsheets/pdf_di...
# 423   http://sharkattackfile.net/spreadsheets/pdf_di...
# 4240  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1911  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5768  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1418  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1922  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4467  http://sharkattackfile.net/spreadsheets/pdf_di...
# 751   http://sharkattackfile.net/spreadsheets/pdf_di...
# 2187  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4682  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3499  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2955  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2458  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3795  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3393  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4110  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4251  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4103  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2344  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Unnamed: 22  \
# 1825  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 423   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4240  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1911  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5768  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1418  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1922  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4467  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 751   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2187  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4682  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3499  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2955  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2458  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3795  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3393  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4110  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4251  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4103  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2344  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
#
#      Unnamed: 23
# 1825         NaN
# 423          NaN
# 4240         NaN
# 1911         NaN
# 5768         NaN
# 1418         NaN
# 1922         NaN
# 4467         NaN
# 751          NaN
# 2187         NaN
# 4682         NaN
# 3499         NaN
# 2955         NaN
# 2458         NaN
# 3795         NaN
# 3393         NaN
# 4110         NaN
# 4251         NaN
# 4103         NaN
# 2344         NaN
#
# [20 rows x 23 columns]

# %%
shark_clean['Date'] = pd.to_datetime(shark_clean['Date'], errors='coerce', infer_datetime_format=True)
shark_clean.dtypes
# Out:
# Case Number                       object
# Date                      datetime64[ns]
# Year                             float64
# Type                              object
# Country                           object
# Area                              object
# Location                          object
# Activity                          object
# Name                              object
# Sex                               object
# Age                               object
# Fatal (Y/N)                       object
# Species                           object
# Time                              object
# Investigator or Source            object
# original order                   float64
# Case Number.1                     object
# Case Number.2                     object
# pdf                               object
# href formula                      object
# href                              object
# Unnamed: 22                       object
# Unnamed: 23                       object
# dtype: object

# %%
shark_clean.head()
# Out:
#   Case Number       Date    Year        Type    Country             Area  \
# 0  2018.06.25 2018-06-25  2018.0     Boating        USA       California
# 1  2018.06.18 2018-06-18  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09 2018-06-09  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08 2018-06-08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04 2018-06-04  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
#             Time          Investigator or Source original order Case Number.1  \
# 0          18h00                R. Collier, GSAF         6303.0    2018.06.25
# 1  14h00  -15h00  K.McMurray, TrackingSharks.com         6302.0    2018.06.18
# 2          07h45  K.McMurray, TrackingSharks.com         6301.0    2018.06.09
# 3            NaN                  B. Myatt, GSAF         6300.0    2018.06.08
# 4            NaN                       A .Kipper         6299.0    2018.06.04
#
#   Case Number.2                       pdf  \
# 0    2018.06.25      2018.06.25-Wolfe.pdf
# 1    2018.06.18    2018.06.18-McNeely.pdf
# 2    2018.06.09     2018.06.09-Denges.pdf
# 3    2018.06.08  2018.06.08-Arrawarra.pdf
# 4    2018.06.04      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Unnamed: 22 Unnamed: 23
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# # limpieza de year

# %%
'''
convierte los valores de años a str
'''
shark_clean['Year']=shark_clean['Year'].fillna(shark_clean['Year'].mean())
shark_clean.head(10)
# Out:
#   Case Number       Date         Year                     Type    Country  \
# 0  2018.06.25 2018-06-25  2018.000000                  Boating        USA
# 1  2018.06.18 2018-06-18  2018.000000               Unprovoked        USA
# 2  2018.06.09 2018-06-09  2018.000000                  Invalid        USA
# 3  2018.06.08 2018-06-08  2018.000000               Unprovoked  AUSTRALIA
# 4  2018.06.04 2018-06-04  2018.000000                 Provoked     MEXICO
# 5  2018.06.03 2018-06-03  2018.000000               Unprovoked  AUSTRALIA
# 6  2010.01.01        NaT  1926.970957  No injury, board bitten          N
# 7  2018.06.03 2018-06-03  2018.000000               Unprovoked     BRAZIL
# 8  2018.05.27 2018-05-27  2018.000000               Unprovoked        USA
# 9  2018.05.26 2018-05-26  2018.000000               Unprovoked        USA
#
#               Area                                           Location  \
# 0       California                        Oceanside, San Diego County
# 1          Georgia                     St. Simon Island, Glynn County
# 2           Hawaii                                       Habush, Oahu
# 3  New South Wales                                 Arrawarra Headland
# 4           Colima                                           La Ticla
# 5  New South Wales                                 Flat Rock, Ballina
# 6              NaN                                                NaN
# 7       Pernambuco                              Piedade Beach, Recife
# 8          Florida  Lighhouse Point Park, Ponce Inlet, Volusia County
# 9          Florida                       Cocoa Beach, Brevard  County
#
#                     Activity                       Name  \
# 0                   Paddling                Julie Wolfe
# 1                   Standing            Adyson McNeely
# 2                    Surfing                John Denges
# 3                    Surfing                       male
# 4                Free diving             Gustavo Ramos
# 5               Kite surfing                     Chris
# 6  Daily Telegraph, 6/4/2018  2018.06.03.b-FlatRock.pdf
# 7                   Swimming     Jose Ernesto da Silva
# 8                    Fishing                       male
# 9                    Walking                  Cody High
#
#                                                 Sex   ...            Time  \
# 0                                                  F  ...           18h00
# 1                                                  F  ...   14h00  -15h00
# 2                                                  M  ...           07h45
# 3                                                  M  ...             NaN
# 4                                                  M  ...             NaN
# 5                                                NaN  ...             NaN
# 6  http://sharkattackfile.net/spreadsheets/pdf_di...  ...            6298
# 7                                                  M  ...  Late afternoon
# 8                                                  M  ...             NaN
# 9                                                  M  ...           17h00
#
#             Investigator or Source original order Case Number.1 Case Number.2  \
# 0                 R. Collier, GSAF         6303.0    2018.06.25    2018.06.25
# 1   K.McMurray, TrackingSharks.com         6302.0    2018.06.18    2018.06.18
# 2   K.McMurray, TrackingSharks.com         6301.0    2018.06.09    2018.06.09
# 3                   B. Myatt, GSAF         6300.0    2018.06.08    2018.06.08
# 4                        A .Kipper         6299.0    2018.06.04    2018.06.04
# 5                              NaN            NaN           NaN           NaN
# 6                              NaN            NaN           NaN           NaN
# 7   Diario de Pernambuco, 6/4/2018         6297.0  2018.06.03.a  2018.06.03.a
# 8  K. McMurray, TrackingSharks.com         6296.0    2018.05.27    2018.05.27
# 9   K.McMurray, TrackingSharks.com         6295.0  2018.05.26.b  2018.05.26.b
#
#                         pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
# 5                       NaN
# 6                       NaN
# 7  2018.06.03.a-daSilva.pdf
# 8      2018.05.27-Ponce.pdf
# 9     2018.05.26.b-High.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5                                                NaN
# 6                                                NaN
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Unnamed: 22 Unnamed: 23
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 5                                                NaN         NaN         NaN
# 6                                                NaN         NaN         NaN
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
#
# [10 rows x 23 columns]

# %%
shark_clean['Year']= shark_clean['Year'].astype({'Year':'str'})
shark_clean.head(10)
# Out:
#   Case Number       Date                Year                     Type  \
# 0  2018.06.25 2018-06-25              2018.0                  Boating
# 1  2018.06.18 2018-06-18              2018.0               Unprovoked
# 2  2018.06.09 2018-06-09              2018.0                  Invalid
# 3  2018.06.08 2018-06-08              2018.0               Unprovoked
# 4  2018.06.04 2018-06-04              2018.0                 Provoked
# 5  2018.06.03 2018-06-03              2018.0               Unprovoked
# 6  2010.01.01        NaT  1926.9709569909537  No injury, board bitten
# 7  2018.06.03 2018-06-03              2018.0               Unprovoked
# 8  2018.05.27 2018-05-27              2018.0               Unprovoked
# 9  2018.05.26 2018-05-26              2018.0               Unprovoked
#
#      Country             Area  \
# 0        USA       California
# 1        USA          Georgia
# 2        USA           Hawaii
# 3  AUSTRALIA  New South Wales
# 4     MEXICO           Colima
# 5  AUSTRALIA  New South Wales
# 6          N              NaN
# 7     BRAZIL       Pernambuco
# 8        USA          Florida
# 9        USA          Florida
#
#                                             Location  \
# 0                        Oceanside, San Diego County
# 1                     St. Simon Island, Glynn County
# 2                                       Habush, Oahu
# 3                                 Arrawarra Headland
# 4                                           La Ticla
# 5                                 Flat Rock, Ballina
# 6                                                NaN
# 7                              Piedade Beach, Recife
# 8  Lighhouse Point Park, Ponce Inlet, Volusia County
# 9                       Cocoa Beach, Brevard  County
#
#                     Activity                       Name  \
# 0                   Paddling                Julie Wolfe
# 1                   Standing            Adyson McNeely
# 2                    Surfing                John Denges
# 3                    Surfing                       male
# 4                Free diving             Gustavo Ramos
# 5               Kite surfing                     Chris
# 6  Daily Telegraph, 6/4/2018  2018.06.03.b-FlatRock.pdf
# 7                   Swimming     Jose Ernesto da Silva
# 8                    Fishing                       male
# 9                    Walking                  Cody High
#
#                                                 Sex   ...            Time  \
# 0                                                  F  ...           18h00
# 1                                                  F  ...   14h00  -15h00
# 2                                                  M  ...           07h45
# 3                                                  M  ...             NaN
# 4                                                  M  ...             NaN
# 5                                                NaN  ...             NaN
# 6  http://sharkattackfile.net/spreadsheets/pdf_di...  ...            6298
# 7                                                  M  ...  Late afternoon
# 8                                                  M  ...             NaN
# 9                                                  M  ...           17h00
#
#             Investigator or Source original order Case Number.1 Case Number.2  \
# 0                 R. Collier, GSAF         6303.0    2018.06.25    2018.06.25
# 1   K.McMurray, TrackingSharks.com         6302.0    2018.06.18    2018.06.18
# 2   K.McMurray, TrackingSharks.com         6301.0    2018.06.09    2018.06.09
# 3                   B. Myatt, GSAF         6300.0    2018.06.08    2018.06.08
# 4                        A .Kipper         6299.0    2018.06.04    2018.06.04
# 5                              NaN            NaN           NaN           NaN
# 6                              NaN            NaN           NaN           NaN
# 7   Diario de Pernambuco, 6/4/2018         6297.0  2018.06.03.a  2018.06.03.a
# 8  K. McMurray, TrackingSharks.com         6296.0    2018.05.27    2018.05.27
# 9   K.McMurray, TrackingSharks.com         6295.0  2018.05.26.b  2018.05.26.b
#
#                         pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
# 5                       NaN
# 6                       NaN
# 7  2018.06.03.a-daSilva.pdf
# 8      2018.05.27-Ponce.pdf
# 9     2018.05.26.b-High.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5                                                NaN
# 6                                                NaN
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Unnamed: 22 Unnamed: 23
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 5                                                NaN         NaN         NaN
# 6                                                NaN         NaN         NaN
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
#
# [10 rows x 23 columns]

# %%
shark_clean['Year'] = shark_clean['Year'].str.replace('\.[0-9]+','',regex=True)
shark_clean.head(10)
# Out:
#   Case Number       Date  Year                     Type    Country  \
# 0  2018.06.25 2018-06-25  2018                  Boating        USA
# 1  2018.06.18 2018-06-18  2018               Unprovoked        USA
# 2  2018.06.09 2018-06-09  2018                  Invalid        USA
# 3  2018.06.08 2018-06-08  2018               Unprovoked  AUSTRALIA
# 4  2018.06.04 2018-06-04  2018                 Provoked     MEXICO
# 5  2018.06.03 2018-06-03  2018               Unprovoked  AUSTRALIA
# 6  2010.01.01        NaT  1926  No injury, board bitten          N
# 7  2018.06.03 2018-06-03  2018               Unprovoked     BRAZIL
# 8  2018.05.27 2018-05-27  2018               Unprovoked        USA
# 9  2018.05.26 2018-05-26  2018               Unprovoked        USA
#
#               Area                                           Location  \
# 0       California                        Oceanside, San Diego County
# 1          Georgia                     St. Simon Island, Glynn County
# 2           Hawaii                                       Habush, Oahu
# 3  New South Wales                                 Arrawarra Headland
# 4           Colima                                           La Ticla
# 5  New South Wales                                 Flat Rock, Ballina
# 6              NaN                                                NaN
# 7       Pernambuco                              Piedade Beach, Recife
# 8          Florida  Lighhouse Point Park, Ponce Inlet, Volusia County
# 9          Florida                       Cocoa Beach, Brevard  County
#
#                     Activity                       Name  \
# 0                   Paddling                Julie Wolfe
# 1                   Standing            Adyson McNeely
# 2                    Surfing                John Denges
# 3                    Surfing                       male
# 4                Free diving             Gustavo Ramos
# 5               Kite surfing                     Chris
# 6  Daily Telegraph, 6/4/2018  2018.06.03.b-FlatRock.pdf
# 7                   Swimming     Jose Ernesto da Silva
# 8                    Fishing                       male
# 9                    Walking                  Cody High
#
#                                                 Sex   ...            Time  \
# 0                                                  F  ...           18h00
# 1                                                  F  ...   14h00  -15h00
# 2                                                  M  ...           07h45
# 3                                                  M  ...             NaN
# 4                                                  M  ...             NaN
# 5                                                NaN  ...             NaN
# 6  http://sharkattackfile.net/spreadsheets/pdf_di...  ...            6298
# 7                                                  M  ...  Late afternoon
# 8                                                  M  ...             NaN
# 9                                                  M  ...           17h00
#
#             Investigator or Source original order Case Number.1 Case Number.2  \
# 0                 R. Collier, GSAF         6303.0    2018.06.25    2018.06.25
# 1   K.McMurray, TrackingSharks.com         6302.0    2018.06.18    2018.06.18
# 2   K.McMurray, TrackingSharks.com         6301.0    2018.06.09    2018.06.09
# 3                   B. Myatt, GSAF         6300.0    2018.06.08    2018.06.08
# 4                        A .Kipper         6299.0    2018.06.04    2018.06.04
# 5                              NaN            NaN           NaN           NaN
# 6                              NaN            NaN           NaN           NaN
# 7   Diario de Pernambuco, 6/4/2018         6297.0  2018.06.03.a  2018.06.03.a
# 8  K. McMurray, TrackingSharks.com         6296.0    2018.05.27    2018.05.27
# 9   K.McMurray, TrackingSharks.com         6295.0  2018.05.26.b  2018.05.26.b
#
#                         pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
# 5                       NaN
# 6                       NaN
# 7  2018.06.03.a-daSilva.pdf
# 8      2018.05.27-Ponce.pdf
# 9     2018.05.26.b-High.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5                                                NaN
# 6                                                NaN
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Unnamed: 22 Unnamed: 23
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 5                                                NaN         NaN         NaN
# 6                                                NaN         NaN         NaN
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
#
# [10 rows x 23 columns]

# %%
shark_clean['Year'] = shark_clean['Year'].apply(pd.to_numeric)
shark_clean.sample(10)
# Out:
#      Case Number       Date  Year        Type           Country  \
# 280   2016.05.03 2016-05-03  2016  Unprovoked               USA
# 4689  1943.00.00        NaT  1943  Unprovoked               USA
# 5562  1900.07.00        NaT  1900    Provoked               USA
# 907   2011.06.24 2011-06-24  2011  Unprovoked               USA
# 5000  1932.01.11 1932-01-11  1932     Boating         AUSTRALIA
# 95    2017.09.02 2017-09-02  2017  Unprovoked               USA
# 1053  2010.01.09 2010-01-09  2010  Unprovoked         AUSTRALIA
# 4403  1952.10.12 1952-10-12  1952  Unprovoked  PAPUA NEW GUINEA
# 6196     ND-0133        NaT     0  Unprovoked               USA
# 4303  1955.03.00        NaT  1955    Provoked         AUSTRALIA
#
#                                      Area  \
# 280                                Hawaii
# 4689                               Hawaii
# 5562                          Connecticut
# 907                            California
# 5000                             Victoria
# 95                                  Texas
# 1053                        Torres Strait
# 4403  Abau Sub District, Central Province
# 6196                           California
# 4303                    Western Australia
#
#                                           Location  \
# 280                             Wailea Beach, Maui
# 4689  Midway Island, Northwestern Hawaiian Islands
# 5562                  Bridgeport, Fairfield County
# 907       San Onofre State Beach, San Diego County
# 5000                                     Frankston
# 95              South Padre Island, Cameron County
# 1053                               Thursday Island
# 4403                               Lalaura Village
# 6196                      Monterey, Montery County
# 4303                               Woodmans Point
#
#                                                Activity  \
# 280                                            Floating
# 4689                                       Spearfishing
# 5562
# 907                                             Surfing
# 5000                                            Fishing
# 95                                             Swimming
# 1053                                         Snorkeling
# 4403                                            Fishing
# 6196                         Fishing for basking sharks
# 4303  Competing in U/W endurance record, standing be...
#
#                                                    Name Sex   ...   Time  \
# 280                                                male    M  ...  15h49
# 4689                                            2 males    M  ...    NaN
# 5562  skiff with Dr. William T. Healey, Dr. Henry Ca...  NaN  ...    NaN
# 907                                          Doug Green    M  ...  13h30
# 5000                                               boat  NaN  ...    NaN
# 95                                               female    F  ...    NaN
# 1053                                  Reenie Morrissey     F  ...    NaN
# 4403                                               male    M  ...    NaN
# 6196                                              males    M  ...    NaN
# 4303                                   Theo Watts Brown    M  ...  11h55
#
#                                  Investigator or Source original order  \
# 280                                  Maui Now, 5/3/2016         6024.0
# 4689                                      W. M. Chapman         1616.0
# 5562                                    Times, 8/1/1900          743.0
# 907                                          R. Collier         5397.0
# 5000  G.P. Whitley citing Herald (Melbourne) 1/12/1932          1305.0
# 95                         Brownsville Herald, 9/5/2017         6209.0
# 1053                            Courier-Mail, 1/10/2009         5251.0
# 4403                    A. Bleakley; A.M. Rapson, p.148         1902.0
# 6196                                        C.F. Holder          109.0
# 4303                              H.D. Baldridge, p.104         2002.0
#
#      Case Number.1 Case Number.2                           pdf  \
# 280     2016.05.03    2016.05.03           2016.05.03-Maui.pdf
# 4689  1943.00.00.c  1943.00.00.c     1943.00.00.c - Midway.pdf
# 5562    1900.07.00    1900.07.00     1900.07.00-Bridgeport.pdf
# 907     2011.06.24    2011.06.24          2011.06.24-Green.pdf
# 5000    1932.01.11    1932.01.11  1932.01.11-boatFrankston.pdf
# 95    2017.09.02.b  2017.09.02.b   2017.09.02.b-SouthPadre.pdf
# 1053  2010.01.09.d  2010.01.09.d    2010.01.09.d-Morrissey.pdf
# 4403    1952.10.12    1952.10.12        1952.10.12-Lalaura.pdf
# 6196       ND-0133       ND-0133      ND-0133-BaskingShark.pdf
# 4303  1955.03.00.a  1955.03.00.a        1955.03.00.a-Brown.pdf
#
#                                            href formula  \
# 280   http://sharkattackfile.net/spreadsheets/pdf_di...
# 4689  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5562  http://sharkattackfile.net/spreadsheets/pdf_di...
# 907   http://sharkattackfile.net/spreadsheets/pdf_di...
# 5000  http://sharkattackfile.net/spreadsheets/pdf_di...
# 95    http://sharkattackfile.net/spreadsheets/pdf_di...
# 1053  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4403  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6196  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4303  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Unnamed: 22  \
# 280   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4689  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5562  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 907   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5000  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 95    http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1053  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4403  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6196  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4303  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
#
#      Unnamed: 23
# 280          NaN
# 4689         NaN
# 5562         NaN
# 907          NaN
# 5000         NaN
# 95           NaN
# 1053         NaN
# 4403         NaN
# 6196         NaN
# 4303         NaN
#
# [10 rows x 23 columns]

# %%
shark_clean['Year'] = shark_clean['Year'].astype({'Year':'int'})
shark_clean.dtypes
# Out:
# Case Number                       object
# Date                      datetime64[ns]
# Year                               int64
# Type                              object
# Country                           object
# Area                              object
# Location                          object
# Activity                          object
# Name                              object
# Sex                               object
# Age                               object
# Fatal (Y/N)                       object
# Species                           object
# Time                              object
# Investigator or Source            object
# original order                   float64
# Case Number.1                     object
# Case Number.2                     object
# pdf                               object
# href formula                      object
# href                              object
# Unnamed: 22                       object
# Unnamed: 23                       object
# dtype: object

# %%
aux_fun = lambda x : int(x)
shark_clean['Year'] = shark_clean['Year'].map(aux_fun)
shark_clean.head(10)
# Out:
#   Case Number       Date  Year                     Type    Country  \
# 0  2018.06.25 2018-06-25  2018                  Boating        USA
# 1  2018.06.18 2018-06-18  2018               Unprovoked        USA
# 2  2018.06.09 2018-06-09  2018                  Invalid        USA
# 3  2018.06.08 2018-06-08  2018               Unprovoked  AUSTRALIA
# 4  2018.06.04 2018-06-04  2018                 Provoked     MEXICO
# 5  2018.06.03 2018-06-03  2018               Unprovoked  AUSTRALIA
# 6  2010.01.01        NaT  1926  No injury, board bitten          N
# 7  2018.06.03 2018-06-03  2018               Unprovoked     BRAZIL
# 8  2018.05.27 2018-05-27  2018               Unprovoked        USA
# 9  2018.05.26 2018-05-26  2018               Unprovoked        USA
#
#               Area                                           Location  \
# 0       California                        Oceanside, San Diego County
# 1          Georgia                     St. Simon Island, Glynn County
# 2           Hawaii                                       Habush, Oahu
# 3  New South Wales                                 Arrawarra Headland
# 4           Colima                                           La Ticla
# 5  New South Wales                                 Flat Rock, Ballina
# 6              NaN                                                NaN
# 7       Pernambuco                              Piedade Beach, Recife
# 8          Florida  Lighhouse Point Park, Ponce Inlet, Volusia County
# 9          Florida                       Cocoa Beach, Brevard  County
#
#                     Activity                       Name  \
# 0                   Paddling                Julie Wolfe
# 1                   Standing            Adyson McNeely
# 2                    Surfing                John Denges
# 3                    Surfing                       male
# 4                Free diving             Gustavo Ramos
# 5               Kite surfing                     Chris
# 6  Daily Telegraph, 6/4/2018  2018.06.03.b-FlatRock.pdf
# 7                   Swimming     Jose Ernesto da Silva
# 8                    Fishing                       male
# 9                    Walking                  Cody High
#
#                                                 Sex   ...            Time  \
# 0                                                  F  ...           18h00
# 1                                                  F  ...   14h00  -15h00
# 2                                                  M  ...           07h45
# 3                                                  M  ...             NaN
# 4                                                  M  ...             NaN
# 5                                                NaN  ...             NaN
# 6  http://sharkattackfile.net/spreadsheets/pdf_di...  ...            6298
# 7                                                  M  ...  Late afternoon
# 8                                                  M  ...             NaN
# 9                                                  M  ...           17h00
#
#             Investigator or Source original order Case Number.1 Case Number.2  \
# 0                 R. Collier, GSAF         6303.0    2018.06.25    2018.06.25
# 1   K.McMurray, TrackingSharks.com         6302.0    2018.06.18    2018.06.18
# 2   K.McMurray, TrackingSharks.com         6301.0    2018.06.09    2018.06.09
# 3                   B. Myatt, GSAF         6300.0    2018.06.08    2018.06.08
# 4                        A .Kipper         6299.0    2018.06.04    2018.06.04
# 5                              NaN            NaN           NaN           NaN
# 6                              NaN            NaN           NaN           NaN
# 7   Diario de Pernambuco, 6/4/2018         6297.0  2018.06.03.a  2018.06.03.a
# 8  K. McMurray, TrackingSharks.com         6296.0    2018.05.27    2018.05.27
# 9   K.McMurray, TrackingSharks.com         6295.0  2018.05.26.b  2018.05.26.b
#
#                         pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
# 5                       NaN
# 6                       NaN
# 7  2018.06.03.a-daSilva.pdf
# 8      2018.05.27-Ponce.pdf
# 9     2018.05.26.b-High.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5                                                NaN
# 6                                                NaN
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Unnamed: 22 Unnamed: 23
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 5                                                NaN         NaN         NaN
# 6                                                NaN         NaN         NaN
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
#
# [10 rows x 23 columns]

# %%
shark_clean.dtypes
# Out:
# Case Number                       object
# Date                      datetime64[ns]
# Year                               int64
# Type                              object
# Country                           object
# Area                              object
# Location                          object
# Activity                          object
# Name                              object
# Sex                               object
# Age                               object
# Fatal (Y/N)                       object
# Species                           object
# Time                              object
# Investigator or Source            object
# original order                   float64
# Case Number.1                     object
# Case Number.2                     object
# pdf                               object
# href formula                      object
# href                              object
# Unnamed: 22                       object
# Unnamed: 23                       object
# dtype: object

# %% [markdown]
# # limpieza de type

# %%
shark_clean['Type']= shark_clean['Type'].str.replace('Invalid|0','Unknown',regex=True).fillna('Unknown')
shark_clean.sample(60)
# Out:
#      Case Number       Date  Year          Type       Country  \
# 3360  1971.08.21 1971-08-21  1971      Provoked     AUSTRALIA
# 6089  1831.08.24 1831-08-24  1831          Boat           USA
# 3723  1963.12.21 1963-12-21  1963      Provoked     AUSTRALIA
# 6121  1811.03.01 1811-03-01  1811    Unprovoked           NaN
# 669   2013.06.14        NaT  2013    Unprovoked           USA
# 4367  1953.09.18 1953-09-18  1953  Sea Disaster           USA
# 1421  2006.10.31 2006-10-31  2006    Unprovoked           USA
# 4522  1949.01.13 1949-01-13  1949    Unprovoked     AUSTRALIA
# 3010  1981.10.01 1981-10-01  1981    Unprovoked           USA
# 2816  1986.08.00        NaT  1986    Unprovoked        FRANCE
# 4857  1937.02.11 1937-02-11  1937    Unprovoked     AUSTRALIA
# 6215     ND-0106        NaT     0    Unprovoked  SOUTH AFRICA
# 6000  1856.02.06 1856-02-06  1856    Unprovoked     AUSTRALIA
# 2249  1997.06.24 1997-06-24  1997    Unprovoked           USA
# 4002  1960.04.10 1960-04-10  1960      Provoked     AUSTRALIA
# 2707  1988.11.07 1988-11-07  1988  Sea Disaster     AUSTRALIA
# 3827  1962.04.20 1962-04-20  1962      Provoked     AUSTRALIA
# 1654  2004.07.27 2004-07-27  2004    Unprovoked           USA
# 207   2016.10.13 2016-10-13  2016       Unknown        MEXICO
# 1437  2006.09.02 2006-09-02  2006    Unprovoked           USA
# 3372  1971.01.02 1971-01-02  1971    Unprovoked     AUSTRALIA
# 3326  1972.09.09 1972-09-09  1972    Unprovoked           USA
# 1635  2004.10.06 2004-10-06  2004    Unprovoked       REUNION
# 2149  1998.12.18 1998-12-18  1998    Unprovoked  SOUTH AFRICA
# 1637  2004.10.01 2004-10-01  2004    Unprovoked           USA
# 1411  2007.01.07 2007-01-07  2007       Unknown           USA
# 6169  1617.00.00        NaT  1617    Unprovoked         INDIA
# 2198  1998.03.31 1998-03-31  1998    Unprovoked           USA
# 1300  2008.00.00        NaT  2008    Unprovoked        MEXICO
# 5992  1858.04.04 1858-04-04  1858    Unprovoked        TOBAGO
# 1838  2002.08.07 2002-08-07  2002    Unprovoked           USA
# 727   2012.10.30 2012-10-30  2012    Unprovoked           USA
# 3186  1976.06.01 1976-06-01  1976          Boat     AUSTRALIA
# 4578  1947.06.16 1947-06-16  1947       Boating     AUSTRALIA
# 4517  1949.04.17 1949-04-17  1949    Unprovoked     AUSTRALIA
# 3694  1964.02.17        NaT  1964      Provoked          FIJI
# 1100  2009.08.10 2009-08-10  2009    Unprovoked           USA
# 5061  1929.12.13 1929-12-13  1929    Unprovoked     AUSTRALIA
# 2638  1990.05.06 1990-05-06  1990    Unprovoked  SOUTH AFRICA
# 5428  1909.01.00        NaT  1909       Unknown         ITALY
# 2765  1987.10.26 1987-10-26  1987    Unprovoked           USA
# 3405  1970.01.23 1970-01-23  1970    Unprovoked    MOZAMBIQUE
# 963   2010.12.01 2010-12-01  2010    Unprovoked         EGYPT
# 5409  1910.01.26 1910-01-26  1910    Unprovoked     AUSTRALIA
# 4295  1955.07.07 1955-07-07  1955    Unprovoked         YEMEN
# 4883  1936.04.08        NaT  1936    Unprovoked     AUSTRALIA
# 546   2014.06.09 2014-06-09  2014    Unprovoked     AUSTRALIA
# 2509  1993.02.18 1993-02-18  1993  Sea Disaster         TONGA
# 402   2015.06.27 2015-06-27  2015    Unprovoked  SOUTH AFRICA
# 509   2014.08.28 2014-08-28  2014      Provoked           USA
# 5664  1893.10.20        NaT  1893    Unprovoked         INDIA
# 3592  1966.01.15 1966-01-15  1966    Unprovoked     AUSTRALIA
# 1163  2009.01.26        NaT  2009       Unknown        BRAZIL
# 79    2017.09.25 2017-09-25  2017    Unprovoked     AUSTRALIA
# 2030  2000.07.22 2000-07-22  2000    Unprovoked           USA
# 1194  2008.11.06 2008-11-06  2008    Unprovoked   PHILIPPINES
# 3077  1980.01.15 1980-01-15  1980      Provoked  SOUTH AFRICA
# 2165  1998.09.16        NaT  1998    Unprovoked  SOUTH AFRICA
# 5131  1927.04.08 1927-04-08  1927    Unprovoked     AUSTRALIA
# 3871  1961.12.13 1961-12-13  1961    Unprovoked     AUSTRALIA
#
#                         Area  \
# 3360         New South Wales
# 6089                    CUBA
# 3723         New South Wales
# 6121                     NaN
# 669           South Carolina
# 4367                 Georgia
# 1421                  Oregon
# 4522         New South Wales
# 3010                 Florida
# 2816           Gulf of Lyons
# 4857         New South Wales
# 6215   Western Cape Province
# 6000                Victoria
# 2249                  Hawaii
# 4002       Western Australia
# 2707              Queensland
# 3827              Queensland
# 1654                   Texas
# 207                      NaN
# 1437                 Florida
# 3372                Tasmania
# 3326              California
# 1635  Conservatória District
# 2149   Eastern Cape Province
# 1637              California
# 1411                New York
# 6169             West Bengal
# 2198                 Florida
# 1300         Baja California
# 5992                     NaN
# 1838                 Florida
# 727               California
# 3186              Queensland
# 4578         New South Wales
# 4517              Queensland
# 3694                     NaN
# 1100                 Florida
# 5061           Torres Strait
# 2638   Eastern Cape Province
# 5428                  Sicily
# 2765              California
# 3405           Limpopo River
# 963    South Sinai Peninsula
# 5409         New South Wales
# 4295                    Aden
# 4883              Queensland
# 546          South Australia
# 2509         Tongapatu Group
# 402    Western Cape Province
# 509                 Maryland
# 5664           Bay of Bengal
# 3592         New South Wales
# 1163                     NaN
# 79         Western Australia
# 2030                 Florida
# 1194                   Luzon
# 3077           KwaZulu-Natal
# 2165   Eastern Cape Province
# 5131              Queensland
# 3871           Torres Strait
#
#                                                Location  \
# 3360                           Manly Marineland, Sydney
# 6089                                        Near Havana
# 3723                          Woolgoolga, Coffs Harbour
# 6121                                                NaN
# 669                          Myrtle Beach, Horry County
# 4367                         200 miles east of Savannah
# 1421                 Siletz River mouth, Lincoln County
# 4522                             Mona Vale, near Sydney
# 3010                   Playalinda Beach, Brevard County
# 2816                                           Gruissan
# 4857                                            Kempsey
# 6215                          Murray Bay, Robben Island
# 6000                                        Point Henry
# 2249                                 Sunset Beach, Oahu
# 4002                                Off Rottnest Island
# 2707               Off North Keppel Island, off Yeppoon
# 3827                                       Nobbys Beach
# 1654                                   Galveston Island
# 207                                    Guadalupe Island
# 1437                   New Smyrna Beach, Volusia County
# 3372                                                NaN
# 3326                         Point Sur, Monterey County
# 1635                         P' tit Paris, Saint-Pierre
# 2149                                    Kei River Mouth
# 1637  Lifeguard Tower 16, Huntington Beach, Orange C...
# 1411                           Smith Point, Long Island
# 6169                                       Ganges Delta
# 2198                   Jensen Beach Park, Martin County
# 1300                                  Playas de Tijuana
# 5992                                          Rocky Bay
# 1838                Ponce De Leon Inlet, Volusia County
# 727               Humboldt Bay, Eureka, Humboldt County
# 3186                              Off Stradbroke Island
# 4578                                             Coogee
# 4517                  Ellis Beach, 20 miles from Cairns
# 3694                                        Savuli Reef
# 1100                              Ponce, Volusia County
# 5061                                    Thursday Island
# 2638                                        Cintsa East
# 5428         Off Capo San Croce, near Augusta (Catania)
# 2765                  Davenport Light, San Mateo County
# 3405                              Gijana, 150 km inland
# 963                        Ras Nasrani, Sharm el-Sheikh
# 5409                                   Newcastle Harbor
# 4295                                      Telegraph Bay
# 4883                         Arlington Reef near Cairns
# 546                  Parsons Beach,  Fleurieu Peninsula
# 2509                         Between 'Ata and Tongapatu
# 402                             Buffels Bay near Knysna
# 509                        Assateague National Seashore
# 5664                                      Madras Harbor
# 3592                                           Bellambi
# 1163                               Praia do Olho d'Aqua
# 79                                            Gracetown
# 2030                       Big Pine Key, Monroe County
# 1194                   off Paoay, Ilocos Norte Province
# 3077                                           Ansteys
# 2165                                        Kowie River
# 5131                               Near Thursday Island
# 3871                  Horn Island, near Thursday Island
#
#                                                Activity  \
# 3360                        Scuba diving & feeding fish
# 6089                American schooner Orator capsized
# 3723                                            Fishing
# 6121                                     Fell overboard
# 669                                     Boogie Boarding
# 4367                                   Aircaft exploded
# 1421                                            Surfing
# 4522                                        Surf skiing
# 3010                                            Surfing
# 2816                                                NaN
# 4857              Swimming ashore after launch capsized
# 6215                                           Swimming
# 6000                                           Swimming
# 2249                        Spearfishing / night diving
# 4002  Spearfishing, shot a sandtiger shark. Cord to ...
# 2707  The Christie V sank on 11/6/1988, survivors we...
# 3827                                            Fishing
# 1654                                           Swimming
# 207                                         Cage Diving
# 1437                                           Swimming
# 3372                                           Swimming
# 3326                                            Surfing
# 1635                                      Body boarding
# 2149                                          Splashing
# 1637                                            Surfing
# 1411                                            Surfing
# 6169                                                NaN
# 2198                                           Swimming
# 1300                                            Surfing
# 5992                                            Bathing
# 1838                                           Standing
# 727                                             Surfing
# 3186            Sitting in bow of her father's 5 m boat
# 4578                                            Fishing
# 4517                        Bathing in water 0.9 m deep
# 3694                                            Fishing
# 1100                                           Swimming
# 5061                                       Pearl diving
# 2638                               Resting on surfboard
# 5428  On December 28, 1908, an earthquake, followed ...
# 2765                                            Surfing
# 3405                                           Swimming
# 963                                          Snorkeling
# 5409                                                NaN
# 4295                                           Swimming
# 4883                                             Diving
# 546                                       Body boarding
# 2509                                       Sea disaster
# 402                                       Body Boarding
# 509                                             Fishing
# 5664                                             Murder
# 3592                                       Spearfishing
# 1163                                                NaN
# 79                                              Surfing
# 2030                                         Snorkeling
# 1194                                            Fishing
# 3077                                       Spearfishing
# 2165                   Fishing / washing bait off hands
# 5131                                       Pearl diving
# 3871                Swimming with other crew near wharf
#
#                                                    Name Sex   ...  \
# 3360                                         Jim Allman    M  ...
# 6089                                           crew x 2    M  ...
# 3723                                        Leslie Cook    M  ...
# 6121                                        John Walker    M  ...
# 669                                     Allison Foreman    F  ...
# 4367                       Sgt. Larry Charles  Graybill    M  ...
# 1421                                         Tony Perez    M  ...
# 4522                                          Don Dixon    M  ...
# 3010                                    Scott Armstrong    M  ...
# 2816                                                NaN  NaN  ...
# 4857                                         Mr. Redman    M  ...
# 6215                             male, a mental patient    M  ...
# 6000                    a seaman from the John and Lucy    M  ...
# 2249                                          L. Molina    M  ...
# 4002                                       Mick Coleman    M  ...
# 2707                                      Cedric Coucom    M  ...
# 3827  surf boat, occupants: Ray Sturdy and 4 other f...  NaN  ...
# 1654                                       Erika Hailey    F  ...
# 207                                           Ming Chan    M  ...
# 1437                                               male    M  ...
# 3372                                      Ralph Painter    M  ...
# 3326                                    Hans Kretschmer    M  ...
# 1635                                    Vincent Motais     M  ...
# 2149                                 Douw van der Merwe    M  ...
# 1637                                       Chuck Wilson    M  ...
# 1411                                      Wayne Brodsky    M  ...
# 6169                                      Indian people  NaN  ...
# 2198                                               male    M  ...
# 1300                                      Chase Edwards    M  ...
# 5992                                      John Williams    M  ...
# 1838                                David Brennen Smith    M  ...
# 727                                      Scott Stephens    M  ...
# 3186                                    Debbie McMillan    F  ...
# 4578      12-foot dinghy Occupants: R. Hunt & a friend.  NaN  ...
# 4517                             Richard Joseph Maguire    M  ...
# 3694              boat, occupant: R. Southey of Lautoka  NaN  ...
# 1100                               A visitor from Spain    M  ...
# 5061                             Nago, a Japanese diver    M  ...
# 2638                                  Richard Forrester    M  ...
# 5428                                                NaN  NaN  ...
# 2765                                       Conrad Brown    M  ...
# 3405                                   Elissane Mobunda    M  ...
# 963                         Yevgeniy (Eugene) Trishkin     M  ...
# 5409                               Alfred Victor Clulow    M  ...
# 4295                                   Mrs. W. F. Dixon    F  ...
# 4883                                               Ohta    M  ...
# 546                                         Scott Berry    M  ...
# 2509                                         Siale Sime    M  ...
# 402                                     Caleb Swanepoel    M  ...
# 509                                      Mathew Vickers    M  ...
# 5664                               A young pearl trader    M  ...
# 3592                                    Cornelius Meyer    M  ...
# 1163                       Luciano Guimaraes dos Santos    M  ...
# 79                                    Catherine Vissers    M  ...
# 2030                                        Andrea Nani    F  ...
# 1194                                         Joel Bacud    M  ...
# 3077                                      Les Winkworth    M  ...
# 2165                                       Grant Rielly    M  ...
# 5131                                            Eseromi    M  ...
# 3871  George Jimmy Stevens, aborgine from the lugg...    M  ...
#
#                      Time                             Investigator or Source  \
# 3360                13h15                   Sydney Morning Herald, 8/22/1971
# 6089                  NaN                   New York Evening Post, 9/14/1831
# 3723                  NaN  Daily Examiner (Grafton, NSW), 12/23/1963; J. ...
# 6121                  NaN                         Journal of Captain Marryat
# 669             Afternoon                               WMBF News, 6/14/2013
# 4367                  NaN                                    New York Times
# 1421  Just before sundown                                         R. Collier
# 4522                  NaN  G.P. Whitley (1951), p.193; V.M. Coppleson (19...
# 3010                  NaN                    St. Petersburg Times, 10/3/1981
# 2816                  NaN                                             MEDSAF
# 4857                  NaN                          Canberra Times, 2/12/1937
# 6215                  NaN       L.Green, A Decent Fellow doesn't Work, p.225
# 6000                  NaN                                The Argus, 2/8/1856
# 2249                23h00    Hawaii Department of Land and Natural Resources
# 4002                  NaN                       V.M. Coppleson (1962), p.252
# 2707            Nightfall                             H. Edwards, pp.115-116
# 3827                  NaN                 Sydney Daily Telegraph, 4/21/1962
# 1654                16h30                                        KETK56 News
# 207                   NaN                                            YouTube
# 1437                17h55                                 S. Petersohn, GSAF
# 3372                16h30  C. Black, GSAF; H.D. Baldridge (1994) SAF Case...
# 3326                10h00  D. Miller & R. Collier, R. Collier, pp. 52-53;...
# 1635                16h15                       Federation Francaise de Surf
# 2149                  NaN                           Sunday Times, 12/20/1998
# 1637                14h00                                   R. Collier, GSAF
# 1411                14h00                                         W. Brodsky
# 6169                  NaN            H. Edwards, p.31, citing Samuel Purchas
# 2198                15h30                     The Stuart (FL) News, 4/1/1998
# 1300                  NaN                         San Diego Reader, 1/7/2009
# 5992                  NaN                                     C. Moore, GSAF
# 1838                12h30  S. Petersohn, GSAF; J. Eager; A. Caldwell, Orl...
# 727                 12h00               R. Collier; Redwood Times, 11/5/2012
# 3186                  NaN                                   A. Sharpe, p.103
# 4578                  NaN         Geraldton Guardian and Express, 6/317/1947
# 4517                13h30  G.P. Whitley (1951), p.194; V.M. Coppleson (19...
# 3694                  NaN                              Fiji Times, 2/17/1964
# 1100                19h00                                       S. Petersohn
# 5061                  NaN       J. Green, p.32; V.M. Coppleson (1958), p.242
# 2638                12h00                      R. Forrester, M. Levine, GSAF
# 5428                  NaN                                             MEDSAF
# 2765                17h00                                  R. Collier, p.101
# 3405                  NaN              Natal Daily News, 2/4/1970; D. Davies
# 963                 11h00  M. Levine, R. Collier, E. Ritter, M. Fouda, et al
# 5409                  NaN                       V.M. Coppleson (1962), p.245
# 4295                  NaN  Evening Sun (Baltimore), 9/27/1955; V.M. Coppl...
# 4883                  NaN                                The Argus, 4/9/1936
# 546                 09h45                           The Australian, 6/9/2014
# 2509            Afternoon                        Tongan Chronicle, 2/26/1993
# 402                 14h40                                     NSRI, 6/27/205
# 509                   NaN                            Delmarva Now, 8/29/2014
# 5664                  NaN                 Middletown Daily Argus, 10/20/1893
# 3592                  NaN                            The Age, 1/17/1966, p.1
# 1163                  NaN                          Jornal Pequeno, 1/26/2009
# 79                  18h00                           Stab Magazine, 9/26/2017
# 2030                  NaN                                    E. Ritter, GSAF
# 1194       10h00 -- 11h00                               Sun Star, 11/08/2008
# 3077                05h00                      L. Winkworth, M. Levine, GSAF
# 2165                 Dusk                          Daily Dispatch, 9/16/1998
# 5131                  NaN       J. Green, p.32; V.M. Coppleson (1958), p.241
# 3871                14h00  Brisbane Courier Mail, 12/14/1961; V.M. Copple...
#
#      original order Case Number.1 Case Number.2  \
# 3360         2945.0    1971.08.21    1971.08.21
# 6089          216.0    1831.08.24    1831.08.24
# 3723         2582.0    1963.12.21    1963.12.21
# 6121          184.0    1811.03.01    1811.03.01
# 669          5635.0  2013.06.14.R  2013.06.14.R
# 4367         1938.0    1953.09.18    1953.09.18
# 1421         4883.0    2006.10.31    2006.10.31
# 4522         1783.0    1949.01.13    1949.01.13
# 3010         3295.0    1981.10.01    1981.10.01
# 2816         3489.0    1986.08.00    1986.08.00
# 4857         1448.0    1937.02.11    1937.02.11
# 6215           90.0       ND-0106       ND-0106
# 6000          305.0    1856.02.06    1856.02.06
# 2249         4056.0    1997.06.24    1997.06.24
# 4002         2303.0    1960.04.10    1960.04.10
# 2707         3598.0    1988.11.07    1988.11.07
# 3827         2478.0    1962.04.20    1962.04.20
# 1654         4650.0  2004.07.27.a  2004.07.27.a
# 207          6097.0  2016.10.13.R  2016.10.13.R
# 1437         4867.0    2006.09.02    2006.09.02
# 3372         2933.0    1971.01.02    1971.01.02
# 3326         2979.0    1972.09.09    1972.09.09
# 1635         4669.0    2004.10.06    2004.10.06
# 2149         4155.0    1998.12.18    1998.12.18
# 1637         4667.0    2004.10.01    2004.10.01
# 1411         4893.0    2007.01.07    2007.01.07
# 6169          136.0  1617.00.00.R  1617.00.00.R
# 2198         4106.0    1998.03.31    1998.03.31
# 1300         5004.0  2008.00.00.a  2008.00.00.a
# 5992          313.0    1858.04.04    1858.04.04
# 1838         4466.0    2002.08.07    2002.08.07
# 727          5577.0    2012.10.30    2012.10.30
# 3186         3119.0    1976.06.01    1976.06.01
# 4578         1727.0    1947.06.16    1947.06.16
# 4517         1788.0    1949.04.17    1949.04.17
# 3694         2611.0  1964.02.17.R  1964.02.17.R
# 1100         5204.0    2009.08.10    2009.08.10
# 5061         1244.0    1929.12.13    1929.12.13
# 2638         3667.0    1990.05.06    1990.05.06
# 5428          877.0    1909.01.00    1909.01.00
# 2765         3540.0    1987.10.26    1987.10.26
# 3405         2900.0  1970.01.23.a  1970.01.23.a
# 963          5341.0  2010.12.01.b  2010.12.01.b
# 5409          896.0    1910.01.26    1910.01.26
# 4295         2010.0    1955.07.07    1955.07.07
# 4883         1422.0    1936.04.08    1936.04.08
# 546          5758.0  2014.06.09.a  2014.06.09.a
# 2509         3796.0    1993.02.18    1993.02.18
# 402          5902.0  2015.06.27.a  2015.06.27.a
# 509          5795.0    2014.08.28    2014.08.28
# 5664          641.0  1893.10.20.R  1893.10.20.R
# 3592         2713.0    1966.01.15    1966.01.15
# 1163         5141.0  2009.01.26.R  2009.01.26.R
# 79           6225.0  2017.09.25.a  2017.09.25.a
# 2030         4274.0    2000.07.22    2000.07.22
# 1194         5110.0    2008.11.06    2008.11.06
# 3077         3228.0    1980.01.15    1980.01.15
# 2165         4139.0  1998.09.16.R  1998.09.16.R
# 5131         1174.0    1927.04.08    1927.04.08
# 3871         2434.0    1961.12.13    1961.12.13
#
#                                      pdf  \
# 3360               1971.08.21-Allman.pdf
# 6089               1831.08.24-Orator.pdf
# 3723                 1963.12.21-Cook.pdf
# 6121          1811.03.01-John-Walker.pdf
# 669             2013.06.14.R-Foreman.pdf
# 4367             1953.09.18-Graybill.pdf
# 1421                2006.10.31-Perez.pdf
# 4522             1949.01.13-DonDixon.pdf
# 3010            1981.10.01-Armstrong.pdf
# 2816            1986.08.00-NV-France.pdf
# 4857               1937.02.11-Redman.pdf
# 6215           ND-0106-MentalPatient.pdf
# 6000          1856.02.06-Point-Henry.pdf
# 2249               1997.06.24-Molina.pdf
# 4002              1960.04.10-Coleman.pdf
# 2707         1988.11.07-CedricCoucom.pdf
# 3827               1962.04.20-Sturdy.pdf
# 1654             2004.07.27.a-Hailey.pdf
# 207              2016.10.13.R-Breach.pdf
# 1437          2006.09.02.b-Child-NSB.pdf
# 3372              1971.01.02-Painter.pdf
# 3326   1972.09.09-Kretschmer_Collier.pdf
# 1635               2004.10.06-Motais.pdf
# 2149          1998.12.18-vanderMerwe.pdf
# 1637               2004.10.01-Wilson.pdf
# 1411              2007.01.07-Brodsky.pdf
# 6169              1617.00.00-Purchas.pdf
# 2198          1998.03.31-JensenBeach.pdf
# 1300            2008.00.00.a-Edwards.pdf
# 5992             1858.04.04-Williams.pdf
# 1838                2002.08.07-Smith.pdf
# 727              2012.10.30-Stephens.pdf
# 3186             1976.06.01-McMillan.pdf
# 4578     1947.06.16-fishermen-Coogee.pdf
# 4517              1949.04.17-Maguire.pdf
# 3694          1964.02.17.R-Fiji-boat.pdf
# 1100              2009.08.10-Volusia.pdf
# 5061                 1929.12.13-Nago.pdf
# 2638            1990.05.06-Forrester.pdf
# 5428              1909.01.00-Messina.pdf
# 2765        1987.10.26-Brown_Collier.pdf
# 3405            1970.01.23.a-Mobunda.pdf
# 963   2010.12.01.b-Yevgeniy-Trishkin.pdf
# 5409               1910.01.26-Clulow.pdf
# 4295                1955.07.07-Dixon.pdf
# 4883                 1936.04.08-Ohta.pdf
# 546               2014.06.09.a-Berry.pdf
# 2509            1993.02.18-SialeSime.pdf
# 402           2015.06.27.a-Swanepoel.pdf
# 509               2014.08.28-Vickers.pdf
# 5664        1893.10.20.R-PearlTrader.pdf
# 3592                1966.01.15-Meyer.pdf
# 1163             2009.01.26.R-Brazil.pdf
# 79              2017.09.25.a-Vissers.pdf
# 2030                 2000.07.22-Nani.pdf
# 1194                2008.11.06-Bacud.pdf
# 3077            1980.01.15-Winkworth.pdf
# 2165             1998.09.16.R-Rielly.pdf
# 5131              1927.04.08-Eseromi.pdf
# 3871              1961.12.13-Stevens.pdf
#
#                                            href formula  \
# 3360  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6089  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3723  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6121  http://sharkattackfile.net/spreadsheets/pdf_di...
# 669   http://sharkattackfile.net/spreadsheets/pdf_di...
# 4367  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1421  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4522  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3010  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2816  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4857  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6215  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6000  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2249  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4002  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2707  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3827  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1654  http://sharkattackfile.net/spreadsheets/pdf_di...
# 207   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1437  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3372  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3326  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1635  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2149  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1637  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1411  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6169  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2198  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1300  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5992  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1838  http://sharkattackfile.net/spreadsheets/pdf_di...
# 727   http://sharkattackfile.net/spreadsheets/pdf_di...
# 3186  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4578  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4517  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3694  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1100  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5061  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2638  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5428  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2765  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3405  http://sharkattackfile.net/spreadsheets/pdf_di...
# 963   http://sharkattackfile.net/spreadsheets/pdf_di...
# 5409  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4295  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4883  http://sharkattackfile.net/spreadsheets/pdf_di...
# 546   http://sharkattackfile.net/spreadsheets/pdf_di...
# 2509  http://sharkattackfile.net/spreadsheets/pdf_di...
# 402   http://sharkattackfile.net/spreadsheets/pdf_di...
# 509   http://sharkattackfile.net/spreadsheets/pdf_di...
# 5664  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3592  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1163  http://sharkattackfile.net/spreadsheets/pdf_di...
# 79    http://sharkattackfile.net/spreadsheets/pdf_di...
# 2030  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1194  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3077  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2165  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5131  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3871  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Unnamed: 22  \
# 3360  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6089  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3723  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6121  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 669   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4367  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1421  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4522  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3010  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2816  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4857  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6215  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6000  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2249  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4002  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2707  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3827  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1654  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 207   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1437  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3372  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3326  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1635  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2149  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1637  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1411  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6169  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2198  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1300  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5992  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1838  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 727   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3186  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4578  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4517  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3694  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1100  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5061  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2638  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5428  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2765  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3405  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 963   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5409  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4295  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4883  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 546   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2509  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 402   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 509   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5664  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3592  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1163  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 79    http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2030  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1194  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3077  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2165  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5131  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3871  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
#
#      Unnamed: 23
# 3360         NaN
# 6089         NaN
# 3723         NaN
# 6121         NaN
# 669          NaN
# 4367         NaN
# 1421         NaN
# 4522         NaN
# 3010         NaN
# 2816         NaN
# 4857         NaN
# 6215         NaN
# 6000         NaN
# 2249         NaN
# 4002         NaN
# 2707         NaN
# 3827         NaN
# 1654         NaN
# 207          NaN
# 1437         NaN
# 3372         NaN
# 3326         NaN
# 1635         NaN
# 2149         NaN
# 1637         NaN
# 1411         NaN
# 6169         NaN
# 2198         NaN
# 1300         NaN
# 5992         NaN
# 1838         NaN
# 727          NaN
# 3186         NaN
# 4578         NaN
# 4517         NaN
# 3694         NaN
# 1100         NaN
# 5061         NaN
# 2638         NaN
# 5428         NaN
# 2765         NaN
# 3405         NaN
# 963          NaN
# 5409         NaN
# 4295         NaN
# 4883         NaN
# 546          NaN
# 2509         NaN
# 402          NaN
# 509          NaN
# 5664         NaN
# 3592         NaN
# 1163         NaN
# 79           NaN
# 2030         NaN
# 1194         NaN
# 3077         NaN
# 2165         NaN
# 5131         NaN
# 3871         NaN
#
# [60 rows x 23 columns]

# %%
shark_clean.Type.unique
# Out:
# <bound method Series.unique of 0          Boating
# 1       Unprovoked
# 2          Unknown
# 3       Unprovoked
# 4         Provoked
#            ...
# 6309       Unknown
# 6310       Unknown
# 6311       Unknown
# 6312       Unknown
# 6313       Unknown
# Name: Type, Length: 6314, dtype: object>

# %%
def tipo(x):
    if 'Boat' in x:
        return 'Boating'
    elif 'Unprov' in x:
        return 'Unprovoked'
    elif 'Unknown' in x:
        return 'Unknown'
    elif 'Prov' in x:
        return 'Provoked'
    else:
        return 'Unknown'

shark_clean['Type'] = shark_clean['Type'].apply(tipo)

# %%
shark_clean.Type
# Out:
# 0          Boating
# 1       Unprovoked
# 2          Unknown
# 3       Unprovoked
# 4         Provoked
#            ...
# 6309       Unknown
# 6310       Unknown
# 6311       Unknown
# 6312       Unknown
# 6313       Unknown
# Name: Type, Length: 6314, dtype: object

# %% [markdown]
# # limpieza de country

# %%
shark_clean['Country'] = shark_clean['Country'].fillna('Unknown')
shark_clean.sample(10)
# Out:
#      Case Number       Date  Year        Type       Country  \
# 6022  1852.05.24 1852-05-24  1852  Unprovoked  SOUTH AFRICA
# 5994  1858.01.14        NaT  1858  Unprovoked           USA
# 2053  2000.06.02 2000-06-02  2000  Unprovoked           USA
# 3419  1969.11.11 1969-11-11  1969  Unprovoked           USA
# 30    2018.04.15 2018-04-15  2018  Unprovoked     AUSTRALIA
# 625   2013.09.08 2013-09-08  2013  Unprovoked           USA
# 3790  1962.10.06 1962-10-06  1962     Unknown           USA
# 3246  1975.01.19 1975-01-19  1975  Unprovoked     AUSTRALIA
# 4570  1947.10.28 1947-10-28  1947  Unprovoked     AUSTRALIA
# 1283  2008.03.28 2008-03-28  2008  Unprovoked           USA
#
#                     Area                                       Location  \
# 6022       KwaZulu-Natal                                     Durban Bay
# 5994              Hawaii                                            NaN
# 2053             Florida  27th Avenue, New Smyrna Beach, Volusia County
# 3419              Hawaii                          Barbers Point, O'ahu
# 30     Western Australia              Cobblestones, Margaret River Area
# 625       South Carolina             St. Helena Island, Beaufort County
# 3790          California              2 miles off Santa Catalina Island
# 3246     South Australia                                     Coffin Bay
# 4570  Northern Territory         Mornington Island, Gulf of Carpentaria
# 1283             Florida              Near Cocoa Beach, Brevard  County
#
#                                                Activity                  Name  \
# 6022                        Swimming from capsized boat  Mr. Messum's servant
# 5994                                           Swimming         Minor Hodgdon
# 2053                                         Snorkeling          Brian Alcorn
# 3419                          Scuba diving for lobsters         D.R. McGinnis
# 30                                              Surfing  Alejandro Travaglini
# 625                                                 NaN                female
# 3790  Overcome by CO fumes, fell overboard from 36' ...           Marian Leaf
# 3246                                            Surfing       David Barrowman
# 4570                        Fishing in waist-deep water    Dan, an aboriginal
# 1283                                    Boogie Boarding       Teresa Holloway
#
#      Sex   ...   Time                             Investigator or Source  \
# 6022    M  ...    NaN             M. Levine, GSAF; Natal Times, 6/4/1852
# 5994    M  ...    NaN                           New York Times 3/14/1858
# 2053    M  ...  14h55  S. Petersohn, GSAF; D. Brannon; M.I. Johnson, ...
# 3419    M  ...    NaN  H.D. Baldridge, p.185; J. Borg, p.74;  L. Tayl...
# 30      M  ...  08h00                                      B.Myatt, GSAF
# 625     F  ...    NaN                                   WIS-TV, 9/9/2013
# 3790    F  ...    NaN  Long Beach Independent, 10/9/1962; H.D. Baldri...
# 3246    M  ...    NaN  J. West; Adelaide Advertiser, 1/20/1975; P. Ke...
# 4570    M  ...    NaN  G.P. Whitley (1951), p.193; V.M. Coppleson (19...
# 1283    M  ...    NaN                    D. MacAnnally, Eyewitness News
#
#      original order Case Number.1 Case Number.2  \
# 6022          283.0    1852.05.24    1852.05.24
# 5994          311.0  1858.01.14.R  1858.01.14.R
# 2053         4251.0    2000.06.02    2000.06.02
# 3419         2886.0    1969.11.11    1969.11.11
# 30           6274.0  2018.04.15.a  2018.04.15.a
# 625          5679.0    2013.09.08    2013.09.08
# 3790         2515.0    1962.10.06    1962.10.06
# 3246         3059.0    1975.01.19    1975.01.19
# 4570         1735.0    1947.10.28    1947.10.28
# 1283         5021.0  2008.03.28.a  2008.03.28.a
#
#                                 pdf  \
# 6022  1852.05.24-Messum-servant.pdf
# 5994       1858.01.14.R-Hodgdon.pdf
# 2053          2000.06.02-Alcorn.pdf
# 3419        1969.11.11-McGinnis.pdf
# 30      2018.04.15.a-Travaglini.pdf
# 625        2013.09.08-St-Helena.pdf
# 3790            1962.10.06-Leaf.pdf
# 3246       1975.01.19-Barrowman.pdf
# 4570             1947.10.28-Dan.pdf
# 1283      2008.03.28.a-Holloway.pdf
#
#                                            href formula  \
# 6022  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5994  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2053  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3419  http://sharkattackfile.net/spreadsheets/pdf_di...
# 30    http://sharkattackfile.net/spreadsheets/pdf_di...
# 625   http://sharkattackfile.net/spreadsheets/pdf_di...
# 3790  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3246                                                NaN
# 4570  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1283  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Unnamed: 22  \
# 6022  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5994  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2053  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3419  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 30    http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 625   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3790  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3246  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4570  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1283  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
#
#      Unnamed: 23
# 6022         NaN
# 5994         NaN
# 2053         NaN
# 3419         NaN
# 30           NaN
# 625          NaN
# 3790         NaN
# 3246         NaN
# 4570         NaN
# 1283         NaN
#
# [10 rows x 23 columns]

# %% [markdown]
# # limpieza de Area

# %%
shark_clean['Area'] = shark_clean['Area'].fillna('Unknown')
shark_clean.sample(10)
# Out:
#      Case Number       Date  Year        Type           Country  \
# 522   2014.08.05 2014-08-05  2014  Unprovoked               USA
# 6268     ND.0037        NaT     0  Unprovoked      SAUDI ARABIA
# 690   2013.04.02 2013-04-02  2013  Unprovoked               USA
# 97    2017.08.29 2017-08-29  2017  Unprovoked         AUSTRALIA
# 1368  2007.06.30 2007-06-30  2007    Provoked               USA
# 880   2011.08.23 2011-08-23  2011  Unprovoked      SOUTH AFRICA
# 3461  1968.08.24 1968-08-24  1968  Unprovoked               USA
# 5149  1926.07.12 1926-07-12  1926     Boating               USA
# 195   2016.12.11 2016-12-11  2016  Unprovoked  FRENCH POLYNESIA
# 5854  1877.12.12 1877-12-12  1877  Unprovoked         AUSTRALIA
#
#                        Area  \
# 522                 Florida
# 6268       Eastern Province
# 690                  Hawaii
# 97                 Victoria
# 1368                Florida
# 880   Western Cape Province
# 3461                Florida
# 5149             New Jersey
# 195                Tuamotos
# 5854        New South Wales
#
#                                                Location  \
# 522                        Cocoa Beach, Brevard  County
# 6268                East of the Ras Tanura-Jubail area
# 690                                   Kaanapali Shores
# 97                                       Cathedral Rock
# 1368                                     Marques Island
# 880   Lookout Beach, near the Keurbooms river mouth ...
# 3461                 Half mile north of Juno Beach Pier
# 5149                             20 miles off Seabright
# 195                                      Takapoto Atoll
# 5854                                        Near Sydney
#
#                                         Activity  \
# 522                                     Swimming
# 6268                                      Diving
# 690                                      Surfing
# 97                                       Surfing
# 1368                    Removing hook from shark
# 880                                      Surfing
# 3461      Playing with a frisbee in the shallows
# 5149                                     Fishing
# 195                                      Fishing
# 5854  Washed overboard from the barque Mary Eady
#
#                                                    Name Sex   ...   Time  \
# 522                                              female    F  ...    NaN
# 6268                                      a pearl diver    M  ...    NaN
# 690                                                male    M  ...  08h30
# 97                                      Marcel Brundler    M  ...  10h30
# 1368                                      Samuel Gruber    M  ...    NaN
# 880                                     Tim van Heerden    M  ...  09h11
# 3461              Colleen Chamberlin & Scott Chamberlin  NaN  ...  16h00
# 5149  boat, occupants:  Andrew Peterson & Peter Jerg...    M  ...    NaN
# 195                                                male    M  ...    NaN
# 5854                                            2 males    M  ...    NaN
#
#                    Investigator or Source original order Case Number.1  \
# 522                   Inquisitr, 8/7/2014         5782.0    2014.08.05
# 6268                            G.F. Mead           37.0       ND.0037
# 690                    Maui Now, 4/2/2013         5614.0  2013.04.02.a
# 97                         B. Myatt, GSAF         6207.0    2017.08.29
# 1368  S. Gruber; SharkAttackSurvivors.com         4936.0  2007.06.30.b
# 880                     News24, 8/23/2011         5424.0    2011.08.23
# 3461                   M. Vorenberg, GSAF         2844.0    1968.08.24
# 5149        Evening Sun, undated clipping         1156.0    1926.07.12
# 195               Tahiti Info, 12/12/2016         6109.0  2016.12.11.b
# 5854         Brisbane Courier, 12/15/1877          451.0    1877.12.12
#
#      Case Number.2                            pdf  \
# 522     2014.08.05           2014.08.05-Tulip.pdf
# 6268       ND.0037  ND-0037-PearlDiver-sepsis.pdf
# 690   2013.04.02.a        2013.04.02.a-Hawaii.pdf
# 97      2017.08.29        2017.08.27-Brundler.pdf
# 1368  2007.06.30.b        2007.06.30.b-Gruber.pdf
# 880     2011.08.23      2011.08.23-VanHeerden.pdf
# 3461    1968.08.24      1968.08.24-Chamberlin.pdf
# 5149    1926.07.12            1926.07.12-boat.pdf
# 195   2016.12.11.b      2015.12.11.b-Takapoto.pdf
# 5854    1877.12.12        1877.12.12-MaryEady.pdf
#
#                                            href formula  \
# 522   http://sharkattackfile.net/spreadsheets/pdf_di...
# 6268  http://sharkattackfile.net/spreadsheets/pdf_di...
# 690   http://sharkattackfile.net/spreadsheets/pdf_di...
# 97    http://sharkattackfile.net/spreadsheets/pdf_di...
# 1368  http://sharkattackfile.net/spreadsheets/pdf_di...
# 880   http://sharkattackfile.net/spreadsheets/pdf_di...
# 3461  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5149  http://sharkattackfile.net/spreadsheets/pdf_di...
# 195   http://sharkattackfile.net/spreadsheets/pdf_di...
# 5854  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Unnamed: 22  \
# 522   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6268  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 690   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 97    http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1368  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 880   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3461  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5149  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 195   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5854  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
#
#      Unnamed: 23
# 522          NaN
# 6268         NaN
# 690          NaN
# 97           NaN
# 1368         NaN
# 880          NaN
# 3461         NaN
# 5149         NaN
# 195          NaN
# 5854         NaN
#
# [10 rows x 23 columns]

# %% [markdown]
# # limpieza de location

# %%
shark_clean['Location']=shark_clean['Location'].fillna('Unknown')
shark_clean.sample(13)
# Out:
#      Case Number       Date  Year        Type          Country  \
# 455   2015.01.23 2015-01-23  2015  Unprovoked     SOUTH AFRICA
# 5164  1925.11.00        NaT  1925  Unprovoked              USA
# 2109  1999.08.21 1999-08-21  1999  Unprovoked              USA
# 5041  1930.08.06 1930-08-06  1930  Unprovoked              USA
# 539   2014.06.27        NaT  2014     Boating       ST. MARTIN
# 1584  2005.06.02 2005-06-02  2005  Unprovoked              USA
# 6250     ND.0057        NaT     0  Unprovoked       MADAGASCAR
# 4220  1957.00.00        NaT  1957  Unprovoked             IRAN
# 3183  1976.06.23 1976-06-23  1976  Unprovoked              USA
# 2414  1994.12.01 1994-12-01  1994  Unprovoked           BRAZIL
# 3098  1979.05.05        NaT  1979    Provoked     SOUTH AFRICA
# 6221     ND.0095        NaT     0  Unprovoked  SOLOMON ISLANDS
# 3320  1972.12.01 1972-12-01  1972  Unprovoked          REUNION
#
#                        Area                                         Location  \
# 455   Eastern Cape Province                                     Nahoon Beach
# 5164            Puerto Rico                          Condado Beach, San Juan
# 2109                Florida                      Ponce Inlet, Volusia County
# 5041                Florida              Palm Beach Inlet, Palm Beach County
# 539                 Unknown                              20 miles from shore
# 1584                  Texas                   Mustang Island, Corpus Christi
# 6250     Toamasina Province                                         Tamatave
# 4220            Karun River  near Band Misan in Shustar, 420 km from the sea
# 3183                Florida               St. Andrews State Park, Bay County
# 2414             Pernambuco                                            Paiva
# 3098  Western Cape Province                              Hangklip, False Bay
# 6221       Malaita Province                                  Waibana Passage
# 3320         Saint-Philippe                                     Basse Vallée
#
#                   Activity                       Name Sex   ...       Time  \
# 455               Floating             Christiaan Nel    M  ...  Afternoon
# 5164                   NaN            American lawyer    M  ...        NaN
# 2109               Surfing                       G.C.    M  ...      18h40
# 5041              Swimming            Captain W. Kemp    M  ...      06h00
# 539   Transatlantic Rowing              Victor Mooney    M  ...        NaN
# 1584                Wading                       male    M  ...    Morning
# 6250               Bathing                       male    M  ...        NaN
# 4220                   NaN                 Mr. Paniry    M  ...        NaN
# 3183            Skindiving                Paul Maurer    M  ...      Night
# 2414               Surfing  Laudenilson Gomes de Lima    M  ...        NaN
# 3098          Spearfishing            Piet Boonzaaier    M  ...      14h00
# 6221                Diving               Albert Raiti    M  ...        NaN
# 3320          Spearfishing                        NaN  NaN  ...        NaN
#
#                               Investigator or Source original order  \
# 455                        Daily Dispatch, 1/31/2015         5849.0
# 5164              V.M. Coppleson (1958), pp.48 & 265         1141.0
# 2109                              S. Petersohn, GSAF         4195.0
# 5041                       Palm Beach Post, 8/7/1930         1264.0
# 539   Star Advertiser, 6/272014; Goree Challenge.com         5765.0
# 1584                                      KRIS6 News         4720.0
# 6250                    V.M. Coppleson (1958), p.259           55.0
# 4220                                         B. Coad         2085.0
# 3183                 Albuquerque Journal, 6/25/1976          3122.0
# 2414         San Jose Mercury News, 1/6/1995, p.12A          3891.0
# 3098                                Dr. P. Landsberg         3207.0
# 6221                  Islands Magazine, 2/1998, p.76           84.0
# 3320                              G. Van Grevelynghe         2985.0
#
#      Case Number.1 Case Number.2                                    pdf  \
# 455     2015.01.23    2015.01.23                     2015.01.23-Nel.pdf
# 5164  1925.11.00.a  1925.11.00.a                1925.11.00.a-Lawyer.pdf
# 2109    1999.08.21    1999.08.21                      1999.08.21-GC.pdf
# 5041    1930.08.06    1930.08.06                    1930.08.06-Kemp.pdf
# 539   2014.06.27.R  2014.06.27.R                  2014.06.27-Mooney.pdf
# 1584    2005.06.02    2005.06.02                   2005.06.02-Texas.pdf
# 6250       ND.0057       ND.0057        ND-0057-Tamatave-Madagascar.pdf
# 4220  1957.00.00.d  1957.00.00.d                1957.00.00.d-Paniry.pdf
# 3183    1976.06.23    1976.06.23                  1976.06.23-Maurer.pdf
# 2414    1994.12.01    1994.12.01  1994.12.01-LaudenilsonGomesDeLima.pdf
# 3098    1979.05.05    1979.05.05              1979.05.05-Boonzaaier.pdf
# 6221       ND.0095       ND.0095                ND-0095-AlbertRaiti.pdf
# 3320    1972.12.01    1972.12.01                 1972.12.01-Reunion.pdf
#
#                                            href formula  \
# 455   http://sharkattackfile.net/spreadsheets/pdf_di...
# 5164  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2109  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5041  http://sharkattackfile.net/spreadsheets/pdf_di...
# 539   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1584  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6250  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4220  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3183  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2414  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3098  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6221  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3320  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Unnamed: 22  \
# 455   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5164  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2109  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5041  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 539   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1584  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6250  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4220  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3183  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2414  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3098  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6221  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3320  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
#
#      Unnamed: 23
# 455          NaN
# 5164         NaN
# 2109         NaN
# 5041         NaN
# 539          NaN
# 1584         NaN
# 6250         NaN
# 4220         NaN
# 3183         NaN
# 2414         NaN
# 3098         NaN
# 6221         NaN
# 3320         NaN
#
# [13 rows x 23 columns]

# %% [markdown]
# # limpieza de Activity

# %%
shark_clean['Activity']=shark_clean['Activity'].fillna('Unknown')
shark_clean.head()
# Out:
#   Case Number       Date  Year        Type    Country             Area  \
# 0  2018.06.25 2018-06-25  2018     Boating        USA       California
# 1  2018.06.18 2018-06-18  2018  Unprovoked        USA          Georgia
# 2  2018.06.09 2018-06-09  2018     Unknown        USA           Hawaii
# 3  2018.06.08 2018-06-08  2018  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04 2018-06-04  2018    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
#             Time          Investigator or Source original order Case Number.1  \
# 0          18h00                R. Collier, GSAF         6303.0    2018.06.25
# 1  14h00  -15h00  K.McMurray, TrackingSharks.com         6302.0    2018.06.18
# 2          07h45  K.McMurray, TrackingSharks.com         6301.0    2018.06.09
# 3            NaN                  B. Myatt, GSAF         6300.0    2018.06.08
# 4            NaN                       A .Kipper         6299.0    2018.06.04
#
#   Case Number.2                       pdf  \
# 0    2018.06.25      2018.06.25-Wolfe.pdf
# 1    2018.06.18    2018.06.18-McNeely.pdf
# 2    2018.06.09     2018.06.09-Denges.pdf
# 3    2018.06.08  2018.06.08-Arrawarra.pdf
# 4    2018.06.04      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Unnamed: 22 Unnamed: 23
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
#
# [5 rows x 23 columns]

# %%
shark_clean.Activity.unique()
# Out:
# array(['Paddling', 'Standing', 'Surfing', ...,
#        'Crew swimming alongside their anchored ship',
#        '4 men were bathing', 'Wreck of  large double sailing canoe'],
#       dtype=object)

# %%
def actividad(x):
    if 'Padd' in x:
        return 'Paddling'
    elif 'Surf' in x:
        return 'Surfing'
    else:
        return 'Unknown'

# %%
shark_clean.Activity = shark_clean.Activity.apply(actividad)
shark_clean
# Out:
#      Case Number       Date  Year        Type    Country             Area  \
# 0     2018.06.25 2018-06-25  2018     Boating        USA       California
# 1     2018.06.18 2018-06-18  2018  Unprovoked        USA          Georgia
# 2     2018.06.09 2018-06-09  2018     Unknown        USA           Hawaii
# 3     2018.06.08 2018-06-08  2018  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04 2018-06-04  2018    Provoked     MEXICO           Colima
# ...          ...        ...   ...         ...        ...              ...
# 6309           0        NaT  1926     Unknown    Unknown          Unknown
# 6310           0        NaT  1926     Unknown    Unknown          Unknown
# 6311           0        NaT  1926     Unknown    Unknown          Unknown
# 6312  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
# 6313  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
#
#                             Location  Activity             Name Sex   ...  \
# 0        Oceanside, San Diego County  Paddling      Julie Wolfe    F  ...
# 1     St. Simon Island, Glynn County   Unknown  Adyson McNeely     F  ...
# 2                       Habush, Oahu   Surfing      John Denges    M  ...
# 3                 Arrawarra Headland   Surfing             male    M  ...
# 4                           La Ticla   Unknown   Gustavo Ramos     M  ...
# ...                              ...       ...              ...  ...  ...
# 6309                         Unknown   Unknown              NaN  NaN  ...
# 6310                         Unknown   Unknown              NaN  NaN  ...
# 6311                         Unknown   Unknown              NaN  NaN  ...
# 6312                         Unknown   Unknown              NaN  NaN  ...
# 6313                         Unknown   Unknown              NaN  NaN  ...
#
#                Time          Investigator or Source original order  \
# 0             18h00                R. Collier, GSAF         6303.0
# 1     14h00  -15h00  K.McMurray, TrackingSharks.com         6302.0
# 2             07h45  K.McMurray, TrackingSharks.com         6301.0
# 3               NaN                  B. Myatt, GSAF         6300.0
# 4               NaN                       A .Kipper         6299.0
# ...             ...                             ...            ...
# 6309            NaN                             NaN         6309.0
# 6310            NaN                             NaN         6310.0
# 6311            NaN                             NaN            NaN
# 6312            NaN                             NaN            NaN
# 6313            NaN                             NaN            NaN
#
#      Case Number.1 Case Number.2                       pdf  \
# 0       2018.06.25    2018.06.25      2018.06.25-Wolfe.pdf
# 1       2018.06.18    2018.06.18    2018.06.18-McNeely.pdf
# 2       2018.06.09    2018.06.09     2018.06.09-Denges.pdf
# 3       2018.06.08    2018.06.08  2018.06.08-Arrawarra.pdf
# 4       2018.06.04    2018.06.04      2018.06.04-Ramos.pdf
# ...            ...           ...                       ...
# 6309           NaN           NaN                       NaN
# 6310           NaN           NaN                       NaN
# 6311           NaN           NaN                       NaN
# 6312           NaN           NaN                       NaN
# 6313           NaN           NaN                       NaN
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6309                                                NaN
# 6310                                                NaN
# 6311                                                NaN
# 6312                                                NaN
# 6313                                                NaN
#
#                                                    href Unnamed: 22  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                 ...         ...
# 6309                                                NaN         NaN
# 6310                                                NaN         NaN
# 6311                                                NaN         NaN
# 6312                                                NaN         NaN
# 6313                                                NaN         NaN
#
#      Unnamed: 23
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 6309         NaN
# 6310         NaN
# 6311         NaN
# 6312         NaN
# 6313         NaN
#
# [6314 rows x 23 columns]

# %% [markdown]
# # limpieza Name

# %%
shark_clean['Name'].value_counts()
# Out:
# male                            550
# female                           97
# boy                              23
# 2 males                          16
# boat                             14
#                                ...
# Kevin Cole                        1
# Mark Van Leer                     1
# Rich Reed                         1
# F. Mautin                         1
# William (or Richard) Schwall      1
# Name: Name, Length: 5232, dtype: int64

# %%
shark_clean['Name']=shark_clean['Name'].str.replace\
('male|female|boy|2 males|boat|sailor|JapaneseUnknown|Anonymous|Unknowns|child|girl|a Unknown|Unidentified|\
fisherman| Unknown|a pearl diver|a soldier|IndianUnknown|a native|blackUnknown|\
ArabUnknown|AmericanUnknown|ZuluUnknown|JapaneseUnknown|\
2 fishermen|youngUnknown|FijianUnknown|Unknown x 2|unknown|3Unknown|aboriginalUnknown|\
Japanese diver|nativeUnknown|woman|2 women|RussianUnknown|dinghy|AUnknown'\
 ,'Unknown',regex=True)\
.fillna('Unknown')
shark_clean.sample(10)
# Out:
#      Case Number       Date  Year        Type       Country  \
# 1725  2003.11.00        NaT  2003    Provoked        PANAMA
# 3120  1978.07.27 1978-07-27  1978     Unknown           USA
# 4213  1957.00.00        NaT  1957     Unknown     SRI LANKA
# 2287  1996.09.01 1996-09-01  1996     Unknown           USA
# 614   2013.10.11 2013-10-11  2013  Unprovoked  SOUTH AFRICA
# 2157  1998.10.24 1998-10-24  1998  Unprovoked           USA
# 4291  1955.08.00        NaT  1955     Boating     AUSTRALIA
# 3285  1974.00.00        NaT  1974  Unprovoked     AUSTRALIA
# 2204  1998.01.25 1998-01-25  1998  Unprovoked       REUNION
# 5076  1929.04.11 1929-04-11  1929    Provoked     AUSTRALIA
#
#                        Area                            Location Activity  \
# 1725          Pearl Islands                             Unknown  Unknown
# 3120         South Carolina                             Unknown  Unknown
# 4213       Western Province                      Colombo Harbor  Unknown
# 2287         South Carolina     Garden City Beach, Horry County  Unknown
# 614   Eastern Cape Province  Albatros Point, near Jeffrey's Bay  Unknown
# 2157                Florida    Jupiter Beach, Palm Beach County  Unknown
# 4291        South Australia                        Port Augusta  Unknown
# 3285      Western Australia                         Emu Channel  Unknown
# 2204             Grand'Anse                             Unknown  Unknown
# 5076             Queensland           Bribie Passage, Caloundra  Unknown
#
#                                   Name Sex   ...           Time  \
# 1725                     Richard Hatch    M  ...            NaN
# 3120                         Sam Boger    M  ...            NaN
# 4213                    F. L. Fernando    M  ...            NaN
# 2287                           Unknown    F  ...      Afternoon
# 614         Burgert Van Der Westhuizen    M  ...          11h30
# 2157                  Jessica Stephens    F  ...      Afternoon
# 4291  launch, occupant: Clarrie Whelan  NaN  ...            NaN
# 3285                    Glen Tunbridge    M  ...            NaN
# 2204                      Philippe Blu    M  ...  Mid afternoon
# 5076           David Alexander Manners    M  ...          13h45
#
#                                Investigator or Source original order  \
# 1725                         J. Eager, scubaradio.com         4579.0
# 3120                  NY Times, 7/28/1978, p.6, col.6         3185.0
# 4213                                    R. I. DeSilva         2092.0
# 2287                                The Sun, 9/2/1996         4018.0
# 614                          JBayNews.com, 10/11/2013         5690.0
# 2157  Sun Sentinel. Fort Lauderdale, 10/25/1998, p.3B         4147.0
# 4291                V.M. Coppleson (1958), pp.184-185         2014.0
# 3285                                     G. Tunbridge         3020.0
# 2204                               G. Van Grevelynghe         4100.0
# 5076    Brisbane Courier, 4/12/1929; Coppleson (1933)         1229.0
#
#      Case Number.1 Case Number.2                           pdf  \
# 1725    2003.11.00    2003.11.00   2003.11.00-RichardHatch.pdf
# 3120    1978.07.27    1978.07.27          1978.07.27-Boger.pdf
# 4213  1957.00.00.k  1957.00.00.k     1957.00.00.k-Fernando.pdf
# 2287  1996.09.01.b  1996.09.01.b   1996.09.01.b-GardenCity.pdf
# 614     2013.10.11    2013.10.11  2013.10.11-Vd-Westhuizen.pdf
# 2157    1998.10.24    1998.10.24       1998.10.24-Stephens.pdf
# 4291  1955.08.00.a  1955.08.00.a       1955.08.00.a-Whelan.pdf
# 3285  1974.00.00.b  1974.00.00.b    1974.00.00.b-Tunbridge.pdf
# 2204  1998.01.25.b  1998.01.25.b          1998.01.25.b-Blu.pdf
# 5076    1929.04.11    1929.04.11        1929.04.11-Manners.pdf
#
#                                            href formula  \
# 1725  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3120  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4213  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2287  http://sharkattackfile.net/spreadsheets/pdf_di...
# 614   http://sharkattackfile.net/spreadsheets/pdf_di...
# 2157  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4291  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3285  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2204  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5076  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Unnamed: 22  \
# 1725  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3120  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4213  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2287  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 614   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2157  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4291  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3285  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2204  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5076  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
#
#      Unnamed: 23
# 1725         NaN
# 3120         NaN
# 4213         NaN
# 2287         NaN
# 614          NaN
# 2157         NaN
# 4291         NaN
# 3285         NaN
# 2204         NaN
# 5076         NaN
#
# [10 rows x 23 columns]

# %%
shark_clean['Name'].value_counts().sample(10)
# Out:
# Bruce Corby                                          1
# Kristina Aleksandrova                                1
# Mira Kudlich                                         1
# Harold Tait                                          1
# canoe. Occupants: Doreen Tyrell & Frederick Bates    1
# J. Gillies                                           1
# Steve Robles                                         1
# Clarence Ware                                        1
# Felix Brem                                           1
# crew                                                 2
# Name: Name, dtype: int64

# %% [markdown]
# # limpieza sex

# %%
shark_clean.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Fatal (Y/N)', 'Species ', 'Time',
#        'Investigator or Source', 'original order', 'Case Number.1',
#        'Case Number.2', 'pdf', 'href formula', 'href', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
columnas = {shark_clean.columns[9] : 'Sex'}
shark_clean = shark_clean.rename(columns=columnas)
shark_clean['Sex']
# Out:
# 0         F
# 1         F
# 2         M
# 3         M
# 4         M
#        ...
# 6309    NaN
# 6310    NaN
# 6311    NaN
# 6312    NaN
# 6313    NaN
# Name: Sex, Length: 6314, dtype: object

# %%
def sexo(x):
    if 'F' in x:
        return 'Female'
    elif 'M' in x:
        return 'Male'
    elif 'M ' in x:
        return 'Male'
    elif 'ND' in x:
        return 'ND'
    else:
        return 'ND'

# %%
shark_clean['Sex'].unique()
# Out:
# array(['F', 'M', nan,
#        'http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.03.b-FlatRock.pdf',
#        'M ', 'lli',
#        'http://sharkattackfile.net/spreadsheets/pdf_directory/1998.00.00.c-Transkei.pdf',
#        'N', '.'], dtype=object)

# %%
shark_clean['Sex']=shark_clean['Sex'].fillna('ND')

# %%
shark_clean['Sex'] = shark_clean.Sex.apply(sexo)
shark_clean.Sex.unique()
# Out:
# array(['Female', 'Male', 'ND'], dtype=object)

# %% [markdown]
# # limpieza Age

# %%
shark_clean['Age']
# Out:
# 0        57
# 1        11
# 2        48
# 3       NaN
# 4       NaN
#        ...
# 6309    NaN
# 6310    NaN
# 6311    NaN
# 6312    NaN
# 6313    NaN
# Name: Age, Length: 6314, dtype: object

# %%
shark_clean['Age'] = shark_clean['Age'].fillna('15')
shark_clean['Age'] = shark_clean['Age'].loc[shark_clean['Age'].str.isnumeric()]
shark_clean['Age'] = shark_clean['Age'].str.replace('½', '')

# %%
shark_clean['Age'] = shark_clean['Age'].fillna(0)
shark_clean['Age'] = shark_clean['Age'].astype('int64')
shark_clean
# Out:
#      Case Number       Date  Year        Type    Country             Area  \
# 0     2018.06.25 2018-06-25  2018     Boating        USA       California
# 1     2018.06.18 2018-06-18  2018  Unprovoked        USA          Georgia
# 2     2018.06.09 2018-06-09  2018     Unknown        USA           Hawaii
# 3     2018.06.08 2018-06-08  2018  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04 2018-06-04  2018    Provoked     MEXICO           Colima
# ...          ...        ...   ...         ...        ...              ...
# 6309           0        NaT  1926     Unknown    Unknown          Unknown
# 6310           0        NaT  1926     Unknown    Unknown          Unknown
# 6311           0        NaT  1926     Unknown    Unknown          Unknown
# 6312  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
# 6313  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
#
#                             Location  Activity             Name     Sex  ...  \
# 0        Oceanside, San Diego County  Paddling      Julie Wolfe  Female  ...
# 1     St. Simon Island, Glynn County   Unknown  Adyson McNeely   Female  ...
# 2                       Habush, Oahu   Surfing      John Denges    Male  ...
# 3                 Arrawarra Headland   Surfing          Unknown    Male  ...
# 4                           La Ticla   Unknown   Gustavo Ramos     Male  ...
# ...                              ...       ...              ...     ...  ...
# 6309                         Unknown   Unknown          Unknown      ND  ...
# 6310                         Unknown   Unknown          Unknown      ND  ...
# 6311                         Unknown   Unknown          Unknown      ND  ...
# 6312                         Unknown   Unknown          Unknown      ND  ...
# 6313                         Unknown   Unknown          Unknown      ND  ...
#
#                Time          Investigator or Source original order  \
# 0             18h00                R. Collier, GSAF         6303.0
# 1     14h00  -15h00  K.McMurray, TrackingSharks.com         6302.0
# 2             07h45  K.McMurray, TrackingSharks.com         6301.0
# 3               NaN                  B. Myatt, GSAF         6300.0
# 4               NaN                       A .Kipper         6299.0
# ...             ...                             ...            ...
# 6309            NaN                             NaN         6309.0
# 6310            NaN                             NaN         6310.0
# 6311            NaN                             NaN            NaN
# 6312            NaN                             NaN            NaN
# 6313            NaN                             NaN            NaN
#
#      Case Number.1 Case Number.2                       pdf  \
# 0       2018.06.25    2018.06.25      2018.06.25-Wolfe.pdf
# 1       2018.06.18    2018.06.18    2018.06.18-McNeely.pdf
# 2       2018.06.09    2018.06.09     2018.06.09-Denges.pdf
# 3       2018.06.08    2018.06.08  2018.06.08-Arrawarra.pdf
# 4       2018.06.04    2018.06.04      2018.06.04-Ramos.pdf
# ...            ...           ...                       ...
# 6309           NaN           NaN                       NaN
# 6310           NaN           NaN                       NaN
# 6311           NaN           NaN                       NaN
# 6312           NaN           NaN                       NaN
# 6313           NaN           NaN                       NaN
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6309                                                NaN
# 6310                                                NaN
# 6311                                                NaN
# 6312                                                NaN
# 6313                                                NaN
#
#                                                    href Unnamed: 22  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                 ...         ...
# 6309                                                NaN         NaN
# 6310                                                NaN         NaN
# 6311                                                NaN         NaN
# 6312                                                NaN         NaN
# 6313                                                NaN         NaN
#
#      Unnamed: 23
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 6309         NaN
# 6310         NaN
# 6311         NaN
# 6312         NaN
# 6313         NaN
#
# [6314 rows x 23 columns]

# %%
shark_clean.dtypes
# Out:
# Case Number                       object
# Date                      datetime64[ns]
# Year                               int64
# Type                              object
# Country                           object
# Area                              object
# Location                          object
# Activity                          object
# Name                              object
# Sex                               object
# Age                                int64
# Fatal (Y/N)                       object
# Species                           object
# Time                              object
# Investigator or Source            object
# original order                   float64
# Case Number.1                     object
# Case Number.2                     object
# pdf                               object
# href formula                      object
# href                              object
# Unnamed: 22                       object
# Unnamed: 23                       object
# dtype: object

# %% [markdown]
# # limpieza de Fatal (Y/N)

# %%
columnas = {shark_clean.columns[11] : 'Fatal'}
shark_clean = shark_clean.rename(columns=columnas)
shark_clean['Fatal']
# Out:
# 0         N
# 1         N
# 2         N
# 3         N
# 4         N
#        ...
# 6309    NaN
# 6310    NaN
# 6311    NaN
# 6312    NaN
# 6313    NaN
# Name: Fatal, Length: 6314, dtype: object

# %%
shark_clean['Fatal'] = shark_clean['Fatal'].fillna('Unknown')
shark_clean['Fatal'].unique()
# Out:
# array(['No', 'Unkown', 'Yes'], dtype=object)

# %%
shark_clean['Fatal'].unique()
# Out:
# array(['N', 'Unknown', '2018.06.03.b', 'Y', 'M', 'UNKNOWN', '2017',
#        '1998.00.00.c', ' N', 'N ', 'y'], dtype=object)

# %%
def fatalidad(x):
    if 'N' in x:
        return 'No'
    elif 'Y' in x:
        return 'Yes'
    elif ' N' in x:
        return 'No'
    elif 'N ' in x:
        return 'No'
    elif 'y' in x:
        return 'Yes'
    else:
        return 'Unkown'

# %%
shark_clean['Fatal'] = shark_clean['Fatal'].apply(fatalidad)
shark_clean['Fatal'].unique()
# Out:
# array(['No', 'Unkown', 'Yes'], dtype=object)

# %% [markdown]
# # limpieza de Species

# %%
def spec_filter(x):
    if 'White' or 'white' in x:
        return 'White Shark'
    elif 'tig' or 'Tig' in x:
        return 'Tiger Shark'
    elif 'grey' or 'Grey' in x:
        return 'grey'
    elif 'Bull' or 'bull' in x:
        return 'Bull Shark'
    elif 'Blacktip' or 'blacktip' in x:
        return 'Blacktip Shark'
    elif 'Wob' or 'wob' in x:
        return 'Wobbegong Shark'
    elif 'nurse' or 'Nurse' in x:
        return 'Nurse Shark'
    elif 'Spin' or 'spin' in x:
        return 'Spinner Shark'
    elif 'Lem' or 'lem':
        return 'Lemon Shark'
    elif 'Ang' or 'ang' in x:
        return 'Angel Shark'
    elif 'Dog' or 'dog' in x:
        return 'Dogfish Shark'

# %%
for i in shark_clean['Species '].unique():
    print(i)
# Out:
# White shark
# nan
# 2 m shark
# Tiger shark, 3m
# Tiger shark
# Lemon shark, 3'
# Bull shark, 6'
# Grey reef shark
# Invalid incident
# Tawny nurse shark, 2m
# Shark involvement not confirmed
# Questionable
# 3 m shark
# White shark, 3.5 m
# White shark, 2.5 m
# 6' shark
# Juvenile bull shark
# Bull shark
# Tiger shark, 12'
# Wobbegong shark
# 3.5 m shark
# 1.8 m shark
# Blacktip shark
# Juvenile white shark,  2.7 to 3.2 m
# Bull shark, 2 m
# Possibly a wobbegong
# Injury believed caused by an eel, not a shark
# Galapagos shark?
# 2m shark
# Bull shark, 3 m
# Grey reef shark. 2 m
# small shark
# Wobbegong shark?
# Juvenile nurse shark
# Nurse shark. 5'
# Tiger shark, female
# Some drowned but other may have been killed by blue sharks
# White shark, 4.6 m
# Cookiecutter shark
# Wobbegong shark, 1 m
# White shark, 4.5 m
# Spinner shark, 4 to 5 feet
# Tiger shark, 8 to 10 feet
# 8' shark
# Death may have been due to drowning
# 5' shark
# 4' to 5' shark
# Porbeagle, 1.5 m
# White shark, 3.5m
# 5' to 6' shark
# White shark, 3 to 3.5m
# Nurse shark
# White shark, 3 m
# Shark involvement questionable
# White shark, 5' to 7'
# Possibly a juvenile blacktip shark
# Oceanic whitetip shark, 1.8 to 2 m
# 4' shark
# White shark, 10'
# A small shark
# Sandtiger shark  2'
# Blue shark 6'
# "A small shark"
# White shark, 11' to 13'
# White shark, 8' to 10'
# White shark, 9'
# Bull shark, 4' to 5'
# Tiger shark, 100 kg
# Shark involvement prior to death not confirmed
# No shark invovlement
# Bull shark, 2m
# White shark, 4 m
# Seven-gill shark
# 3m shark, probably a smooth hound
# 3' shark
# 9' shark
# Shark involvement highly doubtful
# No shark invovlement - it ws a publicity stunt
# Bull shark, 5' to 7'
# 10' shark
# Lemon shark
# Bull shark, 1.5
# Lemon shark pup
# White shark, female, 14'
# Caribbean reef shark
# Bull shark, 4 m
# Bull shark, 1 m
# a small shark
# Wobbegong shark, 2m
# Broadnose sevengill shark, 1.5 m
#  6' to 8' shark
# 3' to 4' shark
# Tiger shark, 10'
# Invalid
# Bull shark, 3.5 m
# Tiger shark, 10'
# Blue shark
# Nurse shark, 4'
# reef shark, 1m
# White shark, 10' to 12'
# Lemon shark, 9'
# Angel shark
# dogfish shark
# Tawny nurse shark
# Caribbean reef shark, 4.5'
# 3' to 5' shark
# Said to involve an 8' shark but more likely damage caused by debris
# 3+ m shark
# Mako shark
# Bronze whaler sharks x 3
# Blacktip shark, 4'
# Nurse shark, 2'
# Mako shark, 1.5 m [5']
# Grey reef shark, 2 m
# Bull shark, 7'
# Tiger shark, 2.5 m
# Nurse shark, 2.5-ft
# Bronze whaler
# Sandtiger shark
# No shark involvement
# Reef shark, 5'
# Bull sharks x 2
# Tiger shark, 14'
# Silky shark, 6.5'
# Bronze whaler shark, 6'
# Tiger shark, 1.5 m
# Galapagos shark
# Spinner shark, 7'
# Bull shark, 2.8 to 3.1 m
# Spinner shark, 5'
# Tiger shark, 7'
# Hammerhead sp.
# Tiger shark, 13'
# Blacktip shark, 4' to 5'
# Blacktip shark, 5' to 6'
# White shark, 19'
# juvenile shark
# Tiger shark, 13'
# Hammerhead shark
# White shark, 11' to 12'
# Hammerhead shark.
# 4' shark?
# White shark, 10' to 12'
# White shark, 13'
# Hammerhead shark. 6' to 7'
# Blacktip or spinner shark, 4'
# Thought to involve a 3' to 4' shark, but shark involvement not confirmed
# White shark, 3.9 to 4.2 m
# Mako shark, 100-lb
# Bronze whaler shark, 1.5m
# White shark, 7'
# Shark involvement not cofirmed
# 6' to 7' shark
# White shark, 2m to 3 m
# Bull shark, 5'
# small nurse shark
# Bull shark, 2.5 m
# 1m to 1.2 m shark
# 3- to 4-foot shark
# White shark, 6 m
# Blue shark, 8 to 9 feet
# Tiger shark, 8 to 12 feet
# Blacktip Reef shark
# Tiger shark, 3.5 m
# 3.5 to 4 m shark
# 2 m to  3 m shark
# Bull shark, 1.3 m
# 5 m shark
# 1.5 m shark
# White shark or oceanic whitetip shark
# Raggedtooth shark, 1.3 m
# White shark, 4 to 5 m
# Shark involvement prior to death still to be determined
# Shark involvement not confirmed & highly unlikely
# Goblin shark
# 2' shark
# 12' to 14' shark
# 1 m shark
# Bull shark, 3' to 4'
# White shark, 18' to 20'
# 8' to 10' shark
# 2 white shark: 13' & 9"8"
# 7' shark
# White shark, 12' to 14'
# Spinner shark
# Spinner shark or blacktip shark
# 4' to 6' shark
# Bull shark, 4.5'
# reef shark
#  Bull shark, 8'
# Bull shark, 9' to 10'
#  Bull shark, 5'
# 4' tp 5' shark
# Possibly juvenile tiger shark
# 1.8 metre shark
# 6' to 8' shark
#  White shark, 7'
# Oceanic whitetip shark'
# Caribbean reef shark, 7' to 8'
#  Lemon shark, 3.5 m
#  Sandbar shark, 3' to 4'
#  Bull shark, 1.2m
# 3m shark
#  Tawney nurse shark, 1m
#  white shark, 15'
# Cow shark
# reef shark?
#  Raggedtooth shark, 2m
# 3 m to 4 m white shark
# Blacktip or spinner shark?
# Blacktip reef shark
# 7-gill shark?
# 1m shark
# 7-gill shark
# Oceanic whitetip shark
# Reported to involve a bull shark
# White shark, 3m
# Tiger shark, 10' to 12'
#  Wobbegong shark, 1.6 to 1.8m
# Tiger shark, 3m
# Thought to involve a white shark
# White shark, 10 '
# Reported to involve a white shark
# Blacktip reef shark, 1m
# Thought to involve a bull shark
# Reported to involve a 4 m white shark
# Whitetip reef shark, 4' to 6'
# Nurse shark?
# Small bull shark
# Salmon shark
# Mako shark, 5'
# Tiger shark?
# Bull shark, 8'
# Bull shark, 6' to 8'
# Tiger shark, 8' to 10'
# Possibly a Bull shark, 3'
# Lemon shark, 4'
# Wobbegong, 2m
# Grey nurse shark, 3m
# Possibly a blacktip reef shark
# shark involvement not confirmed
# Raggedtooth shark, 1.5 m
# Tiger shark, 4.8 m
# Bronze whaler shark, 2.5m
# "small sharks"
# White shark, 4m
# White shark, 5m
# Tiger shark, 15'
# Bronze whaler shark, 3m
# 2.5 m shark
# Bull shark, 2m
# Tiger shark, 6'
# 2' to 3' shark
# Tiger shark, 8'
# Tiger shark, 10' to 12'
# White shark, 15' to 16'
# Possibly a 3 m bull shark
# 3.5' to 4' shark
# Porbeagle shark, 7'
# 4.5 m shark
# Lemon shark, 4' to 5'
# Lemon shark, 2.5m to 3m
# White shark or bronze whaler
# Salmon shark suspected, but unlikely
# 14' to 18'shark
# 15' shark
# possibly a bull shark
# a small reef shark
# small blacktip shark?
# Blacktip shark
# Blue shark, 2.5m
# White shark, 2 m
# 18" to 24" shark
# Bull shark, 3m
# Tiger shark, 8' to 9'
# White shark, 4 m to 5m
# White shark, 6m
# Tiger shark, 10'
# White shark, 4m
# Possibly a bull shark
# Possibly a 5' to 6' bull shark
# Tawny nurse shark, 40cm
# Grey nurse shark
# White shark, 7m
# Blue shark, 70-kg blue shark
# White shark, 2.7 m
# Allegedly a 4 m tiger shark
# 7' to 8' shark
# White shark, 2.5m
# White shark, 15' to 16'
# Raggedtooth shark
# White shark, 15'
# Port Jackson shark, 1m
# 10' to 12' shark
# 2 to 2.5 m shark
# Tiger shark, 2m
# 6' shark, possibly a blactip or spinner shark
# White shark, >6'
# Possibly a 5' to 6' sandtiger shark
# 4 m shark
# Grey reef shark
# White shark, 3m to 4m
# Bull shark, 3m female
# White shark, 5' k
# Oceanic whitetip shark, 7'
# Sevengill shark, 6' to 8'
# Zambesi shark
#  Tiger shark, 2.8m
# Sandbar shark, 8'
# Bull shark, 12'
# reef shark, 1.5m
# 1' to 2' shark
# possibly a bronze whaler shark
#  Bull shark, 2.5 m
# Blacktip shark pup
# Bull shark, 2.5m
# 3 m to 4 m shark
# White shark x 2
# Oceanic whitetip shark, 2.5m
# Mako shark
# Oceanic whitetip shark, 2.5m, female
# Porbeagle shark, 8'
# White shark, 14' to 18'
# Bull shark, 1.4m
# Possibly a 6' lemon shark
# Shark involvement prior to death was not confirmed
# Possibly a small blacktip shark
# Sandtiger shark, 4' to 5'
# A small spinner shark
# Nurse shark, juvenile
# Blue shark, 7'
# 20 to 30kg shark
# Lemon shark, 6'
# 14' shark
# Oceanic whitetip shark, 6'
# Possibly a blue shark
# Wobbegong shark, 1.6m
# 2 m to 3 m shark
# Spinner shark, 6'
# Thought to involve a juvenile hammerhead shark
# Whitetip reef shark, 1m
# Zambesi shark, 2m
# White shark, 2.8 to 3 m
# Sandtiger shark, 8'
# Thresher shark
# Bull shark, 10'
# Spurdog
# White shark, 5' to 6' juvenile
# White shark, 2m
# Tiger shark, 12
# Bull shark?
# Caribbean reef shark, 6'
# Nurse shark, 6'
# Thought to involve a Bronze whale shark, 2m
# Shark involvement probable, but not confirmed
# Oceanic whitetip shark, 2.5 to 3m
# 80 kg shark
# 5' to 8' shark
# blacktip or spinner shark
# White shark, 12' to 15' female
# Bronze whaler shark?
# Blacktip reef shark pup
# Thought to involve a cookie cutter shark
# Wobbegong shark, 60cm
# Blue shark, 1m
# 2.6 m shark
# White shark, 2.5m
# Bull shark, 2.7 m
# White shark, 12'
# White shark, 5.5 m
# White sharks
# Dusky shark, 2m
# Mako shark, 3m
# Broadnose sevengill shark
# White shark, 4m to 5m
# 4 to 5m white shark
# Raggedtooth shark, 2m
# White shark, 4.5 to 5 m
# Zambesi shark?
# Bronze whaler shark
#  reef shark, 1.8m
# 5 m white shark
# +3' shark
# 2' to 3' juvenile shark
# White shark, 14' to 16'
# 8' bull shark or Caribbean reef shark
# 8' white shark or 7-gill shark
# 3'  shark
# 2'  shark
# 2' to 3' reef shark
# Starry smoothhound shark, 1m
# Bull shark, 6' to 7'
# White shark, 4.5m
# 4.5 to 5' shark
# Basking shark
# Tiger sharks in area
# 2 small bull sharks
# Bull shark, 1.8m
# White shark, 12' to 15'
# Tiger shark, 2.3m
# Tiger shark, 13' female
# Reported by media as shark attack, but shark involvement prior to death was not confirmed
# Shark involvement not confirmed; thought to be a barracuda bite
# 1.5' to 2' shark
# 2.5' shark
# A bull shark, according to some of the divers on the boat
# Goblin shark, 4.2'
# Blacktip shark, 2m
# Mako shark, 90kg
# Bronze whaler shark, 4m
# Nurse shark, 10'
# Possibly a hammerhead shark
# "a small shark"
# Not a shark attack; it was a hoax
# 2.27 m shark
# 1.5 to 2 m shark
# Blacktip shark, 5'
# Oceanic whitetip sharks were in the vicinity
# Gray reef shark
# 9.5' shark?
# Nurse shark, 2' to 3'
# Possibly a spinner shark
# White shark, 12'
# Sand shark
# Possibly a 6' bull shark
#
# Possibly a 10' bull shark
# Bronze whaler shark, 1.5 m
# 3' small spotted catshark, Scyliorhinus canicula
# Bull shark, 5'
# Questionable Incident
# Lemon shark, 6' female
# A 10-year-old 94-pound pregnant blacktip reef shark
# Lesser spotted dogfish, Scyliorhinus canicula, less than 80 cm in length
# White shark, 2m
# Tiger shark, 14'
# Lemon shark, >1 m
# Bull shark, 10'
# White shark, 3m
# 2.4 m shark
# 24" to 30" shark
# 6' to 8' shark, possibly a tiger shark
# 2.5 to 3 m shark
# 2 to 3 m shark
# White shark, 12' to 15'
# Raggedtooth shark, 150-kg
# White shark, 5m
# Bull shark, 1.5m
# White shark, 16'
# 1' to 4' shark
# 3' to 3.5' shark
# White shark, 3.5m
# small catsharks
# White shark?
# Thought to involve a mako shark, but possibly a sea lion
# Bull shark, 4' to 5'
# Angel shark, 1.2m
# Shark involvement not confirmed, injury may have been caused by a bluefish
# Bull or tiger shark
# 5' to 6' spinner or bull shark
# 1.8 m blacktip "reef" shark
# Possibly a 1' to 3' blacktip or spinner shark
# 14' white shark
# Tiger shark, 8' to 12'
# Tiger shark, 15' female
# Grey reef shark, 5' to 8'
# Wobbegong shark, 2 m
# Bull shark, 4' to bull shark
# Bronze whaler shark, a  juvenile
# Raggedtooth shark, 2.5 m to 3 m
# 3 m, 600-kg shark
# Tiger shark, 5'
# Bronze whaler shark, 2 m
# 5' to 7' shark
# 4.5 m white shark
# 12' to 18' shark
# 12' shark
# 3.5 m white shark
# Said to involve a 1.5 m shark
# Whitetip reef shark
# 4 m white shark
# 3 m white shark
# Raggedtooth shark, 2.5m
# 12' to 14' white shark
# 18' white shark
# Tiger shark, less than 10'
# Caribbean reef sharks
# Tiger shark, 3 m
# 14' to 16' white shark
# 4 m [13'] white shark
# 2 m [6.75'] shark, 200-kg shark T
# juvenile white shark
# Possibly a sandbar shark or small blacktip shark
# 1.8 m [6'] shark
# 3.5 m [11.5']shark
# [4.5' to 5'] shark
# [4' to 5']
# 1.8 m [6'] bull shark
# On 8/13/2005 anglers from New Zealand caught a 2.8 m [9'3"], 140-kg [309-lb] shark at the same spot. It was believed this was the same shark that killed Alysha
# Unknown, but it was reported that a shark tooth was recovered from the wound
# 3 m [10'] white shark
# Mr. Burgess of ISAF announced the injury was the bite of a 1.8 m [6'], 2- to 3-year old white shark. Subsequent investigation revealed there was  no shark involvement in this incident
# "small shark"
# 18" to 36" shark
# Tiger shark, 3 m [10']
# 2 m [6.75'] copper shark
# 1.8 m [6'] blacktip shark
# small hammerhead shark
# 4 m [13'] shark
# 6 m [20'] white shark
# Sandtiger shark, 2.1 m [7']
# Bronze whaler shark, 4.3 m [14']
# Nurse shark, 3'
# Tiger shark, 2.4 m [8']
# 1.8 m [6'] Caribbean reef shark
# 3 m [10'] shark
# Bronze whaler shark, 2 m to 3 m [6.75' to 10']
# 4.5 m & 5 m white shark
# 5.5 m [18'] white shark
# 2.5 m [8.25'] bull shark
# 2 m [6.75'] white shark
# Bronze whaler shark, 2.4 m [8']
# 1.8 m to 2.4 m [6' to 8'] white shark
# Tiger shark, 2.4 m to 3.7 m [8' to 12']
# Raggedtooth shark, 1.5 to 2 m [5' to 6.75']
# Thought to involve a 2.5 m bull or tiger shark
# Tiger shark, 3 m [10']
# 2.4 m [8'] shark
# 0.9 m to 1.2 m [3' to 4'] white shark
# 4.9 m to 5.5 m [16' to 18'] white shark
# 1.2 m [4'] shark
# 3 m to 4 m [10' to 13']  white shark
# 1.2 m to 1.5 m [4' to 5'] shark
# Longfin mako shark, 3.5 m [11.5'], 350-kg [772-lb]
# 2 sharks, 4.5 m & 3 m
# "black tipped" shark
# 9'2" white shark
# Bronze whaler shark, 2.5 m [8.25']
# 0.9 m to 1.5 m [3' to 5'] shark
# 2.4 m to 3.7 m [8' to 12'] shark
# 1,5 m [5'] Caribbean reef shark (Carcharhinus  perezi)
# Mako shark, 1.8 m [6']
# Wobbegong shark, 1.2 m [4'] k
# White shark, 5.5 m [18']
# small sharks
# 5 m [16.5'] white shark
# 1.2 m [4'] bull shark
# bull shark
# Tiger shark, 2.4 m to 3 m [8' to 10']
# Bronze whaler shark, 1.5 m [5']
# 2 m [6.75'] sevengill  shark
# 60 cm [23.6"] blind or brown shark
# 4 m to 5 m [13' to 16.5'] white shark
# Possibily a  1.5 to 2 m sandtiger shark
# Shark involvement doubtful
# Bull shark, 1.65 m [5'5"] was speared & killed
# Bull shark, 132-kg [291-lb]
# Mako shark, 3 m to 4 m [10' to 13']
# Raggedtooth shark, 3.5 m [11.5']
# Shortfin mako shark
# Wobbegong shark, 1.2 m [4']
# Tiger shark, 4 m [13']  ?
# 2.5 oceanic whitetip shark
# Nurse shark, 60 cm to 90 cm [2' to 3']
# 1.5 m [5'] shark, either a bronze whaler or a grey nurse shark
# 1.2 m [4'] "grey-colored shark"
# 2 m cow shark
# 4.5 m to 5.5 m [15' to 18'] white shark
# 3.5 m [11.5'] white shark
# Unidentified species
# 1.5 m to 1.8 m [5' to 6'] shark
# 2.1 m  [7'] bull shark
# 8' great hammerhead shark
# 106 cm [3.5']  shark
# small brown shark
# 3.7 m to 4.3 m [12' to 14'] shark
# "sand shark"
# 1.8 m [6'] reef shark - or a 2.1 m to 2.4 m [7' to 8'] grey-colored shark
# 0.9 m to 1.2 m [3' to 4'] shark
# A small shark
# 15 cm to 20 cm [6" to 8"] bite diameter just below left knee
# Mako shark, 3 m [10']
# 60 cm [2'] captive shark
# 2.5 m [8.25'] white shark
# Species unidentified
# Thought to involve a 2 m [6.75'] grey nurse shark
# Thought to involve a >2 m [6.75'] bull shark
# Reported to involve a hammerhead shark
# White shark, 4 m white shark
# Wobbegong shark, 1m
# Shark involvement not confirmed, injury may be due to a stingray
# 3 m to 4.5 m [10' to 15'] white shark
# 2.4 m to 3 m [8' to 10'] grey colored shark
# 1.8 m to 2.1 m [6' to 7']  Caribbean Reef Shark
# Possibly a bull shark or tiger shark
# Blacktip or spinner shark
# 3.5' to 4.5' shark
# 1.2 m [4'] blacktip shark
# Tiger shark, 1.5 m [5']k
# 3 m to 3.7 m [10' to 12'] shark
# 1' to 2' hammerhead or bonnethed shark
# 0.9 m  to 1.2 m [3' to 4'] shark
# Nurse shark, 1.5 m [5']
# Sandtiger shark, 3 m [10']
# 1.2 m [4'] blacktip or sandbar shark
# Bull shark, 1.8 m to 2.1 m [6' to 7']
# Mako shark, 400-lb
# 1.2 m to 1.5 m [4' to 5'] shark, possibly a bull shark
# Tiger shark, 2.4 m to 2.7 m [8' to 9']
# 0.9 m to 1.2 m [3' to 4'] shark; Tooth fragment recovered from hand
#
# 1.5 to 2.5 m [5' to 8.25'] copper shark
# 3.7 m to 4.3 m [12' to 14'] white shark
# 1 m  shark
# 3' blacktip shark
# 2.1 m to 2.4 m [7' to 8'] shark
# White shark, 6m [20']
# Bull shark, 400-lb
# 0.9 m [3'] shark
# Nurse shark, 1m
# Spinner shark, 3' to 4'
# Shark involvement prior to death unconfired
# 1.5 m [5'] "whaler shark"
# C. leucas tooth fragment recovered from kayak
# Unidentified
# Tiger shark, 1.8 m [6']
# Mako shark, 2 m [6.75']
# Tiger shark, 1.8 m [6']
# Questionable incident - shark bite may have precipitated drowning
# 2' to 3.5' shark
# 12' sandtiger shark
# A large white shark was filmed by divers on a local wreck 2 days prior to the incident.
# 1.5 m [5'] shark
# 3 m [10'] bull shark
# Possibly  a blacktip or spinner shark
# 3' shark, possibly  a blacktip or spinner shark
# Blacktip shark, 5' to 6'
# 1.9 m [6.5'] bull shark
# Mako shark, 14'
# 0.9 m  [3'] shark
# Bull shark, 2.3 m [7.5']
# White shark, 2.4 m to 3 m [8' to 10']
# 1.2 m to 1.5 m [4.5' to 5'] shark
# White shark, 2.7 m to 3 m [9' to 10']
# Possibly a juvenile blacktip or spinner shark
# Possibly a 1.5 m [5'] blacktip or spinner shark
# 1 m shark, possibly whitetip reef shark
# White shark, 2.7 m [9']
# Spinner shark, 1.2 m to 1.5 m [4' to 5']
# Tiger shark, 8'
# White shark, 5 m [16.5']
# Bronze whaler shark, 2.5 m [8.25']  k
# 2 m [6.75'] shark
# White shark, 4.3 m [14']
# 1.8 m to 2.4 m [6' to 8'] "black finned shark"
# 6 m [20'] shark
# White shark, 4.5 m [14'9"]
# Porbeagle shark, 3 m [10']rk
# Tiger shark, 4 m
# 1.2 m to 1.8 m [4' to 6'] shark
# White shark, 4.9 m [16']
# Tiger shark, 1.8 m to 2.4 m [6' to 8']
# 2.1 to 2.4 m [7' to 8'] shark
# Blacktip shark, 2'
# White shark, 4.3 m [14']
# White shark, 4 m to 5 m [13' to 16.5']
# 100-kg [221-lb] dead blue shark
# White shark, 2.5 m
# 60 cm to 90 cm [2' to 3'] shark
# White shark, 3.5 m [11.5']  male
# Thought to involve a Zambesi shark
# A 2' shark was seen in the area by witnesses
# Thought to involve a 2.7 m [9'], 400-lb bull shark
# Tiger shark, 3.7 m to 4.5 m [12' to 14'9"]
# Blacktip shark, 2.4 m to 3 m [8' to 10']
# Shark involvement  not confirmed
# Nurse shark, 1.5 m [5']
# 1.8 m [6'] grey-colored shark
# Grey reef shark, 2 m [6.75']
# Lemon shark, 2.1  m to 2.4 m [7' to 8']
# Tiger shark, 0.9 m to 1.5 m [3' to 5'] ?
# Nurse shark, 1.2 m [4']
# 0.9 m [3'] shark,  probably a blacktip or spinner shark
# Bull shark, 2.4 m [8']
# Blacktip shark, 1.2 m to 1.8 m [4' to 6']
# Tiger sharks & bull sharks (20 sharks in all)
# Tiger shark, 4 m [13'] ?
# 2 m to 2.5 m [6.75'  to 8.25'] shark
# Shark involvement  questionable
# Shortfin mako shark, 3 m to 3.4 m [10' to 11']
# Miami, a 60 cm blacktip  shark and two 60 cm bamboo catsharks
# Sevengill shark
# Thought to involve a white, bull or tiger shark
# White shark, 3 m [10']
# 1.3 to 1.6 m shark
# Grey reef shark, 1.2 m [4']
# Lemon shark, 2.7 m [9']
# Said to involve a 7 m [23'] white shark
# 2.7 m [9']  bull shark or Caribbean reef shark
# White shark, 3 m to 5 m [10' to 16.5']
# Bull shark, 2.1 m [7']
# Blacktip shark, 1.8 m [6']
# White shark, 4 m [13']
# Tiger shark, 2.5 m [8.25']
# Grey reef shark, 1.5 m
# 3 bull sharks
# Sevengill shark, 2.4 m [8']
# 200 to 300 kg shark
# Mako shark, 1.3 m gaffed
# 3.7 m to 4.6 m [12' to 15'] shark seen in the vicinity
# Bronze whaler or tiger shark
# White shark, 4.6 m [15']
# Possibly a white shark
# A "small shark"
# White shark, 5 m  to 6 m [16.5' to 20']
# Though to involve a white shark
# White shark, 5 m to 6 m [16.5' to 20']
# Dusky shark, 12'
# Caribbean reef shark, 1.2 m to 1.5 m [4' to 5']
# 4.5' to 5' shark
# Sandtiger shark, 2 m, male
# White shark, 4.9 m [16']
# Raggedtooth shark, 1.2 m [4']
# Thought to involve a 5.5 m white shark named Kong
# 3 m to 4 m [10' to 13'] white shark
# Lemon shark, 1.5 m [5'], identified  by the surfer
# 1.8 m [6'] shark, possibly a blacktip
# Nurse shark, 0.9 m [3']
# 5' spinner shark
# 1.7 m shark
# Small dusky shark or blackfin shark
# sandtiger shark
# Shark involvement prior to death suspected but not confirmed
# Tiger shark, 4 m to 4.3 m [13' to 14']
# Possibly a blacktip shark
# Soupfin shark
# small blacktip shark
# Tiger shark, 5.2 m [17']
# Thought to involve an oceanic whitetip shark or a white shark
# "juvenile shark"
# Tiger shark, 2.7m  [9']
# 1.2 m [4'] shark (spinner shark?)
# Possibly a sand shark
# Possibly a Caribbean reef shark
# 3.7m  to 4.2 m white shark
# Tiger shark, 2m to 3m
# 1.8 m to 2.1 m [6' to 7'] shark
# Tiger shark, 4.5 m [14'9"]
# 3 m to 5 m [10' to 16.5'] white shark
# 5.5 m to 6 m [18' to 20'] white shark
# "a young shark"
# Tiger shark, 2.4 m [8']
# 1.8 m to 2.1 m [6' to 7'] hammerhead shark
# said to involve an oceanic whitetip shark
# 2.5 m [8.25'] white shark
# 60 cm to 90 cm [2' to 3'] blacktip or spinner shark
# nurse shark
# "reef shark"
# Nurse shark, 0.9 m  [3']
# Possibly a tiger shark
# Mako shark, 4.3 m [14']
# Tiger shark, 300-kg [662-lb]
# Tiger shark, 2.5 m [8.25']
# 1.2 m to 1.5 m [4' to 5']   shark
# 1.5 to 1.8 m [5' to 6'] shark
# 3 m to 3.7 m [10' to 12'] bull shark
# "sand" shark
# Two 1.2 m to 1.5 m [4' to 5'] sharks
# White shark (tooth fragment recovered)
# Tiger shark, 3.7 m [12']
# Though to involve a tiger shark
# 3.7 m [12'] shark
# Bronze whaler shark, 2 m
# Leopard shark
# 5 m to 5.5 m [16.5' to 18'] white shark
# Raggedtooth shark, 2.7 m [9']
# 2.7 m [9'] shark
# Thought to involve a small sand shark
# Small shark
# 3 to 3.5 m [10' to 11.5'] bull shark
# 1.2 m [4'] spinner shark
# 2.1 m [7'] shark
# >1.8 m [6'] shark
# 3 m [10'], 200-kg [441-lb] bull shark
# 4.9 m white shark
# 3.6 m [11'9"] white shark
# Lemon shark, 4'
# 1.3 m [4'3"] shark
# Tiger shark said to be 5 to 7 m [16.5' to 23']
# On 11-Jan-1994, his remains washed ashore. A 2.4 m [8'] tiger shark thought to be involved
# Tiger shark caught 6 days later with divers remains in its gut
# >6 m [20'] white shark
# 3.7 m [12'] white shark
# 1.8 m [6'] blacktip shark or Caribbean reef shark
# >6 m white shark, according to witnesses
# 5.5 m to 6 m [18' to 20']  white shark
# 1.8 m to 2.4 m [6' to 8'] shark, tooth fragments recovered
# Thought to involve a tiger shark
# Remains recovered from 5.5 m [18'] white shark
# Possiby white shark
# Tiger shark, 3.7 m [12'], (tooth fragment recovered from wound)
# Two 3 m [10'] oceanic whitetip sharks
# Tiger shark, 3 m to 4.9 m [10' to 16']
# Mako shark, 1.8 m [6']
# 6' to 7' blacktip shark
# 5 m to 6 m white shark
# 3 m hammerhead shark
# Unidentified shark
# Tiger shark, 3 m to 3.7 m [10' to 12']
# Tiger shark, 4.3 m [14']
# 4.2 m white shark
# 4 m to 5 m [13' to 16.5']  white shark
# Questionable incident
# Nurse shark, 3', 20-lb
# Bull shark or lemon shark
# White shark, identification by K. Nakaya
# Tiger shark, 3 m to 4 m [10' to 13']
# 4 m [13'], 590-kg white shark
# >2 m shark
# Bronze whaler shark, 3 m
# 5 m [16.5'] white shark, identification by K. Nakaya
# Said to involve a 6 m to 7 m [20' to 23'] white shark
# 5 m [16.5'] shark
# 1.8 m grey shark
# Bronze whaler shark, 2.3 m [7.5']
# Zambesi shark, 1.7 m [5.5']
# Possibly a 1.5 m [5'] blacktip shark
# Tiger shark, 2.4 m 3.4 m [8' to 11']
# 5 m to 6 m [16.5' to 20'] white shark
# 3 m [10'], 270- kg [595-lb] shark
# sand shark
# Lemon shark, 30-lb
# 2.1 m [7'], 140-lb reef shark
# Tiger shark, 3 to 4 m [10' to 13']
# 2.7 m [9'] bull or lemon shark
# Tiger shark, >3 m [10']
# 3.5 m [11.5'] female white shark named "Notchfin"
# 170-kg, 2.8 m shark
# 7' female shark
# "Shark had a very large girth"
# Grey nurse shark, 2 m
# 1.8 m [6'] shark
# 4' spinner shark
# 1.8 m to 2.4 m [6' to 8'] shark
# 5 m  [16.5'] white shark
# 2.5 m to 3 m [8.25' to 10']  white shark
# Shark involvement prior to death could not be determined
# 4.5 m [14'9"] white shark
# 6 m, 600-kg shark
# 2 m hammerhead
# 5.5 m [18'] white shark, identified by witnesses & tooth marks
# 2.3 m [7.5'] white shark, identified by M. Smale
# Two sharks seen in vicinity: 2.4 m & 4.25 m  [8' & 14'] TL
# Tiger shark, 2m
# 2 m shark, possibly a bronze whaler
# 2.7 m [9'] white shark
# Shark involvement suspected but not confirmed
# White shark, identified by tooth pattern
# 150-lb shark
# 4 to 5 m white shark
# 4 m to 5 m [13' to 16.5']  white shark
# Sandbar shark
# Blue Shark
# >3.4 m [11'] white shark
# Bronze whaler shark, 3 m [10']
# 1.8 m [6'] sandtiger shark
# 5 m to 7 m white shark
# Tiger shark, 3.5 m
# 3 m [10'] gaffed shark
# 1.8 m to 2.4 m [6' to 8'] hammerhead shark
# Tiger shark, 4 m [13']
# 7' silvertip shark
# 16' white shark
# 2.4 m to 3 m [8' to 10'] white shark
# 2 m to 2.5 m shark
# 1.5 m [5'] Caribbean reef shark
# Sand shark?
# 1.5 m to 2 m [5' to 6.75'] shark
# Raggedtooth shark, 2 m
# 1 m "grey-colored" shark
# Zambezi shark (tooth fragments recovered)
# Mako shark, 3 m [10'], 200-kg [441-lb]
# 1.5 m copper shark
# 6 m shark
# 40 to 50 sharks attacked survivors in the water
# 3.5 m [11.5']  white shark
# 5.7 m white shark
# 1.5 m [5'] blacktip shark
# 4.3 m shark
# Bronze whaler shark, 2 m to 3 m
# >2.5 m [8.25'] white shark
# Doubtful / Unconfirmed attack / Unable to verify in local records
# Raggedtooth shark, 2.5 m [8.25']
# 1.8 m to 2.1 m [6' to 7'] spinner or blacktip shark
# Raggedtooth shark, 1.96 m, 140-kg
# Lemon shark, 1.8 m to 2.4 m [6' to 8'], tooth fragment recovered
# 1.6 m shark
# Tooth fragment of a white shark recovered. Authorities believed shark was 6 m [20']  total length
# 1.2 m [4'] dusky shark
# >1 m shark
# >2.4 m [8'] white shark
# Raggedtooth shark, 2 m [6.75']
# Bronze whaler shark, 3.5 m
# 5.2 to 5.8 m white shark
# 2 m to 2.5 m [6.75'  to 8.25'] sixgill or sevengill shark
# Thought to involve a Tiger shark,  3.7 m [12']
# 6', 100-lb shark
# 1.8 m silky shark
# Possibly a small hammerhead shark
# Tiger shark, 2.4 m to 2.7 m [8' to 9']
# 3 m to 3.6 m  [10' to 11'9"] white shark
# 30-kg [66-lb] shark
# 3.5 m white shark, tooth fragments recovered
# 1.5 m [5'] dusky shark
# Shark involvement not confirmed; officials considered barracua
# Hammerhead shark?+O2356
# small blue shark
# 4.5 m to 5 m white shark
# 4.5 m to 5.5m white shark
# Raggedtooth shark
# 2.4 m [8'] white shark
# 1.2 m to 1.5 m [4' to 5'] hammerhead shark
# 2.5 m [8.25'] shark
# Raggedtooth shark, 56-kg [123-lb]
#  1.5 m [5'] dusky shark
# 1.5 m white-tipped reef shark
# Raggedtooth shark, 1 m
# 12' white shark
# Raggedtooth shark, >1 m
# .5 m shark
# 4.5' shark
# 6' to 8' bull shark
# Tiger shark, 5 m [16.5']
# 3 m to 4 m [10' to 13'] shark
# 3.5' hammerhead shark
# 6' blacktip shark
# Raggedtooth shark, 1.5 m [5'] (tooth fragment recovered)
# 1.8 m [6'] Zambezi shark
# Blue sharks
# Believed to involve a 2.8 m [9'3"] white shark
# Questionable incident; reported as shark attack but thought to involve a pinniped instead
# 2.1 m [7'] shark, possibly a spinner shark
# 2.4 m [8'] white shark, species identity confirmed by tooth fragment
# 4.5 m to 5.5 m [14.7' to 18'] white shark
# Reported as a shark attack, the story was a hoax
# 2.4 m [8'] white shark, species identity confirmed by witnesses & tooth pattern in surfboard
# Lemon shark, 2 m [6'9"]
# 1.2 m to 1.5 m [4' to 5'] "reef shark"
# 5.5 m [18''] white shark
# 7 m [23'] white shark
# Tiger shark, 3.7 m [12']
# 3.5 m [11.5'], 510-kg [1125-lb] hooked & shot white shark
# 2.1 m [7'] shark with "a very flat head that had followed the boat for 3 days
# Said to involve a tiger shark or a hammerhead shark
# 1.8 m [6'] shark, species identity questionable
# Shark involvement prior to death remains unconfirmed
# Mako shark (tooth fragments recovered)
# "sandshark"
# Possibly a  1.8 m [6'] Zambezi shark
# "gray shark"
# 13', 400-lb thresher shark
# 6 m  white shark
# Tiger shark, 2.1 m [7']
# 1.2 m to 1.5 m [4' to 5'] bull, sandbar or dusky shark
# C. maculpinnis or C. limbatus
# Juvenile dusky or blacktip shark
# 1 m hammerhead shark
# Tiger shark, 2.5 m
# 3.5 m [11.5'] shark
# 1.8 m [6'] white shark
# 4' to 8' shark
# 1.5 m [5'] hammerhead shark
# 2.8 m [9'3"] white shark
# 2.2 m shark
# 2 m [6'9"] Zambesi shark
# Raggedtooth shark, 2 m [6'9"]
# 1.8 m [6'] dogfish
# Said to involve a white shark but shark involvement not confirmed
# White shark, 5 m
# Raggedtooth shark, 50-kg [110-lb], 2 m [6.75'] gaffed
# White shark, 2.5 m [8.25']
# White shark, 2.3 m [7.5'], tooth fragment recovered
# White shark, 3.7 m [12']
# 2 m [6'9"] shark
# Sevengill shark, 2.4 m
# 270 kg shark
# Thought to involve a blacktip shark
# 3 m [10'] white shark (Tooth  recovered from boat)
# 1.5 to 2 m [5' to 6.75'] shark
# White shark, 5.5 m to 6 m [18' to 20']
# Bull shark, 8
# Mako shark, 2.3 m, 150-kg
# White shark, 5.5 m [18']
# White shark, 3 m [10'] k
# 2.1 m [7'] lemon shark or bull shark
# White shark, 4.8 m
# White shark, 3 m to 4 m [10' to 13']
# White shark, 3.5 m [11.5'], species identity confirmed by tooth fragment
# 2.7 m  [9'] shark
# Tiger shark, 6'
# White shark, 4.5 m
# Blue shark, 2m
# Mako shark, 180-kg [397-lb]
# Whale shark
# White shark named Spotty
# Grey nurse shark, 10'
# Juvenile dusky shark
# Shark involvement unconfirmed
# White shark, 2.4 m [8']
# White shark, 5.8 m [19']
# White shark, 5m to 6m
# 2.4 m [8'] whaler shark
# White shark, 600-kg [1323-lb]
# 1.5 m [5']  shark
# Mako shark, 3 m [10']
# Carpet shark, 10'
# Copper shark, 50-kg [110-b]
# 8' blue shark
# White shark, 5.5 m to 6 m [18' to 20']
# White shark, 4 m to 5 m
# Shortfin mako shark, 2.3 m [7.5']
# White shark, 5 m to 6 m [16.5 to 20']
# small sharks'
# 3.7 m [12'] sharks
# White shark, 5 m [16.5']
# Raggedtooth shark, 1.5 m [5']
# Bronze whaler shark, 4'
# 7' to 8' bull shark
# 1.5 m to 1.8 m [5' to 6']  blacktip shark
# 2 m shark, possibly a dusky or blacktip shark
# 1.2 m to 1.8 m [4' to 6'] shark observed in area
# White shark, > 3 m [10']
# Bronze whaler shark, 10'
# Oceanic whitetip shark x 2
# White shark, 6 m [20']
# White shark, 4.4 m to 5 m [14.5' to 16.5']
# 1.5 m grey reef shark
# White shark, 2.5 m [8.25']
# 1.8 m [6'] grey reef shark
# White shark, 3 m [10']rk
# 1.5 m to 2 m shark
# White shark, 5 m to 6 m [16.5' to 20']
# Grey nurse shark, 11'
# White shark, 3 m [10'], species identity confirmed by witnesses & tooth pattern in leg & board
# 3.6 m  porbeagle shark
# White shark according to tooth pattern and witnesses
# 1.8 to 2 m C. albimarginatus
# "Dog shark"
# 7.5' shark
# Raggedtooth shark, 2 m [6'9"], 5-year-old, captive female
# Wobbegong shark
# Carpet shark
# >2.4 m [8'] shark
# White shark, 4.3 m 4.9 m [14' to 16']
# Considered a "Doubtful" incident
# Lemon shark, 9'
# White shark, identified by tooth fragments in surfboard
# 2 scalloped hammerhead sharks, 1.5 m & 1.8 m [5' & 6']
# 90-kg "blackfin" shark
# White shark, 4.3 m [14'], (tooth fragment recovered)
# a small hammerhead shark
# 4m [13'] shark
# Not authenticated
# 1.5 m to 2 m [5' to 6.75'] Caribbean reef shark
# 2.7 m [9'] silky shark
# Bronze whaler shark, 1.8 m [6']
# "Blue whaler" (Galeolamna)
# 1.5 m to 1.8m [5' to 6'] shark
# 5' blue shark
# Nurse shark, 106 cm, 28-lb, male
# 1.5 m to 1.8 m [5' to 6'] sandbar shark
# Nurse shark, 1 m
# White shark, 4 to 5 m [13' to 16.5']
# White shark or thresher shark
# 2.1 m [7'] sandtiger shark
# Grey nurse shark, 1.5 m [5']
# Grey nurse shark, 1.5 m [5']
# Bronze whaler shark, 2.1 m [7'], a tooth was embedded in the speargun
# Mako shark, 1.9 m [6.5']
# Nurse shark, 2.5'
# A pack of 6 sharks
# 1.5 m to 2.1 m  [5' to 7'] shark
# Spinner or blacktip sharks
# Lemon shark or sandtiger shark
# Local authorities speculated that the water was too cold for sharks, but a 2.1 m [7'], 200-lb pregnant sandbar shark was caught next day
# 1.2 m [4'] hammerhead shark
# Believed white shark and other smaller species of sharks involved.
# Alleged to involve a White shark, 7.6 m [25']
# White shark, 2.5 m [8.25'], an immature female, previously injured
# Copper shark
# Wobbegong shark, 5'
# 1.5 m to 1.8 m [5' to 6'] Zambesi shark
# 76 cm [2.5'] carpet shark
# 1.8 m to 2 m [6' to 6'9"] shark
# 1.8 m [6'] carpet shark
# 4.6 m [15'] shark
# Grey nurse shark, 2.4 m [8']
# 1.8 m [6'], 180-lb shark
# 2 sharks involved
# 300-kg [662-lb] shark
# Lemon shark, 0.5 m
# Tiger shark, tooth fragment recovered
# 1.8 m [6'], 136-kg [300-lb] shark
# 4.9 m [16'] whaler
# Nurse shark, 0.94 m to 1.2 m [3' to 4']
# Small shark with white-tipped dorsal fin
# 1.5 m to 2.1 m [5' to 7'] shark, possibly a mako shark
# White shark, 2.4 m [8']
# White shark, 2.7 m [9'1"], 750-lb
# Grey nurse shark, 1.8 m [6']
# 1.8 to 2.4 m [6' to 8'] shark
# Less than 1.2 m [4']
# white shark
# Lemon shark
# 1.7 m [5.5'] shark
# Tiger shark, 3.5 m, 250-lb female
# White shark, 1.5 m [5'] k
# White shark, 3 m to 3.7 m [10' to 12']
# White shark, 3.6 m [11'9"]
# Wobbegong
# 2.1 m to 2.4 m  [7' to 8'] shark
# Zambesi shark, 1.8 m [6']
# 1.8 m [6']  shark
# 4.3 m [14'], 1000-lb shark
# Dusky shark, 1 m
# Wobbegong shark, 3'
# White shark, 1.7 m [5.5']
# 300- to 400-lb Zambesi shark
# Possibly a broadnose 7-gill shark
# >1.2 m [4'] tiger shark
# White shark, 15'2"
# Silky shark, 1.9 m [6.5']
# Dooley believed his Injury was caused by stingray (Dasyatidae family)
# 500-lb shark
# White shark, 4 m [13'] rk
# 5.5 m [18'] shark
# 8 sharks
# White shark, 3 m
# Hand found in gut of 2.9 m to 3.3 m [9'7" to 10'11"] Galapagos shark, C. galapagensis
# 1.8 m to 2.4 m  [6' to 8'] shark
# 3.7 to 4.5 m [12' to 15'] shark seen in vicinity
# White shark, 2.1 m [7']
# Tooth fragments of whaler shark were recovered, a bull shark, according to Edwards
# 193-lb shark
# Grey nurse shark, 1.8 m [6']
# <1.5 m shark
# Zambesi shark, 2 m [6'9"]
# White shark, 16', 2,312-lb
# White shark, 4.3 m [14'] (or bronze whaler)
# 2 m [6'9"], 87.5-kg [193-lb]  shark
# White shark, 4.3 m to 4.9m [14' to 16']
# 3 m [10'] blue whaler
#  Blacktip shark, C. maculipinnis. 1.9 m to 2.1 m [6.5' to 7']
# "A long thin brown-colored shark"
# Horn shar,k Heterodontus francisci, 1.2 m [4']
# 4.3 m [14'] shark
# Unknown
# 2.7 m to 3 m [9' to 10'] sharks
# Possibly a bronze whaler shark
#  Sevengill  shark, 1.2 m [4']
# Bronze whaler shark, 3.7 m [12']
# Zambesi shark, 1.2 m [4']
# 4.9 m [16']shark
# Bronze whaler shark, 4.6 m [15']
# 1.2 m  [4'] shark
# 60 cm  shark
# Bronze whaler shark,  3m [10']
# Said to involve a 4.9 m [16'] "red shark"
#  Grey nurse shark,  3 m [10']
# Bronze whaler shark, 2.1 m [7'] shark
# Said to involve a Grey nurse shark 3.7 m [12']
# 36"  shark
# Next morning a 3 m [10'] shark was caught that had Andrews' leg in its gut
# Two shark's teeth recovered from canoe
# Oceanic whitetip shar,; identified by Dr. W.C. Schoeder on photograph & Dr. L.P. L. Schultz on sketch by observer
# 1.5 m to 1.8 m  [5' to 6'] shark
# Blacktip shark, 1.8 m to 2.1 m [6' to 7']
# 43" shark
# White shark, 5.2 m [17'], 2500-lb
# 2.7 m [9']shark
# Hammerhead shark, 500-llb
# Wobbegong shark, 1.4 m [4'6"]
# 2 m  "yellow belly" captive shark. Shark destroyed by aquarium staff next day
# Wobbegong shark, O. barbatus,  1.8 m [6'], identified by G.P. Whitley
#  "gummy" shark (Rhizoprionodon or Loxodon) 1.2 m [4']
# Grey nurse shark, 2,7 m [9'], 200-lb
# Wobbegong shark, 1.4 m [4.6']
# Bronze whaler shark, 2.4 m [8'] Identified by Clyde Buttery
# Grey reef shark, 1.8 m [6'] grey reef shark, identified by Dr. L.P. L. Schultz based on photographs; identified as C. melanopterus by Stewart
# Zambesi shark, 4'9"
# 2' "banjo shark"
# 2.1 m [7'], 90-kg shark
# Grey nurse shark, 2.7 m [9']
# Wobbegong shark, 1.5 m [5']
# White shark, based on bite pattern
# Hammerhead shark, 1.8 m [6']
# Six Zambesi sharks seen to 1.5 m [5'] in length
# > 3 m shark
# White shark, 3 m [10'], tooth fragment from wounds identified as that of a white shark
# Grey nurse shark, 1m
# Bull shark, 1m
# Wobbegong shark, 1.8 m [6']
# White shark (tooth fragments recovered from hull of boat)
# 1.4 m [4'6"] blacktip shark
# White shark, 3.7 m to 4.6 m [12' to 15']
# White shark, 18 mm tooth fragment  recovered from the hull
# 2.4 m [8'], 600-lb shark
# Lemon shark, 1164 mm, immature male, identified by  V.G. Springer
# 80-lb hooked shark
# Mako shark, 1.8 m to 2.1 m [6' to 7']  with hook & wire leader caught in mouth
# Dusky shark, 2.7 m [9'] dusky shark C. obscurus identified by S. Springer on tooth recovered
# Lemon shark, 1.8 m [6'] male, N. breviostris, identified by W.A. Stark II, later the same day a 6'8" pregnant female lemon shark bit the bow of the boat
# White shark, 2.1 m [7']  based on tooth pattern
# Bronze whaler shark, 3 m [10'], 200-lb
# Raggedtooth shark, 100-lb
# Bronze whaler shark, 3.7 m [12'] identified by G.P. Whitley based on description
# White shark (tooth fragments recovered)
# 1.2 m [4'], possibly  larger shark
# Two 2.1 m [7'] sharks
# Bronze whaler shark,4 m [13']
# According to Benjamin, the injury was inflicted by a barracuda, not a shark
# Tiger shark, 3.4 m [11'] captured
# Grey nurse shark, 2.9 m [9'6"]
# Shark involvement prior to deaths was not confirmed
# 3.5 m [11'6"] shark captured
# Blue pointer
# 4.9 m [16'] shark
# 3.7 m to 4.6 m [12' to 15'] shark
# Blacktail reef shark
# Blacktip reef shark
# 3.7 m [12'] tiger shark
# 2.4 m  [8'] shark
# 2.7 m [9']  shark
# 3 m to 4.3 m [10' to 14'] shark
# Thresher shark, 3.7 m [12']
# Blue shark, 1.5 m [5']
# Carpet shark, 1.5 m [5']
# White shark, 5 m [16.5'], identified by Dr. W. I. Follett on tooth marks
# A hammerhead shark, then 8 to 10 other sharks were said to be  involved
# Said to involve white shark, but species identify questionable
# White shark, 3.5 m [11.5'], identified by W. I.  Follett on tooth fragments
# White shark, based on 2 teeth retrieved from rudder
# 5.5' shark
# Hammerhead shark, 9'
# 20 kg shark
# Blue shark, 3 m [10']
# White shark, 3 m to 5 m [10' to 15']
# Hammerhead shark, 1.8 m [6'] S. zygena identified by C. Limbaugh on description
# Blue shark?
# Hammerhead shark, 2.4 m [8']
# Hammerhead shark, 3 m [10']
# Blue shark, 1.8 m [6']
# Nurse shark, 60 cm [24"], identified by Dr. L.P. L. Schultz on photograph
# Oceanic whitetip shark,1.8 m [6']
# Reported to involve a White shark, 6 m to 7m [20' to 23']
# White shark, 2.7 m [9'], 280-lb
# White shark, 3 m [10']; identifed by Dr. W.I. Follett on tooth marks
# Tiger shark 4.3 m [14']
# Mako shark, 2.4 m [8'], <300-lb, identified by Dr. L.P. L. Schultz on photograph
# 1.8 to 2.1 m [6' to 7'] shark
# Bitten by several 1.8 m [6'] sharks
# Said to involve 2 sharks: 5.2 m & 6 m [17' & 20']
# White shark, 1.8 m to 2.1 m [6' to 7']  according to Shreuder and a witness
# 1.4 m [4.5'] shark
# 1.5 m to 1.8 m [5' to 6'] sharks
# Tiger shark, 12' ?
# Tiger shark, 4.6 m to 7.6 m [15' to 25']
# 200-lb shark
# Hammerhead shark, 5.2 m [17']
# Tiger shark, 1.5 m to 1.8 m [5' to 6']
# Sharks averaged 1.8 m [6'] in length
# Nurse shark, 1.5 m [5']  identified by Dr. E. Clark on description of shark
# Tiger shark, <2 m TL
# Nurse shark, 2.1 m [7']  identified by Dr. E. Clark on color & tooth impressions
# Nurse shark, 1.1 m [3.5']
# Mako shark, 100-kg [221-lb]
# <1 m shark
# Several sharks involved
# >3 m [10'] shark
# Identified as carcharinid shark (based on its behavior) by Dr. D.P. L. Schultz; mako shark according to Huges
# 2.7 m [9'] bull shark, identified by Capt. W. Gray
# Said to involve a 1 m  white shark, but thought  that it was more likely a blue shark
# Shark seen feeding on turtle scraps thrown overboard prior to incident.
# Said to involve a large mako shark
# 3.7 m [12'] shark
# 2.4 m [8'] tiger shark caught 40 hours later with shorts of the boy in its gut
# Mako shark, 125-lb
# White shark, according to witnesses
# a sand shark
# White shark, 13'10", 1320-lb female
# Wobbegong shark, 4'
# Porbeagle or white shark
# 2.3 m [7'] shark
# 8-lb shark
# 3.7 m [12'] shark & may have been another shark nearby
# 40-lb sand shark
# Survivors said 2 species of sharks were involved:  oceanic whitetip sharks and another species
# Survivors said 2 species of sharks were involved:  oceanic whitetip sharks and another species,
# 5' thresher or blue shark. The shark  was killed following the incident
# Tooth fragments recovered from hull
# 0.7 m [2.5'] sand shark
# White shark, 6.5 m
# 2.4 m [8']  shark
# "small brown-colored shark"
# Leopard shark, 3' Triakis semifasciata, identified by J.W. DeWitt (1955)
# White shark, 5 m to 6 m [16.5' to 20]
# 3.6 m  white shark  (or bronze whaler)
# 4 m [13'] shark x 6
# Bronze whaler shark,3.7 m [12']
# "a little shark"
# Blacktip reef shark, 1.5 m [5']
# 20' shark
# Nurse shark, 58", 34-lb
# 5m shark
# 2.4 m [8'] shark, possibly a dusky shark
# White shark tooth fragment recovered from ankle & identified by Dr. W. I. Follett
# Bull shark suspected due to freshwater habitat
# Nurse shark, 1.8 m [6']
# a small shark'
# Said to involve a >4 m [13'] shark
# 3.7 [12'] shark
# 80-lb sand shark
# Hammerhead shark, 1.5 m [5']
# 3 m [10'] shark seen in vicinity
# White shark, 3.7 m [12'], 500 to 500-kg [1,200 lb], identified by W. C. Shroeder based on tooth fragment ebedded in gunwale
# 2 m [6'9"] shark
# 1.5 m [5'] shark, probable bull shark
# White shark,4.6 m [15']
# >6.7 m [22']  shark
# Hammerhead shark, 5'
# Tiger shark, 1.5 m [5']
# White shark, 2 m to 4 m [6'9" to 13']
# Carpet shark, 5'
# "A 2' (0.6 m) brown shark"
# White shark, 15'3", 2,333-lb
# a "small slim brown shark"
# Bull shark, 2.7 m [9'] was captured & dragged on the sand where tissue taken from Eggink was found in its gut. Species identification  was made by S. Springer based on 4 photographs of the shark.
# "Attacked by a number of sharks"
# White shark, 1.8 m [6']
# Wobbegong shark, 4'
# 136-kg [300-lb] shark
# Nurse shark, 10'
# Wobbegong shark, 6'
# White shark, 3m, seen in area and hooked 3 days later
# 1,100-lb shark
# 17' white shark
# 0.7 m [2.5'] shark
# unknown, possibly a white shark
# 2.13 m shark
# 1.5 m to 1.8 m [5' to 6'] spear-eye shark
# small carpet shark
# White shark, 3.7 m [12']  according to witnesses
# White shark, 3.6 m,  420 kg male
# Possibly a lemon shark
# Whtietip reef shark
# Tiger shark, 3.7 m to 4.3 m  [12' to 14']
# Alleged to involve a white shark "with little yellow eyes"
# 2.7 m [9'] shark with black-tipped pectoral fins
# Grey nurse shark, 2.6 m [8.5']
# Bonita sharkk, 200-lb
# Whaler shark, 2.7 m [9'], 350- to 450-lb  identified by G.P. Whitley
# 3.3 m [10'9"] shark
# His hand was found in a 2.4 m [8'] tiger shark caught 1/5/1949
# Said to be 6.4 m [21'] shark
# "grey shark"
# Possibly C. leucas
# Most likely, a small shark
# 1.5 m, 45-kg shark
# Blacktip shark, 2 m [6.75']
# 4.5  m [14'9"] shark
# >1.6 m shark
# 6 m [20']  shark
# White shark, 4.2 m [13'9"]
# Tiger shark, 4.5 to 5.5 m [14'9" to 18'], 2000-lb
# 1.8 m [6'] blacktip shark or spinner shark
# Bull sharks to 1.5 m [5']  in length
# Shark involvement prior to death unconfirmed
# White shark, 2 m [6'9"]  (Tooth fragment recovered from victim's shoulder & identified by J.T. Nicholls)
# White shark, 3.9 m, 550 kg, male
# 1.8 m to 2.4 m [6' to 8'] sharks, most were oceanic whitetip sharks
# White shark, 4.5 m  to 6 m [14'9" to 20'] according to witnesses
# Tiger shark & others
# Porbeagle shark
# Bull shark, 4 m [13']
# Said to involve a 6.5 m [21.5'] shark
# Said to be leopard sharks, more probably tiger sharks
# Reportedly: oceanic whitetip sharks, blue sharks, tiger sharks & bull sharks
# 100-lb shark
# Mako shark (aka bonito shark) 1.2 m [4']
# White shark, species identity confirmed by tooth pattern
# White shark, 160-kg [353-lb], identity confirmed by tooth pattern
#  White shark
# Questionable incident, said to involve a 6' shark
# 2.6 m [8.5'] shark landed 2 hours later
# Blue pointer, 16'
# whaler shark
# Tiger shark, 4.3 m [14'], 3 tooth fragments retrieved from his wounds
# Nurse shark, 2.1 m [7']
# 18' shark
# "a large shark"
# Thought to involve bull sharks
#  Tiger shark, 3'
# "grey-colored shark"
# Tiger shark,  3.6 m [11'9"], 850-kg [1874-lb] female, contained Girvan's remains
# 2.6 m [8.5'] shark
# Tiger shark, 9' to 10'
# Whaler shark, 4 m [13']
# 2 days later a 600-lb shark was caught 100 yards from the site
# 3' "blue nosed" shark
# Grey nurse shark, 8'
# Thought to involve a 12' white shark
# 0.9 m [3']  shark
# Large tiger shark seen in the vicinity the following morning
# Shovelnose shark, 6 m [20']
# White shark (identified by Dr. Hugh Smith)
# Blue shark, 8' [2.4 m], 500-lb
# Tiger shark, 4.6 m [15']
# 650-lb shark
# White shark, 246-kg
# Tiger shark 3 m  [10']
# "Blue nose shark"
# White shark, 3.5 m to 4 m [11.5' to 13']
# Tiger shark, 12'
# 2 sharks
# Blue pointer, 11'
# A 6.5' "blue-nosed shark"
# 4.3 m [14'] shark seen in vicinity
# 4 m [13'] shark seen in vicinity
# Mako shark, 3.7 m [12'] identified by tooth fragments by G.P. Whitley
# 3.4 m [11']  tiger shark & a 5' shark
# 4.3 m [14'] shark seen in area previous week
# Tiger shark, 3.4 m [11']
# 3 sharks
# Blue shark, 4.5 m [14'9"]
# Thought to involve a 2.4 m [8'] lemon shark; two 2.4 m lemon sharks caught within 100 yds of the site a week prior to & a week after this incident
# 7' to 8' shark
# 4.4 m [14'] shark
# Thought to involve a mako or grey nurse shark
# 16' 800-lb shark
# Teeth in hull identified as those from a white shark 4.6 m [15'] in length
# 250-lb "dog shark"
# Raggedtooth shark, 1.2 m to 1.5 m [4' to 5']
# Hammerhead shark, 2.4 m [8'], according to lifeguard Sam Barrows
# "a school of sharks"
# 1.8 m [6'] "cocktail shark
# 7 shark's teeth found embedded in the woodwork of the boat
# White shark 4.9 m [16']
# White shark, 4.5 m [14'9"], identity confirmed by witness & tooth pattern
# 9-foot shark
# Grey nurse shark, 4'
# "a dog shark"
# Blue pointer, 12'
# "Blue nose sharks"
# Morenos leg  & part of his swim suit found in 9' shark caught two hours after the attack. Identified as carcharhinid shark by L. Schultz & C. Limbaugh on photograph
# Species unknown, possibly a white shark
# White shark, 4.4 m [14.5'] .
# Grey nurse shark?
# Grey nurse shark, 4'
# Said to involve 6 to 7 m [20' to 23'] white shark
# "whiptail shark" (thresher shark?)
# 1.5 m [5'] white shark or sevengill shark
# Questionable, 2m shark suspected
# White shark, 3.8 m [12.5']
# According to Carlsmith, the shark's mouth was 3' wide
# White shark, 3.7 m [12']
# "a blue shark"
# Tiger shark, 4 m [13'] female
# Said to be a small shark
# Mako shark, 1.9 m [6.5']. Tooth fragment recovered & identified by J.T. Nichols.
# "a very large shark"
# Atkins' remains were recovered from a dusky shark, C. obscurus, by Capt. W. F. Young, shark fisherman
# 2.7 m [9'] "blue" shark
# "A pack of 6 sharks"
# White shark, 12', identity confirmed by tooth fragment, witness and photograph of captured shark
# 2.7 m [9'] shark later captured by Mitchell-Hedges
# Blue shark, 4'
# Comrades saw shark's tail appear about 5' away
# 15* to 24" dog shark
# 15'
# 3.7 m [12'], 1200-lb shark. Shark caught & its jaw exhibited at the Carnegie Museum
# 3.7 m to 4.3 m [12' to 14']  shark
# 13' shark
# Tiger sharks, 2.4 m to 4.9 m [8' to 16']
# Said to involve a 2.7 m [9'] shark
# Thought to involve a 2.6 m [8.5'] white shark
# Reported to involve a 3.7 m [12'] shark, possibly a white shark
# A 20' shark known as "Old Tom"
# said to involve a tiger shark
# Said to involve a 2.4 m [8'] hammerhead shark
# Tiger shark
# 2.8 m [9'3"] whaler shark captured 3 days later with his remains in its gut
# C. macrurus captured 48 hours after attack with tissue removed from man in its gut; species identified by G.P. Whitley,  reported as C. obscurus by  R. Steel
# Said to involve  9' blue shark
# 5.5' to 6' shark
# 18-foot shark
# Remains recovered from 3 sharks
# Species unknown, possible white shark
# Allegedly a 33-foot shark
# Shark involvement probable
# White shark, 6 m
# Shortfin mako shark, 175-lb
# Remains recovered 5 days later
# Fishermen recovered partial remains from shark a week later
# 1.8 m to 2.7 m [6' to 9'] shark
# Tiger shark, 3.9 m
# 70 kg shark
# 13'10" shark
# Shovelnose shark, 5'
# 16' shark
# 5'7" shark
# Sevengill shark, 14', was caught in the vicinity
# 5m, 3500 kg female shark
# Unknown, but the shark was caught and put on exhibition
# 4.7 m [15.5'] shark
# Shark was said to have a very rough ½-thick skin
# 3 m [10'] sharks
# Said to involve 2 sharks
# a school of sharks
#  a small shark
# Blue or porbeagle shark
# 68" shark
# Wobbegongs
# Identified as C. gangeticus by Dr. J. Fayrer
# "Shark caught later"
# 4' "ground shark"
# Remains recovered from shark caught days later
# Shark involvement prior to deaths unconfirmed
# Tiger shark (pregnant)
# 234-lb shark
# Said to involve a 6 m to 7.3 m [20' to 24'] shark
# Said to be a 7.6 m [25'] shark
# Thought to involve a porbeagle or mako shark
# Description of shark does not ring true
# "The fish was harpooned, dried, and presented to the sailor, who went round Europe exhibiting it  It was said to be 20 feet long.
# White shark, 1600-lb female
# Possibly white sharks
#  Galapagos shark, 6'
# said to involve 2.5 m hammerhead sharks
# Silvertip shark
# A large hammerhead shark
# Nurse shark, 2.1 m [7']
# Shovelnose guitarfish, adult male
# "A pack of sharks"
# White shark, 7' to 8'
# White shark, 1,900-lb
# Bull shark caught, leg recovered & buried beside the man's body
# "a black-tipped shark"
# 12' tiger shark
# Blue pointers
# Said to involve a grey nurse shark that leapt out of the water and  seized the boy but species identification is questionable

# %% [markdown]
# # limpieza investigator or source

# %%
shark_clean['Investigator or Source']=shark_clean['Investigator or Source'].fillna('Unknown')
shark_clean
# Out:
#      Case Number       Date  Year        Type    Country             Area  \
# 0     2018.06.25 2018-06-25  2018     Boating        USA       California
# 1     2018.06.18 2018-06-18  2018  Unprovoked        USA          Georgia
# 2     2018.06.09 2018-06-09  2018     Unknown        USA           Hawaii
# 3     2018.06.08 2018-06-08  2018  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04 2018-06-04  2018    Provoked     MEXICO           Colima
# ...          ...        ...   ...         ...        ...              ...
# 6309           0        NaT  1926     Unknown    Unknown          Unknown
# 6310           0        NaT  1926     Unknown    Unknown          Unknown
# 6311           0        NaT  1926     Unknown    Unknown          Unknown
# 6312  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
# 6313  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
#
#                             Location  Activity             Name     Sex  ...  \
# 0        Oceanside, San Diego County  Paddling      Julie Wolfe  Female  ...
# 1     St. Simon Island, Glynn County   Unknown  Adyson McNeely   Female  ...
# 2                       Habush, Oahu   Surfing      John Denges    Male  ...
# 3                 Arrawarra Headland   Surfing          Unknown    Male  ...
# 4                           La Ticla   Unknown   Gustavo Ramos     Male  ...
# ...                              ...       ...              ...     ...  ...
# 6309                         Unknown   Unknown          Unknown      ND  ...
# 6310                         Unknown   Unknown          Unknown      ND  ...
# 6311                         Unknown   Unknown          Unknown      ND  ...
# 6312                         Unknown   Unknown          Unknown      ND  ...
# 6313                         Unknown   Unknown          Unknown      ND  ...
#
#                Time          Investigator or Source original order  \
# 0             18h00                R. Collier, GSAF         6303.0
# 1     14h00  -15h00  K.McMurray, TrackingSharks.com         6302.0
# 2             07h45  K.McMurray, TrackingSharks.com         6301.0
# 3               NaN                  B. Myatt, GSAF         6300.0
# 4               NaN                       A .Kipper         6299.0
# ...             ...                             ...            ...
# 6309            NaN                         Unknown         6309.0
# 6310            NaN                         Unknown         6310.0
# 6311            NaN                         Unknown            NaN
# 6312            NaN                         Unknown            NaN
# 6313            NaN                         Unknown            NaN
#
#      Case Number.1 Case Number.2                       pdf  \
# 0       2018.06.25    2018.06.25      2018.06.25-Wolfe.pdf
# 1       2018.06.18    2018.06.18    2018.06.18-McNeely.pdf
# 2       2018.06.09    2018.06.09     2018.06.09-Denges.pdf
# 3       2018.06.08    2018.06.08  2018.06.08-Arrawarra.pdf
# 4       2018.06.04    2018.06.04      2018.06.04-Ramos.pdf
# ...            ...           ...                       ...
# 6309           NaN           NaN                       NaN
# 6310           NaN           NaN                       NaN
# 6311           NaN           NaN                       NaN
# 6312           NaN           NaN                       NaN
# 6313           NaN           NaN                       NaN
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6309                                                NaN
# 6310                                                NaN
# 6311                                                NaN
# 6312                                                NaN
# 6313                                                NaN
#
#                                                    href Unnamed: 22  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                 ...         ...
# 6309                                                NaN         NaN
# 6310                                                NaN         NaN
# 6311                                                NaN         NaN
# 6312                                                NaN         NaN
# 6313                                                NaN         NaN
#
#      Unnamed: 23
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 6309         NaN
# 6310         NaN
# 6311         NaN
# 6312         NaN
# 6313         NaN
#
# [6314 rows x 23 columns]

# %%
shark_clean['Investigator or Source'].value_counts()
# Out:
# C. Moore, GSAF                                                    105
# C. Creswell, GSAF                                                  92
# S. Petersohn, GSAF                                                 82
# R. Collier                                                         55
# T. Peake, GSAF                                                     48
#                                                                  ...
# JBayNews.com, 10/11/2013                                            1
# P. Pearman;               C. Creswell, GSAF                         1
# Cambridge Daily News, 7/4/1959; V. M. Coppleson (1962), p. 259      1
# Tin Tuc online, 6/14/2009                                           1
# H.D.Baldridge (1994) SAF Case #1415                                 1
# Name: Investigator or Source, Length: 4968, dtype: int64

# %% [markdown]
# # limpieza original order

# %%
shark_clean['original order'] =shark_clean['original order'].fillna(shark_clean['original order'].mean())
shark_clean
# Out:
#      Case Number       Date  Year        Type    Country             Area  \
# 0     2018.06.25 2018-06-25  2018     Boating        USA       California
# 1     2018.06.18 2018-06-18  2018  Unprovoked        USA          Georgia
# 2     2018.06.09 2018-06-09  2018     Unknown        USA           Hawaii
# 3     2018.06.08 2018-06-08  2018  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04 2018-06-04  2018    Provoked     MEXICO           Colima
# ...          ...        ...   ...         ...        ...              ...
# 6309           0        NaT  1926     Unknown    Unknown          Unknown
# 6310           0        NaT  1926     Unknown    Unknown          Unknown
# 6311           0        NaT  1926     Unknown    Unknown          Unknown
# 6312  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
# 6313  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
#
#                             Location  Activity             Name     Sex  ...  \
# 0        Oceanside, San Diego County  Paddling      Julie Wolfe  Female  ...
# 1     St. Simon Island, Glynn County   Unknown  Adyson McNeely   Female  ...
# 2                       Habush, Oahu   Surfing      John Denges    Male  ...
# 3                 Arrawarra Headland   Surfing          Unknown    Male  ...
# 4                           La Ticla   Unknown   Gustavo Ramos     Male  ...
# ...                              ...       ...              ...     ...  ...
# 6309                         Unknown   Unknown          Unknown      ND  ...
# 6310                         Unknown   Unknown          Unknown      ND  ...
# 6311                         Unknown   Unknown          Unknown      ND  ...
# 6312                         Unknown   Unknown          Unknown      ND  ...
# 6313                         Unknown   Unknown          Unknown      ND  ...
#
#                Time          Investigator or Source original order  \
# 0             18h00                R. Collier, GSAF    6303.000000
# 1     14h00  -15h00  K.McMurray, TrackingSharks.com    6302.000000
# 2             07h45  K.McMurray, TrackingSharks.com    6301.000000
# 3               NaN                  B. Myatt, GSAF    6300.000000
# 4               NaN                       A .Kipper    6299.000000
# ...             ...                             ...            ...
# 6309            NaN                         Unknown    6309.000000
# 6310            NaN                         Unknown    6310.000000
# 6311            NaN                         Unknown    3155.352466
# 6312            NaN                         Unknown    3155.352466
# 6313            NaN                         Unknown    3155.352466
#
#      Case Number.1 Case Number.2                       pdf  \
# 0       2018.06.25    2018.06.25      2018.06.25-Wolfe.pdf
# 1       2018.06.18    2018.06.18    2018.06.18-McNeely.pdf
# 2       2018.06.09    2018.06.09     2018.06.09-Denges.pdf
# 3       2018.06.08    2018.06.08  2018.06.08-Arrawarra.pdf
# 4       2018.06.04    2018.06.04      2018.06.04-Ramos.pdf
# ...            ...           ...                       ...
# 6309           NaN           NaN                       NaN
# 6310           NaN           NaN                       NaN
# 6311           NaN           NaN                       NaN
# 6312           NaN           NaN                       NaN
# 6313           NaN           NaN                       NaN
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6309                                                NaN
# 6310                                                NaN
# 6311                                                NaN
# 6312                                                NaN
# 6313                                                NaN
#
#                                                    href Unnamed: 22  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                 ...         ...
# 6309                                                NaN         NaN
# 6310                                                NaN         NaN
# 6311                                                NaN         NaN
# 6312                                                NaN         NaN
# 6313                                                NaN         NaN
#
#      Unnamed: 23
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 6309         NaN
# 6310         NaN
# 6311         NaN
# 6312         NaN
# 6313         NaN
#
# [6314 rows x 23 columns]

# %%
shark_clean['original order']=shark_clean['original order'].astype({'original order': 'str'})

# %%
shark_clean.dtypes
# Out:
# Case Number                       object
# Date                      datetime64[ns]
# Year                               int64
# Type                              object
# Country                           object
# Area                              object
# Location                          object
# Activity                          object
# Name                              object
# Sex                               object
# Age                                int64
# Fatal                             object
# Species                           object
# Time                              object
# Investigator or Source            object
# original order                    object
# Case Number.1                     object
# Case Number.2                     object
# pdf                               object
# href formula                      object
# href                              object
# Unnamed: 22                       object
# Unnamed: 23                       object
# dtype: object

# %%
shark_clean['original order'] = shark_clean['original order'].str.replace('\.[0-9]+','',regex=True)
shark_clean
# Out:
#      Case Number       Date  Year        Type    Country             Area  \
# 0     2018.06.25 2018-06-25  2018     Boating        USA       California
# 1     2018.06.18 2018-06-18  2018  Unprovoked        USA          Georgia
# 2     2018.06.09 2018-06-09  2018     Unknown        USA           Hawaii
# 3     2018.06.08 2018-06-08  2018  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04 2018-06-04  2018    Provoked     MEXICO           Colima
# ...          ...        ...   ...         ...        ...              ...
# 6309           0        NaT  1926     Unknown    Unknown          Unknown
# 6310           0        NaT  1926     Unknown    Unknown          Unknown
# 6311           0        NaT  1926     Unknown    Unknown          Unknown
# 6312  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
# 6313  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
#
#                             Location  Activity             Name     Sex  ...  \
# 0        Oceanside, San Diego County  Paddling      Julie Wolfe  Female  ...
# 1     St. Simon Island, Glynn County   Unknown  Adyson McNeely   Female  ...
# 2                       Habush, Oahu   Surfing      John Denges    Male  ...
# 3                 Arrawarra Headland   Surfing          Unknown    Male  ...
# 4                           La Ticla   Unknown   Gustavo Ramos     Male  ...
# ...                              ...       ...              ...     ...  ...
# 6309                         Unknown   Unknown          Unknown      ND  ...
# 6310                         Unknown   Unknown          Unknown      ND  ...
# 6311                         Unknown   Unknown          Unknown      ND  ...
# 6312                         Unknown   Unknown          Unknown      ND  ...
# 6313                         Unknown   Unknown          Unknown      ND  ...
#
#                Time          Investigator or Source original order  \
# 0             18h00                R. Collier, GSAF           6303
# 1     14h00  -15h00  K.McMurray, TrackingSharks.com           6302
# 2             07h45  K.McMurray, TrackingSharks.com           6301
# 3               NaN                  B. Myatt, GSAF           6300
# 4               NaN                       A .Kipper           6299
# ...             ...                             ...            ...
# 6309            NaN                         Unknown           6309
# 6310            NaN                         Unknown           6310
# 6311            NaN                         Unknown           3155
# 6312            NaN                         Unknown           3155
# 6313            NaN                         Unknown           3155
#
#      Case Number.1 Case Number.2                       pdf  \
# 0       2018.06.25    2018.06.25      2018.06.25-Wolfe.pdf
# 1       2018.06.18    2018.06.18    2018.06.18-McNeely.pdf
# 2       2018.06.09    2018.06.09     2018.06.09-Denges.pdf
# 3       2018.06.08    2018.06.08  2018.06.08-Arrawarra.pdf
# 4       2018.06.04    2018.06.04      2018.06.04-Ramos.pdf
# ...            ...           ...                       ...
# 6309           NaN           NaN                       NaN
# 6310           NaN           NaN                       NaN
# 6311           NaN           NaN                       NaN
# 6312           NaN           NaN                       NaN
# 6313           NaN           NaN                       NaN
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6309                                                NaN
# 6310                                                NaN
# 6311                                                NaN
# 6312                                                NaN
# 6313                                                NaN
#
#                                                    href Unnamed: 22  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                 ...         ...
# 6309                                                NaN         NaN
# 6310                                                NaN         NaN
# 6311                                                NaN         NaN
# 6312                                                NaN         NaN
# 6313                                                NaN         NaN
#
#      Unnamed: 23
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 6309         NaN
# 6310         NaN
# 6311         NaN
# 6312         NaN
# 6313         NaN
#
# [6314 rows x 23 columns]

# %%
shark_clean['original order']=shark_clean['original order'].astype({'original order':'int64'})

# %%
shark_clean.dtypes
# Out:
# Case Number                       object
# Date                      datetime64[ns]
# Year                               int64
# Type                              object
# Country                           object
# Area                              object
# Location                          object
# Activity                          object
# Name                              object
# Sex                               object
# Age                                int64
# Fatal                             object
# Species                           object
# Time                              object
# Investigator or Source            object
# original order                     int64
# Case Number.1                     object
# Case Number.2                     object
# pdf                               object
# href formula                      object
# href                              object
# Unnamed: 22                       object
# Unnamed: 23                       object
# dtype: object

# %%
shark_clean.sample(10)
# Out:
#      Case Number       Date  Year        Type       Country  \
# 2208  1998.00.00        NaT  1998  Unprovoked  SOUTH AFRICA
# 2183  1998.06.22 1998-06-22  1998  Unprovoked  SOUTH AFRICA
# 960   2010.12.11 2010-12-11  2010  Unprovoked           USA
# 4081  1959.07.30 1959-07-30  1959    Provoked           USA
# 3877  1961.09.26 1961-09-26  1961    Provoked           USA
# 4821  1938.05.02        NaT  1938  Unprovoked         INDIA
# 1692  2004.03.16 2004-03-16  2004  Unprovoked           USA
# 2764  1987.11.00        NaT  1987     Unknown  SOUTH AFRICA
# 4607  1946.02.10 1946-02-10  1946  Unprovoked  SOUTH AFRICA
# 2289  1996.08.29 1996-08-29  1996  Unprovoked           USA
#
#                        Area                                     Location  \
# 2208  Eastern Cape Province                             Hole-in-the Wall
# 2183  Eastern Cape Province      Gonubie, 13 km northeast of East London
# 960                  Hawaii                            Tavares Bay, Maui
# 4081             California  In kelp beds off La Jolla, San Diego County
# 3877                Florida                  Florida Keys, Monroe County
# 4821            West Bengal              Hooghley River near Budge-Budge
# 1692                 Hawaii                       Kalihiwai Beach, Kauai
# 2764          KwaZulu-Natal                                    St. Lucia
# 4607          KwaZulu-Natal                        Battery Beach, Durban
# 2289                 Hawaii                              Paukukalo, Maui
#
#      Activity                                               Name   Sex  ...  \
# 2208  Surfing                                                  M    ND  ...
# 2183  Unknown                                        Anton deVos  Male  ...
# 960   Surfing                                      Andrew Wilson  Male  ...
# 4081  Unknown  4.3 m skiff: occupants: James L. Randles, Jr. ...    ND  ...
# 3877  Unknown                                        Paul Walter  Male  ...
# 4821  Unknown                                            Unknown    ND  ...
# 1692  Surfing                                         Bruce Orth  Male  ...
# 2764  Unknown                                            Unknown  Male  ...
# 4607  Unknown             Janardhan Rughoober Varma, a lifesaver  Male  ...
# 2289  Unknown                                   David Nanod, Jr.  Male  ...
#
#        Time              Investigator or Source original order Case Number.1  \
# 2208    NaN                             Unknown           3155           NaN
# 2183  09h55                    A. Gifford, GSAF           4121    1998.06.22
# 960   13h51               Maui News, 12/14/2010           5344    2010.12.11
# 4081  16h00                LA Times, 7/31/1959            2224    1959.07.30
# 3877  16h30  H.D.Baldridge (1994) SAF Case #923           2428    1961.09.26
# 4821    NaN  The Times (London), 5/2/1938, p.15           1484  1938.05.02.R
# 1692  07h45                  The Hawaii Channel           4612    2004.03.16
# 2764    NaN                                 NSB           3541    1987.11.00
# 4607  09h15        J.R. Varma, M. Levine, GSAF            1698  1946.02.10.a
# 2289  16h00                        Allen, p.117           4016    1996.08.29
#
#      Case Number.2                               pdf  \
# 2208           NaN                               NaN
# 2183    1998.06.22              1998.06.22-deVos.pdf
# 960     2010.12.11             2010.12.11-Wilson.pdf
# 4081    1959.07.30    1959.07.30-Randles_Collier.pdf
# 3877    1961.09.26      1961.09.26-NV-PaulWalter.pdf
# 4821  1938.05.02.R            1938.05.02.R-India.pdf
# 1692    2004.03.16               2004.03.16-Orth.pdf
# 2764    1987.11.00  1987.11.00-StLucia-scavengin.pdf
# 4607  1946.02.10.a            1946.02.10.a-Varma.pdf
# 2289    1996.08.29              1996.08.29-Nanod.pdf
#
#                                            href formula  \
# 2208                                                NaN
# 2183  http://sharkattackfile.net/spreadsheets/pdf_di...
# 960   http://sharkattackfile.net/spreadsheets/pdf_di...
# 4081  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3877  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4821  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1692  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2764  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4607  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2289  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Unnamed: 22  \
# 2208                                                NaN         NaN
# 2183  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 960   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4081  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3877  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4821  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1692  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2764  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4607  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2289  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
#
#      Unnamed: 23
# 2208         NaN
# 2183         NaN
# 960          NaN
# 4081         NaN
# 3877         NaN
# 4821         NaN
# 1692         NaN
# 2764         NaN
# 4607         NaN
# 2289         NaN
#
# [10 rows x 23 columns]

# %% [markdown]
# # limpieza case number.1

# %%
shark_clean['Case Number.1']= shark_clean['Case Number.1'].fillna('2010.01.01')
shark_clean
# Out:
#      Case Number       Date  Year        Type    Country             Area  \
# 0     2018.06.25 2018-06-25  2018     Boating        USA       California
# 1     2018.06.18 2018-06-18  2018  Unprovoked        USA          Georgia
# 2     2018.06.09 2018-06-09  2018     Unknown        USA           Hawaii
# 3     2018.06.08 2018-06-08  2018  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04 2018-06-04  2018    Provoked     MEXICO           Colima
# ...          ...        ...   ...         ...        ...              ...
# 6309           0        NaT  1926     Unknown    Unknown          Unknown
# 6310           0        NaT  1926     Unknown    Unknown          Unknown
# 6311           0        NaT  1926     Unknown    Unknown          Unknown
# 6312  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
# 6313  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
#
#                             Location  Activity             Name     Sex  ...  \
# 0        Oceanside, San Diego County  Paddling      Julie Wolfe  Female  ...
# 1     St. Simon Island, Glynn County   Unknown  Adyson McNeely   Female  ...
# 2                       Habush, Oahu   Surfing      John Denges    Male  ...
# 3                 Arrawarra Headland   Surfing          Unknown    Male  ...
# 4                           La Ticla   Unknown   Gustavo Ramos     Male  ...
# ...                              ...       ...              ...     ...  ...
# 6309                         Unknown   Unknown          Unknown      ND  ...
# 6310                         Unknown   Unknown          Unknown      ND  ...
# 6311                         Unknown   Unknown          Unknown      ND  ...
# 6312                         Unknown   Unknown          Unknown      ND  ...
# 6313                         Unknown   Unknown          Unknown      ND  ...
#
#                Time          Investigator or Source original order  \
# 0             18h00                R. Collier, GSAF           6303
# 1     14h00  -15h00  K.McMurray, TrackingSharks.com           6302
# 2             07h45  K.McMurray, TrackingSharks.com           6301
# 3               NaN                  B. Myatt, GSAF           6300
# 4               NaN                       A .Kipper           6299
# ...             ...                             ...            ...
# 6309            NaN                         Unknown           6309
# 6310            NaN                         Unknown           6310
# 6311            NaN                         Unknown           3155
# 6312            NaN                         Unknown           3155
# 6313            NaN                         Unknown           3155
#
#      Case Number.1 Case Number.2                       pdf  \
# 0       2018.06.25    2018.06.25      2018.06.25-Wolfe.pdf
# 1       2018.06.18    2018.06.18    2018.06.18-McNeely.pdf
# 2       2018.06.09    2018.06.09     2018.06.09-Denges.pdf
# 3       2018.06.08    2018.06.08  2018.06.08-Arrawarra.pdf
# 4       2018.06.04    2018.06.04      2018.06.04-Ramos.pdf
# ...            ...           ...                       ...
# 6309    2010.01.01           NaN                       NaN
# 6310    2010.01.01           NaN                       NaN
# 6311    2010.01.01           NaN                       NaN
# 6312    2010.01.01           NaN                       NaN
# 6313    2010.01.01           NaN                       NaN
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6309                                                NaN
# 6310                                                NaN
# 6311                                                NaN
# 6312                                                NaN
# 6313                                                NaN
#
#                                                    href Unnamed: 22  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                 ...         ...
# 6309                                                NaN         NaN
# 6310                                                NaN         NaN
# 6311                                                NaN         NaN
# 6312                                                NaN         NaN
# 6313                                                NaN         NaN
#
#      Unnamed: 23
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 6309         NaN
# 6310         NaN
# 6311         NaN
# 6312         NaN
# 6313         NaN
#
# [6314 rows x 23 columns]

# %%
shark_clean['Case Number.1']=shark_clean['Case Number.1'].replace('\.[a-z]|\.[A-Z]','',regex=True)

# %%
shark_clean['Case Number.1'] = pd.to_datetime(shark_clean['Case Number.1'], errors='coerce', infer_datetime_format=True)
shark_clean.dtypes
# Out:
# Case Number                       object
# Date                      datetime64[ns]
# Year                               int64
# Type                              object
# Country                           object
# Area                              object
# Location                          object
# Activity                          object
# Name                              object
# Sex                               object
# Age                                int64
# Fatal                             object
# Species                           object
# Time                              object
# Investigator or Source            object
# original order                     int64
# Case Number.1             datetime64[ns]
# Case Number.2                     object
# pdf                               object
# href formula                      object
# href                              object
# Unnamed: 22                       object
# Unnamed: 23                       object
# dtype: object

# %%
shark_clean['Case Number.1'].value_counts()
# Out:
# 2010-01-01    14
# 2001-04-12     5
# 1995-07-28     5
# 2003-10-05     5
# 2010-01-09     4
#               ..
# 1888-12-25     1
# 2011-07-31     1
# 2007-01-05     1
# 1936-01-05     1
# 2004-12-11     1
# Name: Case Number.1, Length: 4802, dtype: int64

# %% [markdown]
# # limpieza case Number.2

# %%
shark_clean['Case Number.2']=shark_clean['Case Number.2'].fillna('2010.01.01')
shark_clean
# Out:
#      Case Number       Date  Year        Type    Country             Area  \
# 0     2018.06.25 2018-06-25  2018     Boating        USA       California
# 1     2018.06.18 2018-06-18  2018  Unprovoked        USA          Georgia
# 2     2018.06.09 2018-06-09  2018     Unknown        USA           Hawaii
# 3     2018.06.08 2018-06-08  2018  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04 2018-06-04  2018    Provoked     MEXICO           Colima
# ...          ...        ...   ...         ...        ...              ...
# 6309           0        NaT  1926     Unknown    Unknown          Unknown
# 6310           0        NaT  1926     Unknown    Unknown          Unknown
# 6311           0        NaT  1926     Unknown    Unknown          Unknown
# 6312  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
# 6313  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
#
#                             Location  Activity             Name     Sex  ...  \
# 0        Oceanside, San Diego County  Paddling      Julie Wolfe  Female  ...
# 1     St. Simon Island, Glynn County   Unknown  Adyson McNeely   Female  ...
# 2                       Habush, Oahu   Surfing      John Denges    Male  ...
# 3                 Arrawarra Headland   Surfing          Unknown    Male  ...
# 4                           La Ticla   Unknown   Gustavo Ramos     Male  ...
# ...                              ...       ...              ...     ...  ...
# 6309                         Unknown   Unknown          Unknown      ND  ...
# 6310                         Unknown   Unknown          Unknown      ND  ...
# 6311                         Unknown   Unknown          Unknown      ND  ...
# 6312                         Unknown   Unknown          Unknown      ND  ...
# 6313                         Unknown   Unknown          Unknown      ND  ...
#
#                Time          Investigator or Source original order  \
# 0             18h00                R. Collier, GSAF           6303
# 1     14h00  -15h00  K.McMurray, TrackingSharks.com           6302
# 2             07h45  K.McMurray, TrackingSharks.com           6301
# 3               NaN                  B. Myatt, GSAF           6300
# 4               NaN                       A .Kipper           6299
# ...             ...                             ...            ...
# 6309            NaN                         Unknown           6309
# 6310            NaN                         Unknown           6310
# 6311            NaN                         Unknown           3155
# 6312            NaN                         Unknown           3155
# 6313            NaN                         Unknown           3155
#
#      Case Number.1 Case Number.2                       pdf  \
# 0       2018-06-25    2018.06.25      2018.06.25-Wolfe.pdf
# 1       2018-06-18    2018.06.18    2018.06.18-McNeely.pdf
# 2       2018-06-09    2018.06.09     2018.06.09-Denges.pdf
# 3       2018-06-08    2018.06.08  2018.06.08-Arrawarra.pdf
# 4       2018-06-04    2018.06.04      2018.06.04-Ramos.pdf
# ...            ...           ...                       ...
# 6309    2010-01-01    2010.01.01                       NaN
# 6310    2010-01-01    2010.01.01                       NaN
# 6311    2010-01-01    2010.01.01                       NaN
# 6312    2010-01-01    2010.01.01                       NaN
# 6313    2010-01-01    2010.01.01                       NaN
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6309                                                NaN
# 6310                                                NaN
# 6311                                                NaN
# 6312                                                NaN
# 6313                                                NaN
#
#                                                    href Unnamed: 22  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                 ...         ...
# 6309                                                NaN         NaN
# 6310                                                NaN         NaN
# 6311                                                NaN         NaN
# 6312                                                NaN         NaN
# 6313                                                NaN         NaN
#
#      Unnamed: 23
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 6309         NaN
# 6310         NaN
# 6311         NaN
# 6312         NaN
# 6313         NaN
#
# [6314 rows x 23 columns]

# %%
shark_clean['Case Number.2'] = shark_clean['Case Number.2'].replace('\.[a-z]|\.[A-Z]','',regex=True)
shark_clean['Case Number.2'].value_counts()
# Out:
# 2010.01.01    14
# 1950.00.00    13
# 1957.00.00    11
# 1942.00.00    11
# 1960.00.00    10
#               ..
# 2016.03.04     1
# 1972.12.31     1
# 2000.09.29     1
# 1965.02.04     1
# 2012.12.28     1
# Name: Case Number.2, Length: 5348, dtype: int64

# %%
shark_clean['Case Number.2'] = pd.to_datetime(shark_clean['Case Number.2'], errors='coerce', infer_datetime_format=True)
shark_clean.dtypes
# Out:
# Case Number                       object
# Date                      datetime64[ns]
# Year                               int64
# Type                              object
# Country                           object
# Area                              object
# Location                          object
# Activity                          object
# Name                              object
# Sex                               object
# Age                                int64
# Fatal                             object
# Species                           object
# Time                              object
# Investigator or Source            object
# original order                     int64
# Case Number.1             datetime64[ns]
# Case Number.2             datetime64[ns]
# pdf                               object
# href formula                      object
# href                              object
# Unnamed: 22                       object
# Unnamed: 23                       object
# dtype: object

# %%
shark_clean
# Out:
#      Case Number       Date  Year        Type    Country             Area  \
# 0     2018.06.25 2018-06-25  2018     Boating        USA       California
# 1     2018.06.18 2018-06-18  2018  Unprovoked        USA          Georgia
# 2     2018.06.09 2018-06-09  2018     Unknown        USA           Hawaii
# 3     2018.06.08 2018-06-08  2018  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04 2018-06-04  2018    Provoked     MEXICO           Colima
# ...          ...        ...   ...         ...        ...              ...
# 6309           0        NaT  1926     Unknown    Unknown          Unknown
# 6310           0        NaT  1926     Unknown    Unknown          Unknown
# 6311           0        NaT  1926     Unknown    Unknown          Unknown
# 6312  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
# 6313  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
#
#                             Location  Activity             Name     Sex  ...  \
# 0        Oceanside, San Diego County  Paddling      Julie Wolfe  Female  ...
# 1     St. Simon Island, Glynn County   Unknown  Adyson McNeely   Female  ...
# 2                       Habush, Oahu   Surfing      John Denges    Male  ...
# 3                 Arrawarra Headland   Surfing          Unknown    Male  ...
# 4                           La Ticla   Unknown   Gustavo Ramos     Male  ...
# ...                              ...       ...              ...     ...  ...
# 6309                         Unknown   Unknown          Unknown      ND  ...
# 6310                         Unknown   Unknown          Unknown      ND  ...
# 6311                         Unknown   Unknown          Unknown      ND  ...
# 6312                         Unknown   Unknown          Unknown      ND  ...
# 6313                         Unknown   Unknown          Unknown      ND  ...
#
#                Time          Investigator or Source original order  \
# 0             18h00                R. Collier, GSAF           6303
# 1     14h00  -15h00  K.McMurray, TrackingSharks.com           6302
# 2             07h45  K.McMurray, TrackingSharks.com           6301
# 3               NaN                  B. Myatt, GSAF           6300
# 4               NaN                       A .Kipper           6299
# ...             ...                             ...            ...
# 6309            NaN                         Unknown           6309
# 6310            NaN                         Unknown           6310
# 6311            NaN                         Unknown           3155
# 6312            NaN                         Unknown           3155
# 6313            NaN                         Unknown           3155
#
#      Case Number.1 Case Number.2                       pdf  \
# 0       2018-06-25    2018-06-25      2018.06.25-Wolfe.pdf
# 1       2018-06-18    2018-06-18    2018.06.18-McNeely.pdf
# 2       2018-06-09    2018-06-09     2018.06.09-Denges.pdf
# 3       2018-06-08    2018-06-08  2018.06.08-Arrawarra.pdf
# 4       2018-06-04    2018-06-04      2018.06.04-Ramos.pdf
# ...            ...           ...                       ...
# 6309    2010-01-01    2010-01-01                       NaN
# 6310    2010-01-01    2010-01-01                       NaN
# 6311    2010-01-01    2010-01-01                       NaN
# 6312    2010-01-01    2010-01-01                       NaN
# 6313    2010-01-01    2010-01-01                       NaN
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6309                                                NaN
# 6310                                                NaN
# 6311                                                NaN
# 6312                                                NaN
# 6313                                                NaN
#
#                                                    href Unnamed: 22  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                 ...         ...
# 6309                                                NaN         NaN
# 6310                                                NaN         NaN
# 6311                                                NaN         NaN
# 6312                                                NaN         NaN
# 6313                                                NaN         NaN
#
#      Unnamed: 23
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 6309         NaN
# 6310         NaN
# 6311         NaN
# 6312         NaN
# 6313         NaN
#
# [6314 rows x 23 columns]

# %%
shark_clean.to_csv('clean.csv')

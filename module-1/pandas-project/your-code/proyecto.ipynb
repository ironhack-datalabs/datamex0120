# %%
import pandas as pd
import re

# %% [markdown]
# # Lectura del archivo csv

# %%
# lee el archivo con un encoding diferente a utf-8 ya que no reconoce ciertos caracteres dentro de el csv
shark = pd.read_csv('attacks.csv',encoding = "ISO-8859-1")
shark_info = pd.DataFrame(shark)

# %%
shark_info
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722         NaN          NaN     NaN         NaN        NaN
# 25723         NaN          NaN     NaN         NaN        NaN
# 25724          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 25720              NaN                             NaN          NaN
# 25721              NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
# 25723              NaN                             NaN          NaN
# 25724              NaN                             NaN          NaN
#
#                   Name Sex   ...         Species   \
# 0          Julie Wolfe    F  ...      White shark
# 1      Adyson McNeely     F  ...              NaN
# 2          John Denges    M  ...              NaN
# 3                 male    M  ...        2 m shark
# 4       Gustavo Ramos     M  ...  Tiger shark, 3m
# ...                ...  ...  ...              ...
# 25720              NaN  NaN  ...              NaN
# 25721              NaN  NaN  ...              NaN
# 25722              NaN  NaN  ...              NaN
# 25723              NaN  NaN  ...              NaN
# 25724              NaN  NaN  ...              NaN
#
#                Investigator or Source                       pdf  \
# 0                    R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1      K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2      K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3                      B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4                           A .Kipper      2018.06.04-Ramos.pdf
# ...                               ...                       ...
# 25720                             NaN                       NaN
# 25721                             NaN                       NaN
# 25722                             NaN                       NaN
# 25723                             NaN                       NaN
# 25724                             NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 25720                                                NaN
# 25721                                                NaN
# 25722                                                NaN
# 25723                                                NaN
# 25724                                                NaN
#
#                                                     href Case Number.1  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                  ...           ...
# 25720                                                NaN           NaN
# 25721                                                NaN           NaN
# 25722                                                NaN           NaN
# 25723                                                NaN           NaN
# 25724                                                NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0        2018.06.25         6303.0         NaN         NaN
# 1        2018.06.18         6302.0         NaN         NaN
# 2        2018.06.09         6301.0         NaN         NaN
# 3        2018.06.08         6300.0         NaN         NaN
# 4        2018.06.04         6299.0         NaN         NaN
# ...             ...            ...         ...         ...
# 25720           NaN            NaN         NaN         NaN
# 25721           NaN            NaN         NaN         NaN
# 25722           NaN            NaN         NaN         NaN
# 25723           NaN            NaN         NaN         NaN
# 25724           NaN            NaN         NaN         NaN
#
# [25725 rows x 24 columns]

# %%
shark_info.shape
# Out:
# (25725, 24)

# %%
shark_info.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %% [markdown]
# # Drop Duplicates

# %%
# elimina todas las filas que contienen valores iguales, que para este caso es nan en todas sus columnas
duplicados = shark_info.drop_duplicates().reset_index()
duplicados.sample(10)
# Out:
#       index   Case Number                  Date    Year        Type  \
# 5966   5966  1862.12.19.R  Reported 19-Dec-1862  1862.0  Unprovoked
# 535     535    2014.07.09            9-Jul-2014  2014.0  Unprovoked
# 6121   6121    1811.03.01           01-Mar-1811  1811.0  Unprovoked
# 3736   3736    1963.11.04           04-Nov-1963  1963.0  Unprovoked
# 1866   1866    2002.04.30           30-Apr-2002  2002.0  Unprovoked
# 3488   3488    1968.02.02           02-Feb-1968  1968.0  Unprovoked
# 3924   3924    1961.02.12           12-Feb-1961  1961.0  Unprovoked
# 4127   4127  1959.00.00.b                  1959  1959.0  Unprovoked
# 4534   4534  1948.12.14.a           14-Dec-1948  1948.0  Unprovoked
# 2649   2649    1990.01.12           12-Jan-1990  1990.0  Unprovoked
#
#                Country                                        Area  \
# 5966         AUSTRALIA                                  Queensland
# 535                USA                                     Florida
# 6121               NaN                                         NaN
# 3736             PALAU                    Western Caroline Islands
# 1866         AUSTRALIA                             South Australia
# 3488         AUSTRALIA                             New South Wales
# 3924      SOUTH AFRICA                       Western Cape Province
# 4127  PAPUA NEW GUINEA  New Ireland Province, Bismarck Archipelago
# 4534              CUBA                         Guantanamo Province
# 2649               USA                                  California
#
#                                            Location  \
# 5966                                 Brisbane River
# 535                New Smyrna Beach, Volusia County
# 6121                                            NaN
# 3736                                          Koror
# 1866  Smoky Bay, near Ceduna, on the Eyre Peninsula
# 3488                                Brunswick Heads
# 3924                                      Sea Point
# 4127                           Enuk Island, Kavieng
# 4534                        10 miles off Cape Maisi
# 2649                Montera Beach, San Mateo County
#
#                                                Activity                  Name  \
# 5966                     Trying to catch a wounded bird                  male
# 535                                             Surfing        Tristan Durham
# 6121                                     Fell overboard           John Walker
# 3736                                            Fishing         Saburo Dooley
# 1866  Scallop diving (using surface-supplied air & a...         Paul Buckland
# 3488                                                NaN             R. Vidler
# 3924  Spearfishing, shark grabbed his white t-shirt ...  Carl Derrick Benzoin
# 4127                                                NaN           Pasinganlas
# 4534  2 messboys (Jeppsen) & Tony Latona (13) were p...          Bret Jeppsen
# 2649                     Surfing (sitting on his board)         Sean Sullivan
#
#       ...                                           Species   \
# 5966  ...                                                NaN
# 535   ...                                                NaN
# 6121  ...                                                NaN
# 3736  ...  Dooley believed his Injury was caused by sting...
# 1866  ...                              White shark, 6m [20']
# 3488  ...                                                NaN
# 3924  ...                                   1.5 m [5'] shark
# 4127  ...                                                NaN
# 4534  ...                                                NaN
# 2649  ...                3 m to 4 m [10' to 13'] white shark
#
#                                  Investigator or Source  \
# 5966                                Courier, 12/19/1862
# 535                                  WESH.com, 7/9/2014
# 6121                         Journal of Captain Marryat
# 3736            R. Yalap, M.D.; H.D. Baldridge, p..104
# 1866                                     T. Peake, GSAF
# 3488                                     J. Green, p.36
# 3924    C.D. Benzoin, M. Levine, GSAF; J. D'Aubrey, ORI
# 4127  J. McLachlan, Medical Officer, Kavieng; A.M. R...
# 4534                   Washington Post, 12/23/1948, p.`
# 2649  J. McCosker & R.N. Lea; R. Collier, p. 116 ; A...
#
#                                   pdf  \
# 5966    1862.12.19.R-Boy-Brisbane.pdf
# 535             2014.07.09-Durham.pdf
# 6121       1811.03.01-John-Walker.pdf
# 3736            1963.11.04-Dooley.pdf
# 1866          2002.04.30-Buckland.pdf
# 3488            1968.02.02-Vidler.pdf
# 3924           1961.02.12-Benzoin.pdf
# 4127     1959.00.00.b-Pasinganlas.pdf
# 4534        1948.12.14.a-Jeppeson.pdf
# 2649  1990.01.12-Sullivan_Collier.pdf
#
#                                            href formula  \
# 5966  http://sharkattackfile.net/spreadsheets/pdf_di...
# 535   http://sharkattackfile.net/spreadsheets/pdf_di...
# 6121  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3736  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1866  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3488  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3924  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4127  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4534  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2649  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 5966  http://sharkattackfile.net/spreadsheets/pdf_di...  1862.12.19.R
# 535   http://sharkattackfile.net/spreadsheets/pdf_di...    2014.07.09
# 6121  http://sharkattackfile.net/spreadsheets/pdf_di...    1811.03.01
# 3736  http://sharkattackfile.net/spreadsheets/pdf_di...    1963.11.04
# 1866  http://sharkattackfile.net/spreadsheets/pdf_di...    2002.04.30
# 3488  http://sharkattackfile.net/spreadsheets/pdf_di...    1968.02.02
# 3924  http://sharkattackfile.net/spreadsheets/pdf_di...    1961.02.12
# 4127  http://sharkattackfile.net/spreadsheets/pdf_di...  1959.00.00.b
# 4534  http://sharkattackfile.net/spreadsheets/pdf_di...  1948.12.14.a
# 2649  http://sharkattackfile.net/spreadsheets/pdf_di...    1990.01.12
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23
# 5966  1862.12.19.R          339.0         NaN         NaN
# 535     2014.07.09         5769.0         NaN         NaN
# 6121    1811.03.01          184.0         NaN         NaN
# 3736    1963.11.04         2569.0         NaN         NaN
# 1866    2002.04.30         4438.0         NaN         NaN
# 3488    1968.02.02         2817.0         NaN         NaN
# 3924    1961.02.12         2381.0         NaN         NaN
# 4127  1959.00.00.b         2178.0         NaN         NaN
# 4534  1948.12.14.a         1771.0         NaN         NaN
# 2649    1990.01.12         3656.0         NaN         NaN
#
# [10 rows x 25 columns]

# %% [markdown]
# # comparacion original vs drop duplicates

# %%
print('tamaño de las filas en el archivo originial',shark_info.shape)
print('tamaño de las filas en el archivo que elimina valores duplicados',duplicados.shape)
# Out:
# tamaño de las filas en el archivo originial (25725, 24)
# tamaño de las filas en el archivo que elimina valores duplicados (6314, 25)

# %%
# reorganizacion de las columnas de la mas importante a menos importante 
cols = ['Case Number', 'Date', 'Year','Type','Country', 'Area','Location',
       'Activity', 'Name', 'Sex ', 'Age', 'Fatal (Y/N)','Species ', 'Time','Investigator or Source',
       'original order','Case Number.1', 'Case Number.2','pdf', 'href formula', 'href','Unnamed: 22','Unnamed: 23']
shark_clean = pd.DataFrame(duplicados, columns=cols)
shark_clean = shark_clean
shark_clean
# Out:
#      Case Number         Date    Year        Type    Country             Area  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
# ...          ...          ...     ...         ...        ...              ...
# 6309           0          NaN     NaN         NaN        NaN              NaN
# 6310           0          NaN     NaN         NaN        NaN              NaN
# 6311           0          NaN     NaN         NaN        NaN              NaN
# 6312         NaN          NaN     NaN         NaN        NaN              NaN
# 6313          xx          NaN     NaN         NaN        NaN              NaN
#
#                             Location     Activity             Name Sex   ...  \
# 0        Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1     St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                       Habush, Oahu      Surfing      John Denges    M  ...
# 3                 Arrawarra Headland      Surfing             male    M  ...
# 4                           La Ticla  Free diving   Gustavo Ramos     M  ...
# ...                              ...          ...              ...  ...  ...
# 6309                             NaN          NaN              NaN  NaN  ...
# 6310                             NaN          NaN              NaN  NaN  ...
# 6311                             NaN          NaN              NaN  NaN  ...
# 6312                             NaN          NaN              NaN  NaN  ...
# 6313                             NaN          NaN              NaN  NaN  ...
#
#                Time          Investigator or Source original order  \
# 0             18h00                R. Collier, GSAF         6303.0
# 1     14h00  -15h00  K.McMurray, TrackingSharks.com         6302.0
# 2             07h45  K.McMurray, TrackingSharks.com         6301.0
# 3               NaN                  B. Myatt, GSAF         6300.0
# 4               NaN                       A .Kipper         6299.0
# ...             ...                             ...            ...
# 6309            NaN                             NaN         6309.0
# 6310            NaN                             NaN         6310.0
# 6311            NaN                             NaN            NaN
# 6312            NaN                             NaN            NaN
# 6313            NaN                             NaN            NaN
#
#      Case Number.1 Case Number.2                       pdf  \
# 0       2018.06.25    2018.06.25      2018.06.25-Wolfe.pdf
# 1       2018.06.18    2018.06.18    2018.06.18-McNeely.pdf
# 2       2018.06.09    2018.06.09     2018.06.09-Denges.pdf
# 3       2018.06.08    2018.06.08  2018.06.08-Arrawarra.pdf
# 4       2018.06.04    2018.06.04      2018.06.04-Ramos.pdf
# ...            ...           ...                       ...
# 6309           NaN           NaN                       NaN
# 6310           NaN           NaN                       NaN
# 6311           NaN           NaN                       NaN
# 6312           NaN           NaN                       NaN
# 6313           NaN           NaN                       NaN
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6309                                                NaN
# 6310                                                NaN
# 6311                                                NaN
# 6312                                                NaN
# 6313                                                NaN
#
#                                                    href Unnamed: 22  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                 ...         ...
# 6309                                                NaN         NaN
# 6310                                                NaN         NaN
# 6311                                                NaN         NaN
# 6312                                                NaN         NaN
# 6313                                                NaN         NaN
#
#      Unnamed: 23
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 6309         NaN
# 6310         NaN
# 6311         NaN
# 6312         NaN
# 6313         NaN
#
# [6314 rows x 23 columns]

# %% [markdown]
# # primera columna 'Case Number'

# %%
# limpiando primera columna de tabla
shark_clean['Case Number'] = shark_clean['Case Number'].str.replace('\.[a-z]+|\.[A-Z]+','', regex=True).fillna('2010.01.01')
shark_clean.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Fatal (Y/N)                object
# Species                    object
# Time                       object
# Investigator or Source     object
# original order            float64
# Case Number.1              object
# Case Number.2              object
# pdf                        object
# href formula               object
# href                       object
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %%
shark_clean['Case Number'] = shark_clean['Case Number'].str.replace('xx','2010.01.01')
shark_clean
# Out:
#      Case Number         Date    Year        Type    Country             Area  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
# ...          ...          ...     ...         ...        ...              ...
# 6309           0          NaN     NaN         NaN        NaN              NaN
# 6310           0          NaN     NaN         NaN        NaN              NaN
# 6311           0          NaN     NaN         NaN        NaN              NaN
# 6312  2010.01.01          NaN     NaN         NaN        NaN              NaN
# 6313  2010.01.01          NaN     NaN         NaN        NaN              NaN
#
#                             Location     Activity             Name Sex   ...  \
# 0        Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1     St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                       Habush, Oahu      Surfing      John Denges    M  ...
# 3                 Arrawarra Headland      Surfing             male    M  ...
# 4                           La Ticla  Free diving   Gustavo Ramos     M  ...
# ...                              ...          ...              ...  ...  ...
# 6309                             NaN          NaN              NaN  NaN  ...
# 6310                             NaN          NaN              NaN  NaN  ...
# 6311                             NaN          NaN              NaN  NaN  ...
# 6312                             NaN          NaN              NaN  NaN  ...
# 6313                             NaN          NaN              NaN  NaN  ...
#
#                Time          Investigator or Source original order  \
# 0             18h00                R. Collier, GSAF         6303.0
# 1     14h00  -15h00  K.McMurray, TrackingSharks.com         6302.0
# 2             07h45  K.McMurray, TrackingSharks.com         6301.0
# 3               NaN                  B. Myatt, GSAF         6300.0
# 4               NaN                       A .Kipper         6299.0
# ...             ...                             ...            ...
# 6309            NaN                             NaN         6309.0
# 6310            NaN                             NaN         6310.0
# 6311            NaN                             NaN            NaN
# 6312            NaN                             NaN            NaN
# 6313            NaN                             NaN            NaN
#
#      Case Number.1 Case Number.2                       pdf  \
# 0       2018.06.25    2018.06.25      2018.06.25-Wolfe.pdf
# 1       2018.06.18    2018.06.18    2018.06.18-McNeely.pdf
# 2       2018.06.09    2018.06.09     2018.06.09-Denges.pdf
# 3       2018.06.08    2018.06.08  2018.06.08-Arrawarra.pdf
# 4       2018.06.04    2018.06.04      2018.06.04-Ramos.pdf
# ...            ...           ...                       ...
# 6309           NaN           NaN                       NaN
# 6310           NaN           NaN                       NaN
# 6311           NaN           NaN                       NaN
# 6312           NaN           NaN                       NaN
# 6313           NaN           NaN                       NaN
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6309                                                NaN
# 6310                                                NaN
# 6311                                                NaN
# 6312                                                NaN
# 6313                                                NaN
#
#                                                    href Unnamed: 22  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                 ...         ...
# 6309                                                NaN         NaN
# 6310                                                NaN         NaN
# 6311                                                NaN         NaN
# 6312                                                NaN         NaN
# 6313                                                NaN         NaN
#
#      Unnamed: 23
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 6309         NaN
# 6310         NaN
# 6311         NaN
# 6312         NaN
# 6313         NaN
#
# [6314 rows x 23 columns]

# %% [markdown]
# # limpieza de las fechas date

# %%
shark_clean['Date'] = shark_clean['Date'].str.replace('Reported| Early| Late|\.[a-z]|\.[A-Z]|Between May &' ,'').fillna('01-01-2000')
shark_clean.sample(20)
# Out:
#      Case Number          Date    Year        Type           Country  \
# 4212  1957.01.05   05-Jan-1957  1957.0  Unprovoked      SOUTH AFRICA
# 4190  1957.11.04   04-Nov-1957  1957.0        Boat         AUSTRALIA
# 2478  1993.09.03   03-Sep-1993  1993.0  Unprovoked             SPAIN
# 993   2010.09.03   03-Sep-2010  2010.0  Unprovoked               USA
# 3027  1981.06.12   12-Jun-1981  1981.0     Invalid               USA
# 1804  2002.12.24   24-Dec-2002  2002.0  Unprovoked      SOUTH AFRICA
# 4078  1959.08.10   10-Aug-1959  1959.0  Unprovoked               USA
# 3482  1968.03.10   10-Mar-1968  1968.0  Unprovoked               USA
# 3041  1981.02.19   19-Feb-1981  1981.0  Unprovoked      SOUTH AFRICA
# 820   2012.02.06   06-Feb-2012  2012.0  Unprovoked         AUSTRALIA
# 880   2011.08.23   23-Aug-2011  2011.0  Unprovoked      SOUTH AFRICA
# 5381  1912.00.00          1912  1912.0  Unprovoked             SPAIN
# 4846  1937.08.02   02-Aug-1937  1937.0  Unprovoked            PANAMA
# 3945  1960.12.24   24-Dec-1960  1960.0  Unprovoked      SOUTH AFRICA
# 4510  1949.07.28   28-Jul-1949  1949.0  Unprovoked              IRAN
# 1142  2009.03.27   27-Mar-2009  2009.0    Provoked      SOUTH AFRICA
# 5105  1928.06.24   24-Jun-1928  1928.0  Unprovoked               USA
# 3610  1965.10.10   10-Oct-1965  1965.0  Unprovoked       NEW BRITAIN
# 4962  1933.07.03   03-Jul-1933  1933.0  Unprovoked         AUSTRALIA
# 2317  1996.02.10   09-Feb-1996  1996.0  Unprovoked  PAPUA NEW GUINEA
#
#                        Area  \
# 4212          KwaZulu-Natal
# 4190        New South Wales
# 2478           Costa Blanca
# 993                 Florida
# 3027                 Hawaii
# 1804  Western Cape Province
# 4078                Georgia
# 3482                Florida
# 3041          KwaZulu-Natal
# 820              Queensland
# 880   Western Cape Province
# 5381              Balearics
# 4846         Colon Province
# 3945          KwaZulu-Natal
# 4510    Shatt-al-Arab River
# 1142  Eastern Cape Province
# 5105                Florida
# 3610             West coast
# 4962      Western Australia
# 2317        Madang Province
#
#                                                Location  \
# 4212                                 Umgeni River Mouth
# 4190                                         Off Scotts
# 2478                     Playa de las Arenas, Valencia
# 993                    New Smyrna Beach, Volusia County
# 3027     Honoli'i Pali, Hilo Bay ('Alae Point), Hawai'i
# 1804                                        Scarborough
# 4078           Savannah Beach, Savannah, Chatham County
# 3482                        Jensen Beach, Martin County
# 3041                                         Umtentweni
# 820                                            Wurtulla
# 880   Lookout Beach, near the Keurbooms river mouth ...
# 5381                                       Isla Cabrera
# 4846                                          Limon Bay
# 3945                                            Margate
# 4510                                           Bashamir
# 1142               2-3 km north of Sunday's River mouth
# 5105                      Daytona Beach, Volusia County
# 3610  Outside the reef off Moputu Village, near Talasea
# 4962                                             Broome
# 2317                                             Madang
#
#                          Activity  \
# 4212                       Wading
# 4190                      Fishing
# 2478                     Swimming
# 993                       Surfing
# 3027                          NaN
# 1804                   Snorkeling
# 4078                     Standing
# 3482                      Surfing
# 3041                     Swimming
# 820                       Surfing
# 880                       Surfing
# 5381          Fell into the water
# 4846                     Swimming
# 3945                     Swimming
# 4510                     Swimming
# 1142                     Fishing
# 5105                     Swimming
# 3610  Spearfishing, shot a turtle
# 4962                 Pearl diving
# 2317                          NaN
#
#                                                    Name Sex   ...  \
# 4212                             Sydney Victor Williams    M  ...
# 4190  16-foot launch, occupants: George Casey, Jack ...  NaN  ...
# 2478                Jorge Durich Heredia (or Hernandez)    M  ...
# 993                                        Andrew Heald    M  ...
# 3027                                   Preston D. Soley    M  ...
# 1804                                        Craig Bovim    M  ...
# 4078                                   Elizabeth Fields    F  ...
# 3482                                          Jan Icyda    M  ...
# 3041                                        Richard Guy    M  ...
# 820                                       Nick Ferguson    M  ...
# 880                                     Tim van Heerden    M  ...
# 5381                            the governor of Cabrera    M  ...
# 4846                                    Jorge Fernandez    M  ...
# 3945                            Serame "Petrus" Sithole    M  ...
# 4510                                                Ali    M  ...
# 1142                                          Tony Dell    M  ...
# 5105                                        Jim Stevens    M  ...
# 3610                                             Kaleva    M  ...
# 4962                                                NaN    M  ...
# 2317                                    a father of six    M  ...
#
#                   Time                             Investigator or Source  \
# 4212               NaN                    Col. C. Maritz, M. Levine, GSAF
# 4190               NaN                                The Age, 11/04/1957
# 2478             08h00  Orlando Sentinel, 9/5/1993, p. A.22 citing El ...
# 993              09h00  S. Petersohn;            M. Johnson, Daytona B...
# 3027               NaN        J. Borg, p.74; L. Taylor (1993), pp.104-105
# 1804  Just after 12h00                                          IOL.co.za
# 4078             18h00             McCutcheon; News (Savannah) 8/18/1959
# 3482         Afternoon               H.D. Baldridge (1994) SAF Case #1548
# 3041             17h20                            R. Guy, M. Levine, GSAF
# 820              12h00                     Sunshine Coast Daily, 2/7/2012
# 880              09h11                                  News24, 8/23/2011
# 5381               NaN                                     C. Moore. GSAF
# 4846               NaN                             The Gleaner, 8/12/1937
# 3945             16h30  D. Davies & J. D'Aubrey; D. Davies, pp. 108-10...
# 4510               NaN  A. Anderson, M.D. / Lt. Col. R.S. Hunt, Royal ...
# 1142               NaN             The Herald (Port Elizabeth), 3/27/2007
# 5105               NaN                    Ludington Daily News, 6/24/1928
# 3610               NaN                 Morning Herald (Sydney) 10/17/1965
# 4962               NaN                           Canberra Times, 7/6/1933
# 2317               NaN                 Sunday Mail (QLD), 2/11/1996, p.28
#
#      original order Case Number.1 Case Number.2  \
# 4212         2093.0    1957.01.05    1957.01.05
# 4190         2115.0  1957.11.04.R  1957.11.04.R
# 2478         3827.0    1993.09.03    1993.09.03
# 993          5311.0  2010.09.03.a  2010.09.03.a
# 3027         3278.0    1981.06.12    1981.06.12
# 1804         4500.0    2002.12.24    2002.12.24
# 4078         2227.0    1959.08.10    1959.08.10
# 3482         2823.0    1968.03.10    1968.03.10
# 3041         3264.0    1981.02.19    1981.02.19
# 820          5484.0    2012.02.06    2012.02.06
# 880          5424.0    2011.08.23    2011.08.23
# 5381          924.0    1912.00.00    1912.00.00
# 4846         1459.0    1937.08.02    1937.08.02
# 3945         2360.0    1960.12.24    1960.12.24
# 4510         1795.0    1949.07.28    1949.07.28
# 1142         5162.0    2009.03.27    2009.03.27
# 5105         1200.0  1928.06.24.R  1928.06.24.R
# 3610         2695.0    1965.10.10    1965.10.10
# 4962         1343.0    1933.07.03    1933.07.03
# 2317         3988.0  1996.02.10.c  1996.02.10.c
#
#                                         pdf  \
# 4212                1957.01.05-Williams.pdf
# 4190        1957.11.04.R-Fishing-launch.pdf
# 2478                 1993.09.03-Heredia.pdf
# 993                  2010.09.03.a-Heald.pdf
# 3027                   1981.06.12-Soley.pdf
# 1804                   2002.12.24-Bovim.pdf
# 4078                  1959.08.10-Fields.pdf
# 3482                   1968.03.10-Icyda.pdf
# 3041                     1981.02.19-Guy.pdf
# 820                 2012.02.06-Ferguson.pdf
# 880               2011.08.23-VanHeerden.pdf
# 5381  1912.00.00-Isla-Cabrera-Balearics.pdf
# 4846               1937.08.02-Fernandez.pdf
# 3945                 1960.12.24-Sithole.pdf
# 4510                     1949.07.28-Ali.pdf
# 1142                2009.03.27-TonyDell.pdf
# 5105               1928.06.24.R-Stevens.pdf
# 3610                  1965.10.10-Kaleva.pdf
# 4962      1933.07.03-Pearl-diver-Broome.pdf
# 2317             1996.02.10.c-PNGfather.pdf
#
#                                            href formula  \
# 4212  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4190  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2478  http://sharkattackfile.net/spreadsheets/pdf_di...
# 993   http://sharkattackfile.net/spreadsheets/pdf_di...
# 3027  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1804  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4078  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3482  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3041  http://sharkattackfile.net/spreadsheets/pdf_di...
# 820   http://sharkattackfile.net/spreadsheets/pdf_di...
# 880   http://sharkattackfile.net/spreadsheets/pdf_di...
# 5381  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4846  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3945  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4510  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1142  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5105  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3610  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4962  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2317  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Unnamed: 22  \
# 4212  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4190  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2478  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 993   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3027  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1804  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4078  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3482  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3041  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 820   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 880   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5381  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4846  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3945  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4510  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1142  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5105  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3610  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4962  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2317  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
#
#      Unnamed: 23
# 4212         NaN
# 4190         NaN
# 2478         NaN
# 993          NaN
# 3027         NaN
# 1804         NaN
# 4078         NaN
# 3482         NaN
# 3041         NaN
# 820          NaN
# 880          NaN
# 5381         NaN
# 4846         NaN
# 3945         NaN
# 4510         NaN
# 1142         NaN
# 5105         NaN
# 3610         NaN
# 4962         NaN
# 2317         NaN
#
# [20 rows x 23 columns]

# %%
shark_clean['Date'] = pd.to_datetime(shark_clean['Date'], errors='coerce', infer_datetime_format=True)
shark_clean.dtypes
# Out:
# Case Number                       object
# Date                      datetime64[ns]
# Year                             float64
# Type                              object
# Country                           object
# Area                              object
# Location                          object
# Activity                          object
# Name                              object
# Sex                               object
# Age                               object
# Fatal (Y/N)                       object
# Species                           object
# Time                              object
# Investigator or Source            object
# original order                   float64
# Case Number.1                     object
# Case Number.2                     object
# pdf                               object
# href formula                      object
# href                              object
# Unnamed: 22                       object
# Unnamed: 23                       object
# dtype: object

# %%
shark_clean.head()
# Out:
#   Case Number       Date    Year        Type    Country             Area  \
# 0  2018.06.25 2018-06-25  2018.0     Boating        USA       California
# 1  2018.06.18 2018-06-18  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09 2018-06-09  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08 2018-06-08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04 2018-06-04  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
#             Time          Investigator or Source original order Case Number.1  \
# 0          18h00                R. Collier, GSAF         6303.0    2018.06.25
# 1  14h00  -15h00  K.McMurray, TrackingSharks.com         6302.0    2018.06.18
# 2          07h45  K.McMurray, TrackingSharks.com         6301.0    2018.06.09
# 3            NaN                  B. Myatt, GSAF         6300.0    2018.06.08
# 4            NaN                       A .Kipper         6299.0    2018.06.04
#
#   Case Number.2                       pdf  \
# 0    2018.06.25      2018.06.25-Wolfe.pdf
# 1    2018.06.18    2018.06.18-McNeely.pdf
# 2    2018.06.09     2018.06.09-Denges.pdf
# 3    2018.06.08  2018.06.08-Arrawarra.pdf
# 4    2018.06.04      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Unnamed: 22 Unnamed: 23
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# # limpieza de year

# %%
'''
convierte los valores de años a str
'''
shark_clean['Year']=shark_clean['Year'].fillna(shark_clean['Year'].mean())
shark_clean.head(10)
# Out:
#   Case Number       Date         Year                     Type    Country  \
# 0  2018.06.25 2018-06-25  2018.000000                  Boating        USA
# 1  2018.06.18 2018-06-18  2018.000000               Unprovoked        USA
# 2  2018.06.09 2018-06-09  2018.000000                  Invalid        USA
# 3  2018.06.08 2018-06-08  2018.000000               Unprovoked  AUSTRALIA
# 4  2018.06.04 2018-06-04  2018.000000                 Provoked     MEXICO
# 5  2018.06.03 2018-06-03  2018.000000               Unprovoked  AUSTRALIA
# 6  2010.01.01        NaT  1926.970957  No injury, board bitten          N
# 7  2018.06.03 2018-06-03  2018.000000               Unprovoked     BRAZIL
# 8  2018.05.27 2018-05-27  2018.000000               Unprovoked        USA
# 9  2018.05.26 2018-05-26  2018.000000               Unprovoked        USA
#
#               Area                                           Location  \
# 0       California                        Oceanside, San Diego County
# 1          Georgia                     St. Simon Island, Glynn County
# 2           Hawaii                                       Habush, Oahu
# 3  New South Wales                                 Arrawarra Headland
# 4           Colima                                           La Ticla
# 5  New South Wales                                 Flat Rock, Ballina
# 6              NaN                                                NaN
# 7       Pernambuco                              Piedade Beach, Recife
# 8          Florida  Lighhouse Point Park, Ponce Inlet, Volusia County
# 9          Florida                       Cocoa Beach, Brevard  County
#
#                     Activity                       Name  \
# 0                   Paddling                Julie Wolfe
# 1                   Standing            Adyson McNeely
# 2                    Surfing                John Denges
# 3                    Surfing                       male
# 4                Free diving             Gustavo Ramos
# 5               Kite surfing                     Chris
# 6  Daily Telegraph, 6/4/2018  2018.06.03.b-FlatRock.pdf
# 7                   Swimming     Jose Ernesto da Silva
# 8                    Fishing                       male
# 9                    Walking                  Cody High
#
#                                                 Sex   ...            Time  \
# 0                                                  F  ...           18h00
# 1                                                  F  ...   14h00  -15h00
# 2                                                  M  ...           07h45
# 3                                                  M  ...             NaN
# 4                                                  M  ...             NaN
# 5                                                NaN  ...             NaN
# 6  http://sharkattackfile.net/spreadsheets/pdf_di...  ...            6298
# 7                                                  M  ...  Late afternoon
# 8                                                  M  ...             NaN
# 9                                                  M  ...           17h00
#
#             Investigator or Source original order Case Number.1 Case Number.2  \
# 0                 R. Collier, GSAF         6303.0    2018.06.25    2018.06.25
# 1   K.McMurray, TrackingSharks.com         6302.0    2018.06.18    2018.06.18
# 2   K.McMurray, TrackingSharks.com         6301.0    2018.06.09    2018.06.09
# 3                   B. Myatt, GSAF         6300.0    2018.06.08    2018.06.08
# 4                        A .Kipper         6299.0    2018.06.04    2018.06.04
# 5                              NaN            NaN           NaN           NaN
# 6                              NaN            NaN           NaN           NaN
# 7   Diario de Pernambuco, 6/4/2018         6297.0  2018.06.03.a  2018.06.03.a
# 8  K. McMurray, TrackingSharks.com         6296.0    2018.05.27    2018.05.27
# 9   K.McMurray, TrackingSharks.com         6295.0  2018.05.26.b  2018.05.26.b
#
#                         pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
# 5                       NaN
# 6                       NaN
# 7  2018.06.03.a-daSilva.pdf
# 8      2018.05.27-Ponce.pdf
# 9     2018.05.26.b-High.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5                                                NaN
# 6                                                NaN
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Unnamed: 22 Unnamed: 23
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 5                                                NaN         NaN         NaN
# 6                                                NaN         NaN         NaN
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
#
# [10 rows x 23 columns]

# %%
shark_clean['Year']= shark_clean['Year'].astype({'Year':'str'})
shark_clean.head(10)
# Out:
#   Case Number       Date                Year                     Type  \
# 0  2018.06.25 2018-06-25              2018.0                  Boating
# 1  2018.06.18 2018-06-18              2018.0               Unprovoked
# 2  2018.06.09 2018-06-09              2018.0                  Invalid
# 3  2018.06.08 2018-06-08              2018.0               Unprovoked
# 4  2018.06.04 2018-06-04              2018.0                 Provoked
# 5  2018.06.03 2018-06-03              2018.0               Unprovoked
# 6  2010.01.01        NaT  1926.9709569909537  No injury, board bitten
# 7  2018.06.03 2018-06-03              2018.0               Unprovoked
# 8  2018.05.27 2018-05-27              2018.0               Unprovoked
# 9  2018.05.26 2018-05-26              2018.0               Unprovoked
#
#      Country             Area  \
# 0        USA       California
# 1        USA          Georgia
# 2        USA           Hawaii
# 3  AUSTRALIA  New South Wales
# 4     MEXICO           Colima
# 5  AUSTRALIA  New South Wales
# 6          N              NaN
# 7     BRAZIL       Pernambuco
# 8        USA          Florida
# 9        USA          Florida
#
#                                             Location  \
# 0                        Oceanside, San Diego County
# 1                     St. Simon Island, Glynn County
# 2                                       Habush, Oahu
# 3                                 Arrawarra Headland
# 4                                           La Ticla
# 5                                 Flat Rock, Ballina
# 6                                                NaN
# 7                              Piedade Beach, Recife
# 8  Lighhouse Point Park, Ponce Inlet, Volusia County
# 9                       Cocoa Beach, Brevard  County
#
#                     Activity                       Name  \
# 0                   Paddling                Julie Wolfe
# 1                   Standing            Adyson McNeely
# 2                    Surfing                John Denges
# 3                    Surfing                       male
# 4                Free diving             Gustavo Ramos
# 5               Kite surfing                     Chris
# 6  Daily Telegraph, 6/4/2018  2018.06.03.b-FlatRock.pdf
# 7                   Swimming     Jose Ernesto da Silva
# 8                    Fishing                       male
# 9                    Walking                  Cody High
#
#                                                 Sex   ...            Time  \
# 0                                                  F  ...           18h00
# 1                                                  F  ...   14h00  -15h00
# 2                                                  M  ...           07h45
# 3                                                  M  ...             NaN
# 4                                                  M  ...             NaN
# 5                                                NaN  ...             NaN
# 6  http://sharkattackfile.net/spreadsheets/pdf_di...  ...            6298
# 7                                                  M  ...  Late afternoon
# 8                                                  M  ...             NaN
# 9                                                  M  ...           17h00
#
#             Investigator or Source original order Case Number.1 Case Number.2  \
# 0                 R. Collier, GSAF         6303.0    2018.06.25    2018.06.25
# 1   K.McMurray, TrackingSharks.com         6302.0    2018.06.18    2018.06.18
# 2   K.McMurray, TrackingSharks.com         6301.0    2018.06.09    2018.06.09
# 3                   B. Myatt, GSAF         6300.0    2018.06.08    2018.06.08
# 4                        A .Kipper         6299.0    2018.06.04    2018.06.04
# 5                              NaN            NaN           NaN           NaN
# 6                              NaN            NaN           NaN           NaN
# 7   Diario de Pernambuco, 6/4/2018         6297.0  2018.06.03.a  2018.06.03.a
# 8  K. McMurray, TrackingSharks.com         6296.0    2018.05.27    2018.05.27
# 9   K.McMurray, TrackingSharks.com         6295.0  2018.05.26.b  2018.05.26.b
#
#                         pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
# 5                       NaN
# 6                       NaN
# 7  2018.06.03.a-daSilva.pdf
# 8      2018.05.27-Ponce.pdf
# 9     2018.05.26.b-High.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5                                                NaN
# 6                                                NaN
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Unnamed: 22 Unnamed: 23
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 5                                                NaN         NaN         NaN
# 6                                                NaN         NaN         NaN
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
#
# [10 rows x 23 columns]

# %%
shark_clean['Year'] = shark_clean['Year'].str.replace('\.[0-9]+','',regex=True)
shark_clean.head(10)
# Out:
#   Case Number       Date  Year                     Type    Country  \
# 0  2018.06.25 2018-06-25  2018                  Boating        USA
# 1  2018.06.18 2018-06-18  2018               Unprovoked        USA
# 2  2018.06.09 2018-06-09  2018                  Invalid        USA
# 3  2018.06.08 2018-06-08  2018               Unprovoked  AUSTRALIA
# 4  2018.06.04 2018-06-04  2018                 Provoked     MEXICO
# 5  2018.06.03 2018-06-03  2018               Unprovoked  AUSTRALIA
# 6  2010.01.01        NaT  1926  No injury, board bitten          N
# 7  2018.06.03 2018-06-03  2018               Unprovoked     BRAZIL
# 8  2018.05.27 2018-05-27  2018               Unprovoked        USA
# 9  2018.05.26 2018-05-26  2018               Unprovoked        USA
#
#               Area                                           Location  \
# 0       California                        Oceanside, San Diego County
# 1          Georgia                     St. Simon Island, Glynn County
# 2           Hawaii                                       Habush, Oahu
# 3  New South Wales                                 Arrawarra Headland
# 4           Colima                                           La Ticla
# 5  New South Wales                                 Flat Rock, Ballina
# 6              NaN                                                NaN
# 7       Pernambuco                              Piedade Beach, Recife
# 8          Florida  Lighhouse Point Park, Ponce Inlet, Volusia County
# 9          Florida                       Cocoa Beach, Brevard  County
#
#                     Activity                       Name  \
# 0                   Paddling                Julie Wolfe
# 1                   Standing            Adyson McNeely
# 2                    Surfing                John Denges
# 3                    Surfing                       male
# 4                Free diving             Gustavo Ramos
# 5               Kite surfing                     Chris
# 6  Daily Telegraph, 6/4/2018  2018.06.03.b-FlatRock.pdf
# 7                   Swimming     Jose Ernesto da Silva
# 8                    Fishing                       male
# 9                    Walking                  Cody High
#
#                                                 Sex   ...            Time  \
# 0                                                  F  ...           18h00
# 1                                                  F  ...   14h00  -15h00
# 2                                                  M  ...           07h45
# 3                                                  M  ...             NaN
# 4                                                  M  ...             NaN
# 5                                                NaN  ...             NaN
# 6  http://sharkattackfile.net/spreadsheets/pdf_di...  ...            6298
# 7                                                  M  ...  Late afternoon
# 8                                                  M  ...             NaN
# 9                                                  M  ...           17h00
#
#             Investigator or Source original order Case Number.1 Case Number.2  \
# 0                 R. Collier, GSAF         6303.0    2018.06.25    2018.06.25
# 1   K.McMurray, TrackingSharks.com         6302.0    2018.06.18    2018.06.18
# 2   K.McMurray, TrackingSharks.com         6301.0    2018.06.09    2018.06.09
# 3                   B. Myatt, GSAF         6300.0    2018.06.08    2018.06.08
# 4                        A .Kipper         6299.0    2018.06.04    2018.06.04
# 5                              NaN            NaN           NaN           NaN
# 6                              NaN            NaN           NaN           NaN
# 7   Diario de Pernambuco, 6/4/2018         6297.0  2018.06.03.a  2018.06.03.a
# 8  K. McMurray, TrackingSharks.com         6296.0    2018.05.27    2018.05.27
# 9   K.McMurray, TrackingSharks.com         6295.0  2018.05.26.b  2018.05.26.b
#
#                         pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
# 5                       NaN
# 6                       NaN
# 7  2018.06.03.a-daSilva.pdf
# 8      2018.05.27-Ponce.pdf
# 9     2018.05.26.b-High.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5                                                NaN
# 6                                                NaN
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Unnamed: 22 Unnamed: 23
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 5                                                NaN         NaN         NaN
# 6                                                NaN         NaN         NaN
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
#
# [10 rows x 23 columns]

# %%
shark_clean['Year'] = shark_clean['Year'].apply(pd.to_numeric)
shark_clean.sample(10)
# Out:
#      Case Number       Date  Year        Type          Country  \
# 5893  1873.06.09        NaT  1873     Invalid        AUSTRALIA
# 2442  1994.04.15 1994-04-15  1994  Unprovoked          REUNION
# 4555  1948.02.12 1948-02-12  1948  Unprovoked        AUSTRALIA
# 1896  2001.10.02 2001-10-02  2001  Unprovoked        AUSTRALIA
# 1442  2006.08.22 2006-08-22  2006     Invalid           BRAZIL
# 5853  1877.12.15 1877-12-15  1877  Unprovoked        AUSTRALIA
# 1845  2002.07.09 2002-07-10  2002  Unprovoked           BRAZIL
# 4034  1960.00.00        NaT  1960  Unprovoked       MOZAMBIQUE
# 6006  1855.02.12        NaT  1855  Unprovoked  SOLOMON ISLANDS
# 2356  1995.08.22 1995-08-22  1995  Unprovoked              USA
#
#                        Area                                Location  \
# 5893        New South Wales                              Newcastle
# 2442           Saint-Joseph                        Lieu-dit Cayenne
# 4555        New South Wales               Stockton Beach, Newcastle
# 1896             Queensland                      200 miles offshore
# 1442             Pernambuco                                    Pina
# 5853        New South Wales          Peacock Point, Balmain, Sydney
# 1845             Pernambuco                   Piedade Beach, Recife
# 4034                   Gaza                                 Xai Xai
# 6006  Makira-Ulawa Province  Makira Island (Formerly San Cristobal)
# 2356                Florida     Ponce de Leon Inlet, Volusia County
#
#         Activity                           Name Sex   ...   Time  \
# 5893     Bathing                   Joseph Henry    M  ...    NaN
# 2442         NaN                            NaN  NaN  ...    NaN
# 4555    Swimming                 Ronald Johnson    M  ...    NaN
# 1896  Snorkeling                Katherine Jones    F  ...  13h00
# 1442         NaN          Tatiano Silva de Melo    M  ...    NaN
# 5853     Bathing          Albert Thomas Burless    M  ...    NaN
# 1845     Surfing  Mário César Carneiro da Silva    M  ...  15h00
# 4034    Swimming                  Miss Fillardo    F  ...    NaN
# 6006   Swimming                            male    M  ...    NaN
# 2356     Surfing                    Jason Barzo    M  ...  19h00
#
#                                  Investigator or Source original order  \
# 5893                              The Mercury, 6/9/1873          412.0
# 2442                                 G. Van Grevelynghe         3863.0
# 4555  G.P. Whitley (1951), p.193; V.M. Coppleson (19...         1750.0
# 1896                                           K. Jones         4408.0
# 1442                                 JC Oline 8/24/2006         4862.0
# 5853  Sydney Mail, 2/16/1878; G.P. Whitley, (1951) p...          452.0
# 1845                                   P.M. Lopes, GSAF         4459.0
# 4034                                    M. Levine, GSAF         2271.0
# 6006                    The Hobarton Mercury, 2/12/1855          299.0
# 2356    C. Lancaster, Orlando Sentinel, 8/24/1995, p.D1         3949.0
#
#      Case Number.1 Case Number.2                             pdf  \
# 5893  1873.06.09.R  1873.06.09.R          1873.06.09.R-Henry.pdf
# 2442    1994.04.15    1994.04.15          1994.04.15-Reunion.pdf
# 4555    1948.02.12    1948.02.12          1948.02.12-Johnson.pdf
# 1896    2001.10.02    2001.10.02  2001.10.02-Katherine-Jones.pdf
# 1442  2006.08.22.b  2006.08.22.b           2006.08.22.b-Melo.pdf
# 5853    1877.12.15    1877.12.15          1877.12.15-Burless.pdf
# 1845  2002.07.09.a  2002.07.09.a        2002.07.09.a-daSilva.pdf
# 4034  1960.00.00.b  1960.00.00.b       1960.00.00.b-Fillardo.pdf
# 6006  1855.02.12.R  1855.02.12.R         1855.02.12.R-Native.pdf
# 2356  1995.08.22.a  1995.08.22.a          1995.08.22.a-Barzo.pdf
#
#                                            href formula  \
# 5893  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2442  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4555  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1896  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1442  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5853  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1845  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4034  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6006  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2356  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Unnamed: 22  \
# 5893  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2442  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4555  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1896  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1442  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5853  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1845  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4034  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6006  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2356  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
#
#      Unnamed: 23
# 5893         NaN
# 2442         NaN
# 4555         NaN
# 1896         NaN
# 1442         NaN
# 5853         NaN
# 1845         NaN
# 4034         NaN
# 6006         NaN
# 2356         NaN
#
# [10 rows x 23 columns]

# %%
shark_clean['Year'] = shark_clean['Year'].astype({'Year':'int'})
shark_clean.dtypes
# Out:
# Case Number                       object
# Date                      datetime64[ns]
# Year                               int64
# Type                              object
# Country                           object
# Area                              object
# Location                          object
# Activity                          object
# Name                              object
# Sex                               object
# Age                               object
# Fatal (Y/N)                       object
# Species                           object
# Time                              object
# Investigator or Source            object
# original order                   float64
# Case Number.1                     object
# Case Number.2                     object
# pdf                               object
# href formula                      object
# href                              object
# Unnamed: 22                       object
# Unnamed: 23                       object
# dtype: object

# %%
aux_fun = lambda x : int(x)
shark_clean['Year'] = shark_clean['Year'].map(aux_fun)
shark_clean.head(10)
# Out:
#   Case Number       Date  Year                     Type    Country  \
# 0  2018.06.25 2018-06-25  2018                  Boating        USA
# 1  2018.06.18 2018-06-18  2018               Unprovoked        USA
# 2  2018.06.09 2018-06-09  2018                  Invalid        USA
# 3  2018.06.08 2018-06-08  2018               Unprovoked  AUSTRALIA
# 4  2018.06.04 2018-06-04  2018                 Provoked     MEXICO
# 5  2018.06.03 2018-06-03  2018               Unprovoked  AUSTRALIA
# 6  2010.01.01        NaT  1926  No injury, board bitten          N
# 7  2018.06.03 2018-06-03  2018               Unprovoked     BRAZIL
# 8  2018.05.27 2018-05-27  2018               Unprovoked        USA
# 9  2018.05.26 2018-05-26  2018               Unprovoked        USA
#
#               Area                                           Location  \
# 0       California                        Oceanside, San Diego County
# 1          Georgia                     St. Simon Island, Glynn County
# 2           Hawaii                                       Habush, Oahu
# 3  New South Wales                                 Arrawarra Headland
# 4           Colima                                           La Ticla
# 5  New South Wales                                 Flat Rock, Ballina
# 6              NaN                                                NaN
# 7       Pernambuco                              Piedade Beach, Recife
# 8          Florida  Lighhouse Point Park, Ponce Inlet, Volusia County
# 9          Florida                       Cocoa Beach, Brevard  County
#
#                     Activity                       Name  \
# 0                   Paddling                Julie Wolfe
# 1                   Standing            Adyson McNeely
# 2                    Surfing                John Denges
# 3                    Surfing                       male
# 4                Free diving             Gustavo Ramos
# 5               Kite surfing                     Chris
# 6  Daily Telegraph, 6/4/2018  2018.06.03.b-FlatRock.pdf
# 7                   Swimming     Jose Ernesto da Silva
# 8                    Fishing                       male
# 9                    Walking                  Cody High
#
#                                                 Sex   ...            Time  \
# 0                                                  F  ...           18h00
# 1                                                  F  ...   14h00  -15h00
# 2                                                  M  ...           07h45
# 3                                                  M  ...             NaN
# 4                                                  M  ...             NaN
# 5                                                NaN  ...             NaN
# 6  http://sharkattackfile.net/spreadsheets/pdf_di...  ...            6298
# 7                                                  M  ...  Late afternoon
# 8                                                  M  ...             NaN
# 9                                                  M  ...           17h00
#
#             Investigator or Source original order Case Number.1 Case Number.2  \
# 0                 R. Collier, GSAF         6303.0    2018.06.25    2018.06.25
# 1   K.McMurray, TrackingSharks.com         6302.0    2018.06.18    2018.06.18
# 2   K.McMurray, TrackingSharks.com         6301.0    2018.06.09    2018.06.09
# 3                   B. Myatt, GSAF         6300.0    2018.06.08    2018.06.08
# 4                        A .Kipper         6299.0    2018.06.04    2018.06.04
# 5                              NaN            NaN           NaN           NaN
# 6                              NaN            NaN           NaN           NaN
# 7   Diario de Pernambuco, 6/4/2018         6297.0  2018.06.03.a  2018.06.03.a
# 8  K. McMurray, TrackingSharks.com         6296.0    2018.05.27    2018.05.27
# 9   K.McMurray, TrackingSharks.com         6295.0  2018.05.26.b  2018.05.26.b
#
#                         pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
# 5                       NaN
# 6                       NaN
# 7  2018.06.03.a-daSilva.pdf
# 8      2018.05.27-Ponce.pdf
# 9     2018.05.26.b-High.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5                                                NaN
# 6                                                NaN
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Unnamed: 22 Unnamed: 23
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 5                                                NaN         NaN         NaN
# 6                                                NaN         NaN         NaN
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
#
# [10 rows x 23 columns]

# %%
shark_clean.dtypes
# Out:
# Case Number                       object
# Date                      datetime64[ns]
# Year                               int64
# Type                              object
# Country                           object
# Area                              object
# Location                          object
# Activity                          object
# Name                              object
# Sex                               object
# Age                               object
# Fatal (Y/N)                       object
# Species                           object
# Time                              object
# Investigator or Source            object
# original order                   float64
# Case Number.1                     object
# Case Number.2                     object
# pdf                               object
# href formula                      object
# href                              object
# Unnamed: 22                       object
# Unnamed: 23                       object
# dtype: object

# %% [markdown]
# # limpieza de type

# %%
shark_clean['Type']= shark_clean['Type'].str.replace('Invalid|0','Unknown',regex=True).fillna('Unknown')
shark_clean.sample(60)
# Out:
#      Case
# 1317  2007.10.15 2007-10-15  2007    Unprovoked             AUSTRALIA
# 4454  1951.01.21 1951-01-21  1951    Unprovoked          SOUTH AFRICA
# 1992  2000.11.10 2000-11-10  2000       Unknown                   USA
# 4421  1952.00.00        NaT  1952    Unprovoked      PAPUA NEW GUINEA
# 3404  1970.01.23 1970-01-23  1970    Unprovoked            MOZAMBIQUE
# 1296  2008.01.19        NaT  2008       Unknown           NEW ZEALAND
# 316   2016.01.24 2016-01-24  2016       Boating  UNITED ARAB EMIRATES
# 888   2011.08.15 2011-08-15  2011       Unknown                   USA
# 4061  1959.09.26 1959-09-26  1959  Sea Disaster                   USA
# 3718  1963.12.26 1963-12-26  1963    Unprovoked          SOUTH AFRICA
# 3179  1976.07.24 1976-07-24  1976    Unprovoked                   USA
# 3564  1966.08.14 1966-08-14  1966    Unprovoked                TAIWAN
# 3968  1960.08.30 1960-08-30  1960    Unprovoked                   USA
# 394   2015.07.04 2015-07-04  2015    Unprovoked               BAHAMAS
# 2276  1996.10.28 1996-10-28  1996    Unprovoked                BRAZIL
#
#                                    Area  \
# 4104                    New South Wales
# 3128              Eastern Cape Province
# 2659                           Tasmania
# 1853                            Florida
# 691                     New South Wales
# 4735                          Off Libya
# 5936                           New York
# 5843       Off the coast of West Africa
# 3318                         Queensland
# 3284                               Gaza
# 2125                         Pernambuco
# 4044   400 miles southeast of Sri Lanka
# 3631                         California
# 5371                   Central Province
# 2009                     South Carolina
# 2005                    South Australia
# 5167                     South Carolina
# 273                          California
# 2828              Eastern Cape Province
# 1660                            Alabama
# 401                      North Carolina
# 3532                      KwaZulu-Natal
# 1882                         Queensland
# 4564                    South Australia
# 896                        Saint-Gilles
# 3478                    New South Wales
# 181                              Bimini
# 3930                    New South Wales
# 200                              Hawaii
# 2402                         Pernambuco
# 3322                    New South Wales
# 4628                           Tel Aviv
# 5816                         Queensland
# 4354                                NaN
# 6049                     South Carolina
# 856                   Western Australia
# 5306                         New Jersey
# 2281                         Pernambuco
# 725                              Hawaii
# 5088                    New South Wales
# 5871                      Mount Lebanon
# 5952                            Sumatra
# 5229                    Kingston Parish
# 5681                           Brittany
# 277                             Florida
# 1317                    New South Wales
# 4454                      KwaZulu-Natal
# 1992                            Florida
# 4421  Admiralty Islands, Manus Province
# 3404                      Limpopo River
# 1296                       South Island
# 316                    Fujairah Emirate
# 888                      South Carolina
# 4061                            Florida
# 3718                      KwaZulu-Natal
# 3179                            Florida
# 3564                                NaN
# 3968                         New Jersey
# 394                 Grand Bahama Island
# 2276                         Pernambuco
#
#                                                Location  \
# 4104                                           Thirroul
# 3128                             Gulu Deep, East London
# 2659                                      Shelly Point
# 1853                St Augustine Beach, St Johns County
# 691                                      Terrigal Beach
# 4735                                                NaN
# 5936                       Greenport Sound, Long Island
# 5843                                                NaN
# 3318                                     Currumbin Rock
# 3284                                            Xai Xai
# 2125                           Boa Viagem Beach, Recife
# 4044                                                NaN
# 3631                         Pacifica, San Mateo County
# 5371                                               Savo
# 2009                   Isle of Palms, Charleston County
# 2005                        Black Point, Eyre Peninsula
# 5167                      Folly Island, near Charleston
# 273              Corona Del Mar, Newport, Orange County
# 2828                                        Cape Recife
# 1660                  Gulf Shores Beach, Baldwin County
# 401                               Rodanthe, Dare County
# 3532                                      Paradise Reef
# 1882                                     Sunshine Beach
# 4564                     3 miles out to sea off Glenelg
# 896                                          Brisants.
# 3478                                        South Coast
# 181                                                 NaN
# 3930                                        Cook Island
# 200                          Kamaole Beach Park I, Maui
# 2402                                            Piedade
# 3322                                     Tabourie Beach
# 4628                                                NaN
# 5816                       Petrie Bight, Brisbane River
# 4354                                                NaN
# 6049                                                NaN
# 856                                     Cottesloe Beach
# 5306  In Matawan Creek, off NJ Clay Company brickyar...
# 2281                                                NaN
# 725                                Makena Landing, Maui
# 5088                                              Bondi
# 5871                                            Batroun
# 5952                                    Off Acheen Head
# 5229                                    Kingston Harbor
# 5681                                              Brest
# 277          Hugenot Beach , Jacksonville, Duval County
# 1317                                          Byron Bay
# 4454                               Native Beach, Durban
# 1992                       Vaughn Beach, Flagler County
# 4421                                       Manus Island
# 3404                              Gijana, 150 km inland
# 1296                                     Marfells Beach
# 316                               35 miles off Fujairah
# 888                          Myrtle Beach, Horry County
# 4061                Off Port Everglades, Broward County
# 3718                                     Umhlanga Rocks
# 3179                                   St. Lucie County
# 3564                                            Ye Leow
# 3968                        Ocean City, Cape May County
# 394                               Port Lucaya, Freeport
# 2276                                   Barra de Jangada
#
#                                                Activity  \
# 4104                                       Spearfishing
# 3128                                                NaN
# 2659                                            Surfing
# 1853                                            Surfing
# 691                                             Surfing
# 4735      HMAS Parramatta torpedoed & sunk by the U-559
# 5936   Swimming alongside the schooner Catherine Wilcox
# 5843  Boat with 5 men capsized while returning to th...
# 3318                                                NaN
# 3284                                           Swimming
# 2125                                            Surfing
# 4044      17 Maldivians adrift in open boat for 31 days
# 3631                                            Surfing
# 5371                                            Bathing
# 2009                                                NaN
# 2005                                            Surfing
# 5167                                           Swimming
# 273                                            Swimming
# 2828                                            Surfing
# 1660                                             Wading
# 401                                            Swimming
# 3532                                       Spearfishing
# 1882                                            Surfing
# 4564                                            Fishing
# 896                             Kayaking or Wave skiing
# 3478  Diving. Shark swallowed his hand, so he thre...
# 181                                        Scuba Diving
# 3930                      Collecting aquarium specimens
# 200                                            Floating
# 2402                                            Surfing
# 3322                                            Surfing
# 4628                                           Swimming
# 5816                                           Swimming
# 4354                                                NaN
# 6049                                            Boating
# 856                                            Swimming
# 5306                                           Swimming
# 2281                                                NaN
# 725                                              Diving
# 5088                                       Body surfing
# 5871                                      Sponge diving
# 5952                        Reaching for life preserver
# 5229                                            Fishing
# 5681                                       Fishing boat
# 277                                            Swimming
# 1317                                        Surf-skiing
# 4454                                           Swimming
# 1992                                            Walking
# 4421                                       Spearfishing
# 3404                                           Swimming
# 1296                                             Wading
# 316                                             Fishing
# 888                                 Playing in the surf
# 4061  Adrift, hanging onto cushion, after his 17' sk...
# 3718                                          Swimming
# 3179                                       Spearfishing
# 3564                         Lobster diving using Scuba
# 3968                          Swimming 3 miles offshore
# 394                                        Spearfishing
# 2276                                            Surfing
#
#                                              Name Sex   ...          Time  \
# 4104                                 Jeff McAuley    M  ...           NaN
# 3128   6 m skiboat, occupants: P.A. Reeder & crew  NaN  ...           NaN
# 2659                                Steven Jillet    M  ...         14h20
# 1853                                  Jason Smith    M  ...         13h00
# 691                              Richard Tognetti    M  ...           NaN
# 4735                                    Bill Nash    M  ...           NaN
# 5936                                Peter Johnson    M  ...         09h00
# 5843                               Antonio du Val    M  ...           NaN
# 3318                                  Mark Worman    M  ...           NaN
# 3284                                         male    M  ...           NaN
# 2125                 Charles Heitor Barbosa Pires    M  ...     Afternoon
# 4044                                        child    F  ...           NaN
# 3631                               Michael Sammut    M  ...         16h00
# 5371                                         male    M  ...           NaN
# 2009                                          NaN  NaN  ...           NaN
# 2005                                 Jevan Wright    M  ...         13h00
# 5167                         Mrs. Walter H. Kahrs    F  ...           NaN
# 273                           Maria Korcsmaros \n    F  ...         16h00
# 2828                                    John Fick    M  ...         18h00
# 1660                               Trenton Martin    M  ...         16h40
# 401                                     John Cole    M  ...         16h00
# 3532                                    Len Jones    M  ...         06h50
# 1882                                  Kirk Koster    M  ...  09h00 -10h00
# 4564                                   10' dinghy  NaN  ...           NaN
# 896                                          male    M  ...         17h00
# 3478                                Rodney Castle    M  ...           NaN
# 181                                    Freek Vonk    M  ...           NaN
# 3930                                  Robert Webb    M  ...       Morning
# 200                               Barbara Zawacki    F  ...         10h30
# 2402                     Humberto Moraes de Souza    M  ...           NaN
# 3322                                 Terry Cooper    M  ...           NaN
# 4628                            British constable    M  ...           NaN
# 5816                                 Alexey Drury    M  ...     Afternoon
# 4354                                Bernard Vieux    M  ...           NaN
# 6049                                        adult    M  ...           NaN
# 856                                   Bryn Martin    M  ...         08h10
# 5306                                    John Dunn    M  ...           NaN
# 2281                                Josebias Dias  NaN  ...           NaN
# 725                                   Mark Riglos    M  ...         08h30
# 5088                          Colin James Stewart    M  ...         18h10
# 5871                                         male    M  ...           NaN
# 5952                male, from the ship Speedwell    M  ...         16h00
# 5229                                          NaN    M  ...           NaN
# 5681                                          NaN  NaN  ...           NaN
# 277                                        female    F  ...         17h46
# 1317                             Linda Whitehurst    F  ...         11h30
# 4454                               Hendrie Nkwazi    M  ...         16h25
# 1992                                 Eileen Skeie    F  ...           NaN
# 4421                                         male    M  ...           NaN
# 3404                               Mabua Mogadura    M  ...           NaN
# 1296                              Matthew O'Neill    M  ...           NaN
# 316   Occupants: Hamza Humaid Al Sahraa & 5 crew    M  ...           NaN
# 888                                  Rudy Varney     M  ...           NaN
# 4061                                Robert Walker    M  ...         17h00
# 3718                                Ronnie De Wet    M  ...         15h00
# 3179                                 Charles Cook    M  ...         10h30
# 3564                             Jack W. Caldwell    M  ...         17h30
# 3968                                Richard Chung    M  ...         17h15
# 394                                  Katie Hester    F  ...           NaN
# 2276                        Luis Henrique Messias    M  ...           NaN
#
#                                  Investigator or Source original order  \
# 4104        P. Gilbert, L. Schultz & S. Springer (1960)         2201.0
# 3128                                               GSAF         3177.0
# 2659  Hobart Mercury, 10/23/1989, p.1; C. Black, pp ...         3646.0
http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4354  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6049  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 856   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5306  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2281  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 725   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5088  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5871  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5952  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5229  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5681  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 277   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1317  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4454  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1992  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4421  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3404  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1296  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 316   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 888   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4061  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3718  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3179  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3564  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3968  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 394   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2276  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
#
#      Unnamed: 23
# 4104         NaN
# 3128         NaN
# 2659         NaN
# 1853         NaN
# 691          NaN
# 4735         NaN
# 5936         NaN
# 5843         NaN
# 3318         NaN
# 3284         NaN
# 2125         NaN
# 4044         NaN
# 3631         NaN
# 5371         NaN
# 2009         NaN
# 2005         NaN
# 5167         NaN
# 273          NaN
# 2828         NaN
# 1660         NaN
# 401          NaN
# 3532         NaN
# 1882         NaN
# 4564         NaN
# 896          NaN
# 3478         NaN
# 181          NaN
# 3930         NaN
# 200          NaN
# 2402         NaN
# 3322         NaN
# 4628         NaN
# 5816         NaN
# 4354         NaN
# 6049         NaN
# 856          NaN
# 5306         NaN
# 2281         NaN
# 725          NaN
# 5088         NaN
# 5871         NaN
# 5952         NaN
# 5229         NaN
# 5681         NaN
# 277          NaN
# 1317         NaN
# 4454         NaN
# 1992         NaN
# 4421         NaN
# 3404         NaN
# 1296         NaN
# 316          NaN
# 888          NaN
# 4061         NaN
# 3718         NaN
# 3179         NaN
# 3564         NaN
# 3968         NaN
# 394          NaN
# 2276         NaN
#
# [60 rows x 23 columns]

# %%
shark_clean.dtypes
# Out:
# Case Number                       object
# Date                      datetime64[ns]
# Year                               int64
# Type                              object
# Country                           object
# Area                              object
# Location                          object
# Activity                          object
# Name                              object
# Sex                               object
# Age                               object
# Fatal (Y/N)                       object
# Species                           object
# Time                              object
# Investigator or Source            object
# original order                   float64
# Case Number.1                     object
# Case Number.2                     object
# pdf                               object
# href formula                      object
# href                              object
# Unnamed: 22                       object
# Unnamed: 23                       object
# dtype: object

# %% [markdown]
# # limpieza de country

# %%
shark_clean['Country'] = shark_clean['Country'].fillna('Unknown')
shark_clean.sample(10)
# Out:
#      Case Number       Date  Year          Type           Country  \
# 2093  1999.11.00        NaT  1999    Unprovoked  MARSHALL ISLANDS
# 748   2012.09.02 2012-09-02  2012      Provoked               USA
# 1188  2008.12.00        NaT  2008    Unprovoked        MOZAMBIQUE
# 2706  1988.11.08 1988-11-08  1988  Sea Disaster         AUSTRALIA
# 3985  1960.06.27 1960-06-27  1960      Provoked       NEW ZEALAND
# 2692  1989.03.09 1989-03-09  1989    Unprovoked         AUSTRALIA
# 580   2014.03.02 2014-03-02  2014    Unprovoked               USA
# 4175  1958.00.00        NaT  1958      Provoked             SAMOA
# 1415  2006.12.10 2006-12-10  2006    Unprovoked               USA
# 4573  1947.07.27        NaT  1947      Provoked               USA
#
#                      Area                                           Location  \
# 2093    Alinglaplap Atoll                                         Island J4H
# 748                Hawaii                               Spreckelsville, Maui
# 1188   Inhambane Province                                        Chidenguele
# 2706           Queensland               Off North Keppel Island, off Yeppoon
# 3985          Cook Strait                                       Tory Channel
# 2692      South Australia  Waitpinga Beach, near Victor Harbor, Encounter...
# 580               Florida  Santa Lucea Beach, South Hutchinson Island, St...
# 4175  South Pacific Ocean                           North of Northeast Samoa
# 1415           California                         Dillon Beach, Marin County
# 4573           California                   Santa Monica, Los Angeles County
#
#                                                Activity  \
# 2093                                           Swimming
# 748                                        Spearfishing
# 1188                                       Spearfishing
# 2706  The Christie V sank on 11/6/1988, survivors we...
# 3985                                      Shark fishing
# 2692                                            Surfing
# 580                                             Surfing
# 4175           Placed hand in disemboweled sharks jaws
# 1415                                            Surfing
# 4573                                            Fishing
#
#                        Name Sex   ...           Time  \
# 2093          Morson Daniel    M  ...            NaN
# 748              M. Malabon  NaN  ...          12h00
# 1188           Darryl Kriel    M  ...            NaN
# 2706           Bruce Coucom    M  ...  Early morning
# 3985  boat (a whale chaser)  NaN  ...            NaN
# 2692          Matthew Foale    M  ...          20h15
# 580            Dylan Fugitt    M  ...            NaN
# 4175            Takai Otiai  NaN  ...            NaN
# 1415           Royce Fraley    M  ...          11h50
# 4573            Philip Dorn    M  ...            NaN
#
#                                  Investigator or Source original order  \
# 2093        www.svcherokee.com/pages/ Ailingilaplap.htm         4211.0
# 748                                       HawaiiNow.com         5556.0
# 1188                                          J. Little         5116.0
# 2706                             H. Edwards, pp.115-116         3599.0
# 3985                  The Age, 6/28/1960; SAF Case #772         2320.0
# 2692       Courier-Mail, 3/11/1989, p.5;  J. West, ASAF         3613.0
# 580                          L.Gordon, CBS 12, 3/3/2014         5724.0
# 4175                       V.M. Coppleson (1962), p.248         2130.0
# 1415  P. Immerz; R. Collier; San Francisco Chronicle...         4889.0
# 4573                            Joplin Globe, 7/27/1947         1732.0
#
#      Case Number.1 Case Number.2                               pdf  \
# 2093  1999.11.00.a  1999.11.00.a           1999.11.00.a-Morson.pdf
# 748   2012.09.02.b  2012.09.02.b          2012.09.02.c-Malabon.pdf
# 1188    2008.12.00    2008.12.00              2008.12.00-Kriel.pdf
# 2706    1988.11.08    1988.11.08        1988.11.08-BruceCoucom.pdf
# 3985  1960.06.27.b  1960.06.27.b  1960.06.27-b-Harpooned-shark.pdf
# 2692    1989.03.09    1989.03.09              1989.03.09-Foale.pdf
# 580     2014.03.02    2014.03.02             2014.03.02-Fugitt.pdf
# 4175  1958.00.00.i  1958.00.00.i            1958.00.00.i-Otiai.pdf
# 1415    2006.12.10    2006.12.10            2006.12.10-Frailey.pdf
# 4573  1947.07.27.R  1947.07.27.R       1947.07.27.R-PhilipDorn.pdf
#
#                                            href formula  \
# 2093  http://sharkattackfile.net/spreadsheets/pdf_di...
# 748   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1188  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2706  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3985  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2692  http://sharkattackfile.net/spreadsheets/pdf_di...
# 580   http://sharkattackfile.net/spreadsheets/pdf_di...
# 4175  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1415  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4573  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Unnamed: 22  \
# 2093  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 748   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1188  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2706  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3985  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2692  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 580   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4175  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1415  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4573  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
#
#      Unnamed: 23
# 2093         NaN
# 748          NaN
# 1188         NaN
# 2706         NaN
# 3985         NaN
# 2692         NaN
# 580          NaN
# 4175         NaN
# 1415         NaN
# 4573         NaN
#
# [10 rows x 23 columns]

# %% [markdown]
# # limpieza de Area

# %%
shark_clean['Area'] = shark_clean['Area'].fillna('Unknown')
shark_clean.sample(60)
# Out:
#      Case Number       Date  Year          Type           Country  \
# 5197  1923.11.23 1923-11-23  1923    Unprovoked         AUSTRALIA
# 4295  1955.07.07 1955-07-07  1955    Unprovoked             YEMEN
# 2674  1989.08.09 1989-08-09  1989    Unprovoked           BAHAMAS
# 6073  1839.11.17 1839-11-17  1839       Unknown         AUSTRALIA
# 385   2015.07.26 2015-07-26  2015       Unknown               USA
# 4236  1956.08.25 1956-08-25  1956    Unprovoked  PAPUA NEW GUINEA
# 167   2017.04.02 2017-04-02  2017    Unprovoked               USA
# 5042  1930.07.19 1930-07-19  1930    Unprovoked              CUBA
# 925   2011.05.13 2011-05-13  2011    Unprovoked               USA
# 3168  1976.10.27 1976-10-27  1976          Boat      SOUTH AFRICA
# 2456  1994.01.31 1994-01-31  1994    Unprovoked               USA
# 614   2013.10.11 2013-10-11  2013    Unprovoked      SOUTH AFRICA
# 1532        Mavericks, Half Moon Bay, San Mateo County
# 5389                                Delaware Lightship
# 2324                            KaelekiI Point, Maui
# 709                                     Bullcock Beach
# 5518                 Off Diamond Head, Honolulu, O'ahu
# 6268               East of the Ras Tanura-Jubail area
# 4754                         Ahvaz, on the Karun River
# 2525                                               NaN
# 901                                      Roches Noires
# 5286                       Sea Bright, Monmouth County
# 309                                  Stradbroke Island
# 2168                       Ponce Inlet, Volusia County
# 202                Mayport Naval Station  Duval County
# 4603                                        Port Newby
# 1932                          Marathon , Monroe County
#
#                                                Activity  \
# 5197                                       Dry shelling
# 4295                                           Swimming
# 2674                                       Spearfishing
# 6073                                                NaN
# 385                                            Floating
# 4236                                           Fishing
# 167                                            Swimming
# 5042                                           Swimming
# 925                                             Surfing
# 3168                                               Boat
# 2456                                            Surfing
# 614                               Swimming / snorkeling
# 4364                                                NaN
# 1568                                           Swimming
# 1748                                      Body boarding
# 1309                                            Fishing
# 3370  Wreck of the 1689-ton Portuguese  coaster Angoche
# 3498                                                NaN
# 742                                             Surfing
# 4728  Jumped overboard from torpedoed Panamanian fre...
# 5435                                                NaN
# 328                                     Lobster fishing
# 5742                                           Swimming
# 5138                                           Swimming
# 4366                                       Scuba diving
# 3954                                            Fishing
# 1260                                           Swimming
# 4172                                                NaN
# 17                                              Surfing
# 96                                              Surfing
# 4464                                            Fishing
# 2030                                         Snorkeling
# 2522                                            Surfing
# 3629                                           Swimming
# 1563                                           Swimming
# 2682                                       Spearfishing
# 6014  He was fighting a shark when his boat capsized...
# 2313                              Swimming breast stoke
# 4875                                            Fishing
# 3633                                    Walking on reef
# 2192                                      Body boarding
# 5749                                           Swimming
# 5952                        Reaching for life preserver
# 5573                                           Swimming
# 637                                   Wrangling a shark
# 1532                                            Surfing
# 5389                                            Fishing
# 2324                       Swimming with mask & snorkel
# 709           Dragging stranded shark into deeper water
# 5518                                           Swimming
# 6268                                             Diving
# 4754                                           Standing
# 2525                                       Scuba diving
# 901                                             Surfing
# 5286                   Swimming, towing an empty barrel
# 309                                             Walking
# 2168                                            Surfing
# 202                                             Surfing
# 4603                                            Fishing
# 1932                                                NaN
#
#                                                    Name Sex   ...  \
# 5197             Selim and Dea Opre,  Koepang Islanders    M  ...
# 4295                                   Mrs. W. F. Dixon    F  ...
# 2674                                     Judy St. Clair    F  ...
# 6073                                  Mr.Johnson (male)    M  ...
# 385                                              female    F  ...
# 4236                             Kara Benagi, from Hula    M  ...
# 167                                      Caitlyn Taylor    F  ...
# 5042                                     Emilio Grenet     M  ...
# 925                                      Adrian Bronson    M  ...
# 3168  7 m skiboat Alrehmah III, occupants: Adolph Sc...  NaN  ...
# 2456                                         Jim Broach    M  ...
# 614                          Burgert Van Der Westhuizen    M  ...
# 4364                                          Len Kosky    M  ...
# 1568                                      Valentyn Onuk    M  ...
# 1748                                      David Bornman    M  ...
# 1309                                               male    M  ...
# 3370   Sailed with 23 crew, half survived the explosion  NaN  ...
# 3498                                        Joe Stinson    M  ...
# 742                                      Matthew Fowler    M  ...
# 4728                                               male    M  ...
# 5435                                                NaN  NaN  ...
# 328                                      Richard Pinder    M  ...
# 5742                                 Joseph Weissmantel    M  ...
# 5138                                      Mervwyn Allum    M  ...
# 4366                                         Al Diamond    M  ...
# 3954                                               male    M  ...
# 1260                                         Jason Cull    M  ...
# 4172                                               male    M  ...
# 17                                                 male    M  ...
# 96                                         Chase Elmore    M  ...
# 4464                                  Valentine Sichter    M  ...
# 2030                                        Andrea Nani    F  ...
# 2522                             Matthew Robertson Paul    M  ...
# 3629               Father Jose de Jesus Gomez, a priest    M  ...
# 1563                                       Michael Lamb    M  ...
# 2682                                           Carl Loe    M  ...
# 6014                                        a young man    M  ...
# 2313                                    Jean Hotchkiss     F  ...
# 4875  rowboat, occupants: James Mitchell-Hedges & Ra...    M  ...
# 3633                                     Barry Nakamura    M  ...
# 2192                                    Neal Stephenson    M  ...
# 5749                                            Zangile    M  ...
# 5952                      male, from the ship Speedwell    M  ...
# 5573                                        Delano Wood    M  ...
# 637                                            Otto Lee    M  ...
# 1532                                           Tim West    M  ...
# 5389                                        Martin Berg    M  ...
# 2324                                    Robert Rogowicz    M  ...
# 709                                    Paul Marshallsea    M  ...
# 5518                                               male    M  ...
# 6268                                      a pearl diver    M  ...
# 4754                                    a old fisherman    M  ...
# 2525                                         Chad Smith    M  ...
# 901                                      Arnaud Dussel     M  ...
# 5286                         Daniel Thompson, lifeguard    M  ...
# 309                                              female    F  ...
# 2168                                       J. Howington    M  ...
# 202                                       Derrick Shoup    M  ...
# 4603                 boat, occupants: C. Nardelli & son  NaN  ...
# 1932                                             female    F  ...
#
#                Time                             Investigator or Source  \
# 5197            NaN  Western Mail, 11/29/1923; V.M. Coppleson (1933...
# 4295            NaN  Evening Sun (Baltimore), 9/27/1955; V.M. Coppl...
# 2674            NaN  Orlando Sentinel, 8/10/1989, pp B3 & B5; Palm ...
# 6073            NaN                              H.D. Baldridge, p.146
# 385           10h10               C. Creswell, GSAF, ABC 11, 7/27/2015
# 4236            NaN  V.M. Coppleson (1958), pp.49-51 & 264; A.M. Ra...
# 167           15h00                   Okaloosa County Sheriff's Office
# 5042        Evening  NY Times, 7/21/1930, p.7 & 8/27/1931; V.M. Cop...
# 925           06h30              L. Lelis, Orlando Sentinel, 5/13/2011
# 3168            NaN                                   T. Wallett, p.32
# 2456            NaN                            G. Balazs; Allen, p.109
# 614           11h30                           JBayNews.com, 10/11/2013
# 4364            NaN                       V.M. Coppleson (1958), p.172
# 1568            NaN                                   R.D. Weeks, GSAF
# 1748          14h30  E. Ritter, GSAF;      http://www.wavescape.co....
# 1309            NaN                         thewest.com.au, 11/19/2007
# 3370            NaN                                    M. Levine, GSAF
# 3498            NaN                H.D.Baldridge (1994) SAF Case #1566
# 742           12h00                             Shark Attack Survivors
# 4728            NaN                       V.M. Coppleson (1962), p.258
# 5435            NaN                                     C. Moore, GSAF
# 328             NaN                        Nassau Guardian, 12/12/2015
# 5742            NaN                                     C. Moore, GSAF
# 5138          11h30  V.M. Coppleson.N.21.(1933); V.M. Coppleson (19...
# 4366            NaN                         Oakland Tribune, 9/20/1953
# 3954            NaN                   A. Bleakley; A.M. Rapson, p.150
http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
#
#      Unnamed: 23
# 5197         NaN
# 4295         NaN
# 2674         NaN
# 6073         NaN
# 385          NaN
# 4236         NaN
# 167          NaN
# 5042         NaN
# 925          NaN
# 3168         NaN
# 2456         NaN
# 614          NaN
# 4364         NaN
# 1568         NaN
# 1748         NaN
# 1309         NaN
# 3370         NaN
# 3498         NaN
# 742          NaN
# 4728         NaN
# 5435         NaN
# 328          NaN
# 5742         NaN
# 5138         NaN
# 4366         NaN
# 3954         NaN
# 1260         NaN
# 4172         NaN
# 17           NaN
# 96           NaN
# 4464         NaN
# 2030         NaN
# 2522         NaN
# 3629         NaN
# 1563         NaN
# 2682         NaN
# 6014         NaN
# 2313         NaN
# 4875         NaN
# 3633         NaN
# 2192         NaN
# 5749         NaN
# 5952         NaN
# 5573         NaN
# 637          NaN
# 1532         NaN
# 5389         NaN
# 2324         NaN
# 709          NaN
# 5518         NaN
# 6268         NaN
# 4754         NaN
# 2525         NaN
# 901          NaN
# 5286         NaN
# 309          NaN
# 2168         NaN
# 202          NaN
# 4603         NaN
# 1932         NaN
#
# [60 rows x 23 columns]

# %% [markdown]
# # limpieza de location

# %%
shark_clean['Location']=shark_clean['Location'].fillna('Unknown')
shark_clean.sample(13)
# Out:
#      Case Number       Date  Year          Type           Country  \
# 5333  1914.10.17 1914-10-17  1914  Sea Disaster             SAMOA
# 3542  1966.12.31 1966-12-31  1966    Unprovoked         AUSTRALIA
# 817   2012.02.26 2012-02-26  2012      Provoked               USA
# 3065  1980.07.00        NaT  1980    Unprovoked               USA
# 165   2017.04.05 2017-04-05  2017    Unprovoked               USA
# 6087  1832.06.04 1832-06-04  1832    Unprovoked         AUSTRALIA
# 6010  1853.07.13        NaT  1853    Unprovoked               USA
# 5883  1874.07.15        NaT  1874    Unprovoked               USA
# 1862  2002.05.21 2002-05-21  2002    Unprovoked  PAPUA NEW GUINEA
# 809   2012.03.14 2012-03-14  2012    Unprovoked               USA
# 6220     ND.0096        NaT     0    Unprovoked           REUNION
# 5485  1906.01.28 1906-01-28  1906    Unprovoked         AUSTRALIA
# 4980  1932.10.11 1932-10-11  1932    Unprovoked        CAPE VERDE
#
#                     Area                                 Location  \
# 5333      Apolima Strait               Opposite Apelima &  Manona
# 3542            Tasmania  Piccaninny Point, 10 miles from Bicheno
# 817              Florida      Palm Beach Inlet, Palm Beach County
# 3065             Florida         New Smyrna Beach, Volusia County
# 165              Florida         New Smyrna Beach, Volusia County
# 6087     New South Wales                       South Head, Sydney
# 6010      South Carolina     Charleston Harbor, Charleston County
# 5883              Hawaii                                  Waikiki
# 1862  Milne Bay Province                          Tewatewa Island
# 809              Florida         New Smyrna Beach, Volusia County
# 6220          Grand'Anse                               Petite-île
# 5485     New South Wales                            Georges River
# 4980  Barlavento Islands                             São Vicente
#
#                                                Activity  \
# 5333  Copra vessel with 19 on board was wrecked in a...
# 3542                                            Fishing
# 817                                        Kite Surfing
# 3065                                            Surfing
# 165                                            Swimming
# 6087                                            Fishing
# 6010                                           Swimming
# 5883                                            Fishing
# 1862                            Collecting beche-de-mer
# 809                                             Surfing
# 6220                              yachtsman in a zodiac
# 5485                                            Bathing
# 4980                                           Swimming
#
#                         Name Sex   ...   Time  \
# 5333                  female    F  ...    NaN
# 3542            Alf Bosworth    M  ...    NaN
# 817             Jason Lasser    M  ...  14h00
# 3065            Tom Durrance    M  ...    NaN
# 165           Melanie Lawson    F  ...  13h00
# 6087       Aboriginal female    F  ...    NaN
# 6010                    male    M  ...    NaN
# 5883      a native fisherman    M  ...    NaN
# 1862           Billy Leonard    M  ...    NaN
# 809              Sydney Levy    F  ...  16h00
# 6220                     NaN    M  ...    NaN
# 5485  William Joseph Dobson.    M  ...  14h10
# 4980            Michele Ruck    M  ...    NaN
#
#                                 Investigator or Source original order  \
# 5333                           Evening Post, 12/2/1914          972.0
# 3542            J. Green, p.35; Sun (Sydney), 1/3/1967         2763.0
# 817                        Aspen Daily News, 2/29/2012         5487.0
# 3065           Daytona Beach Morning Journal, 7/9/1980         3240.0
# 165                                      AJC, 4/5/2017         6139.0
# 6087                          Sydney Herald, 6/11/1832          218.0
# 6010                        Democratic Banner 8/5/1853          295.0
# 5883                                 Empire, 7/15/1874          422.0
# 1862                  PNG Post-Courier, 6/13/2002, p.5         4442.0
# 809   C. Graham, Daytona Beach News-Journal, 3/14/2012         5495.0
# 6220                                G. Van Grevelynghe           85.0
# 5485                                    J. Green, p.31          820.0
# 4980                                    C. Moore, GSAF         1325.0
#
#      Case Number.1 Case Number.2                             pdf  \
# 5333    1914.10.17    1914.10.17            1914.10.17-Samoa.pdf
# 3542    1966.12.31    1966.12.31         1966.12.31-Bosworth.pdf
# 817     2012.02.26    2012.02.26           2012.02.26-Lasser.pdf
# 3065    1980.07.00    1980.07.00         1980.07.00-Durrance.pdf
# 165     2017.04.05    2017.04.05              2017.04.05-NSB.pdf
# 6087    1832.06.04    1832.06.04  1832.06.04-AboriginalWoman.pdf
# 6010  1853.07.13.R  1853.07.13.R     1853.07.13.R-Charleston.pdf
# 5883  1874.07.15.R  1874.07.15.R         1874.07.15.R-Hawaii.pdf
# 1862    2002.05.21    2002.05.21        2002.05.21.a-Leonard.pdf
# 809   2012.03.14.b  2012.03.14.b           2012.03.14.b-Levy.pdf
# 6220       ND.0096       ND.0096      ND-0096-Zodiac-Reunion.pdf
# 5485    1906.01.28    1906.01.28           1906.01.28-Dobson.pdf
# 4980    1932.10.11    1932.10.11             1932.10.11-Ruck.pdf
#
#                                            href formula  \
# 5333  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3542  http://sharkattackfile.net/spreadsheets/pdf_di...
# 817   http://sharkattackfile.net/spreadsheets/pdf_di...
# 3065  http://sharkattackfile.net/spreadsheets/pdf_di...
# 165   http://sharkattackfile.net/spreadsheets/pdf_di...
# 6087  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6010  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5883  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1862  http://sharkattackfile.net/spreadsheets/pdf_di...
# 809   http://sharkattackfile.net/spreadsheets/pdf_di...
# 6220  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5485  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4980  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Unnamed: 22  \
# 5333  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3542  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 817   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3065  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 165   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6087  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6010  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5883  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1862  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 809   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6220  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5485  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4980  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
#
#      Unnamed: 23
# 5333         NaN
# 3542         NaN
# 817          NaN
# 3065         NaN
# 165          NaN
# 6087         NaN
# 6010         NaN
# 5883         NaN
# 1862         NaN
# 809          NaN
# 6220         NaN
# 5485         NaN
# 4980         NaN
#
# [13 rows x 23 columns]

# %% [markdown]
# # limpieza de Activity

# %%
shark_clean['Activity']=shark_clean['Activity'].fillna('Unknown')
shark_clean
# Out:
#      Case Number       Date  Year        Type    Country             Area  \
# 0     2018.06.25 2018-06-25  2018     Boating        USA       California
# 1     2018.06.18 2018-06-18  2018  Unprovoked        USA          Georgia
# 2     2018.06.09 2018-06-09  2018     Unknown        USA           Hawaii
# 3     2018.06.08 2018-06-08  2018  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04 2018-06-04  2018    Provoked     MEXICO           Colima
# ...          ...        ...   ...         ...        ...              ...
# 6309           0        NaT  1926     Unknown    Unknown          Unknown
# 6310           0        NaT  1926     Unknown    Unknown          Unknown
# 6311           0        NaT  1926     Unknown    Unknown          Unknown
# 6312  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
# 6313  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
#
#                             Location     Activity             Name Sex   ...  \
# 0        Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1     St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                       Habush, Oahu      Surfing      John Denges    M  ...
# 3                 Arrawarra Headland      Surfing             male    M  ...
# 4                           La Ticla  Free diving   Gustavo Ramos     M  ...
# ...                              ...          ...              ...  ...  ...
# 6309                         Unknown      Unknown              NaN  NaN  ...
# 6310                         Unknown      Unknown              NaN  NaN  ...
# 6311                         Unknown      Unknown              NaN  NaN  ...
# 6312                         Unknown      Unknown              NaN  NaN  ...
# 6313                         Unknown      Unknown              NaN  NaN  ...
#
#                Time          Investigator or Source original order  \
# 0             18h00                R. Collier, GSAF         6303.0
# 1     14h00  -15h00  K.McMurray, TrackingSharks.com         6302.0
# 2             07h45  K.McMurray, TrackingSharks.com         6301.0
# 3               NaN                  B. Myatt, GSAF         6300.0
# 4               NaN                       A .Kipper         6299.0
# ...             ...                             ...            ...
# 6309            NaN                             NaN         6309.0
# 6310            NaN                             NaN         6310.0
# 6311            NaN                             NaN            NaN
# 6312            NaN                             NaN            NaN
# 6313            NaN                             NaN            NaN
#
#      Case Number.1 Case Number.2                       pdf  \
# 0       2018.06.25    2018.06.25      2018.06.25-Wolfe.pdf
# 1       2018.06.18    2018.06.18    2018.06.18-McNeely.pdf
# 2       2018.06.09    2018.06.09     2018.06.09-Denges.pdf
# 3       2018.06.08    2018.06.08  2018.06.08-Arrawarra.pdf
# 4       2018.06.04    2018.06.04      2018.06.04-Ramos.pdf
# ...            ...           ...                       ...
# 6309           NaN           NaN                       NaN
# 6310           NaN           NaN                       NaN
# 6311           NaN           NaN                       NaN
# 6312           NaN           NaN                       NaN
# 6313           NaN           NaN                       NaN
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6309                                                NaN
# 6310                                                NaN
# 6311                                                NaN
# 6312                                                NaN
# 6313                                                NaN
#
#                                                    href Unnamed: 22  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                 ...         ...
# 6309                                                NaN         NaN
# 6310                                                NaN         NaN
# 6311                                                NaN         NaN
# 6312                                                NaN         NaN
# 6313                                                NaN         NaN
#
#      Unnamed: 23
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 6309         NaN
# 6310         NaN
# 6311         NaN
# 6312         NaN
# 6313         NaN
#
# [6314 rows x 23 columns]

# %% [markdown]
# # limpieza Name

# %%
shark_clean['Name'].value_counts()
# Out:
# male                                                                          550
# female                                                                         97
# boy                                                                            23
# 2 males                                                                        16
# boat                                                                           14
#                                                                              ...
# 3.5 -metre fibreglass boat, occupants: Harry Ulbrich and another fisherman      1
# Fred Wort                                                                       1
# Avery Olearczyk                                                                 1
# Daniel Smith                                                                    1
# Gustavo Ramos                                                                   1
# Name: Name, Length: 5232, dtype: int64

# %%
shark_clean['Name']=shark_clean['Name'].str.replace\
('male|female|boy|2 males|boat|sailor|JapaneseUnknown|Anonymous|Unknowns|child|girl|a Unknown|Unidentified|\
fisherman| Unknown|a pearl diver|a soldier|IndianUnknown|a native|blackUnknown|\
ArabUnknown|AmericanUnknown|ZuluUnknown|JapaneseUnknown|\
2 fishermen|youngUnknown|FijianUnknown|Unknown x 2|unknown|3Unknown|aboriginalUnknown|\
Japanese diver|nativeUnknown|woman|2 women|RussianUnknown|dinghy|AUnknown'\
 ,'Unknown',regex=True)\
.fillna('Unknown')
shark_clean.sample(10)
# Out:
#      Case Number       Date  Year        Type      Country  \
# 5200  1923.10.17 1923-10-17  1923     Boating    AUSTRALIA
# 3867  1961.12.27 1961-12-27  1961    Provoked    AUSTRALIA
# 5712  1890.00.00        NaT  1890  Unprovoked  NEW ZEALAND
# 1001  2010.08.08 2010-08-08  2010  Unprovoked    AUSTRALIA
# 721   2012.11.30 2012-11-30  2012  Unprovoked          USA
# 1635  2004.10.06 2004-10-06  2004  Unprovoked      REUNION
# 3875  1961.10.00        NaT  1961        Boat      VANUATU
# 5794  1883.00.00        NaT  1883  Unprovoked          USA
# 692   2013.03.29 2013-03-29  2013  Unprovoked   SEYCHELLES
# 2543  1992.08.17 1992-08-17  1992    Provoked          USA
#
#                         Area  \
# 5200         New South Wales
# 3867       Western Australia
# 5712            North Island
# 1001         New South Wales
# 721                   Hawaii
# 1635  Conservatória District
# 3875          Shefa Province
# 5794          South Carolina
# 692                  Unknown
# 2543                 Florida
#
#                                                Location  \
# 5200                         Black Head, south of Taree
# 3867  North of main swimming area in Waterman's Bay ...
# 5712                        Lampton Harbour, Wellington
# 1001                                      Crescent Head
# 721                                         Kihei, Maui
# 1635                         P' tit Paris, Saint-Pierre
# 3875                                      Lelepa Island
# 5794                                            Unknown
# 692                                          Ile Platte
# 2543                       Manalapan, Palm Beach County
#
#                       Activity                        Name Sex   ...   Time  \
# 5200                   Fishing                 15' Unknown  NaN  ...    NaN
# 3867              Spearfishing               John Parker      M  ...  07h00
# 5712                  Swimming                    soldier     M  ...    NaN
# 1001                   Surfing                Rick Carroll    M  ...  08h00
# 721                 Snorkeling       Thomas Floyd Kennedy     M  ...  09h40
# 1635             Body boarding             Vincent Motais     M  ...  16h15
# 3875  Paddling outrigger canoe  Unknown from Lelepa Island    M  ...    NaN
# 5794                   Unknown                 an aeronaut    M  ...    NaN
# 692                Free diving           Richard Parkinson    M  ...    NaN
# 2543                Snorkeling                  Rod Duguid    M  ...    NaN
#
#                             Investigator or Source original order  \
# 5200          V.M. Coppleson (1933); SAF Case #494         1105.0
# 3867               The West Australia, 12/28/1961          2438.0
# 5712                           A. W. Parrott, p.68          593.0
# 1001                      Macleay Argus, 8/10/2010         5303.0
# 721                              KHON2, 11/30/2012         5583.0
# 1635                  Federation Francaise de Surf         4669.0
# 3875        Pacific Islands Monthly, October 1961          2430.0
# 5794                               W.H. Greg, p.22          511.0
# 692                                E. Ritter, GSAF         5612.0
# 2543  J.A. Plunkett, Miami Herald, 8/19/1992, p.1B         3762.0
#
#      Case Number.1 Case Number.2                        pdf  \
# 5200    1923.10.17    1923.10.17  1923.10.17-boat-Taree.pdf
# 3867    1961.12.27    1961.12.27      1961.12.27-Parker.pdf
# 5712  1890.00.00.b  1890.00.00.b   1890.00.00.b-soldier.pdf
# 1001    2010.08.08    2010.08.08     2010.08.08-Carroll.pdf
# 721     2012.11.30    2012.11.30     2012.11.30-Kennedy.pdf
# 1635    2004.10.06    2004.10.06      2004.10.06-Motais.pdf
# 3875  1961.10.00.b  1961.10.00.b   1961.10.00.b-Vanuatu.pdf
# 5794  1883.00.00.a  1883.00.00.a  1883.00.00.a-aeronaut.pdf
# 692     2013.03.29    2013.03.29   2013.03.29-Parkinson.pdf
# 2543    1992.08.17    1992.08.17      1992.08.17-Duguid.pdf
#
#                                            href formula  \
# 5200  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3867  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5712  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1001  http://sharkattackfile.net/spreadsheets/pdf_di...
# 721   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1635  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3875  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5794  http://sharkattackfile.net/spreadsheets/pdf_di...
# 692   http://sharkattackfile.net/spreadsheets/pdf_di...
# 2543  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Unnamed: 22  \
# 5200  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3867  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5712  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1001  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 721   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1635  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3875  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5794  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 692   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2543  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
#
#      Unnamed: 23
# 5200         NaN
# 3867         NaN
# 5712         NaN
# 1001         NaN
# 721          NaN
# 1635         NaN
# 3875         NaN
# 5794         NaN
# 692          NaN
# 2543         NaN
#
# [10 rows x 23 columns]

# %%
shark_clean['Name'].value_counts().sample(10)
# Out:
# Arnold Lum                 1
# Barry Watkins              1
# Chris Massahos             1
# a GurkhUnknown             1
# Chris Myers                1
# Daniel Viva, missionary    1
# Sammy Mira                 1
# James Bailey               1
# Nicholas Vossler           1
# Veron Edwards, Sr.         1
# Name: Name, dtype: int64

# %% [markdown]
# # limpieza sex

# %%
shark_clean.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Fatal (Y/N)', 'Species ', 'Time',
#        'Investigator or Source', 'original order', 'Case Number.1',
#        'Case Number.2', 'pdf', 'href formula', 'href', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
columnas = {shark_clean.columns[9] : 'Sex'}
shark_clean = shark_clean.rename(columns=columnas)
shark_clean['Sex']
# Out:
# 0         F
# 1         F
# 2         M
# 3         M
# 4         M
#        ...
# 6309    NaN
# 6310    NaN
# 6311    NaN
# 6312    NaN
# 6313    NaN
# Name: Sex, Length: 6314, dtype: object

# %%
shark_clean['Sex']=shark_clean['Sex'].fillna('ND')
shark_clean.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex', 'Age', 'Fatal (Y/N)', 'Species ', 'Time',
#        'Investigator or Source', 'original order', 'Case Number.1',
#        'Case Number.2', 'pdf', 'href formula', 'href', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %% [markdown]
# # limpieza Age

# %%
shark_clean['Age']
# Out:
# 0        57
# 1        11
# 2        48
# 3       NaN
# 4       NaN
#        ...
# 6309    NaN
# 6310    NaN
# 6311    NaN
# 6312    NaN
# 6313    NaN
# Name: Age, Length: 6314, dtype: object

# %%
shark_clean['Age'] = shark_clean['Age'].fillna('15')
shark_clean['Age'] = shark_clean['Age'].loc[shark_clean['Age'].str.isnumeric()]
shark_clean['Age'] = shark_clean['Age'].str.replace('½', '')

# %%
shark_clean['Age'] = shark_clean['Age'].fillna(0)
shark_clean['Age'] = shark_clean['Age'].astype('int64')
shark_clean
# Out:
#      Case Number       Date  Year        Type    Country             Area  \
# 0     2018.06.25 2018-06-25  2018     Boating        USA       California
# 1     2018.06.18 2018-06-18  2018  Unprovoked        USA          Georgia
# 2     2018.06.09 2018-06-09  2018     Unknown        USA           Hawaii
# 3     2018.06.08 2018-06-08  2018  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04 2018-06-04  2018    Provoked     MEXICO           Colima
# ...          ...        ...   ...         ...        ...              ...
# 6309           0        NaT  1926     Unknown    Unknown          Unknown
# 6310           0        NaT  1926     Unknown    Unknown          Unknown
# 6311           0        NaT  1926     Unknown    Unknown          Unknown
# 6312  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
# 6313  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
#
#                             Location     Activity             Name Sex  ...  \
# 0        Oceanside, San Diego County     Paddling      Julie Wolfe   F  ...
# 1     St. Simon Island, Glynn County     Standing  Adyson McNeely    F  ...
# 2                       Habush, Oahu      Surfing      John Denges   M  ...
# 3                 Arrawarra Headland      Surfing          Unknown   M  ...
# 4                           La Ticla  Free diving   Gustavo Ramos    M  ...
# ...                              ...          ...              ...  ..  ...
# 6309                         Unknown      Unknown          Unknown  ND  ...
# 6310                         Unknown      Unknown          Unknown  ND  ...
# 6311                         Unknown      Unknown          Unknown  ND  ...
# 6312                         Unknown      Unknown          Unknown  ND  ...
# 6313                         Unknown      Unknown          Unknown  ND  ...
#
#                Time          Investigator or Source original order  \
# 0             18h00                R. Collier, GSAF         6303.0
# 1     14h00  -15h00  K.McMurray, TrackingSharks.com         6302.0
# 2             07h45  K.McMurray, TrackingSharks.com         6301.0
# 3               NaN                  B. Myatt, GSAF         6300.0
# 4               NaN                       A .Kipper         6299.0
# ...             ...                             ...            ...
# 6309            NaN                             NaN         6309.0
# 6310            NaN                             NaN         6310.0
# 6311            NaN                             NaN            NaN
# 6312            NaN                             NaN            NaN
# 6313            NaN                             NaN            NaN
#
#      Case Number.1 Case Number.2                       pdf  \
# 0       2018.06.25    2018.06.25      2018.06.25-Wolfe.pdf
# 1       2018.06.18    2018.06.18    2018.06.18-McNeely.pdf
# 2       2018.06.09    2018.06.09     2018.06.09-Denges.pdf
# 3       2018.06.08    2018.06.08  2018.06.08-Arrawarra.pdf
# 4       2018.06.04    2018.06.04      2018.06.04-Ramos.pdf
# ...            ...           ...                       ...
# 6309           NaN           NaN                       NaN
# 6310           NaN           NaN                       NaN
# 6311           NaN           NaN                       NaN
# 6312           NaN           NaN                       NaN
# 6313           NaN           NaN                       NaN
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6309                                                NaN
# 6310                                                NaN
# 6311                                                NaN
# 6312                                                NaN
# 6313                                                NaN
#
#                                                    href Unnamed: 22  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                 ...         ...
# 6309                                                NaN         NaN
# 6310                                                NaN         NaN
# 6311                                                NaN         NaN
# 6312                                                NaN         NaN
# 6313                                                NaN         NaN
#
#      Unnamed: 23
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 6309         NaN
# 6310         NaN
# 6311         NaN
# 6312         NaN
# 6313         NaN
#
# [6314 rows x 23 columns]

# %%
shark_clean.dtypes
# Out:
# Case Number                       object
# Date                      datetime64[ns]
# Year                               int64
# Type                              object
# Country                           object
# Area                              object
# Location                          object
# Activity                          object
# Name                              object
# Sex                               object
# Age                                int64
# Fatal (Y/N)                       object
# Species                           object
# Time                              object
# Investigator or Source            object
# original order                   float64
# Case Number.1                     object
# Case Number.2                     object
# pdf                               object
# href formula                      object
# href                              object
# Unnamed: 22                       object
# Unnamed: 23                       object
# dtype: object

# %% [markdown]
# # limpieza de Fatal (Y/N)

# %%
columnas = {shark_clean.columns[11] : 'Fatal'}
shark_clean = shark_clean.rename(columns=columnas)
shark_clean['Fatal']
# Out:
# 0         N
# 1         N
# 2         N
# 3         N
# 4         N
#        ...
# 6309    NaN
# 6310    NaN
# 6311    NaN
# 6312    NaN
# 6313    NaN
# Name: Fatal, Length: 6314, dtype: object

# %%
shark_clean['Fatal'] = shark_clean['Fatal'].fillna('Unknown')
shark_clean['Fatal']
# Out:
# 0             N
# 1             N
# 2             N
# 3             N
# 4             N
#          ...
# 6309    Unknown
# 6310    Unknown
# 6311    Unknown
# 6312    Unknown
# 6313    Unknown
# Name: Fatal, Length: 6314, dtype: object

# %% [markdown]
# # limpieza de Species

# %%
shark_clean.columns[13]
# Out:
# 'Time'

# %%
columnas = {shark_clean.columns[13] : 'Species'}
shark_clean = shark_clean.rename(columns=columnas)
shark_clean['Species'] = shark_clean['Species'].fillna('ND')
shark_clean['Species']
# Out:
# 0               18h00
# 1       14h00  -15h00
# 2               07h45
# 3                  ND
# 4                  ND
#             ...
# 6309               ND
# 6310               ND
# 6311               ND
# 6312               ND
# 6313               ND
# Name: Species, Length: 6314, dtype: object

# %%
# crea una nueva columna con horas
shark_clean = shark_clean.drop('Species', axis=1)

# %% [markdown]
# # limpieza investigator or source

# %%
shark_clean['Investigator or Source']=shark_clean['Investigator or Source'].fillna('Unknown')
shark_clean
# Out:
#      Case Number       Date  Year        Type    Country             Area  \
# 0     2018.06.25 2018-06-25  2018     Boating        USA       California
# 1     2018.06.18 2018-06-18  2018  Unprovoked        USA          Georgia
# 2     2018.06.09 2018-06-09  2018     Unknown        USA           Hawaii
# 3     2018.06.08 2018-06-08  2018  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04 2018-06-04  2018    Provoked     MEXICO           Colima
# ...          ...        ...   ...         ...        ...              ...
# 6309           0        NaT  1926     Unknown    Unknown          Unknown
# 6310           0        NaT  1926     Unknown    Unknown          Unknown
# 6311           0        NaT  1926     Unknown    Unknown          Unknown
# 6312  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
# 6313  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
#
#                             Location     Activity             Name Sex  ...  \
# 0        Oceanside, San Diego County     Paddling      Julie Wolfe   F  ...
# 1     St. Simon Island, Glynn County     Standing  Adyson McNeely    F  ...
# 2                       Habush, Oahu      Surfing      John Denges   M  ...
# 3                 Arrawarra Headland      Surfing          Unknown   M  ...
# 4                           La Ticla  Free diving   Gustavo Ramos    M  ...
# ...                              ...          ...              ...  ..  ...
# 6309                         Unknown      Unknown          Unknown  ND  ...
# 6310                         Unknown      Unknown          Unknown  ND  ...
# 6311                         Unknown      Unknown          Unknown  ND  ...
# 6312                         Unknown      Unknown          Unknown  ND  ...
# 6313                         Unknown      Unknown          Unknown  ND  ...
#
#              Species           Investigator or Source original order  \
# 0         White shark                R. Collier, GSAF         6303.0
# 1                 NaN  K.McMurray, TrackingSharks.com         6302.0
# 2                 NaN  K.McMurray, TrackingSharks.com         6301.0
# 3           2 m shark                  B. Myatt, GSAF         6300.0
# 4     Tiger shark, 3m                       A .Kipper         6299.0
# ...               ...                             ...            ...
# 6309              NaN                         Unknown         6309.0
# 6310              NaN                         Unknown         6310.0
# 6311              NaN                         Unknown            NaN
# 6312              NaN                         Unknown            NaN
# 6313              NaN                         Unknown            NaN
#
#      Case Number.1  Case Number.2                       pdf  \
# 0       2018.06.25     2018.06.25      2018.06.25-Wolfe.pdf
# 1       2018.06.18     2018.06.18    2018.06.18-McNeely.pdf
# 2       2018.06.09     2018.06.09     2018.06.09-Denges.pdf
# 3       2018.06.08     2018.06.08  2018.06.08-Arrawarra.pdf
# 4       2018.06.04     2018.06.04      2018.06.04-Ramos.pdf
# ...            ...            ...                       ...
# 6309           NaN            NaN                       NaN
# 6310           NaN            NaN                       NaN
# 6311           NaN            NaN                       NaN
# 6312           NaN            NaN                       NaN
# 6313           NaN            NaN                       NaN
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6309                                                NaN
# 6310                                                NaN
# 6311                                                NaN
# 6312                                                NaN
# 6313                                                NaN
#
#                                                    href Unnamed: 22  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                 ...         ...
# 6309                                                NaN         NaN
# 6310                                                NaN         NaN
# 6311                                                NaN         NaN
# 6312                                                NaN         NaN
# 6313                                                NaN         NaN
#
#      Unnamed: 23
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 6309         NaN
# 6310         NaN
# 6311         NaN
# 6312         NaN
# 6313         NaN
#
# [6314 rows x 22 columns]

# %%
shark_clean['Investigator or Source'].value_counts()
# Out:
# C. Moore, GSAF                                                                   105
# C. Creswell, GSAF                                                                 92
# S. Petersohn, GSAF                                                                82
# R. Collier                                                                        55
# R. Collier, GSAF                                                                  48
#                                                                                 ...
# J. Borg, p.71; L. Taylor (1993), pp.96-97                                          1
# NY Times, 7/6/1975, p.5                                                            1
# R.F. Hutton; V.M. Coppleson (1958) (ref.R. North in Scientific American, 1957      1
# ISAF Case #1439                                                                    1
# The Surf Station, 4/13/2017                                                        1
# Name: Investigator or Source, Length: 4968, dtype: int64

# %% [markdown]
# # limpieza original order

# %%
shark_clean['original order'] =shark_clean['original order'].fillna(shark_clean['original order'].mean())
shark_clean
# Out:
#      Case Number       Date  Year        Type    Country             Area  \
# 0     2018.06.25 2018-06-25  2018     Boating        USA       California
# 1     2018.06.18 2018-06-18  2018  Unprovoked        USA          Georgia
# 2     2018.06.09 2018-06-09  2018     Unknown        USA           Hawaii
# 3     2018.06.08 2018-06-08  2018  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04 2018-06-04  2018    Provoked     MEXICO           Colima
# ...          ...        ...   ...         ...        ...              ...
# 6309           0        NaT  1926     Unknown    Unknown          Unknown
# 6310           0        NaT  1926     Unknown    Unknown          Unknown
# 6311           0        NaT  1926     Unknown    Unknown          Unknown
# 6312  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
# 6313  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
#
#                             Location     Activity             Name Sex  ...  \
# 0        Oceanside, San Diego County     Paddling      Julie Wolfe   F  ...
# 1     St. Simon Island, Glynn County     Standing  Adyson McNeely    F  ...
# 2                       Habush, Oahu      Surfing      John Denges   M  ...
# 3                 Arrawarra Headland      Surfing          Unknown   M  ...
# 4                           La Ticla  Free diving   Gustavo Ramos    M  ...
# ...                              ...          ...              ...  ..  ...
# 6309                         Unknown      Unknown          Unknown  ND  ...
# 6310                         Unknown      Unknown          Unknown  ND  ...
# 6311                         Unknown      Unknown          Unknown  ND  ...
# 6312                         Unknown      Unknown          Unknown  ND  ...
# 6313                         Unknown      Unknown          Unknown  ND  ...
#
#              Species           Investigator or Source original order  \
# 0         White shark                R. Collier, GSAF    6303.000000
# 1                 NaN  K.McMurray, TrackingSharks.com    6302.000000
# 2                 NaN  K.McMurray, TrackingSharks.com    6301.000000
# 3           2 m shark                  B. Myatt, GSAF    6300.000000
# 4     Tiger shark, 3m                       A .Kipper    6299.000000
# ...               ...                             ...            ...
# 6309              NaN                         Unknown    6309.000000
# 6310              NaN                         Unknown    6310.000000
# 6311              NaN                         Unknown    3155.352466
# 6312              NaN                         Unknown    3155.352466
# 6313              NaN                         Unknown    3155.352466
#
#      Case Number.1  Case Number.2                       pdf  \
# 0       2018.06.25     2018.06.25      2018.06.25-Wolfe.pdf
# 1       2018.06.18     2018.06.18    2018.06.18-McNeely.pdf
# 2       2018.06.09     2018.06.09     2018.06.09-Denges.pdf
# 3       2018.06.08     2018.06.08  2018.06.08-Arrawarra.pdf
# 4       2018.06.04     2018.06.04      2018.06.04-Ramos.pdf
# ...            ...            ...                       ...
# 6309           NaN            NaN                       NaN
# 6310           NaN            NaN                       NaN
# 6311           NaN            NaN                       NaN
# 6312           NaN            NaN                       NaN
# 6313           NaN            NaN                       NaN
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6309                                                NaN
# 6310                                                NaN
# 6311                                                NaN
# 6312                                                NaN
# 6313                                                NaN
#
#                                                    href Unnamed: 22  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                 ...         ...
# 6309                                                NaN         NaN
# 6310                                                NaN         NaN
# 6311                                                NaN         NaN
# 6312                                                NaN         NaN
# 6313                                                NaN         NaN
#
#      Unnamed: 23
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 6309         NaN
# 6310         NaN
# 6311         NaN
# 6312         NaN
# 6313         NaN
#
# [6314 rows x 22 columns]

# %%
shark_clean['original order']=shark_clean['original order'].astype({'original order': 'str'})

# %%
shark_clean.dtypes
# Out:
# Case Number                       object
# Date                      datetime64[ns]
# Year                               int64
# Type                              object
# Country                           object
# Area                              object
# Location                          object
# Activity                          object
# Name                              object
# Sex                               object
# Age                                int64
# Fatal                             object
# Species                           object
# Investigator or Source            object
# original order                    object
# Case Number.1                     object
# Case Number.2                     object
# pdf                               object
# href formula                      object
# href                              object
# Unnamed: 22                       object
# Unnamed: 23                       object
# dtype: object

# %%
shark_clean['original order'] = shark_clean['original order'].str.replace('\.[0-9]+','',regex=True)
shark_clean
# Out:
#      Case Number       Date  Year        Type    Country             Area  \
# 0     2018.06.25 2018-06-25  2018     Boating        USA       California
# 1     2018.06.18 2018-06-18  2018  Unprovoked        USA          Georgia
# 2     2018.06.09 2018-06-09  2018     Unknown        USA           Hawaii
# 3     2018.06.08 2018-06-08  2018  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04 2018-06-04  2018    Provoked     MEXICO           Colima
# ...          ...        ...   ...         ...        ...              ...
# 6309           0        NaT  1926     Unknown    Unknown          Unknown
# 6310           0        NaT  1926     Unknown    Unknown          Unknown
# 6311           0        NaT  1926     Unknown    Unknown          Unknown
# 6312  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
# 6313  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
#
#                             Location     Activity             Name Sex  ...  \
# 0        Oceanside, San Diego County     Paddling      Julie Wolfe   F  ...
# 1     St. Simon Island, Glynn County     Standing  Adyson McNeely    F  ...
# 2                       Habush, Oahu      Surfing      John Denges   M  ...
# 3                 Arrawarra Headland      Surfing          Unknown   M  ...
# 4                           La Ticla  Free diving   Gustavo Ramos    M  ...
# ...                              ...          ...              ...  ..  ...
# 6309                         Unknown      Unknown          Unknown  ND  ...
# 6310                         Unknown      Unknown          Unknown  ND  ...
# 6311                         Unknown      Unknown          Unknown  ND  ...
# 6312                         Unknown      Unknown          Unknown  ND  ...
# 6313                         Unknown      Unknown          Unknown  ND  ...
#
#              Species           Investigator or Source original order  \
# 0         White shark                R. Collier, GSAF           6303
# 1                 NaN  K.McMurray, TrackingSharks.com           6302
# 2                 NaN  K.McMurray, TrackingSharks.com           6301
# 3           2 m shark                  B. Myatt, GSAF           6300
# 4     Tiger shark, 3m                       A .Kipper           6299
# ...               ...                             ...            ...
# 6309              NaN                         Unknown           6309
# 6310              NaN                         Unknown           6310
# 6311              NaN                         Unknown           3155
# 6312              NaN                         Unknown           3155
# 6313              NaN                         Unknown           3155
#
#      Case Number.1 Case Number.2                       pdf  \
# 0       2018.06.25    2018.06.25      2018.06.25-Wolfe.pdf
# 1       2018.06.18    2018.06.18    2018.06.18-McNeely.pdf
# 2       2018.06.09    2018.06.09     2018.06.09-Denges.pdf
# 3       2018.06.08    2018.06.08  2018.06.08-Arrawarra.pdf
# 4       2018.06.04    2018.06.04      2018.06.04-Ramos.pdf
# ...            ...           ...                       ...
# 6309           NaN           NaN                       NaN
# 6310           NaN           NaN                       NaN
# 6311           NaN           NaN                       NaN
# 6312           NaN           NaN                       NaN
# 6313           NaN           NaN                       NaN
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6309                                                NaN
# 6310                                                NaN
# 6311                                                NaN
# 6312                                                NaN
# 6313                                                NaN
#
#                                                    href Unnamed: 22  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                 ...         ...
# 6309                                                NaN         NaN
# 6310                                                NaN         NaN
# 6311                                                NaN         NaN
# 6312                                                NaN         NaN
# 6313                                                NaN         NaN
#
#      Unnamed: 23
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 6309         NaN
# 6310         NaN
# 6311         NaN
# 6312         NaN
# 6313         NaN
#
# [6314 rows x 22 columns]

# %%
shark_clean['original order']=shark_clean['original order'].astype({'original order':'int64'})

# %%
shark_clean.dtypes
# Out:
# Case Number                       object
# Date                      datetime64[ns]
# Year                               int64
# Type                              object
# Country                           object
# Area                              object
# Location                          object
# Activity                          object
# Name                              object
# Sex                               object
# Age                                int64
# Fatal                             object
# Species                           object
# Investigator or Source            object
# original order                     int64
# Case Number.1                     object
# Case Number.2                     object
# pdf                               object
# href formula                      object
# href                              object
# Unnamed: 22                       object
# Unnamed: 23                       object
# dtype: object

# %%
shark_clean.sample(10)
# Out:
#      Case Number       Date  Year          Type       Country  \
# 1872  2002.04.02 2002-04-02  2002    Unprovoked           USA
# 2990  1982.02.27 1982-02-27  1982    Unprovoked           USA
# 4537  1948.11.18        NaT  1948    Unprovoked     AUSTRALIA
# 6287     ND.0017        NaT     0    Unprovoked  SOUTH AFRICA
# 402   2015.06.27 2015-06-27  2015    Unprovoked  SOUTH AFRICA
# 2661  1989.10.11 1989-10-11  1989    Unprovoked           USA
# 2409  1994.12.13 1994-12-13  1994    Unprovoked        BRAZIL
# 2398  1995.03.05 1995-03-05  1995    Unprovoked        BRAZIL
# 5431  1908.12.16        NaT  1908    Unprovoked        MEXICO
# 5834  1879.08.30        NaT  1879  Sea Disaster          FIJI
#
#                        Area                                    Location  \
# 1872                Florida            New Smyrna Beach, Volusia County
# 2990                Florida               Hobe Sound, Palm Beach County
# 4537          Torres Strait  Saibai Island, 80 miles north of Cape York
# 6287          KwaZulu-Natal                                     Durban
# 402   Western Cape Province                     Buffels Bay near Knysna
# 2661                  Texas                              Surfside Beach
# 2409             Pernambuco                                     Piedade
# 2398               Maranhão              Praia do Olho D'Água, São Luis
# 5431           Quintana Roo                                     Unknown
# 5834              Lau Group                                    Totoya
#
#                                          Activity                    Name Sex  \
# 1872                                       Wading                 Unknown   M
# 2990                                      Surfing           Richard Bauer   M
# 4537                                 Pearl diving             Metuela Mau   M
# 6287  Crew swimming alongside their anchored ship                 Unknown   M
# 402                                 Body Boarding         Caleb Swanepoel   M
# 2661                                      Surfing           Jason Largent   M
# 2409                                      Surfing     Tiago Costa de Lima   M
# 2398                                     Swimming                    E.S.  ND
# 5431           Swimming ashore from capsized boat  Colonel Harry J. Earle   M
# 5834                                      Unknown            Unknown + 20   M
#
#       ...        Species                              Investigator or Source  \
# 1872  ...       3'  shark                                 S. Petersohn, GSAF
# 2990  ...  4' to 5' shark                       Palm Beach Post, 3/2/1982
# 4537  ...             NaN                              The Argus, 11/20/1948
# 6287  ...             NaN  Captain A. Anderson,  Natal Mercury, 12/31/192...
# 402   ...     White shark                                     NSRI, 6/27/205
# 2661  ...        4' shark        Austin American Statesman, 10/13/1989, p.B6
# 2409  ...             NaN                              JCOnline; M. Szpilman
# 2398  ...             NaN                                        M. Szpilman
# 5431  ...             NaN  Lowell Sun, 12/16/1908; V.M. Coppleson (1962),...
# 5834  ...             NaN                  Wagga Wagga Advertiser, 8/30/1879
#
#      original order Case Number.1  Case Number.2  \
# 1872           4432    2002.04.02     2002.04.02
# 2990           3315    1982.02.27     1982.02.27
# 4537           1768    1948.11.18     1948.11.18
# 6287             18       ND.0017        ND.0017
# 402            5902  2015.06.27.a   2015.06.27.a
# 2661           3644    1989.10.11     1989.10.11
# 2409           3896    1994.12.13     1994.12.13
# 2398           3907    1995.03.05     1995.03.05
# 5431            874  1908.12.16.R   1908.12.16.R
# 5834            471  1879.08.30.R   1879.08.30.R
#
#                                   pdf  \
# 1872              2002.04.02-male.pdf
# 2990             1982.02.27-Bauer.pdf
# 4537        1948.11.18-MetuelaMau.pdf
# 6287       ND-0017-alongside-ship.pdf
# 402        2015.06.27.a-Swanepoel.pdf
# 2661           1989.10.11-Largent.pdf
# 2409  1994.12.13-TiagoCostaDaLima.pdf
# 2398            1995.03.05-Brazil.pdf
# 5431             1908.12.16-Earle.pdf
# 5834          1879.08.30.R-Totoya.pdf
#
#                                            href formula  \
# 1872  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2990  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4537  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6287  http://sharkattackfile.net/spreadsheets/pdf_di...
# 402   http://sharkattackfile.net/spreadsheets/pdf_di...
# 2661  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2409  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2398  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5431  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5834  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Unnamed: 22  \
# 1872  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2990  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4537  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6287  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 402   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2661  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2409  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2398  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5431  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5834  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
#
#      Unnamed: 23
# 1872         NaN
# 2990         NaN
# 4537         NaN
# 6287         NaN
# 402          NaN
# 2661         NaN
# 2409         NaN
# 2398         NaN
# 5431         NaN
# 5834         NaN
#
# [10 rows x 22 columns]

# %% [markdown]
# # limpieza case number.1

# %%
shark_clean['Case Number.1']= shark_clean['Case Number.1'].fillna('2010.01.01')
shark_clean
# Out:
#      Case Number       Date  Year        Type    Country             Area  \
# 0     2018.06.25 2018-06-25  2018     Boating        USA       California
# 1     2018.06.18 2018-06-18  2018  Unprovoked        USA          Georgia
# 2     2018.06.09 2018-06-09  2018     Unknown        USA           Hawaii
# 3     2018.06.08 2018-06-08  2018  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04 2018-06-04  2018    Provoked     MEXICO           Colima
# ...          ...        ...   ...         ...        ...              ...
# 6309           0        NaT  1926     Unknown    Unknown          Unknown
# 6310           0        NaT  1926     Unknown    Unknown          Unknown
# 6311           0        NaT  1926     Unknown    Unknown          Unknown
# 6312  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
# 6313  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
#
#                             Location     Activity             Name Sex  ...  \
# 0        Oceanside, San Diego County     Paddling      Julie Wolfe   F  ...
# 1     St. Simon Island, Glynn County     Standing  Adyson McNeely    F  ...
# 2                       Habush, Oahu      Surfing      John Denges   M  ...
# 3                 Arrawarra Headland      Surfing          Unknown   M  ...
# 4                           La Ticla  Free diving   Gustavo Ramos    M  ...
# ...                              ...          ...              ...  ..  ...
# 6309                         Unknown      Unknown          Unknown  ND  ...
# 6310                         Unknown      Unknown          Unknown  ND  ...
# 6311                         Unknown      Unknown          Unknown  ND  ...
# 6312                         Unknown      Unknown          Unknown  ND  ...
# 6313                         Unknown      Unknown          Unknown  ND  ...
#
#              Species           Investigator or Source original order  \
# 0         White shark                R. Collier, GSAF           6303
# 1                 NaN  K.McMurray, TrackingSharks.com           6302
# 2                 NaN  K.McMurray, TrackingSharks.com           6301
# 3           2 m shark                  B. Myatt, GSAF           6300
# 4     Tiger shark, 3m                       A .Kipper           6299
# ...               ...                             ...            ...
# 6309              NaN                         Unknown           6309
# 6310              NaN                         Unknown           6310
# 6311              NaN                         Unknown           3155
# 6312              NaN                         Unknown           3155
# 6313              NaN                         Unknown           3155
#
#      Case Number.1  Case Number.2                       pdf  \
# 0       2018.06.25     2018.06.25      2018.06.25-Wolfe.pdf
# 1       2018.06.18     2018.06.18    2018.06.18-McNeely.pdf
# 2       2018.06.09     2018.06.09     2018.06.09-Denges.pdf
# 3       2018.06.08     2018.06.08  2018.06.08-Arrawarra.pdf
# 4       2018.06.04     2018.06.04      2018.06.04-Ramos.pdf
# ...            ...            ...                       ...
# 6309    2010.01.01            NaN                       NaN
# 6310    2010.01.01            NaN                       NaN
# 6311    2010.01.01            NaN                       NaN
# 6312    2010.01.01            NaN                       NaN
# 6313    2010.01.01            NaN                       NaN
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6309                                                NaN
# 6310                                                NaN
# 6311                                                NaN
# 6312                                                NaN
# 6313                                                NaN
#
#                                                    href Unnamed: 22  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                 ...         ...
# 6309                                                NaN         NaN
# 6310                                                NaN         NaN
# 6311                                                NaN         NaN
# 6312                                                NaN         NaN
# 6313                                                NaN         NaN
#
#      Unnamed: 23
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 6309         NaN
# 6310         NaN
# 6311         NaN
# 6312         NaN
# 6313         NaN
#
# [6314 rows x 22 columns]

# %%
shark_clean['Case Number.1']=shark_clean['Case Number.1'].replace('\.[a-z]|\.[A-Z]','',regex=True)

# %%
shark_clean['Case Number.1'] = pd.to_datetime(shark_clean['Case Number.1'], errors='coerce', infer_datetime_format=True)
shark_clean.dtypes
# Out:
# Case Number                       object
# Date                      datetime64[ns]
# Year                               int64
# Type                              object
# Country                           object
# Area                              object
# Location                          object
# Activity                          object
# Name                              object
# Sex                               object
# Age                                int64
# Fatal                             object
# Species                           object
# Investigator or Source            object
# original order                     int64
# Case Number.1             datetime64[ns]
# Case Number.2                     object
# pdf                               object
# href formula                      object
# href                              object
# Unnamed: 22                       object
# Unnamed: 23                       object
# dtype: object

# %%
shark_clean['Case Number.1'].value_counts()
# Out:
# 2010-01-01    14
# 2001-04-12     5
# 1995-07-28     5
# 2003-10-05     5
# 2010-01-09     4
#               ..
# 1888-12-25     1
# 2011-07-31     1
# 2007-01-05     1
# 1936-01-05     1
# 2004-12-11     1
# Name: Case Number.1, Length: 4802, dtype: int64

# %% [markdown]
# # limpieza case Number.2

# %%
shark_clean['Case Number.2']=shark_clean['Case Number.2'].fillna('2010.01.01')
shark_clean
# Out:
#      Case Number       Date  Year        Type    Country             Area  \
# 0     2018.06.25 2018-06-25  2018     Boating        USA       California
# 1     2018.06.18 2018-06-18  2018  Unprovoked        USA          Georgia
# 2     2018.06.09 2018-06-09  2018     Unknown        USA           Hawaii
# 3     2018.06.08 2018-06-08  2018  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04 2018-06-04  2018    Provoked     MEXICO           Colima
# ...          ...        ...   ...         ...        ...              ...
# 6309           0        NaT  1926     Unknown    Unknown          Unknown
# 6310           0        NaT  1926     Unknown    Unknown          Unknown
# 6311           0        NaT  1926     Unknown    Unknown          Unknown
# 6312  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
# 6313  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
#
#                             Location     Activity             Name Sex  ...  \
# 0        Oceanside, San Diego County     Paddling      Julie Wolfe   F  ...
# 1     St. Simon Island, Glynn County     Standing  Adyson McNeely    F  ...
# 2                       Habush, Oahu      Surfing      John Denges   M  ...
# 3                 Arrawarra Headland      Surfing          Unknown   M  ...
# 4                           La Ticla  Free diving   Gustavo Ramos    M  ...
# ...                              ...          ...              ...  ..  ...
# 6309                         Unknown      Unknown          Unknown  ND  ...
# 6310                         Unknown      Unknown          Unknown  ND  ...
# 6311                         Unknown      Unknown          Unknown  ND  ...
# 6312                         Unknown      Unknown          Unknown  ND  ...
# 6313                         Unknown      Unknown          Unknown  ND  ...
#
#              Species           Investigator or Source original order  \
# 0         White shark                R. Collier, GSAF           6303
# 1                 NaN  K.McMurray, TrackingSharks.com           6302
# 2                 NaN  K.McMurray, TrackingSharks.com           6301
# 3           2 m shark                  B. Myatt, GSAF           6300
# 4     Tiger shark, 3m                       A .Kipper           6299
# ...               ...                             ...            ...
# 6309              NaN                         Unknown           6309
# 6310              NaN                         Unknown           6310
# 6311              NaN                         Unknown           3155
# 6312              NaN                         Unknown           3155
# 6313              NaN                         Unknown           3155
#
#      Case Number.1  Case Number.2                       pdf  \
# 0       2018-06-25     2018.06.25      2018.06.25-Wolfe.pdf
# 1       2018-06-18     2018.06.18    2018.06.18-McNeely.pdf
# 2       2018-06-09     2018.06.09     2018.06.09-Denges.pdf
# 3       2018-06-08     2018.06.08  2018.06.08-Arrawarra.pdf
# 4       2018-06-04     2018.06.04      2018.06.04-Ramos.pdf
# ...            ...            ...                       ...
# 6309    2010-01-01     2010.01.01                       NaN
# 6310    2010-01-01     2010.01.01                       NaN
# 6311    2010-01-01     2010.01.01                       NaN
# 6312    2010-01-01     2010.01.01                       NaN
# 6313    2010-01-01     2010.01.01                       NaN
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6309                                                NaN
# 6310                                                NaN
# 6311                                                NaN
# 6312                                                NaN
# 6313                                                NaN
#
#                                                    href Unnamed: 22  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                 ...         ...
# 6309                                                NaN         NaN
# 6310                                                NaN         NaN
# 6311                                                NaN         NaN
# 6312                                                NaN         NaN
# 6313                                                NaN         NaN
#
#      Unnamed: 23
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 6309         NaN
# 6310         NaN
# 6311         NaN
# 6312         NaN
# 6313         NaN
#
# [6314 rows x 22 columns]

# %%
shark_clean['Case Number.2'] = shark_clean['Case Number.2'].replace('\.[a-z]|\.[A-Z]','',regex=True)
shark_clean['Case Number.2'].value_counts()
# Out:
# 2010.01.01    14
# 1950.00.00    13
# 1942.00.00    11
# 1957.00.00    11
# 1960.00.00    10
#               ..
# 1924.11.21     1
# 1950.11.25     1
# 1976.11.25     1
# 2015.07.27     1
# 1992.11.14     1
# Name: Case Number.2, Length: 5348, dtype: int64

# %%
shark_clean['Case Number.2'] = pd.to_datetime(shark_clean['Case Number.2'], errors='coerce', infer_datetime_format=True)
shark_clean.dtypes
# Out:
# Case Number                       object
# Date                      datetime64[ns]
# Year                               int64
# Type                              object
# Country                           object
# Area                              object
# Location                          object
# Activity                          object
# Name                              object
# Sex                               object
# Age                                int64
# Fatal                             object
# Species                           object
# Investigator or Source            object
# original order                     int64
# Case Number.1             datetime64[ns]
# Case Number.2             datetime64[ns]
# pdf                               object
# href formula                      object
# href                              object
# Unnamed: 22                       object
# Unnamed: 23                       object
# dtype: object

# %%
shark_clean
# Out:
#      Case Number       Date  Year        Type    Country             Area  \
# 0     2018.06.25 2018-06-25  2018     Boating        USA       California
# 1     2018.06.18 2018-06-18  2018  Unprovoked        USA          Georgia
# 2     2018.06.09 2018-06-09  2018     Unknown        USA           Hawaii
# 3     2018.06.08 2018-06-08  2018  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04 2018-06-04  2018    Provoked     MEXICO           Colima
# ...          ...        ...   ...         ...        ...              ...
# 6309           0        NaT  1926     Unknown    Unknown          Unknown
# 6310           0        NaT  1926     Unknown    Unknown          Unknown
# 6311           0        NaT  1926     Unknown    Unknown          Unknown
# 6312  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
# 6313  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
#
#                             Location     Activity             Name Sex  ...  \
# 0        Oceanside, San Diego County     Paddling      Julie Wolfe   F  ...
# 1     St. Simon Island, Glynn County     Standing  Adyson McNeely    F  ...
# 2                       Habush, Oahu      Surfing      John Denges   M  ...
# 3                 Arrawarra Headland      Surfing          Unknown   M  ...
# 4                           La Ticla  Free diving   Gustavo Ramos    M  ...
# ...                              ...          ...              ...  ..  ...
# 6309                         Unknown      Unknown          Unknown  ND  ...
# 6310                         Unknown      Unknown          Unknown  ND  ...
# 6311                         Unknown      Unknown          Unknown  ND  ...
# 6312                         Unknown      Unknown          Unknown  ND  ...
# 6313                         Unknown      Unknown          Unknown  ND  ...
#
#              Species           Investigator or Source original order  \
# 0         White shark                R. Collier, GSAF           6303
# 1                 NaN  K.McMurray, TrackingSharks.com           6302
# 2                 NaN  K.McMurray, TrackingSharks.com           6301
# 3           2 m shark                  B. Myatt, GSAF           6300
# 4     Tiger shark, 3m                       A .Kipper           6299
# ...               ...                             ...            ...
# 6309              NaN                         Unknown           6309
# 6310              NaN                         Unknown           6310
# 6311              NaN                         Unknown           3155
# 6312              NaN                         Unknown           3155
# 6313              NaN                         Unknown           3155
#
#      Case Number.1  Case Number.2                       pdf  \
# 0       2018-06-25     2018-06-25      2018.06.25-Wolfe.pdf
# 1       2018-06-18     2018-06-18    2018.06.18-McNeely.pdf
# 2       2018-06-09     2018-06-09     2018.06.09-Denges.pdf
# 3       2018-06-08     2018-06-08  2018.06.08-Arrawarra.pdf
# 4       2018-06-04     2018-06-04      2018.06.04-Ramos.pdf
# ...            ...            ...                       ...
# 6309    2010-01-01     2010-01-01                       NaN
# 6310    2010-01-01     2010-01-01                       NaN
# 6311    2010-01-01     2010-01-01                       NaN
# 6312    2010-01-01     2010-01-01                       NaN
# 6313    2010-01-01     2010-01-01                       NaN
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6309                                                NaN
# 6310                                                NaN
# 6311                                                NaN
# 6312                                                NaN
# 6313                                                NaN
#
#                                                    href Unnamed: 22  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                 ...         ...
# 6309                                                NaN         NaN
# 6310                                                NaN         NaN
# 6311                                                NaN         NaN
# 6312                                                NaN         NaN
# 6313                                                NaN         NaN
#
#      Unnamed: 23
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 6309         NaN
# 6310         NaN
# 6311         NaN
# 6312         NaN
# 6313         NaN
#
# [6314 rows x 22 columns]

# %%
shark_clean.to_csv('clean.csv')

# %%
import pandas as pd
import re

# %% [markdown]
# # Lectura del archivo csv

# %%
# lee el archivo con un encoding diferente a utf-8 ya que no reconoce ciertos caracteres dentro de el csv
shark = pd.read_csv('attacks.csv',encoding = "ISO-8859-1")
shark_info = pd.DataFrame(shark)

# %%
shark_info
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722         NaN          NaN     NaN         NaN        NaN
# 25723         NaN          NaN     NaN         NaN        NaN
# 25724          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 25720              NaN                             NaN          NaN
# 25721              NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
# 25723              NaN                             NaN          NaN
# 25724              NaN                             NaN          NaN
#
#                   Name Sex   ...         Species   \
# 0          Julie Wolfe    F  ...      White shark
# 1      Adyson McNeely     F  ...              NaN
# 2          John Denges    M  ...              NaN
# 3                 male    M  ...        2 m shark
# 4       Gustavo Ramos     M  ...  Tiger shark, 3m
# ...                ...  ...  ...              ...
# 25720              NaN  NaN  ...              NaN
# 25721              NaN  NaN  ...              NaN
# 25722              NaN  NaN  ...              NaN
# 25723              NaN  NaN  ...              NaN
# 25724              NaN  NaN  ...              NaN
#
#                Investigator or Source                       pdf  \
# 0                    R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1      K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2      K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3                      B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4                           A .Kipper      2018.06.04-Ramos.pdf
# ...                               ...                       ...
# 25720                             NaN                       NaN
# 25721                             NaN                       NaN
# 25722                             NaN                       NaN
# 25723                             NaN                       NaN
# 25724                             NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 25720                                                NaN
# 25721                                                NaN
# 25722                                                NaN
# 25723                                                NaN
# 25724                                                NaN
#
#                                                     href Case Number.1  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                  ...           ...
# 25720                                                NaN           NaN
# 25721                                                NaN           NaN
# 25722                                                NaN           NaN
# 25723                                                NaN           NaN
# 25724                                                NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0        2018.06.25         6303.0         NaN         NaN
# 1        2018.06.18         6302.0         NaN         NaN
# 2        2018.06.09         6301.0         NaN         NaN
# 3        2018.06.08         6300.0         NaN         NaN
# 4        2018.06.04         6299.0         NaN         NaN
# ...             ...            ...         ...         ...
# 25720           NaN            NaN         NaN         NaN
# 25721           NaN            NaN         NaN         NaN
# 25722           NaN            NaN         NaN         NaN
# 25723           NaN            NaN         NaN         NaN
# 25724           NaN            NaN         NaN         NaN
#
# [25725 rows x 24 columns]

# %%
shark_info.shape
# Out:
# (25725, 24)

# %%
shark_info.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %% [markdown]
# # Drop Duplicates

# %%
# elimina todas las filas que contienen valores iguales, que para este caso es nan en todas sus columnas
duplicados = shark_info.drop_duplicates().reset_index()
duplicados.sample(10)
# Out:
#       index   Case Number         Date    Year        Type       Country  \
# 4502   4502    1949.11.20  20-Nov-1949  1949.0  Unprovoked     AUSTRALIA
# 5247   5247    1921.07.21  21-Jul-1921  1921.0  Unprovoked          CUBA
# 6209   6209       ND-0113  Before 1911     0.0  Unprovoked       VIETNAM
# 375     375  2015.08.22.a  22-Aug-2015  2015.0  Unprovoked     AUSTRALIA
# 4335   4335    1954.07.27  27-Jul-1954  1954.0     Boating         ITALY
# 2625   2625    1990.09.08  08-Sep-1990  1990.0  Unprovoked           USA
# 1726   1726  2003.10.31.c  31-Oct-2003  2003.0  Unprovoked           USA
# 2178   2178    1998.07.25  25-Jul-1998  1998.0  Unprovoked           USA
# 4550   4550    1948.04.10  10-Apr-1948  1948.0    Provoked  SOUTH AFRICA
# 3988   3988    1960.06.07  07-Jun-1960  1960.0     Invalid           USA
#
#                        Area                                          Location  \
# 4502        New South Wales                              Kurnell, Botany Bay
# 5247                    NaN                                     Havana Harbor
# 6209                    NaN                                               NaN
# 375         New South Wales                                  Lighthouse Beach
# 4335        Venice Province                                      Off Chioggia
# 2625             California              Russian Gulch, Jenner, Sonoma County
# 1726                Florida               Ponte Vedra Beach, St. Johns County
# 2178                Florida                  New Smyrna Beach, Volusia County
# 4550  Western Cape Province                                          Gansbaai
# 3988             California  10 miles off Santa Barbara, Santa Barbara County
#
#                                                Activity  \
# 4502                Free diving or wading back to shore
# 5247                                     Fell overboard
# 6209                                            Bathing
# 375                                             Surfing
# 4335                      Fishing trawler Flavio Gioia
# 2625  Free diving / spearfishing, from paddleboard &...
# 1726                                            Surfing
# 2178                                            Surfing
# 4550      Bringing hooked, harpooned shark onboard boat
# 3988  Testing classified underwater electronic gear ...
#
#                                                    Name  ...  \
# 4502                               William Edward Brown  ...
# 5247                                       Robert Ellis  ...
# 6209                                               male  ...
# 375                                           Dale Carr  ...
# 4335                                            10 crew  ...
# 2625                                         Rodney Orr  ...
# 1726                                          Adam Gray  ...
# 2178                                      Michael Rinto  ...
# 4550           boat, occupants, P. Groenwald and others  ...
# 3988  Paul Timothy Lovette, Dr. Neal Beardsley, Jame...  ...
#
#                                                Species   \
# 4502                                           6' shark
# 5247                                                NaN
# 6209                                                NaN
# 375                                                 NaN
# 4335                                           5m shark
# 2625                                        White shark
# 1726                    1.2 m to 1.5 m [4' to 5'] shark
# 2178                                                NaN
# 4550                                                NaN
# 3988  Shark involvement prior to death was not confi...
#
#                                  Investigator or Source  \
# 4502                  Sydney Morning Herald, 11/20/1949
# 5247                         Chicago Tribune, 7/22/1921
# 6209                 Daily Kennebec Journal, 3/27/ 1911
# 375                          Daily Telegraph, 8/22/2015
# 4335                                     C. Moore, GSAF
# 2625                              R. Collier pp.120-121
# 1726          D. Dixon, Florida Times-Union, 11/8/2003
# 2178  S. Petersohn, GSAF; Orlando Sentinel, 7/24/199...
# 4550                                    M. Levine, GSAF
# 3988  L.A. Times, 6/10/1960; L. Schultz & M. Malin, ...
#
#                              pdf  \
# 4502        1949.11.20-Brown.pdf
# 5247        1921.07.21-Ellis.pdf
# 6209         ND-0113-Vietnam.pdf
# 375        2015.08.22.a-Carr.pdf
# 4335      1954.07.27-Trawler.pdf
# 2625  1990.09.08-Orr_Collier.pdf
# 1726       2003.10.31.c-Gray.pdf
# 2178        1998.07.25-Rinto.pdf
# 4550    1948.04.10-Groenwald.pdf
# 3988     1960.06.07-Raytheon.pdf
#
#                                            href formula  \
# 4502  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5247  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6209  http://sharkattackfile.net/spreadsheets/pdf_di...
# 375   http://sharkattackfile.net/spreadsheets/pdf_di...
# 4335  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2625  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1726  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2178  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4550  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3988  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 4502  http://sharkattackfile.net/spreadsheets/pdf_di...    1949.11.20
# 5247  http://sharkattackfile.net/spreadsheets/pdf_di...    1921.07.21
# 6209  http://sharkattackfile.net/spreadsheets/pdf_di...       ND-0113
# 375   http://sharkattackfile.net/spreadsheets/pdf_di...  2015.08.22.a
# 4335  http://sharkattackfile.net/spreadsheets/pdf_di...    1954.07.27
# 2625  http://sharkattackfile.net/spreadsheets/pdf_di...    1990.09.08
# 1726  http://sharkattackfile.net/spreadsheets/pdf_di...  2003.10.31.c
# 2178  http://sharkattackfile.net/spreadsheets/pdf_di...    1998.07.25
# 4550  http://sharkattackfile.net/spreadsheets/pdf_di...    1948.04.10
# 3988  http://sharkattackfile.net/spreadsheets/pdf_di...    1960.06.07
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23
# 4502    1949.11.20         1803.0         NaN         NaN
# 5247    1921.07.21         1058.0         NaN         NaN
# 6209       ND-0113           96.0         NaN         NaN
# 375   2015.08.22.a         5929.0         NaN         NaN
# 4335    1954.07.27         1970.0         NaN         NaN
# 2625    1990.09.08         3680.0         NaN         NaN
# 1726  2003.10.31.c         4578.0         NaN         NaN
# 2178    1998.07.25         4126.0         NaN         NaN
# 4550    1948.04.10         1755.0         NaN         NaN
# 3988    1960.06.07         2317.0         NaN         NaN
#
# [10 rows x 25 columns]

# %% [markdown]
# # comparacion original vs drop duplicates

# %%
print('tamaño de las filas en el archivo originial',shark_info.shape)
print('tamaño de las filas en el archivo que elimina valores duplicados',duplicados.shape)
# Out:
# tamaño de las filas en el archivo originial (25725, 24)
# tamaño de las filas en el archivo que elimina valores duplicados (6314, 25)

# %%
# reorganizacion de las columnas de la mas importante a menos importante 
cols = ['Case Number', 'Date', 'Year','Type','Country', 'Area','Location',
       'Activity', 'Name', 'Sex ', 'Age', 'Fatal (Y/N)','Species ', 'Time','Investigator or Source',
       'original order','Case Number.1', 'Case Number.2','pdf', 'href formula', 'href','Unnamed: 22','Unnamed: 23']
shark_clean = pd.DataFrame(duplicados, columns=cols)
shark_clean = shark_clean
shark_clean
# Out:
#      Case Number         Date    Year        Type    Country             Area  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
# ...          ...          ...     ...         ...        ...              ...
# 6309           0          NaN     NaN         NaN        NaN              NaN
# 6310           0          NaN     NaN         NaN        NaN              NaN
# 6311           0          NaN     NaN         NaN        NaN              NaN
# 6312         NaN          NaN     NaN         NaN        NaN              NaN
# 6313          xx          NaN     NaN         NaN        NaN              NaN
#
#                             Location     Activity             Name Sex   ...  \
# 0        Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1     St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                       Habush, Oahu      Surfing      John Denges    M  ...
# 3                 Arrawarra Headland      Surfing             male    M  ...
# 4                           La Ticla  Free diving   Gustavo Ramos     M  ...
# ...                              ...          ...              ...  ...  ...
# 6309                             NaN          NaN              NaN  NaN  ...
# 6310                             NaN          NaN              NaN  NaN  ...
# 6311                             NaN          NaN              NaN  NaN  ...
# 6312                             NaN          NaN              NaN  NaN  ...
# 6313                             NaN          NaN              NaN  NaN  ...
#
#                Time          Investigator or Source original order  \
# 0             18h00                R. Collier, GSAF         6303.0
# 1     14h00  -15h00  K.McMurray, TrackingSharks.com         6302.0
# 2             07h45  K.McMurray, TrackingSharks.com         6301.0
# 3               NaN                  B. Myatt, GSAF         6300.0
# 4               NaN                       A .Kipper         6299.0
# ...             ...                             ...            ...
# 6309            NaN                             NaN         6309.0
# 6310            NaN                             NaN         6310.0
# 6311            NaN                             NaN            NaN
# 6312            NaN                             NaN            NaN
# 6313            NaN                             NaN            NaN
#
#      Case Number.1 Case Number.2                       pdf  \
# 0       2018.06.25    2018.06.25      2018.06.25-Wolfe.pdf
# 1       2018.06.18    2018.06.18    2018.06.18-McNeely.pdf
# 2       2018.06.09    2018.06.09     2018.06.09-Denges.pdf
# 3       2018.06.08    2018.06.08  2018.06.08-Arrawarra.pdf
# 4       2018.06.04    2018.06.04      2018.06.04-Ramos.pdf
# ...            ...           ...                       ...
# 6309           NaN           NaN                       NaN
# 6310           NaN           NaN                       NaN
# 6311           NaN           NaN                       NaN
# 6312           NaN           NaN                       NaN
# 6313           NaN           NaN                       NaN
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6309                                                NaN
# 6310                                                NaN
# 6311                                                NaN
# 6312                                                NaN
# 6313                                                NaN
#
#                                                    href Unnamed: 22  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                 ...         ...
# 6309                                                NaN         NaN
# 6310                                                NaN         NaN
# 6311                                                NaN         NaN
# 6312                                                NaN         NaN
# 6313                                                NaN         NaN
#
#      Unnamed: 23
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 6309         NaN
# 6310         NaN
# 6311         NaN
# 6312         NaN
# 6313         NaN
#
# [6314 rows x 23 columns]

# %% [markdown]
# # primera columna 'Case Number'

# %%
# limpiando primera columna de tabla
shark_clean['Case Number'] = shark_clean['Case Number'].str.replace('\.[a-z]+|\.[A-Z]+','', regex=True).fillna('2010.01.01')
shark_clean.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Fatal (Y/N)                object
# Species                    object
# Time                       object
# Investigator or Source     object
# original order            float64
# Case Number.1              object
# Case Number.2              object
# pdf                        object
# href formula               object
# href                       object
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %%
shark_clean['Case Number'] = shark_clean['Case Number'].str.replace('xx','2010.01.01')
shark_clean
# Out:
#      Case Number         Date    Year        Type    Country             Area  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
# ...          ...          ...     ...         ...        ...              ...
# 6309           0          NaN     NaN         NaN        NaN              NaN
# 6310           0          NaN     NaN         NaN        NaN              NaN
# 6311           0          NaN     NaN         NaN        NaN              NaN
# 6312  2010.01.01          NaN     NaN         NaN        NaN              NaN
# 6313  2010.01.01          NaN     NaN         NaN        NaN              NaN
#
#                             Location     Activity             Name Sex   ...  \
# 0        Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1     St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                       Habush, Oahu      Surfing      John Denges    M  ...
# 3                 Arrawarra Headland      Surfing             male    M  ...
# 4                           La Ticla  Free diving   Gustavo Ramos     M  ...
# ...                              ...          ...              ...  ...  ...
# 6309                             NaN          NaN              NaN  NaN  ...
# 6310                             NaN          NaN              NaN  NaN  ...
# 6311                             NaN          NaN              NaN  NaN  ...
# 6312                             NaN          NaN              NaN  NaN  ...
# 6313                             NaN          NaN              NaN  NaN  ...
#
#                Time          Investigator or Source original order  \
# 0             18h00                R. Collier, GSAF         6303.0
# 1     14h00  -15h00  K.McMurray, TrackingSharks.com         6302.0
# 2             07h45  K.McMurray, TrackingSharks.com         6301.0
# 3               NaN                  B. Myatt, GSAF         6300.0
# 4               NaN                       A .Kipper         6299.0
# ...             ...                             ...            ...
# 6309            NaN                             NaN         6309.0
# 6310            NaN                             NaN         6310.0
# 6311            NaN                             NaN            NaN
# 6312            NaN                             NaN            NaN
# 6313            NaN                             NaN            NaN
#
#      Case Number.1 Case Number.2                       pdf  \
# 0       2018.06.25    2018.06.25      2018.06.25-Wolfe.pdf
# 1       2018.06.18    2018.06.18    2018.06.18-McNeely.pdf
# 2       2018.06.09    2018.06.09     2018.06.09-Denges.pdf
# 3       2018.06.08    2018.06.08  2018.06.08-Arrawarra.pdf
# 4       2018.06.04    2018.06.04      2018.06.04-Ramos.pdf
# ...            ...           ...                       ...
# 6309           NaN           NaN                       NaN
# 6310           NaN           NaN                       NaN
# 6311           NaN           NaN                       NaN
# 6312           NaN           NaN                       NaN
# 6313           NaN           NaN                       NaN
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6309                                                NaN
# 6310                                                NaN
# 6311                                                NaN
# 6312                                                NaN
# 6313                                                NaN
#
#                                                    href Unnamed: 22  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                 ...         ...
# 6309                                                NaN         NaN
# 6310                                                NaN         NaN
# 6311                                                NaN         NaN
# 6312                                                NaN         NaN
# 6313                                                NaN         NaN
#
#      Unnamed: 23
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 6309         NaN
# 6310         NaN
# 6311         NaN
# 6312         NaN
# 6313         NaN
#
# [6314 rows x 23 columns]

# %% [markdown]
# # limpieza de las fechas date

# %%
shark_clean['Date'] = shark_clean['Date'].str.replace('Reported| Early| Late|\.[a-z]|\.[A-Z]|Between May &' ,'').fillna('01-01-2000')
shark_clean.sample(20)
# Out:
#      Case Number               Date    Year        Type        Country  \
# 5914  1870.06.19        19-Jun-1870  1870.0  Unprovoked          INDIA
# 3095  1979.08.03        03-Aug-1979  1979.0  Unprovoked       THAILAND
# 2165  1998.09.16        16-Sep-1998  1998.0  Unprovoked   SOUTH AFRICA
# 875   2011.08.28        28-Aug-2011  2011.0     Invalid      AUSTRALIA
# 6054  1845.11.04        04-Nov-1845  1845.0  Unprovoked         MEXICO
# 1573  2005.07.01         1-Jul-2005  2005.0  Unprovoked            USA
# 3905  1961.04.21        21-Apr-1961  1961.0  Unprovoked     MOZAMBIQUE
# 5164  1925.11.00           Nov-1925  1925.0  Unprovoked            USA
# 785   2012.06.14        14-Jun-2012  2012.0  Unprovoked            USA
# 3518  1967.08.14        14-Aug-1967  1967.0  Unprovoked       COLUMBIA
# 2693  1989.03.04        04-Mar-1989  1989.0     Boating      AUSTRALIA
# 2991  1982.02.17        17-Feb-1982  1982.0    Provoked   SOUTH AFRICA
# 6025  1852.00.00               1852  1852.0  Unprovoked            USA
# 851   2011.10.22        22-Oct-2011  2011.0  Unprovoked      AUSTRALIA
# 2475  1993.09.16        16-Sep-1993  1993.0  Unprovoked    EL SALVADOR
# 4028  1960.00.00  Early summer 1960  1960.0     Invalid  CARIBBEAN SEA
# 1544  2005.10.01        01-Oct-2005  2005.0  Unprovoked   SOUTH AFRICA
# 741   2012.09.09        09-Sep-2012  2012.0  Unprovoked            USA
# 3169  1976.10.18        18-Oct-1976  1976.0  Unprovoked            USA
# 4450  1951.03.15        15-Mar-1951  1951.0  Unprovoked   SOUTH AFRICA
#
#                        Area                                          Location  \
# 5914             22ºN, 88ºE       Calcutta, Hoogly River at  one of the ghats
# 3095      Southern Thailand                                               NaN
# 2165  Eastern Cape Province                                       Kowie River
# 875              Queensland                                    Fantome Island
# 6054              Vera Cruz                                         Vera Cruz
# 1573                Florida                           Boca Grande, Lee County
# 3905                   Gaza                          Sepulveda Beach, Xai Xai
# 5164            Puerto Rico                           Condado Beach, San Juan
# 785          South Carolina                        Myrtle Beach, Horry County
# 3518                    NaN                                               NaN
# 2693      Western Australia                        Near Broome in Roebuck Bay
# 2991  Western Cape Province                                        Mossel Bay
# 6025         South Carolina                 Mount Pleasant, Charleston County
# 851       Western Australia                                   Rottnest Island
# 2475            La Libertad                                    El Cocal Beach
# 4028                    NaN  Between Key West, Florida & Guantanamo Bay, Cuba
# 1544  Western Cape Province                             Sunny Cove, Fish Hoek
# 741                 Florida                  New Smyrna Beach, Volusia County
# 3169             California                  Moonstone Beach, Humboldt County
# 4450          KwaZulu-Natal                               South Beach, Durban
#
#                                             Activity  \
# 5914                                         Bathing
# 3095                        Murdered by Thai pirates
# 2165                Fishing / washing bait off hands
# 875                                         Swimming
# 6054                                         Bathing
# 1573                                        Standing
# 3905                                        Swimming
# 5164                                             NaN
# 785                                         Swimming
# 3518                                             NaN
# 2693                                        Kayaking
# 2991                                         Fishing
# 6025  Vessel capsized, wading ashore carrying an oar
# 851                                           Diving
# 2475                                         Surfing
# 4028                       Aircraft crashed into sea
# 1544                                     Surf-skiing
# 741                                          Surfing
# 3169                                         Surfing
# 4450                                    Body surfing
#
#                            Name Sex   ...   Time  \
# 5914   male, a Hindu shopkeeper    M  ...    NaN
# 3095                       male    M  ...    NaN
# 2165               Grant Rielly    M  ...   Dusk
# 875                     Rooster    M  ...  19h30
# 6054                  a soldier    M  ...    NaN
# 1573               Armin Trojer    M  ...  11h30
# 3905                Brian Dewar    M  ...  10h00
# 5164            American lawyer    M  ...    NaN
# 785             Jordon Garosalo    M  ...  13h20
# 3518               Thomas Walsh    M  ...    NaN
# 2693             Kim Courtenay     M  ...    NaN
# 2991                 J. Jordaan    M  ...    NaN
# 6025           Charles Chambers    M  ...    NaN
# 851           George Wainwright    M  ...  13h25
# 2475  Mauricio Guzman Castaneda    M  ...    NaN
# 4028        male, airline pilot    M  ...    NaN
# 1544              Trevor Wright    M  ...  15h00
# 741                        teen  NaN  ...  14h20
# 3169            William Kennedy    M  ...  14h30
# 4450        Heinrich Stapelberg    M  ...  12h00
#
#                                  Investigator or Source original order  \
# 5914                                    J. Fayrer, M.D.          391.0
# 3095                       The Canberra Times, 8/3/1979         3210.0
# 2165                          Daily Dispatch, 9/16/1998         4139.0
# 875                           Courier Pigeon, 8/30/2011         5429.0
# 6054                       New York Tribune, 12/15/1845          251.0
# 1573                                    E. Ritter, GSAF         4731.0
# 3905  D. Davies, pp.125-126; M. Levine,GSAF; Star, 4...         2400.0
# 5164                 V.M. Coppleson (1958), pp.48 & 265         1141.0
# 785                                         C. Creswell         5519.0
# 3518                          New York Times, 8/14/1967         2787.0
# 2693                       K. Courtenay; T. Peake, GSAF         3612.0
# 2991                   Mossel Bay Advertiser, 2/19/1982         3314.0
# 6025                                 W. H. Gregg, p. 21          280.0
# 851                                Sky News, 10/22/2011         5453.0
# 2475                           Tampa Tribune, 9/18/1993         3830.0
# 4028                  U.S. Naval Aviation Safety Center         2277.0
# 1544                  Cape Argus, Cape Times, 10/3/2005         4760.0
# 741                Daytona Beach News Journal, 9/9/2012         5563.0
# 3169  D. Miller & R. Collier, R. Collier, pp.70-71; ...         3136.0
# 4450                                    M. Levine, GSAF         1855.0
#
#      Case Number.1 Case Number.2                             pdf  \
# 5914    1870.06.19    1870.06.19  1870.06.19-HinduShopkeeper.pdf
# 3095    1979.08.03    1979.08.03        1979.08.03.R-Pirates.pdf
# 2165  1998.09.16.R  1998.09.16.R         1998.09.16.R-Rielly.pdf
# 875   2011.08.28.b  2011.08.28.b         2011.08.28-Roosteer.pdf
# 6054    1845.11.04    1845.11.04         1845.11.04-VeraCruz.pdf
# 1573    2005.07.01    2005.07.01           2005.07.01-Trojer.pdf
# 3905    1961.04.21    1961.04.21            1961.04.21-Dewar.pdf
# 5164  1925.11.00.a  1925.11.00.a         1925.11.00.a-Lawyer.pdf
# 785   2012.06.14.a  2012.06.14.a       2012.06.14.a-Garosalo.pdf
# 3518  1967.08.14.R  1967.08.14.R          1967.08.14.R-Walsh.pdf
# 2693    1989.03.04    1989.03.04        1989.03.04-Courtenay.pdf
# 2991    1982.02.17    1982.02.17          1982.02.17-Jordaan.pdf
# 6025    1852.00.00    1852.00.00         1852.00.00-Chambers.pdf
# 851     2011.10.22    2011.10.22       2011.10.22-Wainwright.pdf
# 2475  1993.09.16.a  1993.09.16.a      1993.09.16.a-Castaneda.pdf
# 4028  1960.00.00.h  1960.00.00.h       1960.00.00.h-aircraft.pdf
# 1544    2005.10.01    2005.10.01           2005.10.01-Wright.pdf
# 741     2012.09.09    2012.09.09              2012.09.09-NSB.pdf
# 3169    1976.10.18    1976.10.18  1976.10.18-Kennedy_Collier.pdf
# 4450    1951.03.15    1951.03.15       1951.03.15-Stapelberg.pdf
#
#                                            href formula  \
# 5914  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3095  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2165  http://sharkattackfile.net/spreadsheets/pdf_di...
# 875   http://sharkattackfile.net/spreadsheets/pdf_di...
# 6054  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1573  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3905  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5164  http://sharkattackfile.net/spreadsheets/pdf_di...
# 785   http://sharkattackfile.net/spreadsheets/pdf_di...
# 3518  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2693  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2991  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6025  http://sharkattackfile.net/spreadsheets/pdf_di...
# 851   http://sharkattackfile.net/spreadsheets/pdf_di...
# 2475  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4028  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1544  http://sharkattackfile.net/spreadsheets/pdf_di...
# 741   http://sharkattackfile.net/spreadsheets/pdf_di...
# 3169  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4450  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Unnamed: 22  \
# 5914  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3095  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2165  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 875   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6054  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1573  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3905  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5164  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 785   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3518  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2693  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2991  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6025  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 851   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2475  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4028  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1544  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 741   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3169  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4450  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
#
#      Unnamed: 23
# 5914         NaN
# 3095         NaN
# 2165         NaN
# 875          NaN
# 6054         NaN
# 1573         NaN
# 3905         NaN
# 5164         NaN
# 785          NaN
# 3518         NaN
# 2693         NaN
# 2991         NaN
# 6025         NaN
# 851          NaN
# 2475         NaN
# 4028         NaN
# 1544         NaN
# 741          NaN
# 3169         NaN
# 4450         NaN
#
# [20 rows x 23 columns]

# %%
shark_clean['Date'] = pd.to_datetime(shark_clean['Date'], errors='coerce', infer_datetime_format=True)
shark_clean.dtypes
# Out:
# Case Number                       object
# Date                      datetime64[ns]
# Year                             float64
# Type                              object
# Country                           object
# Area                              object
# Location                          object
# Activity                          object
# Name                              object
# Sex                               object
# Age                               object
# Fatal (Y/N)                       object
# Species                           object
# Time                              object
# Investigator or Source            object
# original order                   float64
# Case Number.1                     object
# Case Number.2                     object
# pdf                               object
# href formula                      object
# href                              object
# Unnamed: 22                       object
# Unnamed: 23                       object
# dtype: object

# %%
shark_clean.head()
# Out:
#   Case Number       Date    Year        Type    Country             Area  \
# 0  2018.06.25 2018-06-25  2018.0     Boating        USA       California
# 1  2018.06.18 2018-06-18  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09 2018-06-09  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08 2018-06-08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04 2018-06-04  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
#             Time          Investigator or Source original order Case Number.1  \
# 0          18h00                R. Collier, GSAF         6303.0    2018.06.25
# 1  14h00  -15h00  K.McMurray, TrackingSharks.com         6302.0    2018.06.18
# 2          07h45  K.McMurray, TrackingSharks.com         6301.0    2018.06.09
# 3            NaN                  B. Myatt, GSAF         6300.0    2018.06.08
# 4            NaN                       A .Kipper         6299.0    2018.06.04
#
#   Case Number.2                       pdf  \
# 0    2018.06.25      2018.06.25-Wolfe.pdf
# 1    2018.06.18    2018.06.18-McNeely.pdf
# 2    2018.06.09     2018.06.09-Denges.pdf
# 3    2018.06.08  2018.06.08-Arrawarra.pdf
# 4    2018.06.04      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Unnamed: 22 Unnamed: 23
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# # limpieza de year

# %%
'''
convierte los valores de años a str
'''
shark_clean['Year']=shark_clean['Year'].fillna(shark_clean['Year'].mean())
shark_clean.head(10)
# Out:
#   Case Number       Date         Year                     Type    Country  \
# 0  2018.06.25 2018-06-25  2018.000000                  Boating        USA
# 1  2018.06.18 2018-06-18  2018.000000               Unprovoked        USA
# 2  2018.06.09 2018-06-09  2018.000000                  Invalid        USA
# 3  2018.06.08 2018-06-08  2018.000000               Unprovoked  AUSTRALIA
# 4  2018.06.04 2018-06-04  2018.000000                 Provoked     MEXICO
# 5  2018.06.03 2018-06-03  2018.000000               Unprovoked  AUSTRALIA
# 6  2010.01.01        NaT  1926.970957  No injury, board bitten          N
# 7  2018.06.03 2018-06-03  2018.000000               Unprovoked     BRAZIL
# 8  2018.05.27 2018-05-27  2018.000000               Unprovoked        USA
# 9  2018.05.26 2018-05-26  2018.000000               Unprovoked        USA
#
#               Area                                           Location  \
# 0       California                        Oceanside, San Diego County
# 1          Georgia                     St. Simon Island, Glynn County
# 2           Hawaii                                       Habush, Oahu
# 3  New South Wales                                 Arrawarra Headland
# 4           Colima                                           La Ticla
# 5  New South Wales                                 Flat Rock, Ballina
# 6              NaN                                                NaN
# 7       Pernambuco                              Piedade Beach, Recife
# 8          Florida  Lighhouse Point Park, Ponce Inlet, Volusia County
# 9          Florida                       Cocoa Beach, Brevard  County
#
#                     Activity                       Name  \
# 0                   Paddling                Julie Wolfe
# 1                   Standing            Adyson McNeely
# 2                    Surfing                John Denges
# 3                    Surfing                       male
# 4                Free diving             Gustavo Ramos
# 5               Kite surfing                     Chris
# 6  Daily Telegraph, 6/4/2018  2018.06.03.b-FlatRock.pdf
# 7                   Swimming     Jose Ernesto da Silva
# 8                    Fishing                       male
# 9                    Walking                  Cody High
#
#                                                 Sex   ...            Time  \
# 0                                                  F  ...           18h00
# 1                                                  F  ...   14h00  -15h00
# 2                                                  M  ...           07h45
# 3                                                  M  ...             NaN
# 4                                                  M  ...             NaN
# 5                                                NaN  ...             NaN
# 6  http://sharkattackfile.net/spreadsheets/pdf_di...  ...            6298
# 7                                                  M  ...  Late afternoon
# 8                                                  M  ...             NaN
# 9                                                  M  ...           17h00
#
#             Investigator or Source original order Case Number.1 Case Number.2  \
# 0                 R. Collier, GSAF         6303.0    2018.06.25    2018.06.25
# 1   K.McMurray, TrackingSharks.com         6302.0    2018.06.18    2018.06.18
# 2   K.McMurray, TrackingSharks.com         6301.0    2018.06.09    2018.06.09
# 3                   B. Myatt, GSAF         6300.0    2018.06.08    2018.06.08
# 4                        A .Kipper         6299.0    2018.06.04    2018.06.04
# 5                              NaN            NaN           NaN           NaN
# 6                              NaN            NaN           NaN           NaN
# 7   Diario de Pernambuco, 6/4/2018         6297.0  2018.06.03.a  2018.06.03.a
# 8  K. McMurray, TrackingSharks.com         6296.0    2018.05.27    2018.05.27
# 9   K.McMurray, TrackingSharks.com         6295.0  2018.05.26.b  2018.05.26.b
#
#                         pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
# 5                       NaN
# 6                       NaN
# 7  2018.06.03.a-daSilva.pdf
# 8      2018.05.27-Ponce.pdf
# 9     2018.05.26.b-High.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5                                                NaN
# 6                                                NaN
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Unnamed: 22 Unnamed: 23
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 5                                                NaN         NaN         NaN
# 6                                                NaN         NaN         NaN
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
#
# [10 rows x 23 columns]

# %%
shark_clean['Year']= shark_clean['Year'].astype({'Year':'str'})
shark_clean.head(10)
# Out:
#   Case Number       Date                Year                     Type  \
# 0  2018.06.25 2018-06-25              2018.0                  Boating
# 1  2018.06.18 2018-06-18              2018.0               Unprovoked
# 2  2018.06.09 2018-06-09              2018.0                  Invalid
# 3  2018.06.08 2018-06-08              2018.0               Unprovoked
# 4  2018.06.04 2018-06-04              2018.0                 Provoked
# 5  2018.06.03 2018-06-03              2018.0               Unprovoked
# 6  2010.01.01        NaT  1926.9709569909537  No injury, board bitten
# 7  2018.06.03 2018-06-03              2018.0               Unprovoked
# 8  2018.05.27 2018-05-27              2018.0               Unprovoked
# 9  2018.05.26 2018-05-26              2018.0               Unprovoked
#
#      Country             Area  \
# 0        USA       California
# 1        USA          Georgia
# 2        USA           Hawaii
# 3  AUSTRALIA  New South Wales
# 4     MEXICO           Colima
# 5  AUSTRALIA  New South Wales
# 6          N              NaN
# 7     BRAZIL       Pernambuco
# 8        USA          Florida
# 9        USA          Florida
#
#                                             Location  \
# 0                        Oceanside, San Diego County
# 1                     St. Simon Island, Glynn County
# 2                                       Habush, Oahu
# 3                                 Arrawarra Headland
# 4                                           La Ticla
# 5                                 Flat Rock, Ballina
# 6                                                NaN
# 7                              Piedade Beach, Recife
# 8  Lighhouse Point Park, Ponce Inlet, Volusia County
# 9                       Cocoa Beach, Brevard  County
#
#                     Activity                       Name  \
# 0                   Paddling                Julie Wolfe
# 1                   Standing            Adyson McNeely
# 2                    Surfing                John Denges
# 3                    Surfing                       male
# 4                Free diving             Gustavo Ramos
# 5               Kite surfing                     Chris
# 6  Daily Telegraph, 6/4/2018  2018.06.03.b-FlatRock.pdf
# 7                   Swimming     Jose Ernesto da Silva
# 8                    Fishing                       male
# 9                    Walking                  Cody High
#
#                                                 Sex   ...            Time  \
# 0                                                  F  ...           18h00
# 1                                                  F  ...   14h00  -15h00
# 2                                                  M  ...           07h45
# 3                                                  M  ...             NaN
# 4                                                  M  ...             NaN
# 5                                                NaN  ...             NaN
# 6  http://sharkattackfile.net/spreadsheets/pdf_di...  ...            6298
# 7                                                  M  ...  Late afternoon
# 8                                                  M  ...             NaN
# 9                                                  M  ...           17h00
#
#             Investigator or Source original order Case Number.1 Case Number.2  \
# 0                 R. Collier, GSAF         6303.0    2018.06.25    2018.06.25
# 1   K.McMurray, TrackingSharks.com         6302.0    2018.06.18    2018.06.18
# 2   K.McMurray, TrackingSharks.com         6301.0    2018.06.09    2018.06.09
# 3                   B. Myatt, GSAF         6300.0    2018.06.08    2018.06.08
# 4                        A .Kipper         6299.0    2018.06.04    2018.06.04
# 5                              NaN            NaN           NaN           NaN
# 6                              NaN            NaN           NaN           NaN
# 7   Diario de Pernambuco, 6/4/2018         6297.0  2018.06.03.a  2018.06.03.a
# 8  K. McMurray, TrackingSharks.com         6296.0    2018.05.27    2018.05.27
# 9   K.McMurray, TrackingSharks.com         6295.0  2018.05.26.b  2018.05.26.b
#
#                         pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
# 5                       NaN
# 6                       NaN
# 7  2018.06.03.a-daSilva.pdf
# 8      2018.05.27-Ponce.pdf
# 9     2018.05.26.b-High.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5                                                NaN
# 6                                                NaN
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Unnamed: 22 Unnamed: 23
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 5                                                NaN         NaN         NaN
# 6                                                NaN         NaN         NaN
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
#
# [10 rows x 23 columns]

# %%
shark_clean['Year'] = shark_clean['Year'].str.replace('\.[0-9]+','',regex=True)
shark_clean.head(10)
# Out:
#   Case Number       Date  Year                     Type    Country  \
# 0  2018.06.25 2018-06-25  2018                  Boating        USA
# 1  2018.06.18 2018-06-18  2018               Unprovoked        USA
# 2  2018.06.09 2018-06-09  2018                  Invalid        USA
# 3  2018.06.08 2018-06-08  2018               Unprovoked  AUSTRALIA
# 4  2018.06.04 2018-06-04  2018                 Provoked     MEXICO
# 5  2018.06.03 2018-06-03  2018               Unprovoked  AUSTRALIA
# 6  2010.01.01        NaT  1926  No injury, board bitten          N
# 7  2018.06.03 2018-06-03  2018               Unprovoked     BRAZIL
# 8  2018.05.27 2018-05-27  2018               Unprovoked        USA
# 9  2018.05.26 2018-05-26  2018               Unprovoked        USA
#
#               Area                                           Location  \
# 0       California                        Oceanside, San Diego County
# 1          Georgia                     St. Simon Island, Glynn County
# 2           Hawaii                                       Habush, Oahu
# 3  New South Wales                                 Arrawarra Headland
# 4           Colima                                           La Ticla
# 5  New South Wales                                 Flat Rock, Ballina
# 6              NaN                                                NaN
# 7       Pernambuco                              Piedade Beach, Recife
# 8          Florida  Lighhouse Point Park, Ponce Inlet, Volusia County
# 9          Florida                       Cocoa Beach, Brevard  County
#
#                     Activity                       Name  \
# 0                   Paddling                Julie Wolfe
# 1                   Standing            Adyson McNeely
# 2                    Surfing                John Denges
# 3                    Surfing                       male
# 4                Free diving             Gustavo Ramos
# 5               Kite surfing                     Chris
# 6  Daily Telegraph, 6/4/2018  2018.06.03.b-FlatRock.pdf
# 7                   Swimming     Jose Ernesto da Silva
# 8                    Fishing                       male
# 9                    Walking                  Cody High
#
#                                                 Sex   ...            Time  \
# 0                                                  F  ...           18h00
# 1                                                  F  ...   14h00  -15h00
# 2                                                  M  ...           07h45
# 3                                                  M  ...             NaN
# 4                                                  M  ...             NaN
# 5                                                NaN  ...             NaN
# 6  http://sharkattackfile.net/spreadsheets/pdf_di...  ...            6298
# 7                                                  M  ...  Late afternoon
# 8                                                  M  ...             NaN
# 9                                                  M  ...           17h00
#
#             Investigator or Source original order Case Number.1 Case Number.2  \
# 0                 R. Collier, GSAF         6303.0    2018.06.25    2018.06.25
# 1   K.McMurray, TrackingSharks.com         6302.0    2018.06.18    2018.06.18
# 2   K.McMurray, TrackingSharks.com         6301.0    2018.06.09    2018.06.09
# 3                   B. Myatt, GSAF         6300.0    2018.06.08    2018.06.08
# 4                        A .Kipper         6299.0    2018.06.04    2018.06.04
# 5                              NaN            NaN           NaN           NaN
# 6                              NaN            NaN           NaN           NaN
# 7   Diario de Pernambuco, 6/4/2018         6297.0  2018.06.03.a  2018.06.03.a
# 8  K. McMurray, TrackingSharks.com         6296.0    2018.05.27    2018.05.27
# 9   K.McMurray, TrackingSharks.com         6295.0  2018.05.26.b  2018.05.26.b
#
#                         pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
# 5                       NaN
# 6                       NaN
# 7  2018.06.03.a-daSilva.pdf
# 8      2018.05.27-Ponce.pdf
# 9     2018.05.26.b-High.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5                                                NaN
# 6                                                NaN
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Unnamed: 22 Unnamed: 23
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 5                                                NaN         NaN         NaN
# 6                                                NaN         NaN         NaN
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
#
# [10 rows x 23 columns]

# %%
shark_clean['Year'] = shark_clean['Year'].apply(pd.to_numeric)
shark_clean.sample(10)
# Out:
#      Case Number       Date  Year        Type       Country  \
# 6179   0000.0214        NaT     0  Unprovoked           NaN
# 5851  1878.00.00        NaT  1878  Unprovoked     AUSTRALIA
# 4285  1955.08.30 1955-08-30  1955  Unprovoked         JAPAN
# 4766  1940.07.13 1940-07-13  1940  Unprovoked           USA
# 4413  1952.05.07        NaT  1952  Unprovoked     AUSTRALIA
# 224   2016.09.05 2016-09-05  2016  Unprovoked     AUSTRALIA
# 2118  1999.07.04 1999-07-04  1999  Unprovoked           USA
# 3278  1974.02.00        NaT  1974        Boat  SOUTH AFRICA
# 3698  1964.02.10 1964-02-10  1964  Unprovoked   NEW ZEALAND
# 781   2012.06.15 2012-06-15  2012    Provoked           USA
#
#                        Area                                      Location  \
# 6179             Ionian Sea                                           NaN
# 5851        New South Wales                     Balmain, Sydney (Estuary)
# 4285            Izo Islands  Mikura-jima Island, 150 miles south of Tokyo
# 4766         South Carolina                Folly Beach, Charleston County
# 4413      Western Australia                                   Boyup Brook
# 224       Western Australia                                      Injidup
# 2118                Florida             Pensacola  Beach, Escambia County
# 3278  Western Cape Province                                      Macassar
# 3698           North Island               West of Pukerua Bay, Wellington
# 781                 Florida                 Summerland Key, Monroe County
#
#                                      Activity  \
# 6179                    Ascending from a dive
# 5851               Bathing in 2 feet of water
# 4285                                  Fishing
# 4766                                Standing
# 4413  Fishing, standing in water washing fish
# 224                                   Surfing
# 2118             Wading in school of baitfish
# 3278                     Fishing for red fish
# 3698                             Spearfishing
# 781                                   Fishing
#
#                                    Name Sex   ...            Time  \
# 6179            Tharsys, a sponge diver    M  ...             NaN
# 5851                                boy    M  ...             NaN
# 4285                 Otamatsu H. Yoshii    M  ...             NaN
# 4766          Harvey H. Haley (rescuer)    M  ...             NaN
# 4413                        Mr. M. King    M  ...             NaN
# 224                       Fraser Penman    M  ...  Late afternoon
# 2118                     Lisa Alexander    F  ...       Afternoon
# 3278  skiboat, occupant: Danie Schoeman  NaN  ...             NaN
# 3698                 Dr. Ken R. Markham    M  ...           18h30
# 781                                male    M  ...           14h20
#
#                                  Investigator or Source original order  \
# 6179  Reported by Greek poet, Leonidas of Tarentum (...          126.0
# 5851  G.P. Whitley, ref Dr. Cleland, Med. Journal Au...          454.0
# 4285  K. Nakaya, L.A. Times, 8/31/1955; V.M. Copples...         2020.0
# 4766                      V.M. Coppleson (1958), p.253          1539.0
# 4413          T. Peake, GSAF; West Australian, 5/7/1952         1892.0
# 224                                 Perth Now, 9/5/2016         6080.0
# 2118                  Pensacola News Journal, 7/5/1999          4186.0
# 3278                                   T. Wallett, p.37         3027.0
# 3698  R.D. Weeks, GSAF; Otago Daily Times, 2/11/1964...         2607.0
# 781                                             WSVN-TV         5523.0
#
#      Case Number.1 Case Number.2                           pdf  \
# 6179     0000.0214     0000.0214             214BC-Tharsys.pdf
# 5851    1878.00.00    1878.00.00        1878.00.00-Balmain.pdf
# 4285  1955.08.30.b  1955.08.30.b        1955.08.30.b-Yoshi.pdf
# 4766  1940.07.13.a  1940.07.13.a        1940.07.13.a-Haley.pdf
# 4413  1952.05.07.R  1952.05.07.R         1952.05.07.R-King.pdf
# 224   2016.09.05.a  2016.09.05.a       2016.09.05.a-Penman.pdf
# 2118    1999.07.04    1999.07.04  1999.07.04-LisaAlexander.pdf
# 3278  1974.02.00.b  1974.02.00.b     1974.02.00.b-Schoeman.pdf
# 3698    1964.02.10    1964.02.10        1964.02.10-Markham.pdf
# 781     2012.06.15    2012.06.15  2012.06.15-SummerlandKey.pdf
#
#                                            href formula  \
# 6179  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5851  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4285  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4766  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4413  http://sharkattackfile.net/spreadsheets/pdf_di...
# 224   http://sharkattackfile.net/spreadsheets/pdf_di...
# 2118  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3278  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3698  http://sharkattackfile.net/spreadsheets/pdf_di...
# 781   http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Unnamed: 22  \
# 6179  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5851  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4285  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4766  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4413  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 224   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2118  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3278  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3698  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 781   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
#
#      Unnamed: 23
# 6179         NaN
# 5851         NaN
# 4285         NaN
# 4766         NaN
# 4413         NaN
# 224          NaN
# 2118         NaN
# 3278         NaN
# 3698         NaN
# 781          NaN
#
# [10 rows x 23 columns]

# %%
shark_clean['Year'] = shark_clean['Year'].astype({'Year':'int'})
shark_clean.dtypes
# Out:
# Case Number                       object
# Date                      datetime64[ns]
# Year                               int64
# Type                              object
# Country                           object
# Area                              object
# Location                          object
# Activity                          object
# Name                              object
# Sex                               object
# Age                               object
# Fatal (Y/N)                       object
# Species                           object
# Time                              object
# Investigator or Source            object
# original order                   float64
# Case Number.1                     object
# Case Number.2                     object
# pdf                               object
# href formula                      object
# href                              object
# Unnamed: 22                       object
# Unnamed: 23                       object
# dtype: object

# %%
aux_fun = lambda x : int(x)
shark_clean['Year'] = shark_clean['Year'].map(aux_fun)
shark_clean.head(10)
# Out:
#   Case Number       Date  Year                     Type    Country  \
# 0  2018.06.25 2018-06-25  2018                  Boating        USA
# 1  2018.06.18 2018-06-18  2018               Unprovoked        USA
# 2  2018.06.09 2018-06-09  2018                  Invalid        USA
# 3  2018.06.08 2018-06-08  2018               Unprovoked  AUSTRALIA
# 4  2018.06.04 2018-06-04  2018                 Provoked     MEXICO
# 5  2018.06.03 2018-06-03  2018               Unprovoked  AUSTRALIA
# 6  2010.01.01        NaT  1926  No injury, board bitten          N
# 7  2018.06.03 2018-06-03  2018               Unprovoked     BRAZIL
# 8  2018.05.27 2018-05-27  2018               Unprovoked        USA
# 9  2018.05.26 2018-05-26  2018               Unprovoked        USA
#
#               Area                                           Location  \
# 0       California                        Oceanside, San Diego County
# 1          Georgia                     St. Simon Island, Glynn County
# 2           Hawaii                                       Habush, Oahu
# 3  New South Wales                                 Arrawarra Headland
# 4           Colima                                           La Ticla
# 5  New South Wales                                 Flat Rock, Ballina
# 6              NaN                                                NaN
# 7       Pernambuco                              Piedade Beach, Recife
# 8          Florida  Lighhouse Point Park, Ponce Inlet, Volusia County
# 9          Florida                       Cocoa Beach, Brevard  County
#
#                     Activity                       Name  \
# 0                   Paddling                Julie Wolfe
# 1                   Standing            Adyson McNeely
# 2                    Surfing                John Denges
# 3                    Surfing                       male
# 4                Free diving             Gustavo Ramos
# 5               Kite surfing                     Chris
# 6  Daily Telegraph, 6/4/2018  2018.06.03.b-FlatRock.pdf
# 7                   Swimming     Jose Ernesto da Silva
# 8                    Fishing                       male
# 9                    Walking                  Cody High
#
#                                                 Sex   ...            Time  \
# 0                                                  F  ...           18h00
# 1                                                  F  ...   14h00  -15h00
# 2                                                  M  ...           07h45
# 3                                                  M  ...             NaN
# 4                                                  M  ...             NaN
# 5                                                NaN  ...             NaN
# 6  http://sharkattackfile.net/spreadsheets/pdf_di...  ...            6298
# 7                                                  M  ...  Late afternoon
# 8                                                  M  ...             NaN
# 9                                                  M  ...           17h00
#
#             Investigator or Source original order Case Number.1 Case Number.2  \
# 0                 R. Collier, GSAF         6303.0    2018.06.25    2018.06.25
# 1   K.McMurray, TrackingSharks.com         6302.0    2018.06.18    2018.06.18
# 2   K.McMurray, TrackingSharks.com         6301.0    2018.06.09    2018.06.09
# 3                   B. Myatt, GSAF         6300.0    2018.06.08    2018.06.08
# 4                        A .Kipper         6299.0    2018.06.04    2018.06.04
# 5                              NaN            NaN           NaN           NaN
# 6                              NaN            NaN           NaN           NaN
# 7   Diario de Pernambuco, 6/4/2018         6297.0  2018.06.03.a  2018.06.03.a
# 8  K. McMurray, TrackingSharks.com         6296.0    2018.05.27    2018.05.27
# 9   K.McMurray, TrackingSharks.com         6295.0  2018.05.26.b  2018.05.26.b
#
#                         pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
# 5                       NaN
# 6                       NaN
# 7  2018.06.03.a-daSilva.pdf
# 8      2018.05.27-Ponce.pdf
# 9     2018.05.26.b-High.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5                                                NaN
# 6                                                NaN
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Unnamed: 22 Unnamed: 23
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 5                                                NaN         NaN         NaN
# 6                                                NaN         NaN         NaN
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
#
# [10 rows x 23 columns]

# %%
shark_clean.dtypes
# Out:
# Case Number                       object
# Date                      datetime64[ns]
# Year                               int64
# Type                              object
# Country                           object
# Area                              object
# Location                          object
# Activity                          object
# Name                              object
# Sex                               object
# Age                               object
# Fatal (Y/N)                       object
# Species                           object
# Time                              object
# Investigator or Source            object
# original order                   float64
# Case Number.1                     object
# Case Number.2                     object
# pdf                               object
# href formula                      object
# href                              object
# Unnamed: 22                       object
# Unnamed: 23                       object
# dtype: object

# %% [markdown]
# # limpieza de type

# %%
shark_clean['Type']= shark_clean['Type'].str.replace('Invalid|0','Unknown',regex=True).fillna('Unknown')
shark_clean.sample(60)
# Out:
#      Case Number       Date  Year          Type         Country  \
# 1775  2003.05.10 2003-05-10  2003    Unprovoked             USA
# 1249  2008.06.20 2008-06-20  2008    Unprovoked             USA
# 3945  1960.12.24 1960-12-24  1960    Unprovoked    SOUTH AFRICA
# 3471  1968.06.25 1968-06-25  1968    Unprovoked         BAHAMAS
# 460   2015.01.08 2015-01-08  2015       Unknown             USA
# 6045  1847.03.11 1847-03-11  1847  Sea Disaster       AUSTRALIA
# 1086  2009.10.09 2009-10-09  2009    Unprovoked             USA
# 1773  2003.05.25 2003-05-25  2003    Unprovoked             USA
# 482   2014.10.30 2014-10-29  2014      Provoked       AUSTRALIA
# 5239  1921.11.27 1921-11-27  1921    Unprovoked       AUSTRALIA
# 5300  1916.11.09 1916-11-09  1916    Unprovoked       AUSTRALIA
# 3323  1972.10.14 1972-10-14  1972    Unprovoked             USA
# 5230  1922.03.13 1922-03-13  1922    Unprovoked         JAMAICA
# 5756  1886.05.06 1886-05-06  1886    Unprovoked   NEW CALEDONIA
# 1709  2004.01.03 2004-01-03  2004  Sea Disaster           EGYPT
# 6231     ND.0084        NaT     0    Unprovoked    SOUTH AFRICA
# 1992  2000.11.10 2000-11-10  2000       Unknown             USA
# 3212  1975.08.12 1975-08-12  1975    Unprovoked             USA
# 6036  1849.06.08 1849-06-08  1849    Unprovoked             USA
# 5845  1878.08.09 1878-08-09  1878    Unprovoked             USA
# 4017  1960.02.07 1960-02-07  1960      Provoked       AUSTRALIA
# 2757  1988.01.06 1988-01-06  1988      Provoked    SOUTH AFRICA
# 5842  1878.09.14        NaT  1878      Provoked             USA
# 1733  2003.10.05 2003-10-05  2003    Unprovoked             USA
# 2302  1996.06.06 1996-06-06  1996    Unprovoked       AUSTRALIA
# 46    2018.02.03 2018-02-03  2018    Unprovoked         ECUADOR
# 3361  1971.07.26 1971-07-26  1971    Unprovoked             USA
# 458   2015.01.17 2015-01-17  2015       Boating       AUSTRALIA
# 3998  1960.04.22 1960-04-22  1960      Provoked       AUSTRALIA
# 413   2015.06.14 2015-06-14  2015    Unprovoked             USA
# 2078  2000.01.05 2000-01-05  2000    Unprovoked        THAILAND
# 5946     1864.05        NaT  1864    Unprovoked       MAURITIUS
# 5102  1928.08.24        NaT  1928       Unknown             USA
# 1886  2002.01.30 2002-01-30  2002    Unprovoked       AUSTRALIA
# 5745  1887.03.12 1887-03-12  1887       Boating       AUSTRALIA
# 3050  1980.12.30        NaT  1980    Unprovoked    SOUTH AFRICA
# 1225  2008.07.30        NaT  2008    Unprovoked    SOUTH AFRICA
# 5687  1892.00.00        NaT  1892      Provoked       AUSTRALIA
# 429   2015.05.02 2015-05-02  2015    Unprovoked    SOUTH AFRICA
# 1402  2007.02.04 2007-02-04  2007       Unknown      COSTA RICA
# 3121  1978.07.19 1978-07-19  1978      Provoked             USA
# 3748  1963.07.10        NaT  1963  Sea Disaster         JAMAICA
# 3948  1960.11.27 1960-11-27  1960    Unprovoked       AUSTRALIA
# 4815  1938.07.17 1938-07-17  1938      Provoked             USA
# 833   2011.12.23 2011-12-23  2011    Unprovoked             USA
# 1944  2001.05.29 2001-05-29  2001    Unprovoked             USA
# 15    2018.05.00        NaT  2018      Provoked       AUSTRALIA
# 1115  2009.07.05 2009-07-05  2009    Unprovoked             USA
# 6145  1779.00.00        NaT  1779    Unprovoked             USA
# 3865  1961.12.28 1961-12-28  1961    Unprovoked       AUSTRALIA
# 2191  1998.05.16 1998-05-16  1998    Unprovoked             USA
# 3457  1968.10.13 1968-10-13  1968    Unprovoked             USA
# 628   2013.09.02        NaT  2013    Unprovoked             USA
# 1518  2005.12.20 2005-12-20  2005       Boating  ATLANTIC OCEAN
# 4798  1939.05.03 1939-05-03  1939    Unprovoked             USA
# 5305  1916.07.13 1916-07-13  1916    Unprovoked             USA
# 4113  1959.01.31 1959-01-31  1959    Unprovoked       AUSTRALIA
# 2753  1988.02.02 1988-02-02  1988    Unprovoked            Fiji
# 4966  1933.05.24 1933-05-24  1933  Sea Disaster        BARBADOS
# 3435  1969.05.24 1969-05-24  1969      Provoked             USA
#
#                                    Area  \
# 1775                             Hawaii
# 1249                            Florida
# 3945                      KwaZulu-Natal
# 3471                          Eleuthera
# 460                             Florida
# 6045                         Queensland
# 1086                         California
# 1773                            Florida
# 482                     New South Wales
# 5239                         Queensland
# 5300                         Queensland
# 3323                  US Virgin Islands
# 5230                    Kingston Parish
# 5756                     South Province
# 1709                    Sinai Peninsula
# 6231              Eastern Cape Province
# 1992                            Florida
# 3212                            Florida
# 6036                            Florida
# 5845                           New York
# 4017                    New South Wales
# 2757              Western Cape Province
# 5842                        Connecticut
# 1733                            Florida
# 2302                           Victoria
# 46                    Galapagos Islands
# 3361                            Florida
# 458                     New South Wales
# 3998                  Western Australia
# 413                      North Carolina
# 2078                 Phang nga Province
# 5946        300 miles east of Mauritius
# 5102                         New Jersey
# 1886                  Western Australia
# 5745                    South Australia
# 3050              Eastern Cape Province
# 1225                                NaN
# 5687                      Torres Strait
# 429               Eastern Cape Province
# 1402                                NaN
# 3121                         California
# 3748                                NaN
# 3948                         Queensland
# 4815                         California
# 833                             Florida
# 1944                              Texas
# 15                    Westerm Australia
# 1115                            Florida
# 6145                             Hawaii
# 3865                         Queensland
# 2191                            Florida
# 3457                            Florida
# 628                             Florida
# 1518  600 nm west of the Canary Islands
# 4798                           Virginia
# 5305                           New York
# 4113                  Western Australia
# 2753                         Vanua Levu
# 4966                  St Michael Parish
# 3435                            Florida
#
#                                                Location  \
# 1775  Between Magic Sands Beach and Kahaluu Beach on...
# 1249                    Fernandina Beach, Nassau County
# 3945                                            Margate
# 3471                                     Spanish Wells
# 460                                                 NaN
# 6045                                        Moreton Bay
# 1086           San Onofre State Beach, San Diego County
# 1773  Coral Cove Park, Jupiter Inlet, Palm Beach County
# 482                                       Wallabi Point
# 5239      Gays Corner, Bulimba Reach of Brisbane River
# 5300                     Kissing Point Camp, Townsville
# 3323                                St. Croix, Cane Bay
# 5230                                    Kingston Harbor
# 5756                                             Noumea
# 1709                                Off Sharm El-Sheikh
# 6231                              Keiskamma River mouth
# 1992                       Vaughn Beach, Flagler County
# 3212                      Daytona Beach, Volusia County
# 6036                         Pensacola, Escambia County
# 5845                                         East River
# 4017                           Wattamolla National Park
# 2757                                         Struisbaai
# 5842                         Branford, New Haven County
# 1733  Ocean Reef Park, Singer Island, Palm Beach County
# 2302                           Suicide Point, Point Leo
# 46                                      Santa Fe Island
# 3361                      Daytona Beach, Volusia County
# 458                                Off Blacksmith Beach
# 3998                                    Rottnest Island
# 413                        Oak Island, Brunswick County
# 2078                                   Phang nga Island
# 5946                                                NaN
# 5102                                          Off shore
# 1886                                      Collie River
# 5745                                        Black Point
# 3050                                             Nahoon
# 1225                                                NaN
# 5687                                        Badu Island
# 429                                     Port St. John's
# 1402                                                NaN
# 3121                       Newport Beach, Orange County
# 3748                                                NaN
# 3948             Blacks Beach, 9 miles north of Mackay
# 4815                          Dana Point, Orange County
# 833                                    New Smyrna Beach
# 1944                                   Galveston Island
# 15                                           Dugong Bay
# 1115                      Daytona Beach, Volusia County
# 6145                                     Maliu, Hawai'i
# 3865                            Lamberts Beach, Mackay
# 2191                     Walden Rocks, St. Lucie County
# 3457                    Egmont Key, Hillsborough County
# 628                        Ormond Beach, Volusia County
# 1518                                                NaN
# 4798  At sea, several hundred miles south east of Ca...
# 5305                           Sheepshead Bay, Brooklyn
# 4113                                        South Perth
# 2753                                                NaN
# 4966                                 Off Pelican Island
# 3435                                    Sarasota County
#
#                                                Activity  \
# 1775                                           Swimming
# 1249                                             Wading
# 3945                                           Swimming
# 3471                                       Spearfishing
# 460                    Swimming after falling overboard
# 6045                             Wreck of the Sovereign
# 1086                                            Surfing
# 1773                                            Surfing
# 482                                             Surfing
# 5239         Fell from his father's back into the water
# 5300                                            Bathing
# 3323                                       Scuba diving
# 5230                                           Standing
# 5756                                            Bathing
# 1709  Air disaster. Flash Airlines Boeing 737 crashe...
# 6231                           Crossing river on a raft
# 1992                                            Walking
# 3212                   Floating on a small orange raft
# 6036                                            Bathing
# 5845                                           Swimming
# 4017                                       Spearfishing
# 2757                   Attempting to lasso shark's tail
# 5842                                            Fishing
# 1733                                            Surfing
# 2302                                            Surfing
# 46                                           Snorkeling
# 3361                                             Wading
# 458                                             Fishing
# 3998                     Fishing, hauling in a set line
# 413                                              Wading
# 2078                                             Diving
# 5946                                     Fell overboard
# 5102                                                NaN
# 1886                                           Swimming
# 5745                                    Rowing a dinghy
# 3050                                       Paddleskiing
# 1225                                                NaN
# 5687                                       Dress diving
# 429                                              Diving
# 1402                                           Swimming
# 3121                                            Fishing
# 3748                63' fishing boat Sno' Bay foundered
# 3948                                           Swimming
# 4815          Fishing, removing gaff from shark's mouth
# 833                                             Surfing
# 1944                                                NaN
# 15                                       Feeding sharks
# 1115                                    Boogie Boarding
# 6145                                            Surfing
# 3865                                           Standing
# 2191                                 Swimming / surfing
# 3457                           Spearfishing using Scuba
# 628                                            Swimming
# 1518     Competing in the Woodvale Atlantic Rowing Race
# 4798      Washed off freighter Huncliff by a freak wave
# 5305                                           Swimming
# 4113                                  Working prawn net
# 2753                                             Diving
# 4966                   Yacht of Michael Howell capsized
# 3435                                             Diving
#
#                                                    Name Sex   ...       Time  \
# 1775                                          Koa Paulo    M  ...      11h45
# 1249                                    Jennifer Cation    F  ...      11h10
# 3945                            Serame "Petrus" Sithole    M  ...      16h30
# 3471                                         Roy Pinder    M  ...        NaN
# 460                                          Rob Konrad    M  ...      Night
# 6045                                             Spicer    M  ...        NaN
# 1086                                      Bernard Wagor    M  ...      11h00
# 1773                             Kris "Cutty" Kildosher    M  ...      10h00
# 482                                           Ryan Hunt    M  ...      18h00
# 5239                                        George Jack    M  ...    Morning
# 5300                          Robert Alexander Poultney    M  ...    Evening
# 3323                                      Rodney Temple    M  ...        NaN
# 5230                                      Adeline Lopez    F  ...        NaN
# 5756                                               male    M  ...      12h00
# 1709                           135 passengers & 13 crew  NaN  ...      03h00
# 6231                                              Sinsa    M  ...        NaN
# 1992                                       Eileen Skeie    F  ...        NaN
# 3212                                     Henry Peterson    M  ...      12h00
# 6036                                       Mrs. Cracton    F  ...        NaN
# 5845                                               Cole    M  ...  Afternoon
# 4017                       John Gilles & Harry Dowswell    M  ...        NaN
# 2757                                         J.A. McKay    M  ...      11h15
# 5842                                   Captain Pattison    M  ...        NaN
# 1733                                             female    F  ...      15h00
# 2302                                       George Lucas    M  ...      17h30
# 46                                 Andrew Phipps Newman    M  ...        NaN
# 3361                                    Michael Prather    M  ...  Afternoon
# 458        Boat: occupants: Tim Watson & Allan de Sylva    M  ...      13h45
# 3998          Ted Nelson  onboard fishing boat Wayfarer    M  ...        NaN
# 413                                     Hunter Treschel    M  ...      17h51
# 2078                                       Stephan Kahl    M  ...        NaN
# 5946                     male from the whaler Albatross    M  ...        NaN
# 5102                                               male    M  ...        NaN
# 1886                                     Shayne Calliss    M  ...        NaN
# 5745                           Mr. Boucaut & Mr. Harris  NaN  ...        NaN
# 3050                                         Noel Yates    M  ...      17h15
# 1225                                     Michael Rutzen    M  ...        NaN
# 5687                                     Mr. A. Rotaman    M  ...        NaN
# 429                                     Mathieu Dasnois    M  ...      13h00
# 1402                                         Jason Cash    M  ...        NaN
# 3121                                      Harry Griffet    M  ...        NaN
# 3748                             40 people were onboard  NaN  ...        NaN
# 3948                                     Harry Bicknell    M  ...      14h45
# 4815     Harry Griffet, passenger on fishing boat Flyer    M  ...        NaN
# 833                                         Will Futato    M  ...      12h30
# 1944                                               male    M  ...        NaN
# 15                                      Melisa Brunning    F  ...        NaN
# 1115                                             female    F  ...      16h00
# 6145                                   Nu'u-anu-pa'a hu    M  ...        NaN
# 3865                                    Martyn Steffens    M  ...      16h15
# 2191                                        Roger Moore    M  ...      15h00
# 3457                                     Jim C. Johnson    M  ...        NaN
# 628                                       Raushod Floyd    M  ...      13h00
# 1518  7 m boat, occupants: Tara Remington & Iain Rudkin  NaN  ...      13h30
# 4798                                        John Heagan    M  ...        NaN
# 5305                                    Thomas Richards    M  ...        NaN
# 4113                                     George E. Rudd    M  ...      Night
# 2753                                      Qalo Moceyawa    M  ...        NaN
# 4966                              9 people in the water  NaN  ...        NaN
# 3435                                       Brian Martel    M  ...      11h00
#
#                                  Investigator or Source original order  \
# 1775                                WestHawaiiToday.com         4529.0
# 1249                             News-Leader, 6/21/2008         5055.0
# 3945  D. Davies & J. D'Aubrey; D. Davies, pp. 108-10...         2360.0
# 3471                 H.D. Baldridge, p.260; Clark, p.87         2834.0
# 460                                      UPI, 1/12/2015         5844.0
# 6045                        The Queenslander, 3/12/1921          260.0
# 1086                                         R. Collier         5218.0
# 1773                                       Local 6 News         4531.0
# 482               The Sydney Morning Herald, 10/30/2014         5822.0
# 5239                 V.M. Coppleson (1958), pp.92 & 237         1066.0
# 5300                       Brisbane Courier, 11/10/1916         1005.0
# 3323                       H.D. Baldridge, pp.177 & 185         2982.0
# 5230  Daily Gleaner, 3/21/1922, p.8; H. E. Lloyd, N....         1075.0
# 5756                            Timaru Herald, 6/8/1886          549.0
# 1709                                 Scotsman, 1/4/2004         4595.0
# 6231                        Whitaker, The Sun, 1/3/1967           74.0
# 1992                                           E. Skeie         4312.0
# 3212                          NY Times, 8/17/1975, p.27         3093.0
# 6036                           Adams Sentinel, 8/6/1849          269.0
# 5845                  Daily Kennebec Journal, 8/10/1878          460.0
# 4017        Unidentified press clipping;. SAF Case #203         2288.0
# 2757                                    M. Levine, GSAF         3548.0
# 5842                       St. Joseph Herald, 9/14/1878          463.0
# 1733                           J. Eager, scubaradio.com         4571.0
# 2302            P. Anderson, Herald Sun, 6/8/1996, p.7          4003.0
# 46                          The Standard (UK), 2/6/2018         6258.0
# 3361                              Miami News, 7/27/1971         2944.0
# 458                The Sydney Morning Herald, 1/18/2015         5846.0
# 3998                       L. Schultz & M. Malin, p.546         2307.0
# 413                                   C. Creswell, GSAF         5891.0
# 2078                                          A. Xuereb         4226.0
# 5946                  North Adams Transcript, 3/18/1898          359.0
# 5102                 Decatur Evening Herald, 8/24/1928          1203.0
# 1886                           T. Peake, GSAF; D. Green         4418.0
# 5745                          New York Times, 5/16/1887          560.0
# 3050                          N. Yates, M. Levine, GSAF         3255.0
# 1225  http://www.youtube.com/watch?v=0jVJFXlapWY&fea...         5079.0
# 5687                                G.P. Whitley, p.259          618.0
# 429                              DispatchLive, 5/4/2015         5875.0
# 1402                                The Argus, 3/2/2007         4902.0
# 3121                              Fresno Bee, 7/19/1978         3184.0
# 3748                  The Blade (Toledo, OH), 7/10/1963         2557.0
# 3948                Daily Mercury (Mackay), 11/28/1960          2357.0
# 4815                             L.A. Times, 7/18/1938          1490.0
# 833              Daytona Beach News-Journal, 12/24/2011         5471.0
# 1944                                   sharkattacks.com         4360.0
# 15                                 Perth Now, 6/30/2018         6289.0
# 1115                                       S. Petersohn         5189.0
# 6145  G.H. Balazs; J. Borg, p.68; L. Taylor (1993), ...          160.0
# 3865  V.M. Coppleson (1962), p.246; A. MacCormick, p...         2440.0
# 2191                    The Stuart (FL) News, 5/17/1998         4113.0
# 3457                              H.D. Baldridge, p.185         2848.0
# 628                                      WFTV, 9/2/2013         5676.0
# 1518            R.D. Weeks, GSAF; NZ Herald, 12/21/2005         4786.0
# 4798  L.A. Times, 5/7/1939; NY Times, 5/8/1939, p.18...         1507.0
# 5305                              NY Tribune, 7/14/1916         1000.0
# 4113  West Australian (Perth), * Sunday Times, 2/1/1...         2192.0
# 2753                                Sun, 2/5/1988, p.15         3552.0
# 4966  New York Times 5/26/1933; L. Schultz & M. Mali...         1339.0
# 3435                H.D.Baldridge (1994) SAF Case #1596         2870.0
#
#      Case Number.1 Case Number.2                                 pdf  \
# 1775    2003.05.10    2003.05.10                2003.05.10-Paulo.pdf
# 1249    2008.06.20    2008.06.20               2008.06.20-Cation.pdf
# 3945    1960.12.24    1960.12.24              1960.12.24-Sithole.pdf
# 3471    1968.06.25    1968.06.25               1968.06.25-Pinder.pdf
# 460     2015.01.08    2015.01.08               2015.01.08-Konrad.pdf
# 6045    1847.03.11    1847.03.11               1847.03.11-Spicer.pdf
# 1086    2009.10.09    2009.10.09                2009.10.09-Wagor.pdf
# 1773    2003.05.25    2003.05.25            2003.05.25-Kildosher.pdf
# 482     2014.10.30    2014.10.30                 2014.10.29-Hunt.pdf
# 5239  1921.11.27.b  1921.11.27.b             1921.11.27.a-b-Jack.pdf
# 5300    1916.11.09    1916.11.09             1916.11.09-Poultney.pdf
# 3323  1972.10.14.b  1972.10.14.b             1972.10.14.b-Temple.pdf
# 5230    1922.03.13    1922.03.13                1922.03.13-Lopez.pdf
# 5756    1886.05.06    1886.05.06               1886.05.06-Noumea.pdf
# 1709  2004.01.03.a  2004.01.03.a  2004.01.03.a-RedSeaAirDisaster.pdf
# 6231       ND.0084       ND.0084                   ND-0084-Sinsa.pdf
# 1992    2000.11.10    2000.11.10                2000.11.10-Skeie.pdf
# 3212    1975.08.12    1975.08.12             1975.08.12-Peterson.pdf
# 6036  1849.06.08.a  1849.06.08.a            1849.06.08.a-Cracton.pdf
# 5845    1878.08.09    1878.08.09                 1878.08.09-Cole.pdf
# 4017    1960.02.07    1960.02.07              1960.02.07-Gillies.pdf
# 2757    1988.01.06    1988.01.06                1988.01.06-McKay.pdf
# 5842  1878.09.14.R  1878.09.14.R           1878.09.14.R-Pattison.pdf
# 1733  2003.10.05.e  2003.10.05.e             2003.10.05.e-female.pdf
# 2302    1996.06.06    1996.06.06                1996.06.06-Lucas.pdf
# 46      2018.02.03    2018.02.03               2018.02.03-Newman.pdf
# 3361    1971.07.26    1971.07.26              1971.07.26-Prather.pdf
# 458     2015.01.17    2015.01.17         2015.01.17-Watson-Tinny.pdf
# 3998    1960.04.22    1960.04.22               1960.04.22-Nelson.pdf
# 413   2015.06.14.b  2015.06.14.b           2015.06.14.b-Treschel.pdf
# 2078    2000.01.05    2000.01.05                 2000.01.05-Kahl.pdf
# 5946    1864.05.00    1864.05.00            1864.05.00.Mauritius.pdf
# 5102  1928.08.24.R  1928.08.24.R              1928.08.24.R-Thumb.pdf
# 1886  2002.01.30.a  2002.01.30.a            2002.01.30.a-Calliss.pdf
# 5745    1887.03.12    1887.03.12   1887.03.12-dinghy-Black-Point.pdf
# 3050    1980.12.30    1980.12.30                1980.12.30-Yates.pdf
# 1225    2008.07.30    2008.07.30             2008.07.30.R-Rutzen.pdf
# 5687    1892.00.00    1892.00.00              1892.00.00-Rotaman.pdf
# 429     2015.05.02    2015.05.02              2015.05.02-Dasnois.pdf
# 1402    2007.02.04    2007.02.04                 2007.02.04-Cash.pdf
# 3121    1978.07.19    1978.07.19              1978.07.19-Griffet.pdf
# 3748  1963.07.10.R  1963.07.10.R            1963.07.10.R-Sno'Boy.pdf
# 3948    1960.11.27    1960.11.27             1960.11.27-Bicknell.pdf
# 4815    1938.07.17    1938.07.17              1938.07.17-Griffet.pdf
# 833     2011.12.23    2011.12.23               2011.12.23-Futato.pdf
# 1944    2001.05.29    2001.05.29            2001.05.29-Galveston.pdf
# 15      2018.05.00    2018.05.00             2018.05.00-Brunning.pdf
# 1115    2009.07.05    2009.07.05              2009.07.05-Daytona.pdf
# 6145    1779.00.00    1779.00.00               1779.00.00-Hawaii.pdf
# 3865  1961.12.28.b  1961.12.28.b           1961.12.28.b-Steffens.pdf
# 2191  1998.05.16.b  1998.05.16.b              1998.05.16.b-Moore.pdf
# 3457    1968.10.13    1968.10.13              1968.10.13-Johnson.pdf
# 628     2013.09.02    2013.09.02                2013.09.02-Floyd.pdf
# 1518    2005.12.20    2005.12.20              2005.12.20-rowboat.pdf
# 4798    1939.05.03    1939.05.03               1939.05.03-Heagan.pdf
# 5305    1916.07.13    1916.07.13           1916.07.13.a-Richards.pdf
# 4113    1959.01.31    1959.01.31                 1959.01.31-Rudd.pdf
# 2753    1988.02.02    1988.02.02        1988.02.02-Fiji-Moceyawa.pdf
# 4966    1933.05.24    1933.05.24       1933.05.24-yacht-Barbados.pdf
# 3435    1969.05.24    1969.05.24            1969.05.24-NV-Martel.pdf
#
#                                            href formula  \
# 1775  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1249  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3945  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3471  http://sharkattackfile.net/spreadsheets/pdf_di...
# 460   http://sharkattackfile.net/spreadsheets/pdf_di...
# 6045  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1086  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1773  http://sharkattackfile.net/spreadsheets/pdf_di...
# 482   http://sharkattackfile.net/spreadsheets/pdf_di...
# 5239  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5300  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3323  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5230  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5756  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1709  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6231  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1992  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3212  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6036  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5845  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4017  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2757  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5842  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1733  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2302  http://sharkattackfile.net/spreadsheets/pdf_di...
# 46    http://sharkattackfile.net/spreadsheets/pdf_di...
# 3361  http://sharkattackfile.net/spreadsheets/pdf_di...
# 458   http://sharkattackfile.net/spreadsheets/pdf_di...
# 3998  http://sharkattackfile.net/spreadsheets/pdf_di...
# 413   http://sharkattackfile.net/spreadsheets/pdf_di...
# 2078  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5946  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5102  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1886  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5745  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3050  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1225  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5687  http://sharkattackfile.net/spreadsheets/pdf_di...
# 429   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1402  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3121  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3748  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3948  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4815  http://sharkattackfile.net/spreadsheets/pdf_di...
# 833   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1944  http://sharkattackfile.net/spreadsheets/pdf_di...
# 15    http://sharkattackfile.net/spreadsheets/pdf_di...
# 1115  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6145  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3865  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2191  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3457  http://sharkattackfile.net/spreadsheets/pdf_di...
# 628   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1518  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4798  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5305  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4113  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2753  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4966  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3435  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Unnamed: 22  \
# 1775  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1249  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3945  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3471  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 460   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6045  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1086  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1773  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 482   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5239  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5300  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3323  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5230  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5756  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1709  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6231  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1992  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3212  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6036  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5845  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4017  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2757  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5842  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1733  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2302  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 46    http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3361  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 458   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3998  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 413   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2078  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5946  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5102  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1886  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5745  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3050  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1225  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5687  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 429   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1402  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3121  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3748  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3948  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4815  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 833   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1944  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 15    http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1115  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6145  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3865  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2191  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3457  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 628   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1518  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4798  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5305  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4113  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2753  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4966  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3435  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
#
#           Unnamed: 23
# 1775              NaN
# 1249              NaN
# 3945              NaN
# 3471              NaN
# 460               NaN
# 6045              NaN
# 1086              NaN
# 1773              NaN
# 482               NaN
# 5239              NaN
# 5300              NaN
# 3323              NaN
# 5230              NaN
# 5756              NaN
# 1709              NaN
# 6231              NaN
# 1992              NaN
# 3212              NaN
# 6036              NaN
# 5845              NaN
# 4017              NaN
# 2757              NaN
# 5842  change filename
# 1733              NaN
# 2302              NaN
# 46                NaN
# 3361              NaN
# 458               NaN
# 3998              NaN
# 413               NaN
# 2078              NaN
# 5946              NaN
# 5102              NaN
# 1886              NaN
# 5745              NaN
# 3050              NaN
# 1225              NaN
# 5687              NaN
# 429               NaN
# 1402              NaN
# 3121              NaN
# 3748              NaN
# 3948              NaN
# 4815              NaN
# 833               NaN
# 1944              NaN
# 15                NaN
# 1115              NaN
# 6145              NaN
# 3865              NaN
# 2191              NaN
# 3457              NaN
# 628               NaN
# 1518              NaN
# 4798              NaN
# 5305              NaN
# 4113              NaN
# 2753              NaN
# 4966              NaN
# 3435              NaN
#
# [60 rows x 23 columns]

# %%
shark_clean.Type.unique
# Out:
# <bound method Series.unique of 0          Boating
# 1       Unprovoked
# 2          Unknown
# 3       Unprovoked
# 4         Provoked
#            ...
# 6309       Unknown
# 6310       Unknown
# 6311       Unknown
# 6312       Unknown
# 6313       Unknown
# Name: Type, Length: 6314, dtype: object>

# %%
def tipo(x):
    if 'Boat' in x:
        return 'Boating'
    elif 'Unprov' in x:
        return 'Unprovoked'
    elif 'Unknown' in x:
        return 'Unknown'
    elif 'Prov' in x:
        return 'Provoked'
    else:
        return 'Unknown'

shark_clean['Type'] = shark_clean['Type'].apply(tipo)

# %%
shark_clean.Type
# Out:
# 0          Boating
# 1       Unprovoked
# 2          Unknown
# 3       Unprovoked
# 4         Provoked
#            ...
# 6309       Unknown
# 6310       Unknown
# 6311       Unknown
# 6312       Unknown
# 6313       Unknown
# Name: Type, Length: 6314, dtype: object

# %% [markdown]
# # limpieza de country

# %%
shark_clean['Country'] = shark_clean['Country'].fillna('Unknown')
shark_clean.sample(10)
# Out:
#      Case Number       Date  Year        Type         Country  \
# 1338  2007.09.03 2007-09-03  2007  Unprovoked             USA
# 4912  1935.04.25 1935-04-25  1935     Unknown       AUSTRALIA
# 5699  1890.10.25        NaT  1890  Unprovoked  ATLANTIC OCEAN
# 225   2016.09.04 2016-09-04  2016  Unprovoked             USA
# 5859  1877.03.16 1877-03-16  1877  Unprovoked           ITALY
# 5997  1856.11.25        NaT  1856  Unprovoked            FIJI
# 5414  1909.12.05 1909-12-05  1909    Provoked       AUSTRALIA
# 4914  1935.04.08        NaT  1935  Unprovoked             USA
# 2322  1996.01.23 1996-01-23  1996    Provoked             USA
# 3628  1965.05.00        NaT  1965  Unprovoked         JAMAICA
#
#                    Area                           Location  \
# 1338            Florida    Fort Lauderdale, Broward County
# 4912    New South Wales                             Coogee
# 5699                NaN                                NaN
# 225             Florida   New Smyrna Beach, Volusia County
# 5859  Strait of Messina                       Off Calabria
# 5997                NaN                                NaN
# 5414    New South Wales                              Bondi
# 4914         California  Hermosa Beach, Los Angeles County
# 2322            Florida        Florida Keys, Monroe County
# 3628                NaN                                NaN
#
#                                                Activity  \
# 1338                                           Swimming
# 4912  Disappeared 11 days earlier, probable homicide...
# 5699                                   Thrown overboard
# 225                                       Body boarding
# 5859                                           Paddling
# 5997                                           Swimming
# 5414                                            Fishing
# 4914                                                NaN
# 2322                                             Wading
# 3628                                             Diving
#
#                             Name Sex   ...   Time  \
# 1338           Dominco Iaciofano    M  ...  09h45
# 4912  James Smith, murder victim    M  ...    NaN
# 5699          Captain Lavarello     M  ...    NaN
# 225                 Austin Moore    M  ...    NaN
# 5859         Captain Paul Boyton    M  ...    NaN
# 5997                    a seaman    M  ...    NaN
# 5414                        male    M  ...    NaN
# 4914                 A. R. Davis    M  ...    NaN
# 2322           Christopher Riley    M  ...    NaN
# 3628                 Ken Bernard    M  ...    NaN
#
#                              Investigator or Source original order  \
# 1338  S. Wyman, Sun-Sentinel, 9/3/2007; Local10.com         4966.0
# 4912                            A. Sharpe, pp.28-32         1393.0
# 5699                    Taranaki Herald, 10/25/1890          606.0
# 225                      Orlando Sentinel, 9/7/2016         6079.0
# 5859                             J. Stanton, et. Al          446.0
# 5997                          The Argus, 11/25/1856          308.0
# 5414                      The Advertiser, 12/9/1909          891.0
# 4914                   Los Angeles Times, 4/8/1935          1391.0
# 2322                        Miami Herald, 1/25/1996         3983.0
# 3628            H.D.Baldridge (1994) SAF Case #1498         2677.0
#
#      Case Number.1 Case Number.2                          pdf  \
# 1338  2007.09.03.a  2007.09.03.a   2007.09.03.a-Iaciofano.pdf
# 4912    1935.04.25    1935.04.25  1935.04.25-SharkArmCase.pdf
# 5699  1890.10.25.R  1890.10.25.R   1890.10.25.R-Lavarello.pdf
# 225     2016.09.04    2016.09.04         2016.09.04-Moore.pdf
# 5859    1877.03.16    1877.03.16        1877.03.16-Boyton.pdf
# 5997  1856.11.25.R  1856.11.25.R        1856.11.25.R-Fiji.pdf
# 5414    1909.12.05    1909.12.05     1909.12.05-Fisherman.pdf
# 4914  1935.04.08.R  1935.04.08.R       1935.04.08.R-Davis.pdf
# 2322    1996.01.23    1996.01.23         1996.01.23-Riley.pdf
# 3628  1965.05.00.b  1965.05.00.b  1965.05.00.b-NV-Bernard.pdf
#
#                                            href formula  \
# 1338  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4912  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5699  http://sharkattackfile.net/spreadsheets/pdf_di...
# 225   http://sharkattackfile.net/spreadsheets/pdf_di...
# 5859  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5997  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5414  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4914  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2322  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3628  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Unnamed: 22  \
# 1338  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4912  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5699  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 225   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5859  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5997  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5414  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4914  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2322  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3628  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
#
#      Unnamed: 23
# 1338         NaN
# 4912         NaN
# 5699         NaN
# 225          NaN
# 5859         NaN
# 5997         NaN
# 5414         NaN
# 4914         NaN
# 2322         NaN
# 3628         NaN
#
# [10 rows x 23 columns]

# %% [markdown]
# # limpieza de Area

# %%
shark_clean['Area'] = shark_clean['Area'].fillna('Unknown')
shark_clean.sample(10)
# Out:
#      Case Number       Date  Year        Type               Country  \
# 318   2016.01.11        NaT  2016  Unprovoked             AUSTRALIA
# 817   2012.02.26 2012-02-26  2012    Provoked                   USA
# 3419  1969.11.11 1969-11-11  1969  Unprovoked                   USA
# 4392  1953.01.08 1953-01-08  1953     Boating             AUSTRALIA
# 3694  1964.02.17        NaT  1964    Provoked                  FIJI
# 4736  1941.11.27 1941-11-27  1941     Unknown  SOUTH ATLANTIC OCEAN
# 3226  1975.06.15 1975-06-15  1975  Unprovoked                   USA
# 6174  1554.00.00        NaT  1554  Unprovoked                FRANCE
# 1109  2009.07.22 2009-07-22  2009  Unprovoked                   USA
# 4922  1935.02.14 1935-02-14  1935  Unprovoked             AUSTRALIA
#
#                    Area                             Location  \
# 318          Queensland        Happy Valley Beach, Caloundra
# 817             Florida  Palm Beach Inlet, Palm Beach County
# 3419             Hawaii                Barbers Point, O'ahu
# 4392           Tasmania                              Wynyard
# 3694            Unknown                          Savuli Reef
# 4736          Off Libya                                  NaN
# 3226            Alabama                5 miles off the coast
# 6174  Nice & Marseilles                                  NaN
# 1109     North Carolina       Holden Beach. Brunswick County
# 4922    New South Wales                            Austinmer
#
#                                            Activity  \
# 318                                         Surfing
# 817                                    Kite Surfing
# 3419                      Scuba diving for lobsters
# 4392                                        Fishing
# 3694                                        Fishing
# 4736  HMAS Parramatta torpedoed & sunk by the U-559
# 3226                         Swimming near his boat
# 6174                                            NaN
# 1109                                       Swimming
# 4922                  Surfing (pneumatic surfboard)
#
#                                        Name Sex   ...       Time  \
# 318                            Shane Hilder    M  ...        NaN
# 817                            Jason Lasser    M  ...      14h00
# 3419                          D.R. McGinnis    M  ...        NaN
# 4392                    14-foot boat Sintra  NaN  ...  Afternoon
# 3694  boat, occupant: R. Southey of Lautoka  NaN  ...        NaN
# 4736                         Gordon Annison    M  ...        NaN
# 3226                  William Wayne Daniels    M  ...        NaN
# 6174                  males (wearing armor)    M  ...        NaN
# 1109                  Julia Anne Mittleberg    F  ...      15h00
# 4922                           Darcy Lorenz    M  ...      17h30
#
#                                  Investigator or Source original order  \
# 318                       ABC Sunshine Coast, 1/11/2016         5986.0
# 817                         Aspen Daily News, 2/29/2012         5487.0
# 3419  H.D. Baldridge, p.185; J. Borg, p.74;  L. Tayl...         2886.0
# 4392                                     C. Black, GSAF         1913.0
# 3694                              Fiji Times, 2/17/1964         2611.0
# 4736                          Canberra Times, 12/3/1941         1569.0
# 3226                                The News, 6/16/1975         3079.0
# 6174                                       G. Rondelet           131.0
# 1109                                  C. Creswell, GSAF         5195.0
# 4922                 V.M. Coppleson (1958), pp.45 & 233         1383.0
#
#      Case Number.1 Case Number.2                          pdf  \
# 318   2016.01.11.R  2016.01.11.R      2016.01.11.R-Hilder.pdf
# 817     2012.02.26    2012.02.26        2012.02.26-Lasser.pdf
# 3419    1969.11.11    1969.11.11      1969.11.11-McGinnis.pdf
# 4392    1953.01.08    1953.01.08       1953.01.08-Wynyard.pdf
# 3694  1964.02.17.R  1964.02.17.R   1964.02.17.R-Fiji-boat.pdf
# 4736  1941.11.27.a  1941.11.27.a     1941.11.27.a-Annison.pdf
# 3226    1975.06.15    1975.06.15       1975.06.15-Daniels.pdf
# 6174    1554.00.00    1554.00.00      1554.00.00-Rondelet.pdf
# 1109  2009.07.22.b  2009.07.22.b  2009.07.22.b-Mittleberg.pdf
# 4922    1935.02.14    1935.02.14        1935.02.14-Lorenz.pdf
#
#                                            href formula  \
# 318   http://sharkattackfile.net/spreadsheets/pdf_di...
# 817   http://sharkattackfile.net/spreadsheets/pdf_di...
# 3419  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4392  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3694  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4736  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3226  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6174  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1109  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4922  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Unnamed: 22  \
# 318   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 817   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3419  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4392  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3694  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4736  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3226  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6174  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1109  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4922  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
#
#      Unnamed: 23
# 318          NaN
# 817          NaN
# 3419         NaN
# 4392         NaN
# 3694         NaN
# 4736         NaN
# 3226         NaN
# 6174         NaN
# 1109         NaN
# 4922         NaN
#
# [10 rows x 23 columns]

# %% [markdown]
# # limpieza de location

# %%
shark_clean['Location']=shark_clean['Location'].fillna('Unknown')
shark_clean.sample(13)
# Out:
#      Case Number       Date  Year        Type       Country  \
# 3232  1975.04.18 1975-04-18  1975     Unknown  SOUTH AFRICA
# 4268  1956.00.00        NaT  1956     Unknown       Unknown
# 2638  1990.05.06 1990-05-06  1990  Unprovoked  SOUTH AFRICA
# 1390  2007.04.13        NaT  2007     Boating           USA
# 3828  1962.04.09 1962-04-09  1962  Unprovoked    MOZAMBIQUE
# 4996  1932.02.16 1932-02-16  1932  Unprovoked           USA
# 717   2012.12.19 2012-12-19  2012  Unprovoked     AUSTRALIA
# 3728  1963.11.30        NaT  1963  Unprovoked   NEW ZEALAND
# 4938  1934.08.21 1934-08-21  1934  Unprovoked       CROATIA
# 159   2017.04.12 2017-04-12  2017  Unprovoked           USA
# 2062  2000.03.30 2000-03-30  2000  Unprovoked     AUSTRALIA
# 218   2016.09.15 2016-09-16  2016  Unprovoked     AUSTRALIA
# 1680  2004.04.13 2004-04-13  2004     Unknown         TONGA
#
#                               Area                              Location  \
# 3232                 KwaZulu-Natal                                Durban
# 4268  Between Comores & Madagascar                           Geyser Bank
# 2638         Eastern Cape Province                           Cintsa East
# 1390                       Florida           Florida Keys, Monroe County
# 3828                          Gaza                               Xai Xai
# 4996                        Hawaii  1 mile off Mala Wharf, Lahaina, Maui
# 717              Western Australia                           Trigg Beach
# 3728                  South Island      Charteris Bay, Lyttleton Harbour
# 4938                  Adriatic Sea                Susak (Rijeka, Istria)
# 159                        Florida                         St. Augustine
# 2062                    Queensland                Main Beach, Gold Coast
# 218                       Victoria                           Bells Beach
# 1680                    Nuku'alofa            30 nautical miles offshore
#
#                                                Activity  \
# 3232                                                NaN
# 4268                                          Shipwreck
# 2638                               Resting on surfboard
# 1390                                            Fishing
# 3828                                           Swimming
# 4996                                           Swimming
# 717                                             Surfing
# 3728      Treading water while alongside capsized yacht
# 4938                                           Swimming
# 159                                             Surfing
# 2062                                           Swimming
# 218                                             Surfing
# 1680  Five men on makeshift raft after their 10 m fi...
#
#                                                    Name Sex   ...   Time  \
# 3232                                        Indian male    M  ...    NaN
# 4268   Captain Eric Hunt, the cook & a French passenger    M  ...    NaN
# 2638                                  Richard Forrester    M  ...  12h00
# 1390               boat: 48' charter boat  GonFishin V   NaN  ...    NaN
# 3828                              Brian Lawrence Martin    M  ...  10h30
# 4996  William France, a sailor from U.S. Navy vessel...    M  ...    NaN
# 717                                       Richard Wands    M  ...   0830
# 3728                                     Charlie Dudley    M  ...  13h00
# 4938                                        Agnes Novak    F  ...    NaN
# 159                                        Kerry Keyton    F  ...  13h45
# 2062                             Anrija (Andy) Rojcezic    M  ...  14h00
# 218                                                male    M  ...    NaN
# 1680                                             male 1    M  ...    NaN
#
#                                  Investigator or Source original order  \
# 3232                                      B. Davis, NSB         3073.0
# 4268                                       dinofish.com         2037.0
# 2638                      R. Forrester, M. Levine, GSAF         3667.0
# 1390              Florida Today, 4/13/2007; A. Brenneka         4914.0
# 3828  M. Levine, GSAF;P.H. Jacques, M.D.;  D. Davies...         2477.0
# 4996  San Antonio Light (San Antonio, Texas), 2/17/1...         1309.0
# 717                      The West Ausralian, 12/20/2012         5587.0
# 3728  C. Dudley, R.D. Weeks, GSAF; H.D. Baldridge, S...         2577.0
# 4938  NY Times, 7/10/1934, p.15; V.M. Coppleson (195...         1367.0
# 159                         The Surf Station, 4/13/2017         6145.0
# 2062                                     T. Peake, GSAF         4242.0
# 218                                  The Age, 9/16/2016         6086.0
# 1680                      New Zealand Herald, 4/15/2004         4624.0
#
#      Case Number.1 Case Number.2                           pdf  \
# 3232    1975.04.18    1975.04.18     1975.04.18-IndianMale.pdf
# 4268  1956.00.00.g  1956.00.00.g    1956.00.00.g-Capt-Hunt.pdf
# 2638    1990.05.06    1990.05.06      1990.05.06-Forrester.pdf
# 1390  2007.04.13.R  2007.04.13.R    2007.04.13.R-GonFishin.pdf
# 3828    1962.04.09    1962.04.09         1962.04.09-Martin.pdf
# 4996    1932.02.16    1932.02.16  1932.02.16-WilliamFrance.pdf
# 717     2012.12.19    2012.12.19          2012.12.19-Wands.pdf
# 3728  1963.11.30.b  1963.11.30.b       1963.11.30.b-Dudley.pdf
# 4938    1934.08.21    1934.08.21          1934.08.21-Novak.pdf
# 159   2017.04.12.b  2017.04.12.b       2017.04.12.b-Keyton.pdf
# 2062    2000.03.30    2000.03.30       2000.03.30-Rojcevic.pdf
# 218     2016.09.16    2016.09.15     2016.09.16-BellsBeach.pdf
# 1680  2004.04.13.a  2004.04.13.a        2004.04.13.a-Tonga.pdf
#
#                                            href formula  \
# 3232  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4268  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2638  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1390  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3828  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4996  http://sharkattackfile.net/spreadsheets/pdf_di...
# 717   http://sharkattackfile.net/spreadsheets/pdf_di...
# 3728  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4938  http://sharkattackfile.net/spreadsheets/pdf_di...
# 159   http://sharkattackfile.net/spreadsheets/pdf_di...
# 2062  http://sharkattackfile.net/spreadsheets/pdf_di...
# 218   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1680  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Unnamed: 22  \
# 3232  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4268  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2638  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1390  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3828  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4996  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 717   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3728  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4938  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 159   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2062  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 218   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1680  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
#
#      Unnamed: 23
# 3232         NaN
# 4268         NaN
# 2638         NaN
# 1390         NaN
# 3828         NaN
# 4996         NaN
# 717          NaN
# 3728         NaN
# 4938         NaN
# 159          NaN
# 2062         NaN
# 218          NaN
# 1680         NaN
#
# [13 rows x 23 columns]

# %% [markdown]
# # limpieza de Activity

# %%
shark_clean['Activity']=shark_clean['Activity'].fillna('Unknown')
shark_clean.head()
# Out:
#   Case Number       Date  Year        Type    Country             Area  \
# 0  2018.06.25 2018-06-25  2018     Boating        USA       California
# 1  2018.06.18 2018-06-18  2018  Unprovoked        USA          Georgia
# 2  2018.06.09 2018-06-09  2018     Unknown        USA           Hawaii
# 3  2018.06.08 2018-06-08  2018  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04 2018-06-04  2018    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
#             Time          Investigator or Source original order Case Number.1  \
# 0          18h00                R. Collier, GSAF         6303.0    2018.06.25
# 1  14h00  -15h00  K.McMurray, TrackingSharks.com         6302.0    2018.06.18
# 2          07h45  K.McMurray, TrackingSharks.com         6301.0    2018.06.09
# 3            NaN                  B. Myatt, GSAF         6300.0    2018.06.08
# 4            NaN                       A .Kipper         6299.0    2018.06.04
#
#   Case Number.2                       pdf  \
# 0    2018.06.25      2018.06.25-Wolfe.pdf
# 1    2018.06.18    2018.06.18-McNeely.pdf
# 2    2018.06.09     2018.06.09-Denges.pdf
# 3    2018.06.08  2018.06.08-Arrawarra.pdf
# 4    2018.06.04      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Unnamed: 22 Unnamed: 23
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
#
# [5 rows x 23 columns]

# %%
shark_clean.Activity.unique()
# Out:
# array(['Paddling', 'Standing', 'Surfing', ...,
#        'Crew swimming alongside their anchored ship',
#        '4 men were bathing', 'Wreck of  large double sailing canoe'],
#       dtype=object)

# %%
def actividad(x):
    if 'Padd' in x:
        return 'Paddling'
    elif 'Surf' in x:
        return 'Surfing'
    else:
        return 'Unknown'

# %%
shark_clean.Activity = shark_clean.Activity.apply(actividad)
shark_clean
# Out:
#      Case Number       Date  Year        Type    Country             Area  \
# 0     2018.06.25 2018-06-25  2018     Boating        USA       California
# 1     2018.06.18 2018-06-18  2018  Unprovoked        USA          Georgia
# 2     2018.06.09 2018-06-09  2018     Unknown        USA           Hawaii
# 3     2018.06.08 2018-06-08  2018  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04 2018-06-04  2018    Provoked     MEXICO           Colima
# ...          ...        ...   ...         ...        ...              ...
# 6309           0        NaT  1926     Unknown    Unknown          Unknown
# 6310           0        NaT  1926     Unknown    Unknown          Unknown
# 6311           0        NaT  1926     Unknown    Unknown          Unknown
# 6312  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
# 6313  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
#
#                             Location  Activity             Name Sex   ...  \
# 0        Oceanside, San Diego County  Paddling      Julie Wolfe    F  ...
# 1     St. Simon Island, Glynn County   Unknown  Adyson McNeely     F  ...
# 2                       Habush, Oahu   Surfing      John Denges    M  ...
# 3                 Arrawarra Headland   Surfing             male    M  ...
# 4                           La Ticla   Unknown   Gustavo Ramos     M  ...
# ...                              ...       ...              ...  ...  ...
# 6309                         Unknown   Unknown              NaN  NaN  ...
# 6310                         Unknown   Unknown              NaN  NaN  ...
# 6311                         Unknown   Unknown              NaN  NaN  ...
# 6312                         Unknown   Unknown              NaN  NaN  ...
# 6313                         Unknown   Unknown              NaN  NaN  ...
#
#                Time          Investigator or Source original order  \
# 0             18h00                R. Collier, GSAF         6303.0
# 1     14h00  -15h00  K.McMurray, TrackingSharks.com         6302.0
# 2             07h45  K.McMurray, TrackingSharks.com         6301.0
# 3               NaN                  B. Myatt, GSAF         6300.0
# 4               NaN                       A .Kipper         6299.0
# ...             ...                             ...            ...
# 6309            NaN                             NaN         6309.0
# 6310            NaN                             NaN         6310.0
# 6311            NaN                             NaN            NaN
# 6312            NaN                             NaN            NaN
# 6313            NaN                             NaN            NaN
#
#      Case Number.1 Case Number.2                       pdf  \
# 0       2018.06.25    2018.06.25      2018.06.25-Wolfe.pdf
# 1       2018.06.18    2018.06.18    2018.06.18-McNeely.pdf
# 2       2018.06.09    2018.06.09     2018.06.09-Denges.pdf
# 3       2018.06.08    2018.06.08  2018.06.08-Arrawarra.pdf
# 4       2018.06.04    2018.06.04      2018.06.04-Ramos.pdf
# ...            ...           ...                       ...
# 6309           NaN           NaN                       NaN
# 6310           NaN           NaN                       NaN
# 6311           NaN           NaN                       NaN
# 6312           NaN           NaN                       NaN
# 6313           NaN           NaN                       NaN
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6309                                                NaN
# 6310                                                NaN
# 6311                                                NaN
# 6312                                                NaN
# 6313                                                NaN
#
#                                                    href Unnamed: 22  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                 ...         ...
# 6309                                                NaN         NaN
# 6310                                                NaN         NaN
# 6311                                                NaN         NaN
# 6312                                                NaN         NaN
# 6313                                                NaN         NaN
#
#      Unnamed: 23
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 6309         NaN
# 6310         NaN
# 6311         NaN
# 6312         NaN
# 6313         NaN
#
# [6314 rows x 23 columns]

# %% [markdown]
# # limpieza Name

# %%
shark_clean['Name'].value_counts()
# Out:
# male                                                                 550
# female                                                                97
# boy                                                                   23
# 2 males                                                               16
# boat                                                                  14
#                                                                     ...
# Frederick Jordan, Jr.                                                  1
# Yevgeniy (Eugene) Trishkin                                             1
# Eric Johanssen                                                         1
# inflatable rescue boat. Occupants: Lauren Johnson &. Kris O'Neill      1
# I. Padden                                                              1
# Name: Name, Length: 5232, dtype: int64

# %%
shark_clean['Name']=shark_clean['Name'].str.replace\
('male|female|boy|2 males|boat|sailor|JapaneseUnknown|Anonymous|Unknowns|child|girl|a Unknown|Unidentified|\
fisherman| Unknown|a pearl diver|a soldier|IndianUnknown|a native|blackUnknown|\
ArabUnknown|AmericanUnknown|ZuluUnknown|JapaneseUnknown|\
2 fishermen|youngUnknown|FijianUnknown|Unknown x 2|unknown|3Unknown|aboriginalUnknown|\
Japanese diver|nativeUnknown|woman|2 women|RussianUnknown|dinghy|AUnknown'\
 ,'Unknown',regex=True)\
.fillna('Unknown')
shark_clean.sample(10)
# Out:
#      Case Number       Date  Year        Type       Country  \
# 1238  2008.07.09 2008-07-09  2008  Unprovoked           USA
# 4135  1958.11.14 1958-11-14  1958     Unknown  SOUTH AFRICA
# 2686  1989.06.00        NaT  1989     Unknown         JAPAN
# 2897  1984.06.03 1984-06-03  1984  Unprovoked       VANUATU
# 720   2012.12.00        NaT  2012  Unprovoked   NEW ZEALAND
# 3713  1964.01.04 1964-01-04  1964  Unprovoked          FIJI
# 3732  1963.11.16        NaT  1963  Unprovoked         ITALY
# 3377  1970.12.13 1970-12-13  1970  Unprovoked    MOZAMBIQUE
# 1472  2006.06.18 2006-06-18  2006  Unprovoked        BRAZIL
# 2450  1994.02.27 1994-02-27  1994  Unprovoked  SOUTH AFRICA
#
#                        Area  \
# 1238         North Carolina
# 4135  Western Cape Province
# 2686           Sea of Japan
# 2897       Malampa Province
# 720            South Island
# 3713          Lomaloma, Lau
# 3732                 Sicily
# 3377       Inhambe Province
# 1472             Pernambuco
# 2450  Western Cape Province
#
#                                                Location Activity  \
# 1238                      Emerald Isle, Carteret County  Unknown
# 4135                                          False Bay  Unknown
# 2686                                            Unknown  Unknown
# 2897                        Atchin Island, off Malakula  Unknown
# 720                              Sunday Cove, Fiordland  Unknown
# 3713                                      Tuvuca Isalnd  Unknown
# 3732                            Off Mondello Lighthouse  Unknown
# 3377  Inhambe Bay Estuary, 10 to 12 miles inland fro...  Unknown
# 1472                     Punta Del Chifre Beach, Olinda  Unknown
# 2450                                         Saxon Reef  Unknown
#
#                          Name Sex   ...   Time         Investigator or Source  \
# 1238         Bailleigh Foster    F  ...  19h30              C. Creswell, GSAF
# 4135                  Unknown    M  ...    NaN      Clipping dated 11/15/1958
# 2686                  Unknown    M  ...    NaN                      K. Nakaya
# 2897               Felix Brem    M  ...    NaN     Telegraph, 6/8/1984, p.12
# 720              Jenny Oliver    F  ...    NaN         Stuff.co.nz, 1/18/2013
# 3713      Tale Meve (Unknown)    F  ...  15h00                 SAF Case #1250
# 3732               Dr. Salito    M  ...    NaN                 C. Moore, GSAF
# 3377            black Unknown    M  ...    NaN     GSAF; H.D. Baldridge, p.22
# 1472  Humberto Pessoa Batista    M  ...  09h00             globalsurfnews.com
# 2450           Gary Lieberman    M  ...  11h00  G. Lieberman, M. Levine, GSAF
#
#      original order Case Number.1 Case Number.2  \
# 1238         5066.0    2008.07.09    2008.07.09
# 4135         2170.0    1958.11.14    1958.11.14
# 2686         3619.0    1989.06.00    1989.06.00
# 2897         3408.0    1984.06.03    1984.06.03
# 720          5584.0    2012.12.00    2012.12.00
# 3713         2592.0    1964.01.04    1964.01.04
# 3732         2573.0  1963.11.16.R  1963.11.16.R
# 3377         2928.0    1970.12.13    1970.12.13
# 1472         4832.0    2006.06.18    2006.06.18
# 2450         3855.0    1994.02.27    1994.02.27
#
#                                       pdf  \
# 1238                2008.07.09-Foster.pdf
# 4135     1958.11.14-FalseBayFisherman.pdf
# 2686          1989.06.00-Sea-of-Japan.pdf
# 2897                  1984.06.03-Brem.pdf
# 720                 2012.12.00-Oliver.pdf
# 3713                  1964.01.04-Meve.pdf
# 3732              1963.11.16.R-Salito.pdf
# 3377  1970.12.13-BlackMale-Mozambique.pdf
# 1472               2006.06.18-Batista.pdf
# 2450             1994.02.27-Lieberman.pdf
#
#                                            href formula  \
# 1238  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4135  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2686  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2897  http://sharkattackfile.net/spreadsheets/pdf_di...
# 720   http://sharkattackfile.net/spreadsheets/pdf_di...
# 3713  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3732  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3377  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1472  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2450  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Unnamed: 22  \
# 1238  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4135  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2686  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2897  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 720   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3713  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3732  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3377  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1472  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2450  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
#
#      Unnamed: 23
# 1238         NaN
# 4135         NaN
# 2686         NaN
# 2897         NaN
# 720          NaN
# 3713         NaN
# 3732         NaN
# 3377         NaN
# 1472         NaN
# 2450         NaN
#
# [10 rows x 23 columns]

# %%
shark_clean['Name'].value_counts().sample(10)
# Out:
# Peter Kurmann         1
# Kahlifeh              1
# Cornelius Conhlren    1
# 25' cutter            1
# Linda Ann Horton      1
# Taylor Warnock        1
# Johnny Simatacolos    1
# Kevin King            1
# Rodney Orr            2
# Lance Donahue, Jr     1
# Name: Name, dtype: int64

# %% [markdown]
# # limpieza sex

# %%
shark_clean.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Fatal (Y/N)', 'Species ', 'Time',
#        'Investigator or Source', 'original order', 'Case Number.1',
#        'Case Number.2', 'pdf', 'href formula', 'href', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
columnas = {shark_clean.columns[9] : 'Sex'}
shark_clean = shark_clean.rename(columns=columnas)
shark_clean['Sex']
# Out:
# 0         F
# 1         F
# 2         M
# 3         M
# 4         M
#        ...
# 6309    NaN
# 6310    NaN
# 6311    NaN
# 6312    NaN
# 6313    NaN
# Name: Sex, Length: 6314, dtype: object

# %%
def sexo(x):
    if 'F' in x:
        return 'Female'
    elif 'M' in x:
        return 'Male'
    elif 'M ' in x:
        return 'Male'
    elif 'ND' in x:
        return 'ND'
    else:
        return 'ND'

# %%
shark_clean['Sex'].unique()
# Out:
# array(['F', 'M', nan,
#        'http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.03.b-FlatRock.pdf',
#        'M ', 'lli',
#        'http://sharkattackfile.net/spreadsheets/pdf_directory/1998.00.00.c-Transkei.pdf',
#        'N', '.'], dtype=object)

# %%
shark_clean['Sex']=shark_clean['Sex'].fillna('ND')

# %%
shark_clean['Sex'] = shark_clean.Sex.apply(sexo)
shark_clean.Sex.unique()
# Out:
# array(['Female', 'Male', 'ND'], dtype=object)

# %% [markdown]
# # limpieza Age

# %%
shark_clean['Age']
# Out:
# 0        57
# 1        11
# 2        48
# 3       NaN
# 4       NaN
#        ...
# 6309    NaN
# 6310    NaN
# 6311    NaN
# 6312    NaN
# 6313    NaN
# Name: Age, Length: 6314, dtype: object

# %%
shark_clean['Age'] = shark_clean['Age'].fillna('15')
shark_clean['Age'] = shark_clean['Age'].loc[shark_clean['Age'].str.isnumeric()]
shark_clean['Age'] = shark_clean['Age'].str.replace('½', '')

# %%
shark_clean['Age'] = shark_clean['Age'].fillna(0)
shark_clean['Age'] = shark_clean['Age'].astype('int64')
shark_clean
# Out:
#      Case Number       Date  Year        Type    Country             Area  \
# 0     2018.06.25 2018-06-25  2018     Boating        USA       California
# 1     2018.06.18 2018-06-18  2018  Unprovoked        USA          Georgia
# 2     2018.06.09 2018-06-09  2018     Unknown        USA           Hawaii
# 3     2018.06.08 2018-06-08  2018  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04 2018-06-04  2018    Provoked     MEXICO           Colima
# ...          ...        ...   ...         ...        ...              ...
# 6309           0        NaT  1926     Unknown    Unknown          Unknown
# 6310           0        NaT  1926     Unknown    Unknown          Unknown
# 6311           0        NaT  1926     Unknown    Unknown          Unknown
# 6312  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
# 6313  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
#
#                             Location  Activity             Name     Sex  ...  \
# 0        Oceanside, San Diego County  Paddling      Julie Wolfe  Female  ...
# 1     St. Simon Island, Glynn County   Unknown  Adyson McNeely   Female  ...
# 2                       Habush, Oahu   Surfing      John Denges    Male  ...
# 3                 Arrawarra Headland   Surfing          Unknown    Male  ...
# 4                           La Ticla   Unknown   Gustavo Ramos     Male  ...
# ...                              ...       ...              ...     ...  ...
# 6309                         Unknown   Unknown          Unknown      ND  ...
# 6310                         Unknown   Unknown          Unknown      ND  ...
# 6311                         Unknown   Unknown          Unknown      ND  ...
# 6312                         Unknown   Unknown          Unknown      ND  ...
# 6313                         Unknown   Unknown          Unknown      ND  ...
#
#                Time          Investigator or Source original order  \
# 0             18h00                R. Collier, GSAF         6303.0
# 1     14h00  -15h00  K.McMurray, TrackingSharks.com         6302.0
# 2             07h45  K.McMurray, TrackingSharks.com         6301.0
# 3               NaN                  B. Myatt, GSAF         6300.0
# 4               NaN                       A .Kipper         6299.0
# ...             ...                             ...            ...
# 6309            NaN                             NaN         6309.0
# 6310            NaN                             NaN         6310.0
# 6311            NaN                             NaN            NaN
# 6312            NaN                             NaN            NaN
# 6313            NaN                             NaN            NaN
#
#      Case Number.1 Case Number.2                       pdf  \
# 0       2018.06.25    2018.06.25      2018.06.25-Wolfe.pdf
# 1       2018.06.18    2018.06.18    2018.06.18-McNeely.pdf
# 2       2018.06.09    2018.06.09     2018.06.09-Denges.pdf
# 3       2018.06.08    2018.06.08  2018.06.08-Arrawarra.pdf
# 4       2018.06.04    2018.06.04      2018.06.04-Ramos.pdf
# ...            ...           ...                       ...
# 6309           NaN           NaN                       NaN
# 6310           NaN           NaN                       NaN
# 6311           NaN           NaN                       NaN
# 6312           NaN           NaN                       NaN
# 6313           NaN           NaN                       NaN
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6309                                                NaN
# 6310                                                NaN
# 6311                                                NaN
# 6312                                                NaN
# 6313                                                NaN
#
#                                                    href Unnamed: 22  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                 ...         ...
# 6309                                                NaN         NaN
# 6310                                                NaN         NaN
# 6311                                                NaN         NaN
# 6312                                                NaN         NaN
# 6313                                                NaN         NaN
#
#      Unnamed: 23
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 6309         NaN
# 6310         NaN
# 6311         NaN
# 6312         NaN
# 6313         NaN
#
# [6314 rows x 23 columns]

# %%
shark_clean.dtypes
# Out:
# Case Number                       object
# Date                      datetime64[ns]
# Year                               int64
# Type                              object
# Country                           object
# Area                              object
# Location                          object
# Activity                          object
# Name                              object
# Sex                               object
# Age                                int64
# Fatal (Y/N)                       object
# Species                           object
# Time                              object
# Investigator or Source            object
# original order                   float64
# Case Number.1                     object
# Case Number.2                     object
# pdf                               object
# href formula                      object
# href                              object
# Unnamed: 22                       object
# Unnamed: 23                       object
# dtype: object

# %% [markdown]
# # limpieza de Fatal (Y/N)

# %%
columnas = {shark_clean.columns[11] : 'Fatal'}
shark_clean = shark_clean.rename(columns=columnas)
shark_clean['Fatal']
# Out:
# 0         N
# 1         N
# 2         N
# 3         N
# 4         N
#        ...
# 6309    NaN
# 6310    NaN
# 6311    NaN
# 6312    NaN
# 6313    NaN
# Name: Fatal, Length: 6314, dtype: object

# %%
shark_clean['Fatal'] = shark_clean['Fatal'].fillna('Unknown')
shark_clean['Fatal']
# Out:
# 0             N
# 1             N
# 2             N
# 3             N
# 4             N
#          ...
# 6309    Unknown
# 6310    Unknown
# 6311    Unknown
# 6312    Unknown
# 6313    Unknown
# Name: Fatal, Length: 6314, dtype: object

# %%
shark_clean['Fatal'].unique()
# Out:
# array(['N', 'Unknown', '2018.06.03.b', 'Y', 'M', 'UNKNOWN', '2017',
#        '1998.00.00.c', ' N', 'N ', 'y'], dtype=object)

# %%
def fatalidad(x):
    if 'N' in x:
        return 'No'
    elif 'Y' in x:
        return 'Yes'
    elif ' N' in x:
        return 'No'
    elif 'N ' in x:
        return 'No'
    elif 'y' in x:
        return 'Yes'
    else:
        return 'Unkown'

# %%
shark_clean['Fatal'] = shark_clean['Fatal'].apply(fatalidad)
shark_clean['Fatal'].unique()
# Out:
# array(['No', 'Unkown', 'Yes'], dtype=object)

# %% [markdown]
# # limpieza de Species

# %%
columna = {shark_clean.columns[12]:'species'}
columna
# Out:
# {'Species ': 'species'}

# %%
shark_clean['Species '] = shark_clean.rename(columna)
shark_clean.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex', 'Age', 'Fatal', 'Species ', 'Time',
#        'Investigator or Source', 'original order', 'Case Number.1',
#        'Case Number.2', 'pdf', 'href formula', 'href', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %% [markdown]
# # limpieza investigator or source

# %%
shark_clean['Investigator or Source']=shark_clean['Investigator or Source'].fillna('Unknown')
shark_clean

# %%
shark_clean['Investigator or Source'].value_counts()

# %% [markdown]
# # limpieza original order

# %%
shark_clean['original order'] =shark_clean['original order'].fillna(shark_clean['original order'].mean())
shark_clean

# %%
shark_clean['original order']=shark_clean['original order'].astype({'original order': 'str'})

# %%
shark_clean.dtypes

# %%
shark_clean['original order'] = shark_clean['original order'].str.replace('\.[0-9]+','',regex=True)
shark_clean

# %%
shark_clean['original order']=shark_clean['original order'].astype({'original order':'int64'})

# %%
shark_clean.dtypes

# %%
shark_clean.sample(10)

# %% [markdown]
# # limpieza case number.1

# %%
shark_clean['Case Number.1']= shark_clean['Case Number.1'].fillna('2010.01.01')
shark_clean

# %%
shark_clean['Case Number.1']=shark_clean['Case Number.1'].replace('\.[a-z]|\.[A-Z]','',regex=True)

# %%
shark_clean['Case Number.1'] = pd.to_datetime(shark_clean['Case Number.1'], errors='coerce', infer_datetime_format=True)
shark_clean.dtypes

# %%
shark_clean['Case Number.1'].value_counts()

# %% [markdown]
# # limpieza case Number.2

# %%
shark_clean['Case Number.2']=shark_clean['Case Number.2'].fillna('2010.01.01')
shark_clean

# %%
shark_clean['Case Number.2'] = shark_clean['Case Number.2'].replace('\.[a-z]|\.[A-Z]','',regex=True)
shark_clean['Case Number.2'].value_counts()

# %%
shark_clean['Case Number.2'] = pd.to_datetime(shark_clean['Case Number.2'], errors='coerce', infer_datetime_format=True)
shark_clean.dtypes

# %%
shark_clean

# %%
shark_clean.to_csv('clean.csv')

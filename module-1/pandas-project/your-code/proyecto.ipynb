# %%
import pandas as pd
import re

# %% [markdown]
# # Lectura del archivo csv

# %%
# lee el archivo con un encoding diferente a utf-8 ya que no reconoce ciertos caracteres dentro de el csv
shark = pd.read_csv('attacks.csv',encoding = "ISO-8859-1")
shark_info = pd.DataFrame(shark)

# %%
shark_info
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 25718              NaN                             NaN          NaN
# 25719              NaN                             NaN          NaN
# 25720              NaN                             NaN          NaN
# 25721              NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
#
#                   Name Sex   ...         Species   \
# 0          Julie Wolfe    F  ...      White shark
# 1      Adyson McNeely     F  ...              NaN
# 2          John Denges    M  ...              NaN
# 3                 male    M  ...        2 m shark
# 4       Gustavo Ramos     M  ...  Tiger shark, 3m
# ...                ...  ...  ...              ...
# 25718              NaN  NaN  ...              NaN
# 25719              NaN  NaN  ...              NaN
# 25720              NaN  NaN  ...              NaN
# 25721              NaN  NaN  ...              NaN
# 25722              NaN  NaN  ...              NaN
#
#                Investigator or Source                       pdf  \
# 0                    R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1      K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2      K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3                      B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4                           A .Kipper      2018.06.04-Ramos.pdf
# ...                               ...                       ...
# 25718                             NaN                       NaN
# 25719                             NaN                       NaN
# 25720                             NaN                       NaN
# 25721                             NaN                       NaN
# 25722                             NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 25718                                                NaN
# 25719                                                NaN
# 25720                                                NaN
# 25721                                                NaN
# 25722                                                NaN
#
#                                                     href Case Number.1  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                  ...           ...
# 25718                                                NaN           NaN
# 25719                                                NaN           NaN
# 25720                                                NaN           NaN
# 25721                                                NaN           NaN
# 25722                                                NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0        2018.06.25         6303.0         NaN         NaN
# 1        2018.06.18         6302.0         NaN         NaN
# 2        2018.06.09         6301.0         NaN         NaN
# 3        2018.06.08         6300.0         NaN         NaN
# 4        2018.06.04         6299.0         NaN         NaN
# ...             ...            ...         ...         ...
# 25718           NaN            NaN         NaN         NaN
# 25719           NaN            NaN         NaN         NaN
# 25720           NaN            NaN         NaN         NaN
# 25721           NaN            NaN         NaN         NaN
# 25722           NaN            NaN         NaN         NaN
#
# [25723 rows x 24 columns]

# %%
shark_info.shape
# Out:
# (25723, 24)

# %%
shark_info.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %% [markdown]
# # Drop Duplicates

# %%
# elimina todas las filas que contienen valores iguales, que para este caso es nan en todas sus columnas
duplicados = shark_info.drop_duplicates()
duplicados.sample(10)
# Out:
#        Case Number                  Date    Year        Type       Country  \
# 2900    1984.03.01           01-Mar-1984  1984.0  Unprovoked     AUSTRALIA
# 1994    2000.11.04           04-Nov-2000  2000.0  Unprovoked           USA
# 1193    2008.11.06           06-Nov-2008  2008.0  Unprovoked   PHILIPPINES
# 1388    2007.04.20           20-Apr-2007  2007.0  Unprovoked           USA
# 5055  1930.00.00.a                  1930  1930.0  Unprovoked  SOUTH AFRICA
# 2394    1995.03.21           21-Mar-1995  1995.0  Unprovoked     AUSTRALIA
# 323   2015.12.21.b           21-Dec-2015  2015.0  Unprovoked     AUSTRALIA
# 6062    1842.07.06           06-Jul-1842  1842.0    Provoked           USA
# 715     2012.12.25           25-Dec-2012  2012.0  Unprovoked  SOUTH AFRICA
# 4273    1955.12.31  Reported 31-Dec-1955  1955.0     Boating     AUSTRALIA
#
#                        Area  \
# 2900      Western Australia
# 1994             California
# 1193                  Luzon
# 1388                Florida
# 5055  Eastern Cape Province
# 2394        New South Wales
# 323         New South Wales
# 6062             New Jersey
# 715   Eastern Cape Province
# 4273               Tasmania
#
#                                                Location           Activity  \
# 2900                                          Coral Bay                NaN
# 1994  1/4 to 1/2 m north of the jetty at Bunkers, Eu...            Surfing
# 1193                   off Paoay, Ilocos Norte Province            Fishing
# 1388                   New Smyrna Beach, Volusia County            Surfing
# 5055                    North End Beach, Port Elizabeth           Swimming
# 2394                       Clark Island, Sydney Harbour        Surf skiing
# 323                                         Bondi Beach            Surfing
# 6062                           Absecon, Atlantic County  Harassing a shark
# 715                                     Port St. John's           Swimming
# 4273                                                NaN       Ocean racing
#
#                Name Sex   ...                                Species   \
# 2900      Greenwood  NaN  ...                                     NaN
# 1994  Casey Stewman    M  ...  White shark, 2.4 m to 3 m [8' to 10']
# 1193     Joel Bacud    M  ...                                     NaN
# 1388   Chad Guthrie    M  ...                          3' to 4' shark
# 5055      Mr. Meyer    M  ...                                     NaN
# 2394   Mary Meagher    F  ...                                     NaN
# 323    Dean Norburn    M  ...                 Bronze whaler shark, 6'
# 6062           male  NaN  ...                                     NaN
# 715     Liya Sibili    M  ...                             Tiger shark
# 4273     yacht Even  NaN  ...                                     NaN
#
#                              Investigator or Source  \
# 2900                                 T. Peake, GSAF
# 1994  J. Ramsay, California Fish & Game; R. Collier
# 1193                           Sun Star, 11/08/2008
# 1388                       Florida Today, 4/21/2007
# 5055                                      H. Monsen
# 2394                       Deseret News, 3/24/1995
# 323                      The Telegraph, 12/22/;2015
# 6062               New York Evening Post, 7/11/1842
# 715                                SAPA, 12/27/2012
# 4273                                 C. Black, GSAF
#
#                               pdf  \
# 2900  1984.03.01-NV-Greenwood.pdf
# 1994       2000.11.04-Stewman.pdf
# 1193         2008.11.06-Bacud.pdf
# 1388   2007.04.20-ChadGuthrie.pdf
# 5055       1930.00.00.a-Meyer.pdf
# 2394       1995.03.21-Meagher.pdf
# 323      2015.12.21.b-Norburn.pdf
# 6062       1842.07.06-Absecon.pdf
# 715         2012.12.25-Sibili.pdf
# 4273        1955.12.31.R-Even.pdf
#
#                                            href formula  \
# 2900  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1994  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1193  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1388  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5055  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2394  http://sharkattackfile.net/spreadsheets/pdf_di...
# 323   http://sharkattackfile.net/spreadsheets/pdf_di...
# 6062  http://sharkattackfile.net/spreadsheets/pdf_di...
# 715   http://sharkattackfile.net/spreadsheets/pdf_di...
# 4273  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 2900  http://sharkattackfile.net/spreadsheets/pdf_di...    1984.03.01
# 1994  http://sharkattackfile.net/spreadsheets/pdf_di...    2000.11.04
# 1193  http://sharkattackfile.net/spreadsheets/pdf_di...    2008.11.06
# 1388  http://sharkattackfile.net/spreadsheets/pdf_di...    2007.04.20
# 5055  http://sharkattackfile.net/spreadsheets/pdf_di...  1930.00.00.a
# 2394  http://sharkattackfile.net/spreadsheets/pdf_di...    1995.03.21
# 323   http://sharkattackfile.net/spreadsheets/pdf_di...  2015.12.21.b
# 6062  http://sharkattackfile.net/spreadsheets/pdf_di...    1842.07.06
# 715   http://sharkattackfile.net/spreadsheets/pdf_di...    2012.12.25
# 4273  http://sharkattackfile.net/spreadsheets/pdf_di...    1955.12.31
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23
# 2900    1984.03.01         3403.0         NaN         NaN
# 1994    2000.11.04         4309.0         NaN         NaN
# 1193    2008.11.06         5110.0         NaN         NaN
# 1388    2007.04.20         4915.0         NaN         NaN
# 5055  1930.00.00.a         1248.0         NaN         NaN
# 2394    1995.03.21         3909.0         NaN         NaN
# 323   2015.12.21.b         5980.0         NaN         NaN
# 6062    1842.07.06          241.0         NaN         NaN
# 715     2012.12.25         5588.0         NaN         NaN
# 4273    1955.12.31         2030.0         NaN         NaN
#
# [10 rows x 24 columns]

# %% [markdown]
# # comparacion original vs drop duplicates

# %%
print('tamaño de las filas en el archivo originial',shark_info.shape)
print('tamaño de las filas en el archivo que elimina valores duplicados',duplicados.shape)
# Out:
# tamaño de las filas en el archivo originial (25723, 24)
# tamaño de las filas en el archivo que elimina valores duplicados (6312, 24)

# %%
# reorganizacion de las columnas de la mas importante a menos importante 
cols = ['Case Number', 'Date', 'Year','Type','Country', 'Area','Location',
       'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)','Species ', 'Time','Investigator or Source',
       'original order','Case Number.1', 'Case Number.2','pdf', 'href formula', 'href','Unnamed: 22','Unnamed: 23']
shark_clean = pd.DataFrame(duplicados, columns=cols)
shark_clean = shark_clean
shark_clean
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 6307            0          NaN     NaN         NaN        NaN
# 6308            0          NaN     NaN         NaN        NaN
# 6309            0          NaN     NaN         NaN        NaN
# 8702          NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 6307               NaN                             NaN          NaN
# 6308               NaN                             NaN          NaN
# 6309               NaN                             NaN          NaN
# 8702               NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
#
#                   Name Sex   ...           Time  \
# 0          Julie Wolfe    F  ...          18h00
# 1      Adyson McNeely     F  ...  14h00  -15h00
# 2          John Denges    M  ...          07h45
# 3                 male    M  ...            NaN
# 4       Gustavo Ramos     M  ...            NaN
# ...                ...  ...  ...            ...
# 6307               NaN  NaN  ...            NaN
# 6308               NaN  NaN  ...            NaN
# 6309               NaN  NaN  ...            NaN
# 8702               NaN  NaN  ...            NaN
# 25722              NaN  NaN  ...            NaN
#
#                Investigator or Source original order Case Number.1  \
# 0                    R. Collier, GSAF         6303.0    2018.06.25
# 1      K.McMurray, TrackingSharks.com         6302.0    2018.06.18
# 2      K.McMurray, TrackingSharks.com         6301.0    2018.06.09
# 3                      B. Myatt, GSAF         6300.0    2018.06.08
# 4                           A .Kipper         6299.0    2018.06.04
# ...                               ...            ...           ...
# 6307                              NaN         6309.0           NaN
# 6308                              NaN         6310.0           NaN
# 6309                              NaN            NaN           NaN
# 8702                              NaN            NaN           NaN
# 25722                             NaN            NaN           NaN
#
#       Case Number.2                       pdf  \
# 0        2018.06.25      2018.06.25-Wolfe.pdf
# 1        2018.06.18    2018.06.18-McNeely.pdf
# 2        2018.06.09     2018.06.09-Denges.pdf
# 3        2018.06.08  2018.06.08-Arrawarra.pdf
# 4        2018.06.04      2018.06.04-Ramos.pdf
# ...             ...                       ...
# 6307            NaN                       NaN
# 6308            NaN                       NaN
# 6309            NaN                       NaN
# 8702            NaN                       NaN
# 25722           NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 6307                                                 NaN
# 6308                                                 NaN
# 6309                                                 NaN
# 8702                                                 NaN
# 25722                                                NaN
#
#                                                     href Unnamed: 22  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                  ...         ...
# 6307                                                 NaN         NaN
# 6308                                                 NaN         NaN
# 6309                                                 NaN         NaN
# 8702                                                 NaN         NaN
# 25722                                                NaN         NaN
#
#       Unnamed: 23
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 6307          NaN
# 6308          NaN
# 6309          NaN
# 8702          NaN
# 25722         NaN
#
# [6312 rows x 24 columns]

# %% [markdown]
# # primera columna 'Case Number'

# %%
# limpiando primera columna de tabla
shark_clean['Case Number'] = shark_clean['Case Number'].str.replace('\.[a-z]+|\.[A-Z]+','', regex=True).fillna('2010.01.01')
shark_clean
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 6307            0          NaN     NaN         NaN        NaN
# 6308            0          NaN     NaN         NaN        NaN
# 6309            0          NaN     NaN         NaN        NaN
# 8702   2010.01.01          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 6307               NaN                             NaN          NaN
# 6308               NaN                             NaN          NaN
# 6309               NaN                             NaN          NaN
# 8702               NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
#
#                   Name Sex   ...           Time  \
# 0          Julie Wolfe    F  ...          18h00
# 1      Adyson McNeely     F  ...  14h00  -15h00
# 2          John Denges    M  ...          07h45
# 3                 male    M  ...            NaN
# 4       Gustavo Ramos     M  ...            NaN
# ...                ...  ...  ...            ...
# 6307               NaN  NaN  ...            NaN
# 6308               NaN  NaN  ...            NaN
# 6309               NaN  NaN  ...            NaN
# 8702               NaN  NaN  ...            NaN
# 25722              NaN  NaN  ...            NaN
#
#                Investigator or Source original order Case Number.1  \
# 0                    R. Collier, GSAF         6303.0    2018.06.25
# 1      K.McMurray, TrackingSharks.com         6302.0    2018.06.18
# 2      K.McMurray, TrackingSharks.com         6301.0    2018.06.09
# 3                      B. Myatt, GSAF         6300.0    2018.06.08
# 4                           A .Kipper         6299.0    2018.06.04
# ...                               ...            ...           ...
# 6307                              NaN         6309.0           NaN
# 6308                              NaN         6310.0           NaN
# 6309                              NaN            NaN           NaN
# 8702                              NaN            NaN           NaN
# 25722                             NaN            NaN           NaN
#
#       Case Number.2                       pdf  \
# 0        2018.06.25      2018.06.25-Wolfe.pdf
# 1        2018.06.18    2018.06.18-McNeely.pdf
# 2        2018.06.09     2018.06.09-Denges.pdf
# 3        2018.06.08  2018.06.08-Arrawarra.pdf
# 4        2018.06.04      2018.06.04-Ramos.pdf
# ...             ...                       ...
# 6307            NaN                       NaN
# 6308            NaN                       NaN
# 6309            NaN                       NaN
# 8702            NaN                       NaN
# 25722           NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 6307                                                 NaN
# 6308                                                 NaN
# 6309                                                 NaN
# 8702                                                 NaN
# 25722                                                NaN
#
#                                                     href Unnamed: 22  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                  ...         ...
# 6307                                                 NaN         NaN
# 6308                                                 NaN         NaN
# 6309                                                 NaN         NaN
# 8702                                                 NaN         NaN
# 25722                                                NaN         NaN
#
#       Unnamed: 23
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 6307          NaN
# 6308          NaN
# 6309          NaN
# 8702          NaN
# 25722         NaN
#
# [6312 rows x 24 columns]

# %% [markdown]
# # limpieza de las fechas date

# %%
shark_clean['Date'] = shark_clean['Date'].str.replace('Reported| Early| Late|\.[a-z]|\.[A-Z]|Between May &' ,'').fillna('01-01-2000')
shark_clean.head(10)
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
# 5  2018.06.03  03-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 6  2018.06.03  03-Jun-2018  2018.0  Unprovoked     BRAZIL       Pernambuco
# 7  2018.05.27  27-May-2018  2018.0  Unprovoked        USA          Florida
# 8  2018.05.26  26-May-2018  2018.0  Unprovoked        USA          Florida
# 9  2018.05.26  26-May-2018  2018.0  Unprovoked        USA          Florida
#
#                                             Location      Activity  \
# 0                        Oceanside, San Diego County      Paddling
# 1                     St. Simon Island, Glynn County      Standing
# 2                                       Habush, Oahu       Surfing
# 3                                 Arrawarra Headland       Surfing
# 4                                           La Ticla   Free diving
# 5                                 Flat Rock, Ballina  Kite surfing
# 6                              Piedade Beach, Recife      Swimming
# 7  Lighhouse Point Park, Ponce Inlet, Volusia County       Fishing
# 8                       Cocoa Beach, Brevard  County       Walking
# 9                      Daytona Beach, Volusia County      Standing
#
#                      Name Sex   ...            Time  \
# 0             Julie Wolfe    F  ...           18h00
# 1         Adyson McNeely     F  ...   14h00  -15h00
# 2             John Denges    M  ...           07h45
# 3                    male    M  ...             NaN
# 4          Gustavo Ramos     M  ...             NaN
# 5                 Chris
#     M  ...             NaN
# 6  Jose Ernesto da Silva     M  ...  Late afternoon
# 7                    male    M  ...             NaN
# 8               Cody High    M  ...           17h00
# 9                    male    M  ...           14h00
#
#              Investigator or Source original order Case Number.1  \
# 0                  R. Collier, GSAF         6303.0    2018.06.25
# 1    K.McMurray, TrackingSharks.com         6302.0    2018.06.18
# 2    K.McMurray, TrackingSharks.com         6301.0    2018.06.09
# 3                    B. Myatt, GSAF         6300.0    2018.06.08
# 4                         A .Kipper         6299.0    2018.06.04
# 5         Daily Telegraph, 6/4/2018         6298.0  2018.06.03.b
# 6    Diario de Pernambuco, 6/4/2018         6297.0  2018.06.03.a
# 7   K. McMurray, TrackingSharks.com         6296.0    2018.05.27
# 8    K.McMurray, TrackingSharks.com         6295.0  2018.05.26.b
# 9  K. McMurray, Tracking Sharks.com         6294.0  2018.05.26.a
#
#   Case Number.2                            pdf  \
# 0    2018.06.25           2018.06.25-Wolfe.pdf
# 1    2018.06.18         2018.06.18-McNeely.pdf
# 2    2018.06.09          2018.06.09-Denges.pdf
# 3    2018.06.08       2018.06.08-Arrawarra.pdf
# 4    2018.06.04           2018.06.04-Ramos.pdf
# 5  2018.06.03.b      2018.06.03.b-FlatRock.pdf
# 6  2018.06.03.a       2018.06.03.a-daSilva.pdf
# 7    2018.05.27           2018.05.27-Ponce.pdf
# 8  2018.05.26.b          2018.05.26.b-High.pdf
# 9  2018.05.26.a  2018.05.26.a-DaytonaBeach.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Unnamed: 22 Unnamed: 23
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 5  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 6  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
#
# [10 rows x 24 columns]

# %% [markdown]
# # limpieza de year

# %%
'''
convierte los valores de años a str
'''
shark_clean['Year']=shark_clean['Year'].fillna(0.0)
shark_clean
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 6307            0   01-01-2000     0.0         NaN        NaN
# 6308            0   01-01-2000     0.0         NaN        NaN
# 6309            0   01-01-2000     0.0         NaN        NaN
# 8702   2010.01.01   01-01-2000     0.0         NaN        NaN
# 25722          xx   01-01-2000     0.0         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 6307               NaN                             NaN          NaN
# 6308               NaN                             NaN          NaN
# 6309               NaN                             NaN          NaN
# 8702               NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
#
#                   Name Sex   ...           Time  \
# 0          Julie Wolfe    F  ...          18h00
# 1      Adyson McNeely     F  ...  14h00  -15h00
# 2          John Denges    M  ...          07h45
# 3                 male    M  ...            NaN
# 4       Gustavo Ramos     M  ...            NaN
# ...                ...  ...  ...            ...
# 6307               NaN  NaN  ...            NaN
# 6308               NaN  NaN  ...            NaN
# 6309               NaN  NaN  ...            NaN
# 8702               NaN  NaN  ...            NaN
# 25722              NaN  NaN  ...            NaN
#
#                Investigator or Source original order Case Number.1  \
# 0                    R. Collier, GSAF         6303.0    2018.06.25
# 1      K.McMurray, TrackingSharks.com         6302.0    2018.06.18
# 2      K.McMurray, TrackingSharks.com         6301.0    2018.06.09
# 3                      B. Myatt, GSAF         6300.0    2018.06.08
# 4                           A .Kipper         6299.0    2018.06.04
# ...                               ...            ...           ...
# 6307                              NaN         6309.0           NaN
# 6308                              NaN         6310.0           NaN
# 6309                              NaN            NaN           NaN
# 8702                              NaN            NaN           NaN
# 25722                             NaN            NaN           NaN
#
#       Case Number.2                       pdf  \
# 0        2018.06.25      2018.06.25-Wolfe.pdf
# 1        2018.06.18    2018.06.18-McNeely.pdf
# 2        2018.06.09     2018.06.09-Denges.pdf
# 3        2018.06.08  2018.06.08-Arrawarra.pdf
# 4        2018.06.04      2018.06.04-Ramos.pdf
# ...             ...                       ...
# 6307            NaN                       NaN
# 6308            NaN                       NaN
# 6309            NaN                       NaN
# 8702            NaN                       NaN
# 25722           NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 6307                                                 NaN
# 6308                                                 NaN
# 6309                                                 NaN
# 8702                                                 NaN
# 25722                                                NaN
#
#                                                     href Unnamed: 22  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                  ...         ...
# 6307                                                 NaN         NaN
# 6308                                                 NaN         NaN
# 6309                                                 NaN         NaN
# 8702                                                 NaN         NaN
# 25722                                                NaN         NaN
#
#       Unnamed: 23
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 6307          NaN
# 6308          NaN
# 6309          NaN
# 8702          NaN
# 25722         NaN
#
# [6312 rows x 24 columns]

# %%
shark_clean['Year']= shark_clean['Year'].astype({'Year':'str'})
shark_clean
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 6307            0   01-01-2000     0.0         NaN        NaN
# 6308            0   01-01-2000     0.0         NaN        NaN
# 6309            0   01-01-2000     0.0         NaN        NaN
# 8702   2010.01.01   01-01-2000     0.0         NaN        NaN
# 25722          xx   01-01-2000     0.0         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 6307               NaN                             NaN          NaN
# 6308               NaN                             NaN          NaN
# 6309               NaN                             NaN          NaN
# 8702               NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
#
#                   Name Sex   ...           Time  \
# 0          Julie Wolfe    F  ...          18h00
# 1      Adyson McNeely     F  ...  14h00  -15h00
# 2          John Denges    M  ...          07h45
# 3                 male    M  ...            NaN
# 4       Gustavo Ramos     M  ...            NaN
# ...                ...  ...  ...            ...
# 6307               NaN  NaN  ...            NaN
# 6308               NaN  NaN  ...            NaN
# 6309               NaN  NaN  ...            NaN
# 8702               NaN  NaN  ...            NaN
# 25722              NaN  NaN  ...            NaN
#
#                Investigator or Source original order Case Number.1  \
# 0                    R. Collier, GSAF         6303.0    2018.06.25
# 1      K.McMurray, TrackingSharks.com         6302.0    2018.06.18
# 2      K.McMurray, TrackingSharks.com         6301.0    2018.06.09
# 3                      B. Myatt, GSAF         6300.0    2018.06.08
# 4                           A .Kipper         6299.0    2018.06.04
# ...                               ...            ...           ...
# 6307                              NaN         6309.0           NaN
# 6308                              NaN         6310.0           NaN
# 6309                              NaN            NaN           NaN
# 8702                              NaN            NaN           NaN
# 25722                             NaN            NaN           NaN
#
#       Case Number.2                       pdf  \
# 0        2018.06.25      2018.06.25-Wolfe.pdf
# 1        2018.06.18    2018.06.18-McNeely.pdf
# 2        2018.06.09     2018.06.09-Denges.pdf
# 3        2018.06.08  2018.06.08-Arrawarra.pdf
# 4        2018.06.04      2018.06.04-Ramos.pdf
# ...             ...                       ...
# 6307            NaN                       NaN
# 6308            NaN                       NaN
# 6309            NaN                       NaN
# 8702            NaN                       NaN
# 25722           NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 6307                                                 NaN
# 6308                                                 NaN
# 6309                                                 NaN
# 8702                                                 NaN
# 25722                                                NaN
#
#                                                     href Unnamed: 22  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                  ...         ...
# 6307                                                 NaN         NaN
# 6308                                                 NaN         NaN
# 6309                                                 NaN         NaN
# 8702                                                 NaN         NaN
# 25722                                                NaN         NaN
#
#       Unnamed: 23
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 6307          NaN
# 6308          NaN
# 6309          NaN
# 8702          NaN
# 25722         NaN
#
# [6312 rows x 24 columns]

# %%
shark_clean['Year'] = shark_clean['Year'].str.replace('\.[0-9]+','',regex=True)
shark_clean
# Out:
#       Case Number         Date  Year        Type    Country             Area  \
# 0      2018.06.25  25-Jun-2018  2018     Boating        USA       California
# 1      2018.06.18  18-Jun-2018  2018  Unprovoked        USA          Georgia
# 2      2018.06.09  09-Jun-2018  2018     Invalid        USA           Hawaii
# 3      2018.06.08  08-Jun-2018  2018  Unprovoked  AUSTRALIA  New South Wales
# 4      2018.06.04  04-Jun-2018  2018    Provoked     MEXICO           Colima
# ...           ...          ...   ...         ...        ...              ...
# 6307            0   01-01-2000     0         NaN        NaN              NaN
# 6308            0   01-01-2000     0         NaN        NaN              NaN
# 6309            0   01-01-2000     0         NaN        NaN              NaN
# 8702   2010.01.01   01-01-2000     0         NaN        NaN              NaN
# 25722          xx   01-01-2000     0         NaN        NaN              NaN
#
#                              Location     Activity             Name Sex   ...  \
# 0         Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1      St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                        Habush, Oahu      Surfing      John Denges    M  ...
# 3                  Arrawarra Headland      Surfing             male    M  ...
# 4                            La Ticla  Free diving   Gustavo Ramos     M  ...
# ...                               ...          ...              ...  ...  ...
# 6307                              NaN          NaN              NaN  NaN  ...
# 6308                              NaN          NaN              NaN  NaN  ...
# 6309                              NaN          NaN              NaN  NaN  ...
# 8702                              NaN          NaN              NaN  NaN  ...
# 25722                             NaN          NaN              NaN  NaN  ...
#
#                 Time          Investigator or Source original order  \
# 0              18h00                R. Collier, GSAF         6303.0
# 1      14h00  -15h00  K.McMurray, TrackingSharks.com         6302.0
# 2              07h45  K.McMurray, TrackingSharks.com         6301.0
# 3                NaN                  B. Myatt, GSAF         6300.0
# 4                NaN                       A .Kipper         6299.0
# ...              ...                             ...            ...
# 6307             NaN                             NaN         6309.0
# 6308             NaN                             NaN         6310.0
# 6309             NaN                             NaN            NaN
# 8702             NaN                             NaN            NaN
# 25722            NaN                             NaN            NaN
#
#       Case Number.1 Case Number.2                       pdf  \
# 0        2018.06.25    2018.06.25      2018.06.25-Wolfe.pdf
# 1        2018.06.18    2018.06.18    2018.06.18-McNeely.pdf
# 2        2018.06.09    2018.06.09     2018.06.09-Denges.pdf
# 3        2018.06.08    2018.06.08  2018.06.08-Arrawarra.pdf
# 4        2018.06.04    2018.06.04      2018.06.04-Ramos.pdf
# ...             ...           ...                       ...
# 6307            NaN           NaN                       NaN
# 6308            NaN           NaN                       NaN
# 6309            NaN           NaN                       NaN
# 8702            NaN           NaN                       NaN
# 25722           NaN           NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 6307                                                 NaN
# 6308                                                 NaN
# 6309                                                 NaN
# 8702                                                 NaN
# 25722                                                NaN
#
#                                                     href Unnamed: 22  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                  ...         ...
# 6307                                                 NaN         NaN
# 6308                                                 NaN         NaN
# 6309                                                 NaN         NaN
# 8702                                                 NaN         NaN
# 25722                                                NaN         NaN
#
#       Unnamed: 23
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 6307          NaN
# 6308          NaN
# 6309          NaN
# 8702          NaN
# 25722         NaN
#
# [6312 rows x 24 columns]

# %%
shark_clean['Year'] = shark_clean['Year'].replace('0','2000')
shark_clean
# Out:
#       Case Number         Date  Year        Type    Country             Area  \
# 0      2018.06.25  25-Jun-2018  2018     Boating        USA       California
# 1      2018.06.18  18-Jun-2018  2018  Unprovoked        USA          Georgia
# 2      2018.06.09  09-Jun-2018  2018     Invalid        USA           Hawaii
# 3      2018.06.08  08-Jun-2018  2018  Unprovoked  AUSTRALIA  New South Wales
# 4      2018.06.04  04-Jun-2018  2018    Provoked     MEXICO           Colima
# ...           ...          ...   ...         ...        ...              ...
# 6307            0   01-01-2000  2000         NaN        NaN              NaN
# 6308            0   01-01-2000  2000         NaN        NaN              NaN
# 6309            0   01-01-2000  2000         NaN        NaN              NaN
# 8702   2010.01.01   01-01-2000  2000         NaN        NaN              NaN
# 25722          xx   01-01-2000  2000         NaN        NaN              NaN
#
#                              Location     Activity             Name Sex   ...  \
# 0         Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1      St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                        Habush, Oahu      Surfing      John Denges    M  ...
# 3                  Arrawarra Headland      Surfing             male    M  ...
# 4                            La Ticla  Free diving   Gustavo Ramos     M  ...
# ...                               ...          ...              ...  ...  ...
# 6307                              NaN          NaN              NaN  NaN  ...
# 6308                              NaN          NaN              NaN  NaN  ...
# 6309                              NaN          NaN              NaN  NaN  ...
# 8702                              NaN          NaN              NaN  NaN  ...
# 25722                             NaN          NaN              NaN  NaN  ...
#
#                 Time          Investigator or Source original order  \
# 0              18h00                R. Collier, GSAF         6303.0
# 1      14h00  -15h00  K.McMurray, TrackingSharks.com         6302.0
# 2              07h45  K.McMurray, TrackingSharks.com         6301.0
# 3                NaN                  B. Myatt, GSAF         6300.0
# 4                NaN                       A .Kipper         6299.0
# ...              ...                             ...            ...
# 6307             NaN                             NaN         6309.0
# 6308             NaN                             NaN         6310.0
# 6309             NaN                             NaN            NaN
# 8702             NaN                             NaN            NaN
# 25722            NaN                             NaN            NaN
#
#       Case Number.1 Case Number.2                       pdf  \
# 0        2018.06.25    2018.06.25      2018.06.25-Wolfe.pdf
# 1        2018.06.18    2018.06.18    2018.06.18-McNeely.pdf
# 2        2018.06.09    2018.06.09     2018.06.09-Denges.pdf
# 3        2018.06.08    2018.06.08  2018.06.08-Arrawarra.pdf
# 4        2018.06.04    2018.06.04      2018.06.04-Ramos.pdf
# ...             ...           ...                       ...
# 6307            NaN           NaN                       NaN
# 6308            NaN           NaN                       NaN
# 6309            NaN           NaN                       NaN
# 8702            NaN           NaN                       NaN
# 25722           NaN           NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 6307                                                 NaN
# 6308                                                 NaN
# 6309                                                 NaN
# 8702                                                 NaN
# 25722                                                NaN
#
#                                                     href Unnamed: 22  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                  ...         ...
# 6307                                                 NaN         NaN
# 6308                                                 NaN         NaN
# 6309                                                 NaN         NaN
# 8702                                                 NaN         NaN
# 25722                                                NaN         NaN
#
#       Unnamed: 23
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 6307          NaN
# 6308          NaN
# 6309          NaN
# 8702          NaN
# 25722         NaN
#
# [6312 rows x 24 columns]

# %%
shark_clean['Year'] = shark_clean['Year'].apply(pd.to_numeric)
shark_clean
# Out:
#       Case Number         Date  Year        Type    Country             Area  \
# 0      2018.06.25  25-Jun-2018  2018     Boating        USA       California
# 1      2018.06.18  18-Jun-2018  2018  Unprovoked        USA          Georgia
# 2      2018.06.09  09-Jun-2018  2018     Invalid        USA           Hawaii
# 3      2018.06.08  08-Jun-2018  2018  Unprovoked  AUSTRALIA  New South Wales
# 4      2018.06.04  04-Jun-2018  2018    Provoked     MEXICO           Colima
# ...           ...          ...   ...         ...        ...              ...
# 6307            0   01-01-2000  2000         NaN        NaN              NaN
# 6308            0   01-01-2000  2000         NaN        NaN              NaN
# 6309            0   01-01-2000  2000         NaN        NaN              NaN
# 8702   2010.01.01   01-01-2000  2000         NaN        NaN              NaN
# 25722          xx   01-01-2000  2000         NaN        NaN              NaN
#
#                              Location     Activity             Name Sex   ...  \
# 0         Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1      St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                        Habush, Oahu      Surfing      John Denges    M  ...
# 3                  Arrawarra Headland      Surfing             male    M  ...
# 4                            La Ticla  Free diving   Gustavo Ramos     M  ...
# ...                               ...          ...              ...  ...  ...
# 6307                              NaN          NaN              NaN  NaN  ...
# 6308                              NaN          NaN              NaN  NaN  ...
# 6309                              NaN          NaN              NaN  NaN  ...
# 8702                              NaN          NaN              NaN  NaN  ...
# 25722                             NaN          NaN              NaN  NaN  ...
#
#                 Time          Investigator or Source original order  \
# 0              18h00                R. Collier, GSAF         6303.0
# 1      14h00  -15h00  K.McMurray, TrackingSharks.com         6302.0
# 2              07h45  K.McMurray, TrackingSharks.com         6301.0
# 3                NaN                  B. Myatt, GSAF         6300.0
# 4                NaN                       A .Kipper         6299.0
# ...              ...                             ...            ...
# 6307             NaN                             NaN         6309.0
# 6308             NaN                             NaN         6310.0
# 6309             NaN                             NaN            NaN
# 8702             NaN                             NaN            NaN
# 25722            NaN                             NaN            NaN
#
#       Case Number.1 Case Number.2                       pdf  \
# 0        2018.06.25    2018.06.25      2018.06.25-Wolfe.pdf
# 1        2018.06.18    2018.06.18    2018.06.18-McNeely.pdf
# 2        2018.06.09    2018.06.09     2018.06.09-Denges.pdf
# 3        2018.06.08    2018.06.08  2018.06.08-Arrawarra.pdf
# 4        2018.06.04    2018.06.04      2018.06.04-Ramos.pdf
# ...             ...           ...                       ...
# 6307            NaN           NaN                       NaN
# 6308            NaN           NaN                       NaN
# 6309            NaN           NaN                       NaN
# 8702            NaN           NaN                       NaN
# 25722           NaN           NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 6307                                                 NaN
# 6308                                                 NaN
# 6309                                                 NaN
# 8702                                                 NaN
# 25722                                                NaN
#
#                                                     href Unnamed: 22  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                  ...         ...
# 6307                                                 NaN         NaN
# 6308                                                 NaN         NaN
# 6309                                                 NaN         NaN
# 8702                                                 NaN         NaN
# 25722                                                NaN         NaN
#
#       Unnamed: 23
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 6307          NaN
# 6308          NaN
# 6309          NaN
# 8702          NaN
# 25722         NaN
#
# [6312 rows x 24 columns]

# %%
#shark_clean['Year'] = shark_clean['Year'].astype({'Year':'int'})
shark_clean.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                        int64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Species                    object
# Time                       object
# Investigator or Source     object
# original order            float64
# Case Number.1              object
# Case Number.2              object
# pdf                        object
# href formula               object
# href                       object
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %%
shark_clean.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                        int64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Species                    object
# Time                       object
# Investigator or Source     object
# original order            float64
# Case Number.1              object
# Case Number.2              object
# pdf                        object
# href formula               object
# href                       object
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %% [markdown]
# # limpieza de type

# %%
shark_clean['Type']= shark_clean['Type'].str.replace('Invalid|0','Unknown',regex=True).fillna('Unknown')
shark_clean.sample(60)
# Out:
#      Case Number           Date  Year          Type               Country  \
# 856   2011.10.05    05-Oct-2011  2011       Boating               REUNION
# 4354  1954.00.00           1954  1954    Unprovoked                   USA
# 804   2012.03.24    24-Mar-2012  2012    Unprovoked                   USA
# 1499  2006.02.23    23-Feb-2006  2006       Unknown                   USA
# 2063  2000.03.24    24-Mar-2000  2000    Unprovoked                   USA
# 6186     ND-0149    Before 1934  2000    Unprovoked               URUGUAY
# 178   2017.02.06    06-Feb-2017  2017       Boating          SOUTH AFRICA
# 1031  2010.04.28    28-Apr-2010  2010      Provoked                   USA
# 925   2011.05.10    10-May-2011  2011      Provoked                   USA
# 5669  1893.04.15    15-Apr-1893  1893    Unprovoked  SOUTH ATLANTIC OCEAN
# 3763  1963.02.04    04-Feb-1963  1963       Unknown                   USA
# 861   2011.09.28    28-Sep-2011  2011    Unprovoked          SOUTH AFRICA
# 1459  2006.07.12    12-Jul-2006  2006    Unprovoked                   USA
# 1374  2007.05.26    26-May-2007  2007    Unprovoked                   USA
# 2819  1986.05.15    15-May-1986  1986    Unprovoked           SOUTH KOREA
# 4269  1956.00.00           1956  1956    Unprovoked                   USA
# 512   2014.08.25    25-Aug-2014  2014      Provoked                   USA
# 5000  1932.00.00           1932  1932    Unprovoked          SOUTH AFRICA
# 4701  1942.10.12    12-Oct-1942  1942  Sea Disaster       SOLOMON ISLANDS
# 2195  1998.04.01    01-Apr-1998  1998    Unprovoked                BRAZIL
# 3868  1961.12.18    18-Dec-1961  1961    Unprovoked             AUSTRALIA
# 5325  1915.03.29    29-Mar-1915  1915    Unprovoked             AUSTRALIA
# 1999  2000.10.09    09-Oct-2000  2000    Unprovoked                   USA
# 1614  2005.01.20    20-Jan-2005  2005    Unprovoked                  CUBA
# 3346  1972.00.00           1972  1972    Unprovoked      MARSHALL ISLANDS
# 4627  1945.00.00           1945  1945    Unprovoked               JAMAICA
# 5828  1880.00.00           1880  1880    Unprovoked           NEW ZEALAND
# 1031                                   Measuring sharks
# 925                                            Fishing
# 5669  Swimming after falling overboard from the seal...
# 3763  S.S. Marine Sulphur Queen, laden with molten s...
# 861                                            Swimming
# 1459                                           Swimming
# 1374                                             Wading
# 2819                                       Shell diving
# 4269                                           Swimming
# 512                                  Fishing for sharks
# 5000              Collecting fish by lamplight in gully
# 4701  His ship, the US destroyer Duncan DD 485, had ...
# 2195                                          Swimming
# 3868                      Surfing, pushing board ashore
# 5325  Skin diving for trepang but at surface next to...
# 1999                                            Surfing
# 1614                                           Swimming
# 3346                     Free diving, collecting shells
# 4627                                             Diving
# 5828                                                NaN
# 2171                                       Spearfishing
# 4263                                           Swimming
# 2689                              Paddling on surfboard
# 4911                                             Diving
# 1206                                            Surfing
# 412                                              Wading
# 2808                                                NaN
# 5827                                                NaN
# 4899                Diving for beche-de-mer from lugger
# 1783                                            Surfing
# 359                                              Wading
# 2792                                               Boat
# 1366                                             Murder
# 1571                    Holding onto an inflatable boat
# 3262                Free diving for abalone (submerged)
# 798                                             Surfing
# 3157                                                NaN
# 1281                                            Surfing
# 2059                           Boogie boarding / wading
# 4134                                       Spearfishing
# 2469                                            Surfing
# 4618                                           Swimming
# 1392                                            Surfing
# 6174                                                NaN
# 5706  Fishing boat with 4 men on board was rammed & ...
# 2884                                         Skindiving
# 4189                                                NaN
# 67                              Stand-Up Paddleboarding
# 1791                                            Surfing
# 2896                                       Spearfishing
# 2498                                           Swimming
# 5303                                           Swimming
# 4925                                          Splashing
#
#                                             Name Sex   ...            Time  \
# 856                      Jean-Pierre Castellani     M  ...           10h30
# 4354                                    Severino    M  ...             NaN
# 804                                 Joey Coppola    M  ...           14h00
# 1499                               Anthony Moore    M  ...  Late afternoon
# 2063                              Barry Pasonski    M  ...           14h00
# 6186                                    Maciello    M  ...             NaN
# 178                               Murray Van Wyk    M  ...             NaN
# 1031                               Kirk Gastrich    M  ...       Afternoon
# 925                                 Brian Storch    M  ...             NaN
# 5669                             Charles Barclay    M  ...             NaN
# 3763                                     2 males    M  ...             NaN
# 861                                Michael Cohen    M  ...           12h25
# 1459                                      female    F  ...           13h30
# 1374                             Susan Dornquast    F  ...           17h00
# 2819                                        male    M  ...             NaN
# 4269                                        girl    F  ...             NaN
# 512                                   John Wiley    M  ...             NaN
# 5000                             Manning Samuels    M  ...      After dusk
# 4701  Lieutenant Commander Herbert Richard Kabat    M  ...             NaN
# 2195                                Unidentified    M  ...             NaN
# 3868                        John Grayson Andrews    M  ...           06h15
# 5325                                        Hana    M  ...             NaN
# 1999                            Matt Kraskiewicz    M  ...         Morning
# 1614                             Hurdenis Jérez     M  ...             NaN
# 3346                              Alan Titchenal    M  ...             NaN
# 4627                              Albert Stewart    M  ...             NaN
# 5828                                        male    M  ...             NaN
# 2171                              Kevin Paffrath    M  ...           16h30
# 4263                              Lester  Burton    M  ...             NaN
# 2689                            William P. Allen    M  ...             NaN
# 4911                           Pearl Purdy Scott    F  ...             NaN
# 1206                                 John Morgan    M  ...           12h00
# 412                              Hunter Treschel    M  ...           17h51
# 2808                                         NaN  NaN  ...             NaN
# 5827                                         boy    M  ...             NaN
# 4899                            Barani, a Papuan    M  ...             NaN
# 1783                                        male    M  ...           13h30
# 359                           Joshua Bitner, Jr.    M  ...           12h30
# 2792          Aniello Mattera and Giorgio Allori    M  ...             NaN
# 1366                                  Alex Takyi  NaN  ...             NaN
# 1571                                 Lydia Paulk    F  ...           13h00
# 3262                                 Robert Kehl    M  ...             NaN
# 798                             Justin Ellingham    M  ...           19h28
# 3157                               Jean Blanchet  NaN  ...             NaN
# 1281                                Mark Lemelin    M  ...           18h50
# 2059                                        teen    M  ...           14h30
# 4134                                  native boy    M  ...             NaN
# 2469                                         NaN  NaN  ...             NaN
# 4618                                       Hamid    M  ...             NaN
# 1392                                 Larry Olson    M  ...           14h20
# 6174                                        male    M  ...             NaN
# 5706                 Salvatore & Agostino Bugeja    M  ...             NaN
# 2884                                 Omar Conger    M  ...           08h30
# 4189            Matthew Keia, a Lord Howe native    M  ...           17h30
# 67                                          male    M  ...           15h00
# 1791                                Damien Share    M  ...            Dusk
# 2896                                Anton Bosman    M  ...           13h30
# 2498                               French female    F  ...             NaN
# 5303                             Thomas Richards    M  ...             NaN
# 4925                                Beryl Morrin    F  ...           20h15
#
#                                  Investigator or Source original order  \
# 856                                 Clicanoo, 10/5/2011         5447.0
# 4354        J. Borg, p.73; L. Taylor (1993), pp.100-101         1949.0
# 804                   H. Frederick, NSB News, 3/24/2012         5499.0
# 1499                                http://www.kesq.com         4804.0
# 2063                Orlando Sentinel, 3/25/2000, p.D.3          4240.0
# 6186                                    Di Candia, 2004          117.0
# 178                               The Citizen, 2/8/2017         6125.0
# 1031                     D. Guevara, WSVN-TV, 4/28/2010         5272.0
# 925                                   News 7, 5/11/2011         5378.0
# 5669                                The News, 4/15/1893          634.0
# 3763       NY Journal of Commerce, 3/29/1963;Wikipedia          2540.0
# 861                                  News 24, 9/29/2011         5442.0
# 1459                                  C. Creswell, GSAF         4844.0
# 1374  C. Creswell, GSAF; Hilton Head Island Packet, ...         4929.0
# 2819                                Y. Choi & K. Nakaya         3484.0
# 4269  A. MacCormick, p.11, citing the New Orleans Ti...         2034.0
# 512                                Nooga.com, 8/25/2014         5791.0
# 5000         R. Samuels, K. Reynolds & M. Levine, GSAF          1303.0
# 4701  W. L. Jones, M.D.; Saturday Evening Post; V.M....         1602.0
# 2195                                       JC, 4/2/1998         4108.0
# 3868  Natal Daily News, 12/19/1961; Sydney Morning H...         2435.0
# 5325                                N. Bartlett, pp.234          978.0
# 1999             South Florida Sun-Sentinel, 10/11/2000         4304.0
# 1614                                          Cuba News         4689.0
# 3346                               G. Ambrose, pp.78-86         2957.0
# 4627                             The Gleaner, 4/29/1946         1676.0
# 5828                           Coppleson (1958), p.262           475.0
# 2171                                    E. Ritter, GSAF         4132.0
# 4263  Washington Post, 1/18/1956;  Note: Webster, p....         2040.0
# 2689        J. Borg, p.77; L. Taylor (1993), pp.108-109         3614.0
# 4911                        Port Arthur News, 4/12/1935         1392.0
# 1206                           Mailonline.com, 9/8/2008         5097.0
# 412                                   C. Creswell, GSAF         5891.0
http://sharkattackfile.net/spreadsheets/pdf_di...
# 4354  http://sharkattackfile.net/spreadsheets/pdf_di...
# 804   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1499  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2063  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6186  http://sharkattackfile.net/spreadsheets/pdf_di...
# 178   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1031  http://sharkattackfile.net/spreadsheets/pdf_di...
# 925   http://sharkattackfile.net/spreadsheets/pdf_di...
# 5669  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3763  http://sharkattackfile.net/spreadsheets/pdf_di...
# 861   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1459  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1374  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2819  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4269  http://sharkattackfile.net/spreadsheets/pdf_di...
# 512   http://sharkattackfile.net/spreadsheets/pdf_di...
# 5000  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4701  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2195  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3868  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5325  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1999  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1614  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3346  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4627  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5828  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2171  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4263  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2689  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4911  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1206  http://sharkattackfile.net/spreadsheets/pdf_di...
# 412   http://sharkattackfile.net/spreadsheets/pdf_di...
# 2808  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5827  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4899  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1783  http://sharkattackfile.net/spreadsheets/pdf_di...
# 359   http://sharkattackfile.net/spreadsheets/pdf_di...
# 2792  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1366  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1571  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3262  http://sharkattackfile.net/spreadsheets/pdf_di...
# 798   http://sharkattackfile.net/spreadsheets/pdf_di...
# 3157  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1281  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2059  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4134  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2469  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4618  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1392  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6174  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5706  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2884  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4189  http://sharkattackfile.net/spreadsheets/pdf_di...
# 67    http://sharkattackfile.net/spreadsheets/pdf_di...
# 1791  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2896  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2498  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5303  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4925  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Unnamed: 22  \
# 856   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4354  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 804   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1499  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2063  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6186  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 178   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1031  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 925   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5669  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3763  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 861   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1459  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1374  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2819  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4269  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 512   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5000  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4701  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2195  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3868  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5325  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1999  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1614  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3346  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4627  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5828  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2171  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4263  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2689  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4911  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1206  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 412   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2808  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5827  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4899  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1783  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 359   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2792  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1366  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1571  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3262  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 798   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3157  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1281  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2059  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4134  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2469  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4618  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1392  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6174  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5706  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2884  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4189  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 67    http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1791  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2896  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2498  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5303  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4925  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
#
#      Unnamed: 23
# 856          NaN
# 4354         NaN
# 804          NaN
# 1499         NaN
# 2063         NaN
# 6186         NaN
# 178          NaN
# 1031         NaN
# 925          NaN
# 5669         NaN
# 3763         NaN
# 861          NaN
# 1459         NaN
# 1374         NaN
# 2819         NaN
# 4269         NaN
# 512          NaN
# 5000         NaN
# 4701         NaN
# 2195         NaN
# 3868         NaN
# 5325         NaN
# 1999         NaN
# 1614         NaN
# 3346         NaN
# 4627         NaN
# 5828         NaN
# 2171         NaN
# 4263         NaN
# 2689         NaN
# 4911         NaN
# 1206         NaN
# 412          NaN
# 2808         NaN
# 5827         NaN
# 4899         NaN
# 1783         NaN
# 359          NaN
# 2792         NaN
# 1366         NaN
# 1571         NaN
# 3262         NaN
# 798          NaN
# 3157         NaN
# 1281         NaN
# 2059         NaN
# 4134         NaN
# 2469         NaN
# 4618         NaN
# 1392         NaN
# 6174         NaN
# 5706         NaN
# 2884         NaN
# 4189         NaN
# 67           NaN
# 1791         NaN
# 2896         NaN
# 2498         NaN
# 5303         NaN
# 4925         NaN
#
# [60 rows x 24 columns]

# %%
shark_info.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %% [markdown]
# # limpieza de country

# %%
shark_clean['Country'] = shark_clean['Country'].fillna('Unknown')
shark_clean.sample(40)
# Out:
#      Case Number                Date  Year          Type           Country  \
# 3566  1966.07.31         31-Jul-1966  1966    Unprovoked               USA
# 1231  2008.07.24         24-Jul-2008  2008    Unprovoked               USA
# 3446  1968.12.26         26-Dec-1968  1968      Provoked         AUSTRALIA
# 1819  2002.10.05         05-Oct-2002  2002    Unprovoked               USA
# 2121  1999.06.12         12-Jun-1999  1999    Unprovoked               USA
# 4269                            Virginia
# 2226                             Florida
# 5373                     New South Wales
# 2093                             Florida
# 6195                                 NaN
# 2403                      North Carolina
# 4461                          California
# 919                               Hawaii
# 6290                       KwaZulu-Natal
# 3429                             Florida
# 4138                           Guerrrero
# 396                      New South Wales
# 6069                                 NaN
# 377                           California
# 2106                      North Carolina
# 4098                     New South Wales
# 3106               Eastern Cape Province
#
#                                             Location  \
# 3566                          South Jetty, Galveston
# 1231                   Topsail Island, Pender County
# 3446             Marineland Aquarium, Manley, Sydney
# 1819                New Smyrna Beach, Volusia County
# 2121                   Atlantiic Beach, Duval County
# 3842                                        Cronulla
# 2116                                      Charleston
# 3685                                          Naviti
# 1876            Daytona Beach Shores, Volusia County
# 6298                                             NaN
# 4310                 Vero Beach, Indian River County
# 4323                           Lika-Senj, Pag Island
# 3271                       Inyoni Rocks, Amanzimtoti
# 4938                                        Cronulla
# 4463                   50 miles off Port La Libertad
# 6184                                  Red Frog Beach
# 3984    On board  East German fishing trawler, I Mai
# 3715  Catfish Rock, between Salt Rock & Shakas Rock
# 2002          Wrightsville Beach, New Hanover County
# 4669           40 miles off Islamorada, near Cay Sal
# 4244           Fisherman's Island, near Port Moresby
# 991                 New Smyrna Beach, Volusia County
# 3655                  Fingal Beach, near Tweed Heads
# 4269            Virginia Beach, Princess Anne County
# 2226                New Smyrna Beach, Volusia County
# 5373                                          Coogee
# 2093                   Daytona Beach, Volusia County
# 6195                                             NaN
# 2403                                  Carolina Beach
# 4461                Imperial Beach, San Diego County
# 919                         Lyman Beach, Kailua-Kona
# 6290                                          Durban
# 3429                                    Florida Keys
# 4138                                        Acapulco
# 396                                     East Ballina
# 6069                                             NaN
# 377                             Santa Barbara County
# 2106                 Fort Fisher, New Hanover County
# 4098                                    Maroubra Bay
# 3106                                     Port Alfred
#
#                                                Activity  \
# 3566                            Diving for sand dollars
# 1231                                             Wading
# 3446                           Feeding mullet to sharks
# 1819                                            Surfing
# 2121                                           Swimming
# 3842                                       Spearfishing
# 2116                                                NaN
# 3685                                       Spearfishing
# 1876                        Swimming /  boogie boarding
# 6298                                       Pearl diving
# 4310                                                NaN
# 4323                                            Boating
# 3271                                            Surfing
# 4938                                            Fishing
# 4463       Jerked overboard while pole fishing for tuna
# 6184                                          Swimming/
# 3984                                            Fishing
# 3715                                           Standing
# 2002                                            Surfing
# 4669  Treading water after survivng crash of the US ...
# 4244                                            Fishing
# 991                                             Surfing
# 3655      Swimming out to rescue swimmers in difficulty
# 4269                                           Swimming
# 2226                                            Surfing
# 5373                                           Swimming
# 2093                                      Body boarding
# 6195                                                NaN
# 2403                                       Scuba diving
# 4461                      Body surfing / treading water
# 919                                             Surfing
# 6290                                             Wading
# 3429                                             Wading
# 4138                Slapped shark on tail as it swam by
# 396                                      Body boarding
# 6069                                           Swimming
# 377                                       Kayak Fishing
# 2106                                            Surfing
# 4098                                       Spearfishing
# 3106                       Surfing, collided with shark
#
#                                              Name Sex   ...     Time  \
# 3566                            Robert W. Russell    M  ...      NaN
# 1231                            Madeline Sinsley     F  ...    13h00
# 3446                                  Peter Jones    M  ...  Morning
# 1819                                   Ivan Rios     M  ...    13h30
# 2121                                         male    M  ...    13h15
# 3842                                 Robert Smith    M  ...      NaN
# 2116                                Shannon Morsy    M  ...      NaN
# 3685                           Sailasa Ratubalavu    M  ...    11h30
# 1876                                  John Sadler    M  ...    15h45
# 6298                                        Ahmun    M  ...      NaN
# 4310              2 incidents north of Vero Beach  NaN  ...      NaN
# 4323                                          NaN  NaN  ...      NaN
# 3271                        Anthony Kenneth Baker    M  ...    16h30
# 4938  18' boat, occupants William & Leslie Newton    N  ...      NaN
# 4463                            Robert L. Bottini    M  ...    08h30
# 6184                                         male    M  ...      NaN
# 3984                        Hans Yoachim Schapper    M  ...      NaN
# 3715                         Barbara Elsa Strauss    F  ...    14h00
# 2002                                  Mark Taylor    M  ...    16h30
# 4669                Petty Officer Isadore Stessel    M  ...      NaN
# 4244                                   native boy    M  ...      NaN
# 991                                 Jason Coffman    M  ...    12h00
# 3655                             Glenthorne Prior    M  ...    13h30
# 4269                                         girl    F  ...      NaN
# 2226                                 Robert Lange    M  ...    15h20
# 5373                                    Fred Wort    M  ...    16h00
# 2093                                 Keven Dolsky    M  ...    17h30
# 6195                                         male    M  ...      NaN
# 2403                                       Nunley    M  ...      NaN
# 4461                           Robert B. Campbell    M  ...    12h00
# 919                             Theresa Fernandez    F  ...    13h15
# 6290                             a young Scotsman    M  ...      NaN
# 3429                                Steven Benham    M  ...     1600
# 4138                                         male    M  ...      NaN
# 396                                      Matt Lee    M  ...    09h00
# 6069                                         "A"     M  ...      NaN
# 377                                   Connor Lyon    M  ...    07h30
# 2106                                         male    M  ...      NaN
# 4098                                Peter Holland    M  ...      NaN
# 3106                               Charles Kantor    M  ...    13h15
#
#                                  Investigator or Source original order  \
# 3566                M. Vorenberg, H.D. Baldridge, p.191         2737.0
# 1231                                  C. Creswell, GSAF         5072.0
# 3446                                The Age, 12/27/1968         2857.0
# 1819  S. Petersohn, GSAF; Daytona Beach News Journal...         4484.0
# 2121                     Florida Times-Union, 6/13/1999         4182.0
# 3842  Daily Mirror (Sydney) & Sydney Morning Herald,...         2461.0
# 2116                           Channel 9 News Charlotte         4187.0
# 3685                 H.D. Baldridge, p.196; Clark, p.87         2618.0
# 1876  S. Petersohn, GSAF; Orlando Sentinel, 3/20/200...         4427.0
# 6298              H. Taunton; N. Bartlett,  pp. 233-234            5.0
# 4310  R.F. Hutton; V.M. Coppleson (1958) (ref.R. Nor...         1993.0
# 4323  A. De Maddalena; Anon. (1954), Soldo & Jardas ...         1980.0
# 3271  A. Baker, M. Levine, GSAF; G. Charter & B. Dav...         3032.0
# 4938  G.P. Whitley, ref: Daily Telegraph, 7/11/1934 ...         1365.0
# 4463  Evening Sun (Baltimore), 8/11/1950; Long Beach...         1840.0
# 6184                            C. Mendieta & A. Duarte          119.0
# 3984  Edinburg Evening News, 7/6/1960; Dundee Evenin...         2319.0
# 3715  B. Strauss, D. Davies, 121-122; Daily Dispatch...         2588.0
# 2002              The State (Columbia), 10/6/2000, p.A6         4301.0
# 4669                                          Wikipedia         1634.0
# 4269  1956.00.00.d  1956.00.00.d   1956.00.00.d-girl-VirginiaBeach.pdf
# 2226    1997.09.06    1997.09.06                  1997.09.06-Lange.pdf
# 5373    1912.02.19    1912.02.19                   1912.02.19-Wort.pdf
# 2093  1999.10.30.b  1999.10.30.b               1999.10.30.b-Dolsky.pdf
# 6195       ND-0132       ND-0132    ND-0132-India-fight-with-shark.pdf
# 2403  1995.00.00.c  1995.00.00.c               1995.00.00.c-Nunley.pdf
# 4461    1950.10.08    1950.10.08       1950.10.08-Campbell-Collier.pdf
# 919     2011.05.25    2011.05.25              2011.05.25-Fernandez.pdf
# 6290       ND.0012       ND.0012           ND-0012-Durban-Scotsman.pdf
# 3429    1969.06.27    1969.06.27              1969.06.27-NV-Benham.pdf
# 4138  1958.10.00.b  1958.10.00.b             1958.10.00.b-Acapulco.pdf
# 396     2015.07.02    2015.07.02               2015.07.02-Matt-Lee.pdf
# 6069  1840.04.09.R  1840.04.09.R                    1840.04.09.R-A.pdf
# 377   2015.08.18.b  2015.08.18.b                 2015.08.18.b-Lyon.pdf
# 2106    1999.08.24    1999.08.24             1999.08.24-FortFisher.pdf
# 4098    1959.04.27    1959.04.27                1959.04.27-Holland.pdf
# 3106    1979.02.21    1979.02.21                 1979.02.21-Kantor.pdf
#
#                                            href formula  \
# 3566  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1231  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3446  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1819  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2121  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3842  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2116  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3685  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1876  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4310  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4323  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3271  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4938  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4463  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6184  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3984  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3715  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2002  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4669  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4244  http://sharkattackfile.net/spreadsheets/pdf_di...
# 991   http://sharkattackfile.net/spreadsheets/pdf_di...
# 3655  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4269  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2226  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5373  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2093  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6195  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2403  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4461  http://sharkattackfile.net/spreadsheets/pdf_di...
# 919   http://sharkattackfile.net/spreadsheets/pdf_di...
# 6290  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3429  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4138  http://sharkattackfile.net/spreadsheets/pdf_di...
# 396   http://sharkattackfile.net/spreadsheets/pdf_di...
# 6069  http://sharkattackfile.net/spreadsheets/pdf_di...
# 377   http://sharkattackfile.net/spreadsheets/pdf_di...
# 2106  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4098  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3106  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Unnamed: 22  \
# 3566  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1231  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3446  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1819  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2121  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3842  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2116  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3685  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1876  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4310  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4323  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3271  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4938  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4463  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6184  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3984  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3715  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2002  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4669  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4244  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 991   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3655  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4269  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2226  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5373  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2093  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6195  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2403  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4461  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 919   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6290  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3429  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4138  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 396   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6069  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 377   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2106  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4098  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3106  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
#
#      Unnamed: 23
# 3566         NaN
# 1231         NaN
# 3446         NaN
# 1819         NaN
# 2121         NaN
# 3842         NaN
# 2116         NaN
# 3685         NaN
# 1876         NaN
# 6298         NaN
# 4310         NaN
# 4323         NaN
# 3271         NaN
# 4938         NaN
# 4463         NaN
# 6184         NaN
# 3984         NaN
# 3715         NaN
# 2002         NaN
# 4669         NaN
# 4244         NaN
# 991          NaN
# 3655         NaN
# 4269         NaN
# 2226         NaN
# 5373         NaN
# 2093         NaN
# 6195         NaN
# 2403         NaN
# 4461         NaN
# 919          NaN
# 6290         NaN
# 3429         NaN
# 4138         NaN
# 396          NaN
# 6069         NaN
# 377          NaN
# 2106         NaN
# 4098         NaN
# 3106         NaN
#
# [40 rows x 24 columns]

# %% [markdown]
# # limpieza de Area

# %%
shark_clean['Area'] = shark_clean['Area'].fillna('Unknown')
shark_clean.sample(60)
# Out:
#       Case Number                                        Date  Year  \
# 4682   1943.03.02                  02-Mar-1943 to 07-Mar-1943  1943
# 3515                                           Floating
# 4405                                            Fishing
# 5394                                           Swimming
# 3772                                      Shark fishing
# 5663                                         small boat
# 4569                                          Swimming
# 4839                                   Pleasure boating
# 1803                                         Snorkeling
# 5616                                            Fishing
# 2201                                       Spearfishing
# 4447                       Fishing, casting in the surf
# 1229                                         Snorkeling
# 2162                                            Surfing
# 3740                                            Surfing
# 571                                            Swimming
# 199                                            Floating
# 1956                                            Surfing
# 2075                                            Surfing
# 2661                                            Surfing
# 5736                Fell oveboard from steamer Wanderer
# 1325                                           Swimming
# 2351                                            Surfing
# 5240                           Diving for beche-de-mer
# 3113                                       Spearfishing
# 356                                       Kayak fishing
#
#                                                    Name Sex   ...  \
# 4682                                                NaN  NaN  ...
# 1897  boat: inflatable boat, occupant: Matt George, ...    M  ...
# 4409                                Juan Suarez Morales    M  ...
# 3750                                    Gregory Moffatt    M  ...
# 763                                        Shaka Galera    M  ...
# 5413                                                NaN  NaN  ...
# 4259                                         Theo Brown    M  ...
# 1884                                       Andrew Cribb    M  ...
# 3613                                      French seaman    M  ...
# 1073                                 Melissa Hardcastle    F  ...
# 2643                           Ola Stillman Rockefeller    M  ...
# 2004                                       Jevan Wright    M  ...
# 2743                                     Peggy Schaefer    F  ...
# 3610                                   Dabek Orou, male    M  ...
# 259                                         Jeff Schott    M  ...
# 4506                                 Giovanni Picarelli    M  ...
# 239                                                male    M  ...
# 1021                                    Huynh Nhu Hoang    M  ...
# 4989                                     Asena (female)    F  ...
# 2032                                    Shannon Ainslie    M  ...
# 6051                                      John Williams    M  ...
# 3230                                        Indian male    M  ...
# 6236                                           Ted Luck    M  ...
# 2109                        Christopher (Will)  Handley    M  ...
# 2330                                   Wendall Olanolan    M  ...
# 3709                                      Jack Rochette    M  ...
# 1211                                         Ben Vining    M  ...
# 4328                                         Aldo Campi    M  ...
# 2600                                        Coen Marais    M  ...
# 1437                               Steven Harcourt-Wood    M  ...
# 3635                              Geoffrey Walter Black    M  ...
# 2426                          Alessandro Gomes de Souza    M  ...
# 1273                                        David Weale    M  ...
# 92                                                 male    M  ...
# 2381                                      Amber Delmans    F  ...
# 3515                                       Sue Ferguson    F  ...
# 4405                                  Ben Tillman Homes    M  ...
# 5394                                           a sailor    M  ...
# 3772  boat, occupants: Alf Dean, Jack Hood & Otto Bells  NaN  ...
# 5663                   4 passengers frightened by shark  NaN  ...
# 4569                         Father Serafin de Oliveira    M  ...
# 4839                          Clyde steamer Glen Sannox  NaN  ...
# 1803                                        Craig Bovim    M  ...
# 5616   10' skiff. Occupants F. Whitehead & L. Honeybone    M  ...
# 2201                                               male    M  ...
# 4447                                               male    M  ...
# 1229                                       Kaori Fiack     F  ...
# 2162                                          Kai Haire    M  ...
# 3740                                       Peter Barron    M  ...
# 571                              Friedrich Burgstaller.    M  ...
# 199                                     Barbara Zawacki    F  ...
# 1956                                     Richard Spence    M  ...
# 2075                                      Anthony Hayes    M  ...
# 2661                                        John Benson    M  ...
# 5736                                      Carl Luhudahl    M  ...
# 1325                              Kristina Aleksandrova    F  ...
# 2351                                       Dwight Irvin    M  ...
# 5240                                   aboriginal diver    M  ...
# 3113                                       Erik Lombard    M  ...
# 356                                       Darren Kenney    M  ...
#
#                   Time                             Investigator or Source  \
# 4682               NaN                                   G. Duncan, et al
# 1897              P.M.                                  T. Peake, GSAF
# 4409             11h00  V.M. Coppleson (1958), p.265; J. Randall in Sh...
# 3750               NaN                         San Mateo Times, 5/22/1963
# 763                NaN                         Trinidad Express, 8/3/2012
# 5413               NaN                                The Sun, 7/13/1913
# 4259               NaN        J. Green, p.34, Spokesman-Review, 3/19/1956
# 1884    20h45 (Sunset)                                     T. Peake, GSAF
# 3613               NaN    Manila Daily Bulletin, 9/3/1965; SAF Case #1388
# 1073             16h30                              C. Scofield, WPTV.com
# 2643               NaN                           The News, 3/27/1990, p.6
# 2004             13h00                                     T. Peake, GSAF
# 2743               NaN                       Milwaukee Journal, 4/12/1988
# 3610               NaN      South Pacific Post, 9/22/2965; SAF Case #1386
# 259              15h25                                  C. Creswell, GSAF
# 4506               NaN                                     C. Moore, GSAF
# 239              19h05                             Japan Times, 7/25/2016
# 1021             17h00                         Thanh Nien News, 5/15/2010
# 4989               NaN                       V.M. Coppleson (1958), p.259
# 2032               NaN  A. Gifford, GSAF; Orlando Sentinel, 7/19/2000,...
# 6051               NaN  The Maitland Mercury & Hunter River General Ad...
# 3230               NaN                                      B. Davis, NSB
# 6236               NaN                        N. Caldwell; T. Peake, GSAF
# 2109             17h40  Charlotte Observer, 8/18/1999, p.4C; J. Kenned...
# 2330               NaN                                          G. Balazs
# 3709             12h00  R. Collier, p.261-264; D. Miller & R. Collier;...
# 1211               NaN                                 C. Johansson, GSAF
# 4328               NaN                                     C. Moore, GSAF
# 2600             13h00                                    M. Levine, GSAF
# 1437               NaN                               Cape Times, 9/3/2006
# 3635    15h00 or 15h45  G.W. Black, M. Levine,  GSAF;  T. McHugh, A. H...
# 2426               NaN                                           JCOnline
# 1273             11h00                                 C. Johansson, GSAF
# 92               10h00                              Japan Today, 9/4/2017
# 2381             14h00  Orlando Sentinel, 6/19/1995, p.B3; Fort Pierce...
# 3515             16h00                        Gettysburg Times, 8/15/1967
# 4405               NaN                        News and Courier, 7/28/1952
# 5394               NaN                                        D.G. McComb
# 3772               NaN                                     SAF Case #1184
# 5663               NaN                                      C. Moore.GSAF
# 4569               NaN                               JC Online, 6/25/2012
# 4839               NaN        Daily Mail (undated clipping); A Buttigieg
# 1803  Just after 12h00                                          IOL.co.za
# 5616             05h00              South Australian Register, 12/25/1896
# 2201             20h00                     Daily Telegraph, 1/28/1998.p.2
# 4447               NaN                               LA Times, 3/25/1951
# 1229             08h45                  Honolulu Star Bulletin, 7/26/2008
# 2162               NaN                    The Stuart (FL) News, 9/29/1998
# 3740             09h30   P. Barron; Goulburn Evening Post; J. Green, p.35
# 571              15h00                    Austrian Independent, 3/24/2014
# 199              10h30                              Maui News, 11/14/2016
# 1956             16h45  S. Petersohn, GSAF; Orlando Sentinel, 4/14/200...
# 2075               NaN                                     T. Peake, GSAF
# 2661               NaN                                      J. West, ASAF
# 5736               NaN                   Union County Journal, 12/22/1887
http://sharkattackfile.net/spreadsheets/pdf_di...
# 1897  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4409  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3750  http://sharkattackfile.net/spreadsheets/pdf_di...
# 763   http://sharkattackfile.net/spreadsheets/pdf_di...
# 5413  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4259  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1884  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3613  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1073  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2643  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2004  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2743  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3610  http://sharkattackfile.net/spreadsheets/pdf_di...
# 259   http://sharkattackfile.net/spreadsheets/pdf_di...
# 4506  http://sharkattackfile.net/spreadsheets/pdf_di...
# 239   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1021  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4989  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2032  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6051  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3230  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6236  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2109  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2330  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3709  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1211  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4328  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2600  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1437  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3635  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2426  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1273  http://sharkattackfile.net/spreadsheets/pdf_di...
# 92    http://sharkattackfile.net/spreadsheets/pdf_di...
# 2381  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3515  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4405  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5394  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3772  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5663  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4569  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4839  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1803  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5616  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2201  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4447  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1229  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2162  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3740  http://sharkattackfile.net/spreadsheets/pdf_di...
# 571   http://sharkattackfile.net/spreadsheets/pdf_di...
# 199   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1956  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2075  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2661  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5736  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1325  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2351  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5240  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3113  http://sharkattackfile.net/spreadsheets/pdf_di...
# 356   http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Unnamed: 22  \
# 4682  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1897  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4409  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3750  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 763   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5413  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4259  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1884  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3613  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1073  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2643  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2004  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2743  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3610  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 259   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4506  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 239   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1021  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4989  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2032  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6051  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3230  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6236  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2109  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2330  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3709  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1211  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4328  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2600  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1437  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3635  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2426  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1273  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 92    http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2381  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3515  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4405  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5394  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3772  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5663  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4569  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4839  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1803  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5616  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2201  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4447  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1229  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2162  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3740  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 571   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 199   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1956  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2075  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2661  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5736  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1325  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2351  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5240  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3113  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 356   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
#
#      Unnamed: 23
# 4682         NaN
# 1897         NaN
# 4409         NaN
# 3750         NaN
# 763          NaN
# 5413         NaN
# 4259         NaN
# 1884         NaN
# 3613         NaN
# 1073         NaN
# 2643         NaN
# 2004         NaN
# 2743         NaN
# 3610         NaN
# 259          NaN
# 4506         NaN
# 239          NaN
# 1021         NaN
# 4989         NaN
# 2032         NaN
# 6051         NaN
# 3230         NaN
# 6236         NaN
# 2109         NaN
# 2330         NaN
# 3709         NaN
# 1211         NaN
# 4328         NaN
# 2600         NaN
# 1437         NaN
# 3635         NaN
# 2426         NaN
# 1273         NaN
# 92           NaN
# 2381         NaN
# 3515         NaN
# 4405         NaN
# 5394         NaN
# 3772         NaN
# 5663         NaN
# 4569         NaN
# 4839         NaN
# 1803         NaN
# 5616         NaN
# 2201         NaN
# 4447         NaN
# 1229         NaN
# 2162         NaN
# 3740         NaN
# 571          NaN
# 199          NaN
# 1956         NaN
# 2075         NaN
# 2661         NaN
# 5736         NaN
# 1325         NaN
# 2351         NaN
# 5240         NaN
# 3113         NaN
# 356          NaN
#
# [60 rows x 24 columns]

# %% [markdown]
# # limpieza de location

# %%
shark_clean['Location']=shark_clean['Location'].fillna('Unknown')
shark_clean
# Out:
#       Case Number         Date  Year        Type    Country             Area  \
# 0      2018.06.25  25-Jun-2018  2018     Boating        USA       California
# 1      2018.06.18  18-Jun-2018  2018  Unprovoked        USA          Georgia
# 2      2018.06.09  09-Jun-2018  2018     Unknown        USA           Hawaii
# 3      2018.06.08  08-Jun-2018  2018  Unprovoked  AUSTRALIA  New South Wales
# 4      2018.06.04  04-Jun-2018  2018    Provoked     MEXICO           Colima
# ...           ...          ...   ...         ...        ...              ...
# 6307            0   01-01-2000  2000     Unknown    Unknown          Unknown
# 6308            0   01-01-2000  2000     Unknown    Unknown          Unknown
# 6309            0   01-01-2000  2000     Unknown    Unknown          Unknown
# 8702   2010.01.01   01-01-2000  2000     Unknown    Unknown          Unknown
# 25722          xx   01-01-2000  2000     Unknown    Unknown          Unknown
#
#                              Location     Activity             Name Sex   ...  \
# 0         Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1      St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                        Habush, Oahu      Surfing      John Denges    M  ...
# 3                  Arrawarra Headland      Surfing             male    M  ...
# 4                            La Ticla  Free diving   Gustavo Ramos     M  ...
# ...                               ...          ...              ...  ...  ...
# 6307                          Unknown          NaN              NaN  NaN  ...
# 6308                          Unknown          NaN              NaN  NaN  ...
# 6309                          Unknown          NaN              NaN  NaN  ...
# 8702                          Unknown          NaN              NaN  NaN  ...
# 25722                         Unknown          NaN              NaN  NaN  ...
#
#                 Time          Investigator or Source original order  \
# 0              18h00                R. Collier, GSAF         6303.0
# 1      14h00  -15h00  K.McMurray, TrackingSharks.com         6302.0
# 2              07h45  K.McMurray, TrackingSharks.com         6301.0
# 3                NaN                  B. Myatt, GSAF         6300.0
# 4                NaN                       A .Kipper         6299.0
# ...              ...                             ...            ...
# 6307             NaN                             NaN         6309.0
# 6308             NaN                             NaN         6310.0
# 6309             NaN                             NaN            NaN
# 8702             NaN                             NaN            NaN
# 25722            NaN                             NaN            NaN
#
#       Case Number.1 Case Number.2                       pdf  \
# 0        2018.06.25    2018.06.25      2018.06.25-Wolfe.pdf
# 1        2018.06.18    2018.06.18    2018.06.18-McNeely.pdf
# 2        2018.06.09    2018.06.09     2018.06.09-Denges.pdf
# 3        2018.06.08    2018.06.08  2018.06.08-Arrawarra.pdf
# 4        2018.06.04    2018.06.04      2018.06.04-Ramos.pdf
# ...             ...           ...                       ...
# 6307            NaN           NaN                       NaN
# 6308            NaN           NaN                       NaN
# 6309            NaN           NaN                       NaN
# 8702            NaN           NaN                       NaN
# 25722           NaN           NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 6307                                                 NaN
# 6308                                                 NaN
# 6309                                                 NaN
# 8702                                                 NaN
# 25722                                                NaN
#
#                                                     href Unnamed: 22  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                  ...         ...
# 6307                                                 NaN         NaN
# 6308                                                 NaN         NaN
# 6309                                                 NaN         NaN
# 8702                                                 NaN         NaN
# 25722                                                NaN         NaN
#
#       Unnamed: 23
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 6307          NaN
# 6308          NaN
# 6309          NaN
# 8702          NaN
# 25722         NaN
#
# [6312 rows x 24 columns]

# %% [markdown]
# # limpieza de Activity

# %%
shark_clean['Activity']=shark_clean['Activity'].fillna('Unknown')
shark_clean
# Out:
#       Case Number         Date  Year        Type    Country             Area  \
# 0      2018.06.25  25-Jun-2018  2018     Boating        USA       California
# 1      2018.06.18  18-Jun-2018  2018  Unprovoked        USA          Georgia
# 2      2018.06.09  09-Jun-2018  2018     Unknown        USA           Hawaii
# 3      2018.06.08  08-Jun-2018  2018  Unprovoked  AUSTRALIA  New South Wales
# 4      2018.06.04  04-Jun-2018  2018    Provoked     MEXICO           Colima
# ...           ...          ...   ...         ...        ...              ...
# 6307            0   01-01-2000  2000     Unknown    Unknown          Unknown
# 6308            0   01-01-2000  2000     Unknown    Unknown          Unknown
# 6309            0   01-01-2000  2000     Unknown    Unknown          Unknown
# 8702   2010.01.01   01-01-2000  2000     Unknown    Unknown          Unknown
# 25722          xx   01-01-2000  2000     Unknown    Unknown          Unknown
#
#                              Location     Activity             Name Sex   ...  \
# 0         Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1      St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                        Habush, Oahu      Surfing      John Denges    M  ...
# 3                  Arrawarra Headland      Surfing             male    M  ...
# 4                            La Ticla  Free diving   Gustavo Ramos     M  ...
# ...                               ...          ...              ...  ...  ...
# 6307                          Unknown      Unknown              NaN  NaN  ...
# 6308                          Unknown      Unknown              NaN  NaN  ...
# 6309                          Unknown      Unknown              NaN  NaN  ...
# 8702                          Unknown      Unknown              NaN  NaN  ...
# 25722                         Unknown      Unknown              NaN  NaN  ...
#
#                 Time          Investigator or Source original order  \
# 0              18h00                R. Collier, GSAF         6303.0
# 1      14h00  -15h00  K.McMurray, TrackingSharks.com         6302.0
# 2              07h45  K.McMurray, TrackingSharks.com         6301.0
# 3                NaN                  B. Myatt, GSAF         6300.0
# 4                NaN                       A .Kipper         6299.0
# ...              ...                             ...            ...
# 6307             NaN                             NaN         6309.0
# 6308             NaN                             NaN         6310.0
# 6309             NaN                             NaN            NaN
# 8702             NaN                             NaN            NaN
# 25722            NaN                             NaN            NaN
#
#       Case Number.1 Case Number.2                       pdf  \
# 0        2018.06.25    2018.06.25      2018.06.25-Wolfe.pdf
# 1        2018.06.18    2018.06.18    2018.06.18-McNeely.pdf
# 2        2018.06.09    2018.06.09     2018.06.09-Denges.pdf
# 3        2018.06.08    2018.06.08  2018.06.08-Arrawarra.pdf
# 4        2018.06.04    2018.06.04      2018.06.04-Ramos.pdf
# ...             ...           ...                       ...
# 6307            NaN           NaN                       NaN
# 6308            NaN           NaN                       NaN
# 6309            NaN           NaN                       NaN
# 8702            NaN           NaN                       NaN
# 25722           NaN           NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 6307                                                 NaN
# 6308                                                 NaN
# 6309                                                 NaN
# 8702                                                 NaN
# 25722                                                NaN
#
#                                                     href Unnamed: 22  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                  ...         ...
# 6307                                                 NaN         NaN
# 6308                                                 NaN         NaN
# 6309                                                 NaN         NaN
# 8702                                                 NaN         NaN
# 25722                                                NaN         NaN
#
#       Unnamed: 23
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 6307          NaN
# 6308          NaN
# 6309          NaN
# 8702          NaN
# 25722         NaN
#
# [6312 rows x 24 columns]

# %% [markdown]
# # limpieza Name

# %%
shark_clean['Name'].value_counts()
# Out:
# male               550
# female              97
# boy                 23
# 2 males             16
# boat                14
#                   ...
# soldier              1
# Bret Jeppsen         1
# Jude Chamberlin      1
# Corey Brooks         1
# "a lad"              1
# Name: Name, Length: 5230, dtype: int64

# %%
shark_clean['Name']=shark_clean['Name'].str.replace('male|female|boy|2 males|boat','Unknown',regex=True).fillna('Unknown')
shark_clean.sample(10)
# Out:
#      Case Number          Date  Year        Type       Country  \
# 1304  2007.12.14   14-Dec-2007  2007     Unknown     AUSTRALIA
# 5825  1880.00.00         1880?  1880     Unknown         SYRIA
# 3754  1963.04.17   17-Apr-1963  1963  Unprovoked  SOUTH AFRICA
# 5854  1877.08.28   28-Aug-1877  1877     Unknown  INDIAN OCEAN
# 4989  1932.06.20   20-Jun-1932  1932  Unprovoked          FIJI
# 6277     ND.0025   Before 1927  2000  Unprovoked     AUSTRALIA
# 5363  1913.00.00          1913  1913  Unprovoked       REUNION
# 792   2012.05.23   23-May-2012  2012  Unprovoked           USA
# 6126  1805.09.00      Sep-1805  1805     Unknown           USA
# 5142  1926.10.23   23-Oct-1926  1926  Unprovoked     AUSTRALIA
#
#                  Area                        Location  \
# 1304  New South Wales                          Bondi
# 5825          Unknown                         Unknown
# 3754    KwaZulu-Natal                     Amanzimtoti
# 5854          Unknown                         Unknown
# 4989   Yasawa Islands                       Nabukeru
# 6277  New South Wales  Spectacle Island, Port Jackson
# 5363      Saint-Denis               Barachoise bridge
# 792           Florida      Jacksonville, Duval County
# 6126         New York      Sag Harbor, Suffolk County
# 5142  New South Wales                  Clarence River
#
#                       Activity                              Name Sex   ...  \
# 1304                  Swimming                      Scott Wright    M  ...
# 5825        Diving for sponges                           Unknown    M  ...
# 3754                  Swimming                      Errol Fourie    M  ...
# 5854                   Unknown                           Unknown    M  ...
# 4989  Free diving with goggles                   Asena (Unknown)    F  ...
# 6277                   Unknown  Unknown, the Sergeant of Marines    M  ...
# 5363    Swimming after his hat                           Unknown    M  ...
# 792                    Surfing                        Chad Refro    M  ...
# 6126                   Unknown                           Unknown    M  ...
# 5142                   Bathing                   Herbert Webster    M  ...
#
#            Time                 Investigator or Source original order  \
# 1304      20h30      Sydney Morning Herald, 12/16/2007         4999.0
# 5825        NaN                         C. Moore, GSAF          478.0
# 3754      12h45  D. Davies, p.118-119; M. Levine, GSAF         2549.0
# 5854        NaN    Western Australian Times, 8/28/1877          449.0
# 4989        NaN           V.M. Coppleson (1958), p.259         1314.0
# 6277        NaN                              H. Capper           26.0
# 5363        NaN                               H. Cornu          940.0
# 792       15h00            First Coast News, 5/24/2012         5511.0
# 6126        NaN                   S.L. Mitchill (1814)          177.0
# 5142  Afternoon              Barrier Miner, 10/25/1926         1161.0
#
#      Case Number.1 Case Number.2                              pdf  \
# 1304    2007.12.14    2007.12.14            2007.12.14-Wright.pdf
# 5825  1880.00.00.e  1880.00.00.e           1898.00.00.R-Syria.pdf
# 3754    1963.04.17    1963.04.17            1963.04.17-Fourie.pdf
# 5854  1877.08.28.R  1877.08.28.R     1877.08.28.R-IndianOcean.pdf
# 4989    1932.06.20    1932.06.20             1932.06.20-Asena.pdf
# 6277       ND.0025       ND.0025  ND-0025-Sgt-SpectacleIsland.pdf
# 5363  1913.00.00.d  1913.00.00.d   1913.00.00.d-ReunionIsland.pdf
# 792     2012.05.23    2012.05.23            2012.05.23-Renfro.pdf
# 6126    1805.09.00    1805.09.00                1805.09.00-NY.pdf
# 5142  1926.10.23.b  1926.10.23.b         1926.10.23.b-Webster.pdf
#
#                                            href formula  \
# 1304  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5825  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3754  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5854  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4989  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6277  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5363  http://sharkattackfile.net/spreadsheets/pdf_di...
# 792   http://sharkattackfile.net/spreadsheets/pdf_di...
# 6126  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5142  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Unnamed: 22  \
# 1304  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5825  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3754  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5854  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4989  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6277  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5363  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 792   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6126  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5142  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
#
#      Unnamed: 23
# 1304         NaN
# 5825         NaN
# 3754         NaN
# 5854         NaN
# 4989         NaN
# 6277         NaN
# 5363         NaN
# 792          NaN
# 6126         NaN
# 5142         NaN
#
# [10 rows x 24 columns]

# %% [markdown]
# # limpieza sex

# %%
shark_clean['Sex ']=shark_clean['Sex '].fillna('ND')
shark_clean.sample(10)
# Out:
#      Case Number          Date  Year          Type         Country  \
# 5417  1909.07.15   15-Jul-1909  1909    Unprovoked             USA
# 5035  1930.09.26   26-Sep-1930  1930    Unprovoked        HONDURAS
# 3842  1962.01.21   21-Jan-1962  1962      Provoked       AUSTRALIA
# 6096  1828.09.28   28-Sep-1828  1828    Unprovoked    SIERRA LEONE
# 6106  1825.00.00         1820s  1825    Unprovoked       AUSTRALIA
# 3930  1961.01.06   06-Jan-1961  1961  Sea Disaster  ATLANTIC OCEAN
# 1600  2005.04.06   06-Apr-2005  2005       Unknown        HONDURAS
# 4074  1959.08.12   12-Aug-1959  1959      Provoked         CROATIA
# 4914  1935.03.25   25-Mar-1935  1935      Provoked    SOUTH AFRICA
# 2538  1992.08.25   25-Aug-1992  1992    Unprovoked       AUSTRALIA
#
#                  Area                                           Location  \
# 5417          Florida                            Panama City, Bay County
# 5035      Black River                                            Unknown
# 3842  New South Wales                                           Cronulla
# 6096     Western Area  River Sierra Leone, 35 miles  upriver from Fre...
# 6106         Tasmania                      Sweet Water Point, Pitt Water
# 3930     9.35N 79.35W    East of La Grande Island, North of Panama Canal
# 1600      Bay Islands                                              Utila
# 4074           Istria                                               Pula
# 4914    KwaZulu-Natal                                 North Pier, Durban
# 2538  South Australia                             Lipson Cove, Tumby Bay
#
#                                                Activity  \
# 5417                                           Swimming
# 5035                                           Swimming
# 3842                                       Spearfishing
# 6096  British ship, Britannia,  was loading lumber. ...
# 6106                                           Swimming
# 3930                        Pacific Seafarer of US Navy
# 1600                                       SCUBA Diving
# 4074                                            Fishing
# 4914     Put foot inside mouth of supposedly dead shark
# 2538                                            Surfing
#
#                                               Name Sex   ...   Time  \
# 5417                                  Henry Munson    M  ...    NaN
# 5035                                  Indian guide    M  ...    NaN
# 3842                                  Robert Smith    M  ...    NaN
# 6096  Thomas Corrigle, an apprentice from the ship    M  ...    NaN
# 6106                     "Amphibious Jack" Unknown    M  ...    NaN
# 3930                                       Unknown   ND  ...    NaN
# 1600                                       Unknown    F  ...    NaN
# 4074                                Narcisco Tomaz    M  ...    NaN
# 4914                                       Unknown    M  ...    NaN
# 2538                                   Jason Bates    M  ...  17h50
#
#                                  Investigator or Source original order  \
# 5417                             News Herald, 7/29/2001          886.0
# 5035                                NY Times, 9/26/1930         1268.0
# 3842  Daily Mirror (Sydney) & Sydney Morning Herald,...         2461.0
# 6096                                Account by J. Boyle          207.0
# 6106  C. Black, GSAF, G.T. Lloyd, pp.79-81; C. Black...          197.0
# 3930                                    C.R. Wolf, M.D.         2373.0
# 1600                  J. Engel, SRI & S. Fox, Deep Blue         4703.0
# 4074                                     C. Moore, GSAF         2229.0
# 4914                      Natal Coast Angler, 3/25/1935         1389.0
# 2538          Advertiser, 8/28/1992, p.3; J. West, ASAF         3765.0
#
#      Case Number.1 Case Number.2                               pdf  \
# 5417    1909.07.15    1909.07.15             1909.07.15-Munson.pdf
# 5035  1930.09.26.R  1930.09.26.R      1930.09.26.R-IndianGuide.pdf
# 3842    1962.01.21    1962.01.21              1962.01.21-Smith.pdf
# 6096    1828.09.28    1828.09.28           1828.09.28-Corrigle.pdf
# 6106  1825.00.00.b  1825.00.00.b   1825.00.00.b-AmphibiousJack.pdf
# 3930  1961.01.06.b  1961.01.06.b  1961.01.06.b-PacificSeafarer.pdf
# 1600    2005.04.06    2005.04.06            2005.04.06.b-Utila.pdf
# 4074    1959.08.12    1959.08.12              1959.08.12-Tomaz.pdf
# 4914  1935.03.25.R  1935.03.25.R           1935.03.25.R-Durban.pdf
# 2538    1992.08.25    1992.08.25              1992.08.25-Bates.pdf
#
#                                            href formula  \
# 5417  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5035  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3842  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6096  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6106  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3930  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1600  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4074  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4914  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2538  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Unnamed: 22  \
# 5417  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5035  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3842  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6096  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6106  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3930  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1600  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4074  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4914  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2538  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
#
#      Unnamed: 23
# 5417         NaN
# 5035         NaN
# 3842         NaN
# 6096         NaN
# 6106         NaN
# 3930         NaN
# 1600         NaN
# 4074         NaN
# 4914         NaN
# 2538         NaN
#
# [10 rows x 24 columns]

# %% [markdown]
# # limpieza Time "Eliminar"

# %%
shark_clean['Time'].value_counts()
# Out:
# Afternoon       187
# 11h00           128
# Morning         121
# 12h00           109
# 15h00           108
#                ...
# After 04h00       1
# 13h51             1
# "After dark"      1
# 07h08             1
# Mid morning       1
# Name: Time, Length: 366, dtype: int64

# %% [markdown]
# # limpieza investigator or source

# %%
shark_clean['Investigator or Source']=shark_clean['Investigator or Source'].fillna('Unknown')
shark_clean
# Out:
#       Case Number         Date  Year        Type    Country             Area  \
# 0      2018.06.25  25-Jun-2018  2018     Boating        USA       California
# 1      2018.06.18  18-Jun-2018  2018  Unprovoked        USA          Georgia
# 2      2018.06.09  09-Jun-2018  2018     Unknown        USA           Hawaii
# 3      2018.06.08  08-Jun-2018  2018  Unprovoked  AUSTRALIA  New South Wales
# 4      2018.06.04  04-Jun-2018  2018    Provoked     MEXICO           Colima
# ...           ...          ...   ...         ...        ...              ...
# 6307            0   01-01-2000  2000     Unknown    Unknown          Unknown
# 6308            0   01-01-2000  2000     Unknown    Unknown          Unknown
# 6309            0   01-01-2000  2000     Unknown    Unknown          Unknown
# 8702   2010.01.01   01-01-2000  2000     Unknown    Unknown          Unknown
# 25722          xx   01-01-2000  2000     Unknown    Unknown          Unknown
#
#                              Location     Activity             Name Sex   ...  \
# 0         Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1      St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                        Habush, Oahu      Surfing      John Denges    M  ...
# 3                  Arrawarra Headland      Surfing          Unknown    M  ...
# 4                            La Ticla  Free diving   Gustavo Ramos     M  ...
# ...                               ...          ...              ...  ...  ...
# 6307                          Unknown      Unknown          Unknown   ND  ...
# 6308                          Unknown      Unknown          Unknown   ND  ...
# 6309                          Unknown      Unknown          Unknown   ND  ...
# 8702                          Unknown      Unknown          Unknown   ND  ...
# 25722                         Unknown      Unknown          Unknown   ND  ...
#
#                 Time          Investigator or Source original order  \
# 0              18h00                R. Collier, GSAF         6303.0
# 1      14h00  -15h00  K.McMurray, TrackingSharks.com         6302.0
# 2              07h45  K.McMurray, TrackingSharks.com         6301.0
# 3                NaN                  B. Myatt, GSAF         6300.0
# 4                NaN                       A .Kipper         6299.0
# ...              ...                             ...            ...
# 6307             NaN                         Unknown         6309.0
# 6308             NaN                         Unknown         6310.0
# 6309             NaN                         Unknown            NaN
# 8702             NaN                         Unknown            NaN
# 25722            NaN                         Unknown            NaN
#
#       Case Number.1 Case Number.2                       pdf  \
# 0        2018.06.25    2018.06.25      2018.06.25-Wolfe.pdf
# 1        2018.06.18    2018.06.18    2018.06.18-McNeely.pdf
# 2        2018.06.09    2018.06.09     2018.06.09-Denges.pdf
# 3        2018.06.08    2018.06.08  2018.06.08-Arrawarra.pdf
# 4        2018.06.04    2018.06.04      2018.06.04-Ramos.pdf
# ...             ...           ...                       ...
# 6307            NaN           NaN                       NaN
# 6308            NaN           NaN                       NaN
# 6309            NaN           NaN                       NaN
# 8702            NaN           NaN                       NaN
# 25722           NaN           NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 6307                                                 NaN
# 6308                                                 NaN
# 6309                                                 NaN
# 8702                                                 NaN
# 25722                                                NaN
#
#                                                     href Unnamed: 22  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                  ...         ...
# 6307                                                 NaN         NaN
# 6308                                                 NaN         NaN
# 6309                                                 NaN         NaN
# 8702                                                 NaN         NaN
# 25722                                                NaN         NaN
#
#       Unnamed: 23
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 6307          NaN
# 6308          NaN
# 6309          NaN
# 8702          NaN
# 25722         NaN
#
# [6312 rows x 24 columns]

# %% [markdown]
# # limpieza original order

# %%
shark_clean['original order'] =shark_clean['original order'].fillna('6000')
shark_clean
# Out:
#       Case Number         Date  Year        Type    Country             Area  \
# 0      2018.06.25  25-Jun-2018  2018     Boating        USA       California
# 1      2018.06.18  18-Jun-2018  2018  Unprovoked        USA          Georgia
# 2      2018.06.09  09-Jun-2018  2018     Unknown        USA           Hawaii
# 3      2018.06.08  08-Jun-2018  2018  Unprovoked  AUSTRALIA  New South Wales
# 4      2018.06.04  04-Jun-2018  2018    Provoked     MEXICO           Colima
# ...           ...          ...   ...         ...        ...              ...
# 6307            0   01-01-2000  2000     Unknown    Unknown          Unknown
# 6308            0   01-01-2000  2000     Unknown    Unknown          Unknown
# 6309            0   01-01-2000  2000     Unknown    Unknown          Unknown
# 8702   2010.01.01   01-01-2000  2000     Unknown    Unknown          Unknown
# 25722          xx   01-01-2000  2000     Unknown    Unknown          Unknown
#
#                              Location     Activity             Name Sex   ...  \
# 0         Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1      St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                        Habush, Oahu      Surfing      John Denges    M  ...
# 3                  Arrawarra Headland      Surfing          Unknown    M  ...
# 4                            La Ticla  Free diving   Gustavo Ramos     M  ...
# ...                               ...          ...              ...  ...  ...
# 6307                          Unknown      Unknown          Unknown   ND  ...
# 6308                          Unknown      Unknown          Unknown   ND  ...
# 6309                          Unknown      Unknown          Unknown   ND  ...
# 8702                          Unknown      Unknown          Unknown   ND  ...
# 25722                         Unknown      Unknown          Unknown   ND  ...
#
#                 Time          Investigator or Source original order  \
# 0              18h00                R. Collier, GSAF           6303
# 1      14h00  -15h00  K.McMurray, TrackingSharks.com           6302
# 2              07h45  K.McMurray, TrackingSharks.com           6301
# 3                NaN                  B. Myatt, GSAF           6300
# 4                NaN                       A .Kipper           6299
# ...              ...                             ...            ...
# 6307             NaN                         Unknown           6309
# 6308             NaN                         Unknown           6310
# 6309             NaN                         Unknown           6000
# 8702             NaN                         Unknown           6000
# 25722            NaN                         Unknown           6000
#
#       Case Number.1 Case Number.2                       pdf  \
# 0        2018.06.25    2018.06.25      2018.06.25-Wolfe.pdf
# 1        2018.06.18    2018.06.18    2018.06.18-McNeely.pdf
# 2        2018.06.09    2018.06.09     2018.06.09-Denges.pdf
# 3        2018.06.08    2018.06.08  2018.06.08-Arrawarra.pdf
# 4        2018.06.04    2018.06.04      2018.06.04-Ramos.pdf
# ...             ...           ...                       ...
# 6307            NaN           NaN                       NaN
# 6308            NaN           NaN                       NaN
# 6309            NaN           NaN                       NaN
# 8702            NaN           NaN                       NaN
# 25722           NaN           NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 6307                                                 NaN
# 6308                                                 NaN
# 6309                                                 NaN
# 8702                                                 NaN
# 25722                                                NaN
#
#                                                     href Unnamed: 22  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                  ...         ...
# 6307                                                 NaN         NaN
# 6308                                                 NaN         NaN
# 6309                                                 NaN         NaN
# 8702                                                 NaN         NaN
# 25722                                                NaN         NaN
#
#       Unnamed: 23
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 6307          NaN
# 6308          NaN
# 6309          NaN
# 8702          NaN
# 25722         NaN
#
# [6312 rows x 24 columns]

# %% [markdown]
# # limpieza case number.1

# %%
shark_clean['Case Number.1']= shark_clean['Case Number.1'].fillna('2010.01.01')
shark_clean
# Out:
#       Case Number         Date  Year        Type    Country             Area  \
# 0      2018.06.25  25-Jun-2018  2018     Boating        USA       California
# 1      2018.06.18  18-Jun-2018  2018  Unprovoked        USA          Georgia
# 2      2018.06.09  09-Jun-2018  2018     Unknown        USA           Hawaii
# 3      2018.06.08  08-Jun-2018  2018  Unprovoked  AUSTRALIA  New South Wales
# 4      2018.06.04  04-Jun-2018  2018    Provoked     MEXICO           Colima
# ...           ...          ...   ...         ...        ...              ...
# 6307            0   01-01-2000  2000     Unknown    Unknown          Unknown
# 6308            0   01-01-2000  2000     Unknown    Unknown          Unknown
# 6309            0   01-01-2000  2000     Unknown    Unknown          Unknown
# 8702   2010.01.01   01-01-2000  2000     Unknown    Unknown          Unknown
# 25722          xx   01-01-2000  2000     Unknown    Unknown          Unknown
#
#                              Location     Activity             Name Sex   ...  \
# 0         Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1      St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                        Habush, Oahu      Surfing      John Denges    M  ...
# 3                  Arrawarra Headland      Surfing          Unknown    M  ...
# 4                            La Ticla  Free diving   Gustavo Ramos     M  ...
# ...                               ...          ...              ...  ...  ...
# 6307                          Unknown      Unknown          Unknown   ND  ...
# 6308                          Unknown      Unknown          Unknown   ND  ...
# 6309                          Unknown      Unknown          Unknown   ND  ...
# 8702                          Unknown      Unknown          Unknown   ND  ...
# 25722                         Unknown      Unknown          Unknown   ND  ...
#
#                 Time          Investigator or Source original order  \
# 0              18h00                R. Collier, GSAF           6303
# 1      14h00  -15h00  K.McMurray, TrackingSharks.com           6302
# 2              07h45  K.McMurray, TrackingSharks.com           6301
# 3                NaN                  B. Myatt, GSAF           6300
# 4                NaN                       A .Kipper           6299
# ...              ...                             ...            ...
# 6307             NaN                         Unknown           6309
# 6308             NaN                         Unknown           6310
# 6309             NaN                         Unknown           6000
# 8702             NaN                         Unknown           6000
# 25722            NaN                         Unknown           6000
#
#       Case Number.1 Case Number.2                       pdf  \
# 0        2018.06.25    2018.06.25      2018.06.25-Wolfe.pdf
# 1        2018.06.18    2018.06.18    2018.06.18-McNeely.pdf
# 2        2018.06.09    2018.06.09     2018.06.09-Denges.pdf
# 3        2018.06.08    2018.06.08  2018.06.08-Arrawarra.pdf
# 4        2018.06.04    2018.06.04      2018.06.04-Ramos.pdf
# ...             ...           ...                       ...
# 6307     2010.01.01           NaN                       NaN
# 6308     2010.01.01           NaN                       NaN
# 6309     2010.01.01           NaN                       NaN
# 8702     2010.01.01           NaN                       NaN
# 25722    2010.01.01           NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 6307                                                 NaN
# 6308                                                 NaN
# 6309                                                 NaN
# 8702                                                 NaN
# 25722                                                NaN
#
#                                                     href Unnamed: 22  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                  ...         ...
# 6307                                                 NaN         NaN
# 6308                                                 NaN         NaN
# 6309                                                 NaN         NaN
# 8702                                                 NaN         NaN
# 25722                                                NaN         NaN
#
#       Unnamed: 23
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 6307          NaN
# 6308          NaN
# 6309          NaN
# 8702          NaN
# 25722         NaN
#
# [6312 rows x 24 columns]

# %% [markdown]
# # limpieza case Number.2

# %%
shark_clean['Case Number.2']=shark_clean['Case Number.2'].fillna('2010.01.01')
shark_clean
# Out:
#       Case Number         Date  Year        Type    Country             Area  \
# 0      2018.06.25  25-Jun-2018  2018     Boating        USA       California
# 1      2018.06.18  18-Jun-2018  2018  Unprovoked        USA          Georgia
# 2      2018.06.09  09-Jun-2018  2018     Unknown        USA           Hawaii
# 3      2018.06.08  08-Jun-2018  2018  Unprovoked  AUSTRALIA  New South Wales
# 4      2018.06.04  04-Jun-2018  2018    Provoked     MEXICO           Colima
# ...           ...          ...   ...         ...        ...              ...
# 6307            0   01-01-2000  2000     Unknown    Unknown          Unknown
# 6308            0   01-01-2000  2000     Unknown    Unknown          Unknown
# 6309            0   01-01-2000  2000     Unknown    Unknown          Unknown
# 8702   2010.01.01   01-01-2000  2000     Unknown    Unknown          Unknown
# 25722          xx   01-01-2000  2000     Unknown    Unknown          Unknown
#
#                              Location     Activity             Name Sex   ...  \
# 0         Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1      St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                        Habush, Oahu      Surfing      John Denges    M  ...
# 3                  Arrawarra Headland      Surfing          Unknown    M  ...
# 4                            La Ticla  Free diving   Gustavo Ramos     M  ...
# ...                               ...          ...              ...  ...  ...
# 6307                          Unknown      Unknown          Unknown   ND  ...
# 6308                          Unknown      Unknown          Unknown   ND  ...
# 6309                          Unknown      Unknown          Unknown   ND  ...
# 8702                          Unknown      Unknown          Unknown   ND  ...
# 25722                         Unknown      Unknown          Unknown   ND  ...
#
#                 Time          Investigator or Source original order  \
# 0              18h00                R. Collier, GSAF           6303
# 1      14h00  -15h00  K.McMurray, TrackingSharks.com           6302
# 2              07h45  K.McMurray, TrackingSharks.com           6301
# 3                NaN                  B. Myatt, GSAF           6300
# 4                NaN                       A .Kipper           6299
# ...              ...                             ...            ...
# 6307             NaN                         Unknown           6309
# 6308             NaN                         Unknown           6310
# 6309             NaN                         Unknown           6000
# 8702             NaN                         Unknown           6000
# 25722            NaN                         Unknown           6000
#
#       Case Number.1 Case Number.2                       pdf  \
# 0        2018.06.25    2018.06.25      2018.06.25-Wolfe.pdf
# 1        2018.06.18    2018.06.18    2018.06.18-McNeely.pdf
# 2        2018.06.09    2018.06.09     2018.06.09-Denges.pdf
# 3        2018.06.08    2018.06.08  2018.06.08-Arrawarra.pdf
# 4        2018.06.04    2018.06.04      2018.06.04-Ramos.pdf
# ...             ...           ...                       ...
# 6307     2010.01.01    2010.01.01                       NaN
# 6308     2010.01.01    2010.01.01                       NaN
# 6309     2010.01.01    2010.01.01                       NaN
# 8702     2010.01.01    2010.01.01                       NaN
# 25722    2010.01.01    2010.01.01                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 6307                                                 NaN
# 6308                                                 NaN
# 6309                                                 NaN
# 8702                                                 NaN
# 25722                                                NaN
#
#                                                     href Unnamed: 22  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                  ...         ...
# 6307                                                 NaN         NaN
# 6308                                                 NaN         NaN
# 6309                                                 NaN         NaN
# 8702                                                 NaN         NaN
# 25722                                                NaN         NaN
#
#       Unnamed: 23
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 6307          NaN
# 6308          NaN
# 6309          NaN
# 8702          NaN
# 25722         NaN
#
# [6312 rows x 24 columns]

# %%
shark_info.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

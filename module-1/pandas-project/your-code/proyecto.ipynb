# %%
import pandas as pd
import re

# %% [markdown]
# # Lectura del archivo csv

# %%
# lee el archivo con un encoding diferente a utf-8 ya que no reconoce ciertos caracteres dentro de el csv
shark = pd.read_csv('attacks.csv',encoding = "ISO-8859-1")
shark_info = pd.DataFrame(shark)

# %%
shark_info
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722         NaN          NaN     NaN         NaN        NaN
# 25723         NaN          NaN     NaN         NaN        NaN
# 25724          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 25720              NaN                             NaN          NaN
# 25721              NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
# 25723              NaN                             NaN          NaN
# 25724              NaN                             NaN          NaN
#
#                   Name Sex   ...         Species   \
# 0          Julie Wolfe    F  ...      White shark
# 1      Adyson McNeely     F  ...              NaN
# 2          John Denges    M  ...              NaN
# 3                 male    M  ...        2 m shark
# 4       Gustavo Ramos     M  ...  Tiger shark, 3m
# ...                ...  ...  ...              ...
# 25720              NaN  NaN  ...              NaN
# 25721              NaN  NaN  ...              NaN
# 25722              NaN  NaN  ...              NaN
# 25723              NaN  NaN  ...              NaN
# 25724              NaN  NaN  ...              NaN
#
#                Investigator or Source                       pdf  \
# 0                    R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1      K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2      K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3                      B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4                           A .Kipper      2018.06.04-Ramos.pdf
# ...                               ...                       ...
# 25720                             NaN                       NaN
# 25721                             NaN                       NaN
# 25722                             NaN                       NaN
# 25723                             NaN                       NaN
# 25724                             NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 25720                                                NaN
# 25721                                                NaN
# 25722                                                NaN
# 25723                                                NaN
# 25724                                                NaN
#
#                                                     href Case Number.1  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                  ...           ...
# 25720                                                NaN           NaN
# 25721                                                NaN           NaN
# 25722                                                NaN           NaN
# 25723                                                NaN           NaN
# 25724                                                NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0        2018.06.25         6303.0         NaN         NaN
# 1        2018.06.18         6302.0         NaN         NaN
# 2        2018.06.09         6301.0         NaN         NaN
# 3        2018.06.08         6300.0         NaN         NaN
# 4        2018.06.04         6299.0         NaN         NaN
# ...             ...            ...         ...         ...
# 25720           NaN            NaN         NaN         NaN
# 25721           NaN            NaN         NaN         NaN
# 25722           NaN            NaN         NaN         NaN
# 25723           NaN            NaN         NaN         NaN
# 25724           NaN            NaN         NaN         NaN
#
# [25725 rows x 24 columns]

# %%
shark_info.shape
# Out:
# (25725, 24)

# %%
shark_info.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %% [markdown]
# # Drop Duplicates

# %%
# elimina todas las filas que contienen valores iguales, que para este caso es nan en todas sus columnas
duplicados = shark_info.drop_duplicates().reset_index()
duplicados.sample(10)
# Out:
#       index   Case Number                        Date    Year        Type  \
# 37       37    2018.03.14                 14-Mar-2018  2018.0  Unprovoked
# 4688   4688  1943.00.00.d                        1943  1943.0  Unprovoked
# 2128   2128    1999.04.01                 01-Apr-1999  1999.0  Unprovoked
# 3036   3036    1981.05.05                 05-May-1981  1981.0  Unprovoked
# 5263   5263  1920.00.00.b                        1920  1920.0  Unprovoked
# 3128   3128    1978.03.05                 05-Mar-1978  1978.0        Boat
# 4241   4241    1956.08.01                  1-Aug-1956  1956.0  Unprovoked
# 1941   1941    2001.06.10                 10-Jun-2001  2001.0    Provoked
# 274     274  2016.05.29.a                 29-May-2016  2016.0  Unprovoked
# 6262   6262       ND.0043  "During the war" 1943-1945     0.0  Unprovoked
#
#               Country                   Area  \
# 37          AUSTRALIA      Western Australia
# 4688             IRAQ                    NaN
# 2128              USA                Florida
# 3036     SOUTH AFRICA  Eastern Cape Province
# 5263      NEW ZEALAND           North Island
# 3128     SOUTH AFRICA  Eastern Cape Province
# 4241     SOUTH AFRICA          KwaZulu-Natal
# 1941              USA             California
# 274               USA                Florida
# 6262  SOLOMON ISLANDS            New Georgia
#
#                                  Location                  Activity  \
# 37                         Waterman's Bay                    Wading
# 4688                         River Tigris                  Swimming
# 2128  Hobe Sound Beach, Palm Beach County                   Surfing
# 3036                        Ntlonyane Bay                   Surfing
# 5263         Stanley Bay, Auckland Harbor                       NaN
# 3128               Gulu Deep, East London                       NaN
# 4241             Chain Rocks, Amanzimtoti  Free diving for crayfish
# 1941                      Catalina Island              Spearfishing
# 274                 Neptune, Duval County                  Swimming
# 6262         Munda Island, Roviana Lagoon      Floating on his back
#
#                                             Name  ...  \
# 37                          Luke Guy & Finn Bald  ...
# 4688                            Syed Khaleeulla   ...
# 2128                                        male  ...
# 3036                             Simon Hammerton  ...
# 5263                                      female  ...
# 3128  6 m skiboat, occupants: P.A. Reeder & crew  ...
# 4241                  Maximilliaan Roual Van Dam  ...
# 1941                                 Bill McNair  ...
# 274                                         male  ...
# 6262                               American male  ...
#
#                                     Species   \
# 37                           Wobbegong shark
# 4688                                     NaN
# 2128                                     NaN
# 3036                 Tiger shark, 2.1 m [7']
# 5263                                     NaN
# 3128                                     NaN
# 4241                                     NaN
# 1941  White shark, 2.4 m to 3 m [8' to 10']
# 274                                 5' shark
# 6262                                     NaN
#
#                                  Investigator or Source  \
# 37                                       B. Myatt, GSAF
# 4688                          Times of India, 8/19/2001
# 2128                          Palm Beach Post, 4/1/1999
# 3036  S. Hammerton, M. Levine, GSAF; W. Pople,  G. C...
# 5263                       V.M. Coppleson (1958), p.262
# 3128                                               GSAF
# 4241             Umtali Post, 8/8/1956, M. Levine, GSAF
# 1941                                   R. Collier, GSAF
# 274                                 News4Jax, 5/29/2016
# 6262  W. Chapman (1949) Fishing in Troubled Waters, ...
#
#                                  pdf  \
# 37       2018.03.14-WatermansBay.pdf
# 4688      1943.00.00.d-Khaleeula.pdf
# 2128  1999.04.01-HobeSoundSurfer.pdf
# 3036        1981.05.05-Hammerton.pdf
# 5263     1920.00.00.b-StanleyBay.pdf
# 3128         1978.03.05-GuluDeep.pdf
# 4241           1956.08.01-VanDam.pdf
# 1941           2001.06.10-McNair.pdf
# 274         2016.05.29.a-Neptune.pdf
# 6262       ND-0043-American-male.pdf
#
#                                            href formula  \
# 37    http://sharkattackfile.net/spreadsheets/pdf_di...
# 4688  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2128  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3036  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5263  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3128  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4241  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1941  http://sharkattackfile.net/spreadsheets/pdf_di...
# 274   http://sharkattackfile.net/spreadsheets/pdf_di...
# 6262  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 37    http://sharkattackfile.net/spreadsheets/pdf_di...    2018.03.14
# 4688  http://sharkattackfile.net/spreadsheets/pdf_di...  1943.00.00.d
# 2128  http://sharkattackfile.net/spreadsheets/pdf_di...    1999.04.01
# 3036  http://sharkattackfile.net/spreadsheets/pdf_di...    1981.05.05
# 5263  http://sharkattackfile.net/spreadsheets/pdf_di...  1920.00.00.b
# 3128  http://sharkattackfile.net/spreadsheets/pdf_di...    1978.03.05
# 4241  http://sharkattackfile.net/spreadsheets/pdf_di...    1956.08.01
# 1941  http://sharkattackfile.net/spreadsheets/pdf_di...    2001.06.10
# 274   http://sharkattackfile.net/spreadsheets/pdf_di...  2016.05.29.a
# 6262  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0043
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23
# 37      2018.03.14         6267.0         NaN         NaN
# 4688  1943.00.00.d         1617.0         NaN         NaN
# 2128    1999.04.01         4176.0         NaN         NaN
# 3036    1981.05.05         3269.0         NaN         NaN
# 5263  1920.00.00.b         1042.0         NaN         NaN
# 3128    1978.03.05         3177.0         NaN         NaN
# 4241    1956.08.01         2064.0         NaN         NaN
# 1941    2001.06.10         4363.0         NaN         NaN
# 274   2016.05.29.a         6030.0         NaN         NaN
# 6262       ND.0043           43.0         NaN         NaN
#
# [10 rows x 25 columns]

# %% [markdown]
# # comparacion original vs drop duplicates

# %%
print('tamaño de las filas en el archivo originial',shark_info.shape)
print('tamaño de las filas en el archivo que elimina valores duplicados',duplicados.shape)
# Out:
# tamaño de las filas en el archivo originial (25725, 24)
# tamaño de las filas en el archivo que elimina valores duplicados (6314, 25)

# %%
# reorganizacion de las columnas de la mas importante a menos importante 
cols = ['Case Number', 'Date', 'Year','Type','Country', 'Area','Location',
       'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)','Species ', 'Time','Investigator or Source',
       'original order','Case Number.1', 'Case Number.2','pdf', 'href formula', 'href','Unnamed: 22','Unnamed: 23']
shark_clean = pd.DataFrame(duplicados, columns=cols)
shark_clean = shark_clean
shark_clean
# Out:
#      Case Number         Date    Year        Type    Country             Area  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
# ...          ...          ...     ...         ...        ...              ...
# 6309           0          NaN     NaN         NaN        NaN              NaN
# 6310           0          NaN     NaN         NaN        NaN              NaN
# 6311           0          NaN     NaN         NaN        NaN              NaN
# 6312         NaN          NaN     NaN         NaN        NaN              NaN
# 6313          xx          NaN     NaN         NaN        NaN              NaN
#
#                             Location     Activity             Name Sex   ...  \
# 0        Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1     St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                       Habush, Oahu      Surfing      John Denges    M  ...
# 3                 Arrawarra Headland      Surfing             male    M  ...
# 4                           La Ticla  Free diving   Gustavo Ramos     M  ...
# ...                              ...          ...              ...  ...  ...
# 6309                             NaN          NaN              NaN  NaN  ...
# 6310                             NaN          NaN              NaN  NaN  ...
# 6311                             NaN          NaN              NaN  NaN  ...
# 6312                             NaN          NaN              NaN  NaN  ...
# 6313                             NaN          NaN              NaN  NaN  ...
#
#                Time          Investigator or Source original order  \
# 0             18h00                R. Collier, GSAF         6303.0
# 1     14h00  -15h00  K.McMurray, TrackingSharks.com         6302.0
# 2             07h45  K.McMurray, TrackingSharks.com         6301.0
# 3               NaN                  B. Myatt, GSAF         6300.0
# 4               NaN                       A .Kipper         6299.0
# ...             ...                             ...            ...
# 6309            NaN                             NaN         6309.0
# 6310            NaN                             NaN         6310.0
# 6311            NaN                             NaN            NaN
# 6312            NaN                             NaN            NaN
# 6313            NaN                             NaN            NaN
#
#      Case Number.1 Case Number.2                       pdf  \
# 0       2018.06.25    2018.06.25      2018.06.25-Wolfe.pdf
# 1       2018.06.18    2018.06.18    2018.06.18-McNeely.pdf
# 2       2018.06.09    2018.06.09     2018.06.09-Denges.pdf
# 3       2018.06.08    2018.06.08  2018.06.08-Arrawarra.pdf
# 4       2018.06.04    2018.06.04      2018.06.04-Ramos.pdf
# ...            ...           ...                       ...
# 6309           NaN           NaN                       NaN
# 6310           NaN           NaN                       NaN
# 6311           NaN           NaN                       NaN
# 6312           NaN           NaN                       NaN
# 6313           NaN           NaN                       NaN
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6309                                                NaN
# 6310                                                NaN
# 6311                                                NaN
# 6312                                                NaN
# 6313                                                NaN
#
#                                                    href Unnamed: 22  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                 ...         ...
# 6309                                                NaN         NaN
# 6310                                                NaN         NaN
# 6311                                                NaN         NaN
# 6312                                                NaN         NaN
# 6313                                                NaN         NaN
#
#      Unnamed: 23
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 6309         NaN
# 6310         NaN
# 6311         NaN
# 6312         NaN
# 6313         NaN
#
# [6314 rows x 24 columns]

# %% [markdown]
# # primera columna 'Case Number'

# %%
# limpiando primera columna de tabla
shark_clean['Case Number'] = shark_clean['Case Number'].str.replace('\.[a-z]+|\.[A-Z]+','', regex=True).fillna('2010.01.01')
shark_clean.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                       float64
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Species                    object
# Time                       object
# Investigator or Source     object
# original order            float64
# Case Number.1              object
# Case Number.2              object
# pdf                        object
# href formula               object
# href                       object
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %%
shark_clean['Case Number'] = shark_clean['Case Number'].str.replace('xx','2010.01.01')
shark_clean
# Out:
#      Case Number         Date    Year        Type    Country             Area  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
# ...          ...          ...     ...         ...        ...              ...
# 6309           0          NaN     NaN         NaN        NaN              NaN
# 6310           0          NaN     NaN         NaN        NaN              NaN
# 6311           0          NaN     NaN         NaN        NaN              NaN
# 6312  2010.01.01          NaN     NaN         NaN        NaN              NaN
# 6313  2010.01.01          NaN     NaN         NaN        NaN              NaN
#
#                             Location     Activity             Name  Sex  ...  \
# 0        Oceanside, San Diego County     Paddling      Julie Wolfe  NaN  ...
# 1     St. Simon Island, Glynn County     Standing  Adyson McNeely   NaN  ...
# 2                       Habush, Oahu      Surfing      John Denges  NaN  ...
# 3                 Arrawarra Headland      Surfing             male  NaN  ...
# 4                           La Ticla  Free diving   Gustavo Ramos   NaN  ...
# ...                              ...          ...              ...  ...  ...
# 6309                             NaN          NaN              NaN  NaN  ...
# 6310                             NaN          NaN              NaN  NaN  ...
# 6311                             NaN          NaN              NaN  NaN  ...
# 6312                             NaN          NaN              NaN  NaN  ...
# 6313                             NaN          NaN              NaN  NaN  ...
#
#                Time          Investigator or Source original order  \
# 0             18h00                R. Collier, GSAF         6303.0
# 1     14h00  -15h00  K.McMurray, TrackingSharks.com         6302.0
# 2             07h45  K.McMurray, TrackingSharks.com         6301.0
# 3               NaN                  B. Myatt, GSAF         6300.0
# 4               NaN                       A .Kipper         6299.0
# ...             ...                             ...            ...
# 6309            NaN                             NaN         6309.0
# 6310            NaN                             NaN         6310.0
# 6311            NaN                             NaN            NaN
# 6312            NaN                             NaN            NaN
# 6313            NaN                             NaN            NaN
#
#      Case Number.1 Case Number.2                       pdf  \
# 0       2018.06.25    2018.06.25      2018.06.25-Wolfe.pdf
# 1       2018.06.18    2018.06.18    2018.06.18-McNeely.pdf
# 2       2018.06.09    2018.06.09     2018.06.09-Denges.pdf
# 3       2018.06.08    2018.06.08  2018.06.08-Arrawarra.pdf
# 4       2018.06.04    2018.06.04      2018.06.04-Ramos.pdf
# ...            ...           ...                       ...
# 6309           NaN           NaN                       NaN
# 6310           NaN           NaN                       NaN
# 6311           NaN           NaN                       NaN
# 6312           NaN           NaN                       NaN
# 6313           NaN           NaN                       NaN
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6309                                                NaN
# 6310                                                NaN
# 6311                                                NaN
# 6312                                                NaN
# 6313                                                NaN
#
#                                                    href Unnamed: 22  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                 ...         ...
# 6309                                                NaN         NaN
# 6310                                                NaN         NaN
# 6311                                                NaN         NaN
# 6312                                                NaN         NaN
# 6313                                                NaN         NaN
#
#      Unnamed: 23
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 6309         NaN
# 6310         NaN
# 6311         NaN
# 6312         NaN
# 6313         NaN
#
# [6314 rows x 24 columns]

# %% [markdown]
# # limpieza de las fechas date

# %%
shark_clean['Date'] = shark_clean['Date'].str.replace('Reported| Early| Late|\.[a-z]|\.[A-Z]|Between May &' ,'').fillna('01-01-2000')
shark_clean.sample(20)
# Out:
#      Case Number                                               Date    Year  \
# 5650  1894.11.28                                        28-Nov-1894  1894.0
# 40    2018.02.24                                        24-Feb-2018  2018.0
# 3701  1964.02.05                                        05-Feb-1964  1964.0
# 1573  2005.07.01                                         1-Jul-2005  2005.0
# 3729  1963.11.30                                        30-Nov-1963  1963.0
# 2749  1988.02.15                                        15-Feb-1988  1988.0
# 6226     ND.0089                           No date, Before Aug-1987     0.0
# 4224  1956.12.26                                        26-Dec-1956  1956.0
# 6142  1784.12.12                                        12-Dec-1784  1784.0
# 386   2015.07.25                                        25-Jul-2015  2015.0
# 518   2014.08.09                                        09-Aug-2014  2014.0
# 5601  1898.00.00  1898 (soon after the close of the Spanish-Amer...  1898.0
# 2536  1992.09.11                                        11-Sep-1992  1992.0
# 5344  1914.03.10                                        10-Mar-1914  1914.0
# 2136  1999.02.26                                        26-Feb-1999  1999.0
# 5495  1905.07.25                                        25-Jul-1905  1905.0
# 19    2018.04.28                                        28-Apr-2018  2018.0
# 3290  1973.12.18                                        18-Dec-1973  1973.0
# 5415  1909.11.14                         14-Nov-1909 to 19-Nov-1909  1909.0
# 2071  2000.03.00                                           Mar-2000  2000.0
#
#               Type           Country                       Area  \
# 5650    Unprovoked         AUSTRALIA            New South Wales
# 40      Unprovoked      SOUTH AFRICA              KwaZulu-Natal
# 3701    Unprovoked       NEW ZEALAND               South Island
# 1573    Unprovoked               USA                    Florida
# 3729      Provoked  PAPUA NEW GUINEA              Gulf Province
# 2749          Boat      SOUTH AFRICA              KwaZulu-Natal
# 6226      Provoked           VANUATU           Malampa Province
# 4224    Unprovoked  PAPUA NEW GUINEA         Milne Bay Province
# 6142    Unprovoked           JAMAICA                        NaN
# 386     Unprovoked         AUSTRALIA                   Tasmania
# 518     Unprovoked           BAHAMAS                        NaN
# 5601    Unprovoked              CUBA  Santiago de Cuba Province
# 2536    Unprovoked               USA                    Florida
# 5344  Sea Disaster            GUYANA                  Essequibo
# 2136       Boating               USA             North Carolina
# 5495       Invalid             ITALY                        NaN
# 19      Unprovoked        COSTA RICA               Cocos Island
# 3290    Unprovoked               USA                     Hawaii
# 5415  Sea Disaster         INDONESIA       30 nm from Singapore
# 2071    Unprovoked               USA                  Louisiana
#
#                                                Location  \
# 5650                                         Newcastle
# 40                                               Durban
# 3701                           St. Clair Beach, Dunedin
# 1573                            Boca Grande, Lee County
# 3729  Kukipi, 150 miles west of Port Moresby in the ...
# 2749                             Brighton Beach, Durban
# 6226                                    Hokai, Malakula
# 4224                         Samarai Island (south end)
# 6142                                           Kingston
# 386                      Lachan Island, Mercury Passage
# 518                                                 NaN
# 5601                               Off Santiago de Cuba
# 2536      South Jetty, New Smyrna Beach, Volusia County
# 5344                              Essequibo River Mouth
# 2136                                  Frying Pan Shoals
# 5495                                             Naples
# 19                                            Manuelita
# 3290                          Kalama Beach, Kihei, Maui
# 5415                                        Rhio Strait
# 2071                  Midnight Lump (38 miles offshore)
#
#                                                Activity  \
# 5650                                            Bathing
# 40                                         Scuba Diving
# 3701                                           Swimming
# 1573                                           Standing
# 3729             Fishing / standing in waist deep water
# 2749                                                NaN
# 6226                Attempting to drive shark from area
# 4224                                       Spearfishing
# 6142                                           Swimming
# 386                            Scallop diving on hookah
# 518                                        Spearfishing
# 5601  13 men in the water after sailboat capsized & ...
# 2536                                           Standing
# 5344                                       Boat swamped
# 2136                                           Cruising
# 5495                                                NaN
# 19                                         Scuba diving
# 3290                                           Swimming
# 5415  The 2379-ton French steamer La Seyne collied w...
# 2071                                       Spearfishing
#
#                                                    Name  Sex  ...     Time  \
# 5650                                     Horace Hewison  NaN  ...  Morning
# 40                                          Elton Polly  NaN  ...      NaN
# 3701                              Leslie Francis Jordan  NaN  ...    06h45
# 1573                                       Armin Trojer  NaN  ...    11h30
# 3729                                 Siara Ikui, female  NaN  ...    14h00
# 2749  Semi-rigid rescue  boat: occupants, Edward Moo...  NaN  ...      NaN
# 6226                                            a chief  NaN  ...      NaN
# 4224                          Patterson (John) Nikuniko  NaN  ...    13h00
# 6142                                       Richard Page  NaN  ...    22h00
# 386                                      Damien Johnson  NaN  ...    10h00
# 518                                      Andrew Hindley  NaN  ...      NaN
# 5601                                             seamen  NaN  ...      NaN
# 2536                                    Tracie Langbein  NaN  ...    15h00
# 5344                                    Harold F. Brook  NaN  ...      NaN
# 2136                   28' sport fishing boat, Bird Dog  NaN  ...      NaN
# 5495                                                boy  NaN  ...      NaN
# 19                                                 male  NaN  ...    10h40
# 3290                                      Gary W. Floyd  NaN  ...      NaN
# 5415                                                NaN  NaN  ...      NaN
# 2071                                        Kurt Bickel  NaN  ...    16h00
#
#                                  Investigator or Source original order  \
# 5650                    Brisbane Courier, 1/7/1895, p.5          655.0
# 40               International Business Times, 3/1/2018         6264.0
# 3701  R.D. Weeks, GSAF; Otago Daily Times, 2/6/1964 ...         2604.0
# 1573                                    E. Ritter, GSAF         4731.0
# 3729           M. Malin; The Sun (Melbourne), 12/2/1963         2576.0
http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
#
#      Unnamed: 23
# 5650         NaN
# 40           NaN
# 3701         NaN
# 1573         NaN
# 3729         NaN
# 2749         NaN
# 6226         NaN
# 4224         NaN
# 6142         NaN
# 386          NaN
# 518          NaN
# 5601         NaN
# 2536         NaN
# 5344         NaN
# 2136         NaN
# 5495         NaN
# 19           NaN
# 3290         NaN
# 5415         NaN
# 2071         NaN
#
# [20 rows x 24 columns]

# %%
shark_clean['Date'] = pd.to_datetime(shark_clean['Date'], errors='coerce', infer_datetime_format=True)
shark_clean.dtypes
# Out:
# Case Number                       object
# Date                      datetime64[ns]
# Year                             float64
# Type                              object
# Country                           object
# Area                              object
# Location                          object
# Activity                          object
# Name                              object
# Sex                              float64
# Age                               object
# Injury                            object
# Fatal (Y/N)                       object
# Species                           object
# Time                              object
# Investigator or Source            object
# original order                   float64
# Case Number.1                     object
# Case Number.2                     object
# pdf                               object
# href formula                      object
# href                              object
# Unnamed: 22                       object
# Unnamed: 23                       object
# dtype: object

# %%
shark_clean.head()
# Out:
#   Case Number       Date    Year        Type    Country             Area  \
# 0  2018.06.25 2018-06-25  2018.0     Boating        USA       California
# 1  2018.06.18 2018-06-18  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09 2018-06-09  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08 2018-06-08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04 2018-06-04  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name  Sex  ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe  NaN  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely   NaN  ...
# 2                    Habush, Oahu      Surfing      John Denges  NaN  ...
# 3              Arrawarra Headland      Surfing             male  NaN  ...
# 4                        La Ticla  Free diving   Gustavo Ramos   NaN  ...
#
#             Time          Investigator or Source original order Case Number.1  \
# 0          18h00                R. Collier, GSAF         6303.0    2018.06.25
# 1  14h00  -15h00  K.McMurray, TrackingSharks.com         6302.0    2018.06.18
# 2          07h45  K.McMurray, TrackingSharks.com         6301.0    2018.06.09
# 3            NaN                  B. Myatt, GSAF         6300.0    2018.06.08
# 4            NaN                       A .Kipper         6299.0    2018.06.04
#
#   Case Number.2                       pdf  \
# 0    2018.06.25      2018.06.25-Wolfe.pdf
# 1    2018.06.18    2018.06.18-McNeely.pdf
# 2    2018.06.09     2018.06.09-Denges.pdf
# 3    2018.06.08  2018.06.08-Arrawarra.pdf
# 4    2018.06.04      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Unnamed: 22 Unnamed: 23
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# # limpieza de year

# %%
'''
convierte los valores de años a str
'''
shark_clean['Year']=shark_clean['Year'].fillna(shark_clean['Year'].mean())
shark_clean.head(10)
# Out:
#   Case Number       Date         Year                     Type    Country  \
# 0  2018.06.25 2018-06-25  2018.000000                  Boating        USA
# 1  2018.06.18 2018-06-18  2018.000000               Unprovoked        USA
# 2  2018.06.09 2018-06-09  2018.000000                  Invalid        USA
# 3  2018.06.08 2018-06-08  2018.000000               Unprovoked  AUSTRALIA
# 4  2018.06.04 2018-06-04  2018.000000                 Provoked     MEXICO
# 5  2018.06.03 2018-06-03  2018.000000               Unprovoked  AUSTRALIA
# 6  2010.01.01        NaT  1926.970957  No injury, board bitten          N
# 7  2018.06.03 2018-06-03  2018.000000               Unprovoked     BRAZIL
# 8  2018.05.27 2018-05-27  2018.000000               Unprovoked        USA
# 9  2018.05.26 2018-05-26  2018.000000               Unprovoked        USA
#
#               Area                                           Location  \
# 0       California                        Oceanside, San Diego County
# 1          Georgia                     St. Simon Island, Glynn County
# 2           Hawaii                                       Habush, Oahu
# 3  New South Wales                                 Arrawarra Headland
# 4           Colima                                           La Ticla
# 5  New South Wales                                 Flat Rock, Ballina
# 6              NaN                                                NaN
# 7       Pernambuco                              Piedade Beach, Recife
# 8          Florida  Lighhouse Point Park, Ponce Inlet, Volusia County
# 9          Florida                       Cocoa Beach, Brevard  County
#
#                     Activity                       Name  Sex  ...  \
# 0                   Paddling                Julie Wolfe  NaN  ...
# 1                   Standing            Adyson McNeely   NaN  ...
# 2                    Surfing                John Denges  NaN  ...
# 3                    Surfing                       male  NaN  ...
# 4                Free diving             Gustavo Ramos   NaN  ...
# 5               Kite surfing                     Chris   NaN  ...
# 6  Daily Telegraph, 6/4/2018  2018.06.03.b-FlatRock.pdf  NaN  ...
# 7                   Swimming     Jose Ernesto da Silva   NaN  ...
# 8                    Fishing                       male  NaN  ...
# 9                    Walking                  Cody High  NaN  ...
#
#              Time           Investigator or Source original order  \
# 0           18h00                 R. Collier, GSAF         6303.0
# 1   14h00  -15h00   K.McMurray, TrackingSharks.com         6302.0
# 2           07h45   K.McMurray, TrackingSharks.com         6301.0
# 3             NaN                   B. Myatt, GSAF         6300.0
# 4             NaN                        A .Kipper         6299.0
# 5             NaN                              NaN            NaN
# 6            6298                              NaN            NaN
# 7  Late afternoon   Diario de Pernambuco, 6/4/2018         6297.0
# 8             NaN  K. McMurray, TrackingSharks.com         6296.0
# 9           17h00   K.McMurray, TrackingSharks.com         6295.0
#
#   Case Number.1 Case Number.2                       pdf  \
# 0    2018.06.25    2018.06.25      2018.06.25-Wolfe.pdf
# 1    2018.06.18    2018.06.18    2018.06.18-McNeely.pdf
# 2    2018.06.09    2018.06.09     2018.06.09-Denges.pdf
# 3    2018.06.08    2018.06.08  2018.06.08-Arrawarra.pdf
# 4    2018.06.04    2018.06.04      2018.06.04-Ramos.pdf
# 5           NaN           NaN                       NaN
# 6           NaN           NaN                       NaN
# 7  2018.06.03.a  2018.06.03.a  2018.06.03.a-daSilva.pdf
# 8    2018.05.27    2018.05.27      2018.05.27-Ponce.pdf
# 9  2018.05.26.b  2018.05.26.b     2018.05.26.b-High.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5                                                NaN
# 6                                                NaN
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Unnamed: 22 Unnamed: 23
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 5                                                NaN         NaN         NaN
# 6                                                NaN         NaN         NaN
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
#
# [10 rows x 24 columns]

# %%
shark_clean['Year']= shark_clean['Year'].astype({'Year':'str'})
shark_clean.head(10)
# Out:
#   Case Number       Date                Year                     Type  \
# 0  2018.06.25 2018-06-25              2018.0                  Boating
# 1  2018.06.18 2018-06-18              2018.0               Unprovoked
# 2  2018.06.09 2018-06-09              2018.0                  Invalid
# 3  2018.06.08 2018-06-08              2018.0               Unprovoked
# 4  2018.06.04 2018-06-04              2018.0                 Provoked
# 5  2018.06.03 2018-06-03              2018.0               Unprovoked
# 6  2010.01.01        NaT  1926.9709569909537  No injury, board bitten
# 7  2018.06.03 2018-06-03              2018.0               Unprovoked
# 8  2018.05.27 2018-05-27              2018.0               Unprovoked
# 9  2018.05.26 2018-05-26              2018.0               Unprovoked
#
#      Country             Area  \
# 0        USA       California
# 1        USA          Georgia
# 2        USA           Hawaii
# 3  AUSTRALIA  New South Wales
# 4     MEXICO           Colima
# 5  AUSTRALIA  New South Wales
# 6          N              NaN
# 7     BRAZIL       Pernambuco
# 8        USA          Florida
# 9        USA          Florida
#
#                                             Location  \
# 0                        Oceanside, San Diego County
# 1                     St. Simon Island, Glynn County
# 2                                       Habush, Oahu
# 3                                 Arrawarra Headland
# 4                                           La Ticla
# 5                                 Flat Rock, Ballina
# 6                                                NaN
# 7                              Piedade Beach, Recife
# 8  Lighhouse Point Park, Ponce Inlet, Volusia County
# 9                       Cocoa Beach, Brevard  County
#
#                     Activity                       Name  Sex  ...  \
# 0                   Paddling                Julie Wolfe  NaN  ...
# 1                   Standing            Adyson McNeely   NaN  ...
# 2                    Surfing                John Denges  NaN  ...
# 3                    Surfing                       male  NaN  ...
# 4                Free diving             Gustavo Ramos   NaN  ...
# 5               Kite surfing                     Chris   NaN  ...
# 6  Daily Telegraph, 6/4/2018  2018.06.03.b-FlatRock.pdf  NaN  ...
# 7                   Swimming     Jose Ernesto da Silva   NaN  ...
# 8                    Fishing                       male  NaN  ...
# 9                    Walking                  Cody High  NaN  ...
#
#              Time           Investigator or Source original order  \
# 0           18h00                 R. Collier, GSAF         6303.0
# 1   14h00  -15h00   K.McMurray, TrackingSharks.com         6302.0
# 2           07h45   K.McMurray, TrackingSharks.com         6301.0
# 3             NaN                   B. Myatt, GSAF         6300.0
# 4             NaN                        A .Kipper         6299.0
# 5             NaN                              NaN            NaN
# 6            6298                              NaN            NaN
# 7  Late afternoon   Diario de Pernambuco, 6/4/2018         6297.0
# 8             NaN  K. McMurray, TrackingSharks.com         6296.0
# 9           17h00   K.McMurray, TrackingSharks.com         6295.0
#
#   Case Number.1 Case Number.2                       pdf  \
# 0    2018.06.25    2018.06.25      2018.06.25-Wolfe.pdf
# 1    2018.06.18    2018.06.18    2018.06.18-McNeely.pdf
# 2    2018.06.09    2018.06.09     2018.06.09-Denges.pdf
# 3    2018.06.08    2018.06.08  2018.06.08-Arrawarra.pdf
# 4    2018.06.04    2018.06.04      2018.06.04-Ramos.pdf
# 5           NaN           NaN                       NaN
# 6           NaN           NaN                       NaN
# 7  2018.06.03.a  2018.06.03.a  2018.06.03.a-daSilva.pdf
# 8    2018.05.27    2018.05.27      2018.05.27-Ponce.pdf
# 9  2018.05.26.b  2018.05.26.b     2018.05.26.b-High.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5                                                NaN
# 6                                                NaN
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Unnamed: 22 Unnamed: 23
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 5                                                NaN         NaN         NaN
# 6                                                NaN         NaN         NaN
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
#
# [10 rows x 24 columns]

# %%
shark_clean['Year'] = shark_clean['Year'].str.replace('\.[0-9]+','',regex=True)
shark_clean.head(10)
# Out:
#   Case Number       Date  Year                     Type    Country  \
# 0  2018.06.25 2018-06-25  2018                  Boating        USA
# 1  2018.06.18 2018-06-18  2018               Unprovoked        USA
# 2  2018.06.09 2018-06-09  2018                  Invalid        USA
# 3  2018.06.08 2018-06-08  2018               Unprovoked  AUSTRALIA
# 4  2018.06.04 2018-06-04  2018                 Provoked     MEXICO
# 5  2018.06.03 2018-06-03  2018               Unprovoked  AUSTRALIA
# 6  2010.01.01        NaT  1926  No injury, board bitten          N
# 7  2018.06.03 2018-06-03  2018               Unprovoked     BRAZIL
# 8  2018.05.27 2018-05-27  2018               Unprovoked        USA
# 9  2018.05.26 2018-05-26  2018               Unprovoked        USA
#
#               Area                                           Location  \
# 0       California                        Oceanside, San Diego County
# 1          Georgia                     St. Simon Island, Glynn County
# 2           Hawaii                                       Habush, Oahu
# 3  New South Wales                                 Arrawarra Headland
# 4           Colima                                           La Ticla
# 5  New South Wales                                 Flat Rock, Ballina
# 6              NaN                                                NaN
# 7       Pernambuco                              Piedade Beach, Recife
# 8          Florida  Lighhouse Point Park, Ponce Inlet, Volusia County
# 9          Florida                       Cocoa Beach, Brevard  County
#
#                     Activity                       Name  Sex  ...  \
# 0                   Paddling                Julie Wolfe  NaN  ...
# 1                   Standing            Adyson McNeely   NaN  ...
# 2                    Surfing                John Denges  NaN  ...
# 3                    Surfing                       male  NaN  ...
# 4                Free diving             Gustavo Ramos   NaN  ...
# 5               Kite surfing                     Chris   NaN  ...
# 6  Daily Telegraph, 6/4/2018  2018.06.03.b-FlatRock.pdf  NaN  ...
# 7                   Swimming     Jose Ernesto da Silva   NaN  ...
# 8                    Fishing                       male  NaN  ...
# 9                    Walking                  Cody High  NaN  ...
#
#              Time           Investigator or Source original order  \
# 0           18h00                 R. Collier, GSAF         6303.0
# 1   14h00  -15h00   K.McMurray, TrackingSharks.com         6302.0
# 2           07h45   K.McMurray, TrackingSharks.com         6301.0
# 3             NaN                   B. Myatt, GSAF         6300.0
# 4             NaN                        A .Kipper         6299.0
# 5             NaN                              NaN            NaN
# 6            6298                              NaN            NaN
# 7  Late afternoon   Diario de Pernambuco, 6/4/2018         6297.0
# 8             NaN  K. McMurray, TrackingSharks.com         6296.0
# 9           17h00   K.McMurray, TrackingSharks.com         6295.0
#
#   Case Number.1 Case Number.2                       pdf  \
# 0    2018.06.25    2018.06.25      2018.06.25-Wolfe.pdf
# 1    2018.06.18    2018.06.18    2018.06.18-McNeely.pdf
# 2    2018.06.09    2018.06.09     2018.06.09-Denges.pdf
# 3    2018.06.08    2018.06.08  2018.06.08-Arrawarra.pdf
# 4    2018.06.04    2018.06.04      2018.06.04-Ramos.pdf
# 5           NaN           NaN                       NaN
# 6           NaN           NaN                       NaN
# 7  2018.06.03.a  2018.06.03.a  2018.06.03.a-daSilva.pdf
# 8    2018.05.27    2018.05.27      2018.05.27-Ponce.pdf
# 9  2018.05.26.b  2018.05.26.b     2018.05.26.b-High.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5                                                NaN
# 6                                                NaN
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Unnamed: 22 Unnamed: 23
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 5                                                NaN         NaN         NaN
# 6                                                NaN         NaN         NaN
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
#
# [10 rows x 24 columns]

# %%
shark_clean['Year'] = shark_clean['Year'].apply(pd.to_numeric)
shark_clean.sample(10)
# Out:
#      Case Number       Date  Year        Type           Country  \
# 604   2013.11.07 2013-11-07  2013  Unprovoked               USA
# 843   2011.11.28 2011-11-28  2011  Unprovoked         AUSTRALIA
# 6216     ND.0104        NaT     0  Unprovoked         AUSTRALIA
# 1747  2003.09.13 2003-09-13  2003  Unprovoked               USA
# 6082  1836.07.26        NaT  1836     Invalid             SPAIN
# 168   2017.03.27 2017-03-27  2017  Unprovoked               USA
# 1762  2003.07.00        NaT  2003  Unprovoked  FRENCH POLYNESIA
# 5915  1870.06.01 1870-06-01  1870  Unprovoked             INDIA
# 3962  1960.10.00        NaT  1960     Invalid   JOHNSTON ISLAND
# 5466  1906.11.16 1906-11-16  1906  Unprovoked           JAMAICA
#
#                      Area                          Location  \
# 604            New Jersey            Bay Head, Ocean County
# 843            Queensland                          Peregian
# 6216        Torres Strait                               NaN
# 1747       South Carolina  Isle of Palms, Charleston County
# 6082                  NaN                               NaN
# 168               Florida  New Smyrna Beach, Volusia County
# 1762      Society Islands                            Moorea
# 5915          West Bengal            Hoogly River, Calcutta
# 3962                  NaN                               NaN
# 5466  Westmoreland Parish             Cabaritta River mouth
#
#                                          Activity                    Name  \
# 604                                 Body boarding             Quinn Gates
# 843                                      Swimming              Eamon Kriz
# 6216                                Helmet diving                    male
# 1747                   Standing, stepped on shark               Joe Davis
# 6082                                          NaN                     NaN
# 168                                       Surfing           Robert Nesbit
# 1762                                 Spearfishing                    male
# 5915                           Bathing / standing  B., "an Ooryah coolie"
# 3962  Free diving / photography, kneeling on sand   Raymond F. McAllister
# 5466                                      Fishing             Zacey Allen
#
#       Sex  ...            Time  \
# 604   NaN  ...       Afternoon
# 843   NaN  ...       Afternoon
# 6216  NaN  ...             NaN
# 1747  NaN  ...       Afternoon
# 6082  NaN  ...             NaN
# 168   NaN  ...           10h00
# 1762  NaN  ...             NaN
# 5915  NaN  ...             NaN
# 3962  NaN  ...  12h00 to 14h00
# 5466  NaN  ...             NaN
#
#                                  Investigator or Source original order  \
# 604           S. Nagiewicz, SRI; Star Ledger, 11/9/2013         5700.0
# 843                    Sunshire Coast Daily, 12/1/2011          5461.0
# 6216  A. Seekee & R. Callinan, Courier-Mail, 7/7/199...           89.0
# 1747                          P. Caston, Post & Courier         4557.0
# 6082                                     C. Moore, GSAF          223.0
# 168                         Orlando Sentinel, 3/27/2017         6136.0
# 1762                                       Noonsite.com         4542.0
# 5915                                    J. Fayrer, M.D.          390.0
# 3962                  R. McAllister; SAF ISAF Case #958         2343.0
# 5466                  The Gleaner (Jamaica), 11/20/1906          839.0
#
#      Case Number.1 Case Number.2                                     pdf  \
# 604   2013.11.07.b  2013.11.07.b                  2013.11.07.b-Gates.pdf
# 843     2011.11.28    2011.11.28  2011.11.28-Kriz-not-on-spreadsheet.pdf
# 6216       ND.0104       ND.0104                 ND-0104-HelmetDiver.pdf
# 1747  2003.09.13.a  2003.09.13.a               2003.09.13.a-JoeDavis.pdf
# 6082  1836.07.26.R  1836.07.26.R                  1836.07.26.R-Spain.pdf
# 168     2017.03.27    2017.03.27                      2017.03.27-NSB.pdf
# 1762  2003.07.00.b  2003.07.00.b                 2003.07.00.b-Moorea.pdf
# 5915    1870.06.01    1870.06.01                   1870.06.01-Ooryah.pdf
# 3962  1960.10.00.a  1960.10.00.a             1960.10.00.a-McAllister.pdf
# 5466    1906.11.16    1906.11.16               1906.11.16-ZaceyAllen.pdf
#
#                                            href formula  \
# 604   http://sharkattackfile.net/spreadsheets/pdf_di...
# 843   http://sharkattackfile.net/spreadsheets/pdf_di...
# 6216  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1747  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6082  http://sharkattackfile.net/spreadsheets/pdf_di...
# 168   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1762  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5915  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3962  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5466  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Unnamed: 22  \
# 604   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 843   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6216  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1747  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6082  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 168   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1762  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5915  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3962  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5466  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
#
#      Unnamed: 23
# 604          NaN
# 843          NaN
# 6216         NaN
# 1747         NaN
# 6082         NaN
# 168          NaN
# 1762         NaN
# 5915         NaN
# 3962         NaN
# 5466         NaN
#
# [10 rows x 24 columns]

# %%
shark_clean['Year'] = shark_clean['Year'].astype({'Year':'int'})
shark_clean.dtypes
# Out:
# Case Number                       object
# Date                      datetime64[ns]
# Year                               int64
# Type                              object
# Country                           object
# Area                              object
# Location                          object
# Activity                          object
# Name                              object
# Sex                              float64
# Age                               object
# Injury                            object
# Fatal (Y/N)                       object
# Species                           object
# Time                              object
# Investigator or Source            object
# original order                   float64
# Case Number.1                     object
# Case Number.2                     object
# pdf                               object
# href formula                      object
# href                              object
# Unnamed: 22                       object
# Unnamed: 23                       object
# dtype: object

# %%
aux_fun = lambda x : int(x)
shark_clean['Year'] = shark_clean['Year'].map(aux_fun)
shark_clean.head(10)
# Out:
#   Case Number       Date  Year                     Type    Country  \
# 0  2018.06.25 2018-06-25  2018                  Boating        USA
# 1  2018.06.18 2018-06-18  2018               Unprovoked        USA
# 2  2018.06.09 2018-06-09  2018                  Invalid        USA
# 3  2018.06.08 2018-06-08  2018               Unprovoked  AUSTRALIA
# 4  2018.06.04 2018-06-04  2018                 Provoked     MEXICO
# 5  2018.06.03 2018-06-03  2018               Unprovoked  AUSTRALIA
# 6  2010.01.01        NaT  1926  No injury, board bitten          N
# 7  2018.06.03 2018-06-03  2018               Unprovoked     BRAZIL
# 8  2018.05.27 2018-05-27  2018               Unprovoked        USA
# 9  2018.05.26 2018-05-26  2018               Unprovoked        USA
#
#               Area                                           Location  \
# 0       California                        Oceanside, San Diego County
# 1          Georgia                     St. Simon Island, Glynn County
# 2           Hawaii                                       Habush, Oahu
# 3  New South Wales                                 Arrawarra Headland
# 4           Colima                                           La Ticla
# 5  New South Wales                                 Flat Rock, Ballina
# 6              NaN                                                NaN
# 7       Pernambuco                              Piedade Beach, Recife
# 8          Florida  Lighhouse Point Park, Ponce Inlet, Volusia County
# 9          Florida                       Cocoa Beach, Brevard  County
#
#                     Activity                       Name  Sex  ...  \
# 0                   Paddling                Julie Wolfe  NaN  ...
# 1                   Standing            Adyson McNeely   NaN  ...
# 2                    Surfing                John Denges  NaN  ...
# 3                    Surfing                       male  NaN  ...
# 4                Free diving             Gustavo Ramos   NaN  ...
# 5               Kite surfing                     Chris   NaN  ...
# 6  Daily Telegraph, 6/4/2018  2018.06.03.b-FlatRock.pdf  NaN  ...
# 7                   Swimming     Jose Ernesto da Silva   NaN  ...
# 8                    Fishing                       male  NaN  ...
# 9                    Walking                  Cody High  NaN  ...
#
#              Time           Investigator or Source original order  \
# 0           18h00                 R. Collier, GSAF         6303.0
# 1   14h00  -15h00   K.McMurray, TrackingSharks.com         6302.0
# 2           07h45   K.McMurray, TrackingSharks.com         6301.0
# 3             NaN                   B. Myatt, GSAF         6300.0
# 4             NaN                        A .Kipper         6299.0
# 5             NaN                              NaN            NaN
# 6            6298                              NaN            NaN
# 7  Late afternoon   Diario de Pernambuco, 6/4/2018         6297.0
# 8             NaN  K. McMurray, TrackingSharks.com         6296.0
# 9           17h00   K.McMurray, TrackingSharks.com         6295.0
#
#   Case Number.1 Case Number.2                       pdf  \
# 0    2018.06.25    2018.06.25      2018.06.25-Wolfe.pdf
# 1    2018.06.18    2018.06.18    2018.06.18-McNeely.pdf
# 2    2018.06.09    2018.06.09     2018.06.09-Denges.pdf
# 3    2018.06.08    2018.06.08  2018.06.08-Arrawarra.pdf
# 4    2018.06.04    2018.06.04      2018.06.04-Ramos.pdf
# 5           NaN           NaN                       NaN
# 6           NaN           NaN                       NaN
# 7  2018.06.03.a  2018.06.03.a  2018.06.03.a-daSilva.pdf
# 8    2018.05.27    2018.05.27      2018.05.27-Ponce.pdf
# 9  2018.05.26.b  2018.05.26.b     2018.05.26.b-High.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5                                                NaN
# 6                                                NaN
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Unnamed: 22 Unnamed: 23
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 5                                                NaN         NaN         NaN
# 6                                                NaN         NaN         NaN
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN         NaN
#
# [10 rows x 24 columns]

# %%
shark_clean.dtypes
# Out:
# Case Number                       object
# Date                      datetime64[ns]
# Year                               int64
# Type                              object
# Country                           object
# Area                              object
# Location                          object
# Activity                          object
# Name                              object
# Sex
# 4059  1959.09.30 1959-09-30  1959    Unprovoked       PHILIPPINES
# 3310  1973.01.09 1973-01-09  1973    Unprovoked               USA
# 5908  1871.05.13        NaT  1871       Unknown            GUYANA
# 4841  1937.09.12 1937-09-12  1937       Boating          SCOTLAND
# 1399  2007.03.12 2007-03-12  2007    Unprovoked         AUSTRALIA
# 2245  1997.07.17 1997-07-17  1997    Unprovoked            BRAZIL
# 892   2011.07.30 2011-07-30  2011  Sea Disaster       PHILIPPINES
# 865   2011.09.20 2011-09-20  2011          Boat               USA
# 841   2011.12.02 2011-12-02  2011    Unprovoked         AUSTRALIA
# 233   2016.08.06 2016-08-06  2016    Unprovoked               USA
# 2775  1987.07.12 1987-07-12  1987    Unprovoked               USA
# 3667  1964.08.23 1964-08-23  1964    Unprovoked            MEXICO
# 1727  2003.10.31 2003-10-31  2003    Unprovoked         AUSTRALIA
# 6055  1845.09.16        NaT  1845    Unprovoked           ENGLAND
# 5421  1909.06.26 1909-06-26  1909    Unprovoked      SOUTH AFRICA
# 955   2011.01.15 2011-01-15  2011    Unprovoked      SOUTH AFRICA
# 1916  2001.08.25 2001-08-25  2001    Unprovoked               USA
# 4328  1954.09.15 1954-09-15  1954    Unprovoked         HONG KONG
#
#                                    Area  \
# 708                          Queensland
# 4462                         Queensland
# 785                      South Carolina
# 2517                             Vavau
# 1887                      KwaZulu-Natal
# 5859                  Strait of Messina
# 1712                            Florida
# 103                      South Carolina
# 5902                  Lomaiviti Provine
# 1698                                NaN
# 4906                         New Jersey
# 3201                         California
# 808                             Florida
# 4715                         Queensland
# 2027                            Florida
# 5302                          Louisiana
# 2385                     Clearwater Bay
# 3416                             Basrah
# 1722                    Sinai Peninsula
# 1968                Rio Grande de Norte
# 2614                         Queensland
# 2223              Eastern Cape Province
# 4273  Admiralty Islands, Manus Province
# 3610                         West coast
# 2531                    New South Wales
# 4529      Bougainville (North Solomons)
# 4688                                NaN
# 896                        Saint-Gilles
# 5197                  Western Australia
# 5445                          Hong Kong
# 1270                            Florida
# 4825                      KwaZulu-Natal
# 1420              Eastern Cape Province
# 5734                       South Island
# 5304                           New York
# 5818                                NaN
# 491                             Florida
# 222                      North Province
# 1139                      KwaZulu-Natal
# 617                             Florida
# 1966                    New South Wales
# 1396                            Florida
# 4059                       Leyte Island
# 3310                             Hawaii
# 5908                                NaN
# 4841                        Argyllshire
# 1399                         Queensland
# 2245                         Pernambuco
# 892                                 NaN
# 865                              Hawaii
# 841                     New South Wales
# 233                              Hawaii
# 2775                              Texas
# 3667                           Guerrero
# 1727                    New South Wales
# 6055                                NaN
# 5421              Western Cape Province
# 955               Eastern Cape Province
# 1916                            Florida
# 4328                                NaN
#
#                                                Location  \
# 708                                               Noosa
# 4462                                            Yeppoon
# 785                          Myrtle Beach, Horry County
# 2517                       Between Ofu & Fafini Islands
# 1887                                      Durban Harbor
# 5859                                       Off Calabria
# 1712                                 Miami, Dade County
# 103   Sea Pines Resort, Hilton Head Island, Beaufort...
# 5902                        Levuka Point, Ovalau Island
# 1698                         Coral Bay, Sharm-el-Sheikh
# 4906                                  50 miles offshore
# 3201                                   Farallon Islands
# 808                        Jensen Beach, Martin County
# 4715                     Great Barrier Reef, off Cairns
# 2027                                       Florida Keys
# 5302                                         Grand Lake
# 2385                                        First Beach
# 3416                                Shatt-al-Arab River
# 1722                    Shaab Mahmud, Ras Mohamed Park
# 1968                            Praia de Camapum, Macau
# 2614                                       Nerang River
# 2223                                    Off Port Alfred
# 4273                                        Hus Island
# 3610  Outside the reef off Moputu Village, near Talasea
# 2531                                       Avalon Beach
# 4529                        Sohano Island, Buka Passage
# 4688                                       River Tigris
# 896                                          Brisants.
# 5197                   Condon, 88 km NE of Port Hedland
# 5445    Sharp Peak, Sai Kung Peninsula, New Territories
# 1270                   New Smyrna Beach, Volusia County
# 4825                               Vetchs Pier, Durban
# 1420                                Nahoon, East London
# 5734                                             Oamaru
# 5304                           Sheepshead Bay, Brooklyn
# 5818                                                NaN
# 491                    New Smyrna Beach, Volusia County
# 222                                              Koumac
# 1139                                         Umtentweni
# 617                             Destin, Okaloosa County
# 1966                                       Bronte Beach
# 1396                                      Jupiter Inlet
# 4059                                        Luang Dulag
# 3310                        Ho'okipa Beach, Pa'ia, Maui
# 5908                                           Demerara
# 4841                                              Arran
# 1399                     Moore Park, north of Bundaberg
# 2245                                 Boa Viagem, Recife
# 892                                                 NaN
# 865                                               Kauai
# 841                                         Broken Head
# 233                                                Maui
# 2775                  Mustang Island, near Port Aransas
# 3667                                           Acapulco
# 1727                       Lighthouse Beach, Seal Rocks
# 6055                                                NaN
# 5421                                          Cape Town
# 955                       Second Beach, Port St. John's
# 1916                   New Smyrna Beach, Volusia County
# 4328                                           Junk Bay
#
#                                                Activity  \
# 708                                             Surfing
# 4462                                   Paddling a canoe
# 785                                            Swimming
# 2517                                       Spearfishing
# 1887                                            Fishing
# 5859                                           Paddling
# 1712                                           Swimming
# 103                                            Swimming
# 5902                                      boat capsized
# 1698                                         Snorkeling
# 4906        Fishing for bluefish, shark leapt into dory
# 3201                        Scuba diving & spearfishing
# 808                                             Surfing
# 4715                                 Diving from lugger
# 2027              Attempting to illegally enter the USA
# 5302                                     Netting shrimp
# 2385                                           Swimming
# 3416                                           Swimming
# 1722                                         Snorkeling
# 1968                                              Batin
# 2614                                          Swimming
# 2223                                          Fishingat
# 4273                                                NaN
# 3610                        Spearfishing, shot a turtle
# 2531                                       Scuba diving
# 4529                            Swimming close to wharf
# 4688                                           Swimming
# 896                             Kayaking or Wave skiing
# 5197                                       Dry shelling
# 5445                                            Fishing
# 1270                                            Surfing
# 4825  Watching seine netters with friends, one of wh...
# 1420                                           Canoeing
# 5734                               Floating on his back
# 5304                                           Swimming
# 5818                     Swimming to retrieve a flannel
# 491                                             Surfing
# 222                                        Kite surfing
# 1139                                           Swimming
# 617                                              Wading
# 1966                                         Snorkeling
# 1396                                            Surfing
# 4059                                          Swimming
# 3310                                            Surfing
# 5908                                            Suicide
# 4841                                   Pleasure boating
# 1399                                           Swimming
# 2245                                            Surfing
# 892                                        Sea disaster
# 865                                            Canoeing
# 841                                             Surfing
# 233                                   SUP Foil boarding
# 2775                                             Wading
# 3667              Floating on his back in an inner tube
# 1727                                            Surfing
# 6055                                                NaN
# 5421                                                NaN
# 955                                             Surfing
# 1916                                    Boogie Boarding
# 4328                                           Swimming
#
#                                                    Name  Sex  ...       Time  \
# 708                                   Matthew Cassaigne  NaN  ...        NaN
# 4462  A canoe; occupants Harry Goodson & Douglas Barnes  NaN  ...        NaN
# 785                                     Jordon Garosalo  NaN  ...      13h20
# 2517                                 A diver from Spain  NaN  ...        NaN
# 1887                                       Imraan Sheik  NaN  ...      02h00
# 5859                                Captain Paul Boyton  NaN  ...        NaN
# 1712                                    Richard Hansell  NaN  ...        NaN
# 103                                       Linton Suttle  NaN  ...      13h30
# 5902                                        Mr. Manning  NaN  ...       dusk
# 1698                                               male  NaN  ...        NaN
# 4906  Captain Manuel Chalor of fishing trawler Nautilus  NaN  ...        NaN
# 3201                               Robin Buckley (male)  NaN  ...      12h00
# 808                                         Frank Wacha  NaN  ...      15h50
# 4715                                    Abraham Johnson  NaN  ...        NaN
# 2027                                  Juan & Alex Bueno  NaN  ...        NaN
# 5302                                      William Lerey  NaN  ...        NaN
# 2385                                     Wong Kwai-yung  NaN  ...        NaN
# 3416                                               male  NaN  ...      12h00
# 1722                                      Igor Fedorov   NaN  ...        NaN
# 1968                                             A.C.C.  NaN  ...        NaN
# 2614                                   Michael Pignolet  NaN  ...        NaN
# 2223                         Andre Marais & Tony Jensen  NaN  ...        NaN
# 4273                                               male  NaN  ...        NaN
# 3610                                             Kaleva  NaN  ...        NaN
# 2531                                     Dave Gannicott  NaN  ...        NaN
# 4529                                               male  NaN  ...        NaN
# 4688                                   Syed Khaleeulla   NaN  ...        NaN
# 896                                                male  NaN  ...      17h00
# 5197             Selim and Dea Opre,  Koepang Islanders  NaN  ...        NaN
# 5445                                          fishermen  NaN  ...        NaN
# 1270                                             female  NaN  ...      08h45
# 4825                                      George Parkin  NaN  ...        NaN
# 1420                                     Richard Tebutt  NaN  ...  Afternoon
# 5734                                        David Grant  NaN  ...      06h00
# 5304                                    Gertude Hoffman  NaN  ...      10h00
# 5818                                         Farejallah  NaN  ...      11h45
# 491                                          Kevin Ross  NaN  ...      11h30
# 222                                        David Jewell  NaN  ...      15h40
# 1139                                  Odwa Hlanganisela  NaN  ...    Morning
# 617                            Zachary Tyke Standridge   NaN  ...      15h30
# 1966                                Andranik Markossian  NaN  ...        NaN
# 1396                                          Sam Chief  NaN  ...    Evening
# 4059                                 Francisco Daguinot  NaN  ...        NaN
# 3310                                    Robert Sterling  NaN  ...        NaN
# 5908                                              Grant  NaN  ...        NaN
# 4841                          Clyde steamer Glen Sannox  NaN  ...        NaN
# 1399                                     Mary Jane Ryan  NaN  ...      15h30
# 2245                José Roberto Paraizo de Albuquerque  NaN  ...        NaN
# 892   Fishing vessel. Occupants Gerry Malabago, Mark...  NaN  ...        NaN
# 865                                        Tom Bartlett  NaN  ...      15h00
# 841                                       Milton Carter  NaN  ...      06h00
# 233                                       Connor Baxter  NaN  ...      16h30
# 2775                                        Brenda King  NaN  ...      14h30
# 3667                                      Thad T. Moore  NaN  ...      14h00
# 1727                                       Nick Anthony  NaN  ...      17h30
# 6055                                   a school teacher  NaN  ...        NaN
# 5421                                                NaN  NaN  ...        NaN
# 955                                        Zama Ndamase  NaN  ...      12h30
# 1916                                               male  NaN  ...      14h00
# 4328                James Cook, a seaman from HMS Comus  NaN  ...        NaN
#
#                                  Investigator or Source original order  \
# 708                                sharkattackfile.info         5596.0
# 4462                  Sydney Morning Herald, 11/13/1950         1843.0
# 785                                         C. Creswell         5519.0
# 2517                          Drs. S. Fonea & A. Carafa         3788.0
# 1887                                   G. Gifford, GSAF         4417.0
# 5859                                 J. Stanton, et. Al          446.0
# 1712                The Times (London), 12/27/2003, p.4         4592.0
# 103                                   C. Creswell, GSAF         6201.0
# 5902                                  Empire, 2/20/1872          403.0
# 1698                                       divernet.com         4606.0
# 4906                         NY Times, 6/19/1935, p.21          1399.0
# 3201  D. Miller & R. Collier, R. Collier, pp.67-69; ...         3104.0
# 808                                 WPBF.com, 3/16/2012         5496.0
# 4715                       V.M. Coppleson (1958), p.245         1590.0
# 2027                                    Press clippings         4277.0
# 5302                                The News, 8/15/1916         1003.0
# 2385  J. Wong & R.D. Weeks, GSAF; Daily Telegraph Mi...         3920.0
# 3416                       B.W. Coad & L.A.J. Al-Hassan         2889.0
# 1722                                       N. Pankratov         4582.0
# 1968                                        M. Szpilman         4336.0
# 2614                       Herald Sun, 11/30/1990, p.34         3691.0
# 2223                         Daily Dispatch, 10/11/1997         4082.0
# 4273                                A.M. Rapson, p.149;         2032.0
# 3610                 Morning Herald (Sydney) 10/17/1965         2695.0
# 2531                 Orlando Sentinel, 10/15/1992, p.A3         3774.0
# 4529                  A. Bleakley;  A. M. Rapson, p.148         1776.0
# 4688                          Times of India, 8/19/2001         1617.0
# 896                                  Le Post, 7/19/2011         5408.0
# 5197  Western Mail, 11/29/1923; V.M. Coppleson (1933...         1108.0
# 5445                      Dawson Daily News, 11/20/1907          860.0
# 1270                                S. Petersohn, GSAF          5034.0
# 4825                                    M. Levine, GSAF         1480.0
# 1420                            P. Immerz, SharkProject         4884.0
# 5734  R.D. Weeks, GSAF; K.C. McDonald; Evening Post ...          570.0
# 5304                          New York Times, 7/14/1916         1001.0
# 5818                     Newfoundlander (NZ), 11/5/1880          487.0
# 491                                    WESH2, 10/6/2014         5813.0
# 222                              TVANouvelles, 9/6/2016         6082.0
# 1139                          Daily Dispatch, 4/10/2009         5165.0
# 617                   Monroe County Advocate, 10/9/2013         5687.0
# 1966   ABC News; Northern Territory News, 4/9/2001, p.2         4338.0
# 1396                                 TCPalm, 3/23/2007          4908.0
# 4059                            Manila Times, 10/2/1959         2246.0
# 3310        J. Borg, p.74; L. Taylor (1993), pp.102-103         2995.0
# 5908                 The Buffalo Commercial, 5//13/1871          397.0
http://sharkattackfile.net/spreadsheets/pdf_di...
# 2245  http://sharkattackfile.net/spreadsheets/pdf_di...
# 892   http://sharkattackfile.net/spreadsheets/pdf_di...
# 865   http://sharkattackfile.net/spreadsheets/pdf_di...
# 841   http://sharkattackfile.net/spreadsheets/pdf_di...
# 233   http://sharkattackfile.net/spreadsheets/pdf_di...
# 2775  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3667  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1727  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6055  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5421  http://sharkattackfile.net/spreadsheets/pdf_di...
# 955   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1916  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4328  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Unnamed: 22  \
# 708   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4462  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 785   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2517  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1887  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5859  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1712  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 103   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5902  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1698  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4906  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3201  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 808   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4715  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2027  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5302  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2385  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3416  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1722  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1968  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2614  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2223  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4273  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3610  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2531  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4529  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4688  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 896   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5197  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5445  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1270  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4825  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1420  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5734  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5304  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5818  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 491   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 222   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1139  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 617   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1966  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1396  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4059  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3310  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5908  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4841  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1399  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2245  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 892   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 865   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 841   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 233   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2775  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3667  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1727  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6055  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5421  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 955   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1916  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4328  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
#
#      Unnamed: 23
# 708          NaN
# 4462         NaN
# 785          NaN
# 2517         NaN
# 1887         NaN
# 5859         NaN
# 1712         NaN
# 103          NaN
# 5902         NaN
# 1698         NaN
# 4906         NaN
# 3201         NaN
# 808          NaN
# 4715         NaN
# 2027         NaN
# 5302         NaN
# 2385         NaN
# 3416         NaN
# 1722         NaN
# 1968         NaN
# 2614         NaN
# 2223         NaN
# 4273         NaN
# 3610         NaN
# 2531         NaN
# 4529         NaN
# 4688         NaN
# 896          NaN
# 5197         NaN
# 5445         NaN
# 1270         NaN
# 4825         NaN
# 1420         NaN
# 5734         NaN
# 5304         NaN
# 5818         NaN
# 491          NaN
# 222          NaN
# 1139         NaN
# 617          NaN
# 1966         NaN
# 1396         NaN
# 4059         NaN
# 3310         NaN
# 5908         NaN
# 4841         NaN
# 1399         NaN
# 2245         NaN
# 892          NaN
# 865          NaN
# 841          NaN
# 233          NaN
# 2775         NaN
# 3667         NaN
# 1727         NaN
# 6055         NaN
# 5421         NaN
# 955          NaN
# 1916         NaN
# 4328         NaN
#
# [60 rows x 24 columns]

# %%
shark_clean.dtypes
# Out:
# Case Number                       object
# Date                      datetime64[ns]
# Year                               int64
# Type                              object
# Country                           object
# Area                              object
# Location                          object
# Activity                          object
# Name                              object
# Sex                              float64
# Age                               object
# Injury                            object
# Fatal (Y/N)                       object
# Species                           object
# Time                              object
# Investigator or Source            object
# original order                   float64
# Case Number.1                     object
# Case Number.2                     object
# pdf                               object
# href formula                      object
# href                              object
# Unnamed: 22                       object
# Unnamed: 23                       object
# dtype: object

# %% [markdown]
# # limpieza de country

# %%
shark_clean['Country'] = shark_clean['Country'].fillna('Unknown')
shark_clean.sample(10)
# Out:
#      Case Number       Date  Year        Type       Country  \
# 294   2016.03.30 2016-03-30  2016  Unprovoked     AUSTRALIA
# 1600  2005.04.06 2005-04-06  2005  Unprovoked           USA
# 3149  1977.05.26 1977-05-26  1977        Boat  SOUTH AFRICA
# 2220  1997.10.28 1997-10-28  1997  Unprovoked           USA
# 5054  1930.01.16 1930-01-16  1930  Unprovoked  SOUTH AFRICA
# 4968  1933.06.08        NaT  1933  Unprovoked     AUSTRALIA
# 1149  2009.03.17 2009-03-17  2009  Unprovoked           USA
# 173   2017.02.25 2017-02-25  2017  Unprovoked     AUSTRALIA
# 5986  1860.04.00        NaT  1860  Unprovoked   NEW ZEALAND
# 992   2010.09.03 2010-09-03  2010  Unprovoked           USA
#
#                        Area  \
# 294         New South Wales
# 1600                Florida
# 3149  Western Cape Province
# 2220                 Hawaii
# 5054  Western Cape Province
# 4968             Queensland
# 1149                 Hawaii
# 173       Western Australia
# 5986           North Island
# 992                 Florida
#
#                                                Location  \
# 294                                         Bombo Beach
# 1600                   Jacksonville Beach, Duval County
# 3149                                  13 km off Knysna
# 2220  Waiokapua Bay/Majors Bay, Brennecke Beach, Poi...
# 5054                                Melkbaai, False Bay
# 4968                                          Currumbin
# 1149                                 Alenuihaha Channel
# 173                                         Mauds Point
# 5986                  St. George's Bay, Auckland Harbor
# 992                    New Smyrna Beach, Volusia County
#
#                       Activity  \
# 294                    Surfing
# 1600                       NaN
# 3149    Fishing for yellowtail
# 2220  Body boarding or surfing
# 5054                  Swimming
# 4968            Treading water
# 1149                  Swimming
# 173                 Snorkeling
# 5986                   Bathing
# 992                    Surfing
#
#                                                    Name  Sex  ...     Time  \
# 294                                     Brett Connellan  NaN  ...    19h00
# 1600                                        Jessica Abe  NaN  ...      NaN
# 3149  5 m skiboat Graanjan, occupants: Rudy van Graa...  NaN  ...      NaN
# 2220                                         Mike Coots  NaN  ...    07h20
# 5054                                       Servy LeRoux  NaN  ...    17h30
# 4968                                    Walter Mitchell  NaN  ...      NaN
# 1149                                     Mike Spaulding  NaN  ...    20h00
# 173                                              female  NaN  ...  Morning
# 5986                                         H. Bradley  NaN  ...      NaN
# 992                                       Jason Coffman  NaN  ...    12h00
#
#                                  Investigator or Source original order  \
# 294                          Daily Telegraph, 3/30/2016         6010.0
# 1600                                  WJXT News4Jax.com         4704.0
# 3149                               T. Wallett, pp.32-33         3156.0
# 2220                       Yahoo News Canada, 8/16/2012         4085.0
# 5054     A. LeRoux, M. Levine, GSAF; L. Green; G.Wilson         1251.0
# 4968               Townsville Daily Bulletin, 6/9/1933          1337.0
# 1149                     B. Perry, Maui News, 3/18/2009         5155.0
# 173                                Perth Now, 2/27/2017         6131.0
# 5986                                        P. Tichener          319.0
# 992   S. Petersohn; Daytona Beach News-Journal, 9/3/...         5312.0
#
#      Case Number.1 Case Number.2                              pdf  \
# 294     2016.03.30    2016.03.30         2016.03.30-Connellan.pdf
# 1600    2005.04.06    2005.04.06             2005.04.06.a-Abe.pdf
# 3149    1977.05.26    1977.05.26           1977.05.26-Lombard.pdf
# 2220  1997.10.28.a  1997.10.28.a           1997.10.28.a-Coots.pdf
# 5054    1930.01.16    1930.01.16           1930.01.16-le-Roux.pdf
# 4968  1933.06.08.R  1933.06.08.R          1933.06.08-Mitchell.pdf
# 1149    2009.03.17    2009.03.17       2009.03.17.a-Spaulding.pdf
# 173     2017.02.25    2017.02.25  2017.02.25-WesternAustralia.pdf
# 5986  1860.04.00.a  1860.04.00.a         1860.04.00.a-Bradley.pdf
# 992   2010.09.03.b  2010.09.03.b         2010.09.03.b-Coffman.pdf
#
#                                            href formula  \
# 294   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1600  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3149  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2220  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5054  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4968  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1149  http://sharkattackfile.net/spreadsheets/pdf_di...
# 173   http://sharkattackfile.net/spreadsheets/pdf_di...
# 5986  http://sharkattackfile.net/spreadsheets/pdf_di...
# 992   http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Unnamed: 22  \
# 294   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1600  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3149  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2220  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5054  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4968  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1149  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 173   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5986  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 992   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
#
#      Unnamed: 23
# 294          NaN
# 1600         NaN
# 3149         NaN
# 2220         NaN
# 5054         NaN
# 4968         NaN
# 1149         NaN
# 173          NaN
# 5986         NaN
# 992          NaN
#
# [10 rows x 24 columns]

# %% [markdown]
# # limpieza de Area

# %%
shark_clean['Area'] = shark_clean['Area'].fillna('Unknown')
shark_clean.sample(60)
# Out:
#      Case
# 881   2011.08.18 2011-08-18  2011    Unprovoked             RUSSIA
# 3761  1963.02.27 1963-02-27  1963    Unprovoked   PAPUA NEW GUINEA
# 1303  2007.12.18 2007-12-18  2007    Unprovoked          AUSTRALIA
# 4545  1948.08.03 1948-08-03  1948    Unprovoked               IRAN
# 4967  1933.05.23 1933-05-23  1933      Provoked          AUSTRALIA
# 6138  1788.05.10 1788-05-10  1788          Boat          AUSTRALIA
# 5377  1912.01.26 1912-01-26  1912    Unprovoked          AUSTRALIA
# 573   2014.03.22 2014-03-22  2014    Unprovoked                USA
# 1081  2009.10.24 2009-10-24  2009    Unprovoked                USA
# 5974  1862.05.05 1862-05-05  1862    Unprovoked       SOUTH AFRICA
# 3332  1972.06.26        NaT  1972    Unprovoked          AUSTRALIA
# 6153  1751.07.27 1751-07-27  1751    Unprovoked                USA
# 5287  1917.09.09 1917-09-09  1917      Provoked                USA
# 4851  1937.06.15        NaT  1937    Unprovoked                USA
# 500   2014.09.13 2014-09-13  2014       Unknown                USA
# 1616  2005.01.19 2005-01-19  2005      Provoked          AUSTRALIA
# 5375  1912.02.19 1912-02-19  1912    Unprovoked          AUSTRALIA
#
#                                                    Area  \
# 1061                                    Maputo Province
# 5079                                            Florida
# 5514                                     South Province
# 5525                                         Queensland
# 5212                                      Caribbean Sea
# 6045                                         Queensland
# 5650                                    New South Wales
# 249                                             Unknown
# 1166                                    New South Wales
# 2458                                  Western Australia
# 3461                                            Florida
# 5560                       Primorje-Gorski Kotar County
# 5977                                            Unknown
# 3060                                             Hawaii
# 5589                                            Unknown
# 1682                              Western Cape Province
# 2895                              Western Cape Province
# 2129                                       South Island
# 4041                                           Victoria
# 5189                                             Galica
# 4846                                     Colon Province
# 5123                                    New South Wales
# 2729                                            Unknown
# 4032                                             Madang
# 1063                                         Queensland
# 3752                                         California
# 3805                                     Tyrrhenian Sea
# 3827                                         Queensland
# 1327                                            Florida
# 5110                                         Queensland
# 4973                                    South Australia
# 4426                                    New South Wales
# 2491                                         Saint-Paul
# 458                                     New South Wales
# 1297                                       North Island
# 3552                                             Hawaii
# 3992                                              Paget
# 6042                                      Massachusetts
# 4334                                            Unknown
# 5328                                         Queensland
# 764                                            Trinidad
# 4776                                      KwaZulu-Natal
# 656                                             Unknown
# 881   Peter the Great Bay, Khasan, Primorsky Krai (F...
# 3761                               New Ireland Province
# 1303                                    New South Wales
# 4545                                Shatt-al-Arab River
# 4967                                         Queensland
# 6138                                    New South Wales
# 5377                                    New South Wales
# 573                                             Florida
# 1081                                         California
# 5974                                      KwaZulu-Natal
# 3332                                         Queensland
# 6153                                      Massachusetts
# 5287                                             Hawaii
# 4851                                              Texas
# 500                                          California
# 1616                                           Victoria
# 5375                                    New South Wales
#
#                                                Location  \
# 1061                                      Ponta do Ouro
# 5079                              Sea Spray, Palm Beach
# 5514                                             Noumea
# 5525                                        Logan River
# 5212                               20 miles from Havana
# 6045                                        Moreton Bay
# 5650                                         Newcastle
# 249                                         Tiger Beach
# 1166                           Surf Beach, Batemans Bay
# 2458                                             Albany
# 3461                 Half mile north of Juno Beach Pier
# 5560                                   Volosko, Opatija
# 5977                                                NaN
# 3060                             Puamana, Lahaina, Maui
# 5589                                                NaN
# 1682             Surfers' Corner, Muizenberg, False Bay
# 2895                              Muizenberg, False Bay
# 2129  Codfish Island (Whenua Hau) west of Stewart Is...
# 4041                                  Altona, Melbourne
# 5189                                   Sisargas Islands
# 4846                                          Limon Bay
# 5123                             Bradleys Head, Sydney
# 2729                                                NaN
# 4032                                                NaN
# 1063                                        Lamont Reef
# 3752                                   San Mateo County
# 3805                             Circeo, Secca del Faro
# 3827                                       Nobbys Beach
# 1327                                      Jupiter Inlet
# 5110                                         Graceville
# 4973                                           Adelaide
# 4426                                        North Bondi
# 2491                                 Cap de la Marianne
# 458                                Off Blacksmith Beach
# 1297                                        Omaha Beach
# 3552                            50 miles NE of Honolulu
# 3992                         Elbow Beach /  Coral Beach
# 6042                      Chelsea Beach, Suffolk County
# 4334                                   Singapore Harbor
# 5328                                      Wynnum-Manley
# 764                    Off Radix Village, Mayoro County
# 4776                          Warner Beach, South Coast
# 656                                                 NaN
# 881                                   Zheltukhin Island
# 3761                                          Namatanai
# 1303                                      Jimmy's Beach
# 4545                                           Bashamir
# 4967                              Off Stradbroke Island
# 6138                                      Sydney Harbor
# 5377     Fig Tree Bridge, Lane Cove River, near Sydney
# 573                                        Delray Beach
# 1081                      San Onofre, San Diego County
# 5974                                             Durban
# 3332                                      Pancake Creek
# 6153                                                NaN
# 5287                                    Nanakuli, Oahu
# 4851                                          Galveston
# 500              Manresa State Beach, Santa Cruz County
# 1616                                   Port Phillip Bay
# 5375                                             Coogee
#
#                                                Activity  \
# 1061                                           Swimming
# 5079                                           Swimming
# 5514                                            Bathing
# 5525                                           Swimming
# 5212               seaplane Columbus ditched in the sea
# 6045                             Wreck of the Sovereign
# 5650                                            Bathing
# 249                                        Scuba Diving
# 1166                                           Swimming
# 2458                                            Fishing
# 3461             Playing with a frisbee in the shallows
# 5560                                           Swimming
# 5977  Bathing alongside the American ship Thomas W. ...
# 3060                              Resting on body board
# 5589                                             Diving
# 1682                                            Surfing
# 2895                                            Surfing
# 2129                     Spearfishing & diving for paua
# 4041  Spearfishing, Smith  & Walker touched shark wi...
# 5189                                            Fishing
# 4846                                           Swimming
# 5123  The steamer Tahiti collided with the ferry Gre...
# 2729                                       Spearfishing
# 4032            Spear fishing, removing fish from spear
# 1063                                       Spearfishing
# 3752                                           Swimming
# 3805                                             Diving
# 3827                                            Fishing
# 1327                                       Scuba diving
# 5110                                            Bathing
# 4973                                                NaN
# 4426                                       Spearfishing
# 2491                                      Body boarding
# 458                                             Fishing
# 1297               Attempting to chase shark out to sea
# 3552                                            Fishing
# 3992          Free diving but treading water at surface
# 6042                                             Wading
# 4334  Closed circuit diving (submerged). Diving to r...
# 5328                                           Swimming
# 764                                            Swimming
# 4776                                          Swimming
# 656                                            Swimming
# 881                                            Swimming
# 3761                                           Swimming
# 1303                                            Surfing
# 4545                                           Swimming
# 4967                                            Fishing
# 6138                                            Fishing
# 5377                                           Swimming
# 573                                        Kite Surfing
# 1081                                            Surfing
# 5974                                            Bathing
# 3332                                                NaN
# 6153                                           Swimming
# 5287                Stuffing a shark into an automobile
# 4851                                           Swimming
# 500                                             Surfing
# 1616                                       Spearfishing
# 5375                                           Swimming
#
#                                                    Name  Sex  ...     Time  \
# 1061                                       Peter Fraser  NaN  ...    16h30
# 5079                                   Leroy Chadbourne  NaN  ...    12h00
# 5514                                      Charley Smith  NaN  ...      NaN
# 5525                                   William Bartlett  NaN  ...      NaN
# 5212                               Edwin F. Atkins, Jr.  NaN  ...      NaN
# 6045                                             Spicer  NaN  ...      NaN
# 5650                                     Horace Hewison  NaN  ...  Morning
# 249                                   Michael Dornellas  NaN  ...      NaN
# 1166                                    Jeremy McDonagh  NaN  ...    16h30
# 2458  5 m aluminum boat, occupants: Ben Turnbull, Li...  NaN  ...    07h30
# 3461              Colleen Chamberlin & Scott Chamberlin  NaN  ...    16h00
# 5560                                               male  NaN  ...      NaN
# 5977                                               crew  NaN  ...    10h30
# 3060                                       Mark Skidgel  NaN  ...      NaN
# 5589                                               male  NaN  ...      NaN
# 1682                                        J.P. Andrew  NaN  ...    14h00
# 2895                                       Selwyn Doran  NaN  ...    17h30
# 2129                                         Zane Smith  NaN  ...      NaN
# 4041                        Barry Smith & Harold Walker  NaN  ...      NaN
# 5189                      Boat owned by Ricardo Laneiro  NaN  ...      NaN
# 4846                                    Jorge Fernandez  NaN  ...      NaN
# 5123                                                NaN  NaN  ...      NaN
# 2729                                       Peter Albury  NaN  ...      NaN
# 4032                                                Sek  NaN  ...      NaN
# 1063                                      John Pengelly  NaN  ...    07h30
# 3752                                    Gregory Moffatt  NaN  ...      NaN
# 3805                                  Dante Matacchione  NaN  ...      NaN
# 3827  surf boat, occupants: Ray Sturdy and 4 other f...  NaN  ...      NaN
# 1327                                        Nikki Cuomo  NaN  ...      NaN
# 5110                                         Noel Arthy  NaN  ...  Morning
# 4973                                               boat  NaN  ...      NaN
# 4426                                      Lindsay  Munn  NaN  ...      NaN
# 2491                                   Theirry Mercredi  NaN  ...      NaN
# 458        Boat: occupants: Tim Watson & Allan de Sylva  NaN  ...    13h45
# 1297  inflatable rescue boat. Occupants: Lauren John...  NaN  ...    14h00
# 3552                                    Akiyoshi Morita  NaN  ...      NaN
# 3992                                       Louis Goiran  NaN  ...    15h00
# 6042                                      Amos Thompson  NaN  ...      NaN
# 4334                    C.B. Larkin, a Royal Navy diver  NaN  ...      NaN
# 5328                                         H. Stanton  NaN  ...      NaN
# 764                                        Shaka Galera  NaN  ...      NaN
# 4776                            Frederick Aubrey Hooper  NaN  ...    16h00
# 656                                      Fernando Licay  NaN  ...      NaN
# 881                                  Valery Sidorovich   NaN  ...      NaN
# 3761                                     Joseph To Toba  NaN  ...    11h00
# 1303                                         Ben Morcom  NaN  ...    11h00
# 4545                                             Ismail  NaN  ...      NaN
# 4967                                      Mr. E.B. Port  NaN  ...      NaN
# 6138                                               boat  NaN  ...      NaN
# 5377                                James Edward Morgan  NaN  ...    15h00
# 573                                        Kurt Hoffman  NaN  ...      NaN
# 1081                                       Scott Barton  NaN  ...    17h30
# 5974                                       Mr. Cummings  NaN  ...      NaN
# 3332                                  Kenneth Murchison  NaN  ...      NaN
# 6153                                               male  NaN  ...      NaN
# 5287                                       Carl Nakuina  NaN  ...      NaN
# 4851                               Hal A. Thompson, Jr.  NaN  ...    Night
# 500                                       Beau Browning  NaN  ...    18h45
# 1616                                  Julian McLaughlin  NaN  ...      NaN
# 5375                                          Fred Wort  NaN  ...    16h00
#
#                                  Investigator or Source original order  \
# 1061                                  Beeld, 12/29/2009         5243.0
# 5079  New York Herald Tribune, 3/17/1929 edtion; H. ...         1226.0
# 5514                           The Advertiser, 2/4/1904          791.0
# 5525                   Sydney Morning Herald, 3/16/1903          780.0
# 5212     W.E., pp.152-156; L. Schultz & M. Malin, p.557         1093.0
# 6045                        The Queenslander, 3/12/1921          260.0
# 5650                    Brisbane Courier, 1/7/1895, p.5          655.0
# 249                                  GrindTV, 7/14/2016         6055.0
# 1166                                ABC News, 1/28/2009         5138.0
# 2458                        Advertiser, 1/12/1994, p.18         3847.0
# 3461                                 M. Vorenberg, GSAF         2844.0
# 5560                                     C. Moore, GSAF          745.0
# 5977                              The Argus, 11/15/1861          328.0
# 3060  J. Borg, p.75; L. Taylor (1993), pp.104-105 - ...         3245.0
# 5589       Lincoln Evening News & Daily Call, 9/19/1898          716.0
# 1682                      L. Compagno & E. Ritter, GSAF         4622.0
# 2895                               The Argus, 6/16/1984         3410.0
# 2129                         Southland Times, 3/18/1999         4175.0
# 4041                      V.M. Coppleson (1962), p.252;         2264.0
# 5189                                     C. Moore, GSAF         1116.0
# 4846                             The Gleaner, 8/12/1937         1459.0
# 5123                         Oakland Tribune, 8/16/1930         1182.0
# 2729                                      E. Pace, GSAF         3576.0
# 4032                                        A.M. Rapson         2273.0
# 1063                         Brisbane Times, 12/20/2009         5241.0
# 3752                         San Mateo Times, 5/22/1963         2553.0
# 3805  A. De Maddalena; Carletti (1973), Giudici & Fi...         2500.0
# 3827                 Sydney Daily Telegraph, 4/21/1962          2478.0
# 1327                          Florida Today, 12/14/2007         4977.0
# 5110                         Brisbane Courier, 5/8/1928         1195.0
# 4973  G.P. Whitley citing Sydney Morning Herald, 2/1...         1332.0
# 4426                 V.M. Coppleson (1958), pp. 171-172         1879.0
# 2491                               Quotidien, 4/12/1999         3814.0
# 458                The Sydney Morning Herald, 1/18/2015         5846.0
# 1297                              TV3; R.D. Weeks, GSAF         5007.0
# 3552  Japan Times, 9/23/1966; Mainichi News, 9/25/19...         2753.0
# 3992  L.Goiran; S. Waterman; Royal Gazette (Hamilton...         2313.0
# 6042               Louisville Daily Courier. 9/16/1847           263.0
# 4334  New York Times, 7/29/1954; V.M. Coppleson (195...         1971.0
# 5328                         Brisbane Courier, 2/8/1915          977.0
# 764                          Trinidad Express, 8/3/2012         5540.0
http://sharkattackfile.net/spreadsheets/pdf_di...
# 4776  http://sharkattackfile.net/spreadsheets/pdf_di...
# 656   http://sharkattackfile.net/spreadsheets/pdf_di...
# 881   http://sharkattackfile.net/spreadsheets/pdf_di...
# 3761  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1303  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4545  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4967  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6138  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5377  http://sharkattackfile.net/spreadsheets/pdf_di...
# 573   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1081  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5974  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3332  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6153  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5287  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4851  http://sharkattackfile.net/spreadsheets/pdf_di...
# 500   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1616  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5375  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Unnamed: 22  \
# 1061  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5079  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5514  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5525  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5212  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6045  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5650  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 249   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1166  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2458  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3461  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5560  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5977  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3060  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5589  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1682  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2895  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2129  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4041  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5189  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4846  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5123  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2729  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4032  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1063  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3752  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3805  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3827  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1327  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5110  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4973  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4426  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2491  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 458   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1297  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3552  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3992  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6042  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4334  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5328  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 764   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4776  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 656   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 881   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3761  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1303  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4545  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4967  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6138  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5377  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 573   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1081  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5974  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3332  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6153  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5287  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4851  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 500   http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1616  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5375  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
#
#      Unnamed: 23
# 1061         NaN
# 5079         NaN
# 5514         NaN
# 5525         NaN
# 5212         NaN
# 6045         NaN
# 5650         NaN
# 249          NaN
# 1166         NaN
# 2458         NaN
# 3461         NaN
# 5560         NaN
# 5977         NaN
# 3060         NaN
# 5589         NaN
# 1682         NaN
# 2895         NaN
# 2129         NaN
# 4041         NaN
# 5189         NaN
# 4846         NaN
# 5123         NaN
# 2729         NaN
# 4032         NaN
# 1063         NaN
# 3752         NaN
# 3805         NaN
# 3827         NaN
# 1327         NaN
# 5110         NaN
# 4973         NaN
# 4426         NaN
# 2491         NaN
# 458          NaN
# 1297         NaN
# 3552         NaN
# 3992         NaN
# 6042         NaN
# 4334         NaN
# 5328         NaN
# 764          NaN
# 4776         NaN
# 656          NaN
# 881          NaN
# 3761         NaN
# 1303         NaN
# 4545         NaN
# 4967         NaN
# 6138         NaN
# 5377         NaN
# 573          NaN
# 1081         NaN
# 5974         NaN
# 3332         NaN
# 6153         NaN
# 5287         NaN
# 4851         NaN
# 500          NaN
# 1616         NaN
# 5375         NaN
#
# [60 rows x 24 columns]

# %% [markdown]
# # limpieza de location

# %%
shark_clean['Location']=shark_clean['Location'].fillna('Unknown')
shark_clean.sample(13)
# Out:
#      Case Number       Date  Year          Type           Country  \
# 4345  1954.05.00        NaT  1954    Unprovoked  PAPUA NEW GUINEA
# 4074  1959.08.14 1959-08-14  1959  Sea Disaster       PHILIPPINES
# 5392  1911.05.01 1911-05-01  1911    Unprovoked      SOUTH AFRICA
# 6239     ND.0073        NaT     0    Unprovoked         SINGAPORE
# 2448  1994.03.07 1994-03-07  1994      Provoked               USA
# 6229     ND.0086        NaT     0       Unknown  PAPUA NEW GUINEA
# 2978  1982.07.01 1982-07-01  1982    Unprovoked               USA
# 2128  1999.04.01 1999-04-01  1999    Unprovoked               USA
# 1098  2009.08.25 2009-08-25  2009    Unprovoked               USA
# 1182  2008.12.27 2008-12-27  2008       Boating         AUSTRALIA
# 1878  2002.03.15 2002-03-15  2002    Unprovoked               USA
# 2486  1993.08.00        NaT  1993    Unprovoked     NEW CALEDONIA
# 1502  2006.02.12 2006-02-12  2006    Unprovoked         AUSTRALIA
#
#                        Area  \
# 4345        Madang Province
# 4074                 Queaon
# 5392  Western Cape Province
# 6239                Unknown
# 2448             California
# 6229    Milne Bay  Province
# 2978                Florida
# 2128                Florida
# 1098             California
# 1182        New South Wales
# 1878                Florida
# 2486         South Province
# 1502             Queensland
#
#                                                Location  \
# 4345                                   Near Madang Town
# 4074                 Between Unisan & Angadanan Islands
# 5392                                       Victoria Bay
# 6239  Keppel Harbor,  2 miles from Singapore city ce...
# 2448                                            Unknown
# 6229    D'Entrecasteaux islands, 20 miles off the coast
# 2978                      Daytona Beach, Volusia County
# 2128                Hobe Sound Beach, Palm Beach County
# 1098         Terramar Beach, Carlsbad, San Diego County
# 1182                         Long Reef, north of Sydney
# 1878  Deerfield Beach (near Boca Raton), Broward County
# 2486                                           Ile Moro
# 1502                           Point Vernon, Hervey Bay
#
#                                     Activity  \
# 4345                                     NaN
# 4074                  Fishing boat capsized
# 5392                                Swimming
# 6239                                Swimming
# 2448  Removing shark from tank in nightclub
# 6229                            Scuba diving
# 2978                                Swimming
# 2128                                 Surfing
# 1098                                Swimming
# 1182                                Kayaking
# 1878                              Snorkeling
# 2486                    Fishing for lobsters
# 1502                                Swimming
#
#                                                    Name  Sex  ...       Time  \
# 4345                                              child  NaN  ...        NaN
# 4074  15 shipwrecked passengers and crew were in the...  NaN  ...  Afternoon
# 5392                                      James Jantjes  NaN  ...        NaN
# 6239                                                NaN  NaN  ...        NaN
# 2448                                   Steve Rosebloome  NaN  ...        NaN
# 6229                                          Dan Hogan  NaN  ...        NaN
# 2978                                         Janet Babb  NaN  ...      14h30
# 2128                                               male  NaN  ...        NaN
# 1098                                     Bethany Edmund  NaN  ...      16h30
# 1182                                      Steve Kulcsar  NaN  ...      11h00
# 1878                                        Robert Land  NaN  ...    Morning
# 2486                                    Thierry Kouathe  NaN  ...        NaN
# 1502                                               male  NaN  ...        NaN
#
#                                  Investigator or Source original order  \
# 4345                       V.M. Coppleson (1962), p.248         1960.0
# 4074  Manila Chronicle, 8/18/1959; V.M. Coppleson (1...         2231.0
# 5392  Cape Mercantile Advertiser, 5/2/1911, M. Levin...          913.0
# 6239                       V.M. Coppleson (1958), p.266           66.0
# 2448                               A. MacCormick, p.227         3857.0
# 6229                                F. Dennis, pp.15-16           76.0
# 2978            Daytona Beach Morning Journal, 7/2/1982         3327.0
# 2128                          Palm Beach Post, 4/1/1999         4176.0
# 1098                                   R. Collier, GSAF         5206.0
# 1182                         Canberra Times, 12/28/2008         5122.0
# 1878                                        ezboard.com         4426.0
# 2486                                         W. Leander         3819.0
# 1502                  G. Stolz, Courier-Mail, 2/14/2006         4802.0
#
#      Case Number.1 Case Number.2                                 pdf  \
# 4345    1954.05.00    1954.05.00                1954.05.00-child.pdf
# 4074  1959.08.14.a  1959.08.14.a        1959.08.14.a-Fishingboat.pdf
# 5392    1911.05.01    1911.05.01             1911.05.01-Jantjies.pdf
# 6239       ND.0073       ND.0073  ND-0073-KeppelHarbourSingapore.pdf
# 2448    1994.03.07    1994.03.07          1994.03.07-Rosenbloome.pdf
# 6229       ND.0086       ND.0086                ND-0086-DanHogan.pdf
# 2978    1982.07.01    1982.07.01                 1982.07.01-Babb.pdf
# 2128    1999.04.01    1999.04.01      1999.04.01-HobeSoundSurfer.pdf
# 1098    2009.08.25    2009.08.25               2009.08.25-Edmund.pdf
# 1182  2008.12.27.b  2008.12.27.b            2008.12.27.b-Kulcsar.pdf
# 1878  2002.03.15.b  2002.03.15.b               2002.03.15.b-Land.pdf
# 2486  1993.08.00.b  1993.08.00.b            1993.08.00.b-Kouathe.pdf
# 1502  2006.02.12.b  2006.02.12.b          2006.02.12.b-HerveyBay.pdf
#
#                                            href formula  \
# 4345  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4074  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5392  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6239  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2448  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6229  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2978  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2128  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1098  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1182  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1878  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2486  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1502  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Unnamed: 22  \
# 4345  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4074  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 5392  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6239  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2448  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 6229  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2978  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2128  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1098  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1182  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1878  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2486  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1502  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
#
#      Unnamed: 23
# 4345         NaN
# 4074         NaN
# 5392         NaN
# 6239         NaN
# 2448         NaN
# 6229         NaN
# 2978         NaN
# 2128         NaN
# 1098         NaN
# 1182         NaN
# 1878         NaN
# 2486         NaN
# 1502         NaN
#
# [13 rows x 24 columns]

# %% [markdown]
# # limpieza de Activity

# %%
shark_clean['Activity']=shark_clean['Activity'].fillna('Unknown')
shark_clean
# Out:
#      Case Number       Date  Year        Type    Country             Area  \
# 0     2018.06.25 2018-06-25  2018     Boating        USA       California
# 1     2018.06.18 2018-06-18  2018  Unprovoked        USA          Georgia
# 2     2018.06.09 2018-06-09  2018     Unknown        USA           Hawaii
# 3     2018.06.08 2018-06-08  2018  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04 2018-06-04  2018    Provoked     MEXICO           Colima
# ...          ...        ...   ...         ...        ...              ...
# 6309           0        NaT  1926     Unknown    Unknown          Unknown
# 6310           0        NaT  1926     Unknown    Unknown          Unknown
# 6311           0        NaT  1926     Unknown    Unknown          Unknown
# 6312  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
# 6313  2010.01.01        NaT  1926     Unknown    Unknown          Unknown
#
#                             Location     Activity             Name  Sex  ...  \
# 0        Oceanside, San Diego County     Paddling      Julie Wolfe  NaN  ...
# 1     St. Simon Island, Glynn County     Standing  Adyson McNeely   NaN  ...
# 2                       Habush, Oahu      Surfing      John Denges  NaN  ...
# 3                 Arrawarra Headland      Surfing             male  NaN  ...
# 4                           La Ticla  Free diving   Gustavo Ramos   NaN  ...
# ...                              ...          ...              ...  ...  ...
# 6309                         Unknown      Unknown              NaN  NaN  ...
# 6310                         Unknown      Unknown              NaN  NaN  ...
# 6311                         Unknown      Unknown              NaN  NaN  ...
# 6312                         Unknown      Unknown              NaN  NaN  ...
# 6313                         Unknown      Unknown              NaN  NaN  ...
#
#                Time          Investigator or Source original order  \
# 0             18h00                R. Collier, GSAF         6303.0
# 1     14h00  -15h00  K.McMurray, TrackingSharks.com         6302.0
# 2             07h45  K.McMurray, TrackingSharks.com         6301.0
# 3               NaN                  B. Myatt, GSAF         6300.0
# 4               NaN                       A .Kipper         6299.0
# ...             ...                             ...            ...
# 6309            NaN                             NaN         6309.0
# 6310            NaN                             NaN         6310.0
# 6311            NaN                             NaN            NaN
# 6312            NaN                             NaN            NaN
# 6313            NaN                             NaN            NaN
#
#      Case Number.1 Case Number.2                       pdf  \
# 0       2018.06.25    2018.06.25      2018.06.25-Wolfe.pdf
# 1       2018.06.18    2018.06.18    2018.06.18-McNeely.pdf
# 2       2018.06.09    2018.06.09     2018.06.09-Denges.pdf
# 3       2018.06.08    2018.06.08  2018.06.08-Arrawarra.pdf
# 4       2018.06.04    2018.06.04      2018.06.04-Ramos.pdf
# ...            ...           ...                       ...
# 6309           NaN           NaN                       NaN
# 6310           NaN           NaN                       NaN
# 6311           NaN           NaN                       NaN
# 6312           NaN           NaN                       NaN
# 6313           NaN           NaN                       NaN
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6309                                                NaN
# 6310                                                NaN
# 6311                                                NaN
# 6312                                                NaN
# 6313                                                NaN
#
#                                                    href Unnamed: 22  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
# ...                                                 ...         ...
# 6309                                                NaN         NaN
# 6310                                                NaN         NaN
# 6311                                                NaN         NaN
# 6312                                                NaN         NaN
# 6313                                                NaN         NaN
#
#      Unnamed: 23
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 6309         NaN
# 6310         NaN
# 6311         NaN
# 6312         NaN
# 6313         NaN
#
# [6314 rows x 24 columns]

# %% [markdown]
# # limpieza Name

# %%
shark_clean['Name'].value_counts()
# Out:
# male                  550
# female                 97
# boy                    23
# 2 males                16
# boat                   14
#                      ...
# Jonathan Popper         1
# Hercules Pretorius      1
# Pete Swenson            1
# Regan Readnour          1
# Jack Rochette           1
# Name: Name, Length: 5232, dtype: int64

# %%
shark_clean['Name']=shark_clean['Name'].str.replace\
('male|female|boy|2 males|boat|sailor|JapaneseUnknown|Anonymous|Unknowns|child|girl|a Unknown|Unidentified|\
fisherman| Unknown|a pearl diver|a soldier|IndianUnknown|a native|blackUnknown|\
ArabUnknown|AmericanUnknown|ZuluUnknown|JapaneseUnknown|\
2 fishermen|youngUnknown|FijianUnknown|Unknown x 2|unknown|3Unknown|aboriginalUnknown|\
Japanese diver|nativeUnknown|woman|2 women|RussianUnknown|dinghy|AUnknown'\
 ,'Unknown',regex=True)\
.fillna('Unknown')
shark_clean.sample(10)
# Out:
#      Case Number       Date  Year        Type           Country  \
# 315   2016.01.24 2016-01-24  2016  Unprovoked               USA
# 6086  1834.07.15        NaT  1834  Unprovoked  FRENCH POLYNESIA
# 3011  1981.09.28 1981-09-28  1981  Unprovoked               USA
# 6019  1852.08.07 1852-08-07  1852  Unprovoked             TONGA
# 3059  1980.08.10 1980-08-10  1980  Unprovoked               USA
# 3103  1979.04.08 1979-04-08  1979  Unprovoked               USA
# 5020  1931.06.04        NaT  1931  Unprovoked               USA
http://sharkattackfile.net/spreadsheets/pdf_di...         NaN
#
#      Unnamed: 23
# 315          NaN
# 6086         NaN
# 3011         NaN
# 6019         NaN
# 3059         NaN
# 3103         NaN
# 5020         NaN
# 1343         NaN
# 3516         NaN
# 1251         NaN
#
# [10 rows x 24 columns]

# %%
shark_clean['Name'].value_counts().sample(10)
# Out:
# Jeandre Nagel                                                                  1
# D. Martin                                                                      1
# Tommy Ryan                                                                     1
# James Edward Morgan                                                            1
# Jose                                                                           1
# Christian Frederick                                                            1
# Cuban refugees                                                                 1
# Frank Chorie                                                                   1
# rowUnknown, occupant: Joe Whitted, Christopher Quevedo & 2 Willard Brothers    1
# Gerald Perez                                                                   1
# Name: Name, dtype: int64

# %% [markdown]
# # limpieza sex

# %%
shark_clean['Sex ']=shark_clean['Sex '].fillna('ND')
shark_clean.sample(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/jibo16/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sex '
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-92-bce248baa982> in <module>
# ----> 1 shark_clean['Sex ']=shark_clean['Sex '].fillna('ND')
#       2 shark_clean.sample(10)
#
# /home/jibo16/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# /home/jibo16/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sex '

# %% [markdown]
# # limpieza Age

# %%
shark_clean['Age']

# %%
shark_clean['Age'] = shark_clean['Age'].fillna('15')

# %% [markdown]
# # limpieza de Injury

# %%
shark_clean['Injury'] = shark_clean['Injury'].fillna('Unknown')
shark_clean['Injury']

# %% [markdown]
# # limpieza de Fatal (Y/N)

# %%
shark_clean['Fatal (Y/N)'] = shark_clean['Fatal (Y/N)'].fillna('Unknown')

# %% [markdown]
# # limpieza de Species

# %%
shark_clean['Species ']=shark_clean['Species '].fillna('Unknown')
shark_clean['Species ']

# %% [markdown]
# # limpieza Time "Eliminar"

# %%
shark_clean['Time'].value_counts()

# %%
shark_clean['Time']=shark_clean['Time'].fillna('Unknown')
shark_clean

# %% [markdown]
# # limpieza investigator or source

# %%
shark_clean['Investigator or Source']=shark_clean['Investigator or Source'].fillna('Unknown')
shark_clean

# %%
shark_clean['Investigator or Source'].value_counts()

# %% [markdown]
# # limpieza original order

# %%
shark_clean['original order'] =shark_clean['original order'].fillna(shark_clean['original order'].mean())
shark_clean

# %%
shark_clean['original order']=shark_clean['original order'].astype({'original order': 'str'})

# %%
shark_clean.dtypes

# %%
shark_clean['original order'] = shark_clean['original order'].str.replace('\.[0-9]+','',regex=True)
shark_clean

# %%
shark_clean['original order']=shark_clean['original order'].astype({'original order':'int64'})

# %%
shark_clean.dtypes

# %%
shark_clean.sample(10)

# %% [markdown]
# # limpieza case number.1

# %%
shark_clean['Case Number.1']= shark_clean['Case Number.1'].fillna('2010.01.01')
shark_clean

# %%
shark_clean['Case Number.1']=shark_clean['Case Number.1'].replace('\.[a-z]|\.[A-Z]','',regex=True)

# %%
shark_clean['Case Number.1'] = pd.to_datetime(shark_clean['Case Number.1'], errors='coerce', infer_datetime_format=True)
shark_clean.dtypes

# %%
shark_clean['Case Number.1'].value_counts()

# %% [markdown]
# # limpieza case Number.2

# %%
shark_clean['Case Number.2']=shark_clean['Case Number.2'].fillna('2010.01.01')
shark_clean

# %%
shark_clean['Case Number.2'] = shark_clean['Case Number.2'].replace('\.[a-z]|\.[A-Z]','',regex=True)
shark_clean['Case Number.2'].value_counts()

# %%
shark_clean['Case Number.2'] = pd.to_datetime(shark_clean['Case Number.2'], errors='coerce', infer_datetime_format=True)
shark_clean.dtypes

# %%
shark_clean

# %%
shark_clean.to_csv('Clean.csv')

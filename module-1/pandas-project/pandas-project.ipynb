# %%
import pandas as pd
import xlrd
import re
attacks = pd.read_excel('C:/Users/Data Analyst/Documents/Otros/sharks.xlsx')
df = attacks
df.drop_duplicates()
# Out:
#      Case Number   Date    Year        Type    Country             Area  \
# 0     2018.06.25  43276  2018.0     Boating        USA       California
# 1     2018.06.18  43269  2018.0  Unprovoked        USA          Georgia
# 2     2018.06.09  43260  2018.0     Invalid        USA           Hawaii
# 3     2018.06.08  43259  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04  43255  2018.0    Provoked     MEXICO           Colima
# ...          ...    ...     ...         ...        ...              ...
# 6304           0    NaN     NaN         NaN        NaN              NaN
# 6305           0    NaN     NaN         NaN        NaN              NaN
# 6306           0    NaN     NaN         NaN        NaN              NaN
# 6307           0    NaN     NaN         NaN        NaN              NaN
# 6308           0    NaN     NaN         NaN        NaN              NaN
#
#                             Location     Activity             Name Sex   ...  \
# ...

# %%
df.drop([6302,6303,6304,6305,6306,6307,6308], inplace = True)

# %%
for i in df:
    df[i].fillna('Unknown', inplace = True)

# %%
df.Date = df.Date.str.replace(r'\bReported','')
df.Date = df.Date.str.replace(r'\bAfter','')
df.Date = df.Date.str.replace(r'\bBetween','')
df.Date = df.Date.str.replace(r'\bBefore','')
df.Date = df.Date.str.replace(r'\bSummer','')
df.Date = df.Date.str.replace(r'\bEarly','')
df.Date = df.Date.str.lstrip()

# %%
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%d/%B/%Y', errors = 'coerce')
print(set(df.Date))

# %%
df.drop(df.loc[df['Type']=='Unknown'].index, inplace=True)
df.Type.value_counts()
# Out:
# Unprovoked      4595
# Provoked         574
# Invalid          547
# Sea Disaster     239
# Boating          203
# Boat             137
# Questionable       2
# Boatomg            1
# Name: Type, dtype: int64

# %%
countries = ['USA', 'AUSTRALIA', 'SOUTH AFRICA','PAPUA NEW GUINEA', 'NEW ZELAND', 'BRAZIL', 'BAHAMAS', 'MEXICO', 'ITALY', 'FIJI','PILIPPINES', 'REUNION', 'NEW  CALEDONIA', 'CUBA' 'MOZAMBIQUE', 'ENGLAND']
df.Country = [df.drop(df.loc[df.Country[i]].index, inplace=True) for i in df.Country if i not in countries]

# %%
df.Name[df.Name.str.startswith('mal')]  ='Unknown'
df.Name[df.Name.str.startswith('fema')] = 'Unknown'
df.drop(df.loc[df['Name']=='Unknown'].index, inplace=True)
# Out:
# C:\Users\Data Analyst\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Data Analyst\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
j = df.Species.value_counts()
j.head(50)
# Out:
# White shark                                           157
# Shark involvement prior to death was not confirmed     74
# Tiger shark                                            66
# Shark involvement not confirmed                        63
# Bull shark                                             44
# Shark involvement prior to death unconfirmed           40
# 6' shark                                               37
# 1.8 m [6'] shark                                       34
# 4' shark                                               34
# 1.5 m [5'] shark                                       28
# 3' shark                                               26
# 1.2 m [4'] shark                                       25
# 5' shark                                               23
# Questionable incident                                  23
# 4' to 5' shark                                         22
# Wobbegong shark                                        21
# ...

# %%
df.drop(df.loc[df['Species']=='Invalid'].index, inplace=True)
df.drop(df.loc[df['Species']=='Questionable'].index, inplace=True)
df1 = df[df['Species'].str.contains('white') | df['Species'].str.contains('tiger') |
         df['Species'].str.contains('lemon')|df['Species'].str.contains('Tiger')|
       df['Species'].str.contains('White')|df['Species'].str.contains('tiger')|
        df['Species'].str.contains('Zambesi')|df['Species'].str.contains('Hammerhead')|
        df['Species'].str.contains('Nurse')|df['Species'].str.contains('nurse')|
        df['Species'].str.contains('Whaler')| df['Species'].str.contains('bull')|
        df['Species'].str.contains('Bull')|df['Species'].str.contains('Lemon')|
        df['Species'].str.contains('blue')|df['Species'].str.contains('Blue')|
        df['Species'].str.contains('spinner')|df['Species'].str.contains('Spinner')|
        df['Species'].str.contains('blacktip')| df['Species'].str.contains('Bronze')|
        df['Species'].str.contains('Mako')|df['Species'].str.contains('Raggedtooth')|
        df['Species'].str.contains('Wobbegong') |df['Species'].str.contains('mako') |
         df['Species'].str.contains('Blacktip') |df['Species'].str.contains('Spinner')
        
        ]

# %%
import pandas as pd
import json
import requests
from pandas.io.json import json_normalize
import time

# %%
# Getting Credentials
user = 'juliocrn94'
key_f = open('../token.txt','r')
key = key_f.read()
print(key)
# Out:
# 7cc2a6c2b75e5532d11b5584d8b5970e6fa880b0

# %% [markdown]
# # Challenge 1: Fork Languages

# %%
m_owner = "ironhack-datalabs"
repo = "datamex0120"
base_url = "https://api.github.com/"
forks = base_url+"repos/{}/{}/forks".format(owner,repo)
print(forks)
# Out:
# https://api.github.com/repos/rossberto/datamex0120/forks

# %%
response = requests.get(forks, auth=(user,key))
results = response.json()
#forks_df = pd.DataFrame(results)
#forks_df
forks_df=pd.DataFrame(json_normalize(results))

#l_user = list(forks_df['owner.login'])
#l_user
#l_forks = list(forks_df['language'])
forks_df
#l_forks
# Out:
#            id                           node_id         name  \
# 0   232196826  MDEwOlJlcG9zaXRvcnkyMzIxOTY4MjY=  datamex0120
# 1   232180648  MDEwOlJlcG9zaXRvcnkyMzIxODA2NDg=  datamex0120
# 2   232146333  MDEwOlJlcG9zaXRvcnkyMzIxNDYzMzM=  datamex0120
# 3   232144911  MDEwOlJlcG9zaXRvcnkyMzIxNDQ5MTE=  datamex0120
# 4   232143481  MDEwOlJlcG9zaXRvcnkyMzIxNDM0ODE=  datamex0120
# 5   232143418  MDEwOlJlcG9zaXRvcnkyMzIxNDM0MTg=  datamex0120
# 6   232143415  MDEwOlJlcG9zaXRvcnkyMzIxNDM0MTU=  datamex0120
# 7   232143407  MDEwOlJlcG9zaXRvcnkyMzIxNDM0MDc=  datamex0120
# 8   232143260  MDEwOlJlcG9zaXRvcnkyMzIxNDMyNjA=  datamex0120
# 9   232143225  MDEwOlJlcG9zaXRvcnkyMzIxNDMyMjU=  datamex0120
# 10  232143208  MDEwOlJlcG9zaXRvcnkyMzIxNDMyMDg=  datamex0120
# 11  232143202  MDEwOlJlcG9zaXRvcnkyMzIxNDMyMDI=  datamex0120
#
#                         full_name  private  \
# 0   SaulMonzalvoRojas/datamex0120    False
# 1             axme100/datamex0120    False
# 2         ta-data-mex/datamex0120    False
# 3              vannia/datamex0120    False
# 4      rubenperez1982/datamex0120    False
# 5         hatchdavid1/datamex0120    False
# 6            ArturoQR/datamex0120    False
# 7           YonatanRA/datamex0120    False
# 8              jibo16/datamex0120    False
# 9          juliocrn94/datamex0120    False
# 10          albertoid/datamex0120    False
# 11          rossberto/datamex0120    False
#
#                                             html_url description  fork  \
# 0   https://github.com/SaulMonzalvoRojas/datamex0120        None  True
# 1             https://github.com/axme100/datamex0120        None  True
# 2         https://github.com/ta-data-mex/datamex0120        None  True
# 3              https://github.com/vannia/datamex0120        None  True
# 4      https://github.com/rubenperez1982/datamex0120        None  True
# 5         https://github.com/hatchdavid1/datamex0120        None  True
# 6            https://github.com/ArturoQR/datamex0120        None  True
# 7           https://github.com/YonatanRA/datamex0120        None  True
# 8              https://github.com/jibo16/datamex0120        None  True
# 9          https://github.com/juliocrn94/datamex0120        None  True
# 10          https://github.com/albertoid/datamex0120        None  True
# 11          https://github.com/rossberto/datamex0120        None  True
#
#                                                   url  \
# 0   https://api.github.com/repos/SaulMonzalvoRojas...
# 1    https://api.github.com/repos/axme100/datamex0120
# 2   https://api.github.com/repos/ta-data-mex/datam...
# 3     https://api.github.com/repos/vannia/datamex0120
# 4   https://api.github.com/repos/rubenperez1982/da...
# 5   https://api.github.com/repos/hatchdavid1/datam...
# 6   https://api.github.com/repos/ArturoQR/datamex0120
# 7   https://api.github.com/repos/YonatanRA/datamex...
# 8     https://api.github.com/repos/jibo16/datamex0120
# 9   https://api.github.com/repos/juliocrn94/datame...
# 10  https://api.github.com/repos/albertoid/datamex...
# 11  https://api.github.com/repos/rossberto/datamex...
#
#                                             forks_url  ... owner.type  \
# 0   https://api.github.com/repos/SaulMonzalvoRojas...  ...       User
# 1   https://api.github.com/repos/axme100/datamex01...  ...       User
# 2   https://api.github.com/repos/ta-data-mex/datam...  ...       User
# 3   https://api.github.com/repos/vannia/datamex012...  ...       User
# 4   https://api.github.com/repos/rubenperez1982/da...  ...       User
# 5   https://api.github.com/repos/hatchdavid1/datam...  ...       User
# 6   https://api.github.com/repos/ArturoQR/datamex0...  ...       User
# 7   https://api.github.com/repos/YonatanRA/datamex...  ...       User
# 8   https://api.github.com/repos/jibo16/datamex012...  ...       User
# 9   https://api.github.com/repos/juliocrn94/datame...  ...       User
# 10  https://api.github.com/repos/albertoid/datamex...  ...       User
# 11  https://api.github.com/repos/rossberto/datamex...  ...       User
#
#    owner.site_admin license.key                            license.name  \
# 0             False    agpl-3.0  GNU Affero General Public License v3.0
# 1             False    agpl-3.0  GNU Affero General Public License v3.0
# 2             False    agpl-3.0  GNU Affero General Public License v3.0
# 3             False    agpl-3.0  GNU Affero General Public License v3.0
# 4             False    agpl-3.0  GNU Affero General Public License v3.0
# 5             False    agpl-3.0  GNU Affero General Public License v3.0
# 6             False    agpl-3.0  GNU Affero General Public License v3.0
# 7             False    agpl-3.0  GNU Affero General Public License v3.0
# 8             False    agpl-3.0  GNU Affero General Public License v3.0
# 9             False    agpl-3.0  GNU Affero General Public License v3.0
# 10            False    agpl-3.0  GNU Affero General Public License v3.0
# 11            False    agpl-3.0  GNU Affero General Public License v3.0
#
#    license.spdx_id                               license.url  \
# 0         AGPL-3.0  https://api.github.com/licenses/agpl-3.0
# 1         AGPL-3.0  https://api.github.com/licenses/agpl-3.0
# 2         AGPL-3.0  https://api.github.com/licenses/agpl-3.0
# 3         AGPL-3.0  https://api.github.com/licenses/agpl-3.0
# 4         AGPL-3.0  https://api.github.com/licenses/agpl-3.0
# 5         AGPL-3.0  https://api.github.com/licenses/agpl-3.0
# 6         AGPL-3.0  https://api.github.com/licenses/agpl-3.0
# 7         AGPL-3.0  https://api.github.com/licenses/agpl-3.0
# 8         AGPL-3.0  https://api.github.com/licenses/agpl-3.0
# 9         AGPL-3.0  https://api.github.com/licenses/agpl-3.0
# 10        AGPL-3.0  https://api.github.com/licenses/agpl-3.0
# 11        AGPL-3.0  https://api.github.com/licenses/agpl-3.0
#
#      license.node_id permissions.admin permissions.push permissions.pull
# 0   MDc6TGljZW5zZTE=             False            False             True
# 1   MDc6TGljZW5zZTE=             False            False             True
# 2   MDc6TGljZW5zZTE=             False            False             True
# 3   MDc6TGljZW5zZTE=             False            False             True
# 4   MDc6TGljZW5zZTE=             False            False             True
# 5   MDc6TGljZW5zZTE=             False            False             True
# 6   MDc6TGljZW5zZTE=             False            False             True
# 7   MDc6TGljZW5zZTE=             False            False             True
# 8   MDc6TGljZW5zZTE=             False            False             True
# 9   MDc6TGljZW5zZTE=              True             True             True
# 10  MDc6TGljZW5zZTE=             False            False             True
# 11  MDc6TGljZW5zZTE=             False            False             True
#
# [12 rows x 97 columns]

# %%
l_user = list(forks_df['owner.login'])
l_user
# Out:
# ['SaulMonzalvoRojas',
#  'axme100',
#  'ta-data-mex',
#  'vannia',
#  'rubenperez1982',
#  'hatchdavid1',
#  'ArturoQR',
#  'YonatanRA',
#  'jibo16',
#  'juliocrn94',
#  'albertoid',
#  'rossberto']

# %%
repo = "datamex0120"
base_url = "https://api.github.com/"

for owner in l_user:
    forks_2 = base_url+"repos/{}/{}/forks".format(owner,repo)
    response_2 = requests.get(forks_2, auth=(user,key))
    results_2 = response_2.json()
    print(owner,' ',len(results_2))
    print(results_2)
    if len(results_2) == 0:
        continue
    if len(results_2)>0:
        forks_df_2 =pd.DataFrame(json_normalize(results_2))
        forks_df = forks_df.append(forks_df_2)
# Out:
# SaulMonzalvoRojas   0
# []
# axme100   0
# []
# ta-data-mex   0
# []
# vannia   0
# []
# rubenperez1982   0
# []
# hatchdavid1   0
# []
# ArturoQR   0
# []
# YonatanRA   2
# [{'id': 234819289, 'node_id': 'MDEwOlJlcG9zaXRvcnkyMzQ4MTkyODk=', 'name': 'datamex0120', 'full_name': 'germfy/datamex0120', 'private': False, 'owner': {'login': 'germfy', 'id': 11635442, 'node_id': 'MDQ6VXNlcjExNjM1NDQy', 'avatar_url': 'https://avatars0.githubusercontent.com/u/11635442?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/germfy', 'html_url': 'https://github.com/germfy', 'followers_url': 'https://api.github.com/users/germfy/followers', 'following_url': 'https://api.github.com/users/germfy/following{/other_user}', 'gists_url': 'https://api.github.com/users/germfy/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/germfy/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/germfy/subscriptions', 'organizations_url': 'https://api.github.com/users/germfy/orgs', 'repos_url': 'https://api.github.com/users/germfy/repos', 'events_url': 'https://api.github.com/users/germfy/events{/privacy}', 'received_events_url': 'https://api.github.com/users/germfy/received_events', 'type': 'User', 'site_admin': False}, 'html_url': 'https://github.com/germfy/datamex0120', 'description': None, 'fork': True, 'url': 'https://api.github.com/repos/germfy/datamex0120', 'forks_url': 'https://api.github.com/repos/germfy/datamex0120/forks', 'keys_url': 'https://api.github.com/repos/germfy/datamex0120/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/germfy/datamex0120/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/germfy/datamex0120/teams', 'hooks_url': 'https://api.github.com/repos/germfy/datamex0120/hooks', 'issue_events_url': 'https://api.github.com/repos/germfy/datamex0120/issues/events{/number}', 'events_url': 'https://api.github.com/repos/germfy/datamex0120/events', 'assignees_url': 'https://api.github.com/repos/germfy/datamex0120/assignees{/user}', 'branches_url': 'https://api.github.com/repos/germfy/datamex0120/branches{/branch}', 'tags_url': 'https://api.github.com/repos/germfy/datamex0120/tags', 'blobs_url': 'https://api.github.com/repos/germfy/datamex0120/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/germfy/datamex0120/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/germfy/datamex0120/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/germfy/datamex0120/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/germfy/datamex0120/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/germfy/datamex0120/languages', 'stargazers_url': 'https://api.github.com/repos/germfy/datamex0120/stargazers', 'contributors_url': 'https://api.github.com/repos/germfy/datamex0120/contributors', 'subscribers_url': 'https://api.github.com/repos/germfy/datamex0120/subscribers', 'subscription_url': 'https://api.github.com/repos/germfy/datamex0120/subscription', 'commits_url': 'https://api.github.com/repos/germfy/datamex0120/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/germfy/datamex0120/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/germfy/datamex0120/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/germfy/datamex0120/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/germfy/datamex0120/contents/{+path}', 'compare_url': 'https://api.github.com/repos/germfy/datamex0120/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/germfy/datamex0120/merges', 'archive_url': 'https://api.github.com/repos/germfy/datamex0120/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/germfy/datamex0120/downloads', 'issues_url': 'https://api.github.com/repos/germfy/datamex0120/issues{/number}', 'pulls_url': 'https://api.github.com/repos/germfy/datamex0120/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/germfy/datamex0120/milestones{/number}', 'notifications_url': 'https://api.github.com/repos/germfy/datamex0120/notifications{?since,all,participating}', 'labels_url': 'https://api.github.com/repos/germfy/d ...
# jibo16   0
# []
# juliocrn94   0
# []
# albertoid   0
# []
# rossberto   0
# []

# %%
#All languages from Main Forks and 2level Forks:
l_langs = list(forks_df['language'])
print(len(l_langs))
print(l_langs)
forks_df.reset_index()
forks_df.head()
# Out:
# 14
# ['Jupyter Notebook', None, None, None, None, 'Jupyter Notebook', 'Jupyter Notebook', None, 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', None, None]
#           id                           node_id         name  \
# 0  232196826  MDEwOlJlcG9zaXRvcnkyMzIxOTY4MjY=  datamex0120
# 1  232180648  MDEwOlJlcG9zaXRvcnkyMzIxODA2NDg=  datamex0120
# 2  232146333  MDEwOlJlcG9zaXRvcnkyMzIxNDYzMzM=  datamex0120
# 3  232144911  MDEwOlJlcG9zaXRvcnkyMzIxNDQ5MTE=  datamex0120
# 4  232143481  MDEwOlJlcG9zaXRvcnkyMzIxNDM0ODE=  datamex0120
#
#                        full_name  private  \
# 0  SaulMonzalvoRojas/datamex0120    False
# 1            axme100/datamex0120    False
# 2        ta-data-mex/datamex0120    False
# 3             vannia/datamex0120    False
# 4     rubenperez1982/datamex0120    False
#
#                                            html_url description  fork  \
# 0  https://github.com/SaulMonzalvoRojas/datamex0120        None  True
# 1            https://github.com/axme100/datamex0120        None  True
# 2        https://github.com/ta-data-mex/datamex0120        None  True
# 3             https://github.com/vannia/datamex0120        None  True
# 4     https://github.com/rubenperez1982/datamex0120        None  True
#
#                                                  url  \
# 0  https://api.github.com/repos/SaulMonzalvoRojas...
# 1   https://api.github.com/repos/axme100/datamex0120
# 2  https://api.github.com/repos/ta-data-mex/datam...
# 3    https://api.github.com/repos/vannia/datamex0120
# 4  https://api.github.com/repos/rubenperez1982/da...
#
#                                            forks_url  ... owner.type  \
# 0  https://api.github.com/repos/SaulMonzalvoRojas...  ...       User
# 1  https://api.github.com/repos/axme100/datamex01...  ...       User
# 2  https://api.github.com/repos/ta-data-mex/datam...  ...       User
# 3  https://api.github.com/repos/vannia/datamex012...  ...       User
# 4  https://api.github.com/repos/rubenperez1982/da...  ...       User
#
#   owner.site_admin license.key                            license.name  \
# 0            False    agpl-3.0  GNU Affero General Public License v3.0
# 1            False    agpl-3.0  GNU Affero General Public License v3.0
# 2            False    agpl-3.0  GNU Affero General Public License v3.0
# 3            False    agpl-3.0  GNU Affero General Public License v3.0
# 4            False    agpl-3.0  GNU Affero General Public License v3.0
#
#   license.spdx_id                               license.url   license.node_id  \
# 0        AGPL-3.0  https://api.github.com/licenses/agpl-3.0  MDc6TGljZW5zZTE=
# 1        AGPL-3.0  https://api.github.com/licenses/agpl-3.0  MDc6TGljZW5zZTE=
# 2        AGPL-3.0  https://api.github.com/licenses/agpl-3.0  MDc6TGljZW5zZTE=
# 3        AGPL-3.0  https://api.github.com/licenses/agpl-3.0  MDc6TGljZW5zZTE=
# 4        AGPL-3.0  https://api.github.com/licenses/agpl-3.0  MDc6TGljZW5zZTE=
#
#   permissions.admin permissions.push permissions.pull
# 0             False            False             True
# 1             False            False             True
# 2             False            False             True
# 3             False            False             True
# 4             False            False             True
#
# [5 rows x 97 columns]

# %% [markdown]
# # Challenge 2: Count Commits

# %%
commits = base_url + 'repos/{}/{}/commits'.format(m_owner,repo)
print(commits)
# Out:
# https://api.github.com/repos/ironhack-datalabs/datamex0120/commits

# %%
response = requests.get(commits, auth=(user,key))
results = response.json()
commits_df=pd.DataFrame(json_normalize(results))

# %%
commits_df.head()
# Out:
#                                         sha  \
# 0  ad0710ecb264769fbdb8e8ed3e14f9bf5a5223f9
#
#                                              node_id  \
# 0  MDY6Q29tbWl0MjMyMTQxMTc1OmFkMDcxMGVjYjI2NDc2OW...
#
#                                                  url  \
# 0  https://api.github.com/repos/ironhack-datalabs...
#
#                                             html_url  \
# 0  https://github.com/ironhack-datalabs/datamex01...
#
#                                         comments_url parents  \
# 0  https://api.github.com/repos/ironhack-datalabs...      []
#
#   commit.author.name commit.author.email    commit.author.date  \
# 0          YonatanRA       yeho@mail.com  2020-01-06T16:34:12Z
#
#   commit.committer.name  ...  \
# 0             YonatanRA  ...
#
#                              committer.following_url  \
# 0  https://api.github.com/users/YonatanRA/followi...
#
#                                  committer.gists_url  \
# 0  https://api.github.com/users/YonatanRA/gists{/...
#
#                                committer.starred_url  \
# 0  https://api.github.com/users/YonatanRA/starred...
#
#                          committer.subscriptions_url  \
# 0  https://api.github.com/users/YonatanRA/subscri...
#
#                    committer.organizations_url  \
# 0  https://api.github.com/users/YonatanRA/orgs
#
#                             committer.repos_url  \
# 0  https://api.github.com/users/YonatanRA/repos
#
#                                 committer.events_url  \
# 0  https://api.github.com/users/YonatanRA/events{...
#
#                        committer.received_events_url committer.type  \
# 0  https://api.github.com/users/YonatanRA/receive...           User
#
#   committer.site_admin
# 0                False
#
# [1 rows x 57 columns]

# %% [markdown]
# # Challenge 3: Hidden Cold Joke

# %%
repo_3 = 'scavenger'
owner_3 = 'ironhack-datalabs'
base_url = "https://api.github.com/"
content = base_url+"repos/{}/{}/contents".format(owner_3,repo_3)
# content -> GET /repos/:owner/:repo/contents/:path

# %%
res = requests.get(content, auth=(user,key))
results = res.json()

# %%
content = pd.DataFrame(results)
content

content[content['type']=='dir']
# Out:
#      name   path                                       sha  size  \
# 1   15024  15024  2945e51c87ad5da893c954afcf092f06343bbb7d     0
# 2   15534  15534  5af6f2a7287e4191f39e55693fc1e9c8918d1d3a     0
# 3   17020  17020  9c49f920aa4d9433fa99a5824128f0e6b90ec5f2     0
# 4   30351  30351  c488d7f64088c852e22067d48fdc64ee3670f3ba     0
# 5   40303  40303  30193d9cf62b07bcbb6366513ff03596861f2d29     0
# 6   44639  44639  22fc3d5c2db80822c351edb2248f3491c8ebda86     0
# 7   45525  45525  6a4a88cd9084110c8646c3cfd84dfe96b300a4a7     0
# 8   47222  47222  c7001604cdadc2fe7b82e0f6996690718cac6941     0
# 9   47830  47830  f84882ad7560fd2b8c6a0867bc707ce9009ef288     0
# 10  49418  49418  46bc658c09589d9023246b00e848ce97d30d4989     0
# 11  50896  50896  e47a7a35a19f80694587330c57d94e28d3b4c054     0
# 12  55417  55417  636fa555a2ee752759144a268fd860feb2b6fd2d     0
# 13  55685  55685  a00a8148a88287508a867616d7063786d3d5d4ff     0
# 14  60224  60224  28d70fba98bfacfaa5e5544b2eff6b61c9e8f57b     0
# 15  64880  64880  88b159d6f73378e6968bb35ccfd8e3ad0cc462d2     0
# 16  66032  66032  0230fa6fa1ccf49ab976fbbfc9eb838094779785     0
# 17  68848  68848  ed2f90be6835e7e74c283aedba1942b788754d32     0
# 18  70751  70751  a5d9391003b67cecf3c336398ec38cfa75a689b7     0
# 19  70985  70985  d1a654c5811f52ec8a101652b0a04367644eab99     0
# 20  88596  88596  f294d2a0e55a4bab12625a7f709b44450a5e4648     0
# 21  89046  89046  5f3ef5f14cf72bbe03a24b69777ba02f19a3adb5     0
# 22  89338  89338  79c94a4032a927b2af52cc6da4ce27eb2abbf55e     0
# 23  91701  91701  0ad19115f0b56c3cd10cb7e077140c201b527301     0
# 24  97881  97881  c369c43c17ec44cc3e66dd27f8e557f9d15d40f4     0
# 25  98750  98750  cdc23915e0a5179127458431986ba3750840a924     0
#
#                                                   url  \
# 1   https://api.github.com/repos/ironhack-datalabs...
# 2   https://api.github.com/repos/ironhack-datalabs...
# 3   https://api.github.com/repos/ironhack-datalabs...
# 4   https://api.github.com/repos/ironhack-datalabs...
# 5   https://api.github.com/repos/ironhack-datalabs...
# 6   https://api.github.com/repos/ironhack-datalabs...
# 7   https://api.github.com/repos/ironhack-datalabs...
# 8   https://api.github.com/repos/ironhack-datalabs...
# 9   https://api.github.com/repos/ironhack-datalabs...
# 10  https://api.github.com/repos/ironhack-datalabs...
# 11  https://api.github.com/repos/ironhack-datalabs...
# 12  https://api.github.com/repos/ironhack-datalabs...
# 13  https://api.github.com/repos/ironhack-datalabs...
# 14  https://api.github.com/repos/ironhack-datalabs...
# 15  https://api.github.com/repos/ironhack-datalabs...
# 16  https://api.github.com/repos/ironhack-datalabs...
# 17  https://api.github.com/repos/ironhack-datalabs...
# 18  https://api.github.com/repos/ironhack-datalabs...
# 19  https://api.github.com/repos/ironhack-datalabs...
# 20  https://api.github.com/repos/ironhack-datalabs...
# 21  https://api.github.com/repos/ironhack-datalabs...
# 22  https://api.github.com/repos/ironhack-datalabs...
# 23  https://api.github.com/repos/ironhack-datalabs...
# 24  https://api.github.com/repos/ironhack-datalabs...
# 25  https://api.github.com/repos/ironhack-datalabs...
#
#                                              html_url  \
# 1   https://github.com/ironhack-datalabs/scavenger...
# 2   https://github.com/ironhack-datalabs/scavenger...
# 3   https://github.com/ironhack-datalabs/scavenger...
# 4   https://github.com/ironhack-datalabs/scavenger...
# 5   https://github.com/ironhack-datalabs/scavenger...
# 6   https://github.com/ironhack-datalabs/scavenger...
# 7   https://github.com/ironhack-datalabs/scavenger...
# 8   https://github.com/ironhack-datalabs/scavenger...
# 9   https://github.com/ironhack-datalabs/scavenger...
# 10  https://github.com/ironhack-datalabs/scavenger...
# 11  https://github.com/ironhack-datalabs/scavenger...
# 12  https://github.com/ironhack-datalabs/scavenger...
# 13  https://github.com/ironhack-datalabs/scavenger...
# 14  https://github.com/ironhack-datalabs/scavenger...
# 15  https://github.com/ironhack-datalabs/scavenger...
# 16  https://github.com/ironhack-datalabs/scavenger...
# 17  https://github.com/ironhack-datalabs/scavenger...
# 18  https://github.com/ironhack-datalabs/scavenger...
# 19  https://github.com/ironhack-datalabs/scavenger...
# 20  https://github.com/ironhack-datalabs/scavenger...
# 21  https://github.com/ironhack-datalabs/scavenger...
# 22  https://github.com/ironhack-datalabs/scavenger...
# 23  https://github.com/ironhack-datalabs/scavenger...
# 24  https://github.com/ironhack-datalabs/scavenger...
# 25  https://github.com/ironhack-datalabs/scavenger...
#
#                                               git_url download_url type  \
# 1   https://api.github.com/repos/ironhack-datalabs...         None  dir
# 2   https://api.github.com/repos/ironhack-datalabs...         None  dir
# 3   https://api.github.com/repos/ironhack-datalabs...         None  dir
# 4   https://api.github.com/repos/ironhack-datalabs...         None  dir
# 5   https://api.github.com/repos/ironhack-datalabs...         None  dir
# 6   https://api.github.com/repos/ironhack-datalabs...         None  dir
# 7   https://api.github.com/repos/ironhack-datalabs...         None  dir
# 8   https://api.github.com/repos/ironhack-datalabs...         None  dir
# 9   https://api.github.com/repos/ironhack-datalabs...         None  dir
# 10  https://api.github.com/repos/ironhack-datalabs...         None  dir
# 11  https://api.github.com/repos/ironhack-datalabs...         None  dir
# 12  https://api.github.com/repos/ironhack-datalabs...         None  dir
# 13  https://api.github.com/repos/ironhack-datalabs...         None  dir
# 14  https://api.github.com/repos/ironhack-datalabs...         None  dir
# 15  https://api.github.com/repos/ironhack-datalabs...         None  dir
# 16  https://api.github.com/repos/ironhack-datalabs...         None  dir
# 17  https://api.github.com/repos/ironhack-datalabs...         None  dir
# 18  https://api.github.com/repos/ironhack-datalabs...         None  dir
# 19  https://api.github.com/repos/ironhack-datalabs...         None  dir
# 20  https://api.github.com/repos/ironhack-datalabs...         None  dir
# 21  https://api.github.com/repos/ironhack-datalabs...         None  dir
# 22  https://api.github.com/repos/ironhack-datalabs...         None  dir
# 23  https://api.github.com/repos/ironhack-datalabs...         None  dir
# 24  https://api.github.com/repos/ironhack-datalabs...         None  dir
# 25  https://api.github.com/repos/ironhack-datalabs...         None  dir
#
#                                                _links
# 1   {'self': 'https://api.github.com/repos/ironhac...
# 2   {'self': 'https://api.github.com/repos/ironhac...
# 3   {'self': 'https://api.github.com/repos/ironhac...
# 4   {'self': 'https://api.github.com/repos/ironhac...
# 5   {'self': 'https://api.github.com/repos/ironhac...
# 6   {'self': 'https://api.github.com/repos/ironhac...
# 7   {'self': 'https://api.github.com/repos/ironhac...
# 8   {'self': 'https://api.github.com/repos/ironhac...
# 9   {'self': 'https://api.github.com/repos/ironhac...
# 10  {'self': 'https://api.github.com/repos/ironhac...
# 11  {'self': 'https://api.github.com/repos/ironhac...
# 12  {'self': 'https://api.github.com/repos/ironhac...
# 13  {'self': 'https://api.github.com/repos/ironhac...
# 14  {'self': 'https://api.github.com/repos/ironhac...
# 15  {'self': 'https://api.github.com/repos/ironhac...
# 16  {'self': 'https://api.github.com/repos/ironhac...
# 17  {'self': 'https://api.github.com/repos/ironhac...
# 18  {'self': 'https://api.github.com/repos/ironhac...
# 19  {'self': 'https://api.github.com/repos/ironhac...
# 20  {'self': 'https://api.github.com/repos/ironhac...
# 21  {'self': 'https://api.github.com/repos/ironhac...
# 22  {'self': 'https://api.github.com/repos/ironhac...
# 23  {'self': 'https://api.github.com/repos/ironhac...
# 24  {'self': 'https://api.github.com/repos/ironhac...
# 25  {'self': 'https://api.github.com/repos/ironhac...

# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
apiUrl = 'https://api.github.com'
datamexEndpoint = '/repos/rossberto/scavenger/commits?since=2019-12-30T00:17:44Z' #I used a personal repo and limited from decembre 2019

token = '29284a2e99021cffa57320e5b3179e4703e6bbf2'

# %%
response = requests.get(apiUrl+datamexEndpoint, headers={'Authorization':'token ' +token})
results = response.json()
pd.DataFrame(results)
# Out:
#                                         sha  \
# 0  d377de7deb582effc23544191c3fd16d7d473d2f
# 1  a52654be15648e6416abd0b0f3764283d42be419
# 2  947b8477dd1e05eb3c1ddd07543fbff0e66d426a
# 3  19be5509e7e3b809a912dae29c412bbd2d5573af
# 4  227c041fbd4c15f6922d7f3dfa329773f6b1b18c
# 5  309e7521a2bac29ffa6d52daab76c02894e8f846
#
#                                              node_id  \
# 0  MDY6Q29tbWl0MjEzMTk4NjY4OmQzNzdkZTdkZWI1ODJlZm...
# 1  MDY6Q29tbWl0MjEzMTk4NjY4OmE1MjY1NGJlMTU2NDhlNj...
# 2  MDY6Q29tbWl0MjEzMTk4NjY4Ojk0N2I4NDc3ZGQxZTA1ZW...
# 3  MDY6Q29tbWl0MjEzMTk4NjY4OjE5YmU1NTA5ZTdlM2I4MD...
# 4  MDY6Q29tbWl0MjEzMTk4NjY4OjIyN2MwNDFmYmQ0YzE1Zj...
# 5  MDY6Q29tbWl0MjEzMTk4NjY4OjMwOWU3NTIxYTJiYWMyOW...
#
#                                               commit  \
# 0  {'author': {'name': 'ross', 'email': 'dev@rros...
# 1  {'author': {'name': 'ross', 'email': 'dev@rros...
# 2  {'author': {'name': 'ross', 'email': 'dev@rros...
# 3  {'author': {'name': 'ross', 'email': 'dev@rros...
# ...

# %%
results = response.json()
flattened_data = json_normalize(results)

# %%
flattened_data.columns
# Out:
# Index(['sha', 'node_id', 'url', 'html_url', 'comments_url', 'parents',
#        'commit.author.name', 'commit.author.email', 'commit.author.date',
#        'commit.committer.name', 'commit.committer.email',
#        'commit.committer.date', 'commit.message', 'commit.tree.sha',
#        'commit.tree.url', 'commit.url', 'commit.comment_count',
#        'commit.verification.verified', 'commit.verification.reason',
#        'commit.verification.signature', 'commit.verification.payload',
#        'author.login', 'author.id', 'author.node_id', 'author.avatar_url',
#        'author.gravatar_id', 'author.url', 'author.html_url',
#        'author.followers_url', 'author.following_url', 'author.gists_url',
#        'author.starred_url', 'author.subscriptions_url',
#        'author.organizations_url', 'author.repos_url', 'author.events_url',
#        'author.received_events_url', 'author.type', 'author.site_admin',
#        'committer.login', 'committer.id', 'committer.node_id',
# ...

# %%
flattened_data[['commit.author.name', 'commit.author.date']]
# Out:
#    commit.author.name    commit.author.date
# 0                ross  2020-01-04T22:26:06Z
# 1                ross  2020-01-04T22:12:28Z
# 2                ross  2020-01-04T22:00:37Z
# 3                ross  2020-01-04T21:53:27Z
# 4                ross  2019-12-30T02:29:17Z
# 5                ross  2019-12-30T00:17:44Z
# 6                ross  2019-12-29T21:38:38Z
# 7                ross  2019-12-29T18:50:21Z
# 8                ross  2019-12-28T19:35:30Z
# 9                ross  2019-12-28T19:32:37Z
# 10               ross  2019-12-23T23:18:33Z
# 11               ross  2019-12-23T22:07:30Z
# 12               ross  2019-12-23T22:01:33Z
# 13               ross  2019-12-23T21:54:55Z
# 14               ross  2019-12-23T21:46:17Z
# 15               ross  2019-12-23T21:21:20Z
# 16               ross  2019-12-23T15:57:49Z
# 17               ross  2019-12-23T05:45:45Z
# 18               ross  2019-12-23T01:05:13Z
# 19               ross  2019-12-22T23:10:47Z
# ...

# %%
flattened_data['commit.author.name'].value_counts()
# Out:
# ross    6
# Name: commit.author.name, dtype: int64

# %%
indexes = flattened_data['commit.author.name'].value_counts().index
commiters = []
for i in indexes:
    commiters.append(i)
    
commiters
# Out:
# ['ross']

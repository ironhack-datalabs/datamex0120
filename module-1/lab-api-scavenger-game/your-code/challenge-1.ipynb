# %%
import json
import requests

# %%
apiUrl = 'https://api.github.com'
rossEndpoint = '/users/rossberto/repos'# '/user/repos'
ironEndpoint = '/users/ironhack-datalabs/repos'

# %%
token = '29284a2e99021cffa57320e5b3179e4703e6bbf2'

# %%
response = requests.get(apiUrl+ironEndpoint, headers={'Authorization':'token ' +token})
results = response.json()
results
# Out:
# [{'id': 169605092,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNjk2MDUwOTI=',
#   'name': 'bcn-feb-2019',
#   'full_name': 'ironhack-datalabs/bcn-feb-2019',
#   'private': False,
#   'owner': {'login': 'ironhack-datalabs',
#    'id': 44225188,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/44225188?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ironhack-datalabs',
#    'html_url': 'https://github.com/ironhack-datalabs',
#    'followers_url': 'https://api.github.com/users/ironhack-datalabs/followers',
#    'following_url': 'https://api.github.com/users/ironhack-datalabs/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ironhack-datalabs/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ironhack-datalabs/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ironhack-datalabs/subscriptions',
# ...

# %%
import pandas as pd

repos = pd.DataFrame(results)
repos
# Out:
#            id                           node_id                        name  \
# 0   169605092  MDEwOlJlcG9zaXRvcnkxNjk2MDUwOTI=                bcn-feb-2019
# 1   170384482  MDEwOlJlcG9zaXRvcnkxNzAzODQ0ODI=        bcn-feb-2019-prework
# 2   231368458  MDEwOlJlcG9zaXRvcnkyMzEzNjg0NTg=              data-ber-01-20
# 3   213957020  MDEwOlJlcG9zaXRvcnkyMTM5NTcwMjA=              data-ber-10-19
# 4   188433440  MDEwOlJlcG9zaXRvcnkxODg0MzM0NDA=              databcn0519-pt
# 5   188459756  MDEwOlJlcG9zaXRvcnkxODg0NTk3NTY=                 databer0619
# 6   196546532  MDEwOlJlcG9zaXRvcnkxOTY1NDY1MzI=       databer0619-solutions
# 7   198647222  MDEwOlJlcG9zaXRvcnkxOTg2NDcyMjI=                 datalis0819
# 8   167007163  MDEwOlJlcG9zaXRvcnkxNjcwMDcxNjM=                 datamad0119
# 9   233579456  MDEwOlJlcG9zaXRvcnkyMzM1Nzk0NTY=                 datamad0120
# 10  180311907  MDEwOlJlcG9zaXRvcnkxODAzMTE5MDc=                 datamad0419
# ...

# %%
repos[repos.fork==True]
# Out:
#            id                           node_id                        name  \
# 21  221513875  MDEwOlJlcG9zaXRvcnkyMjE1MTM4NzU=  lab-advance-querying-mongo
# 25  153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=                mad-oct-2018
#
#                                        full_name  private  \
# 21  ironhack-datalabs/lab-advance-querying-mongo    False
# 25                ironhack-datalabs/mad-oct-2018    False
#
#                                                 owner  \
# 21  {'login': 'ironhack-datalabs', 'id': 44225188,...
# 25  {'login': 'ironhack-datalabs', 'id': 44225188,...
#
#                                              html_url  \
# 21  https://github.com/ironhack-datalabs/lab-advan...
# 25  https://github.com/ironhack-datalabs/mad-oct-2018
#
#                                           description  fork  \
# 21                                               None  True
# 25  Student labs for Ironhack data analytics bootcamp  True
#
# ...

# %%
repos.columns
# Out:
# Index(['id', 'node_id', 'name', 'full_name', 'private', 'owner', 'html_url',
#        'description', 'fork', 'url', 'forks_url', 'keys_url',
#        'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url',
#        'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url',
#        'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url',
#        'languages_url', 'stargazers_url', 'contributors_url',
#        'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url',
#        'comments_url', 'issue_comment_url', 'contents_url', 'compare_url',
#        'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url',
#        'milestones_url', 'notifications_url', 'labels_url', 'releases_url',
#        'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url',
#        'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size',
#        'stargazers_count', 'watchers_count', 'language', 'has_issues',
# ...

# %%
from pandas.io.json import json_normalize

# %%
results = response.json()
flattened_data = json_normalize(results)

# %%
languages = flattened_data.language.value_counts()

# %%
lang_array = []
for lang in languages.index:
    lang_array.append(lang)

lang_array
# Out:
# ['Jupyter Notebook', 'Python', 'TSQL']

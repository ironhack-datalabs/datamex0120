# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended contennt.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit each url and take a look at its source through Chrome DevTools. You'll need to identify the html tags, special class names etc. used for the html content you are expected to extract.

# %% [markdown]
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are imported for you. If you prefer to use additional libraries feel free to uncomment them.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
# from pprint import pprint
# from lxml import html
# from lxml.html import fromstring
# import urllib.request
# from urllib.request import urlopen
import random
import re
import unidecode
# import scrapy

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %%
#your code
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars0.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars1.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars2.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars3.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-7711557e6465ce09edc3dc672ac615c5.css" integrity="sha512-dxFVfmRlzgntw9xnKsYVxQUyV8JZifjI76hlssNAlbCn/gOmgfo4skfRATXTzQ8qG+NNgIh6fvkeQttpFQRpQQ==" media="all" rel="stylesheet"/>
# ...

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
#your code
articles = soup.find_all('article',{'class':'Box-row d-flex'})
developers = []
for x in range(len(articles)):
    name = articles[x].find_all('div',{'class':'col-md-6'})[0].find_all('a')[0].text
    name = name.strip().strip('\n')
    developer_name = articles[x].find_all('div',{'class':'col-md-6'})[0].find_all('a')[1].text
    developer_name = developer_name.strip().strip('\n')
    developers.append(name + ' (' + developer_name + ') ')
developers
# Out:
# ['강동윤 (kdy1) ',
#  'Alexander Jung (aleju) ',
#  'Maël Nison (arcanis) ',
#  'Dirk Wetter (drwetter) ',
#  'Aleksey Kladov (matklad) ',
#  'Markus Staab (staabm) ',
#  'Lipis (lipis) ',
#  'Vladimir Agafonkin (mourner) ',
#  'Stefano Gottardo (CastagnaIT) ',
#  'Florian Märkl (thestr4ng3r) ',
#  'Calin Crisan (ccrisan) ',
#  'Luiz Irber (luizirber) ',
#  'Mike Penz (mikepenz) ',
#  'Luke Latham (guardrex) ',
#  'Laurent Cozic (laurent22) ',
#  'Andreas Rumpf (Araq) ',
#  'Liyas Thomas (liyasthomas) ',
#  'John Otander (johno) ',
#  'R.I.Pienaar (ripienaar) ',
#  'David Rodríguez (deivid-rodriguez) ',
#  'Colin Rofls (cmyr) ',
#  'Bruno Scheufler (BrunoScheufler) ',
#  'Nicola Corti (cortinico) ',
#  'Tim Pope (tpope) ',
#  'Shmavon Gazanchyan (MunGell) ']

# %% [markdown]
# #### Display the trending Python repositories in GitHub
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars0.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars1.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars2.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars3.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-7711557e6465ce09edc3dc672ac615c5.css" integrity="sha512-dxFVfmRlzgntw9xnKsYVxQUyV8JZifjI76hlssNAlbCn/gOmgfo4skfRATXTzQ8qG+NNgIh6fvkeQttpFQRpQQ==" media="all" rel="stylesheet"/>
# ...

# %%
#your code
articles = soup.find_all('article',{'class':'Box-row'})
repositories = []
for x in range(len(articles)):
    repository = articles[x].find_all('a')[1].text
    repository = repository.replace('\n\n\n\n','').replace('\n\n\n','').replace(' ','').strip()
    repositories.append(repository)
repositories
# Out:
# ['public-apis/public-apis',
#  'n1nj4sec/pupy',
#  'Neo23x0/sigma',
#  'facebookresearch/pytorch3d',
#  'TheAlgorithms/Python',
#  'sundowndev/PhoneInfoga',
#  'firmai/pandapy',
#  'corpnewt/gibMacOS',
#  'streamlit/streamlit',
#  'lazyprogrammer/machine_learning_examples',
#  'joanby/deeplearning-az',
#  'ranaroussi/yfinance',
#  'networkx/networkx',
#  'minimaxir/gpt-2-simple',
#  'dpgaspar/Flask-AppBuilder',
#  'Jrohy/multi-v2ray',
#  'CGCookie/retopoflow',
#  'vintasoftware/django-react-boilerplate',
#  'AIDungeon/AIDungeon',
#  'odoo/odoo',
#  'nficano/pytube',
#  'EdjeElectronics/TensorFlow-Object-Detection-API-Tutorial-Train-Multiple-Objects-Windows-10',
#  'echonet/dynamic',
#  'Hsury/BiliDrive',
#  'taspinar/twitterscraper']

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
#your code
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
images = soup.find_all('a',{'class':'image'})
links = []
for x in range(len(images)):
    href = images[x]['href']
    links.append(href)
links
# Out:
# ['/wiki/File:Walt_Disney_1946.JPG',
#  '/wiki/File:Walt_Disney_1942_signature.svg',
#  '/wiki/File:Walt_Disney_envelope_ca._1921.jpg',
#  '/wiki/File:Trolley_Troubles_poster.jpg',
#  '/wiki/File:Walt_Disney_and_his_cartoon_creation_%22Mickey_Mouse%22_-_National_Board_of_Review_Magazine.jpg',
#  '/wiki/File:Steamboat-willie.jpg',
#  '/wiki/File:Walt_Disney_1935.jpg',
#  '/wiki/File:Walt_Disney_Snow_white_1937_trailer_screenshot_(13).jpg',
#  '/wiki/File:Disney_drawing_goofy.jpg',
#  '/wiki/File:DisneySchiphol1951.jpg',
#  '/wiki/File:WaltDisneyplansDisneylandDec1954.jpg',
#  '/wiki/File:Walt_disney_portrait_right.jpg',
#  '/wiki/File:Walt_Disney_Grave.JPG',
#  '/wiki/File:Roy_O._Disney_with_Company_at_Press_Conference.jpg',
#  '/wiki/File:Disney_Display_Case.JPG',
#  '/wiki/File:Disney1968.jpg',
#  '/wiki/File:The_Walt_Disney_Company_Logo.svg',
#  '/wiki/File:Animation_disc.svg',
#  '/wiki/File:P_vip.svg',
#  '/wiki/File:Magic_Kingdom_castle.jpg',
#  '/wiki/File:Video-x-generic.svg',
# ...

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python'

# %%
#your code
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
link = soup.find_all('link')
a = soup.find_all('a')
list_links = []

for x in range(len(link)):
    list_links.append(link[x]['href'])
    
for x in range(len(a)):
    if 'href' in a[x].attrs:
        list_links.append(a[x]['href'])
        
list_links = list(set(list_links))
list_links
# Out:
# ['https://is.wikipedia.org/wiki/Python_(a%C3%B0greining)',
#  'https://www.wikidata.org/wiki/Special:EntityPage/Q747452#sitelinks-wikipedia',
#  '/wiki/Special:SpecialPages',
#  '/w/index.php?title=Python&action=history',
#  '//foundation.wikimedia.org/wiki/Privacy_policy',
#  'https://id.wikipedia.org/wiki/Python',
#  'https://wikimediafoundation.org/',
#  '/wiki/File:Disambig_gray.svg',
#  '//shop.wikimedia.org',
#  '//foundation.wikimedia.org/wiki/Terms_of_Use',
#  '#Engineering',
#  'https://sk.wikipedia.org/wiki/Python',
#  '//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License',
#  '#People',
#  '/wiki/CMU_Common_Lisp',
#  '/wiki/Pyton',
#  '/wiki/Portal:Current_events',
#  '/w/index.php?title=Special:UserLogin&returnto=Python',
#  '/wiki/Special:MyContributions',
#  'https://it.wikipedia.org/wiki/Python_(disambigua)',
#  '/w/index.php?title=Special:ElectronPdf&page=Python&action=show-download-screen',
#  '/wiki/Pythons_2',
# ...

# %% [markdown]
# #### Number of Titles that have changed in the United States Code since its last release point

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'

# %%
#your code
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
titles = soup.find_all('div', {'class':'usctitlechanged'})
len(titles)
# Out:
# 3

# %% [markdown]
# #### A Python list with the top ten FBI's Most Wanted names

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

# %%
#your code 
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
titles = soup.find_all('h3', {'class':'title'})
most_wanted_names = []

for x in range(len(titles)):
    most_wanted_names.append(titles[x].select('a')[0].text)

most_wanted_names
# Out:
# ['ALEXIS FLORES',
#  'EUGENE PALMER',
#  'SANTIAGO VILLALBA MEDEROS',
#  'RAFAEL CARO-QUINTERO',
#  'ROBERT WILLIAM FISHER',
#  'BHADRESHKUMAR CHETANBHAI PATEL',
#  'ARNOLDO JIMENEZ',
#  'ALEJANDRO ROSALES CASTILLO',
#  'YASER ABDEL SAID',
#  'JASON DEREK BROWN']

# %% [markdown]
# ####  20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

# %%
#your code
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
filas = soup.find_all('tr', {'class':'ligne1 normal'})
terremotos = pd.DataFrame(filas)
terremotos = terremotos.drop([0,1,2,8,9,10,12],axis=1)
columnas = {3:"Fecha/Hora",4:"Grados",5:"Latitud",6:"Grados",7:"Longitud",11:"Region"}
terremotos.rename(columns = columnas, inplace = True)
terremotos.head(20)
# Out:
#                                            Fecha/Hora    Grados Latitud  \
# 0   [[[earthquake], [2020-01-27   01:40:23.3]], [2...  [41.44 ]   [N  ]
# 1   [[[earthquake], [2020-01-27   01:27:33.0]], [3...   [5.65 ]   [S  ]
# 2   [[[earthquake], [2020-01-27   01:18:33.9]], [4...  [38.51 ]   [N  ]
# 3   [[[earthquake], [2020-01-27   00:59:53.9]], [1...  [39.13 ]   [N  ]
# 4   [[[earthquake], [2020-01-27   00:55:08.0]], [1...  [18.04 ]   [N  ]
# 5   [[[earthquake], [2020-01-27   00:49:00.6]], [1...  [38.39 ]   [N  ]
# 6   [[[earthquake], [2020-01-27   00:24:39.7]], [1...  [39.06 ]   [N  ]
# 7   [[[earthquake], [2020-01-26   23:49:34.9]], [2...  [50.97 ]   [N  ]
# 8   [[[earthquake], [2020-01-26   23:45:34.1]], [2...  [40.47 ]   [N  ]
# 9   [[[earthquake], [2020-01-26   22:40:26.8]], [3...  [51.24 ]   [N  ]
# 10  [[[earthquake], [2020-01-26   22:34:14.9]], [3...  [38.32 ]   [N  ]
# 11  [[[earthquake], [2020-01-26   22:19:53.0]], [3...  [39.03 ]   [N  ]
# ...

# %% [markdown]
# #### Display the date, days, title, city, country of next 25 hackathon events as a Pandas dataframe table

# %%
# This is the url you will scrape in this exercise
url ='https://hackevents.co/hackathons'

# %%
#your code
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
soup
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# ConnectionRefusedError: [WinError 10061] No se puede establecer una conexión ya que el equipo de destino denegó expresamente dicha conexión
#
# ...

# %% [markdown]
# #### Count number of tweets by a given Twitter account.

# %% [markdown]
# You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/fifacom'

# %%
#your code
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
tweets = soup.find_all('a',{'data-nav':'tweets'})
tweets[0]['title']
# Out:
# '79.109 Tweets'

# %% [markdown]
# #### Number of followers of a given twitter account

# %% [markdown]
# You will need to include a ***try/except block*** in case account/s name not found.
# <br>***Hint:*** the program should count the followers for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/fifacom'

# %%
#your code
followers = soup.find_all('a',{'data-nav':'followers'})
followers[0]['title']
# Out:
# '13.180.358 Seguidores'

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
#your code
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
tags = soup.findAll('a',{'class':'link-box'})
language_names = []
for x in range(len(tags)):
    language_name = tags[x].select('strong')[0].text
    number = tags[x].select('bdi')[0].text
    number = unidecode.unidecode(number).replace(' ','')
    language_names.append(language_name + ': ' + number + 'articles.')
language_names
# Out:
# ['English: 5994000+articles.',
#  '日本語: 1185000+articles.',
#  'Deutsch: 2385000+articles.',
#  'Español: 1571000+articles.',
#  'Русский: 1590000+articles.',
#  'Français: 2171000+articles.',
#  'Italiano: 1576000+articles.',
#  '中文: 1090000+articles.',
#  'Português: 1018000+articles.',
#  'Polski: 1379000+articles.']

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'

# %%
#your code 
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
columnas = soup.findAll('div', {'class':'grid-row dgu-topics'})
datasets = []
for x in range(len(columnas[0])):
    datasets.append(columnas[0].findAll('a')[x].text)
datasets
# Out:
# ['Business and economy',
#  'Crime and justice',
#  'Defence',
#  'Education',
#  'Environment',
#  'Government',
#  'Government spending']

# %% [markdown]
# #### Top 10 languages by number of native speakers stored in a Pandas Dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
#your code
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
table = soup.findAll('table')[0]
th = table.findAll('th')
nombres_columnas = []
for x in range(len(th)):
    nombres_columnas.append(th[x].text.strip('\n').replace('\n', ' '))
tr = table.findAll('tr')
filas = []
for x in range(1,len(tr)):
    filas.append(tr[x])
df = pd.DataFrame(filas)
df = df.drop([0,2,4,6,8],axis=1)
df = df.rename(columns = {1:nombres_columnas[0],1:nombres_columnas[0],3:nombres_columnas[1],5:nombres_columnas[2],7:nombres_columnas[3],9:nombres_columnas[4]})
for x in df.columns:
    df[x] = df[x].apply(lambda y: unidecode.unidecode(y.text).strip('\n'))
df
# Out:
#    Rank                            Language Speakers(millions)  \
# 0     1                    Mandarin Chinese                918
# 1     2                             Spanish                480
# 2     3                             English                379
# 3     4  Hindi (Sanskritised Hindustani)[9]                341
# 4     5                             Bengali                228
# ..  ...                                 ...                ...
# 86   87                               Czech               10.7
# 87   88                Ta`izzi-Adeni Arabic               10.5
# 88   89                              Uyghur               10.4
# 89   90                    Min Dong Chinese               10.3
# 90   91                             Sylheti               10.3
#
#    % of the World population (March 2019)[8]      Language familyBranch
# 0                                     11.922        Sino-TibetanSinitic
# ...

# %% [markdown]
# ### BONUS QUESTIONS

# %% [markdown]
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code

# %% [markdown]
# #### IMDB's Top 250 data (movie name, Initial release, director name and stars) as a pandas dataframe

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code

# %% [markdown]
# #### Movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
#your code

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = city=input('Enter the city:')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code

# %% [markdown]
# #### Book name,price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
#your code

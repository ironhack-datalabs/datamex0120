# %% [markdown]
# #### 1. Import pandas library

# %%
import pandas as pd

# %% [markdown]
# #### 2. Import pymysql and sqlalchemy as you have learnt in the lesson of importing/exporting data

# %%
import pymysql
from sqlalchemy import create_engine

# %% [markdown]
# #### 3. Create a mysql engine to set the connection to the server. Check the connection details in [this link](https://relational.fit.cvut.cz/search?tableCount%5B%5D=0-10&tableCount%5B%5D=10-30&dataType%5B%5D=Numeric&databaseSize%5B%5D=KB&databaseSize%5B%5D=MB)

# %%
dbURL="mysql+pymysql://guest:relational@relational.fit.cvut.cz/stats"
engine = create_engine(dbURL)

# %% [markdown]
# #### 4. Import the users table

# %%
query="SELECT * FROM users"
users = pd.read_sql(query, engine)

# %%
users.head()
# Out:
#    Id  Reputation        CreationDate   DisplayName      LastAccessDate  \
# 0  -1           1 2010-07-19 06:55:26     Community 2010-07-19 06:55:26
# 1   2         101 2010-07-19 14:01:36  Geoff Dalgas 2013-11-12 22:07:23
# 2   3         101 2010-07-19 15:34:50  Jarrod Dixon 2014-08-08 06:42:58
# 3   4         101 2010-07-19 19:03:27        Emmett 2014-01-02 09:31:02
# 4   5        6792 2010-07-19 19:03:57         Shane 2014-08-13 00:23:47
#
#                        WebsiteUrl            Location  \
# 0  http://meta.stackexchange.com/  on the server farm
# 1        http://stackoverflow.com       Corvallis, OR
# 2        http://stackoverflow.com        New York, NY
# 3    http://minesweeperonline.com   San Francisco, CA
# 4         http://www.statalgo.com        New York, NY
#
#                                              AboutMe  Views  UpVotes  \
# 0  <p>Hi, I'm not really a person.</p>\n\n<p>I'm ...      0     5007
# ...

# %% [markdown]
# #### 5. Rename Id column to userId

# %%
users.rename(columns={'Id':'userId'}, inplace=True)
users.head()
# Out:
#    userId  Reputation        CreationDate   DisplayName      LastAccessDate  \
# 0      -1           1 2010-07-19 06:55:26     Community 2010-07-19 06:55:26
# 1       2         101 2010-07-19 14:01:36  Geoff Dalgas 2013-11-12 22:07:23
# 2       3         101 2010-07-19 15:34:50  Jarrod Dixon 2014-08-08 06:42:58
# 3       4         101 2010-07-19 19:03:27        Emmett 2014-01-02 09:31:02
# 4       5        6792 2010-07-19 19:03:57         Shane 2014-08-13 00:23:47
#
#                        WebsiteUrl            Location  \
# 0  http://meta.stackexchange.com/  on the server farm
# 1        http://stackoverflow.com       Corvallis, OR
# 2        http://stackoverflow.com        New York, NY
# 3    http://minesweeperonline.com   San Francisco, CA
# 4         http://www.statalgo.com        New York, NY
#
#                                              AboutMe  Views  UpVotes  \
# 0  <p>Hi, I'm not really a person.</p>\n\n<p>I'm ...      0     5007
# ...

# %% [markdown]
# #### 6. Import the posts table.

# %%
query="SELECT * FROM posts"
posts = pd.read_sql(query, engine)

# %%
posts.head()
# Out:
#    postId  PostTypeId  AcceptedAnswerId         CreaionDate  Score  ViewCount  \
# 0       1           1              15.0 2010-07-19 19:12:12     23     1278.0
# 1       2           1              59.0 2010-07-19 19:12:57     22     8198.0
# 2       3           1               5.0 2010-07-19 19:13:28     54     3613.0
# 3       4           1             135.0 2010-07-19 19:13:31     13     5224.0
# 4       5           2               NaN 2010-07-19 19:14:43     81        NaN
#
#                                                 Body  OwnerUserId  \
# 0  <p>How should I elicit prior distributions fro...          8.0
# 1  <p>In many different statistical methods there...         24.0
# 2  <p>What are some valuable Statistical Analysis...         18.0
# 3  <p>I have two groups of data.  Each with a dif...         23.0
# 4  <p>The R-project</p>\n\n<p><a href="http://www...         23.0
#
#       LasActivityDate                                              Title  \
# ...

# %% [markdown]
# #### 7. Rename Id column to postId and OwnerUserId to userId

# %%
posts.rename(columns={'Id':'postId'}, inplace=True)

# %% [markdown]
# #### 8. Define new dataframes for users and posts with the following selected columns:
#     **users columns**: userId, Reputation,Views,UpVotes,DownVotes
#     **posts columns**: postId, Score,userID,ViewCount,CommentCount

# %%
usersNew = users.loc[:,["userId", "Reputation", "Views", "UpVotes", "DownVotes"]]
# I think the OwnerUserID column is the userID asked for in the instructions above
postsNew = posts.loc[:,["Score", "OwnerUserId", "ViewCount", "CommentCount"]]
# Out:
#        Score  OwnerUserId  ViewCount  CommentCount
# 0         23          8.0     1278.0             1
# 1         22         24.0     8198.0             1
# 2         54         18.0     3613.0             4
# 3         13         23.0     5224.0             2
# 4         81         23.0        NaN             3
# 5        152          5.0    29229.0             5
# 6         76         38.0     5808.0             3
# 7          0         37.0      288.0             2
# 8         13         50.0        NaN             3
# 9         23         24.0    21925.0             4
# 10         2         34.0      224.0             2
# 11        20          5.0        NaN             1
# 12        14         23.0        NaN             4
# 13         5         36.0        NaN             1
# 14        13          6.0        NaN             0
# 15        16          8.0        NaN             3
# 16         9          NaN     1261.0             0
# ...

# %% [markdown]
# #### 8. Merge both dataframes, users and posts.
# You will need to make a [merge](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html) of posts and users dataframes.

# %%
merged_data_frame = pd.merge(usersNew, postsNew, left_on='userId', right_on='OwnerUserId')
merged_data_frame.head(5000)
# Out:
#       userId  Reputation  Views  UpVotes  DownVotes  Score  OwnerUserId  \
# 0         -1           1      0     5007       1920      0         -1.0
# 1         -1           1      0     5007       1920      0         -1.0
# 2         -1           1      0     5007       1920      0         -1.0
# 3         -1           1      0     5007       1920      0         -1.0
# 4         -1           1      0     5007       1920      0         -1.0
# 5         -1           1      0     5007       1920      0         -1.0
# 6         -1           1      0     5007       1920      0         -1.0
# 7         -1           1      0     5007       1920      0         -1.0
# 8         -1           1      0     5007       1920      0         -1.0
# 9         -1           1      0     5007       1920      0         -1.0
# 10        -1           1      0     5007       1920      0         -1.0
# 11        -1           1      0     5007       1920      0         -1.0
# ...

# %% [markdown]
# #### 9. How many missing values do you have in your merged dataframe? On which columns?

# %%
# https://stackoverflow.com/a/57389011/5420796
merged_data_frame.isnull().sum(axis = 0)
# Out:
# userId              0
# Reputation          0
# Views               0
# UpVotes             0
# DownVotes           0
# Score               0
# OwnerUserId         0
# ViewCount       48396
# CommentCount        0
# dtype: int64

# %% [markdown]
# #### 10. You will need to make something with missing values.  Will you clean or filling them? Explain.
# **Remember** to check the results of your code before passing to the next step

# %%
# I will clean them, because we don't know if they are actually 0
# https://stackoverflow.com/a/13434501/5420796

# merged_data_frame_dropped = merged_data_frame.fillna(subset=['ViewCount'], 0)

merged_data_frame['ViewCount'] = merged_data_frame['ViewCount'].fillna(value=0)

# %% [markdown]
# #### 11. Adjust the data types in order to avoid future issues. Which ones should be changed?

# %%
print(merged_data_frame.dtypes)
merged_data_frame_fixed = merged_data_frame.astype({"OwnerUserId": int, "ViewCount": int})
print(merged_data_frame_fixed.dtypes)
# Out:
# userId            int64
# Reputation        int64
# Views             int64
# UpVotes           int64
# DownVotes         int64
# Score             int64
# OwnerUserId     float64
# ViewCount       float64
# CommentCount      int64
# dtype: object
# userId          int64
# Reputation      int64
# Views           int64
# UpVotes         int64
# DownVotes       int64
# Score           int64
# OwnerUserId     int64
# ViewCount       int64
# CommentCount    int64
# dtype: object

# %% [markdown]
# #### Bonus: Identify extreme values in your merged dataframe as you have learned in class, create a dataframe called outliers with the same columns as our data set and calculate the bounds. The values of the outliers dataframe will be the values of the merged_df that fall outside that bounds. You will need to save your outliers dataframe to a csv file on your-code folder.

# %%
stats = merged_data_frame_fixed.describe().transpose()
stats['IQR'] = stats['75%'] - stats['25%']
stats
# Out:
#                 count          mean           std   min     25%      50%  \
# userId        90584.0  16546.764727  15273.367108  -1.0  3437.0  11032.0
# Reputation    90584.0   6282.395412  15102.268670   1.0    60.0    396.0
# Views         90584.0   1034.245176   2880.074012   0.0     5.0     45.0
# UpVotes       90584.0    734.315718   2050.869327   0.0     1.0     22.0
# DownVotes     90584.0     33.273249    134.936435   0.0     0.0      0.0
# Score         90584.0      2.780767      4.948922 -19.0     1.0      2.0
# OwnerUserId   90584.0  16546.764727  15273.367108  -1.0  3437.0  11032.0
# ViewCount     90584.0    259.253400   1632.261405   0.0     0.0      0.0
# CommentCount  90584.0      1.894650      2.638704   0.0     0.0      1.0
#
#                    75%       max       IQR
# userId        27700.00   55746.0  24263.00
# Reputation     4460.00   87393.0   4400.00
# Views           514.25   20932.0    509.25
# UpVotes         283.00   11442.0    282.00
# ...

# %%
outliers = pd.DataFrame(columns=merged_data_frame_fixed.columns)

# %%
for col in stats.index:
    iqr = stats.at[col,'IQR']
    cutoff = iqr * 1.5
    lower = stats.at[col,'25%'] - cutoff
    upper = stats.at[col,'75%'] + cutoff
    results = merged_data_frame_fixed[(merged_data_frame_fixed[col] < lower) | 
                   (merged_data_frame_fixed[col] > upper)].copy()
    results['Outlier'] = col
    outliers = outliers.append(results)
    

outliers.head()
# Out:
#       CommentCount  DownVotes     Outlier  OwnerUserId  Reputation  Score  \
# 1155           0.0      126.0  Reputation         88.0     14082.0   25.0
# 1156           0.0      126.0  Reputation         88.0     14082.0    5.0
# 1157           1.0      126.0  Reputation         88.0     14082.0    7.0
# 1158           3.0      126.0  Reputation         88.0     14082.0    6.0
# 1159           0.0      126.0  Reputation         88.0     14082.0    7.0
#
#       UpVotes  ViewCount   Views  userId
# 1155   4235.0        0.0  3320.0    88.0
# 1156   4235.0        0.0  3320.0    88.0
# 1157   4235.0        0.0  3320.0    88.0
# 1158   4235.0        0.0  3320.0    88.0
# 1159   4235.0        0.0  3320.0    88.0

# %%
# Save as CSV
outliers.to_csv('outliers.csv')

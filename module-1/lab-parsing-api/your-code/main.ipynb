# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
# your code here
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
resp = requests.get('https://swapi.co/api/people/')
results = resp.json()
results
# Out:
# {'count': 87,
#  'next': 'https://swapi.co/api/people/?page=2',
#  'previous': None,
#  'results': [{'name': 'Luke Skywalker',
#    'height': '172',
#    'mass': '77',
#    'hair_color': 'blond',
#    'skin_color': 'fair',
#    'eye_color': 'blue',
#    'birth_year': '19BBY',
#    'gender': 'male',
#    'homeworld': 'https://swapi.co/api/planets/1/',
#    'films': ['https://swapi.co/api/films/2/',
#     'https://swapi.co/api/films/6/',
#     'https://swapi.co/api/films/3/',
#     'https://swapi.co/api/films/1/',
#     'https://swapi.co/api/films/7/'],
#    'species': ['https://swapi.co/api/species/1/'],
#    'vehicles': ['https://swapi.co/api/vehicles/14/',
#     'https://swapi.co/api/vehicles/30/'],
#    'starships': ['https://swapi.co/api/starships/12/',
#     'https://swapi.co/api/starships/22/'],
#    'created': '2014-12-09T13:50:51.644000Z',
#    'edited': '2014-12-20T21:17:56.891000Z',
#    'url': 'https://swapi.co/api/people/1/'},
#   {'name': 'C-3PO',
#    'height': '167',
# ...

# %%
f = [requests.get(f'https://swapi.co/api/people/?page={e}') for e in range(1,10)]
f
# Out:
# [<Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>]

# %%
v = [i.json() for i in f]
v
# Out:
# [{'count': 87,
#   'next': 'https://swapi.co/api/people/?page=2',
#   'previous': None,
#   'results': [{'name': 'Luke Skywalker',
#     'height': '172',
#     'mass': '77',
#     'hair_color': 'blond',
#     'skin_color': 'fair',
#     'eye_color': 'blue',
#     'birth_year': '19BBY',
#     'gender': 'male',
#     'homeworld': 'https://swapi.co/api/planets/1/',
#     'films': ['https://swapi.co/api/films/2/',
#      'https://swapi.co/api/films/6/',
#      'https://swapi.co/api/films/3/',
#      'https://swapi.co/api/films/1/',
#      'https://swapi.co/api/films/7/'],
#     'species': ['https://swapi.co/api/species/1/'],
#     'vehicles': ['https://swapi.co/api/vehicles/14/',
#      'https://swapi.co/api/vehicles/30/'],
#     'starships': ['https://swapi.co/api/starships/12/',
#      'https://swapi.co/api/starships/22/'],
#     'created': '2014-12-09T13:50:51.644000Z',
#     'edited': '2014-12-20T21:17:56.891000Z',
#     'url': 'https://swapi.co/api/people/1/'},
# ...

# %%
pd.DataFrame(v[0])
# Out:
#    count                                 next previous  \
# 0     87  https://swapi.co/api/people/?page=2     None
# 1     87  https://swapi.co/api/people/?page=2     None
# 2     87  https://swapi.co/api/people/?page=2     None
# 3     87  https://swapi.co/api/people/?page=2     None
# 4     87  https://swapi.co/api/people/?page=2     None
# 5     87  https://swapi.co/api/people/?page=2     None
# 6     87  https://swapi.co/api/people/?page=2     None
# 7     87  https://swapi.co/api/people/?page=2     None
# 8     87  https://swapi.co/api/people/?page=2     None
# 9     87  https://swapi.co/api/people/?page=2     None
#
#                                              results
# 0  {'name': 'Luke Skywalker', 'height': '172', 'm...
# 1  {'name': 'C-3PO', 'height': '167', 'mass': '75...
# 2  {'name': 'R2-D2', 'height': '96', 'mass': '32'...
# 3  {'name': 'Darth Vader', 'height': '202', 'mass...
# 4  {'name': 'Leia Organa', 'height': '150', 'mass...
# ...

# %%
h = [pd.DataFrame(i['results'])for i in v]
# Out:
#                     name height     mass    hair_color        skin_color  \
# 0       Anakin Skywalker    188       84         blond              fair
# 1         Wilhuff Tarkin    180  unknown  auburn, grey              fair
# 2              Chewbacca    228      112         brown           unknown
# 3               Han Solo    180       80         brown              fair
# 4                 Greedo    173       74           n/a             green
# 5  Jabba Desilijic Tiure    175    1,358           n/a  green-tan, brown
# 6         Wedge Antilles    170       77         brown              fair
# 7       Jek Tono Porkins    180      110         brown              fair
# 8                   Yoda     66       17         white             green
# 9              Palpatine    170       75          grey              pale
#
#   eye_color birth_year         gender                         homeworld  \
# 0      blue    41.9BBY           male   https://swapi.co/api/planets/1/
# ...

# %%
pd.concat(h)
# Out:
#               name   height     mass hair_color   skin_color eye_color  \
# 0   Luke Skywalker      172       77      blond         fair      blue
# 1            C-3PO      167       75        n/a         gold    yellow
# 2            R2-D2       96       32        n/a  white, blue       red
# 3      Darth Vader      202      136       none        white    yellow
# 4      Leia Organa      150       49      brown        light     brown
# ..             ...      ...      ...        ...          ...       ...
# 2              Rey  unknown  unknown      brown        light     hazel
# 3      Poe Dameron  unknown  unknown      brown        light     brown
# 4              BB8  unknown  unknown       none         none     black
# 5   Captain Phasma  unknown  unknown    unknown      unknown   unknown
# 6    Padmé Amidala      165       45      brown        light     brown
#
#    birth_year  gender                         homeworld  \
# 0       19BBY    male   https://swapi.co/api/planets/1/
# ...

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here
resp = requests.get('https://swapi.co/api/people/')
results = resp.json()
results
# Out:
# {'count': 87,
#  'next': 'https://swapi.co/api/people/?page=2',
#  'previous': None,
#  'results': [{'name': 'Luke Skywalker',
#    'height': '172',
#    'mass': '77',
#    'hair_color': 'blond',
#    'skin_color': 'fair',
#    'eye_color': 'blue',
#    'birth_year': '19BBY',
#    'gender': 'male',
#    'homeworld': 'https://swapi.co/api/planets/1/',
#    'films': ['https://swapi.co/api/films/2/',
#     'https://swapi.co/api/films/6/',
#     'https://swapi.co/api/films/3/',
#     'https://swapi.co/api/films/1/',
#     'https://swapi.co/api/films/7/'],
#    'species': ['https://swapi.co/api/species/1/'],
#    'vehicles': ['https://swapi.co/api/vehicles/14/',
#     'https://swapi.co/api/vehicles/30/'],
#    'starships': ['https://swapi.co/api/starships/12/',
#     'https://swapi.co/api/starships/22/'],
#    'created': '2014-12-09T13:50:51.644000Z',
#    'edited': '2014-12-20T21:17:56.891000Z',
#    'url': 'https://swapi.co/api/people/1/'},
#   {'name': 'C-3PO',
#    'height': '167',
# ...

# %%
f = [requests.get(f'https://swapi.co/api/people/?page={e}') for e in range(1,10)]
f
# Out:
# [<Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>]

# %%
v = [i.json() for i in f]
v
# Out:
# [{'count': 87,
#   'next': 'https://swapi.co/api/people/?page=2',
#   'previous': None,
#   'results': [{'name': 'Luke Skywalker',
#     'height': '172',
#     'mass': '77',
#     'hair_color': 'blond',
#     'skin_color': 'fair',
#     'eye_color': 'blue',
#     'birth_year': '19BBY',
#     'gender': 'male',
#     'homeworld': 'https://swapi.co/api/planets/1/',
#     'films': ['https://swapi.co/api/films/2/',
#      'https://swapi.co/api/films/6/',
#      'https://swapi.co/api/films/3/',
#      'https://swapi.co/api/films/1/',
#      'https://swapi.co/api/films/7/'],
#     'species': ['https://swapi.co/api/species/1/'],
#     'vehicles': ['https://swapi.co/api/vehicles/14/',
#      'https://swapi.co/api/vehicles/30/'],
#     'starships': ['https://swapi.co/api/starships/12/',
#      'https://swapi.co/api/starships/22/'],
#     'created': '2014-12-09T13:50:51.644000Z',
#     'edited': '2014-12-20T21:17:56.891000Z',
#     'url': 'https://swapi.co/api/people/1/'},
# ...

# %%
pd.DataFrame(v[0])
# Out:
#    count                                 next previous  \
# 0     87  https://swapi.co/api/people/?page=2     None
# 1     87  https://swapi.co/api/people/?page=2     None
# 2     87  https://swapi.co/api/people/?page=2     None
# 3     87  https://swapi.co/api/people/?page=2     None
# 4     87  https://swapi.co/api/people/?page=2     None
# 5     87  https://swapi.co/api/people/?page=2     None
# 6     87  https://swapi.co/api/people/?page=2     None
# 7     87  https://swapi.co/api/people/?page=2     None
# 8     87  https://swapi.co/api/people/?page=2     None
# 9     87  https://swapi.co/api/people/?page=2     None
#
#                                              results
# 0  {'name': 'Luke Skywalker', 'height': '172', 'm...
# 1  {'name': 'C-3PO', 'height': '167', 'mass': '75...
# 2  {'name': 'R2-D2', 'height': '96', 'mass': '32'...
# 3  {'name': 'Darth Vader', 'height': '202', 'mass...
# 4  {'name': 'Leia Organa', 'height': '150', 'mass...
# ...

# %%
h = [pd.DataFrame(i['results'])for i in v]

# %%
pd.concat(h)
# Out:
#               name   height     mass hair_color   skin_color eye_color  \
# 0   Luke Skywalker      172       77      blond         fair      blue
# 1            C-3PO      167       75        n/a         gold    yellow
# 2            R2-D2       96       32        n/a  white, blue       red
# 3      Darth Vader      202      136       none        white    yellow
# 4      Leia Organa      150       49      brown        light     brown
# ..             ...      ...      ...        ...          ...       ...
# 2              Rey  unknown  unknown      brown        light     hazel
# 3      Poe Dameron  unknown  unknown      brown        light     brown
# 4              BB8  unknown  unknown       none         none     black
# 5   Captain Phasma  unknown  unknown    unknown      unknown   unknown
# 6    Padmé Amidala      165       45      brown        light     brown
#
#    birth_year  gender                         homeworld  \
# 0       19BBY    male   https://swapi.co/api/planets/1/
# ...

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here

# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

url = 'https://pokeapi.co/api/v2/pokemon'

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here
response = requests.get(url)
results = response.json()
results
# Out:
# {'count': 964,
#  'next': 'https://pokeapi.co/api/v2/pokemon?offset=20&limit=20',
#  'previous': None,
#  'results': [{'name': 'bulbasaur',
#    'url': 'https://pokeapi.co/api/v2/pokemon/1/'},
#   {'name': 'ivysaur', 'url': 'https://pokeapi.co/api/v2/pokemon/2/'},
#   {'name': 'venusaur', 'url': 'https://pokeapi.co/api/v2/pokemon/3/'},
#   {'name': 'charmander', 'url': 'https://pokeapi.co/api/v2/pokemon/4/'},
#   {'name': 'charmeleon', 'url': 'https://pokeapi.co/api/v2/pokemon/5/'},
#   {'name': 'charizard', 'url': 'https://pokeapi.co/api/v2/pokemon/6/'},
#   {'name': 'squirtle', 'url': 'https://pokeapi.co/api/v2/pokemon/7/'},
#   {'name': 'wartortle', 'url': 'https://pokeapi.co/api/v2/pokemon/8/'},
#   {'name': 'blastoise', 'url': 'https://pokeapi.co/api/v2/pokemon/9/'},
#   {'name': 'caterpie', 'url': 'https://pokeapi.co/api/v2/pokemon/10/'},
#   {'name': 'metapod', 'url': 'https://pokeapi.co/api/v2/pokemon/11/'},
#   {'name': 'butterfree', 'url': 'https://pokeapi.co/api/v2/pokemon/12/'},
#   {'name': 'weedle', 'url': 'https://pokeapi.co/api/v2/pokemon/13/'},
#   {'name': 'kakuna', 'url': 'https://pokeapi.co/api/v2/pokemon/14/'},
#   {'name': 'beedrill', 'url': 'https://pokeapi.co/api/v2/pokemon/15/'},
#   {'name': 'pidgey', 'url': 'https://pokeapi.co/api/v2/pokemon/16/'},
#   {'name': 'pidgeotto', 'url': 'https://pokeapi.co/api/v2/pokemon/17/'},
#   {'name': 'pidgeot', 'url': 'https://pokeapi.co/api/v2/pokemon/18/'},
#   {'name': 'rattata', 'url': 'https://pokeapi.co/api/v2/pokemon/19/'},
#   {'name': 'raticate', 'url': 'https://pokeapi.co/api/v2/pokemon/20/'}]}

# %%
data = pd.DataFrame(results)
data.head()
# Out:
#    count                                               next previous  \
# 0    964  https://pokeapi.co/api/v2/pokemon?offset=20&li...     None
# 1    964  https://pokeapi.co/api/v2/pokemon?offset=20&li...     None
# 2    964  https://pokeapi.co/api/v2/pokemon?offset=20&li...     None
# 3    964  https://pokeapi.co/api/v2/pokemon?offset=20&li...     None
# 4    964  https://pokeapi.co/api/v2/pokemon?offset=20&li...     None
#
#                                              results
# 0  {'name': 'bulbasaur', 'url': 'https://pokeapi....
# 1  {'name': 'ivysaur', 'url': 'https://pokeapi.co...
# 2  {'name': 'venusaur', 'url': 'https://pokeapi.c...
# 3  {'name': 'charmander', 'url': 'https://pokeapi...
# 4  {'name': 'charmeleon', 'url': 'https://pokeapi...

# %%
flattened_data = json_normalize(results['results'])
flattened_data.head()
# Out:
#          name                                   url
# 0   bulbasaur  https://pokeapi.co/api/v2/pokemon/1/
# 1     ivysaur  https://pokeapi.co/api/v2/pokemon/2/
# 2    venusaur  https://pokeapi.co/api/v2/pokemon/3/
# 3  charmander  https://pokeapi.co/api/v2/pokemon/4/
# 4  charmeleon  https://pokeapi.co/api/v2/pokemon/5/

# %%
results = []

for i in range(5):
    response = requests.get(url.format(1))
    results.append(response.json())

pokemons = pd.DataFrame(results)
pokemons
# Out:
#                                            abilities  base_experience  \
# 0  [{'ability': {'name': 'chlorophyll', 'url': 'h...               64
# 1  [{'ability': {'name': 'chlorophyll', 'url': 'h...               64
# 2  [{'ability': {'name': 'chlorophyll', 'url': 'h...               64
# 3  [{'ability': {'name': 'chlorophyll', 'url': 'h...               64
# 4  [{'ability': {'name': 'chlorophyll', 'url': 'h...               64
#
#                                                forms  \
# 0  [{'name': 'bulbasaur', 'url': 'https://pokeapi...
# 1  [{'name': 'bulbasaur', 'url': 'https://pokeapi...
# 2  [{'name': 'bulbasaur', 'url': 'https://pokeapi...
# 3  [{'name': 'bulbasaur', 'url': 'https://pokeapi...
# 4  [{'name': 'bulbasaur', 'url': 'https://pokeapi...
#
#                                         game_indices  height held_items  id  \
# 0  [{'game_index': 1, 'version': {'name': 'white-...       7         []   1
# 1  [{'game_index': 1, 'version': {'name': 'white-...       7         []   1
# 2  [{'game_index': 1, 'version': {'name': 'white-...       7         []   1
# 3  [{'game_index': 1, 'version': {'name': 'white-...       7         []   1
# 4  [{'game_index': 1, 'version': {'name': 'white-...       7         []   1
#
#    is_default                        location_area_encounters  \
# 0        True  https://pokeapi.co/api/v2/pokemon/1/encounters
# 1        True  https://pokeapi.co/api/v2/pokemon/1/encounters
# 2        True  https://pokeapi.co/api/v2/pokemon/1/encounters
# 3        True  https://pokeapi.co/api/v2/pokemon/1/encounters
# 4        True  https://pokeapi.co/api/v2/pokemon/1/encounters
#
#                                                moves       name  order  \
# 0  [{'move': {'name': 'razor-wind', 'url': 'https...  bulbasaur      1
# 1  [{'move': {'name': 'razor-wind', 'url': 'https...  bulbasaur      1
# 2  [{'move': {'name': 'razor-wind', 'url': 'https...  bulbasaur      1
# 3  [{'move': {'name': 'razor-wind', 'url': 'https...  bulbasaur      1
# 4  [{'move': {'name': 'razor-wind', 'url': 'https...  bulbasaur      1
#
#                                              species  \
# 0  {'name': 'bulbasaur', 'url': 'https://pokeapi....
# 1  {'name': 'bulbasaur', 'url': 'https://pokeapi....
# 2  {'name': 'bulbasaur', 'url': 'https://pokeapi....
# 3  {'name': 'bulbasaur', 'url': 'https://pokeapi....
# 4  {'name': 'bulbasaur', 'url': 'https://pokeapi....
#
#                                              sprites  \
# 0  {'back_default': 'https://raw.githubuserconten...
# 1  {'back_default': 'https://raw.githubuserconten...
# 2  {'back_default': 'https://raw.githubuserconten...
# 3  {'back_default': 'https://raw.githubuserconten...
# 4  {'back_default': 'https://raw.githubuserconten...
#
#                                                stats  \
# 0  [{'base_stat': 45, 'effort': 0, 'stat': {'name...
# 1  [{'base_stat': 45, 'effort': 0, 'stat': {'name...
# 2  [{'base_stat': 45, 'effort': 0, 'stat': {'name...
# 3  [{'base_stat': 45, 'effort': 0, 'stat': {'name...
# 4  [{'base_stat': 45, 'effort': 0, 'stat': {'name...
#
#                                                types  weight
# 0  [{'slot': 2, 'type': {'name': 'poison', 'url':...      69
# 1  [{'slot': 2, 'type': {'name': 'poison', 'url':...      69
# 2  [{'slot': 2, 'type': {'name': 'poison', 'url':...      69
# 3  [{'slot': 2, 'type': {'name': 'poison', 'url':...      69
# 4  [{'slot': 2, 'type': {'name': 'poison', 'url':...      69

# %%
pokemons_flat = json_normalize(results)
pokemons_flat.head()
# Out:
#                                            abilities  base_experience  \
# 0  [{'ability': {'name': 'chlorophyll', 'url': 'h...               64
# 1  [{'ability': {'name': 'chlorophyll', 'url': 'h...               64
# 2  [{'ability': {'name': 'chlorophyll', 'url': 'h...               64
#
#                                                forms  \
# 0  [{'name': 'bulbasaur', 'url': 'https://pokeapi...
# 1  [{'name': 'bulbasaur', 'url': 'https://pokeapi...
# 2  [{'name': 'bulbasaur', 'url': 'https://pokeapi...
#
#                                         game_indices  height held_items  id  \
# 0  [{'game_index': 1, 'version': {'name': 'white-...       7         []   1
# 1  [{'game_index': 1, 'version': {'name': 'white-...       7         []   1
# 2  [{'game_index': 1, 'version': {'name': 'white-...       7         []   1
#
#    is_default                        location_area_encounters  \
# 0        True  https://pokeapi.co/api/v2/pokemon/1/encounters
# 1        True  https://pokeapi.co/api/v2/pokemon/1/encounters
# 2        True  https://pokeapi.co/api/v2/pokemon/1/encounters
#
#                                                moves  ... species.name  \
# 0  [{'move': {'name': 'razor-wind', 'url': 'https...  ...    bulbasaur
# 1  [{'move': {'name': 'razor-wind', 'url': 'https...  ...    bulbasaur
# 2  [{'move': {'name': 'razor-wind', 'url': 'https...  ...    bulbasaur
#
#                                     species.url  \
# 0  https://pokeapi.co/api/v2/pokemon-species/1/
# 1  https://pokeapi.co/api/v2/pokemon-species/1/
# 2  https://pokeapi.co/api/v2/pokemon-species/1/
#
#                                 sprites.back_default sprites.back_female  \
# 0  https://raw.githubusercontent.com/PokeAPI/spri...                None
# 1  https://raw.githubusercontent.com/PokeAPI/spri...                None
# 2  https://raw.githubusercontent.com/PokeAPI/spri...                None
#
#                                   sprites.back_shiny  \
# 0  https://raw.githubusercontent.com/PokeAPI/spri...
# 1  https://raw.githubusercontent.com/PokeAPI/spri...
# 2  https://raw.githubusercontent.com/PokeAPI/spri...
#
#   sprites.back_shiny_female  \
# 0                      None
# 1                      None
# 2                      None
#
#                                sprites.front_default sprites.front_female  \
# 0  https://raw.githubusercontent.com/PokeAPI/spri...                 None
# 1  https://raw.githubusercontent.com/PokeAPI/spri...                 None
# 2  https://raw.githubusercontent.com/PokeAPI/spri...                 None
#
#                                  sprites.front_shiny  \
# 0  https://raw.githubusercontent.com/PokeAPI/spri...
# 1  https://raw.githubusercontent.com/PokeAPI/spri...
# 2  https://raw.githubusercontent.com/PokeAPI/spri...
#
#   sprites.front_shiny_female
# 0                       None
# 1                       None
# 2                       None
#
# [3 rows x 25 columns]

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

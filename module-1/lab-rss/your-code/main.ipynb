# %% [markdown]
# # Working with RSS Feeds Lab
#
# Complete the following set of exercises to solidify your knowledge of parsing RSS feeds and extracting information from them.

# %%
import feedparser

# %% [markdown]
# ### 1. Use feedparser to parse the following RSS feed URL.

# %%
url = 'http://feeds.feedburner.com/oreilly/radar/atom'

# %%
atom = feedparser.parse(url)

# %% [markdown]
# ### 2. Obtain a list of components (keys) that are available for this feed.

# %%
atom.keys()
# Out:
# dict_keys(['feed', 'entries', 'bozo', 'headers', 'etag', 'updated', 'updated_parsed', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %% [markdown]
# ### 3. Obtain a list of components (keys) that are available for the *feed* component of this RSS feed.

# %%
atom.feed.keys()
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'subtitle', 'subtitle_detail', 'updated', 'updated_parsed', 'language', 'sy_updateperiod', 'sy_updatefrequency', 'generator_detail', 'generator', 'feedburner_info', 'geo_lat', 'geo_long', 'feedburner_emailserviceid', 'feedburner_feedburnerhostname'])

# %% [markdown]
# ### 4. Extract and print the feed title, subtitle, author, and link.

# %%
title = atom.feed.title
subtitle = atom.feed.subtitle
author = atom.entries[0]['author']
link = atom.entries[0]['link']

print(title)
print(subtitle)
print(author)
print(link)
# Out:
# Radar
# Now, next, and beyond: Tracking need-to-know trends at the intersection of business and technology
# Nat Torkington
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/QTPIfa1h-uM/

# %% [markdown]
# ### 5. Count the number of entries that are contained in this RSS feed.

# %%
print(len(atom.entries))
# Out:
# 60

# %% [markdown]
# ### 6. Obtain a list of components (keys) available for an entry.
#
# *Hint: Remember to index first before requesting the keys*

# %%
components = [i for i in atom.feed.keys()]
components
# Out:
# ['title',
#  'title_detail',
#  'links',
#  'link',
#  'subtitle',
#  'subtitle_detail',
#  'updated',
#  'updated_parsed',
#  'language',
#  'sy_updateperiod',
#  'sy_updatefrequency',
#  'generator_detail',
#  'generator',
#  'feedburner_info',
#  'geo_lat',
#  'geo_long',
#  'feedburner_emailserviceid',
#  'feedburner_feedburnerhostname']

# %% [markdown]
# ### 7. Extract a list of entry titles.

# %%
entry_titles = [atom.entries[i].title for i in range(len(atom.entries))]
entry_titles
# Out:
# ['Four short links: 22 January 2020',
#  'Four short links: 21 January 2020',
#  'Four short links: 20 January 2020',
#  'Four short links: 17 January 2020',
#  'Four short links: 16 January 2020',
#  'Reinforcement learning for the real world',
#  'Four short links: 15 January 2020',
#  'Four short links: 14 January 2020',
#  'Where programming languages are headed in 2020',
#  'Four short links: 13 January 2020',
#  'Four short links: 10 January 2020',
#  'Radar trends to watch: January 2020',
#  'Four short links: 9 January 2020',
#  'Four short links: 8 January 2020',
#  '9 additional books for the Next Economy',
#  '8 AI trends we’re watching in 2020',
#  'Four short links: 7 January 2020',
#  'Rethinking programming',
#  'Four short links: 6 January 2020',
#  'Four short links: 3 January 2020',
#  'Four short links: 2 January 2020',
#  '10+ books for the Next Economy',
#  'Four short links: 1 January 2020',
#  'Four short links: 31 December 2019',
#  'Four short links: 30 December 2019',
#  'Four short links: 27 December 2019',
#  'Four short links: 26 December 2019',
#  'Four short links: 25 December 2019',
#  'Four short links: 24 December 2019',
#  'Four short links: 23 December 2019',
#  'Four short links: 20 December 2019',
#  'Four short links: 19 December 2019',
#  'AI is computer science disguised as hard work',
#  'Four short links: 18 December 2019',
#  'Four short links: 17 December 2019',
#  '5 industries that demonstrate how blockchains go beyond finance',
#  'Four short links: 16 December 2019',
#  'Four short links: 13 December 2019',
#  'Why you should care about debugging machine learning models',
#  'Four short links: 12 December 2019',
#  'Four short links: 11 December 2019',
#  'The road to Software 2.0',
#  'Four short links: 10 December 2019',
#  'Four short links: 9 December 2019',
#  'Four short links: 6 December 2019',
#  'Radar trends to watch: December 2019',
#  'Four short links: 5 December 2019',
#  'Four short links: 4 December 2019',
#  'Use your people as competitive advantage',
#  'Four short links: 3 December 2019',
#  'A 5G future',
#  'Four short links: 2 December 2019',
#  'Four short links: 29 November 2019',
#  'Four short links: 28 November 2019',
#  'Four short links: 27 November 2019',
#  'Moving AI and ML from research into production',
#  'Four short links: 26 November 2019',
#  'Four short links: 25 November 2019',
#  'Four short links: 22 November 2019',
#  'Why you should care about robotic process automation']

# %% [markdown]
# ### 8. Calculate the percentage of "Four short links" entry titles.

# %%
four_short_links = [i for i in entry_titles if 'Four short links' in i]
percentage = len(four_short_links)/len(entry_titles)*100
print(round(percentage, 2), '%')
# Out:
# 73.33 %

# %% [markdown]
# ### 9. Create a Pandas data frame from the feed's entries.

# %%
import pandas as pd

# %%
entries = atom.entries
df = pd.DataFrame(entries)
df
# Out:
#                                                 title  \
# 0                   Four short links: 22 January 2020
# 1                   Four short links: 21 January 2020
# 2                   Four short links: 20 January 2020
# 3                   Four short links: 17 January 2020
# 4                   Four short links: 16 January 2020
# 5           Reinforcement learning for the real world
# 6                   Four short links: 15 January 2020
# 7                   Four short links: 14 January 2020
# 8      Where programming languages are headed in 2020
# 9                   Four short links: 13 January 2020
# 10                  Four short links: 10 January 2020
# 11                Radar trends to watch: January 2020
# 12                   Four short links: 9 January 2020
# 13                   Four short links: 8 January 2020
# 14            9 additional books for the Next Economy
# 15                 8 AI trends we’re watching in 2020
# 16                   Four short links: 7 January 2020
# 17                             Rethinking programming
# 18                   Four short links: 6 January 2020
# 19                   Four short links: 3 January 2020
# 20                   Four short links: 2 January 2020
# 21                     10+ books for the Next Economy
# 22                   Four short links: 1 January 2020
# 23                 Four short links: 31 December 2019
# 24                 Four short links: 30 December 2019
# 25                 Four short links: 27 December 2019
# 26                 Four short links: 26 December 2019
# 27                 Four short links: 25 December 2019
# 28                 Four short links: 24 December 2019
# 29                 Four short links: 23 December 2019
# 30                 Four short links: 20 December 2019
# 31                 Four short links: 19 December 2019
# 32      AI is computer science disguised as hard work
# 33                 Four short links: 18 December 2019
# 34                 Four short links: 17 December 2019
# 35  5 industries that demonstrate how blockchains ...
# 36                 Four short links: 16 December 2019
# 37                 Four short links: 13 December 2019
# 38  Why you should care about debugging machine le...
# 39                 Four short links: 12 December 2019
# 40                 Four short links: 11 December 2019
# 41                           The road to Software 2.0
# 42                 Four short links: 10 December 2019
# 43                  Four short links: 9 December 2019
# 44                  Four short links: 6 December 2019
# 45               Radar trends to watch: December 2019
# 46                  Four short links: 5 December 2019
# 47                  Four short links: 4 December 2019
# 48           Use your people as competitive advantage
# 49                  Four short links: 3 December 2019
# 50                                        A 5G future
# 51                  Four short links: 2 December 2019
# 52                 Four short links: 29 November 2019
# 53                 Four short links: 28 November 2019
# 54                 Four short links: 27 November 2019
# 55     Moving AI and ML from research into production
# 56                 Four short links: 26 November 2019
# 57                 Four short links: 25 November 2019
# 58                 Four short links: 22 November 2019
# 59  Why you should care about robotic process auto...
#
#                                          title_detail  \
# 0   {'type': 'text/plain', 'language': None, 'base...
# 1   {'type': 'text/plain', 'language': None, 'base...
# 2   {'type': 'text/plain', 'language': None, 'base...
# 3   {'type': 'text/plain', 'language': None, 'base...
# 4   {'type': 'text/plain', 'language': None, 'base...
# 5   {'type': 'text/plain', 'language': None, 'base...
# 6   {'type': 'text/plain', 'language': None, 'base...
# 7   {'type': 'text/plain', 'language': None, 'base...
# 8   {'type': 'text/plain', 'language': None, 'base...
# 9   {'type': 'text/plain', 'language': None, 'base...
# 10  {'type': 'text/plain', 'language': None, 'base...
# 11  {'type': 'text/plain', 'language': None, 'base...
# 12  {'type': 'text/plain', 'language': None, 'base...
# 13  {'type': 'text/plain', 'language': None, 'base...
# 14  {'type': 'text/plain', 'language': None, 'base...
# 15  {'type': 'text/plain', 'language': None, 'base...
# 16  {'type': 'text/plain', 'language': None, 'base...
# 17  {'type': 'text/plain', 'language': None, 'base...
# 18  {'type': 'text/plain', 'language': None, 'base...
# 19  {'type': 'text/plain', 'language': None, 'base...
# 20  {'type': 'text/plain', 'language': None, 'base...
# 21  {'type': 'text/plain', 'language': None, 'base...
# 22  {'type': 'text/plain', 'language': None, 'base...
# 23  {'type': 'text/plain', 'language': None, 'base...
# 24  {'type': 'text/plain', 'language': None, 'base...
# 25  {'type': 'text/plain', 'language': None, 'base...
# 26  {'type': 'text/plain', 'language': None, 'base...
# 27  {'type': 'text/plain', 'language': None, 'base...
# 28  {'type': 'text/plain', 'language': None, 'base...
# 29  {'type': 'text/plain', 'language': None, 'base...
# 30  {'type': 'text/plain', 'language': None, 'base...
# 31  {'type': 'text/plain', 'language': None, 'base...
# 32  {'type': 'text/plain', 'language': None, 'base...
# 33  {'type': 'text/plain', 'language': None, 'base...
# 34  {'type': 'text/plain', 'language': None, 'base...
# 35  {'type': 'text/plain', 'language': None, 'base...
# 36  {'type': 'text/plain', 'language': None, 'base...
# 37  {'type': 'text/plain', 'language': None, 'base...
# 38  {'type': 'text/plain', 'language': None, 'base...
# 39  {'type': 'text/plain', 'language': None, 'base...
# 40  {'type': 'text/plain', 'language': None, 'base...
# 41  {'type': 'text/plain', 'language': None, 'base...
# 42  {'type': 'text/plain', 'language': None, 'base...
# 43  {'type': 'text/plain', 'language': None, 'base...
# 44  {'type': 'text/plain', 'language': None, 'base...
# 45  {'type': 'text/plain', 'language': None, 'base...
# 46  {'type': 'text/plain', 'language': None, 'base...
# 47  {'type': 'text/plain', 'language': None, 'base...
# 48  {'type': 'text/plain', 'language': None, 'base...
# 49  {'type': 'text/plain', 'language': None, 'base...
# 50  {'type': 'text/plain', 'language': None, 'base...
# 51  {'type': 'text/plain', 'language': None, 'base...
# 52  {'type': 'text/plain', 'language': None, 'base...
# 53  {'type': 'text/plain', 'language': None, 'base...
# 54  {'type': 'text/plain', 'language': None, 'base...
# 55  {'type': 'text/plain', 'language': None, 'base...
# 56  {'type': 'text/plain', 'language': None, 'base...
# 57  {'type': 'text/plain', 'language': None, 'base...
# 58  {'type': 'text/plain', 'language': None, 'base...
# 59  {'type': 'text/plain', 'language': None, 'base...
#
#                                                 links  \
# 0   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 1   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 2   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 3   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 4   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 5   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 6   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 7   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 8   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 9   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 10  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 11  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 12  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 13  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 14  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 15  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 16  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 17  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 18  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 19  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 20  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 21  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 22  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 23  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 24  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 25  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 26  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 27  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 28  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 29  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 30  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 31  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 32  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 33  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 34  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 35  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 36  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 37  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 38  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 39  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 40  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 41  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 42  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 43  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 44  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 45  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 46  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 47  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 48  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 49  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 50  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 51  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 52  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 53  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 54  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 55  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 56  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 57  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 58  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 59  [{'rel': 'alternate', 'type': 'text/html', 'hr...
#
#                                
# 25  Fri, 27 Dec 2019 05:01:00 +0000    (2019, 12, 27, 5, 1, 0, 4, 361, 0)
# 26  Thu, 26 Dec 2019 05:01:00 +0000    (2019, 12, 26, 5, 1, 0, 3, 360, 0)
# 27  Wed, 25 Dec 2019 05:01:00 +0000    (2019, 12, 25, 5, 1, 0, 2, 359, 0)
# 28  Tue, 24 Dec 2019 05:01:00 +0000    (2019, 12, 24, 5, 1, 0, 1, 358, 0)
# 29  Mon, 23 Dec 2019 05:01:00 +0000    (2019, 12, 23, 5, 1, 0, 0, 357, 0)
# 30  Fri, 20 Dec 2019 05:01:00 +0000    (2019, 12, 20, 5, 1, 0, 4, 354, 0)
# 31  Thu, 19 Dec 2019 05:01:00 +0000    (2019, 12, 19, 5, 1, 0, 3, 353, 0)
# 32  Wed, 18 Dec 2019 11:00:00 +0000   (2019, 12, 18, 11, 0, 0, 2, 352, 0)
# 33  Wed, 18 Dec 2019 05:01:00 +0000    (2019, 12, 18, 5, 1, 0, 2, 352, 0)
# 34  Tue, 17 Dec 2019 05:01:00 +0000    (2019, 12, 17, 5, 1, 0, 1, 351, 0)
# 35  Mon, 16 Dec 2019 11:00:00 +0000   (2019, 12, 16, 11, 0, 0, 0, 350, 0)
# 36  Mon, 16 Dec 2019 05:01:00 +0000    (2019, 12, 16, 5, 1, 0, 0, 350, 0)
# 37  Fri, 13 Dec 2019 05:01:00 +0000    (2019, 12, 13, 5, 1, 0, 4, 347, 0)
# 38  Thu, 12 Dec 2019 11:00:00 +0000   (2019, 12, 12, 11, 0, 0, 3, 346, 0)
# 39  Thu, 12 Dec 2019 05:01:00 +0000    (2019, 12, 12, 5, 1, 0, 3, 346, 0)
# 40  Wed, 11 Dec 2019 05:01:00 +0000    (2019, 12, 11, 5, 1, 0, 2, 345, 0)
# 41  Tue, 10 Dec 2019 11:00:00 +0000   (2019, 12, 10, 11, 0, 0, 1, 344, 0)
# 42  Tue, 10 Dec 2019 05:01:00 +0000    (2019, 12, 10, 5, 1, 0, 1, 344, 0)
# 43  Mon, 09 Dec 2019 05:01:00 +0000     (2019, 12, 9, 5, 1, 0, 0, 343, 0)
# 44  Fri, 06 Dec 2019 05:01:00 +0000     (2019, 12, 6, 5, 1, 0, 4, 340, 0)
# 45  Thu, 05 Dec 2019 12:00:00 +0000    (2019, 12, 5, 12, 0, 0, 3, 339, 0)
# 46  Thu, 05 Dec 2019 05:01:00 +0000     (2019, 12, 5, 5, 1, 0, 3, 339, 0)
# 47  Wed, 04 Dec 2019 05:01:00 +0000     (2019, 12, 4, 5, 1, 0, 2, 338, 0)
# 48  Tue, 03 Dec 2019 09:00:00 +0000     (2019, 12, 3, 9, 0, 0, 1, 337, 0)
# 49  Tue, 03 Dec 2019 05:01:00 +0000     (2019, 12, 3, 5, 1, 0, 1, 337, 0)
# 50  Mon, 02 Dec 2019 10:00:00 +0000    (2019, 12, 2, 10, 0, 0, 0, 336, 0)
# 51  Mon, 02 Dec 2019 05:01:00 +0000     (2019, 12, 2, 5, 1, 0, 0, 336, 0)
# 52  Fri, 29 Nov 2019 05:01:00 +0000    (2019, 11, 29, 5, 1, 0, 4, 333, 0)
# 53  Thu, 28 Nov 2019 05:01:00 +0000    (2019, 11, 28, 5, 1, 0, 3, 332, 0)
# 54  Wed, 27 Nov 2019 05:01:00 +0000    (2019, 11, 27, 5, 1, 0, 2, 331, 0)
# 55  Tue, 26 Nov 2019 05:10:13 +0000  (2019, 11, 26, 5, 10, 13, 1, 330, 0)
# 56  Tue, 26 Nov 2019 05:01:00 +0000    (2019, 11, 26, 5, 1, 0, 1, 330, 0)
# 57  Mon, 25 Nov 2019 05:01:00 +0000    (2019, 11, 25, 5, 1, 0, 0, 329, 0)
# 58  Fri, 22 Nov 2019 05:01:00 +0000    (2019, 11, 22, 5, 1, 0, 4, 326, 0)
# 59  Thu, 21 Nov 2019 12:00:00 +0000   (2019, 11, 21, 12, 0, 0, 3, 325, 0)
#
#                                               authors  \
# 0                        [{'name': 'Nat Torkington'}]
# 1                        [{'name': 'Nat Torkington'}]
# 2                        [{'name': 'Nat Torkington'}]
# 3                        [{'name': 'Nat Torkington'}]
# 4                        [{'name': 'Nat Torkington'}]
# 5                             [{'name': 'Jenn Webb'}]
# 6                        [{'name': 'Nat Torkington'}]
# 7                        [{'name': 'Nat Torkington'}]
# 8          [{'name': 'Zan McQuade and Amanda Quinn'}]
# 9                        [{'name': 'Nat Torkington'}]
# 10                       [{'name': 'Nat Torkington'}]
# 11                        [{'name': 'Mike Loukides'}]
# 12                       [{'name': 'Nat Torkington'}]
# 13                       [{'name': 'Nat Torkington'}]
# 14                                               [{}]
# 15                       [{'name': 'Roger Magoulas'}]
# 16                       [{'name': 'Nat Torkington'}]
# 17                        [{'name': 'Mike Loukides'}]
# 18                       [{'name': 'Nat Torkington'}]
# 19                       [{'name': 'Nat Torkington'}]
# 20                       [{'name': 'Nat Torkington'}]
# 21                                               [{}]
# 22                       [{'name': 'Nat Torkington'}]
# 23                       [{'name': 'Nat Torkington'}]
# 24                       [{'name': 'Nat Torkington'}]
# 25                       [{'name': 'Nat Torkington'}]
# 26                       [{'name': 'Nat Torkington'}]
# 27                       [{'name': 'Nat Torkington'}]
# 28                       [{'name': 'Nat Torkington'}]
# 29                       [{'name': 'Nat Torkington'}]
# 30                       [{'name': 'Nat Torkington'}]
# 31                       [{'name': 'Nat Torkington'}]
# 32                            [{'name': 'Jenn Webb'}]
# 33                       [{'name': 'Nat Torkington'}]
# 34                       [{'name': 'Nat Torkington'}]
# 35                      [{'name': 'Alison McCauley'}]
# 36                       [{'name': 'Nat Torkington'}]
# 37                       [{'name': 'Nat Torkington'}]
# 38         [{'name': 'Patrick Hall and Andrew Burt'}]
# 39                       [{'name': 'Nat Torkington'}]
# 40                       [{'name': 'Nat Torkington'}]
# 41         [{'name': 'Mike Loukides and Ben Lorica'}]
# 42                       [{'name': 'Nat Torkington'}]
# 43                       [{'name': 'Nat Torkington'}]
# 44                       [{'name': 'Nat Torkington'}]
# 45                        [{'name': 'Mike Loukides'}]
# 46                       [{'name': 'Nat Torkington'}]
# 47                       [{'name': 'Nat Torkington'}]
# 48                        [{'name': 'Pamela Rucker'}]
# 49                       [{'name': 'Nat Torkington'}]
# 50                        [{'name': 'Mike Loukides'}]
# 51                       [{'name': 'Nat Torkington'}]
# 52                       [{'name': 'Nat Torkington'}]
# 53                       [{'name': 'Nat Torkington'}]
# 54                       [{'name': 'Nat Torkington'}]
# 55                            [{'name': 'Jenn Webb'}]
# 56                       [{'name': 'Nat Torkington'}]
# 57                       [{'name': 'Nat Torkington'}]
# 58                       [{'name': 'Nat Torkington'}]
# 59  [{'name': 'Sunil Ranka, Roger Magoulas and Ste...
#
#                                           author  \
# 0                                 Nat Torkington
# 1                                 Nat Torkington
# 2                                 Nat Torkington
# 3                                 Nat Torkington
# 4                                 Nat Torkington
# 5                                      Jenn Webb
# 6                                 Nat Torkington
# 7                                 Nat Torkington
# 8                   Zan McQuade and Amanda Quinn
# 9                                 Nat Torkington
# 10                                Nat Torkington
# 11                                 Mike Loukides
# 12                                Nat Torkington
# 13                                Nat Torkington
# 14
# 15                                Roger Magoulas
# 16                                Nat Torkington
# 17                                 Mike Loukides
# 18                                Nat Torkington
# 19                                Nat Torkington
# 20                                Nat Torkington
# 21
# 22                                Nat Torkington
# 23                                Nat Torkington
# 24                                Nat Torkington
# 25                                Nat Torkington
# 26                                Nat Torkington
# 27                                Nat Torkington
# 28                                Nat Torkington
# 29                                Nat Torkington
# 30                                Nat Torkington
# 31                                Nat Torkington
# 32                                     Jenn Webb
# 33                                Nat Torkington
# 34                                Nat Torkington
# 35                               Alison McCauley
# 36                                Nat Torkington
# 37                                Nat Torkington
# 38                  Patrick Hall and Andrew Burt
# 39                                Nat Torkington
# 40                                Nat Torkington
# 41                  Mike Loukides and Ben Lorica
# 42                                Nat Torkington
# 43                                Nat Torkington
# 44                                Nat Torkington
# 45                                 Mike Loukides
# 46                                Nat Torkington
# 47                                Nat Torkington
# 48                                 Pamela Rucker
# 49                                Nat Torkington
# 50                                 Mike Loukides
# 51                                Nat Torkington
# 52                                Nat Torkington
# 53                                Nat Torkington
# 54                                Nat Torkington
# 55                                     Jenn Webb
# 56                                Nat Torkington
# 57                                Nat Torkington
# 58                                Nat Torkington
# 59  Sunil Ranka, Roger Magoulas and Steve Swoyer
#
#                                         author_detail  \
# 0                          {'name': 'Nat Torkington'}
# 1                          {'name': 'Nat Torkington'}
# 2                          {'name': 'Nat Torkington'}
# 3                          {'name': 'Nat Torkington'}
# 4                          {'name': 'Nat Torkington'}
# 5                               {'name': 'Jenn Webb'}
# 6                          {'name': 'Nat Torkington'}
# 7                          {'name': 'Nat Torkington'}
# 8            {'name': 'Zan McQuade and Amanda Quinn'}
# 9                          {'name': 'Nat Torkington'}
# 10                         {'name': 'Nat Torkington'}
# 11                          {'name': 'Mike Loukides'}
# 12                         {'name': 'Nat Torkington'}
# 13                         {'name': 'Nat Torkington'}
# 14                                                NaN
# 15                         {'name': 'Roger Magoulas'}
# 16                         {'name': 'Nat Torkington'}
# 17                          {'name': 'Mike Loukides'}
# 18                         {'name': 'Nat Torkington'}
# 19                         {'name': 'Nat Torkington'}
# 20                         {'name': 'Nat Torkington'}
# 21                                                NaN
# 22                         {'name': 'Nat Torkington'}
# 23                         {'name': 'Nat Torkington'}
# 24                         {'name': 'Nat Torkington'}
# 25                         {'name': 'Nat Torkington'}
# 26                         {'name': 'Nat Torkington'}
# 27                         {'name': 'Nat Torkington'}
# 28                         {'name': 'Nat Torkington'}
# 29                         {'name': 'Nat Torkington'}
# 30                         {'name': 'Nat Torkington'}
# 31                         {'name': 'Nat Torkington'}
# 32                              {'name': 'Jenn Webb'}
# 33                         {'name': 'Nat Torkington'}
# 34                         {'name': 'Nat Torkington'}
# 35                        {'name': 'Alison McCauley'}
# 36                         {'name': 'Nat Torkington'}
# 37                         {'name': 'Nat Torkington'}
# 38           {'name': 'Patrick Hall and Andrew Burt'}
# 39                         {'name': 'Nat Torkington'}
# 40                         {'name': 'Nat Torkington'}
# 41           {'name': 'Mike Loukides and Ben Lorica'}
# 42                         {'name': 'Nat Torkington'}
# 43                         {'name': 'Nat Torkington'}
# 44                         {'name': 'Nat Torkington'}
# 45                          {'name': 'Mike Loukides'}
# 46                         {'name': 'Nat Torkington'}
# 47                         {'name': 'Nat Torkington'}
# 48                          {'name': 'Pamela Rucker'}
# 49                         {'name': 'Nat Torkington'}
# 50                          {'name': 'Mike Loukides'}
# 51                         {'name': 'Nat Torkington'}
# 52                         {'name': 'Nat Torkington'}
# 53                         {'name': 'Nat Torkington'}
# 54                         {'name': 'Nat Torkington'}
# 55                              {'name': 'Jenn Webb'}
# 56                         {'name': 'Nat Torkington'}
# 57                         {'name': 'Nat Torkington'}
# 58                         {'name': 'Nat Torkington'}
# 59  {'name': 'Sunil Ranka, Roger Magoulas and Stev...
#
#                                                  tags  \
# 0   [{'term': 'Four Short Links', 'scheme': None, ...
# 1   [{'term': 'Four Short Links', 'scheme': None, ...
# 2   [{'term': 'Four Short Links', 'scheme': None, ...
# 3   [{'term': 'Four Short Links', 'scheme': None, ...
# 4   [{'term': 'Four Short Links', 'scheme': None, ...
# 5   [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 6   [{'term': 'Four Short Links', 'scheme': None, ...
# 7   [{'term': 'Four Short Links', 'scheme': None, ...
# 8   [{'term': 'Innovation & Disruption', 'scheme':...
# 9   [{'term': 'Four Short Links', 'scheme': None, ...
# 10  [{'term': 'Four Short Links', 'scheme': None, ...
# 11  [{'term': 'Innovation & Disruption', 'scheme':...
# 12  [{'term': 'Four Short Links', 'scheme': None, ...
# 13  [{'term': 'Four Short Links', 'scheme': None, ...
# 14  [{'term': 'Next Economy', 'scheme': None, 'lab...
# 15  [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 16  [{'term': 'Four Short Links', 'scheme': None, ...
# 17  [{'term': 'Innovation & Disruption', 'scheme':...
# 18  [{'term': 'Four Short Links', 'scheme': None, ...
# 19  [{'term': 'Four Short Links', 'scheme': None, ...
# 20  [{'term': 'Four Short Links', 'scheme': None, ...
# 21  [{'term': 'Next Economy', 'scheme': None, 'lab...
# 22  [{'term': 'Four Short Links', 'scheme': None, ...
# 23  [{'term': 'Four Short Links', 'scheme': None, ...
# 24  [{'term': 'Four Short Links', 'scheme': None, ...
# 25  [{'term': 'Four Short Links', 'scheme': None, ...
# 26  [{'term': 'Four Short Links', 'scheme': None, ...
# 27  [{'term': 'Four Short Links', 'scheme': None, ...
# 28  [{'term': 'Four Short Links', 'scheme': None, ...
# 29  [{'term': 'Four Short Links', 'scheme': None, ...
# 30  [{'term': 'Four Short Links', 'scheme': None, ...
# 31  [{'term': 'Four Short Links', 'scheme': None, ...
# 32  [{'term': 'AI & ML', 'scheme': None, 'label': ...
#
# 28  Cybersecurity Book 1.0 Released &#8212; the UK...
# 29  The Hidden Structures of &#8220;Choose Your Ow...
# 30  ArcaneVM &#8212; A Fully Homomorphic Encryptio...
# 31  The #1 Bug Predictor is Not Technical; It&#821...
# 32  Roger Magoulas recently sat down with Rob Thom...
# 33  Tech Lead Expectations for Engineering Project...
# 34  The Essential Guide to Shenzhen (Bunnie Huang)...
# 35  Although blockchain technology is still in its...
# 36  Association of Screen Time and Depression in A...
# 37  Flutter &#8212; Google’s UI toolkit for buildi...
# 38  For all the excitement about machine learning ...
# 39  Social Science One Advisory Group Fingers Face...
# 40  disaster.radio &#8212; a disaster-resilient co...
# 41  Roughly a year ago, we wrote “What machine lea...
# 42  The Hidden Worries of Facial Recognition Techn...
# 43  Learning from Incidents &#8212; super useful a...
# 44  Declarative Assembly of Web Applications From ...
# 45  Privacy and security trends DNS over HTTPS is ...
# 46  Rediscovered Incomplete Infocom Text Adventure...
# 47  The Complexity Explorer &#8212; online courses...
# 48  In a fast-paced digital world, it is tempting ...
# 49  Oxide.computer &#8212; a new hardware company,...
# 50  For the past year, 5G cell technology has gene...
# 51  Two Years at Dropbox &#8212; a lot of wisdom a...
# 52  A Visual Guide to Using BERT for the First Tim...
# 53  Raspberry Pi Recovery Kit &#8212; Pi for Prepp...
# 54  Comby &#8212; a tool for matching and rewritin...
# 55  In this interview from O&#8217;Reilly Foo Camp...
# 56  Braid &#8212; a set of extensions to HTTP whic...
# 57  Why “Always use UTC” is Bad Advice &#8212; thr...
# 58  FAQ Off &#8212; open source software that lets...
# 59  In a classic 1983 paper, cognitive psychologis...
#
#                                        summary_detail  \
# 0   {'type': 'text/html', 'language': None, 'base'...
# 1   {'type': 'text/html', 'language': None, 'base'...
# 2   {'type': 'text/html', 'language': None, 'base'...
# 3   {'type': 'text/html', 'language': None, 'base'...
# 4   {'type': 'text/html', 'language': None, 'base'...
# 5   {'type': 'text/html', 'language': None, 'base'...
# 6   {'type': 'text/html', 'language': None, 'base'...
# 7   {'type': 'text/html', 'language': None, 'base'...
# 8   {'type': 'text/html', 'language': None, 'base'...
# 9   {'type': 'text/html', 'language': None, 'base'...
# 10  {'type': 'text/html', 'language': None, 'base'...
# 11  {'type': 'text/html', 'language': None, 'base'...
# 12  {'type': 'text/html', 'language': None, 'base'...
# 13  {'type': 'text/html', 'language': None, 'base'...
# 14  {'type': 'text/html', 'language': None, 'base'...
# 15  {'type': 'text/html', 'language': None, 'base'...
# 16  {'type': 'text/html', 'language': None, 'base'...
# 17  {'type': 'text/html', 'language': None, 'base'...
# 18  {'type': 'text/html', 'language': None, 'base'...
# 19  {'type': 'text/html', 'language': None, 'base'...
# 20  {'type': 'text/html', 'language': None, 'base'...
# 21  {'type': 'text/html', 'language': None, 'base'...
# 22  {'type': 'text/html', 'language': None, 'base'...
# 23  {'type': 'text/html', 'language': None, 'base'...
# 24  {'type': 'text/html', 'language': None, 'base'...
# 25  {'type': 'text/html', 'language': None, 'base'...
# 26  {'type': 'text/html', 'language': None, 'base'...
# 27  {'type': 'text/html', 'language': None, 'base'...
# 28  {'type': 'text/html', 'language': None, 'base'...
# 29  {'type': 'text/html', 'language': None, 'base'...
# 30  {'type': 'text/html', 'language': None, 'base'...
# 31  {'type': 'text/html', 'language': None, 'base'...
# 32  {'type': 'text/html', 'language': None, 'base'...
# 33  {'type': 'text/html', 'language': None, 'base'...
# 34  {'type': 'text/html', 'language': None, 'base'...
# 35  {'type': 'text/html', 'language': None, 'base'...
# 36  {'type': 'text/html', 'language': None, 'base'...
# 37  {'type': 'text/html', 'language': None, 'base'...
# 38  {'type': 'text/html', 'language': None, 'base'...
# 39  {'type': 'text/html', 'language': None, 'base'...
# 40  {'type': 'text/html', 'language': None, 'base'...
# 41  {'type': 'text/html', 'language': None, 'base'...
# 42  {'type': 'text/html', 'language': None, 'base'...
# 43  {'type': 'text/html', 'language': None, 'base'...
# 44  {'type': 'text/html', 'language': None, 'base'...
# 45  {'type': 'text/html', 'language': None, 'base'...
# 46  {'type': 'text/html', 'language': None, 'base'...
# 47  {'type': 'text/html', 'language': None, 'base'...
# 48  {'type': 'text/html', 'language': None, 'base'...
# 49  {'type': 'text/html', 'language': None, 'base'...
# 50  {'type': 'text/html', 'language': None, 'base'...
# 51  {'type': 'text/html', 'language': None, 'base'...
# 52  {'type': 'text/html', 'language': None, 'base'...
# 53  {'type': 'text/html', 'language': None, 'base'...
# 54  {'type': 'text/html', 'language': None, 'base'...
# 55  {'type': 'text/html', 'language': None, 'base'...
# 56  {'type': 'text/html', 'language': None, 'base'...
# 57  {'type': 'text/html', 'language': None, 'base'...
# 58  {'type': 'text/html', 'language': None, 'base'...
# 59  {'type': 'text/html', 'language': None, 'base'...
#
#                                               content  \
# 0   [{'type': 'text/html', 'language': None, 'base...
# 1   [{'type': 'text/html', 'language': None, 'base...
# 2   [{'type': 'text/html', 'language': None, 'base...
# 3   [{'type': 'text/html', 'language': None, 'base...
# 4   [{'type': 'text/html', 'language': None, 'base...
# 5   [{'type': 'text/html', 'language': None, 'base...
# 6   [{'type': 'text/html', 'language': None, 'base...
# 7   [{'type': 'text/html', 'language': None, 'base...
# 8   [{'type': 'text/html', 'language': None, 'base...
# 9   [{'type': 'text/html', 'language': None, 'base...
# 10  [{'type': 'text/html', 'language': None, 'base...
# 11  [{'type': 'text/html', 'language': None, 'base...
# 12  [{'type': 'text/html', 'language': None, 'base...
# 13  [{'type': 'text/html', 'language': None, 'base...
# 14  [{'type': 'text/html', 'language': None, 'base...
# 15  [{'type': 'text/html', 'language': None, 'base...
# 16  [{'type': 'text/html', 'language': None, 'base...
# 17  [{'type': 'text/html', 'language': None, 'base...
# 18  [{'type': 'text/html', 'language': None, 'base...
# 19  [{'type': 'text/html', 'language': None, 'base...
# 20  [{'type': 'text/html', 'language': None, 'base...
# 21  [{'type': 'text/html', 'language': None, 'base...
# 22  [{'type': 'text/html', 'language': None, 'base...
# 23  [{'type': 'text/html', 'language': None, 'base...
# 24  [{'type': 'text/html', 'language': None, 'base...
# 25  [{'type': 'text/html', 'language': None, 'base...
# 26  [{'type': 'text/html', 'language': None, 'base...
# 27  [{'type': 'text/html', 'language': None, 'base...
# 28  [{'type': 'text/html', 'language': None, 'base...
# 29  [{'type': 'text/html', 'language': None, 'base...
# 30  [{'type': 'text/html', 'language': None, 'base...
# 31  [{'type': 'text/html', 'language': None, 'base...
# 32  [{'type': 'text/html', 'language': None, 'base...
# 33  [{'type': 'text/html', 'language': None, 'base...
# 34  [{'type': 'text/html', 'language': None, 'base...
# 35  [{'type': 'text/html', 'language': None, 'base...
# 36  [{'type': 'text/html', 'language': None, 'base...
# 37  [{'type': 'text/html', 'language': None, 'base...
# 38  [{'type': 'text/html', 'language': None, 'base...
# 39  [{'type': 'text/html', 'language': None, 'base...
# 40  [{'type': 'text/html', 'language': None, 'base...
# 41  [{'type': 'text/html', 'language': None, 'base...
# 42  [{'type': 'text/html', 'language': None, 'base...
# 43  [{'type': 'text/html', 'language': None, 'base...
# 44  [{'type': 'text/html', 'language': None, 'base...
# 45  [{'type': 'text/html', 'language': None, 'base...
# 46  [{'type': 'text/html', 'language': None, 'base...
# 47  [{'type': 'text/html', 'language': None, 'base...
# 48  [{'type': 'text/html', 'language': None, 'base...
# 49  [{'type': 'text/html', 'language': None, 'base...
# 50  [{'type': 'text/html', 'language': None, 'base...
# 51  [{'type': 'text/html', 'language': None, 'base...
# 52  [{'type': 'text/html', 'language': None, 'base...
# 53  [{'type': 'text/html', 'language': None, 'base...
# 54  [{'type': 'text/html', 'language': None, 'base...
# 55  [{'type': 'text/html', 'language': None, 'base...
# 56  [{'type': 'text/html', 'language': None, 'base...
# 57  [{'type': 'text/html', 'language': None, 'base...
# 58  [{'type': 'text/html', 'language': None, 'base...
# 59  [{'type': 'text/html', 'language': None, 'base...
#
#                                        wfw_commentrss slash_comments  \
# 0   https://www.oreilly.com/radar/four-short-links...              0
# 1   https://www.oreilly.com/radar/four-short-links...              0
# 2   https://www.oreilly.com/radar/four-short-links...              0
# 3   https://www.oreilly.com/radar/four-short-links...              0
# 4   https://www.oreilly.com/radar/four-short-links...              0
# 5   https://www.oreilly.com/radar/reinforcement-le...              0
# 6   https://www.oreilly.com/radar/four-short-links...              0
# 7   https://www.oreilly.com/radar/four-short-links...              0
# 8   https://www.oreilly.com/radar/where-programmin...              0
# 9   https://www.oreilly.com/radar/four-short-links...              0
# 10  https://www.oreilly.com/radar/four-short-links...              0
# 11  https://www.oreilly.com/radar/radar-trends-to-...              0
# 12  https://www.oreilly.com/radar/four-short-links...              0
# 13  https://www.oreilly.com/radar/four-short-links...              0
# 14  https://www.oreilly.com/radar/more-books-for-t...              0
# 15  https://www.oreilly.com/radar/8-ai-trends-were...              0
# 16  https://www.oreilly.com/radar/four-short-links...              0
# 17  https://www.oreilly.com/radar/rethinking-progr...              0
# 18  https://www.oreilly.com/radar/four-short-links...              0
# 19  https://www.oreilly.com/radar/four-short-links...              0
# 20  https://www.oreilly.com/radar/four-short-links...              0
# 21  https://www.oreilly.com/radar/books-for-the-ne...              0
# 22  https://www.oreilly.com/radar/four-short-links...              0
# 23  https://www.oreilly.com/radar/four-short-links...              0
# 24  https://www.oreilly.com/radar/four-short-links...              0
# 25  https://www.oreilly.com/radar/four-short-links...              0
# 26  https://www.oreilly.com/radar/four-short-links...              0
# 27  https://www.oreilly.com/radar/four-short-links...              0
# 28  https://www.oreilly.com/radar/four-short-links...              0
# 29  https://www.oreilly.com/radar/four-short-links...              0
# 30  https://www.oreilly.com/radar/four-short-links...              0
# 31  https://www.oreilly.com/radar/four-short-links...              0
# 32  https://www.oreilly.com/radar/ai-is-computer-s...              0
# 33  https://www.oreilly.com/radar/four-short-links...              0
# 34  https://www.oreilly.com/radar/four-short-links...              0
# 35  https://www.oreilly.com/radar/5-industries-tha...              0
# 36  https://www.oreilly.com/radar/four-short-links...              0
# 37  https://www.oreilly.com/radar/four-short-links...              0
# 38  https://www.oreilly.com/radar/why-you-should-c...              0
# 37  https://www.oreilly.com/radar/four-short-links...
# 38  https://www.oreilly.com/radar/why-you-should-c...
# 39  https://www.oreilly.com/radar/four-short-links...
# 40  https://www.oreilly.com/radar/four-short-links...
# 41  https://www.oreilly.com/radar/the-road-to-soft...
# 42  https://www.oreilly.com/radar/four-short-links...
# 43  https://www.oreilly.com/radar/four-short-links...
# 44  https://www.oreilly.com/radar/four-short-links...
# 45  https://www.oreilly.com/radar/radar-trends-to-...
# 46  https://www.oreilly.com/radar/four-short-links...
# 47  https://www.oreilly.com/radar/four-short-links...
# 48  https://www.oreilly.com/radar/use-your-people-...
# 49  https://www.oreilly.com/radar/four-short-links...
# 50         https://www.oreilly.com/radar/a-5g-future/
# 51  https://www.oreilly.com/radar/four-short-links...
# 52  https://www.oreilly.com/radar/four-short-links...
# 53  https://www.oreilly.com/radar/four-short-links...
# 54  https://www.oreilly.com/radar/four-short-links...
# 55  https://www.oreilly.com/radar/moving-ai-and-ml...
# 56  https://www.oreilly.com/radar/four-short-links...
# 57  https://www.oreilly.com/radar/four-short-links...
# 58  https://www.oreilly.com/radar/four-short-links...
# 59  https://www.oreilly.com/radar/why-you-should-c...

# %% [markdown]
# ### 10. Count the number of entries per author and sort them in descending order.

# %%
authors = df.groupby('author', as_index=False).agg({'title':'count'})
authors.columns = ['author', 'entries']
authors.sort_values('entries', ascending=False)
# Out:
#                                           author  entries
# 5                                 Nat Torkington       44
# 3                                  Mike Loukides        4
# 2                                      Jenn Webb        3
# 0                                                       2
# 1                                Alison McCauley        1
# 4                   Mike Loukides and Ben Lorica        1
# 6                                  Pamela Rucker        1
# 7                   Patrick Hall and Andrew Burt        1
# 8                                 Roger Magoulas        1
# 9   Sunil Ranka, Roger Magoulas and Steve Swoyer        1
# 10                  Zan McQuade and Amanda Quinn        1

# %% [markdown]
# ### 11. Add a new column to the data frame that contains the length (number of characters) of each entry title. Return a data frame that contains the title, author, and title length of each entry in descending order (longest title length at the top).

# %%
df['title_length'] = df['title'].apply(len)
df[['title', 'author', 'title_length']].sort_values('title_length', ascending=False)
# Out:
#                                                 title  \
# 35  5 industries that demonstrate how blockchains ...
# 38  Why you should care about debugging machine le...
# 59  Why you should care about robotic process auto...
# 55     Moving AI and ML from research into production
# 8      Where programming languages are headed in 2020
# 32      AI is computer science disguised as hard work
# 5           Reinforcement learning for the real world
# 48           Use your people as competitive advantage
# 14            9 additional books for the Next Economy
# 45               Radar trends to watch: December 2019
# 11                Radar trends to watch: January 2020
# 52                 Four short links: 29 November 2019
# 37                 Four short links: 13 December 2019
# 31                 Four short links: 19 December 2019
# 58                 Four short links: 22 November 2019
# 33                 Four short links: 18 December 2019
# 34                 Four short links: 17 December 2019
# 57                 Four short links: 25 November 2019
# 36                 Four short links: 16 December 2019
# 56                 Four short links: 26 November 2019
# 39                 Four short links: 12 December 2019
# 40                 Four short links: 11 December 2019
# 42                 Four short links: 10 December 2019
# 54                 Four short links: 27 November 2019
# 28                 Four short links: 24 December 2019
# 53                 Four short links: 28 November 2019
# 29                 Four short links: 23 December 2019
# 30                 Four short links: 20 December 2019
# 27                 Four short links: 25 December 2019
# 24                 Four short links: 30 December 2019
# 15                 8 AI trends we’re watching in 2020
# 23                 Four short links: 31 December 2019
# 26                 Four short links: 26 December 2019
# 25                 Four short links: 27 December 2019
# 3                   Four short links: 17 January 2020
# 4                   Four short links: 16 January 2020
# 46                  Four short links: 5 December 2019
# 7                   Four short links: 14 January 2020
# 9                   Four short links: 13 January 2020
# 10                  Four short links: 10 January 2020
# 51                  Four short links: 2 December 2019
# 49                  Four short links: 3 December 2019
# 2                   Four short links: 20 January 2020
# 47                  Four short links: 4 December 2019
# 6                   Four short links: 15 January 2020
# 44                  Four short links: 6 December 2019
# 43                  Four short links: 9 December 2019
# 1                   Four short links: 21 January 2020
# 0                   Four short links: 22 January 2020
# 13                   Four short links: 8 January 2020
# 12                   Four short links: 9 January 2020
# 16                   Four short links: 7 January 2020
# 18                   Four short links: 6 January 2020
# 19                   Four short links: 3 January 2020
# 20                   Four short links: 2 January 2020
# 22                   Four short links: 1 January 2020
# 21                     10+ books for the Next Economy
# 41                           The road to Software 2.0
# 17                             Rethinking programming
# 50                                        A 5G future
#
#                                           author  title_length
# 35                               Alison McCauley            63
# 38                  Patrick Hall and Andrew Burt            59
# 59  Sunil Ranka, Roger Magoulas and Steve Swoyer            52
# 55                                     Jenn Webb            46
# 8                   Zan McQuade and Amanda Quinn            46
# 32                                     Jenn Webb            45
# 5                                      Jenn Webb            41
# 48                                 Pamela Rucker            40
# 14                                                          39
# 45                                 Mike Loukides            36
# 11                                 Mike Loukides            35
# 52                                Nat Torkington            34
# 37                                Nat Torkington            34
# 31                                Nat Torkington            34
# 58                                Nat Torkington            34
# 33                                Nat Torkington            34
# 34                                Nat Torkington            34
# 57                                Nat Torkington            34
# 36                                Nat Torkington            34
# 56                                Nat Torkington            34
# 39                                Nat Torkington            34
# 40                                Nat Torkington            34
# 42                                Nat Torkington            34
# 54                                Nat Torkington            34
# 28                                Nat Torkington            34
# 53                                Nat Torkington            34
# 29                                Nat Torkington            34
# 30                                Nat Torkington            34
# 27                                Nat Torkington            34
# 24                                Nat Torkington            34
# 15                                Roger Magoulas            34
# 23                                Nat Torkington            34
# 26                                Nat Torkington            34
# 25                                Nat Torkington            34
# 3                                 Nat Torkington            33
# 4                                 Nat Torkington            33
# 46                                Nat Torkington            33
# 7                                 Nat Torkington            33
# 9                                 Nat Torkington            33
# 10                                Nat Torkington            33
# 51                                Nat Torkington            33
# 49                                Nat Torkington            33
# 2                                 Nat Torkington            33
# 47                                Nat Torkington            33
# 6                                 Nat Torkington            33
# 44                                Nat Torkington            33
# 43                                Nat Torkington            33
# 1                                 Nat Torkington            33
# 0                                 Nat Torkington            33
# 13                                Nat Torkington            32
# 12                                Nat Torkington            32
# 16                                Nat Torkington            32
# 18                                Nat Torkington            32
# 19                                Nat Torkington            32
# 20                                Nat Torkington            32
# 22                                Nat Torkington            32
# 21                                                          30
# 41                  Mike Loukides and Ben Lorica            24
# 17                                 Mike Loukides            22
# 50                                 Mike Loukides            11

# %% [markdown]
# ### 12. Create a list of entry titles whose summary includes the phrase "machine learning."

# %%
mach_learn = [atom.entries[i]['summary'] for i in range(len(atom.entries))]
dictionary = dict(zip(entry_titles, mach_learn))
text = "machine learning"
machine_learning = [e for e,s in dictionary.items() if text in s]
machine_learning
# Out:
# ['Four short links: 13 January 2020',
#  'Why you should care about debugging machine learning models',
#  'The road to Software 2.0',
#  'Moving AI and ML from research into production']
